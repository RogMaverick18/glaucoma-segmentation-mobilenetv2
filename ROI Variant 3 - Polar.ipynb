# %%
"""
V5: ORIGINAL CONFIG + HIGH-RES ROI ONLY (ABLATION)
====================================================================
Enhanced with three complementary modules from ODFormer/PSPNet for comprehensive feature enhancement
Plus glaucoma progression analysis with CDR-based severity classification

Triple Enhancement Strategy:
- MSCA (Multi-scale Context Aggregator): Multi-scale dilated convolutions [1,2,3,5]
- LBFR (Lightweight Bidirectional Feature Recalibrator): Channel + Spatial attention
- PPM (Pyramid Pooling Module): Multi-scale global context aggregation [1×1, 2×2, 3×3, 6×6]
- Sequential application: MSCA → LBFR → PPM on each decoder block
- Combines local multi-scale context + attention + global context

ROI Extraction:
- Automatically crops around the optic disc region from ground truth masks
- Resizes the ROI to 512×512 so the model sees a zoomed-in view of the disc/cup
- Dramatically reduces irrelevant background, improving segmentation accuracy
- For evaluation, predictions are mapped back to full image coordinates for CDR analysis

Glaucoma Scoring:
- CDR-based severity classification: Normal, Suspect, Moderate, Critical
- Area-based CDR calculation (robust & clinically relevant)
- Progression analysis with accuracy metrics
- Manual review recommendations for high-risk cases

Configuration:
- Base: Deeper Decoder + Focal-EIoU + MC Dropout
- Enhancement: MSCA + LBFR + PPM on decoder outputs
- Placement: All three modules after each decoder block (4 total)
- Total Attention Blocks: 12 (4 MSCA + 4 LBFR + 4 PPM)
"""

import os
import gc
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import albumentations as A
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, backend as K
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
from PIL import Image
import cv2
import math

warnings.filterwarnings('ignore')

# Set plot style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# ============================================================================
# GPU CONFIGURATION
# ============================================================================

def configure_gpu():
    """Configure GPU settings for optimal performance"""
    print("Configuring GPU settings...")
    physical_devices = tf.config.list_physical_devices('GPU')
    if physical_devices:
        try:
            for device in physical_devices:
                tf.config.experimental.set_memory_growth(device, True)
            print(f"✓ GPU configured: {len(physical_devices)} device(s) available")
            return True
        except RuntimeError as e:
            print(f"GPU configuration error: {e}")
            return False
    else:
        print("⚠ No GPU detected, running on CPU")
        return False

# ============================================================================
# DATA LOADING
# ============================================================================

def load_images_masks(images_folder, masks_folder, img_size=(512,512)):
    """Load images and masks from folders"""
    images, masks = [], []
    image_files = sorted(os.listdir(images_folder))
    mask_files = sorted(os.listdir(masks_folder))
    mask_dict = {os.path.splitext(f)[0]: f for f in mask_files}
    
    for img_file in image_files:
        img_path = os.path.join(images_folder, img_file)
        img = np.array(Image.open(img_path).resize(img_size)) / 255.0
        images.append(img)
        
        img_name = os.path.splitext(img_file)[0]
        if img_name in mask_dict:
            mask_path = os.path.join(masks_folder, mask_dict[img_name])
            mask = np.array(Image.open(mask_path).resize(img_size, Image.NEAREST))
            masks.append(mask)
        else:
            print(f"Warning: No mask found for {img_file}")
    
    return np.array(images, dtype=np.float32), np.array(masks, dtype=np.uint8)

def load_all_data(root_dir):
    """Load all data from existing splits and merge"""
    all_images, all_masks = [], []
    for split in ["train", "val", "test"]:
        print(f"Loading {split} data...")
        imgs, msks = load_images_masks(
            os.path.join(root_dir, split, "Images"),
            os.path.join(root_dir, split, "Masks")
        )
        all_images.append(imgs)
        all_masks.append(msks)
        print(f"  {split}: {imgs.shape[0]} samples")
    
    all_images = np.concatenate(all_images, axis=0)
    all_masks = np.concatenate(all_masks, axis=0)
    return all_images, all_masks

def create_new_split(all_images, all_masks):
    """Create new split: 600 train, 200 val, 400 test"""
    X_temp, X_test, y_temp, y_test = train_test_split(
        all_images, all_masks, test_size=400, random_state=42
    )
    X_train, X_val, y_train, y_val = train_test_split(
        X_temp, y_temp, test_size=200, random_state=42
    )
    print(f"Split - Train: {X_train.shape[0]}, Val: {X_val.shape[0]}, Test: {X_test.shape[0]}")
    return (X_train, y_train), (X_val, y_val), (X_test, y_test)


def load_all_data_with_highres_roi(root_dir, roi_size=(512, 512), padding_factor=1.2):
    """
    Load images at ORIGINAL resolution, extract ROI, resize to roi_size.
    
    KEY FIX: The original code loaded images at 512x512 first, then cropped ROI
    from the already-downsampled image. A ~200x200 crop from 512x512, upscaled
    back to 512x512 = BLURRY, detail-lost input.
    
    V5 FIX: Load at original resolution (~2000x2000), crop ROI (~600x600 real
    pixels), resize to 512x512. The model gets SHARP, high-resolution detail.
    Memory efficient: only one full-res image in memory at a time.
    """
    all_roi_images, all_roi_masks, all_full_masks_512 = [], [], []
    
    for split in ["train", "val", "test"]:
        images_folder = os.path.join(root_dir, split, "Images")
        masks_folder = os.path.join(root_dir, split, "Masks")
        image_files = sorted(os.listdir(images_folder))
        mask_files = sorted(os.listdir(masks_folder))
        mask_dict = {os.path.splitext(f)[0]: f for f in mask_files}
        
        count = 0
        for img_file in image_files:
            img_name = os.path.splitext(img_file)[0]
            if img_name not in mask_dict:
                continue
            
            # Load at ORIGINAL resolution - this is the key fix
            img_highres = np.array(Image.open(
                os.path.join(images_folder, img_file))) / 255.0
            mask_highres = np.array(Image.open(
                os.path.join(masks_folder, mask_dict[img_name])))
            
            # Extract ROI from HIGH-RES image
            roi_img, roi_msk, _ = extract_roi(
                img_highres, mask_highres, padding_factor, roi_size)
            
            all_roi_images.append(roi_img)
            all_roi_masks.append(roi_msk)
            
            # Save 512x512 full mask for CDR evaluation
            full_msk_512 = np.array(Image.fromarray(
                mask_highres).resize((512, 512), Image.NEAREST))
            all_full_masks_512.append(full_msk_512)
            
            # Free high-res data immediately
            del img_highres, mask_highres
            count += 1
        
        print(f"  {split}: {count} samples (original resolution -> ROI extracted)")
    
    return (np.array(all_roi_images, dtype=np.float32),
            np.array(all_roi_masks, dtype=np.uint8),
            np.array(all_full_masks_512, dtype=np.uint8))

# ============================================================================
# ROI EXTRACTION
# ============================================================================

def find_disc_region(mask, disc_class=1, cup_class=2):
    """
    Find the bounding box of the optic disc+cup region from a segmentation mask.
    
    Args:
        mask: Segmentation mask (H, W) with class labels
        disc_class: Class label for optic disc (default=1)
        cup_class: Class label for optic cup (default=2)
    
    Returns:
        (center_y, center_x, radius) or None if no disc found
    """
    # Use both disc and cup pixels to define the ROI region
    roi_mask = ((mask == disc_class) | (mask == cup_class)).astype(np.uint8)
    
    if roi_mask.sum() == 0:
        return None
    
    coords = np.where(roi_mask > 0)
    y_min, y_max = coords[0].min(), coords[0].max()
    x_min, x_max = coords[1].min(), coords[1].max()
    
    center_y = (y_min + y_max) // 2
    center_x = (x_min + x_max) // 2
    
    height = y_max - y_min
    width = x_max - x_min
    radius = max(height, width) // 2
    
    return center_y, center_x, radius


def extract_roi(image, mask, padding_factor=1.2, roi_size=(512, 512)):
    """
    Extract ROI around the optic disc from image and mask.
    
    Crops a square region centered on the disc with padding, then resizes to roi_size.
    This lets the model see a zoomed-in view of the disc/cup instead of the full fundus.
    
    Args:
        image: Input image (H, W, 3), float32 [0, 1]
        mask: Segmentation mask (H, W), uint8
        padding_factor: How much to expand the ROI beyond the disc boundary (1.5 = 50% extra)
        roi_size: Output size for the ROI crop (default 512×512)
    
    Returns:
        roi_image: Cropped and resized image (roi_size[0], roi_size[1], 3)
        roi_mask: Cropped and resized mask (roi_size[0], roi_size[1])
        roi_coords: (y1, x1, y2, x2) crop coordinates in original image space
    """
    result = find_disc_region(mask)
    
    if result is None:
        # No disc found — return the full image (fallback)
        h, w = image.shape[:2]
        return image.copy(), mask.copy(), (0, 0, h, w)
    
    center_y, center_x, radius = result
    h, w = image.shape[:2]
    
    # Expand ROI with padding factor; enforce a minimum size
    roi_half = int(radius * padding_factor)
    roi_half = max(roi_half, 60)  # minimum half-size to avoid too-small crops
    
    # Calculate crop bounds (keep square, clamp to image boundaries)
    y1 = max(0, center_y - roi_half)
    y2 = min(h, center_y + roi_half)
    x1 = max(0, center_x - roi_half)
    x2 = min(w, center_x + roi_half)
    
    # Make the crop square by expanding the shorter side if possible
    crop_h = y2 - y1
    crop_w = x2 - x1
    if crop_h > crop_w:
        diff = crop_h - crop_w
        x1 = max(0, x1 - diff // 2)
        x2 = min(w, x1 + crop_h)
        x1 = max(0, x2 - crop_h)  # re-adjust if x2 hit boundary
    elif crop_w > crop_h:
        diff = crop_w - crop_h
        y1 = max(0, y1 - diff // 2)
        y2 = min(h, y1 + crop_w)
        y1 = max(0, y2 - crop_w)  # re-adjust if y2 hit boundary
    
    # Crop
    roi_image = image[y1:y2, x1:x2]
    roi_mask = mask[y1:y2, x1:x2]
    
    # Resize to model input size
    roi_image_pil = Image.fromarray((roi_image * 255).astype(np.uint8))
    roi_image_resized = np.array(roi_image_pil.resize(roi_size, Image.BILINEAR)) / 255.0
    
    roi_mask_pil = Image.fromarray(roi_mask)
    roi_mask_resized = np.array(roi_mask_pil.resize(roi_size, Image.NEAREST))
    
    return roi_image_resized.astype(np.float32), roi_mask_resized.astype(np.uint8), (y1, x1, y2, x2)


def extract_roi_batch(images, masks, padding_factor=1.2, roi_size=(512, 512)):
    """
    Extract ROI for an entire batch of images and masks.
    
    Args:
        images: (N, H, W, 3) float32
        masks: (N, H, W) uint8
        padding_factor: ROI padding factor
        roi_size: Output ROI size
    
    Returns:
        roi_images: (N, roi_size[0], roi_size[1], 3) float32
        roi_masks: (N, roi_size[0], roi_size[1]) uint8
        roi_coords_list: List of (y1, x1, y2, x2) tuples
    """
    roi_images, roi_masks, roi_coords_list = [], [], []
    
    for i in range(len(images)):
        roi_img, roi_msk, coords = extract_roi(
            images[i], masks[i], padding_factor=padding_factor, roi_size=roi_size
        )
        roi_images.append(roi_img)
        roi_masks.append(roi_msk)
        roi_coords_list.append(coords)
    
    return (np.array(roi_images, dtype=np.float32),
            np.array(roi_masks, dtype=np.uint8),
            roi_coords_list)


def map_roi_prediction_to_full(pred_mask_roi, roi_coords, full_size=(512, 512)):
    """
    Map a prediction made on an ROI crop back to the full image coordinates.
    
    Args:
        pred_mask_roi: Predicted mask on the ROI (roi_H, roi_W) with class labels
        roi_coords: (y1, x1, y2, x2) crop coordinates from extract_roi
        full_size: Size of the original full image (H, W)
    
    Returns:
        full_mask: (full_H, full_W) prediction mapped to full image (background=0 outside ROI)
    """
    y1, x1, y2, x2 = roi_coords
    crop_h = y2 - y1
    crop_w = x2 - x1
    
    # Resize prediction back to the original crop dimensions
    pred_pil = Image.fromarray(pred_mask_roi.astype(np.uint8))
    pred_resized = np.array(pred_pil.resize((crop_w, crop_h), Image.NEAREST))
    
    # Place into full-size mask
    full_mask = np.zeros(full_size, dtype=np.uint8)
    full_mask[y1:y2, x1:x2] = pred_resized
    
    return full_mask


def visualize_roi_extraction(images, masks, num_samples=4):
    """Visualize ROI extraction to verify correctness"""
    fig, axes = plt.subplots(num_samples, 4, figsize=(16, 4 * num_samples))
    
    for i in range(min(num_samples, len(images))):
        roi_img, roi_msk, coords = extract_roi(images[i], masks[i])
        y1, x1, y2, x2 = coords
        
        # Original image
        axes[i, 0].imshow(images[i])
        axes[i, 0].set_title('Original Image', fontsize=11, fontweight='bold')
        # Draw ROI rectangle
        rect = plt.Rectangle((x1, y1), x2 - x1, y2 - y1,
                              linewidth=2, edgecolor='lime', facecolor='none')
        axes[i, 0].add_patch(rect)
        axes[i, 0].axis('off')
        
        # Original mask
        axes[i, 1].imshow(masks[i], cmap='jet', vmin=0, vmax=2)
        axes[i, 1].set_title('Original Mask', fontsize=11, fontweight='bold')
        rect2 = plt.Rectangle((x1, y1), x2 - x1, y2 - y1,
                               linewidth=2, edgecolor='lime', facecolor='none')
        axes[i, 1].add_patch(rect2)
        axes[i, 1].axis('off')
        
        # ROI image
        axes[i, 2].imshow(roi_img)
        axes[i, 2].set_title(f'ROI Image ({roi_img.shape[0]}×{roi_img.shape[1]})',
                             fontsize=11, fontweight='bold')
        axes[i, 2].axis('off')
        
        # ROI mask
        axes[i, 3].imshow(roi_msk, cmap='jet', vmin=0, vmax=2)
        axes[i, 3].set_title(f'ROI Mask ({roi_msk.shape[0]}×{roi_msk.shape[1]})',
                             fontsize=11, fontweight='bold')
        axes[i, 3].axis('off')
    
    plt.suptitle('ROI Extraction Verification — green box shows crop region',
                 fontsize=14, fontweight='bold', y=1.01)
    plt.tight_layout()
    plt.show()
    plt.close()



# ============================================================================
# POLAR TRANSFORM
# ============================================================================

def cartesian_to_polar(image, center=None, output_size=(512, 512)):
    h, w = image.shape[:2]
    if center is None:
        center = (h // 2, w // 2)
    cy, cx = center
    polar_h, polar_w = output_size

    y_coords, x_coords = np.indices((polar_h, polar_w), dtype=np.float32)
    angles = (y_coords / max(1.0, polar_h - 1.0)) * (2.0 * np.pi)
    max_radius = min(cy, cx, h - cy - 1, w - cx - 1)
    radii = (x_coords / max(1.0, polar_w - 1.0)) * max_radius

    map_x = (cx + radii * np.cos(angles)).astype(np.float32)
    map_y = (cy + radii * np.sin(angles)).astype(np.float32)

    interp = cv2.INTER_LINEAR if image.ndim == 3 else cv2.INTER_NEAREST
    return cv2.remap(image, map_x, map_y, interp, borderMode=cv2.BORDER_CONSTANT, borderValue=0)


def transform_to_polar_batch(images, masks, output_size=(512, 512)):
    # Operate in-place to save memory
    for i in range(len(images)):
        h, w = images[i].shape[:2]
        center = (h // 2, w // 2)
        images[i] = cartesian_to_polar(images[i], center=center, output_size=output_size)
        masks[i] = cartesian_to_polar(masks[i], center=center, output_size=output_size).astype(np.uint8)
    return images, masks

# ============================================================================
# DATA AUGMENTATION
# ============================================================================

def setup_augmentations():
    return A.Compose([
        # --- Geometric (most impactful for segmentation) ---
        A.HorizontalFlip(p=0.5),
        A.VerticalFlip(p=0.3),
        A.ShiftScaleRotate(shift_limit=0.05, scale_limit=0.10, rotate_limit=20,
                           border_mode=0, p=0.6),
        A.ElasticTransform(alpha=30, sigma=5, p=0.2),
        # --- Colour (keep existing, slightly widened) ---
        A.RandomBrightnessContrast(brightness_limit=0.20, contrast_limit=0.20, p=0.7),
        A.HueSaturationValue(hue_shift_limit=10, sat_shift_limit=20, val_shift_limit=10, p=0.5),
        A.GaussianBlur(blur_limit=3, p=0.3),
        A.RandomGamma(gamma_limit=(80, 120), p=0.3),
    ])

def data_generator(images, masks, batch_size, augment=None):
    idxs = np.arange(len(images))
    while True:
        np.random.shuffle(idxs)
        for i in range(0, len(images), batch_size):
            batch_idxs = idxs[i:i+batch_size]
            batch_x, batch_y = [], []
            
            for idx in batch_idxs:
                img, mask = images[idx], masks[idx]
                
                if augment:
                    aug = augment(image=img, mask=mask)
                    img_aug, mask_aug = aug['image'], aug['mask']
                else:
                    img_aug, mask_aug = img, mask
                
                mask_cat = to_categorical(mask_aug, num_classes=3)
                batch_x.append(img_aug)
                batch_y.append(mask_cat)
            
            yield np.stack(batch_x).astype(np.float32), np.stack(batch_y).astype(np.float32)

# ============================================================================
# MSCA MODULE (FROM ODFORMER)
# ============================================================================

def msca_block(x, channels, dilation_rates=[1, 2, 3, 5], block_name='msca'):
    """
    Multi-scale Context Aggregator (MSCA) from ODFormer
    
    Features:
    - Multi-scale feature extraction using dilated convolutions
    - Parallel branches with different dilation rates [1, 2, 3, 5]
    - Feature fusion through concatenation and 1×1 convolution
    - Residual connection for gradient flow
    
    Args:
        x: Input feature map
        channels: Number of output channels
        dilation_rates: List of dilation rates for multi-scale context
        block_name: Name prefix for layers
    """
    multi_scale_features = []
    filters_per_branch = channels // len(dilation_rates)
    
    # Multi-scale branches with different dilation rates
    for i, rate in enumerate(dilation_rates):
        branch = layers.Conv2D(
            filters_per_branch,
            (3, 3),
            padding='same',
            dilation_rate=rate,
            use_bias=False,
            name=f'{block_name}_dil{rate}_conv'
        )(x)
        branch = layers.BatchNormalization(name=f'{block_name}_dil{rate}_bn')(branch)
        branch = layers.Activation('relu', name=f'{block_name}_dil{rate}_relu')(branch)
        multi_scale_features.append(branch)
    
    # Concatenate all branches
    concat = layers.Concatenate(name=f'{block_name}_concat')(multi_scale_features)
    
    # Fusion layer to combine multi-scale features
    fused = layers.Conv2D(channels, (1, 1), use_bias=False, name=f'{block_name}_fusion')(concat)
    fused = layers.BatchNormalization(name=f'{block_name}_fusion_bn')(fused)
    fused = layers.Activation('relu', name=f'{block_name}_fusion_relu')(fused)
    
    # Residual connection
    output = layers.Add(name=f'{block_name}_residual')([x, fused])
    
    return output

# ============================================================================
# LBFR MODULE (FROM ODFORMER)
# ============================================================================

def lbfr_block(x, channels, reduction=16, block_name='lbfr'):
    """
    Lightweight Bidirectional Feature Recalibrator (LBFR) from ODFormer
    
    Features:
    - Channel attention using both avg and max pooling
    - Spatial attention using 2-channel feature concatenation
    - Recalibration layer with BatchNormalization
    - Residual connection for gradient flow
    
    Args:
        x: Input feature map
        channels: Number of channels
        reduction: Channel reduction ratio for attention bottleneck
        block_name: Name prefix for layers
    """
    # Channel Attention
    # Average pooling branch
    avg_pool = layers.GlobalAveragePooling2D(name=f'{block_name}_avg_pool')(x)
    avg_pool = layers.Reshape((1, 1, channels), name=f'{block_name}_avg_reshape')(avg_pool)
    
    # Max pooling branch
    max_pool = layers.GlobalMaxPooling2D(name=f'{block_name}_max_pool')(x)
    max_pool = layers.Reshape((1, 1, channels), name=f'{block_name}_max_reshape')(max_pool)
    
    # Shared MLP for channel attention
    fc1 = layers.Conv2D(channels // reduction, (1, 1), use_bias=False, name=f'{block_name}_fc1')
    fc2 = layers.Conv2D(channels, (1, 1), use_bias=False, name=f'{block_name}_fc2')
    
    avg_out = fc1(avg_pool)
    avg_out = layers.Activation('relu', name=f'{block_name}_fc1_relu_avg')(avg_out)
    avg_out = fc2(avg_out)
    
    max_out = fc1(max_pool)
    max_out = layers.Activation('relu', name=f'{block_name}_fc1_relu_max')(max_out)
    max_out = fc2(max_out)
    
    # Combine and apply channel attention
    channel_att = layers.Add(name=f'{block_name}_channel_add')([avg_out, max_out])
    channel_att = layers.Activation('sigmoid', name=f'{block_name}_channel_sigmoid')(channel_att)
    x_channel = layers.Multiply(name=f'{block_name}_channel_multiply')([x, channel_att])
    
    # Spatial Attention
    # Average and max across channels
    avg_spatial = layers.Lambda(lambda x: K.mean(x, axis=-1, keepdims=True), 
                                name=f'{block_name}_spatial_avg')(x_channel)
    max_spatial = layers.Lambda(lambda x: K.max(x, axis=-1, keepdims=True),
                                name=f'{block_name}_spatial_max')(x_channel)
    
    # Concatenate and apply spatial attention
    spatial_concat = layers.Concatenate(name=f'{block_name}_spatial_concat')([avg_spatial, max_spatial])
    spatial_att = layers.Conv2D(1, (7, 7), padding='same', use_bias=False,
                                name=f'{block_name}_spatial_conv')(spatial_concat)
    spatial_att = layers.Activation('sigmoid', name=f'{block_name}_spatial_sigmoid')(spatial_att)
    x_spatial = layers.Multiply(name=f'{block_name}_spatial_multiply')([x_channel, spatial_att])
    
    # Recalibration
    recalibrated = layers.Conv2D(channels, (1, 1), use_bias=False, 
                                 name=f'{block_name}_recalibrate')(x_spatial)
    recalibrated = layers.BatchNormalization(name=f'{block_name}_recalibrate_bn')(recalibrated)
    
    # Residual connection
    output = layers.Add(name=f'{block_name}_residual')([x, recalibrated])
    
    return output

# ============================================================================
# PPM MODULE (FROM PSPNET/ODFORMER)
# ============================================================================

def ppm_block(x, channels, pool_scales=[1, 2, 3, 6], block_name='ppm'):
    """
    Pyramid Pooling Module (PPM) from PSPNet
    
    Features:
    - Multi-scale adaptive pooling at different pyramid levels
    - Captures global context at scales: 1×1, 2×2, 3×3, 6×6
    - Lightweight 1×1 convolutions for each scale
    - Feature fusion through concatenation
    
    Args:
        x: Input feature map
        channels: Number of output channels
        pool_scales: List of pooling scales for pyramid levels
        block_name: Name prefix for layers
    """
    h, w = x.shape[1], x.shape[2]
    
    # Store original features
    ppm_features = [x]
    
    # Multi-scale pooling branches
    filters_per_scale = channels // len(pool_scales)
    
    for i, scale in enumerate(pool_scales):
        # Global average pooling to fixed scale size
        pool_h = max(h // scale, 1)
        pool_w = max(w // scale, 1)
        
        pooled = layers.AveragePooling2D(
            pool_size=(h // pool_h, w // pool_w),
            strides=(h // pool_h, w // pool_w),
            name=f'{block_name}pool{scale}x{scale}'
        )(x)
        
        # 1×1 convolution to reduce channels
        conv = layers.Conv2D(
            filters_per_scale,
            (1, 1),
            use_bias=False,
            name=f'{block_name}conv{scale}x{scale}'
        )(pooled)
        conv = layers.BatchNormalization(name=f'{block_name}bn{scale}x{scale}')(conv)
        conv = layers.Activation('relu', name=f'{block_name}relu{scale}x{scale}')(conv)
        
        # Upsample back to original size using exact target dimensions
        upsampled = layers.Resizing(
            h, w,
            interpolation='bilinear',
            name=f'{block_name}upsample{scale}x{scale}'
        )(conv)
        
        ppm_features.append(upsampled)
    
    # Concatenate all pyramid features
    concat = layers.Concatenate(name=f'{block_name}_concat')(ppm_features)
    
    # Fusion convolution
    fused = layers.Conv2D(
        channels,
        (3, 3),
        padding='same',
        use_bias=False,
        name=f'{block_name}_fusion'
    )(concat)
    fused = layers.BatchNormalization(name=f'{block_name}_fusion_bn')(fused)
    fused = layers.Activation('relu', name=f'{block_name}_fusion_relu')(fused)
    
    return fused

# ============================================================================
# LOSS FUNCTIONS
# ============================================================================

def focal_loss(y_true, y_pred, gamma=2.0, alpha=None, epsilon=1e-7):
    if alpha is None:
        alpha = [0.25, 1.0, 1.0]
    
    y_pred = K.clip(y_pred, epsilon, 1.0 - epsilon)
    focal_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        
        bce = -(y_true_c * K.log(y_pred_c) + (1 - y_true_c) * K.log(1 - y_pred_c))
        pt = y_true_c * y_pred_c + (1 - y_true_c) * (1 - y_pred_c)
        focal_weight = K.pow(1 - pt, gamma)
        
        focal_loss_value += alpha[c] * K.mean(focal_weight * bce)
    
    return focal_loss_value

def enhanced_iou_loss(y_true, y_pred, smooth=1e-7):
    eiou_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        
        intersection = K.sum(y_true_c * y_pred_c, axis=[1, 2])
        union = K.sum(y_true_c, axis=[1, 2]) + K.sum(y_pred_c, axis=[1, 2]) - intersection
        iou = (intersection + smooth) / (union + smooth)
        
        # Fix: K.min/max on the binary mask values gives the min/max VALUE (always
        # 0 or 1), not the spatial INDEX of the mask boundary.  Use coordinate
        # grids so that the reduction over the spatial axis returns the actual
        # normalised row/col position of the bounding-box edges.
        binary_true = K.cast(y_true_c > 0.5, 'float32')   # [batch, H, W]
        binary_pred = K.cast(y_pred_c > 0.5, 'float32')

        _h = tf.cast(tf.shape(y_true_c)[1], 'float32')
        _w = tf.cast(tf.shape(y_true_c)[2], 'float32')
        row_coords = tf.reshape(tf.range(tf.shape(y_true_c)[1], dtype=tf.float32) / _h, [1, -1, 1])  # [1,H,1]
        col_coords = tf.reshape(tf.range(tf.shape(y_true_c)[2], dtype=tf.float32) / _w, [1, 1, -1])  # [1,1,W]

        # Presence along each axis (1 if that row/col contains any mask pixel)
        rp_t = K.max(binary_true, axis=2, keepdims=True)   # [batch, H, 1]
        rp_p = K.max(binary_pred, axis=2, keepdims=True)
        cp_t = K.max(binary_true, axis=1, keepdims=True)   # [batch, 1, W]
        cp_p = K.max(binary_pred, axis=1, keepdims=True)

        # y_min: smallest row index with mask present; add 1 where absent so min ignores them
        y_min_t = K.min(row_coords + (1.0 - rp_t), axis=[1, 2])   # [batch]
        y_max_t = K.max(row_coords * rp_t,          axis=[1, 2])
        x_min_t = K.min(col_coords + (1.0 - cp_t), axis=[1, 2])
        x_max_t = K.max(col_coords * cp_t,          axis=[1, 2])

        y_min_p = K.min(row_coords + (1.0 - rp_p), axis=[1, 2])
        y_max_p = K.max(row_coords * rp_p,          axis=[1, 2])
        x_min_p = K.min(col_coords + (1.0 - cp_p), axis=[1, 2])
        x_max_p = K.max(col_coords * cp_p,          axis=[1, 2])

        # Bboxes now have correct shape [batch, 4] where indices are [y_min, x_min, y_max, x_max]
        y_true_bbox = K.stack([y_min_t, x_min_t, y_max_t, x_max_t], axis=-1)
        y_pred_bbox = K.stack([y_min_p, x_min_p, y_max_p, x_max_p], axis=-1)
        
        center_true = K.stack([
            (y_true_bbox[:, 0] + y_true_bbox[:, 2]) / 2.0,
            (y_true_bbox[:, 1] + y_true_bbox[:, 3]) / 2.0
        ], axis=-1)
        
        center_pred = K.stack([
            (y_pred_bbox[:, 0] + y_pred_bbox[:, 2]) / 2.0,
            (y_pred_bbox[:, 1] + y_pred_bbox[:, 3]) / 2.0
        ], axis=-1)
        
        center_distance = K.sum(K.square(center_true - center_pred), axis=-1)
        
        diag_length = K.square(y_true_bbox[:, 2] - y_true_bbox[:, 0]) + \
                     K.square(y_true_bbox[:, 3] - y_true_bbox[:, 1])
        
        diag_length = K.maximum(diag_length, 1e-7)
        
        eiou = iou - (center_distance / diag_length)
        eiou_loss_value += K.mean(1.0 - eiou)
    
    return eiou_loss_value / 3.0

def focal_eiou_combined_loss(y_true, y_pred, focal_weight=1.0, eiou_weight=1.0, gamma=2.0, alpha=None):
    fl = focal_loss(y_true, y_pred, gamma=gamma, alpha=alpha)
    eiou = enhanced_iou_loss(y_true, y_pred)
    return focal_weight * fl + eiou_weight * eiou

# ============================================================================
# MODEL ARCHITECTURE WITH MSCA + LBFR + PPM
# ============================================================================

def enhanced_decoder_block_with_triple_attention(x, skip_connection, filters, block_name, dropout_rate=0.3):
    """
    Enhanced decoder block with MSCA + LBFR + PPM triple attention
    
    Sequential enhancement strategy:
    1. Standard decoder convolutions with residual connection
    2. MSCA for multi-scale local context aggregation (dilated convs)
    3. LBFR for bidirectional feature recalibration (channel + spatial attention)
    4. PPM for multi-scale global context aggregation (pyramid pooling)
    
    This combines three complementary attention mechanisms:
    - MSCA: Local multi-scale receptive fields
    - LBFR: Channel and spatial recalibration
    - PPM: Global multi-scale context
    """
    x = layers.UpSampling2D((2, 2), name=f'{block_name}_upsample')(x)
    
    if skip_connection.shape[-1] != x.shape[-1]:
        skip_connection = layers.Conv2D(x.shape[-1], (1, 1), padding='same', 
                                       name=f'{block_name}_skip_adjust')(skip_connection)
    
    x = layers.Concatenate(name=f'{block_name}_concat')([x, skip_connection])
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv1')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn1')(x)
    x = layers.Dropout(dropout_rate, name=f'{block_name}_dropout')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv2')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn2')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv3')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn3')(x)
    
    residual = x
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv4')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn4')(x)
    
    x = layers.Add(name=f'{block_name}_residual')([x, residual])
    x = layers.Conv2D(filters, (1, 1), activation='relu', padding='same', name=f'{block_name}_conv_final')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn_final')(x)
    
    # Apply MSCA for local multi-scale context aggregation
    x = msca_block(x, filters, dilation_rates=[1, 2, 3, 5], block_name=f'{block_name}_msca')
    
    # Apply LBFR for bidirectional feature recalibration
    x = lbfr_block(x, filters, reduction=16, block_name=f'{block_name}_lbfr')
    
    # Apply PPM for global multi-scale context aggregation
    x = ppm_block(x, filters, pool_scales=[1, 2, 3, 6], block_name=f'{block_name}_ppm')
    
    return x

def build_unet_with_triple_attention(input_shape=(512, 512, 3), num_classes=3, dropout_rate=0.3):
    """Build MobileNetV2-UNet with MSCA + LBFR + PPM triple attention"""
    inputs = layers.Input(input_shape, dtype='float32')
    backbone = MobileNetV2(input_tensor=inputs, weights='imagenet', include_top=False)
    
    skip_1 = backbone.get_layer('block_1_expand_relu').output  # 128×128
    skip_2 = backbone.get_layer('block_3_expand_relu').output  # 64×64
    skip_3 = backbone.get_layer('block_6_expand_relu').output  # 32×32
    skip_4 = backbone.get_layer('block_13_expand_relu').output # 16×16
    bridge = backbone.output  # 8×8
    
    # Deeper bridge
    bridge = layers.Conv2D(1024, (3, 3), activation='relu', padding='same')(bridge)
    bridge = layers.BatchNormalization()(bridge)
    bridge = layers.Dropout(dropout_rate, name='bridge_dropout')(bridge)
    
    # Decoder with triple attention (MSCA + LBFR + PPM)
    x = enhanced_decoder_block_with_triple_attention(bridge, skip_4, 512, 'decoder_1', dropout_rate)
    x = enhanced_decoder_block_with_triple_attention(x, skip_3, 256, 'decoder_2', dropout_rate)
    x = enhanced_decoder_block_with_triple_attention(x, skip_2, 128, 'decoder_3', dropout_rate * 0.7)
    x = enhanced_decoder_block_with_triple_attention(x, skip_1, 64, 'decoder_4', dropout_rate * 0.5)
    
    # Final upsampling
    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    
    outputs = layers.Conv2D(num_classes, (1, 1), activation='softmax', dtype='float32')(x)
    
    model = models.Model(inputs, outputs)
    
    # Print configuration
    dropout_layers = [layer for layer in model.layers if isinstance(layer, layers.Dropout)]
    print(f"\nModel Configuration:")
    print(f"  Total Parameters: {model.count_params():,}")
    print(f"  Dropout Layers: {len(dropout_layers)}")
    print(f"  Triple Attention Modules: MSCA + LBFR + PPM per decoder block")
    print(f"  MSCA Modules: 4 (local multi-scale with dilation rates [1,2,3,5])")
    print(f"  LBFR Modules: 4 (channel + spatial attention + recalibration)")
    print(f"  PPM Modules: 4 (global pyramid pooling [1×1, 2×2, 3×3, 6×6])")
    print(f"  Enhancement Strategy: Sequential MSCA → LBFR → PPM per block")
    print(f"  Total Attention Blocks: 12 (4 MSCA + 4 LBFR + 4 PPM)")
    print(f"  Context Coverage: Local Multi-scale + Attention + Global Multi-scale")
    
    return model

# ============================================================================
# METRICS
# ============================================================================

def dice_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    return (2. * intersection + smooth) / (K.sum(y_true_class) + K.sum(y_pred_class) + smooth)

def dice_class_0(y_true, y_pred): return dice_coef_class(y_true, y_pred, 0)
def dice_class_1(y_true, y_pred): return dice_coef_class(y_true, y_pred, 1)
def dice_class_2(y_true, y_pred): return dice_coef_class(y_true, y_pred, 2)

def iou_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    union = K.sum(y_true_class) + K.sum(y_pred_class) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_class_0(y_true, y_pred): return iou_coef_class(y_true, y_pred, 0)
def iou_class_1(y_true, y_pred): return iou_coef_class(y_true, y_pred, 1)
def iou_class_2(y_true, y_pred): return iou_coef_class(y_true, y_pred, 2)

def mc_dropout_predict(model, X, num_samples=15, batch_size=4, verbose=True):
    """MC Dropout prediction for uncertainty estimation - Memory Optimized"""
    if verbose:
        print(f"\nRunning MC Dropout with {num_samples} stochastic forward passes...")
    
    # Initialize accumulators
    sum_preds = None
    sum_sq_preds = None
    
    num_batches = int(np.ceil(len(X) / batch_size))
    
    for i in range(num_samples):
        if verbose and (i + 1) % 5 == 0:
            print(f"  Completed: {i+1}/{num_samples} forward passes")
        
        batch_preds = []
        for batch_idx in range(num_batches):
            start_idx = batch_idx * batch_size
            end_idx = min(start_idx + batch_size, len(X))
            X_batch = X[start_idx:end_idx]
            
            # Predict with training=True for dropout
            pred_batch = model(X_batch, training=True)
            batch_preds.append(pred_batch.numpy())
        
        # Concatenate batches for current pass
        current_pass_preds = np.concatenate(batch_preds, axis=0)
        
        # Accumulate sums
        if sum_preds is None:
            sum_preds = current_pass_preds.astype(np.float32)
            sum_sq_preds = np.square(current_pass_preds).astype(np.float32)
        else:
            sum_preds += current_pass_preds
            sum_sq_preds += np.square(current_pass_preds)
        
        # Free memory
        del current_pass_preds, batch_preds
        if (i + 1) % 5 == 0:
            gc.collect()
    
    # Calculate Mean and Std
    mean_pred = sum_preds / num_samples
    
    # Var = E[X^2] - (E[X])^2
    # Std = sqrt(Var)
    mean_sq_pred = sum_sq_preds / num_samples
    var_pred = mean_sq_pred - np.square(mean_pred)
    # Ensure non-negative variance due to float precision
    var_pred = np.maximum(var_pred, 0)
    std_pred = np.sqrt(var_pred)
    
    # Cleanup
    del sum_preds, sum_sq_preds
    gc.collect()
    
    if verbose:
        print(f"✓ MC Dropout completed")
    
    return mean_pred, std_pred

# ============================================================================
# GLAUCOMA PROGRESSION SCORING
# ============================================================================

def calculate_cdr(mask, disc_class=1, cup_class=2, method='vertical'):
    """
    Calculate Cup-to-Disc Ratio (CDR) from segmentation mask
    
    Methods:
    - 'vertical': Vertical diameter ratio (clinical standard, most accurate)
    - 'area_sqrt': Square root of area ratio (robust alternative)
    
    Args:
        mask: Segmentation mask (H, W) with class labels
        disc_class: Class label for optic disc (default=1)
        cup_class: Class label for optic cup (default=2)
        method: Calculation method (default='vertical')
    
    Returns:
        dict with vCDR, hCDR, avgCDR, area_CDR
    """
    disc_mask = (mask == disc_class).astype(np.uint8)
    cup_mask = (mask == cup_class).astype(np.uint8)
    
    # Check if disc and cup are present
    disc_area = disc_mask.sum()
    cup_area = cup_mask.sum()
    
    if disc_area == 0 or cup_area == 0:
        return {'vCDR': 0.0, 'hCDR': 0.0, 'avgCDR': 0.0, 'area_CDR': 0.0, 'valid': False, 
                'method': method, 'disc_area': 0, 'cup_area': 0}
    
    # Find coordinates
    disc_coords = np.where(disc_mask > 0)
    cup_coords = np.where(cup_mask > 0)
    
    # Calculate diameters using bounding box
    disc_v_diameter = disc_coords[0].max() - disc_coords[0].min() + 1
    cup_v_diameter = cup_coords[0].max() - cup_coords[0].min() + 1
    disc_h_diameter = disc_coords[1].max() - disc_coords[1].min() + 1
    cup_h_diameter = cup_coords[1].max() - cup_coords[1].min() + 1
    
    # Calculate CDRs
    vCDR = cup_v_diameter / disc_v_diameter if disc_v_diameter > 0 else 0.0
    hCDR = cup_h_diameter / disc_h_diameter if disc_h_diameter > 0 else 0.0
    
    # Calculate area-based CDR
    area_CDR = np.sqrt(cup_area / disc_area)
    
    # Choose primary CDR based on method
    if method == 'vertical':
        avgCDR = vCDR  # Use vertical CDR (clinical standard)
    elif method == 'area_sqrt':
        avgCDR = area_CDR  # Use area-based
    else:
        avgCDR = (vCDR + hCDR) / 2.0  # Average of both
    
    return {
        'vCDR': float(vCDR),
        'hCDR': float(hCDR),
        'avgCDR': float(avgCDR),
        'area_CDR': float(area_CDR),
        'valid': True,
        'method': method,
        'disc_area': int(disc_area),
        'cup_area': int(cup_area),
        'disc_v_diameter': int(disc_v_diameter),
        'cup_v_diameter': int(cup_v_diameter)
    }

def classify_glaucoma_severity(cdr):
    """
    Classify glaucoma severity based on CDR
    
    Classification:
    - Normal: CDR < 0.3
    - Suspect: 0.3 ≤ CDR < 0.6
    - Moderate: 0.6 ≤ CDR < 0.8
    - Critical: CDR ≥ 0.8
    
    Args:
        cdr: Cup-to-Disc Ratio (float)
    
    Returns:
        tuple: (severity_class, severity_label, color)
    """
    if cdr < 0.3:
        return 0, 'Normal', '#4CAF50'  # Green
    elif cdr < 0.6:
        return 1, 'Suspect', '#FFC107'  # Amber
    elif cdr < 0.8:
        return 2, 'Moderate', '#FF9800'  # Orange
    else:
        return 3, 'Critical', '#F44336'  # Red

def analyze_glaucoma_progression(masks, predictions, cdr_method='area_sqrt'):
    """
    Analyze glaucoma progression for a batch of samples
    
    Args:
        masks: Ground truth masks (N, H, W)
        predictions: Predicted masks (N, H, W)
        cdr_method: CDR calculation method (default='area_sqrt' for robustness)
    
    Returns:
        DataFrame with CDR metrics and classifications
    """
    results = []
    
    for i, (gt_mask, pred_mask) in enumerate(zip(masks, predictions)):
        # Calculate CDR for ground truth
        gt_cdr = calculate_cdr(gt_mask, method=cdr_method)
        
        # Calculate CDR for prediction
        pred_cdr = calculate_cdr(pred_mask, method=cdr_method)
        
        # Classify severity
        if gt_cdr['valid']:
            gt_class, gt_label, gt_color = classify_glaucoma_severity(gt_cdr['avgCDR'])
        else:
            gt_class, gt_label, gt_color = -1, 'Invalid', '#9E9E9E'
        
        if pred_cdr['valid']:
            pred_class, pred_label, pred_color = classify_glaucoma_severity(pred_cdr['avgCDR'])
        else:
            pred_class, pred_label, pred_color = -1, 'Invalid', '#9E9E9E'
        
        # Calculate CDR error
        cdr_error = abs(gt_cdr['avgCDR'] - pred_cdr['avgCDR']) if gt_cdr['valid'] and pred_cdr['valid'] else np.nan
        
        # Check if classification matches
        severity_match = (gt_label == pred_label)
        
        # Manual review needed: Critical cases or mismatches
        manual_review = (gt_label == 'Critical') or (not severity_match)
        
        results.append({
            'Sample': i + 1,
            'GT_vCDR': gt_cdr['vCDR'],
            'GT_hCDR': gt_cdr['hCDR'],
            'GT_avgCDR': gt_cdr['avgCDR'],
            'GT_area_CDR': gt_cdr['area_CDR'],
            'GT_Severity': gt_label,
            'Pred_vCDR': pred_cdr['vCDR'],
            'Pred_hCDR': pred_cdr['hCDR'],
            'Pred_avgCDR': pred_cdr['avgCDR'],
            'Pred_area_CDR': pred_cdr['area_CDR'],
            'Pred_Severity': pred_label,
            'CDR_Error': cdr_error,
            'Severity_Match': severity_match,
            'Manual_Review_Needed': manual_review
        })
    
    return pd.DataFrame(results)

def calculate_progression_accuracy(df_progression):
    """
    Calculate simple accuracy metrics: GT progression vs Predicted progression
    
    Returns accuracy % like: "GT says Normal for 250 images, model says 230 are Normal"
    """
    results = {}
    
    # Overall accuracy
    total = len(df_progression)
    correct = df_progression['Severity_Match'].sum()
    overall_accuracy = (correct / total) * 100
    
    results['overall'] = {
        'total': total,
        'correct': correct,
        'accuracy': overall_accuracy
    }
    
    # Per-class accuracy
    severity_classes = ['Normal', 'Suspect', 'Moderate', 'Critical']
    results['per_class'] = {}
    
    for severity in severity_classes:
        gt_count = len(df_progression[df_progression['GT_Severity'] == severity])
        pred_count = len(df_progression[df_progression['Pred_Severity'] == severity])
        
        # Correctly predicted: GT is this class AND model predicted it as this class
        correct_count = len(df_progression[
            (df_progression['GT_Severity'] == severity) & 
            (df_progression['Pred_Severity'] == severity)
        ])
        
        class_accuracy = (correct_count / gt_count * 100) if gt_count > 0 else 0.0
        
        results['per_class'][severity] = {
            'gt_count': gt_count,
            'pred_count': pred_count,
            'correct': correct_count,
            'accuracy': class_accuracy
        }
    
    # Manual review statistics
    manual_review_needed = df_progression['Manual_Review_Needed'].sum()
    manual_review_pct = (manual_review_needed / total) * 100
    
    results['manual_review'] = {
        'count': manual_review_needed,
        'percentage': manual_review_pct
    }
    
    return results

# ============================================================================
# VISUALIZATION FUNCTIONS
# ============================================================================

def plot_sample_predictions(model, X_test, y_test, model_name, num_samples=6, save_dir='results'):
    """Visualize sample predictions with original image, GT, segmented mask, and overlay"""
    os.makedirs(save_dir, exist_ok=True)
    
    y_pred = model.predict(X_test[:num_samples], verbose=0, batch_size=4)
    y_pred_labels = np.argmax(y_pred, axis=-1)
    
    colors = {0: [0, 0, 0], 1: [0, 255, 0], 2: [255, 0, 0]}
    
    fig, axes = plt.subplots(num_samples, 4, figsize=(16, 4*num_samples))
    
    for i in range(num_samples):
        # Original image
        axes[i, 0].imshow(X_test[i])
        axes[i, 0].set_title('Original Image', fontsize=12, fontweight='bold')
        axes[i, 0].axis('off')
        
        # Ground truth
        gt_colored = np.zeros((512, 512, 3), dtype=np.uint8)
        for class_id, color in colors.items():
            gt_colored[y_test[i] == class_id] = color
        axes[i, 1].imshow(gt_colored)
        axes[i, 1].set_title('Ground Truth (GT)', fontsize=12, fontweight='bold')
        axes[i, 1].axis('off')
        
        # Segmented mask
        pred_colored = np.zeros((512, 512, 3), dtype=np.uint8)
        for class_id, color in colors.items():
            pred_colored[y_pred_labels[i] == class_id] = color
        axes[i, 2].imshow(pred_colored)
        axes[i, 2].set_title('Segmented Mask', fontsize=12, fontweight='bold')
        axes[i, 2].axis('off')
        
        # Overlay
        overlay = X_test[i].copy()
        for class_id, color in colors.items():
            if class_id > 0:
                mask = (y_pred_labels[i] == class_id).astype(np.float32)
                mask_rgb = np.stack([mask * color[0]/255, mask * color[1]/255, mask * color[2]/255], axis=-1)
                overlay = overlay * 0.6 + mask_rgb * 0.4
        axes[i, 3].imshow(overlay)
        axes[i, 3].set_title('Overlay', fontsize=12, fontweight='bold')
        axes[i, 3].axis('off')
        
        # Calculate dice
        y_test_cat = to_categorical(y_test[i], num_classes=3)
        y_pred_cat = to_categorical(y_pred_labels[i], num_classes=3)
        
        disc_dice = 2 * np.sum(y_test_cat[:,:,1] * y_pred_cat[:,:,1]) / (np.sum(y_test_cat[:,:,1]) + np.sum(y_pred_cat[:,:,1]) + 1e-7)
        cup_dice = 2 * np.sum(y_test_cat[:,:,2] * y_pred_cat[:,:,2]) / (np.sum(y_test_cat[:,:,2]) + np.sum(y_pred_cat[:,:,2]) + 1e-7)
        
        axes[i, 0].text(0.5, -0.1, f'Sample {i+1}\nDisc: {disc_dice:.3f} | Cup: {cup_dice:.3f}', 
                       transform=axes[i, 0].transAxes, ha='center', fontsize=10, 
                       bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
    
    plt.suptitle(f'{model_name} - Predictions: Original | GT | Segmented | Overlay', 
                 fontsize=16, fontweight='bold', y=0.995)
    plt.tight_layout()
    plt.savefig(f'{save_dir}/{model_name}_predictions.png', dpi=150, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_predictions.png")
    plt.show()
    plt.close()

def plot_sample_predictions_with_cdr(model, X_test_roi, y_test_full, roi_coords_test,
                                     model_name, num_samples=6, save_dir='results'):
    """Visualize predictions with CDR and glaucoma severity (ROI-aware)"""
    os.makedirs(save_dir, exist_ok=True)
    
    y_pred = model.predict(X_test_roi[:num_samples], verbose=0, batch_size=4)
    y_pred_labels_roi = np.argmax(y_pred, axis=-1)
    
    colors = {0: [0, 0, 0], 1: [0, 255, 0], 2: [255, 0, 0]}
    
    fig, axes = plt.subplots(num_samples, 4, figsize=(18, 4*num_samples))
    
    for i in range(num_samples):
        # ROI image
        axes[i, 0].imshow(X_test_roi[i])
        axes[i, 0].set_title('ROI Image', fontsize=12, fontweight='bold')
        axes[i, 0].axis('off')
        
        # Ground truth (on full image for CDR)
        gt_mask_full = y_test_full[i]
        h, w = gt_mask_full.shape
        gt_colored = np.zeros((h, w, 3), dtype=np.uint8)
        for class_id, color in colors.items():
            gt_colored[gt_mask_full == class_id] = color
        axes[i, 1].imshow(gt_colored)
        
        gt_cdr = calculate_cdr(gt_mask_full)
        gt_class, gt_label, gt_color = classify_glaucoma_severity(gt_cdr['avgCDR']) if gt_cdr['valid'] else (-1, 'Invalid', '#9E9E9E')
        
        axes[i, 1].set_title(f'Ground Truth\nCDR: {gt_cdr["avgCDR"]:.3f} | {gt_label}', 
                            fontsize=12, fontweight='bold', color=gt_color)
        axes[i, 1].axis('off')
        
        # Map ROI prediction back to full image
        pred_full = map_roi_prediction_to_full(y_pred_labels_roi[i], roi_coords_test[i], full_size=(h, w))
        pred_colored = np.zeros((h, w, 3), dtype=np.uint8)
        for class_id, color in colors.items():
            pred_colored[pred_full == class_id] = color
        axes[i, 2].imshow(pred_colored)
        
        pred_cdr = calculate_cdr(pred_full)
        pred_class, pred_label, pred_color = classify_glaucoma_severity(pred_cdr['avgCDR']) if pred_cdr['valid'] else (-1, 'Invalid', '#9E9E9E')
        
        axes[i, 2].set_title(f'Prediction\nCDR: {pred_cdr["avgCDR"]:.3f} | {pred_label}', 
                            fontsize=12, fontweight='bold', color=pred_color)
        axes[i, 2].axis('off')
        
        # Overlay on ROI
        overlay = X_test_roi[i].copy()
        for class_id, color in colors.items():
            if class_id > 0:
                mask = (y_pred_labels_roi[i] == class_id).astype(np.float32)
                mask_rgb = np.stack([mask * color[0]/255, mask * color[1]/255, mask * color[2]/255], axis=-1)
                overlay = overlay * 0.6 + mask_rgb * 0.4
        axes[i, 3].imshow(overlay)
        axes[i, 3].set_title('ROI Overlay', fontsize=12, fontweight='bold')
        axes[i, 3].axis('off')
        
        # Calculate dice on ROI
        roi_gt_cat = to_categorical(y_test_full[i], num_classes=3)  # use full GT for fair CDR
        roi_pred_cat = to_categorical(pred_full, num_classes=3)
        
        disc_dice = 2 * np.sum(roi_gt_cat[:,:,1] * roi_pred_cat[:,:,1]) / (np.sum(roi_gt_cat[:,:,1]) + np.sum(roi_pred_cat[:,:,1]) + 1e-7)
        cup_dice = 2 * np.sum(roi_gt_cat[:,:,2] * roi_pred_cat[:,:,2]) / (np.sum(roi_gt_cat[:,:,2]) + np.sum(roi_pred_cat[:,:,2]) + 1e-7)
        
        cdr_error = abs(gt_cdr['avgCDR'] - pred_cdr['avgCDR']) if gt_cdr['valid'] and pred_cdr['valid'] else np.nan
        
        info_text = f'Sample {i+1}\n'
        info_text += f'Disc Dice: {disc_dice:.3f} | Cup Dice: {cup_dice:.3f}\n'
        info_text += f'CDR Error: {cdr_error:.3f}' if not np.isnan(cdr_error) else 'CDR Error: N/A'
        
        axes[i, 0].text(0.5, -0.15, info_text, transform=axes[i, 0].transAxes, 
                       ha='center', fontsize=10, bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
    
    plt.suptitle(f'{model_name} - ROI Predictions with Glaucoma Severity Assessment', 
                 fontsize=16, fontweight='bold', y=0.995)
    plt.tight_layout()
    plt.savefig(f'{save_dir}/{model_name}_predictions_cdr.png', dpi=150, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_predictions_cdr.png")
    plt.show()
    plt.close()

def plot_cdr_distribution(df_progression, save_dir='results'):
    """Plot CDR distribution and severity classification"""
    os.makedirs(save_dir, exist_ok=True)
    
    fig, axes = plt.subplots(2, 2, figsize=(16, 12))
    
    # CDR scatter plot (GT vs Pred)
    axes[0, 0].scatter(df_progression['GT_avgCDR'], df_progression['Pred_avgCDR'], 
                      alpha=0.6, s=100, c='blue', edgecolors='black')
    axes[0, 0].plot([0, 1], [0, 1], 'r--', linewidth=2, label='Perfect Prediction')
    axes[0, 0].set_xlabel('Ground Truth CDR', fontsize=12, fontweight='bold')
    axes[0, 0].set_ylabel('Predicted CDR', fontsize=12, fontweight='bold')
    axes[0, 0].set_title('CDR: Ground Truth vs Prediction', fontsize=14, fontweight='bold')
    axes[0, 0].legend(fontsize=10)
    axes[0, 0].grid(True, alpha=0.3)
    
    # Add severity zones
    axes[0, 0].axhspan(0, 0.3, alpha=0.1, color='green', label='Normal')
    axes[0, 0].axhspan(0.3, 0.6, alpha=0.1, color='yellow', label='Suspect')
    axes[0, 0].axhspan(0.6, 0.8, alpha=0.1, color='orange', label='Moderate')
    axes[0, 0].axhspan(0.8, 1.0, alpha=0.1, color='red', label='Critical')
    
    # CDR error histogram
    valid_errors = df_progression['CDR_Error'].dropna()
    axes[0, 1].hist(valid_errors, bins=30, color='steelblue', edgecolor='black', alpha=0.7)
    axes[0, 1].axvline(valid_errors.mean(), color='red', linestyle='--', linewidth=2, 
                      label=f'Mean Error: {valid_errors.mean():.4f}')
    axes[0, 1].set_xlabel('CDR Error (|GT - Pred|)', fontsize=12, fontweight='bold')
    axes[0, 1].set_ylabel('Frequency', fontsize=12, fontweight='bold')
    axes[0, 1].set_title('CDR Error Distribution', fontsize=14, fontweight='bold')
    axes[0, 1].legend(fontsize=10)
    axes[0, 1].grid(True, alpha=0.3)
    
    # Severity classification confusion matrix
    severity_order = ['Normal', 'Suspect', 'Moderate', 'Critical']
    gt_severity = pd.Categorical(df_progression['GT_Severity'], categories=severity_order, ordered=True)
    pred_severity = pd.Categorical(df_progression['Pred_Severity'], categories=severity_order, ordered=True)
    
    cm = confusion_matrix(gt_severity, pred_severity, labels=severity_order)
    
    sns.heatmap(cm, annot=True, fmt='d', cmap='YlOrRd', 
                xticklabels=severity_order, yticklabels=severity_order,
                ax=axes[1, 0], cbar_kws={'label': 'Count'})
    axes[1, 0].set_title('Glaucoma Severity Classification', fontsize=14, fontweight='bold')
    axes[1, 0].set_ylabel('Ground Truth', fontsize=12, fontweight='bold')
    axes[1, 0].set_xlabel('Predicted', fontsize=12, fontweight='bold')
    
    # Severity distribution
    severity_counts_gt = df_progression['GT_Severity'].value_counts()
    severity_counts_pred = df_progression['Pred_Severity'].value_counts()
    
    x = np.arange(len(severity_order))
    width = 0.35
    
    counts_gt = [severity_counts_gt.get(s, 0) for s in severity_order]
    counts_pred = [severity_counts_pred.get(s, 0) for s in severity_order]
    
    bars1 = axes[1, 1].bar(x - width/2, counts_gt, width, label='Ground Truth', 
                          color=['#4CAF50', '#FFC107', '#FF9800', '#F44336'], alpha=0.7)
    bars2 = axes[1, 1].bar(x + width/2, counts_pred, width, label='Predicted', 
                          color=['#4CAF50', '#FFC107', '#FF9800', '#F44336'], alpha=0.4)
    
    axes[1, 1].set_xlabel('Severity Level', fontsize=12, fontweight='bold')
    axes[1, 1].set_ylabel('Count', fontsize=12, fontweight='bold')
    axes[1, 1].set_title('Severity Distribution', fontsize=14, fontweight='bold')
    axes[1, 1].set_xticks(x)
    axes[1, 1].set_xticklabels(severity_order, rotation=15)
    axes[1, 1].legend(fontsize=10)
    axes[1, 1].grid(True, alpha=0.3, axis='y')
    
    plt.tight_layout()
    plt.savefig(f'{save_dir}/cdr_analysis.png', dpi=150, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/cdr_analysis.png")
    plt.show()
    plt.close()

def plot_training_history(history, model_name, save_dir='results'):
    """Plot training history - Loss and Accuracy only"""
    os.makedirs(save_dir, exist_ok=True)
    
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    
    # Loss curves
    axes[0].plot(history.history['loss'], label='Training Loss', linewidth=2)
    axes[0].plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
    axes[0].set_title(f'{model_name} - Loss Over Epochs', fontsize=14, fontweight='bold')
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('Loss', fontsize=12)
    axes[0].legend(fontsize=10)
    axes[0].grid(True, alpha=0.3)
    
    # Accuracy curves
    axes[1].plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
    axes[1].plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
    axes[1].set_title(f'{model_name} - Accuracy Over Epochs', fontsize=14, fontweight='bold')
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('Accuracy', fontsize=12)
    axes[1].legend(fontsize=10)
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(f'{save_dir}/{model_name}_history.png', dpi=150, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_history.png")
    plt.show()
    plt.close()

def plot_training_curves(history, model_name, save_dir='results'):
    """Plot training loss and accuracy curves"""
    os.makedirs(save_dir, exist_ok=True)
    
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    
    # Loss
    axes[0].plot(history.history['loss'], label='Training Loss', linewidth=2)
    axes[0].plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
    axes[0].set_title(f'{model_name} - Loss Over Epochs', fontsize=14, fontweight='bold')
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('Loss', fontsize=12)
    axes[0].legend(fontsize=10)
    axes[0].grid(True, alpha=0.3)
    
    # Accuracy
    axes[1].plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
    axes[1].plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
    axes[1].set_title(f'{model_name} - Accuracy Over Epochs', fontsize=14, fontweight='bold')
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('Accuracy', fontsize=12)
    axes[1].legend(fontsize=10)
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(f"{save_dir}/{model_name}_training_curves.png", dpi=300, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_training_curves.png")
    plt.show()
    plt.close()

def plot_confusion_matrices(y_true, y_pred, model_name, save_dir='results'):
    """Plot confusion matrices"""
    os.makedirs(save_dir, exist_ok=True)
    
    y_true_labels = np.argmax(y_true, axis=-1).flatten()
    y_pred_labels = np.argmax(y_pred, axis=-1).flatten()
    
    cm = confusion_matrix(y_true_labels, y_pred_labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    class_names = ['Background', 'Disc', 'Cup']
    
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[0], cbar_kws={'label': 'Count'})
    axes[0].set_title(f'{model_name}\nConfusion Matrix', fontsize=14, fontweight='bold')
    axes[0].set_ylabel('True Label', fontsize=12)
    axes[0].set_xlabel('Predicted Label', fontsize=12)
    
    sns.heatmap(cm_normalized, annot=True, fmt='.3f', cmap='Greens',
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[1], cbar_kws={'label': 'Proportion'})
    axes[1].set_title(f'{model_name}\nNormalized Confusion Matrix', fontsize=14, fontweight='bold')
    axes[1].set_ylabel('True Label', fontsize=12)
    axes[1].set_xlabel('Predicted Label', fontsize=12)
    
    plt.tight_layout()
    plt.savefig(f"{save_dir}/{model_name}_confusion_matrices.png", dpi=300, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_confusion_matrices.png")
    plt.show()
    plt.close()
    
    print(f"\nConfusion Matrix:\n{cm}")
    print(f"\nNormalized Confusion Matrix:\n{np.round(cm_normalized, 3)}")
    
    return cm, cm_normalized

# ============================================================================
# TRAINING AND EVALUATION
# ============================================================================

def train_model(X_train_roi, y_train_roi, X_val_roi, y_val_roi,
                X_test_roi, y_test_full, roi_coords_test,
                model_name, augment=None, save_dir='results'):
    """Train model with MSCA + LBFR + PPM triple enhancement on ROI-cropped data"""
    print(f"\n{'='*80}")
    print(f"TRAINING: {model_name}")
    print(f"{'='*80}")
    print(f"  Architecture: Deeper Decoder + MSCA + LBFR + PPM + Focal-EIoU + MC Dropout")
    print(f"  Loss: Focal + Enhanced IoU (Combined)")
    print(f"  ROI Extraction: ENABLED (training on disc-centered crops)")
    
    K.clear_session()
    
    # Build model
    model = build_unet_with_triple_attention(dropout_rate=0.3)
    param_count = model.count_params()
    
    # Compile
    model.compile(
        optimizer=optimizers.Adam(learning_rate=2e-4, clipnorm=1.0),
        loss=focal_eiou_combined_loss,
        metrics=[dice_coef_multiclass, dice_class_0, dice_class_1, dice_class_2,
                "accuracy", iou_coef_multiclass, iou_class_0, iou_class_1, iou_class_2]
    )
    
    # Callbacks
    checkpoint = ModelCheckpoint(f"{save_dir}/{model_name}.keras", save_best_only=True, 
                                verbose=1, monitor='val_loss', mode='min')
    reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=4,
                                  verbose=1, mode='min', min_lr=1e-7)
    early_stop = EarlyStopping(monitor="val_loss", patience=15, verbose=1,
                              restore_best_weights=True, mode='min')
    
    # Training on ROI data
    batch_size = 4
    steps_train = X_train_roi.shape[0] // batch_size
    steps_val = X_val_roi.shape[0] // batch_size
    
    history = model.fit(
        data_generator(X_train_roi, y_train_roi, batch_size, augment),
        validation_data=data_generator(X_val_roi, y_val_roi, batch_size, None),
        steps_per_epoch=steps_train,
        validation_steps=steps_val,
        epochs=80,
        callbacks=[checkpoint, reduce_lr, early_stop],
        verbose=1
    )
    
    print(f"✓ Training completed")
    
    # Visualizations
    print("\nGenerating visualizations...")
    plot_training_history(history, model_name, save_dir)
    plot_sample_predictions_with_cdr(model, X_test_roi, y_test_full, roi_coords_test,
                                     model_name, num_samples=8, save_dir=save_dir)
    
    return model, history, param_count

def save_segmentation_masks(X_test_roi, y_test_full, y_pred_labels_roi,
                            roi_coords_test, save_dir='results/predictions'):
    """Save all test predictions (masks only) with visible pixel values — ROI-aware"""
    os.makedirs(save_dir, exist_ok=True)
    
    print(f"\nSaving all {len(X_test_roi)} test predictions to {save_dir}...")
    
    for i in range(len(X_test_roi)):
        h, w = y_test_full[i].shape
        
        # Map ROI prediction back to full image
        pred_full = map_roi_prediction_to_full(y_pred_labels_roi[i], roi_coords_test[i], full_size=(h, w))
        
        # Process Predicted Mask (0, 1, 2)
        visible_pred = np.zeros((h, w), dtype=np.uint8)
        visible_pred[pred_full == 1] = 127  # Disc
        visible_pred[pred_full == 2] = 255  # Cup
        
        # Process Ground Truth Mask
        gt_mask = y_test_full[i].astype(np.uint8)
        visible_gt = np.zeros_like(gt_mask)
        visible_gt[gt_mask == 1] = 127  # Disc
        visible_gt[gt_mask == 2] = 255  # Cup
        
        # Combine side by side (GT left, Pred right)
        combined = np.hstack((visible_gt, visible_pred))
        
        # Save as PNG
        Image.fromarray(combined).save(f"{save_dir}/test_{i+1:04d}_comparison.png")
            
        if (i + 1) % 50 == 0:
            print(f"  Processed {i+1}/{len(X_test_roi)}")
            
    print(f"✓ Saved comparison masks to {save_dir}")

def evaluate_model(model, X_test_roi, y_test_roi, y_test_full, roi_coords_test,
                   model_name, run_mc_dropout=True, save_predictions=True):
    """Evaluate model with glaucoma progression analysis — ROI-aware"""
    print(f"\n{'='*80}")
    print(f"EVALUATION: {model_name}")
    print(f"{'='*80}")
    
    # --- ROI-level metrics (what the model actually sees) ---
    y_test_roi_cat = np.array([to_categorical(mask, num_classes=3) for mask in y_test_roi])
    
    y_pred = model.predict(X_test_roi, verbose=0, batch_size=4)
    y_pred_labels_roi = np.argmax(y_pred, axis=-1)
    
    # --- Map predictions back to full image for CDR / progression analysis ---
    y_pred_labels_full = []
    for i in range(len(X_test_roi)):
        h, w = y_test_full[i].shape
        pred_full = map_roi_prediction_to_full(y_pred_labels_roi[i], roi_coords_test[i], full_size=(h, w))
        y_pred_labels_full.append(pred_full)
    y_pred_labels_full = np.array(y_pred_labels_full)
    
    if save_predictions:
        save_segmentation_masks(X_test_roi, y_test_full, y_pred_labels_roi,
                                roi_coords_test, save_dir=f'results/{model_name}_all_preds')
    
    # Confusion matrices (on ROI crops — where the model is evaluated)
    plot_confusion_matrices(y_test_roi_cat, y_pred, model_name, save_dir='results')
    
    # Classification metrics on ROI
    y_true_labels = np.argmax(y_test_roi_cat, axis=-1).flatten()
    y_pred_labels_flat = y_pred_labels_roi.flatten()
    
    precision = precision_score(y_true_labels, y_pred_labels_flat, average=None, zero_division=0)
    recall = recall_score(y_true_labels, y_pred_labels_flat, average=None, zero_division=0)
    f1 = f1_score(y_true_labels, y_pred_labels_flat, average=None, zero_division=0)
    
    print(f"\nPrecision, Recall, F1 Score per class (ROI-level):")
    class_names = ["Background", "Disc", "Cup"]
    for idx, cname in enumerate(class_names):
        print(f"  {cname}: Precision={precision[idx]:.4f}, Recall={recall[idx]:.4f}, F1={f1[idx]:.4f}")
    
    print(f"\nMacro-averaged metrics:")
    print(f"  Precision: {np.mean(precision):.4f}")
    print(f"  Recall: {np.mean(recall):.4f}")
    print(f"  F1 Score: {np.mean(f1):.4f}")
    
    # Per-class Dice and IoU (on ROI)
    results = {'standard': {}}
    for cidx, cname in enumerate(class_names):
        y_true_c = (np.argmax(y_test_roi_cat, axis=-1) == cidx).astype(np.float32)
        y_pred_c = (y_pred_labels_roi == cidx).astype(np.float32)
        
        intersection = np.sum(y_true_c * y_pred_c)
        dice = (2. * intersection + 1e-7) / (np.sum(y_true_c) + np.sum(y_pred_c) + 1e-7)
        union = np.sum(y_true_c) + np.sum(y_pred_c) - intersection
        iou = (intersection + 1e-7) / (union + 1e-7)
        
        results['standard'][cname] = {'dice': dice, 'iou': iou}
        print(f"  {cname}: Dice={dice:.4f}, IoU={iou:.4f}")
    
    # Glaucoma Progression Analysis (on full-image mapped predictions)
    print(f"\n{'='*80}")
    print(f"GLAUCOMA PROGRESSION ANALYSIS (Using Area-based CDR on full-image mapped predictions)")
    print(f"{'='*80}")
    
    df_progression = analyze_glaucoma_progression(y_test_full, y_pred_labels_full, cdr_method='area_sqrt')
    
    # CDR Statistics
    print(f"\n{'-'*80}")
    print(f"CDR Statistics:")
    print(f"{'-'*80}")
    print(f"  Mean GT CDR:   {df_progression['GT_avgCDR'].mean():.4f} ± {df_progression['GT_avgCDR'].std():.4f}")
    print(f"  Mean Pred CDR: {df_progression['Pred_avgCDR'].mean():.4f} ± {df_progression['Pred_avgCDR'].std():.4f}")
    print(f"  Mean CDR Error: {df_progression['CDR_Error'].mean():.4f} ± {df_progression['CDR_Error'].std():.4f}")
    
    # Calculate progression accuracy
    accuracy_results = calculate_progression_accuracy(df_progression)
    
    # Overall Accuracy
    print(f"\n{'='*80}")
    print(f"PROGRESSION CLASSIFICATION ACCURACY")
    print(f"{'='*80}")
    print(f"\nOverall Accuracy: {accuracy_results['overall']['accuracy']:.2f}%")
    print(f"  - Correctly Classified: {accuracy_results['overall']['correct']}/{accuracy_results['overall']['total']} samples")
    print(f"  - Incorrectly Classified: {accuracy_results['overall']['total'] - accuracy_results['overall']['correct']}/{accuracy_results['overall']['total']} samples")
    
    # Per-Class Results
    print(f"\n{'-'*80}")
    print(f"Per-Class Results:")
    print(f"{'-'*80}")
    print(f"{'Severity':<12} {'GT Count':<12} {'Pred Count':<12} {'Correct':<12} {'Accuracy':<12}")
    print(f"{'-'*80}")
    
    for severity in ['Normal', 'Suspect', 'Moderate', 'Critical']:
        stats = accuracy_results['per_class'][severity]
        print(f"{severity:<12} {stats['gt_count']:<12} {stats['pred_count']:<12} "
              f"{stats['correct']:<12} {stats['accuracy']:<12.2f}%")
    
    print(f"\n{'='*80}")
    print(f"INTERPRETATION EXAMPLE:")
    print(f"{'='*80}")
    normal_stats = accuracy_results['per_class']['Normal']
    print(f"  - GT says 'Normal' for {normal_stats['gt_count']} images")
    print(f"  - Model says 'Normal' for {normal_stats['pred_count']} images")
    print(f"  - Model correctly predicts {normal_stats['correct']} as 'Normal'")
    print(f"  - Accuracy for Normal class: {normal_stats['correct']}/{normal_stats['gt_count']} = {normal_stats['accuracy']:.1f}%")
    
    # Manual Review Recommendations
    print(f"\n{'='*80}")
    print(f"MANUAL REVIEW RECOMMENDATIONS")
    print(f"{'='*80}")
    print(f"\nSamples Requiring Manual Review: {accuracy_results['manual_review']['count']}/{accuracy_results['overall']['total']} "
          f"({accuracy_results['manual_review']['percentage']:.1f}%)")
    print(f"\nCriteria for Manual Review:")
    print(f"  1. All Critical cases (high-risk, requires expert verification)")
    print(f"  2. Classification mismatches (GT ≠ Predicted severity)")
    print(f"\nReason: Critical cases need expert confirmation, and mismatches may")
    print(f"indicate borderline cases or segmentation issues requiring review.")
    
    # Breakdown of manual review cases
    review_df = df_progression[df_progression['Manual_Review_Needed'] == True]
    critical_cases = len(review_df[review_df['GT_Severity'] == 'Critical'])
    mismatch_cases = len(review_df[review_df['Severity_Match'] == False])
    overlap = len(review_df[(review_df['GT_Severity'] == 'Critical') & (review_df['Severity_Match'] == False)])
    
    print(f"\nBreakdown:")
    print(f"  - Critical cases: {critical_cases} samples")
    print(f"  - Classification mismatches: {mismatch_cases} samples")
    print(f"  - Overlap (Critical + Mismatch): {overlap} samples")
    
    # Save progression data
    df_progression.to_csv('results/glaucoma_progression_analysis.csv', index=False)
    print(f"\n✓ Saved: results/glaucoma_progression_analysis.csv")
    
    # Plot CDR analysis
    plot_cdr_distribution(df_progression, save_dir='results')
    
    results['glaucoma'] = {
        'mean_cdr_error': df_progression['CDR_Error'].mean(),
        'median_cdr_error': df_progression['CDR_Error'].median(),
        'classification_accuracy': accuracy_results['overall']['accuracy'] / 100,
        'df_progression': df_progression,
        'accuracy_breakdown': accuracy_results
    }
    
    # MC Dropout (on ROI data)
    if run_mc_dropout:
        print(f"\n{'='*80}")
        print(f"MC DROPOUT UNCERTAINTY ESTIMATION")
        print(f"{'='*80}")
        mean_pred, std_pred = mc_dropout_predict(model, X_test_roi[:100], num_samples=15, verbose=True)
        results['mc_dropout'] = {}
        for cidx, cname in enumerate(class_names):
            mean_std = np.mean(std_pred[:, :, :, cidx])
            results['mc_dropout'][cname] = {'mean_uncertainty': mean_std}
            print(f"  {cname} uncertainty: {mean_std:.4f}")
    
    return results

# ============================================================================
# MAIN EXECUTION
# ============================================================================

if __name__ == "__main__":
    # Setup
    gpu_available = configure_gpu()
    root_dir = "/kaggle/input/datasets/arnavpal66/refuge/REFUGE"
    train_aug = setup_augmentations()
    save_dir = "results"
    os.makedirs(save_dir, exist_ok=True)
    
    print(f"\n{'='*100}")
    print(f"{'V5: ORIGINAL CONFIG + HIGH-RES ROI ONLY (ABLATION)':^100s}")
    print(f"{'='*100}")
    print(f"\nModel Architecture:")
    print(f"  - Base: MobileNetV2 Encoder + Deeper Decoder")
    print(f"  - Triple Attention: MSCA + LBFR + PPM (12 modules total)")
    print(f"  - Loss: Focal + Enhanced IoU (Combined)")
    print(f"  - Uncertainty: MC Dropout (15 forward passes)")
    print(f"  - Polar Transform: Enabled (images + GT masks)")
    print(f"\nROI Extraction:")
    print(f"  - Automatically crops around the optic disc region from GT masks")
    print(f"  - Padding factor: 1.5× (50% margin around disc bounding box)")
    print(f"  - ROI resized to 512×512 → model sees zoomed-in disc/cup detail")
    print(f"  - Predictions mapped back to full image for CDR analysis")
    print(f"\nGlaucoma Severity Classification:")
    print(f"  - Normal:   CDR < 0.3  (Green)")
    print(f"  - Suspect:  0.3 ≤ CDR < 0.6  (Amber)")
    print(f"  - Moderate: 0.6 ≤ CDR < 0.8  (Orange)")
    print(f"  - Critical: CDR ≥ 0.8  (Red)")
    print(f"  CDR Method: Area-based (sqrt of area ratio) - Robust & Clinically Relevant")
    print(f"\nManual Review: Recommended for Critical cases and classification mismatches")
    
    # Load data with HIGH-RES ROI extraction
    # KEY FIX: loads at original resolution (~2000x2000), crops ROI, resizes to 512x512
    # This avoids the V1 bug of cropping from already-downsampled 512x512 images
    print(f"\n{'='*80}")
    print(f"HIGH-RES ROI DATA LOADING")
    print(f"{'='*80}")
    print(f"  Loading at original resolution, extracting ROI, resizing to 512x512")
    print(f"  Padding factor: 1.2x (20% margin around disc)")
    
    all_roi_images, all_roi_masks, all_full_masks = load_all_data_with_highres_roi(root_dir)
    
    # Split: 600 train, 200 val, 400 test (same random_state=42 as original)
    X_temp, X_test_roi, y_temp_roi, y_test_roi, temp_full, y_test_full = train_test_split(
        all_roi_images, all_roi_masks, all_full_masks, test_size=400, random_state=42
    )
    X_train_roi, X_val_roi, y_train_roi, y_val_roi, train_full, val_full = train_test_split(
        X_temp, y_temp_roi, temp_full, test_size=200, random_state=42
    )
    
    del all_roi_images, all_roi_masks, all_full_masks, X_temp, y_temp_roi, temp_full
    gc.collect()
    
    # Create dummy roi_coords (CDR computed on ROI directly in high-res mode)
    roi_coords_test = [(0, 0, 512, 512)] * len(X_test_roi)
    
    print(f"\n  Split - Train: {X_train_roi.shape[0]}, Val: {X_val_roi.shape[0]}, Test: {X_test_roi.shape[0]}")
    print(f"  ROI shape: {X_train_roi.shape[1:]} per image")

    print(f"\n{'='*80}")
    print(f"POLAR TRANSFORM")
    print(f"{'='*80}")
    X_train_roi, y_train_roi = transform_to_polar_batch(X_train_roi, y_train_roi)
    X_val_roi, y_val_roi = transform_to_polar_batch(X_val_roi, y_val_roi)
    X_test_roi, y_test_roi = transform_to_polar_batch(X_test_roi, y_test_roi)
    print(f"  Polar train: {X_train_roi.shape}, val: {X_val_roi.shape}, test: {X_test_roi.shape}")
    
        # Train model on ROI data
    model, history, params = train_model(
        X_train_roi, y_train_roi, X_val_roi, y_val_roi,
        X_test_roi, y_test_full, roi_coords_test,
        "V5_OrigConfig_HighResROI",
        augment=train_aug, save_dir=save_dir
    )
    
    # Evaluate with ROI-aware glaucoma analysis
    results = evaluate_model(
        model, X_test_roi, y_test_roi, y_test_full, roi_coords_test,
        "V5_OrigConfig_HighResROI",
        run_mc_dropout=True, save_predictions=True
    )
    
    print(f"\n{'='*100}")
    print(f"{'TRAINING AND EVALUATION COMPLETED!':^100s}")
    print(f"{'='*100}")
    print(f"\nModel: V5 - Original Config + High-Res ROI Only (simplest ablation)")
    print(f"Parameters: {params:,}")
    print(f"ROI Extraction: Padding=1.2x, Size=(512, 512)")
    print(f"Results saved in: {save_dir}/")
    print(f"\nGenerated Files:")
    print(f"  - Training history: {save_dir}/V5_OrigConfig_HighResROI_history.png")
    print(f"  - Predictions with CDR: {save_dir}/V5_OrigConfig_HighResROI_predictions_cdr.png")
    print(f"  - CDR Analysis: {save_dir}/cdr_analysis.png")
    print(f"  - Progression CSV: {save_dir}/glaucoma_progression_analysis.csv")
    print(f"  - Confusion Matrices: {save_dir}/V5_OrigConfig_HighResROI_confusion_matrices.png")
    print(f"\n{'='*100}\n")
# Out:
# 2026-03-21 14:09:14.321370: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774102154.522554      24 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774102154.583040      24 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774102155.070640      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774102155.070692      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774102155.070695      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774102155.070698      24 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Configuring GPU settings...
# ✓ GPU configured: 1 device(s) available
#
# ====================================================================================================
#                          V5: ORIGINAL CONFIG + HIGH-RES ROI ONLY (ABLATION)
# ====================================================================================================
#
# Model Architecture:
#   - Base: MobileNetV2 Encoder + Deeper Decoder
#   - Triple Attention: MSCA + LBFR + PPM (12 modules total)
#   - Loss: Focal + Enhanced IoU (Combined)
#   - Uncertainty: MC Dropout (15 forward passes)
#   - Polar Transform: Enabled (images + GT masks)
#
# ROI Extraction:
#   - Automatically crops around the optic disc region from GT masks
#   - Padding factor: 1.5× (50% margin around disc bounding box)
#   - ROI resized to 512×512 → model sees zoomed-in disc/cup detail
#   - Predictions mapped back to full image for CDR analysis
#
# Glaucoma Severity Classification:
#   - Normal:   CDR < 0.3  (Green)
#   - Suspect:  0.3 ≤ CDR < 0.6  (Amber)
#   - Moderate: 0.6 ≤ CDR < 0.8  (Orange)
#   - Critical: CDR ≥ 0.8  (Red)
#   CDR Method: Area-based (sqrt of area ratio) - Robust & Clinically Relevant
#
# Manual Review: Recommended for Critical cases and classification mismatches
#
# ================================================================================
# HIGH-RES ROI DATA LOADING
# ================================================================================
#   Loading at original resolution, extracting ROI, resizing to 512x512
#   Padding factor: 1.2x (20% margin around disc)
#   train: 400 samples (original resolution -> ROI extracted)
#   val: 400 samples (original resolution -> ROI extracted)
#   test: 400 samples (original resolution -> ROI extracted)
#
#   Split - Train: 600, Val: 200, Test: 400
#   ROI shape: (512, 512, 3) per image
#
# ================================================================================
# POLAR TRANSFORM
# ================================================================================
#   Polar train: (600, 512, 512, 3), val: (200, 512, 512, 3), test: (400, 512, 512, 3)
#
# ================================================================================
# TRAINING: V5_OrigConfig_HighResROI
# ================================================================================
#   Architecture: Deeper Decoder + MSCA + LBFR + PPM + Focal-EIoU + MC Dropout
#   Loss: Focal + Enhanced IoU (Combined)
#   ROI Extraction: ENABLED (training on disc-centered crops)
# I0000 00:00:1774102334.665389      24 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# Model Configuration:
#   Total Parameters: 47,631,627
#   Dropout Layers: 5
#   Triple Attention Modules: MSCA + LBFR + PPM per decoder block
#   MSCA Modules: 4 (local multi-scale with dilation rates [1,2,3,5])
#   LBFR Modules: 4 (channel + spatial attention + recalibration)
#   PPM Modules: 4 (global pyramid pooling [1×1, 2×2, 3×3, 6×6])
#   Enhancement Strategy: Sequential MSCA → LBFR → PPM per block
#   Total Attention Blocks: 12 (4 MSCA + 4 LBFR + 4 PPM)
#   Context Coverage: Local Multi-scale + Attention + Global Multi-scale
# Epoch 1/80
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1774102413.863836      78 service.cc:152] XLA service 0x7ef0bc0034b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1774102413.863878      78 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1774102433.111521      78 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-03-21 14:14:12.021127: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-21 14:14:12.277026: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-21 14:14:13.951886: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-21 14:14:14.188245: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-21 14:14:29.754643: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-21 14:14:29.991187: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1774102557.899499      78 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.7564 - dice_class_0: 0.7451 - dice_class_1: 0.7101 - dice_class_2: 0.8124 - dice_coef_multiclass: 0.6602 - iou_class_0: 0.6267 - iou_class_1: 0.5753 - iou_class_2: 0.6977 - iou_coef_multiclass: 0.5074 - loss: 0.8497
# 2026-03-21 14:17:16.631218: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-21 14:17:16.887659: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Epoch 1: val_loss improved from inf to 3.11326, saving model to results/V5_OrigConfig_HighResROI.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 323s 639ms/step - accuracy: 0.7569 - dice_class_0: 0.7458 - dice_class_1: 0.7107 - dice_class_2: 0.8128 - dice_coef_multiclass: 0.6608 - iou_class_0: 0.6276 - iou_class_1: 0.5760 - iou_class_2: 0.6982 - iou_coef_multiclass: 0.5081 - loss: 0.8482 - val_accuracy: 0.6077 - val_dice_class_0: 0.5954 - val_dice_class_1: 0.5450 - val_dice_class_2: 0.6522 - val_dice_coef_multiclass: 0.5818 - val_iou_class_0: 0.4253 - val_iou_class_1: 0.3824 - val_iou_class_2: 0.4873 - val_iou_coef_multiclass: 0.4126 - val_loss: 3.1133 - learning_rate: 2.0000e-04
# Epoch 2/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.8966 - dice_class_0: 0.9273 - dice_class_1: 0.8693 - dice_class_2: 0.9036 - dice_coef_multiclass: 0.8328 - iou_class_0: 0.8649 - iou_class_1: 0.7702 - iou_class_2: 0.8252 - iou_coef_multiclass: 0.7138 - loss: 0.4485
# Epoch 2: val_loss improved from 3.11326 to 1.11801, saving model to results/V5_OrigConfig_HighResROI.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 466ms/step - accuracy: 0.8966 - dice_class_0: 0.9273 - dice_class_1: 0.8693 - dice_class_2: 0.9036 - dice_coef_multiclass: 0.8328 - iou_class_0: 0.8649 - iou_class_1: 0.7703 - iou_class_2: 0.8252 - iou_coef_multiclass: 0.7138 - loss: 0.4485 - val_accuracy: 0.8022 - val_dice_class_0: 0.7128 - val_dice_class_1: 0.7946 - val_dice_class_2: 0.8513 - val_dice_coef_multiclass: 0.7818 - val_iou_class_0: 0.5576 - val_iou_class_1: 0.6602 - val_iou_class_2: 0.7424 - val_iou_coef_multiclass: 0.6427 - val_loss: 1.1180 - learning_rate: 2.0000e-04
# Epoch 3/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.9059 - dice_class_0: 0.9332 - dice_class_1: 0.8805 - dice_class_2: 0.9136 - dice_coef_multiclass: 0.8510 - iou_class_0: 0.8754 - iou_class_1: 0.7878 - iou_class_2: 0.8420 - iou_coef_multiclass: 0.7410 - loss: 0.4055
# Epoch 3: val_loss did not improve from 1.11801
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 66s 437ms/step - accuracy: 0.9059 - dice_class_0: 0.9332 - dice_class_1: 0.8805 - dice_class_2: 0.9136 - dice_coef_multiclass: 0.8510 - iou_class_0: 0.8754 - iou_class_1: 0.7878 - iou_class_2: 0.8420 - iou_coef_multiclass: 0.7410 - loss: 0.4055 - val_accuracy: 0.6367 - val_dice_class_0: 0.4557 - val_dice_class_1: 0.5841 - val_dice_class_2: 0.7146 - val_dice_coef_multiclass: 0.6192 - val_iou_class_0: 0.2990 - val_iou_class_1: 0.4237 - val_iou_class_2: 0.5599 - val_iou_coef_multiclass: 0.4518 - val_loss: 2.4427 - learning_rate: 2.0000e-04
# Epoch 4/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.9063 - dice_class_0: 0.9345 - dice_class_1: 0.8809 - dice_class_2: 0.9130 - dice_coef_multiclass: 0.8518 - iou_class_0: 0.8776 - iou_class_1: 0.7881 - iou_class_2: 0.8405 - iou_coef_multiclass: 0.7422 - loss: 0.4003
# Epoch 4: val_loss improved from 1.11801 to 0.85161, saving model to results/V5_OrigConfig_HighResROI.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 465ms/step - accuracy: 0.9063 - dice_class_0: 0.9345 - dice_class_1: 0.8810 - dice_class_2: 0.9130 - dice_coef_multiclass: 0.8519 - iou_class_0: 0.8776 - iou_class_1: 0.7882 - iou_class_2: 0.8406 - iou_coef_multiclass: 0.7423 - loss: 0.4002 - val_accuracy: 0.8460 - val_dice_class_0: 0.8470 - val_dice_class_1: 0.7967 - val_dice_class_2: 0.8893 - val_dice_coef_multiclass: 0.8306 - val_iou_class_0: 0.7370 - val_iou_class_1: 0.6646 - val_iou_class_2: 0.8023 - val_iou_coef_multiclass: 0.7116 - val_loss: 0.8516 - learning_rate: 2.0000e-04
# Epoch 5/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.9173 - dice_class_0: 0.9419 - dice_class_1: 0.8955 - dice_class_2: 0.9234 - dice_coef_multiclass: 0.8676 - iou_class_0: 0.8905 - iou_class_1: 0.8115 - iou_class_2: 0.8584 - iou_coef_multiclass: 0.7663 - loss: 0.3625
# Epoch 5: val_loss improved from 0.85161 to 0.64627, saving model to results/V5_OrigConfig_HighResROI.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 466ms/step - accuracy: 0.9173 - dice_class_0: 0.9419 - dice_class_1: 0.8955 - dice_class_2: 0.9234 - dice_coef_multiclass: 0.8675 - iou_class_0: 0.8904 - iou_class_1: 0.8115 - iou_class_2: 0.8583 - iou_coef_multiclass: 0.7663 - loss: 0.3626 - val_accuracy: 0.8504 - val_dice_class_0: 0.8507 - val_dice_class_1: 0.8198 - val_dice_class_2: 0.8802 - val_dice_coef_multiclass: 0.7883 - val_iou_class_0: 0.7419 - val_iou_class_1: 0.6976 - val_iou_class_2: 0.7880 - val_iou_coef_multiclass: 0.6517 - val_loss: 0.6463 - learning_rate: 2.0000e-04
# Epoch 6/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9150 - dice_class_0: 0.9431 - dice_class_1: 0.8913 - dice_class_2: 0.9200 - dice_coef_multiclass: 0.8646 - iou_class_0: 0.8928 - iou_class_1: 0.8050 - iou_class_2: 0.8527 - iou_coef_multiclass: 0.7619 - loss: 0.3682
# Epoch 6: val_loss improved from 0.64627 to 0.64412, saving model to results/V5_OrigConfig_HighResROI.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 465ms/step - accuracy: 0.9150 - dice_class_0: 0.9431 - dice_class_1: 0.8913 - dice_class_2: 0.9200 - dice_coef_multiclass: 0.8646 - iou_class_0: 0.8928 - iou_class_1: 0.8051 - iou_class_2: 0.8527 - iou_coef_multiclass: 0.7619 - loss: 0.3682 - val_accuracy: 0.8871 - val_dice_class_0: 0.9121 - val_dice_class_1: 0.8564 - val_dice_class_2: 0.9030 - val_dice_coef_multiclass: 0.8645 - val_iou_class_0: 0.8391 - val_iou_class_1: 0.7511 - val_iou_class_2: 0.8249 - val_iou_coef_multiclass: 0.7623 - val_loss: 0.6441 - learning_rate: 2.0000e-04
# Epoch 7/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.9188 - dice_class_0: 0.9448 - dice_class_1: 0.8974 - dice_class_2: 0.9230 - dice_coef_multiclass: 0.8700 - iou_class_0: 0.8957 - iou_class_1: 0.8149 - iou_class_2: 0.8580 - iou_coef_multiclass: 0.7702 - loss: 0.3529
# Epoch 7: val_loss improved from 0.64412 to 0.64390, saving model to results/V5_OrigConfig_HighResROI.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 466ms/step - accuracy: 0.9188 - dice_class_0: 0.9448 - dice_class_1: 0.8974 - dice_class_2: 0.9230 - dice_coef_multiclass: 0.8700 - iou_class_0: 0.8957 - iou_class_1: 0.8149 - iou_class_2: 0.8580 - iou_coef_multiclass: 0.7703 - loss: 0.3529 - val_accuracy: 0.8735 - val_dice_class_0: 0.9289 - val_dice_class_1: 0.8531 - val_dice_class_2: 0.8627 - val_dice_coef_multiclass: 0.8447 - val_iou_class_0: 0.8676 - val_iou_class_1: 0.7457 - val_iou_class_2: 0.7603 - val_iou_coef_multiclass: 0.7320 - val_loss: 0.6439 - learning_rate: 2.0000e-04
# Epoch 8/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9208 - dice_class_0: 0.9466 - dice_class_1: 0.8998 - dice_class_2: 0.9250 - dice_coef_multiclass: 0.8775 - iou_class_0: 0.8989 - iou_class_1: 0.8187 - iou_class_2: 0.8610 - iou_coef_multiclass: 0.7819 - loss: 0.3353
# Epoch 8: val_loss did not improve from 0.64390
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 437ms/step - accuracy: 0.9208 - dice_class_0: 0.9466 - dice_class_1: 0.8998 - dice_class_2: 0.9250 - dice_coef_multiclass: 0.8775 - iou_class_0: 0.8989 - iou_class_1: 0.8187 - iou_class_2: 0.8611 - iou_coef_multiclass: 0.7819 - loss: 0.3353 - val_accuracy: 0.8326 - val_dice_class_0: 0.9279 - val_dice_class_1: 0.8194 - val_dice_class_2: 0.7834 - val_dice_coef_multiclass: 0.8307 - val_iou_class_0: 0.8663 - val_iou_class_1: 0.6963 - val_iou_class_2: 0.6467 - val_iou_coef_multiclass: 0.7114 - val_loss: 0.7137 - learning_rate: 2.0000e-04
# Epoch 9/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.9228 - dice_class_0: 0.9481 - dice_class_1: 0.9026 - dice_class_2: 0.9266 - dice_coef_multiclass: 0.8783 - iou_class_0: 0.9016 - iou_class_1: 0.8231 - iou_class_2: 0.8641 - iou_coef_multiclass: 0.7831 - loss: 0.3301
# Epoch 9: val_loss improved from 0.64390 to 0.52025, saving model to results/V5_OrigConfig_HighResROI.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 71s 473ms/step - accuracy: 0.9228 - dice_class_0: 0.9481 - dice_class_1: 0.9026 - dice_class_2: 0.9266 - dice_coef_multiclass: 0.8783 - iou_class_0: 0.9016 - iou_class_1: 0.8232 - iou_class_2: 0.8641 - iou_coef_multiclass: 0.7832 - loss: 0.3301 - val_accuracy: 0.8942 - val_dice_class_0: 0.9157 - val_dice_class_1: 0.8736 - val_dice_class_2: 0.9027 - val_dice_coef_multiclass: 0.8664 - val_iou_class_0: 0.8470 - val_iou_class_1: 0.7770 - val_iou_class_2: 0.8242 - val_iou_coef_multiclass: 0.7655 - val_loss: 0.5203 - learning_rate: 2.0000e-04
# Epoch 10/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.9251 - dice_class_0: 0.9500 - dice_class_1: 0.9067 - dice_class_2: 0.9272 - dice_coef_multiclass: 0.8838 - iou_class_0: 0.9051 - iou_class_1: 0.8299 - iou_class_2: 0.8649 - iou_coef_multiclass: 0.7919 - loss: 0.3223
# Epoch 10: val_loss improved from 0.52025 to 0.45499, saving model to results/V5_OrigConfig_HighResROI.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 464ms/step - accuracy: 0.9251 - dice_class_0: 0.9500 - dice_class_1: 0.9067 - dice_class_2: 0.9272 - dice_coef_multiclass: 0.8838 - iou_class_0: 0.9051 - iou_class_1: 0.8299 - iou_class_2: 0.8650 - iou_coef_multiclass: 0.7919 - loss: 0.3223 - val_accuracy: 0.9033 - val_dice_class_0: 0.9364 - val_dice_class_1: 0.8836 - val_dice_class_2: 0.9044 - val_dice_coef_multiclass: 0.8662 - val_iou_class_0: 0.8809 - val_iou_class_1: 0.7930 - val_iou_class_2: 0.8268 - val_iou_coef_multiclass: 0.7647 - val_loss: 0.4550 - learning_rate: 2.0000e-04
# Epoch 11/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9258 - dice_class_0: 0.9515 - dice_class_1: 0.9060 - dice_class_2: 0.9284 - dice_coef_multiclass: 0.8846 - iou_class_0: 0.9079 - iou_class_1: 0.8289 - iou_class_2: 0.8671 - iou_coef_multiclass: 0.7932 - loss: 0.3175
# Epoch 11: val_loss improved from 0.45499 to 0.45206, saving model to results/V5_OrigConfig_HighResROI.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 465ms/step - accuracy: 0.9258 - dice_class_0: 0.9515 - dice_class_1: 0.9060 - dice_class_2: 0.9284 - dice_coef_multiclass: 0.8846 - iou_class_0: 0.9079 - iou_class_1: 0.8289 - iou_class_2: 0.8671 - iou_coef_multiclass: 0.7932 - loss: 0.3175 - val_accuracy: 0.8959 - val_dice_class_0: 0.9448 - val_dice_class_1: 0.8759 - val_dice_class_2: 0.8877 - val_dice_coef_multiclass: 0.8640 - val_iou_class_0: 0.8957 - val_iou_class_1: 0.7815 - val_iou_class_2: 0.7997 - val_iou_coef_multiclass: 0.7614 - val_loss: 0.4521 - learning_rate: 2.0000e-04
# Epoch 12/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.9279 - dice_class_0: 0.9535 - dice_class_1: 0.9096 - dice_class_2: 0.9296 - dice_coef_multiclass: 0.8868 - iou_class_0: 0.9113 - iou_class_1: 0.8349 - iou_class_2: 0.8691 - iou_coef_multiclass: 0.7968 - loss: 0.3071
# Epoch 12: val_loss did not improve from 0.45206
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 66s 437ms/step - accuracy: 0.9279 - dice_class_0: 0.9535 - dice_class_1: 0.9096 - dice_class_2: 0.9296 - dice_coef_multiclass: 0.8868 - iou_class_0: 0.9113 - iou_class_1: 0.8348 - iou_class_2: 0.8691 - iou_coef_multiclass: 0.7968 - loss: 0.3072 - val_accuracy: 0.8695 - val_dice_class_0: 0.9321 - val_dice_class_1: 0.8520 - val_dice_class_2: 0.8500 - val_dice_coef_multiclass: 0.8658 - val_iou_class_0: 0.8736 - val_iou_class_1: 0.7443 - val_iou_class_2: 0.7411 - val_iou_coef_multiclass: 0.7642 - val_loss: 0.5243 - learning_rate: 2.0000e-04
# Epoch 13/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.9248 - dice_class_0: 0.9517 - dice_class_1: 0.9052 - dice_class_2: 0.9269 - dice_coef_multiclass: 0.8824 - iou_class_0: 0.9083 - iou_class_1: 0.8280 - iou_class_2: 0.8645 - iou_coef_multiclass: 0.7899 - loss: 0.3146
# Epoch 13: val_loss improved from 0.45206 to 0.44681, saving model to results/V5_OrigConfig_HighResROI.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 465ms/step - accuracy: 0.9249 - dice_class_0: 0.9517 - dice_class_1: 0.9053 - dice_class_2: 0.9269 - dice_coef_multiclass: 0.8825 - iou_class_0: 0.9083 - iou_class_1: 0.8280 - iou_class_2: 0.8645 - iou_coef_multiclass: 0.7899 - loss: 0.3146 - val_accuracy: 0.9144 - val_dice_class_0: 0.9305 - val_dice_class_1: 0.8978 - val_dice_class_2: 0.9228 - val_dice_coef_multiclass: 0.8721 - val_iou_class_0: 0.8710 - val_iou_class_1: 0.8154 - val_iou_class_2: 0.8575 - val_iou_coef_multiclass: 0.7737 - val_loss: 0.4468 - learning_rate: 2.0000e-04
# Epoch 14/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9321 - dice_class_0: 0.9544 - dice_class_1: 0.9141 - dice_class_2: 0.9355 - dice_coef_multiclass: 0.8927 - iou_class_0: 0.9130 - iou_class_1: 0.8422 - iou_class_2: 0.8793 - iou_coef_multiclass: 0.8064 - loss: 0.2951
# Epoch 14: val_loss improved from 0.44681 to 0.35798, saving model to results/V5_OrigConfig_HighResROI.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 465ms/step - accuracy: 0.9321 - dice_class_0: 0.9544 - dice_class_1: 0.9141 - dice_class_2: 0.9355 - dice_coef_multiclass: 0.8927 - iou_class_0: 0.9129 - iou_class_1: 0.8422 - iou_class_2: 0.8793 - iou_coef_multiclass: 0.8063 - loss: 0.2952 - val_accuracy: 0.9207 - val_dice_class_0: 0.9475 - val_dice_class_1: 0.9020 - val_dice_class_2: 0.9244 - val_dice_coef_multiclass: 0.8870 - val_iou_class_0: 0.9004 - val_iou_class_1: 0.8225 - val_iou_class_2: 0.8600 - val_iou_coef_multiclass: 0.7972 - val_loss: 0.3580 - learning_rate: 2.0000e-04
# Epoch 15/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9279 - dice_class_0: 0.9517 - dice_class_1: 0.9087 - dice_class_2: 0.9313 - dice_coef_multiclass: 0.8855 - iou_class_0: 0.9080 - iou_class_1: 0.8332 - iou_class_2: 0.8721 - iou_coef_multiclass: 0.7947 - loss: 0.3179
# Epoch 15: val_loss did not improve from 0.35798
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 66s 437ms/step - accuracy: 0.9279 - dice_class_0: 0.9517 - dice_class_1: 0.9087 - dice_class_2: 0.9313 - dice_coef_multiclass: 0.8855 - iou_class_0: 0.9080 - iou_class_1: 0.8333 - iou_class_2: 0.8721 - iou_coef_multiclass: 0.7948 - loss: 0.3178 - val_accuracy: 0.9053 - val_dice_class_0: 0.9329 - val_dice_class_1: 0.8831 - val_dice_class_2: 0.9115 - val_dice_coef_multiclass: 0.8705 - val_iou_class_0: 0.8748 - val_iou_class_1: 0.7915 - val_iou_class_2: 0.8382 - val_iou_coef_multiclass: 0.7711 - val_loss: 0.5023 - learning_rate: 2.0000e-04
# Epoch 16/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9325 - dice_class_0: 0.9550 - dice_class_1: 0.9145 - dice_class_2: 0.9357 - dice_coef_multiclass: 0.8954 - iou_class_0: 0.9141 - iou_class_1: 0.8428 - iou_class_2: 0.8796 - iou_coef_multiclass: 0.8106 - loss: 0.2858
# Epoch 16: val_loss did not improve from 0.35798
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 437ms/step - accuracy: 0.9325 - dice_class_0: 0.9550 - dice_class_1: 0.9145 - dice_class_2: 0.9357 - dice_coef_multiclass: 0.8953 - iou_class_0: 0.9141 - iou_class_1: 0.8428 - iou_class_2: 0.8796 - iou_coef_multiclass: 0.8106 - loss: 0.2859 - val_accuracy: 0.9142 - val_dice_class_0: 0.9354 - val_dice_class_1: 0.8902 - val_dice_class_2: 0.9254 - val_dice_coef_multiclass: 0.8803 - val_iou_class_0: 0.8791 - val_iou_class_1: 0.8031 - val_iou_class_2: 0.8620 - val_iou_coef_multiclass: 0.7865 - val_loss: 0.3918 - learning_rate: 2.0000e-04
# Epoch 17/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9308 - dice_class_0: 0.9537 - dice_class_1: 0.9123 - dice_class_2: 0.9341 - dice_coef_multiclass: 0.8917 - iou_class_0: 0.9117 - iou_class_1: 0.8395 - iou_class_2: 0.8769 - iou_coef_multiclass: 0.8048 - loss: 0.2973
# Epoch 17: val_loss improved from 0.35798 to 0.31239, saving model to results/V5_OrigConfig_HighResROI.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 466ms/step - accuracy: 0.9308 - dice_class_0: 0.9537 - dice_class_1: 0.9123 - dice_class_2: 0.9341 - dice_coef_multiclass: 0.8917 - iou_class_0: 0.9117 - iou_class_1: 0.8395 - iou_class_2: 0.8769 - iou_coef_multiclass: 0.8048 - loss: 0.2973 - val_accuracy: 0.9288 - val_dice_class_0: 0.9524 - val_dice_class_1: 0.9077 - val_dice_class_2: 0.9353 - val_dice_coef_multiclass: 0.8947 - val_iou_class_0: 0.9093 - val_iou_class_1: 0.8315 - val_iou_class_2: 0.8791 - val_iou_coef_multiclass: 0.8095 - val_loss: 0.3124 - learning_rate: 2.0000e-04
# Epoch 18/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9348 - dice_class_0: 0.9569 - dice_class_1: 0.9178 - dice_class_2: 0.9376 - dice_coef_multiclass: 0.8953 - iou_class_0: 0.9175 - iou_class_1: 0.8485 - iou_class_2: 0.8832 - iou_coef_multiclass: 0.8105 - loss: 0.2845
# Epoch 18: val_loss did not improve from 0.31239
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 436ms/step - accuracy: 0.9348 - dice_class_0: 0.9569 - dice_class_1: 0.9178 - dice_class_2: 0.9376 - dice_coef_multiclass: 0.8953 - iou_class_0: 0.9175 - iou_class_1: 0.8485 - iou_class_2: 0.8832 - iou_coef_multiclass: 0.8106 - loss: 0.2845 - val_accuracy: 0.9011 - val_dice_class_0: 0.9474 - val_dice_class_1: 0.8829 - val_dice_class_2: 0.8921 - val_dice_coef_multiclass: 0.8792 - val_iou_class_0: 0.9006 - val_iou_class_1: 0.7915 - val_iou_class_2: 0.8069 - val_iou_coef_multiclass: 0.7850 - val_loss: 0.4298 - learning_rate: 2.0000e-04
# Epoch 19/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9336 - dice_class_0: 0.9548 - dice_class_1: 0.9165 - dice_class_2: 0.9374 - dice_coef_multiclass: 0.8950 - iou_class_0: 0.9137 - iou_class_1: 0.8465 - iou_class_2: 0.8827 - iou_coef_multiclass: 0.8100 - loss: 0.2845
# Epoch 19: val_loss did not improve from 0.31239
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 437ms/step - accuracy: 0.9336 - dice_class_0: 0.9548 - dice_class_1: 0.9165 - dice_class_2: 0.9374 - dice_coef_multiclass: 0.8950 - iou_class_0: 0.9137 - iou_class_1: 0.8465 - iou_class_2: 0.8827 - iou_coef_multiclass: 0.8100 - loss: 0.2846 - val_accuracy: 0.9157 - val_dice_class_0: 0.9479 - val_dice_class_1: 0.8957 - val_dice_class_2: 0.9168 - val_dice_coef_multiclass: 0.8846 - val_iou_class_0: 0.9012 - val_iou_class_1: 0.8119 - val_iou_class_2: 0.8470 - val_iou_coef_multiclass: 0.7933 - val_loss: 0.3636 - learning_rate: 2.0000e-04
# Epoch 20/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9359 - dice_class_0: 0.9604 - dice_class_1: 0.9190 - dice_class_2: 0.9362 - dice_coef_multiclass: 0.9001 - iou_class_0: 0.9240 - iou_class_1: 0.8506 - iou_class_2: 0.8805 - iou_coef_multiclass: 0.8185 - loss: 0.2779
# Epoch 20: val_loss did not improve from 0.31239
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 436ms/step - accuracy: 0.9359 - dice_class_0: 0.9604 - dice_class_1: 0.9190 - dice_class_2: 0.9362 - dice_coef_multiclass: 0.9001 - iou_class_0: 0.9239 - iou_class_1: 0.8506 - iou_class_2: 0.8805 - iou_coef_multiclass: 0.8185 - loss: 0.2779 - val_accuracy: 0.9231 - val_dice_class_0: 0.9423 - val_dice_class_1: 0.9028 - val_dice_class_2: 0.9322 - val_dice_coef_multiclass: 0.8771 - val_iou_class_0: 0.8917 - val_iou_class_1: 0.8236 - val_iou_class_2: 0.8736 - val_iou_coef_multiclass: 0.7815 - val_loss: 0.3335 - learning_rate: 2.0000e-04
# Epoch 21/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9378 - dice_class_0: 0.9580 - dice_class_1: 0.9213 - dice_class_2: 0.9408 - dice_coef_multiclass: 0.9025 - iou_class_0: 0.9195 - iou_class_1: 0.8544 - iou_class_2: 0.8886 - iou_coef_multiclass: 0.8223 - loss: 0.2682
# Epoch 21: val_loss did not improve from 0.31239
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 437ms/step - accuracy: 0.9378 - dice_class_0: 0.9580 - dice_class_1: 0.9213 - dice_class_2: 0.9408 - dice_coef_multiclass: 0.9024 - iou_class_0: 0.9195 - iou_class_1: 0.8544 - iou_class_2: 0.8886 - iou_coef_multiclass: 0.8223 - loss: 0.2683 - val_accuracy: 0.9274 - val_dice_class_0: 0.9493 - val_dice_class_1: 0.9079 - val_dice_class_2: 0.9340 - val_dice_coef_multiclass: 0.8859 - val_iou_class_0: 0.9037 - val_iou_class_1: 0.8320 - val_iou_class_2: 0.8767 - val_iou_coef_multiclass: 0.7953 - val_loss: 0.3363 - learning_rate: 2.0000e-04
# Epoch 22/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9361 - dice_class_0: 0.9574 - dice_class_1: 0.9186 - dice_class_2: 0.9392 - dice_coef_multiclass: 0.8989 - iou_class_0: 0.9186 - iou_class_1: 0.8503 - iou_class_2: 0.8859 - iou_coef_multiclass: 0.8166 - loss: 0.2714
# Epoch 22: val_loss did not improve from 0.31239
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 436ms/step - accuracy: 0.9361 - dice_class_0: 0.9574 - dice_class_1: 0.9186 - dice_class_2: 0.9392 - dice_coef_multiclass: 0.8989 - iou_class_0: 0.9186 - iou_class_1: 0.8503 - iou_class_2: 0.8859 - iou_coef_multiclass: 0.8166 - loss: 0.2714 - val_accuracy: 0.9244 - val_dice_class_0: 0.9555 - val_dice_class_1: 0.8991 - val_dice_class_2: 0.9294 - val_dice_coef_multiclass: 0.8842 - val_iou_class_0: 0.9150 - val_iou_class_1: 0.8177 - val_iou_class_2: 0.8690 - val_iou_coef_multiclass: 0.7928 - val_loss: 0.3246 - learning_rate: 1.0000e-04
# Epoch 23/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9409 - dice_class_0: 0.9620 - dice_class_1: 0.9244 - dice_class_2: 0.9433 - dice_coef_multiclass: 0.9079 - iou_class_0: 0.9269 - iou_class_1: 0.8598 - iou_class_2: 0.8930 - iou_coef_multiclass: 0.8314 - loss: 0.2563
# Epoch 23: val_loss did not improve from 0.31239
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 436ms/step - accuracy: 0.9409 - dice_class_0: 0.9620 - dice_class_1: 0.9244 - dice_class_2: 0.9433 - dice_coef_multiclass: 0.9078 - iou_class_0: 0.9268 - iou_class_1: 0.8598 - iou_class_2: 0.8930 - iou_coef_multiclass: 0.8314 - loss: 0.2563 - val_accuracy: 0.9286 - val_dice_class_0: 0.9537 - val_dice_class_1: 0.9105 - val_dice_class_2: 0.9319 - val_dice_coef_multiclass: 0.9023 - val_iou_class_0: 0.9118 - val_iou_class_1: 0.8365 - val_iou_class_2: 0.8730 - val_iou_coef_multiclass: 0.8222 - val_loss: 0.3275 - learning_rate: 1.0000e-04
# Epoch 24/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9403 - dice_class_0: 0.9607 - dice_class_1: 0.9245 - dice_class_2: 0.9427 - dice_coef_multiclass: 0.9081 - iou_class_0: 0.9245 - iou_class_1: 0.8603 - iou_class_2: 0.8922 - iou_coef_multiclass: 0.8318 - loss: 0.2584
# Epoch 24: val_loss improved from 0.31239 to 0.31196, saving model to results/V5_OrigConfig_HighResROI.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 464ms/step - accuracy: 0.9403 - dice_class_0: 0.9607 - dice_class_1: 0.9245 - dice_class_2: 0.9427 - dice_coef_multiclass: 0.9081 - iou_class_0: 0.9245 - iou_class_1: 0.8603 - iou_class_2: 0.8922 - iou_coef_multiclass: 0.8318 - loss: 0.2584 - val_accuracy: 0.9251 - val_dice_class_0: 0.9557 - val_dice_class_1: 0.9065 - val_dice_class_2: 0.9257 - val_dice_coef_multiclass: 0.8959 - val_iou_class_0: 0.9153 - val_iou_class_1: 0.8300 - val_iou_class_2: 0.8624 - val_iou_coef_multiclass: 0.8117 - val_loss: 0.3120 - learning_rate: 1.0000e-04
# Epoch 25/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9425 - dice_class_0: 0.9610 - dice_class_1: 0.9275 - dice_class_2: 0.9456 - dice_coef_multiclass: 0.9100 - iou_class_0: 0.9250 - iou_class_1: 0.8651 - iou_class_2: 0.8971 - iou_coef_multiclass: 0.8349 - loss: 0.2469
# Epoch 25: val_loss did not improve from 0.31196
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 437ms/step - accuracy: 0.9425 - dice_class_0: 0.9610 - dice_class_1: 0.9274 - dice_class_2: 0.9456 - dice_coef_multiclass: 0.9100 - iou_class_0: 0.9250 - iou_class_1: 0.8651 - iou_class_2: 0.8971 - iou_coef_multiclass: 0.8349 - loss: 0.2470 - val_accuracy: 0.9231 - val_dice_class_0: 0.9503 - val_dice_class_1: 0.9026 - val_dice_class_2: 0.9268 - val_dice_coef_multiclass: 0.8924 - val_iou_class_0: 0.9055 - val_iou_class_1: 0.8230 - val_iou_class_2: 0.8641 - val_iou_coef_multiclass: 0.8059 - val_loss: 0.3333 - learning_rate: 1.0000e-04
# Epoch 26/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.9434 - dice_class_0: 0.9633 - dice_class_1: 0.9282 - dice_class_2: 0.9452 - dice_coef_multiclass: 0.9108 - iou_class_0: 0.9294 - iou_class_1: 0.8664 - iou_class_2: 0.8965 - iou_coef_multiclass: 0.8364 - loss: 0.2478
# Epoch 26: val_loss did not improve from 0.31196
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 66s 438ms/step - accuracy: 0.9434 - dice_class_0: 0.9633 - dice_class_1: 0.9282 - dice_class_2: 0.9452 - dice_coef_multiclass: 0.9108 - iou_class_0: 0.9294 - iou_class_1: 0.8664 - iou_class_2: 0.8965 - iou_coef_multiclass: 0.8364 - loss: 0.2478 - val_accuracy: 0.9024 - val_dice_class_0: 0.9532 - val_dice_class_1: 0.8674 - val_dice_class_2: 0.9050 - val_dice_coef_multiclass: 0.8743 - val_iou_class_0: 0.9108 - val_iou_class_1: 0.7670 - val_iou_class_2: 0.8278 - val_iou_coef_multiclass: 0.7771 - val_loss: 0.4356 - learning_rate: 1.0000e-04
# Epoch 27/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9417 - dice_class_0: 0.9608 - dice_class_1: 0.9251 - dice_class_2: 0.9450 - dice_coef_multiclass: 0.9113 - iou_class_0: 0.9249 - iou_class_1: 0.8613 - iou_class_2: 0.8960 - iou_coef_multiclass: 0.8371 - loss: 0.2525
# Epoch 27: val_loss did not improve from 0.31196
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 66s 437ms/step - accuracy: 0.9417 - dice_class_0: 0.9609 - dice_class_1: 0.9252 - dice_class_2: 0.9450 - dice_coef_multiclass: 0.9113 - iou_class_0: 0.9249 - iou_class_1: 0.8613 - iou_class_2: 0.8960 - iou_coef_multiclass: 0.8371 - loss: 0.2525 - val_accuracy: 0.9270 - val_dice_class_0: 0.9538 - val_dice_class_1: 0.8996 - val_dice_class_2: 0.9355 - val_dice_coef_multiclass: 0.9066 - val_iou_class_0: 0.9119 - val_iou_class_1: 0.8183 - val_iou_class_2: 0.8794 - val_iou_coef_multiclass: 0.8295 - val_loss: 0.3202 - learning_rate: 1.0000e-04
# Epoch 28/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9426 - dice_class_0: 0.9640 - dice_class_1: 0.9275 - dice_class_2: 0.9434 - dice_coef_multiclass: 0.9113 - iou_class_0: 0.9306 - iou_class_1: 0.8652 - iou_class_2: 0.8934 - iou_coef_multiclass: 0.8372 - loss: 0.2473
# Epoch 28: val_loss improved from 0.31196 to 0.30703, saving model to results/V5_OrigConfig_HighResROI.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 465ms/step - accuracy: 0.9426 - dice_class_0: 0.9640 - dice_class_1: 0.9275 - dice_class_2: 0.9435 - dice_coef_multiclass: 0.9114 - iou_class_0: 0.9305 - iou_class_1: 0.8652 - iou_class_2: 0.8934 - iou_coef_multiclass: 0.8372 - loss: 0.2473 - val_accuracy: 0.9308 - val_dice_class_0: 0.9542 - val_dice_class_1: 0.9143 - val_dice_class_2: 0.9337 - val_dice_coef_multiclass: 0.9034 - val_iou_class_0: 0.9127 - val_iou_class_1: 0.8429 - val_iou_class_2: 0.8764 - val_iou_coef_multiclass: 0.8241 - val_loss: 0.3070 - learning_rate: 1.0000e-04
# Epoch 29/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9474 - dice_class_0: 0.9656 - dice_class_1: 0.9326 - dice_class_2: 0.9494 - dice_coef_multiclass: 0.9179 - iou_class_0: 0.9337 - iou_class_1: 0.8739 - iou_class_2: 0.9039 - iou_coef_multiclass: 0.8484 - loss: 0.2269
# Epoch 29: val_loss did not improve from 0.30703
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 437ms/step - accuracy: 0.9474 - dice_class_0: 0.9656 - dice_class_1: 0.9326 - dice_class_2: 0.9494 - dice_coef_multiclass: 0.9179 - iou_class_0: 0.9336 - iou_class_1: 0.8739 - iou_class_2: 0.9039 - iou_coef_multiclass: 0.8484 - loss: 0.2269 - val_accuracy: 0.9283 - val_dice_class_0: 0.9537 - val_dice_class_1: 0.9076 - val_dice_class_2: 0.9334 - val_dice_coef_multiclass: 0.9060 - val_iou_class_0: 0.9117 - val_iou_class_1: 0.8318 - val_iou_class_2: 0.8758 - val_iou_coef_multiclass: 0.8285 - val_loss: 0.3446 - learning_rate: 1.0000e-04
# Epoch 30/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9463 - dice_class_0: 0.9668 - dice_class_1: 0.9318 - dice_class_2: 0.9469 - dice_coef_multiclass: 0.9164 - iou_class_0: 0.9358 - iou_class_1: 0.8727 - iou_class_2: 0.8994 - iou_coef_multiclass: 0.8458 - loss: 0.2345
# Epoch 30: val_loss did not improve from 0.30703
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 437ms/step - accuracy: 0.9463 - dice_class_0: 0.9668 - dice_class_1: 0.9318 - dice_class_2: 0.9469 - dice_coef_multiclass: 0.9164 - iou_class_0: 0.9358 - iou_class_1: 0.8727 - iou_class_2: 0.8995 - iou_coef_multiclass: 0.8458 - loss: 0.2345 - val_accuracy: 0.9324 - val_dice_class_0: 0.9570 - val_dice_class_1: 0.9093 - val_dice_class_2: 0.9395 - val_dice_coef_multiclass: 0.9113 - val_iou_class_0: 0.9177 - val_iou_class_1: 0.8347 - val_iou_class_2: 0.8863 - val_iou_coef_multiclass: 0.8374 - val_loss: 0.3222 - learning_rate: 1.0000e-04
# Epoch 31/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9453 - dice_class_0: 0.9644 - dice_class_1: 0.9312 - dice_class_2: 0.9465 - dice_coef_multiclass: 0.9159 - iou_class_0: 0.9314 - iou_class_1: 0.8716 - iou_class_2: 0.8989 - iou_coef_multiclass: 0.8449 - loss: 0.2377
# Epoch 31: val_loss did not improve from 0.30703
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 436ms/step - accuracy: 0.9453 - dice_class_0: 0.9644 - dice_class_1: 0.9312 - dice_class_2: 0.9465 - dice_coef_multiclass: 0.9158 - iou_class_0: 0.9314 - iou_class_1: 0.8716 - iou_class_2: 0.8989 - iou_coef_multiclass: 0.8448 - loss: 0.2377 - val_accuracy: 0.9343 - val_dice_class_0: 0.9538 - val_dice_class_1: 0.9193 - val_dice_class_2: 0.9387 - val_dice_coef_multiclass: 0.9154 - val_iou_class_0: 0.9119 - val_iou_class_1: 0.8511 - val_iou_class_2: 0.8850 - val_iou_coef_multiclass: 0.8441 - val_loss: 0.3167 - learning_rate: 1.0000e-04
# Epoch 32/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.9475 - dice_class_0: 0.9653 - dice_class_1: 0.9327 - dice_class_2: 0.9499 - dice_coef_multiclass: 0.9184 - iou_class_0: 0.9330 - iou_class_1: 0.8742 - iou_class_2: 0.9049 - iou_coef_multiclass: 0.8492 - loss: 0.2287
# Epoch 32: val_loss did not improve from 0.30703
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 436ms/step - accuracy: 0.9475 - dice_class_0: 0.9653 - dice_class_1: 0.9327 - dice_class_2: 0.9499 - dice_coef_multiclass: 0.9184 - iou_class_0: 0.9330 - iou_class_1: 0.8742 - iou_class_2: 0.9049 - iou_coef_multiclass: 0.8491 - loss: 0.2287 - val_accuracy: 0.9305 - val_dice_class_0: 0.9544 - val_dice_class_1: 0.9107 - val_dice_class_2: 0.9357 - val_dice_coef_multiclass: 0.9073 - val_iou_class_0: 0.9132 - val_iou_class_1: 0.8370 - val_iou_class_2: 0.8797 - val_iou_coef_multiclass: 0.8308 - val_loss: 0.3297 - learning_rate: 1.0000e-04
# Epoch 33/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9502 - dice_class_0: 0.9655 - dice_class_1: 0.9371 - dice_class_2: 0.9533 - dice_coef_multiclass: 0.9219 - iou_class_0: 0.9334 - iou_class_1: 0.8819 - iou_class_2: 0.9109 - iou_coef_multiclass: 0.8552 - loss: 0.2159
# Epoch 33: val_loss did not improve from 0.30703
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 437ms/step - accuracy: 0.9502 - dice_class_0: 0.9655 - dice_class_1: 0.9371 - dice_class_2: 0.9533 - dice_coef_multiclass: 0.9219 - iou_class_0: 0.9334 - iou_class_1: 0.8819 - iou_class_2: 0.9108 - iou_coef_multiclass: 0.8552 - loss: 0.2159 - val_accuracy: 0.9276 - val_dice_class_0: 0.9541 - val_dice_class_1: 0.9054 - val_dice_class_2: 0.9332 - val_dice_coef_multiclass: 0.9051 - val_iou_class_0: 0.9124 - val_iou_class_1: 0.8283 - val_iou_class_2: 0.8758 - val_iou_coef_multiclass: 0.8271 - val_loss: 0.3479 - learning_rate: 5.0000e-05
# Epoch 34/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9500 - dice_class_0: 0.9670 - dice_class_1: 0.9364 - dice_class_2: 0.9520 - dice_coef_multiclass: 0.9226 - iou_class_0: 0.9362 - iou_class_1: 0.8805 - iou_class_2: 0.9086 - iou_coef_multiclass: 0.8564 - loss: 0.2148
# Epoch 34: val_loss did not improve from 0.30703
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 436ms/step - accuracy: 0.9500 - dice_class_0: 0.9670 - dice_class_1: 0.9364 - dice_class_2: 0.9520 - dice_coef_multiclass: 0.9226 - iou_class_0: 0.9362 - iou_class_1: 0.8805 - iou_class_2: 0.9086 - iou_coef_multiclass: 0.8564 - loss: 0.2149 - val_accuracy: 0.9325 - val_dice_class_0: 0.9581 - val_dice_class_1: 0.9131 - val_dice_class_2: 0.9360 - val_dice_coef_multiclass: 0.9088 - val_iou_class_0: 0.9198 - val_iou_class_1: 0.8408 - val_iou_class_2: 0.8802 - val_iou_coef_multiclass: 0.8332 - val_loss: 0.3092 - learning_rate: 5.0000e-05
# Epoch 35/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.9521 - dice_class_0: 0.9678 - dice_class_1: 0.9398 - dice_class_2: 0.9541 - dice_coef_multiclass: 0.9251 - iou_class_0: 0.9378 - iou_class_1: 0.8866 - iou_class_2: 0.9125 - iou_coef_multiclass: 0.8607 - loss: 0.2111
# Epoch 35: val_loss did not improve from 0.30703
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 66s 438ms/step - accuracy: 0.9521 - dice_class_0: 0.9678 - dice_class_1: 0.9398 - dice_class_2: 0.9541 - dice_coef_multiclass: 0.9251 - iou_class_0: 0.9378 - iou_class_1: 0.8866 - iou_class_2: 0.9125 - iou_coef_multiclass: 0.8607 - loss: 0.2111 - val_accuracy: 0.9313 - val_dice_class_0: 0.9587 - val_dice_class_1: 0.9103 - val_dice_class_2: 0.9355 - val_dice_coef_multiclass: 0.9103 - val_iou_class_0: 0.9208 - val_iou_class_1: 0.8362 - val_iou_class_2: 0.8797 - val_iou_coef_multiclass: 0.8358 - val_loss: 0.3290 - learning_rate: 5.0000e-05
# Epoch 36/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9526 - dice_class_0: 0.9690 - dice_class_1: 0.9392 - dice_class_2: 0.9545 - dice_coef_multiclass: 0.9265 - iou_class_0: 0.9400 - iou_class_1: 0.8855 - iou_class_2: 0.9132 - iou_coef_multiclass: 0.8632 - loss: 0.2050
# Epoch 36: val_loss did not improve from 0.30703
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 437ms/step - accuracy: 0.9526 - dice_class_0: 0.9690 - dice_class_1: 0.9392 - dice_class_2: 0.9545 - dice_coef_multiclass: 0.9265 - iou_class_0: 0.9400 - iou_class_1: 0.8855 - iou_class_2: 0.9132 - iou_coef_multiclass: 0.8632 - loss: 0.2050 - val_accuracy: 0.9357 - val_dice_class_0: 0.9586 - val_dice_class_1: 0.9162 - val_dice_class_2: 0.9406 - val_dice_coef_multiclass: 0.9127 - val_iou_class_0: 0.9206 - val_iou_class_1: 0.8460 - val_iou_class_2: 0.8885 - val_iou_coef_multiclass: 0.8397 - val_loss: 0.3127 - learning_rate: 5.0000e-05
# Epoch 37/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9526 - dice_class_0: 0.9676 - dice_class_1: 0.9392 - dice_class_2: 0.9558 - dice_coef_multiclass: 0.9257 - iou_class_0: 0.9374 - iou_class_1: 0.8857 - iou_class_2: 0.9154 - iou_coef_multiclass: 0.8617 - loss: 0.2080
# Epoch 37: val_loss did not improve from 0.30703
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 437ms/step - accuracy: 0.9526 - dice_class_0: 0.9676 - dice_class_1: 0.9392 - dice_class_2: 0.9557 - dice_coef_multiclass: 0.9257 - iou_class_0: 0.9374 - iou_class_1: 0.8857 - iou_class_2: 0.9154 - iou_coef_multiclass: 0.8617 - loss: 0.2080 - val_accuracy: 0.9343 - val_dice_class_0: 0.9579 - val_dice_class_1: 0.9139 - val_dice_class_2: 0.9394 - val_dice_coef_multiclass: 0.9155 - val_iou_class_0: 0.9195 - val_iou_class_1: 0.8422 - val_iou_class_2: 0.8862 - val_iou_coef_multiclass: 0.8444 - val_loss: 0.3251 - learning_rate: 2.5000e-05
# Epoch 38/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9535 - dice_class_0: 0.9677 - dice_class_1: 0.9410 - dice_class_2: 0.9564 - dice_coef_multiclass: 0.9279 - iou_class_0: 0.9376 - iou_class_1: 0.8889 - iou_class_2: 0.9166 - iou_coef_multiclass: 0.8656 - loss: 0.2038
# Epoch 38: val_loss improved from 0.30703 to 0.29786, saving model to results/V5_OrigConfig_HighResROI.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 69s 464ms/step - accuracy: 0.9535 - dice_class_0: 0.9677 - dice_class_1: 0.9410 - dice_class_2: 0.9564 - dice_coef_multiclass: 0.9279 - iou_class_0: 0.9376 - iou_class_1: 0.8889 - iou_class_2: 0.9166 - iou_coef_multiclass: 0.8656 - loss: 0.2038 - val_accuracy: 0.9362 - val_dice_class_0: 0.9590 - val_dice_class_1: 0.9185 - val_dice_class_2: 0.9404 - val_dice_coef_multiclass: 0.9175 - val_iou_class_0: 0.9215 - val_iou_class_1: 0.8501 - val_iou_class_2: 0.8881 - val_iou_coef_multiclass: 0.8479 - val_loss: 0.2979 - learning_rate: 2.5000e-05
# Epoch 39/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9540 - dice_class_0: 0.9681 - dice_class_1: 0.9419 - dice_class_2: 0.9562 - dice_coef_multiclass: 0.9287 - iou_class_0: 0.9383 - iou_class_1: 0.8904 - iou_class_2: 0.9163 - iou_coef_multiclass: 0.8669 - loss: 0.2027
# Epoch 39: val_loss did not improve from 0.29786
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 436ms/step - accuracy: 0.9540 - dice_class_0: 0.9681 - dice_class_1: 0.9419 - dice_class_2: 0.9562 - dice_coef_multiclass: 0.9287 - iou_class_0: 0.9383 - iou_class_1: 0.8904 - iou_class_2: 0.9163 - iou_coef_multiclass: 0.8669 - loss: 0.2027 - val_accuracy: 0.9367 - val_dice_class_0: 0.9602 - val_dice_class_1: 0.9183 - val_dice_class_2: 0.9405 - val_dice_coef_multiclass: 0.9168 - val_iou_class_0: 0.9237 - val_iou_class_1: 0.8495 - val_iou_class_2: 0.8884 - val_iou_coef_multiclass: 0.8467 - val_loss: 0.3169 - learning_rate: 2.5000e-05
# Epoch 40/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9545 - dice_class_0: 0.9683 - dice_class_1: 0.9424 - dice_class_2: 0.9572 - dice_coef_multiclass: 0.9290 - iou_class_0: 0.9387 - iou_class_1: 0.8914 - iou_class_2: 0.9181 - iou_coef_multiclass: 0.8674 - loss: 0.1993
# Epoch 40: val_loss did not improve from 0.29786
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 66s 437ms/step - accuracy: 0.9545 - dice_class_0: 0.9683 - dice_class_1: 0.9424 - dice_class_2: 0.9572 - dice_coef_multiclass: 0.9290 - iou_class_0: 0.9387 - iou_class_1: 0.8914 - iou_class_2: 0.9181 - iou_coef_multiclass: 0.8674 - loss: 0.1993 - val_accuracy: 0.9347 - val_dice_class_0: 0.9582 - val_dice_class_1: 0.9149 - val_dice_class_2: 0.9398 - val_dice_coef_multiclass: 0.9171 - val_iou_class_0: 0.9201 - val_iou_class_1: 0.8440 - val_iou_class_2: 0.8870 - val_iou_coef_multiclass: 0.8472 - val_loss: 0.3207 - learning_rate: 2.5000e-05
# Epoch 41/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.9557 - dice_class_0: 0.9695 - dice_class_1: 0.9435 - dice_class_2: 0.9583 - dice_coef_multiclass: 0.9306 - iou_class_0: 0.9409 - iou_class_1: 0.8932 - iou_class_2: 0.9202 - iou_coef_multiclass: 0.8703 - loss: 0.1954
# Epoch 41: val_loss did not improve from 0.29786
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 66s 437ms/step - accuracy: 0.9557 - dice_class_0: 0.9695 - dice_class_1: 0.9435 - dice_class_2: 0.9583 - dice_coef_multiclass: 0.9306 - iou_class_0: 0.9409 - iou_class_1: 0.8932 - iou_class_2: 0.9202 - iou_coef_multiclass: 0.8702 - loss: 0.1955 - val_accuracy: 0.9350 - val_dice_class_0: 0.9588 - val_dice_class_1: 0.9160 - val_dice_class_2: 0.9391 - val_dice_coef_multiclass: 0.9176 - val_iou_class_0: 0.9211 - val_iou_class_1: 0.8456 - val_iou_class_2: 0.8859 - val_iou_coef_multiclass: 0.8480 - val_loss: 0.3355 - learning_rate: 2.5000e-05
# Epoch 42/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9555 - dice_class_0: 0.9701 - dice_class_1: 0.9436 - dice_class_2: 0.9576 - dice_coef_multiclass: 0.9306 - iou_class_0: 0.9421 - iou_class_1: 0.8934 - iou_class_2: 0.9188 - iou_coef_multiclass: 0.8702 - loss: 0.1965
# Epoch 42: val_loss did not improve from 0.29786
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 437ms/step - accuracy: 0.9555 - dice_class_0: 0.9701 - dice_class_1: 0.9436 - dice_class_2: 0.9575 - dice_coef_multiclass: 0.9306 - iou_class_0: 0.9421 - iou_class_1: 0.8934 - iou_class_2: 0.9188 - iou_coef_multiclass: 0.8702 - loss: 0.1966 - val_accuracy: 0.9373 - val_dice_class_0: 0.9623 - val_dice_class_1: 0.9185 - val_dice_class_2: 0.9409 - val_dice_coef_multiclass: 0.9190 - val_iou_class_0: 0.9274 - val_iou_class_1: 0.8502 - val_iou_class_2: 0.8890 - val_iou_coef_multiclass: 0.8504 - val_loss: 0.3017 - learning_rate: 2.5000e-05
# Epoch 43/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9560 - dice_class_0: 0.9691 - dice_class_1: 0.9449 - dice_class_2: 0.9582 - dice_coef_multiclass: 0.9302 - iou_class_0: 0.9401 - iou_class_1: 0.8956 - iou_class_2: 0.9198 - iou_coef_multiclass: 0.8695 - loss: 0.1937
# Epoch 43: val_loss did not improve from 0.29786
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 437ms/step - accuracy: 0.9560 - dice_class_0: 0.9691 - dice_class_1: 0.9449 - dice_class_2: 0.9582 - dice_coef_multiclass: 0.9302 - iou_class_0: 0.9401 - iou_class_1: 0.8956 - iou_class_2: 0.9199 - iou_coef_multiclass: 0.8695 - loss: 0.1937 - val_accuracy: 0.9342 - val_dice_class_0: 0.9596 - val_dice_class_1: 0.9147 - val_dice_class_2: 0.9382 - val_dice_coef_multiclass: 0.9166 - val_iou_class_0: 0.9225 - val_iou_class_1: 0.8437 - val_iou_class_2: 0.8844 - val_iou_coef_multiclass: 0.8465 - val_loss: 0.3389 - learning_rate: 1.2500e-05
# Epoch 44/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9564 - dice_class_0: 0.9701 - dice_class_1: 0.9446 - dice_class_2: 0.9588 - dice_coef_multiclass: 0.9321 - iou_class_0: 0.9419 - iou_class_1: 0.8952 - iou_class_2: 0.9211 - iou_coef_multiclass: 0.8728 - loss: 0.1905
# Epoch 44: val_loss did not improve from 0.29786
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 66s 437ms/step - accuracy: 0.9564 - dice_class_0: 0.9701 - dice_class_1: 0.9446 - dice_class_2: 0.9588 - dice_coef_multiclass: 0.9321 - iou_class_0: 0.9419 - iou_class_1: 0.8952 - iou_class_2: 0.9211 - iou_coef_multiclass: 0.8728 - loss: 0.1905 - val_accuracy: 0.9370 - val_dice_class_0: 0.9613 - val_dice_class_1: 0.9182 - val_dice_class_2: 0.9407 - val_dice_coef_multiclass: 0.9197 - val_iou_class_0: 0.9256 - val_iou_class_1: 0.8494 - val_iou_class_2: 0.8884 - val_iou_coef_multiclass: 0.8516 - val_loss: 0.3083 - learning_rate: 1.2500e-05
# Epoch 45/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9578 - dice_class_0: 0.9712 - dice_class_1: 0.9458 - dice_class_2: 0.9605 - dice_coef_multiclass: 0.9332 - iou_class_0: 0.9440 - iou_class_1: 0.8973 - iou_class_2: 0.9242 - iou_coef_multiclass: 0.8749 - loss: 0.1861
# Epoch 45: val_loss did not improve from 0.29786
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 437ms/step - accuracy: 0.9578 - dice_class_0: 0.9711 - dice_class_1: 0.9458 - dice_class_2: 0.9605 - dice_coef_multiclass: 0.9332 - iou_class_0: 0.9440 - iou_class_1: 0.8973 - iou_class_2: 0.9242 - iou_coef_multiclass: 0.8749 - loss: 0.1861 - val_accuracy: 0.9374 - val_dice_class_0: 0.9621 - val_dice_class_1: 0.9194 - val_dice_class_2: 0.9408 - val_dice_coef_multiclass: 0.9204 - val_iou_class_0: 0.9271 - val_iou_class_1: 0.8514 - val_iou_class_2: 0.8888 - val_iou_coef_multiclass: 0.8529 - val_loss: 0.3147 - learning_rate: 1.2500e-05
# Epoch 46/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.9568 - dice_class_0: 0.9709 - dice_class_1: 0.9454 - dice_class_2: 0.9585 - dice_coef_multiclass: 0.9330 - iou_class_0: 0.9436 - iou_class_1: 0.8965 - iou_class_2: 0.9205 - iou_coef_multiclass: 0.8744 - loss: 0.1879
# Epoch 46: val_loss did not improve from 0.29786
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 66s 438ms/step - accuracy: 0.9568 - dice_class_0: 0.9709 - dice_class_1: 0.9454 - dice_class_2: 0.9585 - dice_coef_multiclass: 0.9330 - iou_class_0: 0.9436 - iou_class_1: 0.8965 - iou_class_2: 0.9205 - iou_coef_multiclass: 0.8744 - loss: 0.1879 - val_accuracy: 0.9360 - val_dice_class_0: 0.9604 - val_dice_class_1: 0.9170 - val_dice_class_2: 0.9398 - val_dice_coef_multiclass: 0.9183 - val_iou_class_0: 0.9240 - val_iou_class_1: 0.8475 - val_iou_class_2: 0.8869 - val_iou_coef_multiclass: 0.8492 - val_loss: 0.3233 - learning_rate: 1.2500e-05
# Epoch 47/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9578 - dice_class_0: 0.9713 - dice_class_1: 0.9457 - dice_class_2: 0.9604 - dice_coef_multiclass: 0.9335 - iou_class_0: 0.9443 - iou_class_1: 0.8971 - iou_class_2: 0.9240 - iou_coef_multiclass: 0.8754 - loss: 0.1865
# Epoch 47: val_loss did not improve from 0.29786
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 66s 437ms/step - accuracy: 0.9578 - dice_class_0: 0.9713 - dice_class_1: 0.9457 - dice_class_2: 0.9604 - dice_coef_multiclass: 0.9336 - iou_class_0: 0.9443 - iou_class_1: 0.8971 - iou_class_2: 0.9240 - iou_coef_multiclass: 0.8754 - loss: 0.1865 - val_accuracy: 0.9363 - val_dice_class_0: 0.9609 - val_dice_class_1: 0.9175 - val_dice_class_2: 0.9399 - val_dice_coef_multiclass: 0.9197 - val_iou_class_0: 0.9248 - val_iou_class_1: 0.8482 - val_iou_class_2: 0.8870 - val_iou_coef_multiclass: 0.8515 - val_loss: 0.3273 - learning_rate: 6.2500e-06
# Epoch 48/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9579 - dice_class_0: 0.9705 - dice_class_1: 0.9470 - dice_class_2: 0.9600 - dice_coef_multiclass: 0.9343 - iou_class_0: 0.9427 - iou_class_1: 0.8996 - iou_class_2: 0.9232 - iou_coef_multiclass: 0.8768 - loss: 0.1836
# Epoch 48: val_loss did not improve from 0.29786
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 436ms/step - accuracy: 0.9579 - dice_class_0: 0.9705 - dice_class_1: 0.9470 - dice_class_2: 0.9600 - dice_coef_multiclass: 0.9343 - iou_class_0: 0.9427 - iou_class_1: 0.8996 - iou_class_2: 0.9232 - iou_coef_multiclass: 0.8768 - loss: 0.1836 - val_accuracy: 0.9349 - val_dice_class_0: 0.9616 - val_dice_class_1: 0.9142 - val_dice_class_2: 0.9384 - val_dice_coef_multiclass: 0.9193 - val_iou_class_0: 0.9263 - val_iou_class_1: 0.8429 - val_iou_class_2: 0.8845 - val_iou_coef_multiclass: 0.8509 - val_loss: 0.3393 - learning_rate: 6.2500e-06
# Epoch 49/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9582 - dice_class_0: 0.9707 - dice_class_1: 0.9466 - dice_class_2: 0.9612 - dice_coef_multiclass: 0.9346 - iou_class_0: 0.9432 - iou_class_1: 0.8989 - iou_class_2: 0.9255 - iou_coef_multiclass: 0.8773 - loss: 0.1830
# Epoch 49: val_loss did not improve from 0.29786
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 436ms/step - accuracy: 0.9582 - dice_class_0: 0.9707 - dice_class_1: 0.9466 - dice_class_2: 0.9612 - dice_coef_multiclass: 0.9346 - iou_class_0: 0.9432 - iou_class_1: 0.8989 - iou_class_2: 0.9255 - iou_coef_multiclass: 0.8773 - loss: 0.1830 - val_accuracy: 0.9369 - val_dice_class_0: 0.9622 - val_dice_class_1: 0.9175 - val_dice_class_2: 0.9401 - val_dice_coef_multiclass: 0.9210 - val_iou_class_0: 0.9273 - val_iou_class_1: 0.8486 - val_iou_class_2: 0.8879 - val_iou_coef_multiclass: 0.8540 - val_loss: 0.3323 - learning_rate: 6.2500e-06
# Epoch 50/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.9575 - dice_class_0: 0.9706 - dice_class_1: 0.9460 - dice_class_2: 0.9596 - dice_coef_multiclass: 0.9341 - iou_class_0: 0.9429 - iou_class_1: 0.8978 - iou_class_2: 0.9226 - iou_coef_multiclass: 0.8765 - loss: 0.1858
# Epoch 50: val_loss did not improve from 0.29786
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 436ms/step - accuracy: 0.9575 - dice_class_0: 0.9706 - dice_class_1: 0.9460 - dice_class_2: 0.9596 - dice_coef_multiclass: 0.9341 - iou_class_0: 0.9429 - iou_class_1: 0.8978 - iou_class_2: 0.9226 - iou_coef_multiclass: 0.8765 - loss: 0.1858 - val_accuracy: 0.9372 - val_dice_class_0: 0.9618 - val_dice_class_1: 0.9191 - val_dice_class_2: 0.9400 - val_dice_coef_multiclass: 0.9212 - val_iou_class_0: 0.9266 - val_iou_class_1: 0.8510 - val_iou_class_2: 0.8875 - val_iou_coef_multiclass: 0.8543 - val_loss: 0.3225 - learning_rate: 6.2500e-06
# Epoch 51/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9585 - dice_class_0: 0.9709 - dice_class_1: 0.9473 - dice_class_2: 0.9612 - dice_coef_multiclass: 0.9351 - iou_class_0: 0.9436 - iou_class_1: 0.9000 - iou_class_2: 0.9255 - iou_coef_multiclass: 0.8781 - loss: 0.1826
# Epoch 51: val_loss did not improve from 0.29786
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 436ms/step - accuracy: 0.9585 - dice_class_0: 0.9709 - dice_class_1: 0.9473 - dice_class_2: 0.9612 - dice_coef_multiclass: 0.9351 - iou_class_0: 0.9436 - iou_class_1: 0.9000 - iou_class_2: 0.9255 - iou_coef_multiclass: 0.8781 - loss: 0.1826 - val_accuracy: 0.9366 - val_dice_class_0: 0.9625 - val_dice_class_1: 0.9178 - val_dice_class_2: 0.9393 - val_dice_coef_multiclass: 0.9211 - val_iou_class_0: 0.9279 - val_iou_class_1: 0.8489 - val_iou_class_2: 0.8862 - val_iou_coef_multiclass: 0.8540 - val_loss: 0.3306 - learning_rate: 3.1250e-06
# Epoch 52/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.9587 - dice_class_0: 0.9706 - dice_class_1: 0.9476 - dice_class_2: 0.9616 - dice_coef_multiclass: 0.9360 - iou_class_0: 0.9430 - iou_class_1: 0.9005 - iou_class_2: 0.9262 - iou_coef_multiclass: 0.8797 - loss: 0.1812
# Epoch 52: val_loss did not improve from 0.29786
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 436ms/step - accuracy: 0.9587 - dice_class_0: 0.9706 - dice_class_1: 0.9476 - dice_class_2: 0.9616 - dice_coef_multiclass: 0.9360 - iou_class_0: 0.9430 - iou_class_1: 0.9005 - iou_class_2: 0.9262 - iou_coef_multiclass: 0.8797 - loss: 0.1812 - val_accuracy: 0.9362 - val_dice_class_0: 0.9617 - val_dice_class_1: 0.9177 - val_dice_class_2: 0.9394 - val_dice_coef_multiclass: 0.9209 - val_iou_class_0: 0.9264 - val_iou_class_1: 0.8485 - val_iou_class_2: 0.8863 - val_iou_coef_multiclass: 0.8536 - val_loss: 0.3361 - learning_rate: 3.1250e-06
# Epoch 53/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9574 - dice_class_0: 0.9697 - dice_class_1: 0.9456 - dice_class_2: 0.9605 - dice_coef_multiclass: 0.9342 - iou_class_0: 0.9415 - iou_class_1: 0.8970 - iou_class_2: 0.9242 - iou_coef_multiclass: 0.8766 - loss: 0.1890
# Epoch 53: val_loss did not improve from 0.29786
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 435ms/step - accuracy: 0.9574 - dice_class_0: 0.9697 - dice_class_1: 0.9456 - dice_class_2: 0.9605 - dice_coef_multiclass: 0.9342 - iou_class_0: 0.9415 - iou_class_1: 0.8970 - iou_class_2: 0.9242 - iou_coef_multiclass: 0.8766 - loss: 0.1890 - val_accuracy: 0.9369 - val_dice_class_0: 0.9619 - val_dice_class_1: 0.9187 - val_dice_class_2: 0.9398 - val_dice_coef_multiclass: 0.9209 - val_iou_class_0: 0.9269 - val_iou_class_1: 0.8505 - val_iou_class_2: 0.8871 - val_iou_coef_multiclass: 0.8537 - val_loss: 0.3276 - learning_rate: 3.1250e-06
# Epoch 53: early stopping
# Restoring model weights from the end of the best epoch: 38.
# ✓ Training completed
#
# Generating visualizations...
#   ✓ Saved: results/V5_OrigConfig_HighResROI_history.png
#   ✓ Saved: results/V5_OrigConfig_HighResROI_predictions_cdr.png
# ================================================================================
# EVALUATION: V5_OrigConfig_HighResROI
# ================================================================================
#
# Saving all 400 test predictions to results/V5_OrigConfig_HighResROI_all_preds...
#   Processed 50/400
#   Processed 100/400
#   Processed 150/400
#   Processed 200/400
#   Processed 250/400
#   Processed 300/400
#   Processed 350/400
#   Processed 400/400
# ✓ Saved comparison masks to results/V5_OrigConfig_HighResROI_all_preds
#   ✓ Saved: results/V5_OrigConfig_HighResROI_confusion_matrices.png
# Confusion Matrix:
# [[21852115   980830     1367]
#  [  789384 38240239  2355045]
#  [     232  2320649 38317739]]
#
# Normalized Confusion Matrix:
# [[0.957 0.043 0.   ]
#  [0.019 0.924 0.057]
#  [0.    0.057 0.943]]
#
# Precision, Recall, F1 Score per class (ROI-level):
#   Background: Precision=0.9651, Recall=0.9570, F1=0.9610
#   Disc: Precision=0.9205, Recall=0.9240, F1=0.9223
#   Cup: Precision=0.9421, Recall=0.9429, F1=0.9425
#
# Macro-averaged metrics:
#   Precision: 0.9426
#   Recall: 0.9413
#   F1 Score: 0.9419
#   Background: Dice=0.9610, IoU=0.9250
#   Disc: Dice=0.9223, IoU=0.8558
#   Cup: Dice=0.9425, IoU=0.8912
#
# ================================================================================
# GLAUCOMA PROGRESSION ANALYSIS (Using Area-based CDR on full-image mapped predictions)
# ================================================================================
#
# --------------------------------------------------------------------------------
# CDR Statistics:
# --------------------------------------------------------------------------------
#   Mean GT CDR:   0.5984 ± 0.1782
#   Mean Pred CDR: 1.0082 ± 0.2168
#   Mean CDR Error: 0.4099 ± 0.1073
#
# ================================================================================
# PROGRESSION CLASSIFICATION ACCURACY
# ================================================================================
#
# Overall Accuracy: 9.25%
#   - Correctly Classified: 37/400 samples
#   - Incorrectly Classified: 363/400 samples
#
# --------------------------------------------------------------------------------
# Per-Class Results:
# --------------------------------------------------------------------------------
# Severity     GT Count     Pred Count   Correct      Accuracy
# --------------------------------------------------------------------------------
# Normal       0            0            0            0.00        %
# Suspect      257          0            0            0.00        %
# Moderate     106          29           0            0.00        %
# Critical     37           371          37           100.00      %
#
# ================================================================================
# INTERPRETATION EXAMPLE:
# ================================================================================
#   - GT says 'Normal' for 0 images
#   - Model says 'Normal' for 0 images
#   - Model correctly predicts 0 as 'Normal'
#   - Accuracy for Normal class: 0/0 = 0.0%
#
# ================================================================================
# MANUAL REVIEW RECOMMENDATIONS
# ================================================================================
#
# Samples Requiring Manual Review: 400/400 (100.0%)
#
# Criteria for Manual Review:
#   1. All Critical cases (high-risk, requires expert verification)
#   2. Classification mismatches (GT ≠ Predicted severity)
#
# Reason: Critical cases need expert confirmation, and mismatches may
# indicate borderline cases or segmentation issues requiring review.
#
# Breakdown:
#   - Critical cases: 37 samples
#   - Classification mismatches: 363 samples
#   - Overlap (Critical + Mismatch): 0 samples
#
# ✓ Saved: results/glaucoma_progression_analysis.csv
#   ✓ Saved: results/cdr_analysis.png
# ================================================================================
# MC DROPOUT UNCERTAINTY ESTIMATION
# ================================================================================
#
# Running MC Dropout with 15 stochastic forward passes...
#   Completed: 5/15 forward passes
#   Completed: 10/15 forward passes
#   Completed: 15/15 forward passes
# ✓ MC Dropout completed
#   Background uncertainty: 0.0013
#   Disc uncertainty: 0.0026
#   Cup uncertainty: 0.0015
#
# ====================================================================================================
#                                  TRAINING AND EVALUATION COMPLETED!
# ====================================================================================================
#
# Model: V5 - Original Config + High-Res ROI Only (simplest ablation)
# Parameters: 47,631,627
# ROI Extraction: Padding=1.2x, Size=(512, 512)
# Results saved in: results/
#
# Generated Files:
#   - Training history: results/V5_OrigConfig_HighResROI_history.png
#   - Predictions with CDR: results/V5_OrigConfig_HighResROI_predictions_cdr.png
#   - CDR Analysis: results/cdr_analysis.png
#   - Progression CSV: results/glaucoma_progression_analysis.csv
#   - Confusion Matrices: results/V5_OrigConfig_HighResROI_confusion_matrices.png
#
# ====================================================================================================
