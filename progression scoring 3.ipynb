# %%
"""
MOBILENET-UNET WITH GLAUCOMA PROGRESSION SCORING
=================================================
Enhanced with:
1. Deeper Decoder Architecture
2. Focal-EIoU Combined Loss
3. MC Dropout for Uncertainty Estimation
4. Glaucoma Progression Scoring based on Cup-to-Disc Ratio (CDR)

Glaucoma Scoring System:
- Normal: CDR < 0.3
- Suspect: 0.3 ≤ CDR < 0.6
- Moderate: 0.6 ≤ CDR < 0.8
- Critical: CDR ≥ 0.8

Additional Features:
- Vertical CDR calculation (vCDR)
- Horizontal CDR calculation (hCDR)
- Average CDR for overall assessment
- Risk classification per sample
- Progression tracking visualization
"""

import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, backend as K
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import albumentations as A
import warnings
import gc
warnings.filterwarnings('ignore')

# Set plot style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# ============================================================================
# GPU CONFIGURATION
# ============================================================================

def configure_gpu():
    """Configure GPU settings for optimal performance"""
    print("Configuring GPU settings...")
    physical_devices = tf.config.list_physical_devices('GPU')
    if physical_devices:
        try:
            for gpu in physical_devices:
                tf.config.experimental.set_memory_growth(gpu, True)
            tf.config.set_visible_devices(physical_devices[0], 'GPU')
            print(f"✓ GPU found: {physical_devices}")
            return True
        except RuntimeError as e:
            print(f"✗ GPU configuration error: {e}")
            return False
    else:
        print("✗ No GPU found, using CPU")
        return False

# ============================================================================
# DATA LOADING
# ============================================================================

def load_images_masks(images_folder, masks_folder, img_size=(256,256)):
    """Load images and masks from folders"""
    images, masks = [], []
    image_files = sorted(os.listdir(images_folder))
    mask_files = sorted(os.listdir(masks_folder))
    mask_dict = {os.path.splitext(f)[0]: f for f in mask_files}
    
    for img_file in image_files:
        base = os.path.splitext(img_file)[0]
        if base in mask_dict:
            img = cv2.imread(os.path.join(images_folder, img_file))
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, img_size) / 255.0
            
            mask = cv2.imread(os.path.join(masks_folder, mask_dict[base]), cv2.IMREAD_GRAYSCALE)
            mask = cv2.resize(mask, img_size)
            unique_vals = np.unique(mask)
            if len(unique_vals) > 3 or np.max(unique_vals) > 2:
                mask = np.clip(mask // 85, 0, 2).astype(np.uint8)
            
            images.append(img)
            masks.append(mask)
    
    return np.array(images, dtype=np.float32), np.array(masks, dtype=np.uint8)

def load_all_data(root_dir):
    """Load all data from existing splits and merge"""
    all_images, all_masks = [], []
    for split in ["train", "val", "test"]:
        print(f"Loading {split} data...")
        imgs, msks = load_images_masks(
            os.path.join(root_dir, split, "Images"),
            os.path.join(root_dir, split, "Masks")
        )
        all_images.append(imgs)
        all_masks.append(msks)
        print(f"  {split}: {imgs.shape[0]} samples")
    
    all_images = np.concatenate(all_images, axis=0)
    all_masks = np.concatenate(all_masks, axis=0)
    return all_images, all_masks

def create_new_split(all_images, all_masks):
    """Create new split: 600 train, 200 val, 400 test"""
    X_temp, X_test, y_temp, y_test = train_test_split(
        all_images, all_masks, test_size=400, random_state=42
    )
    X_train, X_val, y_train, y_val = train_test_split(
        X_temp, y_temp, test_size=200, random_state=42
    )
    print(f"Split - Train: {X_train.shape[0]}, Val: {X_val.shape[0]}, Test: {X_test.shape[0]}")
    return (X_train, y_train), (X_val, y_val), (X_test, y_test)

# ============================================================================
# DATA AUGMENTATION
# ============================================================================

def setup_augmentations():
    return A.Compose([
        A.RandomBrightnessContrast(brightness_limit=0.15, contrast_limit=0.15, p=0.7),
        A.HueSaturationValue(hue_shift_limit=10, sat_shift_limit=15, val_shift_limit=10, p=0.5),
        A.GaussianBlur(blur_limit=3, p=0.3),
        A.RandomGamma(gamma_limit=(80, 120), p=0.3),
    ])

def data_generator(images, masks, batch_size, augment=None):
    idxs = np.arange(len(images))
    while True:
        np.random.shuffle(idxs)
        for i in range(0, len(images), batch_size):
            batch_idxs = idxs[i:i+batch_size]
            batch_x, batch_y = [], []
            
            for idx in batch_idxs:
                img, mask = images[idx], masks[idx]
                
                if augment:
                    aug = augment(image=img, mask=mask)
                    img_aug, mask_aug = aug['image'], aug['mask']
                else:
                    img_aug, mask_aug = img, mask
                
                mask_cat = to_categorical(mask_aug, num_classes=3)
                batch_x.append(img_aug)
                batch_y.append(mask_cat)
            
            yield np.stack(batch_x).astype(np.float32), np.stack(batch_y).astype(np.float32)

# ============================================================================
# LOSS FUNCTIONS
# ============================================================================

def focal_loss(y_true, y_pred, gamma=2.0, alpha=None, epsilon=1e-7):
    if alpha is None:
        alpha = [0.25, 1.0, 1.0]
    
    y_pred = K.clip(y_pred, epsilon, 1.0 - epsilon)
    focal_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        pt = y_pred_c
        focal_weight = K.pow(1.0 - pt, gamma)
        cross_entropy = -K.log(pt)
        focal_loss_c = alpha[c] * focal_weight * cross_entropy * y_true_c
        focal_loss_value += K.mean(focal_loss_c)
    
    return focal_loss_value

def enhanced_iou_loss(y_true, y_pred, smooth=1e-7):
    eiou_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        
        intersection = K.sum(y_true_c * y_pred_c, axis=[1, 2])
        union = K.sum(y_true_c, axis=[1, 2]) + K.sum(y_pred_c, axis=[1, 2]) - intersection
        iou = (intersection + smooth) / (union + smooth)
        
        height = K.cast(K.shape(y_true_c)[1], 'float32')
        width = K.cast(K.shape(y_true_c)[2], 'float32')
        
        y_coords = K.arange(0, height)
        x_coords = K.arange(0, width)
        y_grid = K.tile(K.reshape(y_coords, (-1, 1)), (1, K.cast(width, 'int32')))
        x_grid = K.tile(K.reshape(x_coords, (1, -1)), (K.cast(height, 'int32'), 1))
        y_grid = K.cast(y_grid, 'float32')
        x_grid = K.cast(x_grid, 'float32')
        
        true_mass = K.sum(y_true_c, axis=[1, 2]) + smooth
        true_center_y = K.sum(y_true_c * y_grid, axis=[1, 2]) / true_mass
        true_center_x = K.sum(y_true_c * x_grid, axis=[1, 2]) / true_mass
        
        pred_mass = K.sum(y_pred_c, axis=[1, 2]) + smooth
        pred_center_y = K.sum(y_pred_c * y_grid, axis=[1, 2]) / pred_mass
        pred_center_x = K.sum(y_pred_c * x_grid, axis=[1, 2]) / pred_mass
        
        center_distance = K.square(true_center_y - pred_center_y) + K.square(true_center_x - pred_center_x)
        diagonal = K.square(height) + K.square(width)
        center_penalty = center_distance / (diagonal + smooth)
        
        true_width = K.sqrt(K.sum(K.sum(y_true_c, axis=1), axis=1) + smooth)
        true_height = K.sqrt(K.sum(K.sum(y_true_c, axis=2), axis=1) + smooth)
        pred_width = K.sqrt(K.sum(K.sum(y_pred_c, axis=1), axis=1) + smooth)
        pred_height = K.sqrt(K.sum(K.sum(y_pred_c, axis=2), axis=1) + smooth)
        
        width_diff = K.square(pred_width - true_width)
        height_diff = K.square(pred_height - true_height)
        aspect_penalty = width_diff / (K.square(width) + smooth) + height_diff / (K.square(height) + smooth)
        
        eiou_c = 1.0 - iou + center_penalty + aspect_penalty
        eiou_loss_value += K.mean(eiou_c)
    
    return eiou_loss_value / 3.0

def focal_eiou_combined_loss(y_true, y_pred, focal_weight=1.0, eiou_weight=1.0, gamma=2.0, alpha=None):
    fl = focal_loss(y_true, y_pred, gamma=gamma, alpha=alpha)
    eiou = enhanced_iou_loss(y_true, y_pred)
    return focal_weight * fl + eiou_weight * eiou

# ============================================================================
# MODEL ARCHITECTURE
# ============================================================================

def enhanced_decoder_block(x, skip_connection, filters, block_name, dropout_rate=0.3):
    """Enhanced decoder block with residual connections and dropout"""
    x = layers.UpSampling2D((2, 2), name=f'{block_name}_upsample')(x)
    
    if skip_connection.shape[-1] != x.shape[-1]:
        skip_connection = layers.Conv2D(x.shape[-1], (1, 1), use_bias=False,
                                      name=f'{block_name}_skip_align')(skip_connection)
        skip_connection = layers.BatchNormalization(name=f'{block_name}_skip_bn')(skip_connection)
    
    x = layers.Concatenate(name=f'{block_name}_concat')([x, skip_connection])
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv1')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn1')(x)
    x = layers.Dropout(dropout_rate, name=f'{block_name}_dropout')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv2')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn2')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv3')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn3')(x)
    
    residual = x
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv4')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn4')(x)
    
    x = layers.Add(name=f'{block_name}_residual')([x, residual])
    x = layers.Conv2D(filters, (1, 1), activation='relu', padding='same', name=f'{block_name}_conv_final')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn_final')(x)
    
    return x

def build_deeper_focal_mc_unet(input_shape=(256, 256, 3), num_classes=3, dropout_rate=0.3):
    """Build MobileNetV2-UNet with deeper decoder, focal-eiou loss, and MC dropout"""
    inputs = layers.Input(input_shape, dtype='float32')
    backbone = MobileNetV2(input_tensor=inputs, weights='imagenet', include_top=False)
    
    skip_1 = backbone.get_layer('block_1_expand_relu').output  # 128×128
    skip_2 = backbone.get_layer('block_3_expand_relu').output  # 64×64
    skip_3 = backbone.get_layer('block_6_expand_relu').output  # 32×32
    skip_4 = backbone.get_layer('block_13_expand_relu').output # 16×16
    bridge = backbone.output  # 8×8
    
    # Deeper bridge
    bridge = layers.Conv2D(1024, (3, 3), activation='relu', padding='same')(bridge)
    bridge = layers.BatchNormalization()(bridge)
    bridge = layers.Dropout(dropout_rate, name='bridge_dropout')(bridge)
    
    # Decoder with deeper blocks
    x = enhanced_decoder_block(bridge, skip_4, 512, 'decoder_1', dropout_rate)
    x = enhanced_decoder_block(x, skip_3, 256, 'decoder_2', dropout_rate)
    x = enhanced_decoder_block(x, skip_2, 128, 'decoder_3', dropout_rate * 0.7)
    x = enhanced_decoder_block(x, skip_1, 64, 'decoder_4', dropout_rate * 0.5)
    
    # Final upsampling
    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    
    outputs = layers.Conv2D(num_classes, (1, 1), activation='softmax', dtype='float32')(x)
    
    model = models.Model(inputs, outputs)
    
    # Print configuration
    dropout_layers = [layer for layer in model.layers if isinstance(layer, layers.Dropout)]
    print(f"\nModel Configuration:")
    print(f"  Total Parameters: {model.count_params():,}")
    print(f"  Dropout Layers: {len(dropout_layers)}")
    print(f"  Architecture: Deeper Decoder + Focal-EIoU + MC Dropout")
    
    return model

# ============================================================================
# METRICS
# ============================================================================

def dice_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    return (2. * intersection + smooth) / (K.sum(y_true_class) + K.sum(y_pred_class) + smooth)

def dice_class_0(y_true, y_pred): return dice_coef_class(y_true, y_pred, 0)
def dice_class_1(y_true, y_pred): return dice_coef_class(y_true, y_pred, 1)
def dice_class_2(y_true, y_pred): return dice_coef_class(y_true, y_pred, 2)

def iou_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    union = K.sum(y_true_class) + K.sum(y_pred_class) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_class_0(y_true, y_pred): return iou_coef_class(y_true, y_pred, 0)
def iou_class_1(y_true, y_pred): return iou_coef_class(y_true, y_pred, 1)
def iou_class_2(y_true, y_pred): return iou_coef_class(y_true, y_pred, 2)

def mc_dropout_predict(model, X, num_samples=15, batch_size=4, verbose=True):
    """MC Dropout prediction for uncertainty estimation"""
    if verbose:
        print(f"\nRunning MC Dropout with {num_samples} stochastic forward passes...")
    
    predictions = []
    num_batches = int(np.ceil(len(X) / batch_size))
    
    for i in range(num_samples):
        if verbose and (i + 1) % 5 == 0:
            print(f"  Completed: {i+1}/{num_samples} forward passes")
        
        batch_preds = []
        for batch_idx in range(num_batches):
            start_idx = batch_idx * batch_size
            end_idx = min(start_idx + batch_size, len(X))
            X_batch = X[start_idx:end_idx]
            
            pred_batch = model(X_batch, training=True)
            batch_preds.append(pred_batch.numpy())
        
        pred = np.concatenate(batch_preds, axis=0)
        predictions.append(pred)
        
        if (i + 1) % 5 == 0:
            gc.collect()
    
    all_preds = np.array(predictions)
    mean_pred = np.mean(all_preds, axis=0)
    std_pred = np.std(all_preds, axis=0)
    
    del all_preds
    gc.collect()
    
    if verbose:
        print(f"✓ MC Dropout completed")
    
    return mean_pred, std_pred

# ============================================================================
# GLAUCOMA PROGRESSION SCORING
# ============================================================================

def calculate_cdr(mask, disc_class=1, cup_class=2, method='vertical'):
    """
    Calculate Cup-to-Disc Ratio (CDR) from segmentation mask
    
    Methods:
    - 'vertical': Vertical diameter ratio (clinical standard, most accurate)
    - 'area_sqrt': Square root of area ratio (robust alternative)
    
    Args:
        mask: Segmentation mask (H, W) with class labels
        disc_class: Class label for optic disc (default=1)
        cup_class: Class label for optic cup (default=2)
        method: Calculation method (default='vertical')
    
    Returns:
        dict with vCDR, hCDR, avgCDR, area_CDR
    """
    disc_mask = (mask == disc_class).astype(np.uint8)
    cup_mask = (mask == cup_class).astype(np.uint8)
    
    # Check if disc and cup are present
    disc_area = disc_mask.sum()
    cup_area = cup_mask.sum()
    
    if disc_area == 0 or cup_area == 0:
        return {'vCDR': 0.0, 'hCDR': 0.0, 'avgCDR': 0.0, 'area_CDR': 0.0, 'valid': False, 
                'method': method, 'disc_area': 0, 'cup_area': 0}
    
    # Find coordinates
    disc_coords = np.where(disc_mask > 0)
    cup_coords = np.where(cup_mask > 0)
    
    # Calculate diameters using bounding box
    disc_v_diameter = disc_coords[0].max() - disc_coords[0].min() + 1
    cup_v_diameter = cup_coords[0].max() - cup_coords[0].min() + 1
    disc_h_diameter = disc_coords[1].max() - disc_coords[1].min() + 1
    cup_h_diameter = cup_coords[1].max() - cup_coords[1].min() + 1
    
    # Calculate CDRs
    vCDR = cup_v_diameter / disc_v_diameter if disc_v_diameter > 0 else 0.0
    hCDR = cup_h_diameter / disc_h_diameter if disc_h_diameter > 0 else 0.0
    
    # Calculate area-based CDR
    area_CDR = np.sqrt(cup_area / disc_area)
    
    # Choose primary CDR based on method
    if method == 'vertical':
        avgCDR = vCDR  # Use vertical CDR (clinical standard)
    elif method == 'area_sqrt':
        avgCDR = area_CDR  # Use area-based
    else:
        avgCDR = (vCDR + hCDR) / 2.0  # Average of both
    
    return {
        'vCDR': float(vCDR),
        'hCDR': float(hCDR),
        'avgCDR': float(avgCDR),
        'area_CDR': float(area_CDR),
        'valid': True,
        'method': method,
        'disc_area': int(disc_area),
        'cup_area': int(cup_area),
        'disc_v_diameter': int(disc_v_diameter),
        'cup_v_diameter': int(cup_v_diameter)
    }

def classify_glaucoma_severity(cdr):
    """
    Classify glaucoma severity based on CDR
    
    Classification:
    - Normal: CDR < 0.3
    - Suspect: 0.3 ≤ CDR < 0.6
    - Moderate: 0.6 ≤ CDR < 0.8
    - Critical: CDR ≥ 0.8
    
    Args:
        cdr: Cup-to-Disc Ratio (float)
    
    Returns:
        tuple: (severity_class, severity_label, color)
    """
    if cdr < 0.3:
        return 0, 'Normal', '#4CAF50'  # Green
    elif cdr < 0.6:
        return 1, 'Suspect', '#FFC107'  # Amber
    elif cdr < 0.8:
        return 2, 'Moderate', '#FF9800'  # Orange
    else:
        return 3, 'Critical', '#F44336'  # Red

def analyze_glaucoma_progression(masks, predictions, cdr_method='area_sqrt'):
    """
    Analyze glaucoma progression for a batch of samples
    
    Args:
        masks: Ground truth masks (N, H, W)
        predictions: Predicted masks (N, H, W)
        cdr_method: CDR calculation method (default='area_sqrt' for robustness)
    
    Returns:
        DataFrame with CDR metrics and classifications
    """
    results = []
    
    for i, (gt_mask, pred_mask) in enumerate(zip(masks, predictions)):
        # Calculate CDR for ground truth
        gt_cdr = calculate_cdr(gt_mask, method=cdr_method)
        
        # Calculate CDR for prediction
        pred_cdr = calculate_cdr(pred_mask, method=cdr_method)
        
        # Classify severity
        if gt_cdr['valid']:
            gt_class, gt_label, gt_color = classify_glaucoma_severity(gt_cdr['avgCDR'])
        else:
            gt_class, gt_label, gt_color = -1, 'Invalid', '#9E9E9E'
        
        if pred_cdr['valid']:
            pred_class, pred_label, pred_color = classify_glaucoma_severity(pred_cdr['avgCDR'])
        else:
            pred_class, pred_label, pred_color = -1, 'Invalid', '#9E9E9E'
        
        # Calculate CDR error
        cdr_error = abs(gt_cdr['avgCDR'] - pred_cdr['avgCDR']) if gt_cdr['valid'] and pred_cdr['valid'] else np.nan
        
        # Check if classification matches
        severity_match = (gt_label == pred_label)
        
        # Manual review needed: Critical cases or mismatches
        manual_review = (gt_label == 'Critical') or (not severity_match)
        
        results.append({
            'Sample': i + 1,
            'GT_vCDR': gt_cdr['vCDR'],
            'GT_hCDR': gt_cdr['hCDR'],
            'GT_avgCDR': gt_cdr['avgCDR'],
            'GT_area_CDR': gt_cdr['area_CDR'],
            'GT_Severity': gt_label,
            'Pred_vCDR': pred_cdr['vCDR'],
            'Pred_hCDR': pred_cdr['hCDR'],
            'Pred_avgCDR': pred_cdr['avgCDR'],
            'Pred_area_CDR': pred_cdr['area_CDR'],
            'Pred_Severity': pred_label,
            'CDR_Error': cdr_error,
            'Severity_Match': severity_match,
            'Manual_Review_Needed': manual_review
        })
    
    return pd.DataFrame(results)

# ============================================================================
# VISUALIZATION FUNCTIONS
# ============================================================================

def plot_sample_predictions_with_cdr(model, X_test, y_test, model_name, num_samples=6, save_dir='results'):
    """Visualize predictions with CDR and glaucoma severity"""
    os.makedirs(save_dir, exist_ok=True)
    
    y_pred = model.predict(X_test[:num_samples], verbose=0, batch_size=4)
    y_pred_labels = np.argmax(y_pred, axis=-1)
    
    colors = {0: [0, 0, 0], 1: [0, 255, 0], 2: [255, 0, 0]}
    
    fig, axes = plt.subplots(num_samples, 4, figsize=(18, 4*num_samples))
    
    for i in range(num_samples):
        # Original image
        axes[i, 0].imshow(X_test[i])
        axes[i, 0].set_title('Original Image', fontsize=12, fontweight='bold')
        axes[i, 0].axis('off')
        
        # Ground truth
        gt_colored = np.zeros((256, 256, 3), dtype=np.uint8)
        for class_id, color in colors.items():
            gt_colored[y_test[i] == class_id] = color
        axes[i, 1].imshow(gt_colored)
        
        # Calculate GT CDR
        gt_cdr = calculate_cdr(y_test[i])
        gt_class, gt_label, gt_color = classify_glaucoma_severity(gt_cdr['avgCDR']) if gt_cdr['valid'] else (-1, 'Invalid', '#9E9E9E')
        
        axes[i, 1].set_title(f'Ground Truth\nCDR: {gt_cdr["avgCDR"]:.3f} | {gt_label}', 
                            fontsize=12, fontweight='bold', color=gt_color)
        axes[i, 1].axis('off')
        
        # Prediction
        pred_colored = np.zeros((256, 256, 3), dtype=np.uint8)
        for class_id, color in colors.items():
            pred_colored[y_pred_labels[i] == class_id] = color
        axes[i, 2].imshow(pred_colored)
        
        # Calculate Pred CDR
        pred_cdr = calculate_cdr(y_pred_labels[i])
        pred_class, pred_label, pred_color = classify_glaucoma_severity(pred_cdr['avgCDR']) if pred_cdr['valid'] else (-1, 'Invalid', '#9E9E9E')
        
        axes[i, 2].set_title(f'Prediction\nCDR: {pred_cdr["avgCDR"]:.3f} | {pred_label}', 
                            fontsize=12, fontweight='bold', color=pred_color)
        axes[i, 2].axis('off')
        
        # Overlay
        overlay = X_test[i].copy()
        for class_id, color in colors.items():
            if class_id > 0:
                mask = (y_pred_labels[i] == class_id).astype(np.float32)
                mask_rgb = np.stack([mask * color[0]/255, mask * color[1]/255, mask * color[2]/255], axis=-1)
                overlay = overlay * 0.6 + mask_rgb * 0.4
        axes[i, 3].imshow(overlay)
        axes[i, 3].set_title('Overlay', fontsize=12, fontweight='bold')
        axes[i, 3].axis('off')
        
        # Calculate dice
        y_test_cat = to_categorical(y_test[i], num_classes=3)
        y_pred_cat = to_categorical(y_pred_labels[i], num_classes=3)
        
        disc_dice = 2 * np.sum(y_test_cat[:,:,1] * y_pred_cat[:,:,1]) / (np.sum(y_test_cat[:,:,1]) + np.sum(y_pred_cat[:,:,1]) + 1e-7)
        cup_dice = 2 * np.sum(y_test_cat[:,:,2] * y_pred_cat[:,:,2]) / (np.sum(y_test_cat[:,:,2]) + np.sum(y_pred_cat[:,:,2]) + 1e-7)
        
        cdr_error = abs(gt_cdr['avgCDR'] - pred_cdr['avgCDR']) if gt_cdr['valid'] and pred_cdr['valid'] else np.nan
        
        info_text = f'Sample {i+1}\n'
        info_text += f'Disc Dice: {disc_dice:.3f} | Cup Dice: {cup_dice:.3f}\n'
        info_text += f'CDR Error: {cdr_error:.3f}' if not np.isnan(cdr_error) else 'CDR Error: N/A'
        
        axes[i, 0].text(0.5, -0.15, info_text, transform=axes[i, 0].transAxes, 
                       ha='center', fontsize=10, bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
    
    plt.suptitle(f'{model_name} - Predictions with Glaucoma Severity Assessment', 
                 fontsize=16, fontweight='bold', y=0.995)
    plt.tight_layout()
    plt.savefig(f'{save_dir}/{model_name}_predictions_cdr.png', dpi=150, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_predictions_cdr.png")
    plt.show()
    plt.close()

def plot_cdr_distribution(df_progression, save_dir='results'):
    """Plot CDR distribution and severity classification"""
    os.makedirs(save_dir, exist_ok=True)
    
    fig, axes = plt.subplots(2, 2, figsize=(16, 12))
    
    # CDR scatter plot (GT vs Pred)
    axes[0, 0].scatter(df_progression['GT_avgCDR'], df_progression['Pred_avgCDR'], 
                      alpha=0.6, s=100, c='blue', edgecolors='black')
    axes[0, 0].plot([0, 1], [0, 1], 'r--', linewidth=2, label='Perfect Prediction')
    axes[0, 0].set_xlabel('Ground Truth CDR', fontsize=12, fontweight='bold')
    axes[0, 0].set_ylabel('Predicted CDR', fontsize=12, fontweight='bold')
    axes[0, 0].set_title('CDR: Ground Truth vs Prediction', fontsize=14, fontweight='bold')
    axes[0, 0].legend(fontsize=10)
    axes[0, 0].grid(True, alpha=0.3)
    
    # Add severity zones
    axes[0, 0].axhspan(0, 0.3, alpha=0.1, color='green', label='Normal')
    axes[0, 0].axhspan(0.3, 0.6, alpha=0.1, color='yellow', label='Suspect')
    axes[0, 0].axhspan(0.6, 0.8, alpha=0.1, color='orange', label='Moderate')
    axes[0, 0].axhspan(0.8, 1.0, alpha=0.1, color='red', label='Critical')
    
    # CDR error histogram
    valid_errors = df_progression['CDR_Error'].dropna()
    axes[0, 1].hist(valid_errors, bins=30, color='steelblue', edgecolor='black', alpha=0.7)
    axes[0, 1].axvline(valid_errors.mean(), color='red', linestyle='--', linewidth=2, 
                      label=f'Mean Error: {valid_errors.mean():.4f}')
    axes[0, 1].set_xlabel('CDR Error (|GT - Pred|)', fontsize=12, fontweight='bold')
    axes[0, 1].set_ylabel('Frequency', fontsize=12, fontweight='bold')
    axes[0, 1].set_title('CDR Error Distribution', fontsize=14, fontweight='bold')
    axes[0, 1].legend(fontsize=10)
    axes[0, 1].grid(True, alpha=0.3)
    
    # Severity classification confusion matrix
    severity_order = ['Normal', 'Suspect', 'Moderate', 'Critical']
    gt_severity = pd.Categorical(df_progression['GT_Severity'], categories=severity_order, ordered=True)
    pred_severity = pd.Categorical(df_progression['Pred_Severity'], categories=severity_order, ordered=True)
    
    cm = confusion_matrix(gt_severity, pred_severity, labels=severity_order)
    
    sns.heatmap(cm, annot=True, fmt='d', cmap='YlOrRd', 
                xticklabels=severity_order, yticklabels=severity_order,
                ax=axes[1, 0], cbar_kws={'label': 'Count'})
    axes[1, 0].set_title('Glaucoma Severity Classification', fontsize=14, fontweight='bold')
    axes[1, 0].set_ylabel('Ground Truth', fontsize=12, fontweight='bold')
    axes[1, 0].set_xlabel('Predicted', fontsize=12, fontweight='bold')
    
    # Severity distribution
    severity_counts_gt = df_progression['GT_Severity'].value_counts()
    severity_counts_pred = df_progression['Pred_Severity'].value_counts()
    
    x = np.arange(len(severity_order))
    width = 0.35
    
    counts_gt = [severity_counts_gt.get(s, 0) for s in severity_order]
    counts_pred = [severity_counts_pred.get(s, 0) for s in severity_order]
    
    bars1 = axes[1, 1].bar(x - width/2, counts_gt, width, label='Ground Truth', 
                          color=['#4CAF50', '#FFC107', '#FF9800', '#F44336'], alpha=0.7)
    bars2 = axes[1, 1].bar(x + width/2, counts_pred, width, label='Predicted', 
                          color=['#4CAF50', '#FFC107', '#FF9800', '#F44336'], alpha=0.4)
    
    axes[1, 1].set_xlabel('Severity Level', fontsize=12, fontweight='bold')
    axes[1, 1].set_ylabel('Count', fontsize=12, fontweight='bold')
    axes[1, 1].set_title('Severity Distribution', fontsize=14, fontweight='bold')
    axes[1, 1].set_xticks(x)
    axes[1, 1].set_xticklabels(severity_order, rotation=15)
    axes[1, 1].legend(fontsize=10)
    axes[1, 1].grid(True, alpha=0.3, axis='y')
    
    plt.tight_layout()
    plt.savefig(f'{save_dir}/cdr_analysis.png', dpi=150, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/cdr_analysis.png")
    plt.show()
    plt.close()

def calculate_progression_accuracy(df_progression):
    """
    Calculate simple accuracy metrics: GT progression vs Predicted progression
    
    Returns accuracy % like: "GT says Normal for 250 images, model says 230 are Normal"
    """
    results = {}
    
    # Overall accuracy
    total = len(df_progression)
    correct = df_progression['Severity_Match'].sum()
    overall_accuracy = (correct / total) * 100
    
    results['overall'] = {
        'total': total,
        'correct': correct,
        'accuracy': overall_accuracy
    }
    
    # Per-class accuracy
    severity_classes = ['Normal', 'Suspect', 'Moderate', 'Critical']
    results['per_class'] = {}
    
    for severity in severity_classes:
        gt_count = len(df_progression[df_progression['GT_Severity'] == severity])
        pred_count = len(df_progression[df_progression['Pred_Severity'] == severity])
        
        # Correctly predicted: GT is this class AND model predicted it as this class
        correct_count = len(df_progression[
            (df_progression['GT_Severity'] == severity) & 
            (df_progression['Pred_Severity'] == severity)
        ])
        
        class_accuracy = (correct_count / gt_count * 100) if gt_count > 0 else 0.0
        
        results['per_class'][severity] = {
            'gt_count': gt_count,
            'pred_count': pred_count,
            'correct': correct_count,
            'accuracy': class_accuracy
        }
    
    # Manual review statistics
    manual_review_needed = df_progression['Manual_Review_Needed'].sum()
    manual_review_pct = (manual_review_needed / total) * 100
    
    results['manual_review'] = {
        'count': manual_review_needed,
        'percentage': manual_review_pct
    }
    
    return results

def plot_training_history(history, model_name, save_dir='results'):
    """Plot training history - Loss and Accuracy only"""
    os.makedirs(save_dir, exist_ok=True)
    
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    
    # Loss curves
    axes[0].plot(history.history['loss'], label='Training Loss', linewidth=2)
    axes[0].plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
    axes[0].set_title(f'{model_name} - Loss Over Epochs', fontsize=14, fontweight='bold')
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('Loss', fontsize=12)
    axes[0].legend(fontsize=10)
    axes[0].grid(True, alpha=0.3)
    
    # Accuracy curves
    axes[1].plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
    axes[1].plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
    axes[1].set_title(f'{model_name} - Accuracy Over Epochs', fontsize=14, fontweight='bold')
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('Accuracy', fontsize=12)
    axes[1].legend(fontsize=10)
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(f'{save_dir}/{model_name}_history.png', dpi=150, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_history.png")
    plt.show()
    plt.close()

def plot_confusion_matrices(y_true, y_pred, model_name, save_dir='results'):
    """Plot confusion matrices"""
    os.makedirs(save_dir, exist_ok=True)
    
    y_true_labels = np.argmax(y_true, axis=-1).flatten()
    y_pred_labels = np.argmax(y_pred, axis=-1).flatten()
    
    cm = confusion_matrix(y_true_labels, y_pred_labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    class_names = ['Background', 'Disc', 'Cup']
    
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[0], cbar_kws={'label': 'Count'})
    axes[0].set_title(f'{model_name}\nConfusion Matrix', fontsize=14, fontweight='bold')
    axes[0].set_ylabel('True Label', fontsize=12)
    axes[0].set_xlabel('Predicted Label', fontsize=12)
    
    sns.heatmap(cm_normalized, annot=True, fmt='.3f', cmap='Greens',
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[1], cbar_kws={'label': 'Proportion'})
    axes[1].set_title(f'{model_name}\nNormalized Confusion Matrix', fontsize=14, fontweight='bold')
    axes[1].set_ylabel('True Label', fontsize=12)
    axes[1].set_xlabel('Predicted Label', fontsize=12)
    
    plt.tight_layout()
    plt.savefig(f"{save_dir}/{model_name}_confusion_matrices.png", dpi=300, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_confusion_matrices.png")
    plt.show()
    plt.close()
    
    print(f"\nConfusion Matrix:\n{cm}")
    print(f"\nNormalized Confusion Matrix:\n{np.round(cm_normalized, 3)}")
    
    return cm, cm_normalized

# ============================================================================
# TRAINING AND EVALUATION
# ============================================================================

def train_model(X_train, y_train, X_val, y_val, X_test, y_test, model_name, 
               augment=None, save_dir='results'):
    """Train model"""
    print(f"\n{'='*80}")
    print(f"TRAINING: {model_name}")
    print(f"{'='*80}")
    print(f"  Architecture: Deeper Decoder + Focal-EIoU + MC Dropout")
    print(f"  Loss: Focal + Enhanced IoU (Combined)")
    
    K.clear_session()
    
    # Build model
    model = build_deeper_focal_mc_unet(dropout_rate=0.3)
    param_count = model.count_params()
    
    # Compile
    model.compile(
        optimizer=optimizers.Adam(learning_rate=5e-4),
        loss=focal_eiou_combined_loss,
        metrics=[dice_coef_multiclass, dice_class_0, dice_class_1, dice_class_2,
                "accuracy", iou_coef_multiclass, iou_class_0, iou_class_1, iou_class_2]
    )
    
    # Callbacks
    checkpoint = ModelCheckpoint(f"{save_dir}/{model_name}.keras", save_best_only=True, 
                                verbose=1, monitor='val_loss', mode='min')
    reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=3, 
                                  verbose=1, mode='min', min_lr=1e-7)
    early_stop = EarlyStopping(monitor="val_loss", patience=10, verbose=1, 
                              restore_best_weights=True, mode='min')
    
    # Training
    batch_size = 4
    steps_train = X_train.shape[0] // batch_size
    steps_val = X_val.shape[0] // batch_size
    
    history = model.fit(
        data_generator(X_train, y_train, batch_size, augment),
        validation_data=data_generator(X_val, y_val, batch_size, None),
        steps_per_epoch=steps_train,
        validation_steps=steps_val,
        epochs=50,
        callbacks=[checkpoint, reduce_lr, early_stop],
        verbose=1
    )
    
    print(f"✓ Training completed")
    
    # Visualizations
    print("\nGenerating visualizations...")
    plot_training_history(history, model_name, save_dir)
    plot_sample_predictions_with_cdr(model, X_test, y_test, model_name, num_samples=8, save_dir=save_dir)
    
    return model, history, param_count

def evaluate_model(model, X_test, y_test, model_name, run_mc_dropout=True):
    """Evaluate model with glaucoma progression analysis"""
    print(f"\n{'='*80}")
    print(f"EVALUATION: {model_name}")
    print(f"{'='*80}")
    
    y_test_cat = np.array([to_categorical(mask, num_classes=3) for mask in y_test])
    
    # Predict
    y_pred = model.predict(X_test, verbose=0, batch_size=8)
    y_pred_labels = np.argmax(y_pred, axis=-1)
    
    # Confusion matrices
    plot_confusion_matrices(y_test_cat, y_pred, model_name, save_dir='results')
    
    # Classification metrics
    y_true_labels = np.argmax(y_test_cat, axis=-1).flatten()
    y_pred_labels_flat = y_pred_labels.flatten()
    
    precision = precision_score(y_true_labels, y_pred_labels_flat, average=None, zero_division=0)
    recall = recall_score(y_true_labels, y_pred_labels_flat, average=None, zero_division=0)
    f1 = f1_score(y_true_labels, y_pred_labels_flat, average=None, zero_division=0)
    
    print(f"\nPrecision, Recall, F1 Score per class:")
    class_names = ["Background", "Disc", "Cup"]
    for idx, cname in enumerate(class_names):
        print(f"  {cname}: Precision={precision[idx]:.4f}, Recall={recall[idx]:.4f}, F1={f1[idx]:.4f}")
    
    print(f"\nMacro-averaged metrics:")
    print(f"  Precision: {np.mean(precision):.4f}")
    print(f"  Recall: {np.mean(recall):.4f}")
    print(f"  F1 Score: {np.mean(f1):.4f}")
    
    # Per-class Dice and IoU
    results = {'standard': {}}
    for cidx, cname in enumerate(class_names):
        y_true_c = (np.argmax(y_test_cat, axis=-1) == cidx).astype(np.float32)
        y_pred_c = (y_pred_labels == cidx).astype(np.float32)
        
        intersection = np.sum(y_true_c * y_pred_c)
        dice = (2. * intersection + 1e-7) / (np.sum(y_true_c) + np.sum(y_pred_c) + 1e-7)
        union = np.sum(y_true_c) + np.sum(y_pred_c) - intersection
        iou = (intersection + 1e-7) / (union + 1e-7)
        
        results['standard'][cname] = {'dice': dice, 'iou': iou}
        print(f"  {cname}: Dice={dice:.4f}, IoU={iou:.4f}")
    
    # Glaucoma Progression Analysis
    print(f"\n{'='*80}")
    print(f"GLAUCOMA PROGRESSION ANALYSIS (Using Area-based CDR)")
    print(f"{'='*80}")
    
    df_progression = analyze_glaucoma_progression(y_test, y_pred_labels, cdr_method='area_sqrt')
    
    # CDR Statistics
    print(f"\n{'-'*80}")
    print(f"CDR Statistics:")
    print(f"{'-'*80}")
    print(f"  Mean GT CDR:   {df_progression['GT_avgCDR'].mean():.4f} ± {df_progression['GT_avgCDR'].std():.4f}")
    print(f"  Mean Pred CDR: {df_progression['Pred_avgCDR'].mean():.4f} ± {df_progression['Pred_avgCDR'].std():.4f}")
    print(f"  Mean CDR Error: {df_progression['CDR_Error'].mean():.4f} ± {df_progression['CDR_Error'].std():.4f}")
    
    # Calculate progression accuracy
    accuracy_results = calculate_progression_accuracy(df_progression)
    
    # Overall Accuracy
    print(f"\n{'='*80}")
    print(f"PROGRESSION CLASSIFICATION ACCURACY")
    print(f"{'='*80}")
    print(f"\nOverall Accuracy: {accuracy_results['overall']['accuracy']:.2f}%")
    print(f"  - Correctly Classified: {accuracy_results['overall']['correct']}/{accuracy_results['overall']['total']} samples")
    print(f"  - Incorrectly Classified: {accuracy_results['overall']['total'] - accuracy_results['overall']['correct']}/{accuracy_results['overall']['total']} samples")
    
    # Per-Class Results
    print(f"\n{'-'*80}")
    print(f"Per-Class Results:")
    print(f"{'-'*80}")
    print(f"{'Severity':<12} {'GT Count':<12} {'Pred Count':<12} {'Correct':<12} {'Accuracy':<12}")
    print(f"{'-'*80}")
    
    for severity in ['Normal', 'Suspect', 'Moderate', 'Critical']:
        stats = accuracy_results['per_class'][severity]
        print(f"{severity:<12} {stats['gt_count']:<12} {stats['pred_count']:<12} "
              f"{stats['correct']:<12} {stats['accuracy']:<12.2f}%")
    
    print(f"\n{'='*80}")
    print(f"INTERPRETATION EXAMPLE:")
    print(f"{'='*80}")
    normal_stats = accuracy_results['per_class']['Normal']
    print(f"  - GT says 'Normal' for {normal_stats['gt_count']} images")
    print(f"  - MobileNet model says 'Normal' for {normal_stats['pred_count']} images")
    print(f"  - MobileNet correctly predicts {normal_stats['correct']} as 'Normal'")
    print(f"  - Accuracy for Normal class: {normal_stats['correct']}/{normal_stats['gt_count']} = {normal_stats['accuracy']:.1f}%")
    
    # Manual Review Recommendations
    print(f"\n{'='*80}")
    print(f"MANUAL REVIEW RECOMMENDATIONS")
    print(f"{'='*80}")
    print(f"\nSamples Requiring Manual Review: {accuracy_results['manual_review']['count']}/{accuracy_results['overall']['total']} "
          f"({accuracy_results['manual_review']['percentage']:.1f}%)")
    print(f"\nCriteria for Manual Review:")
    print(f"  1. All Critical cases (high-risk, requires expert verification)")
    print(f"  2. Classification mismatches (GT ≠ Predicted severity)")
    print(f"\nReason: Critical cases need expert confirmation, and mismatches may")
    print(f"indicate borderline cases or segmentation issues requiring review.")
    
    # Breakdown of manual review cases
    review_df = df_progression[df_progression['Manual_Review_Needed'] == True]
    critical_cases = len(review_df[review_df['GT_Severity'] == 'Critical'])
    mismatch_cases = len(review_df[review_df['Severity_Match'] == False])
    overlap = len(review_df[(review_df['GT_Severity'] == 'Critical') & (review_df['Severity_Match'] == False)])
    
    print(f"\nBreakdown:")
    print(f"  - Critical cases: {critical_cases} samples")
    print(f"  - Classification mismatches: {mismatch_cases} samples")
    print(f"  - Overlap (Critical + Mismatch): {overlap} samples")
    
    # Save progression data
    df_progression.to_csv('results/glaucoma_progression_analysis.csv', index=False)
    print(f"\n✓ Saved: results/glaucoma_progression_analysis.csv")
    
    # Plot CDR analysis
    plot_cdr_distribution(df_progression, save_dir='results')
    
    results['glaucoma'] = {
        'mean_cdr_error': df_progression['CDR_Error'].mean(),
        'median_cdr_error': df_progression['CDR_Error'].median(),
        'classification_accuracy': accuracy_results['overall']['accuracy'] / 100,
        'df_progression': df_progression,
        'accuracy_breakdown': accuracy_results
    }
    
    # MC Dropout
    if run_mc_dropout:
        print(f"\n{'='*80}")
        print(f"MC DROPOUT UNCERTAINTY ESTIMATION")
        print(f"{'='*80}")
        mean_pred, std_pred = mc_dropout_predict(model, X_test[:100], num_samples=15, verbose=True)
        results['mc_dropout'] = {}
        for cidx, cname in enumerate(class_names):
            mean_std = np.mean(std_pred[:, :, :, cidx])
            results['mc_dropout'][cname] = {'mean_uncertainty': mean_std}
            print(f"  {cname} uncertainty: {mean_std:.4f}")
    
    return results

# ============================================================================
# MAIN EXECUTION
# ============================================================================

if __name__ == "__main__":
    # Setup
    gpu_available = configure_gpu()
    root_dir = "/kaggle/input/refuge/REFUGE/"
    train_aug = setup_augmentations()
    save_dir = "results"
    os.makedirs(save_dir, exist_ok=True)
    
    print(f"\n{'='*100}")
    print(f"{'MOBILENET-UNET WITH GLAUCOMA PROGRESSION SCORING':^100s}")
    print(f"{'='*100}")
    print(f"\nGlaucoma Severity Classification:")
    print(f"  - Normal:   CDR < 0.3  (Green)")
    print(f"  - Suspect:  0.3 ≤ CDR < 0.6  (Amber)")
    print(f"  - Moderate: 0.6 ≤ CDR < 0.8  (Orange)")
    print(f"  - Critical: CDR ≥ 0.8  (Red)")
    print(f"  CDR Method: Area-based (sqrt of area ratio) - Robust & Clinically Relevant")
    print(f"\nManual Review: Recommended for Critical cases and classification mismatches")
    
    # Load data
    all_images, all_masks = load_all_data(root_dir)
    (X_train, y_train), (X_val, y_val), (X_test, y_test) = create_new_split(all_images, all_masks)
    
    # Train model
    model, history, params = train_model(
        X_train, y_train, X_val, y_val, X_test, y_test,
        "Deeper_Focal_MC_GlaucomaScoring",
        augment=train_aug, save_dir=save_dir
    )
    
    # Evaluate with glaucoma analysis
    results = evaluate_model(model, X_test, y_test, "Deeper+Focal+MC+GlaucomaScoring", run_mc_dropout=True)
    
    print(f"\n{'='*100}")
    print(f"{'✓ TRAINING AND EVALUATION COMPLETED!':^100s}")
    print(f"{'='*100}")
    print(f"\nModel: Deeper + Focal + EIoU + MC Dropout + Glaucoma Scoring")
    print(f"Parameters: {params:,}")
    print(f"Results saved in: {save_dir}/")
    print(f"\nGenerated Files:")
    print(f"  - Training history: {save_dir}/Deeper_Focal_MC_GlaucomaScoring_history.png")
    print(f"  - Predictions with CDR: {save_dir}/Deeper_Focal_MC_GlaucomaScoring_predictions_cdr.png")
    print(f"  - CDR Analysis: {save_dir}/cdr_analysis.png")
    print(f"  - Progression CSV: {save_dir}/glaucoma_progression_analysis.csv")
    print(f"  - Confusion Matrices: {save_dir}/Deeper+Focal+MC+GlaucomaScoring_confusion_matrices.png")
    print(f"\n{'='*100}\n")
# Out:
# Configuring GPU settings...
# ✓ GPU found: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
#
# ====================================================================================================
#                           MOBILENET-UNET WITH GLAUCOMA PROGRESSION SCORING
# ====================================================================================================
#
# Glaucoma Severity Classification:
#   - Normal:   CDR < 0.3  (Green)
#   - Suspect:  0.3 ≤ CDR < 0.6  (Amber)
#   - Moderate: 0.6 ≤ CDR < 0.8  (Orange)
#   - Critical: CDR ≥ 0.8  (Red)
#   CDR Method: Area-based (sqrt of area ratio) - Robust & Clinically Relevant
#
# Manual Review: Recommended for Critical cases and classification mismatches
# Loading train data...
#   train: 400 samples
# Loading val data...
#   val: 400 samples
# Loading test data...
#   test: 400 samples
# Split - Train: 600, Val: 200, Test: 400
#
# ================================================================================
# TRAINING: Deeper_Focal_MC_GlaucomaScoring
# ================================================================================
#   Architecture: Deeper Decoder + Focal-EIoU + MC Dropout
#   Loss: Focal + Enhanced IoU (Combined)
#
# Model Configuration:
#   Total Parameters: 37,129,475
#   Dropout Layers: 5
#   Architecture: Deeper Decoder + Focal-EIoU + MC Dropout
# Epoch 1/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8596 - dice_class_0: 0.9103 - dice_class_1: 0.3914 - dice_class_2: 0.2267 - dice_coef_multiclass: 0.5944 - iou_class_0: 0.8601 - iou_class_1: 0.2568 - iou_class_2: 0.1364 - iou_coef_multiclass: 0.4333 - loss: 1.1661
# Epoch 1: val_loss improved from inf to 0.93045, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 105s 193ms/step - accuracy: 0.8602 - dice_class_0: 0.9107 - dice_class_1: 0.3921 - dice_class_2: 0.2274 - dice_coef_multiclass: 0.5952 - iou_class_0: 0.8606 - iou_class_1: 0.2574 - iou_class_2: 0.1368 - iou_coef_multiclass: 0.4341 - loss: 1.1650 - val_accuracy: 0.9606 - val_dice_class_0: 0.9818 - val_dice_class_1: 0.4218 - val_dice_class_2: 3.8442e-11 - val_dice_coef_multiclass: 0.8687 - val_iou_class_0: 0.9644 - val_iou_class_1: 0.2690 - val_iou_class_2: 3.8442e-11 - val_iou_coef_multiclass: 0.7681 - val_loss: 0.9304 - learning_rate: 5.0000e-04
# Epoch 2/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9833 - dice_class_0: 0.9923 - dice_class_1: 0.7257 - dice_class_2: 0.4237 - dice_coef_multiclass: 0.9069 - iou_class_0: 0.9847 - iou_class_1: 0.5729 - iou_class_2: 0.2704 - iou_coef_multiclass: 0.8306 - loss: 0.7020
# Epoch 2: val_loss improved from 0.93045 to 0.83615, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 147ms/step - accuracy: 0.9833 - dice_class_0: 0.9923 - dice_class_1: 0.7260 - dice_class_2: 0.4240 - dice_coef_multiclass: 0.9071 - iou_class_0: 0.9847 - iou_class_1: 0.5732 - iou_class_2: 0.2707 - iou_coef_multiclass: 0.8309 - loss: 0.7016 - val_accuracy: 0.9400 - val_dice_class_0: 0.9719 - val_dice_class_1: 0.3035 - val_dice_class_2: 0.1746 - val_dice_coef_multiclass: 0.9394 - val_iou_class_0: 0.9454 - val_iou_class_1: 0.1794 - val_iou_class_2: 0.0960 - val_iou_coef_multiclass: 0.8858 - val_loss: 0.8361 - learning_rate: 5.0000e-04
# Epoch 3/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9923 - dice_class_0: 0.9969 - dice_class_1: 0.8129 - dice_class_2: 0.6521 - dice_coef_multiclass: 0.9778 - iou_class_0: 0.9939 - iou_class_1: 0.6874 - iou_class_2: 0.5008 - iou_coef_multiclass: 0.9567 - loss: 0.4622
# Epoch 3: val_loss improved from 0.83615 to 0.37428, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 146ms/step - accuracy: 0.9923 - dice_class_0: 0.9969 - dice_class_1: 0.8130 - dice_class_2: 0.6528 - dice_coef_multiclass: 0.9778 - iou_class_0: 0.9939 - iou_class_1: 0.6875 - iou_class_2: 0.5016 - iou_coef_multiclass: 0.9567 - loss: 0.4617 - val_accuracy: 0.9866 - val_dice_class_0: 0.9940 - val_dice_class_1: 0.6117 - val_dice_class_2: 0.7775 - val_dice_coef_multiclass: 0.9865 - val_iou_class_0: 0.9881 - val_iou_class_1: 0.4484 - val_iou_class_2: 0.6384 - val_iou_coef_multiclass: 0.9734 - val_loss: 0.3743 - learning_rate: 5.0000e-04
# Epoch 4/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9966 - dice_class_0: 0.9989 - dice_class_1: 0.8708 - dice_class_2: 0.8509 - dice_coef_multiclass: 0.9948 - iou_class_0: 0.9977 - iou_class_1: 0.7725 - iou_class_2: 0.7428 - iou_coef_multiclass: 0.9897 - loss: 0.2404
# Epoch 4: val_loss improved from 0.37428 to 0.25748, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 147ms/step - accuracy: 0.9966 - dice_class_0: 0.9989 - dice_class_1: 0.8708 - dice_class_2: 0.8510 - dice_coef_multiclass: 0.9948 - iou_class_0: 0.9977 - iou_class_1: 0.7725 - iou_class_2: 0.7428 - iou_coef_multiclass: 0.9897 - loss: 0.2402 - val_accuracy: 0.9951 - val_dice_class_0: 0.9983 - val_dice_class_1: 0.8050 - val_dice_class_2: 0.8061 - val_dice_coef_multiclass: 0.9951 - val_iou_class_0: 0.9966 - val_iou_class_1: 0.6766 - val_iou_class_2: 0.6785 - val_iou_coef_multiclass: 0.9903 - val_loss: 0.2575 - learning_rate: 5.0000e-04
# Epoch 5/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9970 - dice_class_0: 0.9990 - dice_class_1: 0.8818 - dice_class_2: 0.8679 - dice_coef_multiclass: 0.9964 - iou_class_0: 0.9981 - iou_class_1: 0.7897 - iou_class_2: 0.7683 - iou_coef_multiclass: 0.9928 - loss: 0.1851
# Epoch 5: val_loss did not improve from 0.25748
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9970 - dice_class_0: 0.9990 - dice_class_1: 0.8818 - dice_class_2: 0.8679 - dice_coef_multiclass: 0.9964 - iou_class_0: 0.9981 - iou_class_1: 0.7898 - iou_class_2: 0.7683 - iou_coef_multiclass: 0.9928 - loss: 0.1850 - val_accuracy: 0.9956 - val_dice_class_0: 0.9988 - val_dice_class_1: 0.8187 - val_dice_class_2: 0.7088 - val_dice_coef_multiclass: 0.9956 - val_iou_class_0: 0.9976 - val_iou_class_1: 0.6967 - val_iou_class_2: 0.5545 - val_iou_coef_multiclass: 0.9913 - val_loss: 0.2855 - learning_rate: 5.0000e-04
# Epoch 6/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9974 - dice_class_0: 0.9992 - dice_class_1: 0.8990 - dice_class_2: 0.8868 - dice_coef_multiclass: 0.9971 - iou_class_0: 0.9984 - iou_class_1: 0.8173 - iou_class_2: 0.7978 - iou_coef_multiclass: 0.9943 - loss: 0.1536
# Epoch 6: val_loss did not improve from 0.25748
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9974 - dice_class_0: 0.9992 - dice_class_1: 0.8989 - dice_class_2: 0.8868 - dice_coef_multiclass: 0.9971 - iou_class_0: 0.9984 - iou_class_1: 0.8172 - iou_class_2: 0.7977 - iou_coef_multiclass: 0.9943 - loss: 0.1537 - val_accuracy: 0.9943 - val_dice_class_0: 0.9980 - val_dice_class_1: 0.7412 - val_dice_class_2: 0.7239 - val_dice_coef_multiclass: 0.9943 - val_iou_class_0: 0.9960 - val_iou_class_1: 0.5935 - val_iou_class_2: 0.5755 - val_iou_coef_multiclass: 0.9886 - val_loss: 0.3300 - learning_rate: 5.0000e-04
# Epoch 7/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9973 - dice_class_0: 0.9991 - dice_class_1: 0.8950 - dice_class_2: 0.8798 - dice_coef_multiclass: 0.9971 - iou_class_0: 0.9982 - iou_class_1: 0.8113 - iou_class_2: 0.7887 - iou_coef_multiclass: 0.9942 - loss: 0.1548
# Epoch 7: val_loss improved from 0.25748 to 0.17822, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 147ms/step - accuracy: 0.9973 - dice_class_0: 0.9991 - dice_class_1: 0.8950 - dice_class_2: 0.8798 - dice_coef_multiclass: 0.9971 - iou_class_0: 0.9982 - iou_class_1: 0.8113 - iou_class_2: 0.7887 - iou_coef_multiclass: 0.9942 - loss: 0.1548 - val_accuracy: 0.9970 - val_dice_class_0: 0.9991 - val_dice_class_1: 0.8785 - val_dice_class_2: 0.8416 - val_dice_coef_multiclass: 0.9970 - val_iou_class_0: 0.9982 - val_iou_class_1: 0.7856 - val_iou_class_2: 0.7292 - val_iou_coef_multiclass: 0.9939 - val_loss: 0.1782 - learning_rate: 5.0000e-04
# Epoch 8/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9975 - dice_class_0: 0.9992 - dice_class_1: 0.9015 - dice_class_2: 0.8849 - dice_coef_multiclass: 0.9974 - iou_class_0: 0.9984 - iou_class_1: 0.8214 - iou_class_2: 0.7955 - iou_coef_multiclass: 0.9947 - loss: 0.1464
# Epoch 8: val_loss did not improve from 0.17822
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9975 - dice_class_0: 0.9992 - dice_class_1: 0.9015 - dice_class_2: 0.8850 - dice_coef_multiclass: 0.9974 - iou_class_0: 0.9984 - iou_class_1: 0.8214 - iou_class_2: 0.7955 - iou_coef_multiclass: 0.9947 - loss: 0.1464 - val_accuracy: 0.9968 - val_dice_class_0: 0.9991 - val_dice_class_1: 0.8673 - val_dice_class_2: 0.8125 - val_dice_coef_multiclass: 0.9968 - val_iou_class_0: 0.9982 - val_iou_class_1: 0.7672 - val_iou_class_2: 0.6887 - val_iou_coef_multiclass: 0.9936 - val_loss: 0.2058 - learning_rate: 5.0000e-04
# Epoch 9/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9098 - dice_class_2: 0.9053 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9986 - iou_class_1: 0.8351 - iou_class_2: 0.8280 - iou_coef_multiclass: 0.9953 - loss: 0.1294
# Epoch 9: val_loss did not improve from 0.17822
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9098 - dice_class_2: 0.9053 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9986 - iou_class_1: 0.8351 - iou_class_2: 0.8279 - iou_coef_multiclass: 0.9953 - loss: 0.1294 - val_accuracy: 0.9971 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8844 - val_dice_class_2: 0.8274 - val_dice_coef_multiclass: 0.9971 - val_iou_class_0: 0.9984 - val_iou_class_1: 0.7940 - val_iou_class_2: 0.7096 - val_iou_coef_multiclass: 0.9943 - val_loss: 0.1822 - learning_rate: 5.0000e-04
# Epoch 10/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9093 - dice_class_2: 0.9025 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9986 - iou_class_1: 0.8344 - iou_class_2: 0.8230 - iou_coef_multiclass: 0.9953 - loss: 0.1292
# Epoch 10: val_loss improved from 0.17822 to 0.16891, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 147ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9093 - dice_class_2: 0.9025 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9986 - iou_class_1: 0.8344 - iou_class_2: 0.8230 - iou_coef_multiclass: 0.9953 - loss: 0.1292 - val_accuracy: 0.9971 - val_dice_class_0: 0.9991 - val_dice_class_1: 0.8763 - val_dice_class_2: 0.8698 - val_dice_coef_multiclass: 0.9971 - val_iou_class_0: 0.9981 - val_iou_class_1: 0.7815 - val_iou_class_2: 0.7709 - val_iou_coef_multiclass: 0.9942 - val_loss: 0.1689 - learning_rate: 5.0000e-04
# Epoch 11/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9977 - dice_class_0: 0.9992 - dice_class_1: 0.9060 - dice_class_2: 0.9021 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9985 - iou_class_1: 0.8287 - iou_class_2: 0.8227 - iou_coef_multiclass: 0.9952 - loss: 0.1315
# Epoch 11: val_loss did not improve from 0.16891
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9977 - dice_class_0: 0.9992 - dice_class_1: 0.9060 - dice_class_2: 0.9021 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9985 - iou_class_1: 0.8287 - iou_class_2: 0.8227 - iou_coef_multiclass: 0.9952 - loss: 0.1315 - val_accuracy: 0.9972 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8841 - val_dice_class_2: 0.8221 - val_dice_coef_multiclass: 0.9972 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.7932 - val_iou_class_2: 0.6996 - val_iou_coef_multiclass: 0.9943 - val_loss: 0.1857 - learning_rate: 5.0000e-04
# Epoch 12/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9130 - dice_class_2: 0.9078 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9986 - iou_class_1: 0.8405 - iou_class_2: 0.8322 - iou_coef_multiclass: 0.9956 - loss: 0.1230
# Epoch 12: val_loss improved from 0.16891 to 0.16416, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 147ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9129 - dice_class_2: 0.9078 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9986 - iou_class_1: 0.8405 - iou_class_2: 0.8322 - iou_coef_multiclass: 0.9956 - loss: 0.1230 - val_accuracy: 0.9972 - val_dice_class_0: 0.9991 - val_dice_class_1: 0.8842 - val_dice_class_2: 0.8704 - val_dice_coef_multiclass: 0.9971 - val_iou_class_0: 0.9982 - val_iou_class_1: 0.7940 - val_iou_class_2: 0.7740 - val_iou_coef_multiclass: 0.9942 - val_loss: 0.1642 - learning_rate: 5.0000e-04
# Epoch 13/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9097 - dice_class_2: 0.9017 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9986 - iou_class_1: 0.8349 - iou_class_2: 0.8218 - iou_coef_multiclass: 0.9954 - loss: 0.1300
# Epoch 13: val_loss did not improve from 0.16416
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9097 - dice_class_2: 0.9017 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9986 - iou_class_1: 0.8349 - iou_class_2: 0.8219 - iou_coef_multiclass: 0.9954 - loss: 0.1299 - val_accuracy: 0.9970 - val_dice_class_0: 0.9989 - val_dice_class_1: 0.8661 - val_dice_class_2: 0.8766 - val_dice_coef_multiclass: 0.9970 - val_iou_class_0: 0.9979 - val_iou_class_1: 0.7659 - val_iou_class_2: 0.7815 - val_iou_coef_multiclass: 0.9939 - val_loss: 0.1754 - learning_rate: 5.0000e-04
# Epoch 14/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9980 - dice_class_0: 0.9993 - dice_class_1: 0.9161 - dice_class_2: 0.9119 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8458 - iou_class_2: 0.8390 - iou_coef_multiclass: 0.9958 - loss: 0.1184
# Epoch 14: val_loss did not improve from 0.16416
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9980 - dice_class_0: 0.9993 - dice_class_1: 0.9161 - dice_class_2: 0.9119 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8458 - iou_class_2: 0.8390 - iou_coef_multiclass: 0.9958 - loss: 0.1184 - val_accuracy: 0.9972 - val_dice_class_0: 0.9991 - val_dice_class_1: 0.8874 - val_dice_class_2: 0.8561 - val_dice_coef_multiclass: 0.9972 - val_iou_class_0: 0.9983 - val_iou_class_1: 0.7992 - val_iou_class_2: 0.7510 - val_iou_coef_multiclass: 0.9944 - val_loss: 0.1698 - learning_rate: 5.0000e-04
# Epoch 15/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9207 - dice_class_2: 0.9128 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9987 - iou_class_1: 0.8534 - iou_class_2: 0.8402 - iou_coef_multiclass: 0.9959 - loss: 0.1147
# Epoch 15: val_loss improved from 0.16416 to 0.16092, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 146ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9207 - dice_class_2: 0.9128 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9987 - iou_class_1: 0.8534 - iou_class_2: 0.8402 - iou_coef_multiclass: 0.9959 - loss: 0.1147 - val_accuracy: 0.9974 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8894 - val_dice_class_2: 0.8672 - val_dice_coef_multiclass: 0.9973 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.8021 - val_iou_class_2: 0.7684 - val_iou_coef_multiclass: 0.9947 - val_loss: 0.1609 - learning_rate: 5.0000e-04
# Epoch 16/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9980 - dice_class_0: 0.9993 - dice_class_1: 0.9179 - dice_class_2: 0.9170 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8487 - iou_class_2: 0.8475 - iou_coef_multiclass: 0.9959 - loss: 0.1145
# Epoch 16: val_loss improved from 0.16092 to 0.15597, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9980 - dice_class_0: 0.9993 - dice_class_1: 0.9179 - dice_class_2: 0.9170 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8487 - iou_class_2: 0.8475 - iou_coef_multiclass: 0.9959 - loss: 0.1145 - val_accuracy: 0.9974 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8977 - val_dice_class_2: 0.8674 - val_dice_coef_multiclass: 0.9974 - val_iou_class_0: 0.9984 - val_iou_class_1: 0.8157 - val_iou_class_2: 0.7718 - val_iou_coef_multiclass: 0.9948 - val_loss: 0.1560 - learning_rate: 5.0000e-04
# Epoch 17/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9155 - dice_class_2: 0.9166 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9986 - iou_class_1: 0.8450 - iou_class_2: 0.8469 - iou_coef_multiclass: 0.9957 - loss: 0.1152
# Epoch 17: val_loss did not improve from 0.15597
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9155 - dice_class_2: 0.9166 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9986 - iou_class_1: 0.8450 - iou_class_2: 0.8469 - iou_coef_multiclass: 0.9957 - loss: 0.1152 - val_accuracy: 0.9973 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8812 - val_dice_class_2: 0.8725 - val_dice_coef_multiclass: 0.9973 - val_iou_class_0: 0.9983 - val_iou_class_1: 0.7887 - val_iou_class_2: 0.7754 - val_iou_coef_multiclass: 0.9947 - val_loss: 0.1683 - learning_rate: 5.0000e-04
# Epoch 18/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9981 - dice_class_0: 0.9993 - dice_class_1: 0.9219 - dice_class_2: 0.9223 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9987 - iou_class_1: 0.8555 - iou_class_2: 0.8565 - iou_coef_multiclass: 0.9960 - loss: 0.1078
# Epoch 18: val_loss improved from 0.15597 to 0.14963, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.9981 - dice_class_0: 0.9993 - dice_class_1: 0.9219 - dice_class_2: 0.9223 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9987 - iou_class_1: 0.8555 - iou_class_2: 0.8565 - iou_coef_multiclass: 0.9960 - loss: 0.1078 - val_accuracy: 0.9975 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8979 - val_dice_class_2: 0.8775 - val_dice_coef_multiclass: 0.9974 - val_iou_class_0: 0.9984 - val_iou_class_1: 0.8155 - val_iou_class_2: 0.7836 - val_iou_coef_multiclass: 0.9949 - val_loss: 0.1496 - learning_rate: 5.0000e-04
# Epoch 19/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9981 - dice_class_0: 0.9993 - dice_class_1: 0.9225 - dice_class_2: 0.9282 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9987 - iou_class_1: 0.8567 - iou_class_2: 0.8666 - iou_coef_multiclass: 0.9961 - loss: 0.1038
# Epoch 19: val_loss did not improve from 0.14963
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9981 - dice_class_0: 0.9993 - dice_class_1: 0.9225 - dice_class_2: 0.9281 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9987 - iou_class_1: 0.8567 - iou_class_2: 0.8665 - iou_coef_multiclass: 0.9961 - loss: 0.1038 - val_accuracy: 0.9975 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9013 - val_dice_class_2: 0.8639 - val_dice_coef_multiclass: 0.9975 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.8212 - val_iou_class_2: 0.7625 - val_iou_coef_multiclass: 0.9950 - val_loss: 0.1550 - learning_rate: 5.0000e-04
# Epoch 20/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9190 - dice_class_2: 0.9072 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9985 - iou_class_1: 0.8507 - iou_class_2: 0.8354 - iou_coef_multiclass: 0.9956 - loss: 0.1153
# Epoch 20: val_loss did not improve from 0.14963
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9190 - dice_class_2: 0.9072 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9985 - iou_class_1: 0.8507 - iou_class_2: 0.8355 - iou_coef_multiclass: 0.9956 - loss: 0.1153 - val_accuracy: 0.9974 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8922 - val_dice_class_2: 0.8614 - val_dice_coef_multiclass: 0.9974 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.8069 - val_iou_class_2: 0.7592 - val_iou_coef_multiclass: 0.9948 - val_loss: 0.1620 - learning_rate: 5.0000e-04
# Epoch 21/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9980 - dice_class_0: 0.9993 - dice_class_1: 0.9212 - dice_class_2: 0.9208 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9987 - iou_class_1: 0.8546 - iou_class_2: 0.8547 - iou_coef_multiclass: 0.9959 - loss: 0.1084
# Epoch 21: val_loss improved from 0.14963 to 0.14745, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 146ms/step - accuracy: 0.9980 - dice_class_0: 0.9993 - dice_class_1: 0.9212 - dice_class_2: 0.9209 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9987 - iou_class_1: 0.8546 - iou_class_2: 0.8548 - iou_coef_multiclass: 0.9959 - loss: 0.1084 - val_accuracy: 0.9975 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8994 - val_dice_class_2: 0.8774 - val_dice_coef_multiclass: 0.9974 - val_iou_class_0: 0.9984 - val_iou_class_1: 0.8183 - val_iou_class_2: 0.7835 - val_iou_coef_multiclass: 0.9949 - val_loss: 0.1474 - learning_rate: 5.0000e-04
# Epoch 22/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9274 - dice_class_2: 0.9295 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8649 - iou_class_2: 0.8689 - iou_coef_multiclass: 0.9963 - loss: 0.0998
# Epoch 22: val_loss improved from 0.14745 to 0.14629, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 147ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9274 - dice_class_2: 0.9295 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8649 - iou_class_2: 0.8689 - iou_coef_multiclass: 0.9963 - loss: 0.0998 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8993 - val_dice_class_2: 0.8832 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8176 - val_iou_class_2: 0.7919 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1463 - learning_rate: 5.0000e-04
# Epoch 23/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9253 - dice_class_2: 0.9310 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9987 - iou_class_1: 0.8615 - iou_class_2: 0.8714 - iou_coef_multiclass: 0.9962 - loss: 0.1015
# Epoch 23: val_loss improved from 0.14629 to 0.14532, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9253 - dice_class_2: 0.9310 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9987 - iou_class_1: 0.8615 - iou_class_2: 0.8714 - iou_coef_multiclass: 0.9962 - loss: 0.1014 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9011 - val_dice_class_2: 0.8825 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8208 - val_iou_class_2: 0.7915 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1453 - learning_rate: 5.0000e-04
# Epoch 24/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9288 - dice_class_2: 0.9349 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8674 - iou_class_2: 0.8782 - iou_coef_multiclass: 0.9964 - loss: 0.0954
# Epoch 24: val_loss did not improve from 0.14532
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9288 - dice_class_2: 0.9349 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8674 - iou_class_2: 0.8782 - iou_coef_multiclass: 0.9964 - loss: 0.0954 - val_accuracy: 0.9975 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8926 - val_dice_class_2: 0.8628 - val_dice_coef_multiclass: 0.9974 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8068 - val_iou_class_2: 0.7610 - val_iou_coef_multiclass: 0.9949 - val_loss: 0.1633 - learning_rate: 5.0000e-04
# Epoch 25/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9273 - dice_class_2: 0.9322 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8648 - iou_class_2: 0.8736 - iou_coef_multiclass: 0.9964 - loss: 0.0985
# Epoch 25: val_loss did not improve from 0.14532
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9273 - dice_class_2: 0.9322 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8648 - iou_class_2: 0.8736 - iou_coef_multiclass: 0.9964 - loss: 0.0985 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9011 - val_dice_class_2: 0.8786 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8210 - val_iou_class_2: 0.7851 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1478 - learning_rate: 5.0000e-04
# Epoch 26/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9290 - dice_class_2: 0.9324 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8677 - iou_class_2: 0.8739 - iou_coef_multiclass: 0.9964 - loss: 0.0975
# Epoch 26: val_loss did not improve from 0.14532
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9289 - dice_class_2: 0.9324 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8677 - iou_class_2: 0.8739 - iou_coef_multiclass: 0.9964 - loss: 0.0975 - val_accuracy: 0.9975 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8965 - val_dice_class_2: 0.8673 - val_dice_coef_multiclass: 0.9974 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.8133 - val_iou_class_2: 0.7679 - val_iou_coef_multiclass: 0.9949 - val_loss: 0.1565 - learning_rate: 5.0000e-04
# Epoch 27/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9316 - dice_class_2: 0.9382 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8723 - iou_class_2: 0.8846 - iou_coef_multiclass: 0.9965 - loss: 0.0914
# Epoch 27: val_loss did not improve from 0.14532
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9316 - dice_class_2: 0.9382 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8723 - iou_class_2: 0.8846 - iou_coef_multiclass: 0.9965 - loss: 0.0914 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9021 - val_dice_class_2: 0.8726 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8230 - val_iou_class_2: 0.7759 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1508 - learning_rate: 1.5000e-04
# Epoch 28/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9378 - dice_class_2: 0.9466 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8831 - iou_class_2: 0.8990 - iou_coef_multiclass: 0.9969 - loss: 0.0825
# Epoch 28: val_loss improved from 0.14532 to 0.14514, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 146ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9378 - dice_class_2: 0.9466 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8830 - iou_class_2: 0.8990 - iou_coef_multiclass: 0.9969 - loss: 0.0825 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8978 - val_dice_class_2: 0.8868 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8157 - val_iou_class_2: 0.7983 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1451 - learning_rate: 1.5000e-04
# Epoch 29/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9376 - dice_class_2: 0.9455 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8827 - iou_class_2: 0.8970 - iou_coef_multiclass: 0.9968 - loss: 0.0831
# Epoch 29: val_loss improved from 0.14514 to 0.13740, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 147ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9376 - dice_class_2: 0.9455 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8827 - iou_class_2: 0.8970 - iou_coef_multiclass: 0.9968 - loss: 0.0830 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9080 - val_dice_class_2: 0.8891 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8320 - val_iou_class_2: 0.8018 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1374 - learning_rate: 1.5000e-04
# Epoch 30/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9985 - dice_class_0: 0.9994 - dice_class_1: 0.9370 - dice_class_2: 0.9457 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8817 - iou_class_2: 0.8974 - iou_coef_multiclass: 0.9968 - loss: 0.0829
# Epoch 30: val_loss did not improve from 0.13740
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9985 - dice_class_0: 0.9994 - dice_class_1: 0.9370 - dice_class_2: 0.9457 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8817 - iou_class_2: 0.8974 - iou_coef_multiclass: 0.9968 - loss: 0.0829 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9018 - val_dice_class_2: 0.8701 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8219 - val_iou_class_2: 0.7719 - val_iou_coef_multiclass: 0.9951 - val_loss: 0.1509 - learning_rate: 1.5000e-04
# Epoch 31/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9404 - dice_class_2: 0.9477 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8878 - iou_class_2: 0.9011 - iou_coef_multiclass: 0.9970 - loss: 0.0784
# Epoch 31: val_loss did not improve from 0.13740
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9404 - dice_class_2: 0.9477 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8877 - iou_class_2: 0.9011 - iou_coef_multiclass: 0.9970 - loss: 0.0784 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8995 - val_dice_class_2: 0.8821 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8182 - val_iou_class_2: 0.7906 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1457 - learning_rate: 1.5000e-04
# Epoch 32/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9985 - dice_class_0: 0.9994 - dice_class_1: 0.9371 - dice_class_2: 0.9503 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8822 - iou_class_2: 0.9056 - iou_coef_multiclass: 0.9969 - loss: 0.0803
# Epoch 32: val_loss did not improve from 0.13740
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 4.500000213738531e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9371 - dice_class_2: 0.9503 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8822 - iou_class_2: 0.9056 - iou_coef_multiclass: 0.9969 - loss: 0.0803 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9008 - val_dice_class_2: 0.8809 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8208 - val_iou_class_2: 0.7892 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1489 - learning_rate: 1.5000e-04
# Epoch 33/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9417 - dice_class_2: 0.9495 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8901 - iou_class_2: 0.9042 - iou_coef_multiclass: 0.9971 - loss: 0.0769
# Epoch 33: val_loss did not improve from 0.13740
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9418 - dice_class_2: 0.9495 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8902 - iou_class_2: 0.9042 - iou_coef_multiclass: 0.9971 - loss: 0.0769 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9060 - val_dice_class_2: 0.8864 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8286 - val_iou_class_2: 0.7975 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1396 - learning_rate: 4.5000e-05
# Epoch 34/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9436 - dice_class_2: 0.9542 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9990 - iou_class_1: 0.8934 - iou_class_2: 0.9125 - iou_coef_multiclass: 0.9971 - loss: 0.0732
# Epoch 34: val_loss did not improve from 0.13740
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9436 - dice_class_2: 0.9541 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9990 - iou_class_1: 0.8934 - iou_class_2: 0.9125 - iou_coef_multiclass: 0.9971 - loss: 0.0732 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9029 - val_dice_class_2: 0.8839 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8240 - val_iou_class_2: 0.7942 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1450 - learning_rate: 4.5000e-05
# Epoch 35/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9455 - dice_class_2: 0.9571 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9990 - iou_class_1: 0.8969 - iou_class_2: 0.9181 - iou_coef_multiclass: 0.9972 - loss: 0.0699
# Epoch 35: val_loss did not improve from 0.13740
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1.3500000204658135e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9455 - dice_class_2: 0.9571 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9990 - iou_class_1: 0.8969 - iou_class_2: 0.9180 - iou_coef_multiclass: 0.9972 - loss: 0.0699 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9018 - val_dice_class_2: 0.8856 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8219 - val_iou_class_2: 0.7969 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1431 - learning_rate: 4.5000e-05
# Epoch 36/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9453 - dice_class_2: 0.9552 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9990 - iou_class_1: 0.8965 - iou_class_2: 0.9145 - iou_coef_multiclass: 0.9972 - loss: 0.0711
# Epoch 36: val_loss did not improve from 0.13740
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 124ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9453 - dice_class_2: 0.9552 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9990 - iou_class_1: 0.8965 - iou_class_2: 0.9145 - iou_coef_multiclass: 0.9972 - loss: 0.0711 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9034 - val_dice_class_2: 0.8813 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8245 - val_iou_class_2: 0.7895 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1438 - learning_rate: 1.3500e-05
# Epoch 37/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9444 - dice_class_2: 0.9553 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9990 - iou_class_1: 0.8948 - iou_class_2: 0.9146 - iou_coef_multiclass: 0.9972 - loss: 0.0719
# Epoch 37: val_loss did not improve from 0.13740
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9444 - dice_class_2: 0.9553 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9990 - iou_class_1: 0.8948 - iou_class_2: 0.9146 - iou_coef_multiclass: 0.9972 - loss: 0.0719 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9015 - val_dice_class_2: 0.8849 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8214 - val_iou_class_2: 0.7952 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1452 - learning_rate: 1.3500e-05
# Epoch 38/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9448 - dice_class_2: 0.9523 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9990 - iou_class_1: 0.8956 - iou_class_2: 0.9094 - iou_coef_multiclass: 0.9972 - loss: 0.0730
# Epoch 38: val_loss did not improve from 0.13740
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 4.050000006827758e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9448 - dice_class_2: 0.9523 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9990 - iou_class_1: 0.8956 - iou_class_2: 0.9094 - iou_coef_multiclass: 0.9972 - loss: 0.0730 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9041 - val_dice_class_2: 0.8806 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8258 - val_iou_class_2: 0.7885 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1452 - learning_rate: 1.3500e-05
# Epoch 39/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9446 - dice_class_2: 0.9546 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9990 - iou_class_1: 0.8955 - iou_class_2: 0.9137 - iou_coef_multiclass: 0.9971 - loss: 0.0713
# Epoch 39: val_loss did not improve from 0.13740
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9446 - dice_class_2: 0.9546 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9990 - iou_class_1: 0.8955 - iou_class_2: 0.9137 - iou_coef_multiclass: 0.9971 - loss: 0.0713 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9041 - val_dice_class_2: 0.8837 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8256 - val_iou_class_2: 0.7930 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1432 - learning_rate: 4.0500e-06
# Epoch 39: early stopping
# Restoring model weights from the end of the best epoch: 29.
# ✓ Training completed
#
# Generating visualizations...
#   ✓ Saved: results/Deeper_Focal_MC_GlaucomaScoring_history.png
#   ✓ Saved: results/Deeper_Focal_MC_GlaucomaScoring_predictions_cdr.png
# ================================================================================
# EVALUATION: Deeper+Focal+MC+GlaucomaScoring
# ================================================================================
#   ✓ Saved: results/Deeper+Focal+MC+GlaucomaScoring_confusion_matrices.png
# Confusion Matrix:
# [[25766787    18203        0]
#  [   15226   289544    10301]
#  [      81    14132   100126]]
#
# Normalized Confusion Matrix:
# [[0.999 0.001 0.   ]
#  [0.048 0.919 0.033]
#  [0.001 0.124 0.876]]
#
# Precision, Recall, F1 Score per class:
#   Background: Precision=0.9994, Recall=0.9993, F1=0.9994
#   Disc: Precision=0.8995, Recall=0.9190, F1=0.9092
#   Cup: Precision=0.9067, Recall=0.8757, F1=0.8909
#
# Macro-averaged metrics:
#   Precision: 0.9352
#   Recall: 0.9313
#   F1 Score: 0.9331
#   Background: Dice=0.9994, IoU=0.9987
#   Disc: Dice=0.9092, IoU=0.8334
#   Cup: Dice=0.8909, IoU=0.8033
#
# ================================================================================
# GLAUCOMA PROGRESSION ANALYSIS (Using Area-based CDR)
# ================================================================================
#
# --------------------------------------------------------------------------------
# CDR Statistics:
# --------------------------------------------------------------------------------
#   Mean GT CDR:   0.5969 ± 0.1778
#   Mean Pred CDR: 0.5781 ± 0.1518
#   Mean CDR Error: 0.0648 ± 0.0689
#
# ================================================================================
# PROGRESSION CLASSIFICATION ACCURACY
# ================================================================================
#
# Overall Accuracy: 79.75%
#   - Correctly Classified: 319/400 samples
#   - Incorrectly Classified: 81/400 samples
#
# --------------------------------------------------------------------------------
# Per-Class Results:
# --------------------------------------------------------------------------------
# Severity     GT Count     Pred Count   Correct      Accuracy
# --------------------------------------------------------------------------------
# Normal       0            0            0            0.00        %
# Suspect      259          285          239          92.28       %
# Moderate     103          87           56           54.37       %
# Critical     38           28           24           63.16       %
#
# ================================================================================
# INTERPRETATION EXAMPLE:
# ================================================================================
#   - GT says 'Normal' for 0 images
#   - MobileNet model says 'Normal' for 0 images
#   - MobileNet correctly predicts 0 as 'Normal'
#   - Accuracy for Normal class: 0/0 = 0.0%
#
# ================================================================================
# MANUAL REVIEW RECOMMENDATIONS
# ================================================================================
#
# Samples Requiring Manual Review: 105/400 (26.2%)
#
# Criteria for Manual Review:
#   1. All Critical cases (high-risk, requires expert verification)
#   2. Classification mismatches (GT ≠ Predicted severity)
#
# Reason: Critical cases need expert confirmation, and mismatches may
# indicate borderline cases or segmentation issues requiring review.
#
# Breakdown:
#   - Critical cases: 38 samples
#   - Classification mismatches: 81 samples
#   - Overlap (Critical + Mismatch): 14 samples
#
# ✓ Saved: results/glaucoma_progression_analysis.csv
#   ✓ Saved: results/cdr_analysis.png
# ================================================================================
# MC DROPOUT UNCERTAINTY ESTIMATION
# ================================================================================
#
# Running MC Dropout with 15 stochastic forward passes...
#   Completed: 5/15 forward passes
#   Completed: 10/15 forward passes
#   Completed: 15/15 forward passes
# ✓ MC Dropout completed
#   Background uncertainty: 0.0002
#   Disc uncertainty: 0.0004
#   Cup uncertainty: 0.0001
#
# ====================================================================================================
#                                 ✓ TRAINING AND EVALUATION COMPLETED!
# ====================================================================================================
#
# Model: Deeper + Focal + EIoU + MC Dropout + Glaucoma Scoring
# Parameters: 37,129,475
# Results saved in: results/
#
# Generated Files:
#   - Training history: results/Deeper_Focal_MC_GlaucomaScoring_history.png
#   - Predictions with CDR: results/Deeper_Focal_MC_GlaucomaScoring_predictions_cdr.png
#   - CDR Analysis: results/cdr_analysis.png
#   - Progression CSV: results/glaucoma_progression_analysis.csv
#   - Confusion Matrices: results/Deeper+Focal+MC+GlaucomaScoring_confusion_matrices.png
#
# ====================================================================================================
