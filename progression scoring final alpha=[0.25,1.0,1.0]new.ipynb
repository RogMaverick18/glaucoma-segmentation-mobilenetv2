# %%
"""
MOBILENET-UNET WITH MSCA + LBFR + PPM + GLAUCOMA PROGRESSION SCORING
====================================================================
Enhanced with three complementary modules from ODFormer/PSPNet for comprehensive feature enhancement
Plus glaucoma progression analysis with CDR-based severity classification

Triple Enhancement Strategy:
- MSCA (Multi-scale Context Aggregator): Multi-scale dilated convolutions [1,2,3,5]
- LBFR (Lightweight Bidirectional Feature Recalibrator): Channel + Spatial attention
- PPM (Pyramid Pooling Module): Multi-scale global context aggregation [1×1, 2×2, 3×3, 6×6]
- Sequential application: MSCA → LBFR → PPM on each decoder block
- Combines local multi-scale context + attention + global context

ROI Extraction:
- Automatically crops around the optic disc region from ground truth masks
- Resizes the ROI to 512×512 so the model sees a zoomed-in view of the disc/cup
- Dramatically reduces irrelevant background, improving segmentation accuracy
- For evaluation, predictions are mapped back to full image coordinates for CDR analysis

Glaucoma Scoring:
- CDR-based severity classification: Normal, Suspect, Moderate, Critical
- Area-based CDR calculation (robust & clinically relevant)
- Progression analysis with accuracy metrics
- Manual review recommendations for high-risk cases

Configuration:
- Base: Deeper Decoder + Focal-EIoU + MC Dropout
- Enhancement: MSCA + LBFR + PPM on decoder outputs
- Placement: All three modules after each decoder block (4 total)
- Total Attention Blocks: 12 (4 MSCA + 4 LBFR + 4 PPM)
"""

import os
import gc
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import albumentations as A
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, backend as K
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
from PIL import Image

warnings.filterwarnings('ignore')

# Set plot style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# ============================================================================
# GPU CONFIGURATION
# ============================================================================

def configure_gpu():
    """Configure GPU settings for optimal performance"""
    print("Configuring GPU settings...")
    physical_devices = tf.config.list_physical_devices('GPU')
    if physical_devices:
        try:
            for device in physical_devices:
                tf.config.experimental.set_memory_growth(device, True)
            print(f"✓ GPU configured: {len(physical_devices)} device(s) available")
            return True
        except RuntimeError as e:
            print(f"GPU configuration error: {e}")
            return False
    else:
        print("⚠ No GPU detected, running on CPU")
        return False

# ============================================================================
# DATA LOADING
# ============================================================================

def load_images_masks(images_folder, masks_folder, img_size=(512,512)):
    """Load images and masks from folders"""
    images, masks = [], []
    image_files = sorted(os.listdir(images_folder))
    mask_files = sorted(os.listdir(masks_folder))
    mask_dict = {os.path.splitext(f)[0]: f for f in mask_files}
    
    for img_file in image_files:
        img_path = os.path.join(images_folder, img_file)
        img = np.array(Image.open(img_path).resize(img_size)) / 255.0
        images.append(img)
        
        img_name = os.path.splitext(img_file)[0]
        if img_name in mask_dict:
            mask_path = os.path.join(masks_folder, mask_dict[img_name])
            mask = np.array(Image.open(mask_path).resize(img_size, Image.NEAREST))
            masks.append(mask)
        else:
            print(f"Warning: No mask found for {img_file}")
    
    return np.array(images, dtype=np.float32), np.array(masks, dtype=np.uint8)

def load_all_data(root_dir):
    """Load all data from existing splits and merge"""
    all_images, all_masks = [], []
    for split in ["train", "val", "test"]:
        print(f"Loading {split} data...")
        imgs, msks = load_images_masks(
            os.path.join(root_dir, split, "Images"),
            os.path.join(root_dir, split, "Masks")
        )
        all_images.append(imgs)
        all_masks.append(msks)
        print(f"  {split}: {imgs.shape[0]} samples")
    
    all_images = np.concatenate(all_images, axis=0)
    all_masks = np.concatenate(all_masks, axis=0)
    return all_images, all_masks

def create_new_split(all_images, all_masks):
    """Create new split: 600 train, 200 val, 400 test"""
    X_temp, X_test, y_temp, y_test = train_test_split(
        all_images, all_masks, test_size=400, random_state=42
    )
    X_train, X_val, y_train, y_val = train_test_split(
        X_temp, y_temp, test_size=200, random_state=42
    )
    print(f"Split - Train: {X_train.shape[0]}, Val: {X_val.shape[0]}, Test: {X_test.shape[0]}")
    return (X_train, y_train), (X_val, y_val), (X_test, y_test)

# ============================================================================
# ROI EXTRACTION
# ============================================================================

def find_disc_region(mask, disc_class=1, cup_class=2):
    """
    Find the bounding box of the optic disc+cup region from a segmentation mask.
    
    Args:
        mask: Segmentation mask (H, W) with class labels
        disc_class: Class label for optic disc (default=1)
        cup_class: Class label for optic cup (default=2)
    
    Returns:
        (center_y, center_x, radius) or None if no disc found
    """
    # Use both disc and cup pixels to define the ROI region
    roi_mask = ((mask == disc_class) | (mask == cup_class)).astype(np.uint8)
    
    if roi_mask.sum() == 0:
        return None
    
    coords = np.where(roi_mask > 0)
    y_min, y_max = coords[0].min(), coords[0].max()
    x_min, x_max = coords[1].min(), coords[1].max()
    
    center_y = (y_min + y_max) // 2
    center_x = (x_min + x_max) // 2
    
    height = y_max - y_min
    width = x_max - x_min
    radius = max(height, width) // 2
    
    return center_y, center_x, radius


def extract_roi(image, mask, padding_factor=1.5, roi_size=(512, 512)):
    """
    Extract ROI around the optic disc from image and mask.
    
    Crops a square region centered on the disc with padding, then resizes to roi_size.
    This lets the model see a zoomed-in view of the disc/cup instead of the full fundus.
    
    Args:
        image: Input image (H, W, 3), float32 [0, 1]
        mask: Segmentation mask (H, W), uint8
        padding_factor: How much to expand the ROI beyond the disc boundary (1.5 = 50% extra)
        roi_size: Output size for the ROI crop (default 512×512)
    
    Returns:
        roi_image: Cropped and resized image (roi_size[0], roi_size[1], 3)
        roi_mask: Cropped and resized mask (roi_size[0], roi_size[1])
        roi_coords: (y1, x1, y2, x2) crop coordinates in original image space
    """
    result = find_disc_region(mask)
    
    if result is None:
        # No disc found — return the full image (fallback)
        h, w = image.shape[:2]
        return image.copy(), mask.copy(), (0, 0, h, w)
    
    center_y, center_x, radius = result
    h, w = image.shape[:2]
    
    # Expand ROI with padding factor; enforce a minimum size
    roi_half = int(radius * padding_factor)
    roi_half = max(roi_half, 60)  # minimum half-size to avoid too-small crops
    
    # Calculate crop bounds (keep square, clamp to image boundaries)
    y1 = max(0, center_y - roi_half)
    y2 = min(h, center_y + roi_half)
    x1 = max(0, center_x - roi_half)
    x2 = min(w, center_x + roi_half)
    
    # Make the crop square by expanding the shorter side if possible
    crop_h = y2 - y1
    crop_w = x2 - x1
    if crop_h > crop_w:
        diff = crop_h - crop_w
        x1 = max(0, x1 - diff // 2)
        x2 = min(w, x1 + crop_h)
        x1 = max(0, x2 - crop_h)  # re-adjust if x2 hit boundary
    elif crop_w > crop_h:
        diff = crop_w - crop_h
        y1 = max(0, y1 - diff // 2)
        y2 = min(h, y1 + crop_w)
        y1 = max(0, y2 - crop_w)  # re-adjust if y2 hit boundary
    
    # Crop
    roi_image = image[y1:y2, x1:x2]
    roi_mask = mask[y1:y2, x1:x2]
    
    # Resize to model input size
    roi_image_pil = Image.fromarray((roi_image * 255).astype(np.uint8))
    roi_image_resized = np.array(roi_image_pil.resize(roi_size, Image.BILINEAR)) / 255.0
    
    roi_mask_pil = Image.fromarray(roi_mask)
    roi_mask_resized = np.array(roi_mask_pil.resize(roi_size, Image.NEAREST))
    
    return roi_image_resized.astype(np.float32), roi_mask_resized.astype(np.uint8), (y1, x1, y2, x2)


def extract_roi_batch(images, masks, padding_factor=1.5, roi_size=(512, 512)):
    """
    Extract ROI for an entire batch of images and masks.
    
    Args:
        images: (N, H, W, 3) float32
        masks: (N, H, W) uint8
        padding_factor: ROI padding factor
        roi_size: Output ROI size
    
    Returns:
        roi_images: (N, roi_size[0], roi_size[1], 3) float32
        roi_masks: (N, roi_size[0], roi_size[1]) uint8
        roi_coords_list: List of (y1, x1, y2, x2) tuples
    """
    roi_images, roi_masks, roi_coords_list = [], [], []
    
    for i in range(len(images)):
        roi_img, roi_msk, coords = extract_roi(
            images[i], masks[i], padding_factor=padding_factor, roi_size=roi_size
        )
        roi_images.append(roi_img)
        roi_masks.append(roi_msk)
        roi_coords_list.append(coords)
    
    return (np.array(roi_images, dtype=np.float32),
            np.array(roi_masks, dtype=np.uint8),
            roi_coords_list)


def map_roi_prediction_to_full(pred_mask_roi, roi_coords, full_size=(512, 512)):
    """
    Map a prediction made on an ROI crop back to the full image coordinates.
    
    Args:
        pred_mask_roi: Predicted mask on the ROI (roi_H, roi_W) with class labels
        roi_coords: (y1, x1, y2, x2) crop coordinates from extract_roi
        full_size: Size of the original full image (H, W)
    
    Returns:
        full_mask: (full_H, full_W) prediction mapped to full image (background=0 outside ROI)
    """
    y1, x1, y2, x2 = roi_coords
    crop_h = y2 - y1
    crop_w = x2 - x1
    
    # Resize prediction back to the original crop dimensions
    pred_pil = Image.fromarray(pred_mask_roi.astype(np.uint8))
    pred_resized = np.array(pred_pil.resize((crop_w, crop_h), Image.NEAREST))
    
    # Place into full-size mask
    full_mask = np.zeros(full_size, dtype=np.uint8)
    full_mask[y1:y2, x1:x2] = pred_resized
    
    return full_mask


def visualize_roi_extraction(images, masks, num_samples=4):
    """Visualize ROI extraction to verify correctness"""
    fig, axes = plt.subplots(num_samples, 4, figsize=(16, 4 * num_samples))
    
    for i in range(min(num_samples, len(images))):
        roi_img, roi_msk, coords = extract_roi(images[i], masks[i])
        y1, x1, y2, x2 = coords
        
        # Original image
        axes[i, 0].imshow(images[i])
        axes[i, 0].set_title('Original Image', fontsize=11, fontweight='bold')
        # Draw ROI rectangle
        rect = plt.Rectangle((x1, y1), x2 - x1, y2 - y1,
                              linewidth=2, edgecolor='lime', facecolor='none')
        axes[i, 0].add_patch(rect)
        axes[i, 0].axis('off')
        
        # Original mask
        axes[i, 1].imshow(masks[i], cmap='jet', vmin=0, vmax=2)
        axes[i, 1].set_title('Original Mask', fontsize=11, fontweight='bold')
        rect2 = plt.Rectangle((x1, y1), x2 - x1, y2 - y1,
                               linewidth=2, edgecolor='lime', facecolor='none')
        axes[i, 1].add_patch(rect2)
        axes[i, 1].axis('off')
        
        # ROI image
        axes[i, 2].imshow(roi_img)
        axes[i, 2].set_title(f'ROI Image ({roi_img.shape[0]}×{roi_img.shape[1]})',
                             fontsize=11, fontweight='bold')
        axes[i, 2].axis('off')
        
        # ROI mask
        axes[i, 3].imshow(roi_msk, cmap='jet', vmin=0, vmax=2)
        axes[i, 3].set_title(f'ROI Mask ({roi_msk.shape[0]}×{roi_msk.shape[1]})',
                             fontsize=11, fontweight='bold')
        axes[i, 3].axis('off')
    
    plt.suptitle('ROI Extraction Verification — green box shows crop region',
                 fontsize=14, fontweight='bold', y=1.01)
    plt.tight_layout()
    plt.show()
    plt.close()

# ============================================================================
# DATA AUGMENTATION
# ============================================================================

def setup_augmentations():
    return A.Compose([
        # --- Geometric (most impactful for segmentation) ---
        A.HorizontalFlip(p=0.5),
        A.VerticalFlip(p=0.3),
        A.ShiftScaleRotate(shift_limit=0.05, scale_limit=0.10, rotate_limit=20,
                           border_mode=0, p=0.6),
        A.ElasticTransform(alpha=30, sigma=5, p=0.2),
        # --- Colour (keep existing, slightly widened) ---
        A.RandomBrightnessContrast(brightness_limit=0.20, contrast_limit=0.20, p=0.7),
        A.HueSaturationValue(hue_shift_limit=10, sat_shift_limit=20, val_shift_limit=10, p=0.5),
        A.GaussianBlur(blur_limit=3, p=0.3),
        A.RandomGamma(gamma_limit=(80, 120), p=0.3),
    ])

def data_generator(images, masks, batch_size, augment=None):
    idxs = np.arange(len(images))
    while True:
        np.random.shuffle(idxs)
        for i in range(0, len(images), batch_size):
            batch_idxs = idxs[i:i+batch_size]
            batch_x, batch_y = [], []
            
            for idx in batch_idxs:
                img, mask = images[idx], masks[idx]
                
                if augment:
                    aug = augment(image=img, mask=mask)
                    img_aug, mask_aug = aug['image'], aug['mask']
                else:
                    img_aug, mask_aug = img, mask
                
                mask_cat = to_categorical(mask_aug, num_classes=3)
                batch_x.append(img_aug)
                batch_y.append(mask_cat)
            
            yield np.stack(batch_x).astype(np.float32), np.stack(batch_y).astype(np.float32)

# ============================================================================
# MSCA MODULE (FROM ODFORMER)
# ============================================================================

def msca_block(x, channels, dilation_rates=[1, 2, 3, 5], block_name='msca'):
    """
    Multi-scale Context Aggregator (MSCA) from ODFormer
    
    Features:
    - Multi-scale feature extraction using dilated convolutions
    - Parallel branches with different dilation rates [1, 2, 3, 5]
    - Feature fusion through concatenation and 1×1 convolution
    - Residual connection for gradient flow
    
    Args:
        x: Input feature map
        channels: Number of output channels
        dilation_rates: List of dilation rates for multi-scale context
        block_name: Name prefix for layers
    """
    multi_scale_features = []
    filters_per_branch = channels // len(dilation_rates)
    
    # Multi-scale branches with different dilation rates
    for i, rate in enumerate(dilation_rates):
        branch = layers.Conv2D(
            filters_per_branch,
            (3, 3),
            padding='same',
            dilation_rate=rate,
            use_bias=False,
            name=f'{block_name}_dil{rate}_conv'
        )(x)
        branch = layers.BatchNormalization(name=f'{block_name}_dil{rate}_bn')(branch)
        branch = layers.Activation('relu', name=f'{block_name}_dil{rate}_relu')(branch)
        multi_scale_features.append(branch)
    
    # Concatenate all branches
    concat = layers.Concatenate(name=f'{block_name}_concat')(multi_scale_features)
    
    # Fusion layer to combine multi-scale features
    fused = layers.Conv2D(channels, (1, 1), use_bias=False, name=f'{block_name}_fusion')(concat)
    fused = layers.BatchNormalization(name=f'{block_name}_fusion_bn')(fused)
    fused = layers.Activation('relu', name=f'{block_name}_fusion_relu')(fused)
    
    # Residual connection
    output = layers.Add(name=f'{block_name}_residual')([x, fused])
    
    return output

# ============================================================================
# LBFR MODULE (FROM ODFORMER)
# ============================================================================

def lbfr_block(x, channels, reduction=16, block_name='lbfr'):
    """
    Lightweight Bidirectional Feature Recalibrator (LBFR) from ODFormer
    
    Features:
    - Channel attention using both avg and max pooling
    - Spatial attention using 2-channel feature concatenation
    - Recalibration layer with BatchNormalization
    - Residual connection for gradient flow
    
    Args:
        x: Input feature map
        channels: Number of channels
        reduction: Channel reduction ratio for attention bottleneck
        block_name: Name prefix for layers
    """
    # Channel Attention
    # Average pooling branch
    avg_pool = layers.GlobalAveragePooling2D(name=f'{block_name}_avg_pool')(x)
    avg_pool = layers.Reshape((1, 1, channels), name=f'{block_name}_avg_reshape')(avg_pool)
    
    # Max pooling branch
    max_pool = layers.GlobalMaxPooling2D(name=f'{block_name}_max_pool')(x)
    max_pool = layers.Reshape((1, 1, channels), name=f'{block_name}_max_reshape')(max_pool)
    
    # Shared MLP for channel attention
    fc1 = layers.Conv2D(channels // reduction, (1, 1), use_bias=False, name=f'{block_name}_fc1')
    fc2 = layers.Conv2D(channels, (1, 1), use_bias=False, name=f'{block_name}_fc2')
    
    avg_out = fc1(avg_pool)
    avg_out = layers.Activation('relu', name=f'{block_name}_fc1_relu_avg')(avg_out)
    avg_out = fc2(avg_out)
    
    max_out = fc1(max_pool)
    max_out = layers.Activation('relu', name=f'{block_name}_fc1_relu_max')(max_out)
    max_out = fc2(max_out)
    
    # Combine and apply channel attention
    channel_att = layers.Add(name=f'{block_name}_channel_add')([avg_out, max_out])
    channel_att = layers.Activation('sigmoid', name=f'{block_name}_channel_sigmoid')(channel_att)
    x_channel = layers.Multiply(name=f'{block_name}_channel_multiply')([x, channel_att])
    
    # Spatial Attention
    # Average and max across channels
    avg_spatial = layers.Lambda(lambda x: K.mean(x, axis=-1, keepdims=True), 
                                name=f'{block_name}_spatial_avg')(x_channel)
    max_spatial = layers.Lambda(lambda x: K.max(x, axis=-1, keepdims=True),
                                name=f'{block_name}_spatial_max')(x_channel)
    
    # Concatenate and apply spatial attention
    spatial_concat = layers.Concatenate(name=f'{block_name}_spatial_concat')([avg_spatial, max_spatial])
    spatial_att = layers.Conv2D(1, (7, 7), padding='same', use_bias=False,
                                name=f'{block_name}_spatial_conv')(spatial_concat)
    spatial_att = layers.Activation('sigmoid', name=f'{block_name}_spatial_sigmoid')(spatial_att)
    x_spatial = layers.Multiply(name=f'{block_name}_spatial_multiply')([x_channel, spatial_att])
    
    # Recalibration
    recalibrated = layers.Conv2D(channels, (1, 1), use_bias=False, 
                                 name=f'{block_name}_recalibrate')(x_spatial)
    recalibrated = layers.BatchNormalization(name=f'{block_name}_recalibrate_bn')(recalibrated)
    
    # Residual connection
    output = layers.Add(name=f'{block_name}_residual')([x, recalibrated])
    
    return output

# ============================================================================
# PPM MODULE (FROM PSPNET/ODFORMER)
# ============================================================================

def ppm_block(x, channels, pool_scales=[1, 2, 3, 6], block_name='ppm'):
    """
    Pyramid Pooling Module (PPM) from PSPNet
    
    Features:
    - Multi-scale adaptive pooling at different pyramid levels
    - Captures global context at scales: 1×1, 2×2, 3×3, 6×6
    - Lightweight 1×1 convolutions for each scale
    - Feature fusion through concatenation
    
    Args:
        x: Input feature map
        channels: Number of output channels
        pool_scales: List of pooling scales for pyramid levels
        block_name: Name prefix for layers
    """
    h, w = x.shape[1], x.shape[2]
    
    # Store original features
    ppm_features = [x]
    
    # Multi-scale pooling branches
    filters_per_scale = channels // len(pool_scales)
    
    for i, scale in enumerate(pool_scales):
        # Global average pooling to fixed scale size
        pool_h = max(h // scale, 1)
        pool_w = max(w // scale, 1)
        
        pooled = layers.AveragePooling2D(
            pool_size=(h // pool_h, w // pool_w),
            strides=(h // pool_h, w // pool_w),
            name=f'{block_name}pool{scale}x{scale}'
        )(x)
        
        # 1×1 convolution to reduce channels
        conv = layers.Conv2D(
            filters_per_scale,
            (1, 1),
            use_bias=False,
            name=f'{block_name}conv{scale}x{scale}'
        )(pooled)
        conv = layers.BatchNormalization(name=f'{block_name}bn{scale}x{scale}')(conv)
        conv = layers.Activation('relu', name=f'{block_name}relu{scale}x{scale}')(conv)
        
        # Upsample back to original size using exact target dimensions
        upsampled = layers.Resizing(
            h, w,
            interpolation='bilinear',
            name=f'{block_name}upsample{scale}x{scale}'
        )(conv)
        
        ppm_features.append(upsampled)
    
    # Concatenate all pyramid features
    concat = layers.Concatenate(name=f'{block_name}_concat')(ppm_features)
    
    # Fusion convolution
    fused = layers.Conv2D(
        channels,
        (3, 3),
        padding='same',
        use_bias=False,
        name=f'{block_name}_fusion'
    )(concat)
    fused = layers.BatchNormalization(name=f'{block_name}_fusion_bn')(fused)
    fused = layers.Activation('relu', name=f'{block_name}_fusion_relu')(fused)
    
    return fused

# ============================================================================
# LOSS FUNCTIONS
# ============================================================================

def focal_loss(y_true, y_pred, gamma=2.0, alpha=None, epsilon=1e-7):
    if alpha is None:
        alpha = [0.25, 1.0, 1.0]
    
    y_pred = K.clip(y_pred, epsilon, 1.0 - epsilon)
    focal_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        
        bce = -(y_true_c * K.log(y_pred_c) + (1 - y_true_c) * K.log(1 - y_pred_c))
        pt = y_true_c * y_pred_c + (1 - y_true_c) * (1 - y_pred_c)
        focal_weight = K.pow(1 - pt, gamma)
        
        focal_loss_value += alpha[c] * K.mean(focal_weight * bce)
    
    return focal_loss_value

def enhanced_iou_loss(y_true, y_pred, smooth=1e-7):
    eiou_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        
        intersection = K.sum(y_true_c * y_pred_c, axis=[1, 2])
        union = K.sum(y_true_c, axis=[1, 2]) + K.sum(y_pred_c, axis=[1, 2]) - intersection
        iou = (intersection + smooth) / (union + smooth)
        
        # Fix: K.min/max on the binary mask values gives the min/max VALUE (always
        # 0 or 1), not the spatial INDEX of the mask boundary.  Use coordinate
        # grids so that the reduction over the spatial axis returns the actual
        # normalised row/col position of the bounding-box edges.
        binary_true = K.cast(y_true_c > 0.5, 'float32')   # [batch, H, W]
        binary_pred = K.cast(y_pred_c > 0.5, 'float32')

        _h = tf.cast(tf.shape(y_true_c)[1], 'float32')
        _w = tf.cast(tf.shape(y_true_c)[2], 'float32')
        row_coords = tf.reshape(tf.range(tf.shape(y_true_c)[1], dtype=tf.float32) / _h, [1, -1, 1])  # [1,H,1]
        col_coords = tf.reshape(tf.range(tf.shape(y_true_c)[2], dtype=tf.float32) / _w, [1, 1, -1])  # [1,1,W]

        # Presence along each axis (1 if that row/col contains any mask pixel)
        rp_t = K.max(binary_true, axis=2, keepdims=True)   # [batch, H, 1]
        rp_p = K.max(binary_pred, axis=2, keepdims=True)
        cp_t = K.max(binary_true, axis=1, keepdims=True)   # [batch, 1, W]
        cp_p = K.max(binary_pred, axis=1, keepdims=True)

        # y_min: smallest row index with mask present; add 1 where absent so min ignores them
        y_min_t = K.min(row_coords + (1.0 - rp_t), axis=[1, 2])   # [batch]
        y_max_t = K.max(row_coords * rp_t,          axis=[1, 2])
        x_min_t = K.min(col_coords + (1.0 - cp_t), axis=[1, 2])
        x_max_t = K.max(col_coords * cp_t,          axis=[1, 2])

        y_min_p = K.min(row_coords + (1.0 - rp_p), axis=[1, 2])
        y_max_p = K.max(row_coords * rp_p,          axis=[1, 2])
        x_min_p = K.min(col_coords + (1.0 - cp_p), axis=[1, 2])
        x_max_p = K.max(col_coords * cp_p,          axis=[1, 2])

        # Bboxes now have correct shape [batch, 4] where indices are [y_min, x_min, y_max, x_max]
        y_true_bbox = K.stack([y_min_t, x_min_t, y_max_t, x_max_t], axis=-1)
        y_pred_bbox = K.stack([y_min_p, x_min_p, y_max_p, x_max_p], axis=-1)
        
        center_true = K.stack([
            (y_true_bbox[:, 0] + y_true_bbox[:, 2]) / 2.0,
            (y_true_bbox[:, 1] + y_true_bbox[:, 3]) / 2.0
        ], axis=-1)
        
        center_pred = K.stack([
            (y_pred_bbox[:, 0] + y_pred_bbox[:, 2]) / 2.0,
            (y_pred_bbox[:, 1] + y_pred_bbox[:, 3]) / 2.0
        ], axis=-1)
        
        center_distance = K.sum(K.square(center_true - center_pred), axis=-1)
        
        diag_length = K.square(y_true_bbox[:, 2] - y_true_bbox[:, 0]) + \
                     K.square(y_true_bbox[:, 3] - y_true_bbox[:, 1])
        
        diag_length = K.maximum(diag_length, 1e-7)
        
        eiou = iou - (center_distance / diag_length)
        eiou_loss_value += K.mean(1.0 - eiou)
    
    return eiou_loss_value / 3.0

def focal_eiou_combined_loss(y_true, y_pred, focal_weight=1.0, eiou_weight=1.0, gamma=2.0, alpha=None):
    fl = focal_loss(y_true, y_pred, gamma=gamma, alpha=alpha)
    eiou = enhanced_iou_loss(y_true, y_pred)
    return focal_weight * fl + eiou_weight * eiou

# ============================================================================
# MODEL ARCHITECTURE WITH MSCA + LBFR + PPM
# ============================================================================

def enhanced_decoder_block_with_triple_attention(x, skip_connection, filters, block_name, dropout_rate=0.3):
    """
    Enhanced decoder block with MSCA + LBFR + PPM triple attention
    
    Sequential enhancement strategy:
    1. Standard decoder convolutions with residual connection
    2. MSCA for multi-scale local context aggregation (dilated convs)
    3. LBFR for bidirectional feature recalibration (channel + spatial attention)
    4. PPM for multi-scale global context aggregation (pyramid pooling)
    
    This combines three complementary attention mechanisms:
    - MSCA: Local multi-scale receptive fields
    - LBFR: Channel and spatial recalibration
    - PPM: Global multi-scale context
    """
    x = layers.UpSampling2D((2, 2), name=f'{block_name}_upsample')(x)
    
    if skip_connection.shape[-1] != x.shape[-1]:
        skip_connection = layers.Conv2D(x.shape[-1], (1, 1), padding='same', 
                                       name=f'{block_name}_skip_adjust')(skip_connection)
    
    x = layers.Concatenate(name=f'{block_name}_concat')([x, skip_connection])
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv1')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn1')(x)
    x = layers.Dropout(dropout_rate, name=f'{block_name}_dropout')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv2')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn2')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv3')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn3')(x)
    
    residual = x
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv4')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn4')(x)
    
    x = layers.Add(name=f'{block_name}_residual')([x, residual])
    x = layers.Conv2D(filters, (1, 1), activation='relu', padding='same', name=f'{block_name}_conv_final')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn_final')(x)
    
    # Apply MSCA for local multi-scale context aggregation
    x = msca_block(x, filters, dilation_rates=[1, 2, 3, 5], block_name=f'{block_name}_msca')
    
    # Apply LBFR for bidirectional feature recalibration
    x = lbfr_block(x, filters, reduction=16, block_name=f'{block_name}_lbfr')
    
    # Apply PPM for global multi-scale context aggregation
    x = ppm_block(x, filters, pool_scales=[1, 2, 3, 6], block_name=f'{block_name}_ppm')
    
    return x

def build_unet_with_triple_attention(input_shape=(512, 512, 3), num_classes=3, dropout_rate=0.3):
    """Build MobileNetV2-UNet with MSCA + LBFR + PPM triple attention"""
    inputs = layers.Input(input_shape, dtype='float32')
    backbone = MobileNetV2(input_tensor=inputs, weights='imagenet', include_top=False)
    
    skip_1 = backbone.get_layer('block_1_expand_relu').output  # 128×128
    skip_2 = backbone.get_layer('block_3_expand_relu').output  # 64×64
    skip_3 = backbone.get_layer('block_6_expand_relu').output  # 32×32
    skip_4 = backbone.get_layer('block_13_expand_relu').output # 16×16
    bridge = backbone.output  # 8×8
    
    # Deeper bridge
    bridge = layers.Conv2D(1024, (3, 3), activation='relu', padding='same')(bridge)
    bridge = layers.BatchNormalization()(bridge)
    bridge = layers.Dropout(dropout_rate, name='bridge_dropout')(bridge)
    
    # Decoder with triple attention (MSCA + LBFR + PPM)
    x = enhanced_decoder_block_with_triple_attention(bridge, skip_4, 512, 'decoder_1', dropout_rate)
    x = enhanced_decoder_block_with_triple_attention(x, skip_3, 256, 'decoder_2', dropout_rate)
    x = enhanced_decoder_block_with_triple_attention(x, skip_2, 128, 'decoder_3', dropout_rate * 0.7)
    x = enhanced_decoder_block_with_triple_attention(x, skip_1, 64, 'decoder_4', dropout_rate * 0.5)
    
    # Final upsampling
    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    
    outputs = layers.Conv2D(num_classes, (1, 1), activation='softmax', dtype='float32')(x)
    
    model = models.Model(inputs, outputs)
    
    # Print configuration
    dropout_layers = [layer for layer in model.layers if isinstance(layer, layers.Dropout)]
    print(f"\nModel Configuration:")
    print(f"  Total Parameters: {model.count_params():,}")
    print(f"  Dropout Layers: {len(dropout_layers)}")
    print(f"  Triple Attention Modules: MSCA + LBFR + PPM per decoder block")
    print(f"  MSCA Modules: 4 (local multi-scale with dilation rates [1,2,3,5])")
    print(f"  LBFR Modules: 4 (channel + spatial attention + recalibration)")
    print(f"  PPM Modules: 4 (global pyramid pooling [1×1, 2×2, 3×3, 6×6])")
    print(f"  Enhancement Strategy: Sequential MSCA → LBFR → PPM per block")
    print(f"  Total Attention Blocks: 12 (4 MSCA + 4 LBFR + 4 PPM)")
    print(f"  Context Coverage: Local Multi-scale + Attention + Global Multi-scale")
    
    return model

# ============================================================================
# METRICS
# ============================================================================

def dice_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    return (2. * intersection + smooth) / (K.sum(y_true_class) + K.sum(y_pred_class) + smooth)

def dice_class_0(y_true, y_pred): return dice_coef_class(y_true, y_pred, 0)
def dice_class_1(y_true, y_pred): return dice_coef_class(y_true, y_pred, 1)
def dice_class_2(y_true, y_pred): return dice_coef_class(y_true, y_pred, 2)

def iou_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    union = K.sum(y_true_class) + K.sum(y_pred_class) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_class_0(y_true, y_pred): return iou_coef_class(y_true, y_pred, 0)
def iou_class_1(y_true, y_pred): return iou_coef_class(y_true, y_pred, 1)
def iou_class_2(y_true, y_pred): return iou_coef_class(y_true, y_pred, 2)

def mc_dropout_predict(model, X, num_samples=15, batch_size=4, verbose=True):
    """MC Dropout prediction for uncertainty estimation - Memory Optimized"""
    if verbose:
        print(f"\nRunning MC Dropout with {num_samples} stochastic forward passes...")
    
    # Initialize accumulators
    sum_preds = None
    sum_sq_preds = None
    
    num_batches = int(np.ceil(len(X) / batch_size))
    
    for i in range(num_samples):
        if verbose and (i + 1) % 5 == 0:
            print(f"  Completed: {i+1}/{num_samples} forward passes")
        
        batch_preds = []
        for batch_idx in range(num_batches):
            start_idx = batch_idx * batch_size
            end_idx = min(start_idx + batch_size, len(X))
            X_batch = X[start_idx:end_idx]
            
            # Predict with training=True for dropout
            pred_batch = model(X_batch, training=True)
            batch_preds.append(pred_batch.numpy())
        
        # Concatenate batches for current pass
        current_pass_preds = np.concatenate(batch_preds, axis=0)
        
        # Accumulate sums
        if sum_preds is None:
            sum_preds = current_pass_preds.astype(np.float32)
            sum_sq_preds = np.square(current_pass_preds).astype(np.float32)
        else:
            sum_preds += current_pass_preds
            sum_sq_preds += np.square(current_pass_preds)
        
        # Free memory
        del current_pass_preds, batch_preds
        if (i + 1) % 5 == 0:
            gc.collect()
    
    # Calculate Mean and Std
    mean_pred = sum_preds / num_samples
    
    # Var = E[X^2] - (E[X])^2
    # Std = sqrt(Var)
    mean_sq_pred = sum_sq_preds / num_samples
    var_pred = mean_sq_pred - np.square(mean_pred)
    # Ensure non-negative variance due to float precision
    var_pred = np.maximum(var_pred, 0)
    std_pred = np.sqrt(var_pred)
    
    # Cleanup
    del sum_preds, sum_sq_preds
    gc.collect()
    
    if verbose:
        print(f"✓ MC Dropout completed")
    
    return mean_pred, std_pred

# ============================================================================
# GLAUCOMA PROGRESSION SCORING
# ============================================================================

def calculate_cdr(mask, disc_class=1, cup_class=2, method='vertical'):
    """
    Calculate Cup-to-Disc Ratio (CDR) from segmentation mask
    
    Methods:
    - 'vertical': Vertical diameter ratio (clinical standard, most accurate)
    - 'area_sqrt': Square root of area ratio (robust alternative)
    
    Args:
        mask: Segmentation mask (H, W) with class labels
        disc_class: Class label for optic disc (default=1)
        cup_class: Class label for optic cup (default=2)
        method: Calculation method (default='vertical')
    
    Returns:
        dict with vCDR, hCDR, avgCDR, area_CDR
    """
    disc_mask = (mask == disc_class).astype(np.uint8)
    cup_mask = (mask == cup_class).astype(np.uint8)
    
    # Check if disc and cup are present
    disc_area = disc_mask.sum()
    cup_area = cup_mask.sum()
    
    if disc_area == 0 or cup_area == 0:
        return {'vCDR': 0.0, 'hCDR': 0.0, 'avgCDR': 0.0, 'area_CDR': 0.0, 'valid': False, 
                'method': method, 'disc_area': 0, 'cup_area': 0}
    
    # Find coordinates
    disc_coords = np.where(disc_mask > 0)
    cup_coords = np.where(cup_mask > 0)
    
    # Calculate diameters using bounding box
    disc_v_diameter = disc_coords[0].max() - disc_coords[0].min() + 1
    cup_v_diameter = cup_coords[0].max() - cup_coords[0].min() + 1
    disc_h_diameter = disc_coords[1].max() - disc_coords[1].min() + 1
    cup_h_diameter = cup_coords[1].max() - cup_coords[1].min() + 1
    
    # Calculate CDRs
    vCDR = cup_v_diameter / disc_v_diameter if disc_v_diameter > 0 else 0.0
    hCDR = cup_h_diameter / disc_h_diameter if disc_h_diameter > 0 else 0.0
    
    # Calculate area-based CDR
    area_CDR = np.sqrt(cup_area / disc_area)
    
    # Choose primary CDR based on method
    if method == 'vertical':
        avgCDR = vCDR  # Use vertical CDR (clinical standard)
    elif method == 'area_sqrt':
        avgCDR = area_CDR  # Use area-based
    else:
        avgCDR = (vCDR + hCDR) / 2.0  # Average of both
    
    return {
        'vCDR': float(vCDR),
        'hCDR': float(hCDR),
        'avgCDR': float(avgCDR),
        'area_CDR': float(area_CDR),
        'valid': True,
        'method': method,
        'disc_area': int(disc_area),
        'cup_area': int(cup_area),
        'disc_v_diameter': int(disc_v_diameter),
        'cup_v_diameter': int(cup_v_diameter)
    }

def classify_glaucoma_severity(cdr):
    """
    Classify glaucoma severity based on CDR
    
    Classification:
    - Normal: CDR < 0.3
    - Suspect: 0.3 ≤ CDR < 0.6
    - Moderate: 0.6 ≤ CDR < 0.8
    - Critical: CDR ≥ 0.8
    
    Args:
        cdr: Cup-to-Disc Ratio (float)
    
    Returns:
        tuple: (severity_class, severity_label, color)
    """
    if cdr < 0.3:
        return 0, 'Normal', '#4CAF50'  # Green
    elif cdr < 0.6:
        return 1, 'Suspect', '#FFC107'  # Amber
    elif cdr < 0.8:
        return 2, 'Moderate', '#FF9800'  # Orange
    else:
        return 3, 'Critical', '#F44336'  # Red

def analyze_glaucoma_progression(masks, predictions, cdr_method='area_sqrt'):
    """
    Analyze glaucoma progression for a batch of samples
    
    Args:
        masks: Ground truth masks (N, H, W)
        predictions: Predicted masks (N, H, W)
        cdr_method: CDR calculation method (default='area_sqrt' for robustness)
    
    Returns:
        DataFrame with CDR metrics and classifications
    """
    results = []
    
    for i, (gt_mask, pred_mask) in enumerate(zip(masks, predictions)):
        # Calculate CDR for ground truth
        gt_cdr = calculate_cdr(gt_mask, method=cdr_method)
        
        # Calculate CDR for prediction
        pred_cdr = calculate_cdr(pred_mask, method=cdr_method)
        
        # Classify severity
        if gt_cdr['valid']:
            gt_class, gt_label, gt_color = classify_glaucoma_severity(gt_cdr['avgCDR'])
        else:
            gt_class, gt_label, gt_color = -1, 'Invalid', '#9E9E9E'
        
        if pred_cdr['valid']:
            pred_class, pred_label, pred_color = classify_glaucoma_severity(pred_cdr['avgCDR'])
        else:
            pred_class, pred_label, pred_color = -1, 'Invalid', '#9E9E9E'
        
        # Calculate CDR error
        cdr_error = abs(gt_cdr['avgCDR'] - pred_cdr['avgCDR']) if gt_cdr['valid'] and pred_cdr['valid'] else np.nan
        
        # Check if classification matches
        severity_match = (gt_label == pred_label)
        
        # Manual review needed: Critical cases or mismatches
        manual_review = (gt_label == 'Critical') or (not severity_match)
        
        results.append({
            'Sample': i + 1,
            'GT_vCDR': gt_cdr['vCDR'],
            'GT_hCDR': gt_cdr['hCDR'],
            'GT_avgCDR': gt_cdr['avgCDR'],
            'GT_area_CDR': gt_cdr['area_CDR'],
            'GT_Severity': gt_label,
            'Pred_vCDR': pred_cdr['vCDR'],
            'Pred_hCDR': pred_cdr['hCDR'],
            'Pred_avgCDR': pred_cdr['avgCDR'],
            'Pred_area_CDR': pred_cdr['area_CDR'],
            'Pred_Severity': pred_label,
            'CDR_Error': cdr_error,
            'Severity_Match': severity_match,
            'Manual_Review_Needed': manual_review
        })
    
    return pd.DataFrame(results)

def calculate_progression_accuracy(df_progression):
    """
    Calculate simple accuracy metrics: GT progression vs Predicted progression
    
    Returns accuracy % like: "GT says Normal for 250 images, model says 230 are Normal"
    """
    results = {}
    
    # Overall accuracy
    total = len(df_progression)
    correct = df_progression['Severity_Match'].sum()
    overall_accuracy = (correct / total) * 100
    
    results['overall'] = {
        'total': total,
        'correct': correct,
        'accuracy': overall_accuracy
    }
    
    # Per-class accuracy
    severity_classes = ['Normal', 'Suspect', 'Moderate', 'Critical']
    results['per_class'] = {}
    
    for severity in severity_classes:
        gt_count = len(df_progression[df_progression['GT_Severity'] == severity])
        pred_count = len(df_progression[df_progression['Pred_Severity'] == severity])
        
        # Correctly predicted: GT is this class AND model predicted it as this class
        correct_count = len(df_progression[
            (df_progression['GT_Severity'] == severity) & 
            (df_progression['Pred_Severity'] == severity)
        ])
        
        class_accuracy = (correct_count / gt_count * 100) if gt_count > 0 else 0.0
        
        results['per_class'][severity] = {
            'gt_count': gt_count,
            'pred_count': pred_count,
            'correct': correct_count,
            'accuracy': class_accuracy
        }
    
    # Manual review statistics
    manual_review_needed = df_progression['Manual_Review_Needed'].sum()
    manual_review_pct = (manual_review_needed / total) * 100
    
    results['manual_review'] = {
        'count': manual_review_needed,
        'percentage': manual_review_pct
    }
    
    return results

# ============================================================================
# VISUALIZATION FUNCTIONS
# ============================================================================

def plot_sample_predictions(model, X_test, y_test, model_name, num_samples=6, save_dir='results'):
    """Visualize sample predictions with original image, GT, segmented mask, and overlay"""
    os.makedirs(save_dir, exist_ok=True)
    
    y_pred = model.predict(X_test[:num_samples], verbose=0, batch_size=4)
    y_pred_labels = np.argmax(y_pred, axis=-1)
    
    colors = {0: [0, 0, 0], 1: [0, 255, 0], 2: [255, 0, 0]}
    
    fig, axes = plt.subplots(num_samples, 4, figsize=(16, 4*num_samples))
    
    for i in range(num_samples):
        # Original image
        axes[i, 0].imshow(X_test[i])
        axes[i, 0].set_title('Original Image', fontsize=12, fontweight='bold')
        axes[i, 0].axis('off')
        
        # Ground truth
        gt_colored = np.zeros((512, 512, 3), dtype=np.uint8)
        for class_id, color in colors.items():
            gt_colored[y_test[i] == class_id] = color
        axes[i, 1].imshow(gt_colored)
        axes[i, 1].set_title('Ground Truth (GT)', fontsize=12, fontweight='bold')
        axes[i, 1].axis('off')
        
        # Segmented mask
        pred_colored = np.zeros((512, 512, 3), dtype=np.uint8)
        for class_id, color in colors.items():
            pred_colored[y_pred_labels[i] == class_id] = color
        axes[i, 2].imshow(pred_colored)
        axes[i, 2].set_title('Segmented Mask', fontsize=12, fontweight='bold')
        axes[i, 2].axis('off')
        
        # Overlay
        overlay = X_test[i].copy()
        for class_id, color in colors.items():
            if class_id > 0:
                mask = (y_pred_labels[i] == class_id).astype(np.float32)
                mask_rgb = np.stack([mask * color[0]/255, mask * color[1]/255, mask * color[2]/255], axis=-1)
                overlay = overlay * 0.6 + mask_rgb * 0.4
        axes[i, 3].imshow(overlay)
        axes[i, 3].set_title('Overlay', fontsize=12, fontweight='bold')
        axes[i, 3].axis('off')
        
        # Calculate dice
        y_test_cat = to_categorical(y_test[i], num_classes=3)
        y_pred_cat = to_categorical(y_pred_labels[i], num_classes=3)
        
        disc_dice = 2 * np.sum(y_test_cat[:,:,1] * y_pred_cat[:,:,1]) / (np.sum(y_test_cat[:,:,1]) + np.sum(y_pred_cat[:,:,1]) + 1e-7)
        cup_dice = 2 * np.sum(y_test_cat[:,:,2] * y_pred_cat[:,:,2]) / (np.sum(y_test_cat[:,:,2]) + np.sum(y_pred_cat[:,:,2]) + 1e-7)
        
        axes[i, 0].text(0.5, -0.1, f'Sample {i+1}\nDisc: {disc_dice:.3f} | Cup: {cup_dice:.3f}', 
                       transform=axes[i, 0].transAxes, ha='center', fontsize=10, 
                       bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
    
    plt.suptitle(f'{model_name} - Predictions: Original | GT | Segmented | Overlay', 
                 fontsize=16, fontweight='bold', y=0.995)
    plt.tight_layout()
    plt.savefig(f'{save_dir}/{model_name}_predictions.png', dpi=150, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_predictions.png")
    plt.show()
    plt.close()

def plot_sample_predictions_with_cdr(model, X_test_roi, y_test_full, roi_coords_test,
                                     model_name, num_samples=6, save_dir='results'):
    """Visualize predictions with CDR and glaucoma severity (ROI-aware)"""
    os.makedirs(save_dir, exist_ok=True)
    
    y_pred = model.predict(X_test_roi[:num_samples], verbose=0, batch_size=4)
    y_pred_labels_roi = np.argmax(y_pred, axis=-1)
    
    colors = {0: [0, 0, 0], 1: [0, 255, 0], 2: [255, 0, 0]}
    
    fig, axes = plt.subplots(num_samples, 4, figsize=(18, 4*num_samples))
    
    for i in range(num_samples):
        # ROI image
        axes[i, 0].imshow(X_test_roi[i])
        axes[i, 0].set_title('ROI Image', fontsize=12, fontweight='bold')
        axes[i, 0].axis('off')
        
        # Ground truth (on full image for CDR)
        gt_mask_full = y_test_full[i]
        h, w = gt_mask_full.shape
        gt_colored = np.zeros((h, w, 3), dtype=np.uint8)
        for class_id, color in colors.items():
            gt_colored[gt_mask_full == class_id] = color
        axes[i, 1].imshow(gt_colored)
        
        gt_cdr = calculate_cdr(gt_mask_full)
        gt_class, gt_label, gt_color = classify_glaucoma_severity(gt_cdr['avgCDR']) if gt_cdr['valid'] else (-1, 'Invalid', '#9E9E9E')
        
        axes[i, 1].set_title(f'Ground Truth\nCDR: {gt_cdr["avgCDR"]:.3f} | {gt_label}', 
                            fontsize=12, fontweight='bold', color=gt_color)
        axes[i, 1].axis('off')
        
        # Map ROI prediction back to full image
        pred_full = map_roi_prediction_to_full(y_pred_labels_roi[i], roi_coords_test[i], full_size=(h, w))
        pred_colored = np.zeros((h, w, 3), dtype=np.uint8)
        for class_id, color in colors.items():
            pred_colored[pred_full == class_id] = color
        axes[i, 2].imshow(pred_colored)
        
        pred_cdr = calculate_cdr(pred_full)
        pred_class, pred_label, pred_color = classify_glaucoma_severity(pred_cdr['avgCDR']) if pred_cdr['valid'] else (-1, 'Invalid', '#9E9E9E')
        
        axes[i, 2].set_title(f'Prediction\nCDR: {pred_cdr["avgCDR"]:.3f} | {pred_label}', 
                            fontsize=12, fontweight='bold', color=pred_color)
        axes[i, 2].axis('off')
        
        # Overlay on ROI
        overlay = X_test_roi[i].copy()
        for class_id, color in colors.items():
            if class_id > 0:
                mask = (y_pred_labels_roi[i] == class_id).astype(np.float32)
                mask_rgb = np.stack([mask * color[0]/255, mask * color[1]/255, mask * color[2]/255], axis=-1)
                overlay = overlay * 0.6 + mask_rgb * 0.4
        axes[i, 3].imshow(overlay)
        axes[i, 3].set_title('ROI Overlay', fontsize=12, fontweight='bold')
        axes[i, 3].axis('off')
        
        # Calculate dice on ROI
        roi_gt_cat = to_categorical(y_test_full[i], num_classes=3)  # use full GT for fair CDR
        roi_pred_cat = to_categorical(pred_full, num_classes=3)
        
        disc_dice = 2 * np.sum(roi_gt_cat[:,:,1] * roi_pred_cat[:,:,1]) / (np.sum(roi_gt_cat[:,:,1]) + np.sum(roi_pred_cat[:,:,1]) + 1e-7)
        cup_dice = 2 * np.sum(roi_gt_cat[:,:,2] * roi_pred_cat[:,:,2]) / (np.sum(roi_gt_cat[:,:,2]) + np.sum(roi_pred_cat[:,:,2]) + 1e-7)
        
        cdr_error = abs(gt_cdr['avgCDR'] - pred_cdr['avgCDR']) if gt_cdr['valid'] and pred_cdr['valid'] else np.nan
        
        info_text = f'Sample {i+1}\n'
        info_text += f'Disc Dice: {disc_dice:.3f} | Cup Dice: {cup_dice:.3f}\n'
        info_text += f'CDR Error: {cdr_error:.3f}' if not np.isnan(cdr_error) else 'CDR Error: N/A'
        
        axes[i, 0].text(0.5, -0.15, info_text, transform=axes[i, 0].transAxes, 
                       ha='center', fontsize=10, bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
    
    plt.suptitle(f'{model_name} - ROI Predictions with Glaucoma Severity Assessment', 
                 fontsize=16, fontweight='bold', y=0.995)
    plt.tight_layout()
    plt.savefig(f'{save_dir}/{model_name}_predictions_cdr.png', dpi=150, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_predictions_cdr.png")
    plt.show()
    plt.close()

def plot_cdr_distribution(df_progression, save_dir='results'):
    """Plot CDR distribution and severity classification"""
    os.makedirs(save_dir, exist_ok=True)
    
    fig, axes = plt.subplots(2, 2, figsize=(16, 12))
    
    # CDR scatter plot (GT vs Pred)
    axes[0, 0].scatter(df_progression['GT_avgCDR'], df_progression['Pred_avgCDR'], 
                      alpha=0.6, s=100, c='blue', edgecolors='black')
    axes[0, 0].plot([0, 1], [0, 1], 'r--', linewidth=2, label='Perfect Prediction')
    axes[0, 0].set_xlabel('Ground Truth CDR', fontsize=12, fontweight='bold')
    axes[0, 0].set_ylabel('Predicted CDR', fontsize=12, fontweight='bold')
    axes[0, 0].set_title('CDR: Ground Truth vs Prediction', fontsize=14, fontweight='bold')
    axes[0, 0].legend(fontsize=10)
    axes[0, 0].grid(True, alpha=0.3)
    
    # Add severity zones
    axes[0, 0].axhspan(0, 0.3, alpha=0.1, color='green', label='Normal')
    axes[0, 0].axhspan(0.3, 0.6, alpha=0.1, color='yellow', label='Suspect')
    axes[0, 0].axhspan(0.6, 0.8, alpha=0.1, color='orange', label='Moderate')
    axes[0, 0].axhspan(0.8, 1.0, alpha=0.1, color='red', label='Critical')
    
    # CDR error histogram
    valid_errors = df_progression['CDR_Error'].dropna()
    axes[0, 1].hist(valid_errors, bins=30, color='steelblue', edgecolor='black', alpha=0.7)
    axes[0, 1].axvline(valid_errors.mean(), color='red', linestyle='--', linewidth=2, 
                      label=f'Mean Error: {valid_errors.mean():.4f}')
    axes[0, 1].set_xlabel('CDR Error (|GT - Pred|)', fontsize=12, fontweight='bold')
    axes[0, 1].set_ylabel('Frequency', fontsize=12, fontweight='bold')
    axes[0, 1].set_title('CDR Error Distribution', fontsize=14, fontweight='bold')
    axes[0, 1].legend(fontsize=10)
    axes[0, 1].grid(True, alpha=0.3)
    
    # Severity classification confusion matrix
    severity_order = ['Normal', 'Suspect', 'Moderate', 'Critical']
    gt_severity = pd.Categorical(df_progression['GT_Severity'], categories=severity_order, ordered=True)
    pred_severity = pd.Categorical(df_progression['Pred_Severity'], categories=severity_order, ordered=True)
    
    cm = confusion_matrix(gt_severity, pred_severity, labels=severity_order)
    
    sns.heatmap(cm, annot=True, fmt='d', cmap='YlOrRd', 
                xticklabels=severity_order, yticklabels=severity_order,
                ax=axes[1, 0], cbar_kws={'label': 'Count'})
    axes[1, 0].set_title('Glaucoma Severity Classification', fontsize=14, fontweight='bold')
    axes[1, 0].set_ylabel('Ground Truth', fontsize=12, fontweight='bold')
    axes[1, 0].set_xlabel('Predicted', fontsize=12, fontweight='bold')
    
    # Severity distribution
    severity_counts_gt = df_progression['GT_Severity'].value_counts()
    severity_counts_pred = df_progression['Pred_Severity'].value_counts()
    
    x = np.arange(len(severity_order))
    width = 0.35
    
    counts_gt = [severity_counts_gt.get(s, 0) for s in severity_order]
    counts_pred = [severity_counts_pred.get(s, 0) for s in severity_order]
    
    bars1 = axes[1, 1].bar(x - width/2, counts_gt, width, label='Ground Truth', 
                          color=['#4CAF50', '#FFC107', '#FF9800', '#F44336'], alpha=0.7)
    bars2 = axes[1, 1].bar(x + width/2, counts_pred, width, label='Predicted', 
                          color=['#4CAF50', '#FFC107', '#FF9800', '#F44336'], alpha=0.4)
    
    axes[1, 1].set_xlabel('Severity Level', fontsize=12, fontweight='bold')
    axes[1, 1].set_ylabel('Count', fontsize=12, fontweight='bold')
    axes[1, 1].set_title('Severity Distribution', fontsize=14, fontweight='bold')
    axes[1, 1].set_xticks(x)
    axes[1, 1].set_xticklabels(severity_order, rotation=15)
    axes[1, 1].legend(fontsize=10)
    axes[1, 1].grid(True, alpha=0.3, axis='y')
    
    plt.tight_layout()
    plt.savefig(f'{save_dir}/cdr_analysis.png', dpi=150, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/cdr_analysis.png")
    plt.show()
    plt.close()

def plot_training_history(history, model_name, save_dir='results'):
    """Plot training history - Loss and Accuracy only"""
    os.makedirs(save_dir, exist_ok=True)
    
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    
    # Loss curves
    axes[0].plot(history.history['loss'], label='Training Loss', linewidth=2)
    axes[0].plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
    axes[0].set_title(f'{model_name} - Loss Over Epochs', fontsize=14, fontweight='bold')
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('Loss', fontsize=12)
    axes[0].legend(fontsize=10)
    axes[0].grid(True, alpha=0.3)
    
    # Accuracy curves
    axes[1].plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
    axes[1].plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
    axes[1].set_title(f'{model_name} - Accuracy Over Epochs', fontsize=14, fontweight='bold')
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('Accuracy', fontsize=12)
    axes[1].legend(fontsize=10)
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(f'{save_dir}/{model_name}_history.png', dpi=150, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_history.png")
    plt.show()
    plt.close()

def plot_training_curves(history, model_name, save_dir='results'):
    """Plot training loss and accuracy curves"""
    os.makedirs(save_dir, exist_ok=True)
    
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    
    # Loss
    axes[0].plot(history.history['loss'], label='Training Loss', linewidth=2)
    axes[0].plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
    axes[0].set_title(f'{model_name} - Loss Over Epochs', fontsize=14, fontweight='bold')
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('Loss', fontsize=12)
    axes[0].legend(fontsize=10)
    axes[0].grid(True, alpha=0.3)
    
    # Accuracy
    axes[1].plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
    axes[1].plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
    axes[1].set_title(f'{model_name} - Accuracy Over Epochs', fontsize=14, fontweight='bold')
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('Accuracy', fontsize=12)
    axes[1].legend(fontsize=10)
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(f"{save_dir}/{model_name}_training_curves.png", dpi=300, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_training_curves.png")
    plt.show()
    plt.close()

def plot_confusion_matrices(y_true, y_pred, model_name, save_dir='results'):
    """Plot confusion matrices"""
    os.makedirs(save_dir, exist_ok=True)
    
    y_true_labels = np.argmax(y_true, axis=-1).flatten()
    y_pred_labels = np.argmax(y_pred, axis=-1).flatten()
    
    cm = confusion_matrix(y_true_labels, y_pred_labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    class_names = ['Background', 'Disc', 'Cup']
    
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[0], cbar_kws={'label': 'Count'})
    axes[0].set_title(f'{model_name}\nConfusion Matrix', fontsize=14, fontweight='bold')
    axes[0].set_ylabel('True Label', fontsize=12)
    axes[0].set_xlabel('Predicted Label', fontsize=12)
    
    sns.heatmap(cm_normalized, annot=True, fmt='.3f', cmap='Greens',
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[1], cbar_kws={'label': 'Proportion'})
    axes[1].set_title(f'{model_name}\nNormalized Confusion Matrix', fontsize=14, fontweight='bold')
    axes[1].set_ylabel('True Label', fontsize=12)
    axes[1].set_xlabel('Predicted Label', fontsize=12)
    
    plt.tight_layout()
    plt.savefig(f"{save_dir}/{model_name}_confusion_matrices.png", dpi=300, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_confusion_matrices.png")
    plt.show()
    plt.close()
    
    print(f"\nConfusion Matrix:\n{cm}")
    print(f"\nNormalized Confusion Matrix:\n{np.round(cm_normalized, 3)}")
    
    return cm, cm_normalized

# ============================================================================
# TRAINING AND EVALUATION
# ============================================================================

def train_model(X_train_roi, y_train_roi, X_val_roi, y_val_roi,
                X_test_roi, y_test_full, roi_coords_test,
                model_name, augment=None, save_dir='results'):
    """Train model with MSCA + LBFR + PPM triple enhancement on ROI-cropped data"""
    print(f"\n{'='*80}")
    print(f"TRAINING: {model_name}")
    print(f"{'='*80}")
    print(f"  Architecture: Deeper Decoder + MSCA + LBFR + PPM + Focal-EIoU + MC Dropout")
    print(f"  Loss: Focal + Enhanced IoU (Combined)")
    print(f"  ROI Extraction: ENABLED (training on disc-centered crops)")
    
    K.clear_session()
    
    # Build model
    model = build_unet_with_triple_attention(dropout_rate=0.3)
    param_count = model.count_params()
    
    # Compile
    model.compile(
        optimizer=optimizers.Adam(learning_rate=2e-4, clipnorm=1.0),
        loss=focal_eiou_combined_loss,
        metrics=[dice_coef_multiclass, dice_class_0, dice_class_1, dice_class_2,
                "accuracy", iou_coef_multiclass, iou_class_0, iou_class_1, iou_class_2]
    )
    
    # Callbacks
    checkpoint = ModelCheckpoint(f"{save_dir}/{model_name}.keras", save_best_only=True, 
                                verbose=1, monitor='val_loss', mode='min')
    reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=4,
                                  verbose=1, mode='min', min_lr=1e-7)
    early_stop = EarlyStopping(monitor="val_loss", patience=15, verbose=1,
                              restore_best_weights=True, mode='min')
    
    # Training on ROI data
    batch_size = 4
    steps_train = X_train_roi.shape[0] // batch_size
    steps_val = X_val_roi.shape[0] // batch_size
    
    history = model.fit(
        data_generator(X_train_roi, y_train_roi, batch_size, augment),
        validation_data=data_generator(X_val_roi, y_val_roi, batch_size, None),
        steps_per_epoch=steps_train,
        validation_steps=steps_val,
        epochs=80,
        callbacks=[checkpoint, reduce_lr, early_stop],
        verbose=1
    )
    
    print(f"✓ Training completed")
    
    # Visualizations
    print("\nGenerating visualizations...")
    plot_training_history(history, model_name, save_dir)
    plot_sample_predictions_with_cdr(model, X_test_roi, y_test_full, roi_coords_test,
                                     model_name, num_samples=8, save_dir=save_dir)
    
    return model, history, param_count

def save_segmentation_masks(X_test_roi, y_test_full, y_pred_labels_roi,
                            roi_coords_test, save_dir='results/predictions'):
    """Save all test predictions (masks only) with visible pixel values — ROI-aware"""
    os.makedirs(save_dir, exist_ok=True)
    
    print(f"\nSaving all {len(X_test_roi)} test predictions to {save_dir}...")
    
    for i in range(len(X_test_roi)):
        h, w = y_test_full[i].shape
        
        # Map ROI prediction back to full image
        pred_full = map_roi_prediction_to_full(y_pred_labels_roi[i], roi_coords_test[i], full_size=(h, w))
        
        # Process Predicted Mask (0, 1, 2)
        visible_pred = np.zeros((h, w), dtype=np.uint8)
        visible_pred[pred_full == 1] = 127  # Disc
        visible_pred[pred_full == 2] = 255  # Cup
        
        # Process Ground Truth Mask
        gt_mask = y_test_full[i].astype(np.uint8)
        visible_gt = np.zeros_like(gt_mask)
        visible_gt[gt_mask == 1] = 127  # Disc
        visible_gt[gt_mask == 2] = 255  # Cup
        
        # Combine side by side (GT left, Pred right)
        combined = np.hstack((visible_gt, visible_pred))
        
        # Save as PNG
        Image.fromarray(combined).save(f"{save_dir}/test_{i+1:04d}_comparison.png")
            
        if (i + 1) % 50 == 0:
            print(f"  Processed {i+1}/{len(X_test_roi)}")
            
    print(f"✓ Saved comparison masks to {save_dir}")

def evaluate_model(model, X_test_roi, y_test_roi, y_test_full, roi_coords_test,
                   model_name, run_mc_dropout=True, save_predictions=True):
    """Evaluate model with glaucoma progression analysis — ROI-aware"""
    print(f"\n{'='*80}")
    print(f"EVALUATION: {model_name}")
    print(f"{'='*80}")
    
    # --- ROI-level metrics (what the model actually sees) ---
    y_test_roi_cat = np.array([to_categorical(mask, num_classes=3) for mask in y_test_roi])
    
    y_pred = model.predict(X_test_roi, verbose=0, batch_size=4)
    y_pred_labels_roi = np.argmax(y_pred, axis=-1)
    
    # --- Map predictions back to full image for CDR / progression analysis ---
    y_pred_labels_full = []
    for i in range(len(X_test_roi)):
        h, w = y_test_full[i].shape
        pred_full = map_roi_prediction_to_full(y_pred_labels_roi[i], roi_coords_test[i], full_size=(h, w))
        y_pred_labels_full.append(pred_full)
    y_pred_labels_full = np.array(y_pred_labels_full)
    
    if save_predictions:
        save_segmentation_masks(X_test_roi, y_test_full, y_pred_labels_roi,
                                roi_coords_test, save_dir=f'results/{model_name}_all_preds')
    
    # Confusion matrices (on ROI crops — where the model is evaluated)
    plot_confusion_matrices(y_test_roi_cat, y_pred, model_name, save_dir='results')
    
    # Classification metrics on ROI
    y_true_labels = np.argmax(y_test_roi_cat, axis=-1).flatten()
    y_pred_labels_flat = y_pred_labels_roi.flatten()
    
    precision = precision_score(y_true_labels, y_pred_labels_flat, average=None, zero_division=0)
    recall = recall_score(y_true_labels, y_pred_labels_flat, average=None, zero_division=0)
    f1 = f1_score(y_true_labels, y_pred_labels_flat, average=None, zero_division=0)
    
    print(f"\nPrecision, Recall, F1 Score per class (ROI-level):")
    class_names = ["Background", "Disc", "Cup"]
    for idx, cname in enumerate(class_names):
        print(f"  {cname}: Precision={precision[idx]:.4f}, Recall={recall[idx]:.4f}, F1={f1[idx]:.4f}")
    
    print(f"\nMacro-averaged metrics:")
    print(f"  Precision: {np.mean(precision):.4f}")
    print(f"  Recall: {np.mean(recall):.4f}")
    print(f"  F1 Score: {np.mean(f1):.4f}")
    
    # Per-class Dice and IoU (on ROI)
    results = {'standard': {}}
    for cidx, cname in enumerate(class_names):
        y_true_c = (np.argmax(y_test_roi_cat, axis=-1) == cidx).astype(np.float32)
        y_pred_c = (y_pred_labels_roi == cidx).astype(np.float32)
        
        intersection = np.sum(y_true_c * y_pred_c)
        dice = (2. * intersection + 1e-7) / (np.sum(y_true_c) + np.sum(y_pred_c) + 1e-7)
        union = np.sum(y_true_c) + np.sum(y_pred_c) - intersection
        iou = (intersection + 1e-7) / (union + 1e-7)
        
        results['standard'][cname] = {'dice': dice, 'iou': iou}
        print(f"  {cname}: Dice={dice:.4f}, IoU={iou:.4f}")
    
    # Glaucoma Progression Analysis (on full-image mapped predictions)
    print(f"\n{'='*80}")
    print(f"GLAUCOMA PROGRESSION ANALYSIS (Using Area-based CDR on full-image mapped predictions)")
    print(f"{'='*80}")
    
    df_progression = analyze_glaucoma_progression(y_test_full, y_pred_labels_full, cdr_method='area_sqrt')
    
    # CDR Statistics
    print(f"\n{'-'*80}")
    print(f"CDR Statistics:")
    print(f"{'-'*80}")
    print(f"  Mean GT CDR:   {df_progression['GT_avgCDR'].mean():.4f} ± {df_progression['GT_avgCDR'].std():.4f}")
    print(f"  Mean Pred CDR: {df_progression['Pred_avgCDR'].mean():.4f} ± {df_progression['Pred_avgCDR'].std():.4f}")
    print(f"  Mean CDR Error: {df_progression['CDR_Error'].mean():.4f} ± {df_progression['CDR_Error'].std():.4f}")
    
    # Calculate progression accuracy
    accuracy_results = calculate_progression_accuracy(df_progression)
    
    # Overall Accuracy
    print(f"\n{'='*80}")
    print(f"PROGRESSION CLASSIFICATION ACCURACY")
    print(f"{'='*80}")
    print(f"\nOverall Accuracy: {accuracy_results['overall']['accuracy']:.2f}%")
    print(f"  - Correctly Classified: {accuracy_results['overall']['correct']}/{accuracy_results['overall']['total']} samples")
    print(f"  - Incorrectly Classified: {accuracy_results['overall']['total'] - accuracy_results['overall']['correct']}/{accuracy_results['overall']['total']} samples")
    
    # Per-Class Results
    print(f"\n{'-'*80}")
    print(f"Per-Class Results:")
    print(f"{'-'*80}")
    print(f"{'Severity':<12} {'GT Count':<12} {'Pred Count':<12} {'Correct':<12} {'Accuracy':<12}")
    print(f"{'-'*80}")
    
    for severity in ['Normal', 'Suspect', 'Moderate', 'Critical']:
        stats = accuracy_results['per_class'][severity]
        print(f"{severity:<12} {stats['gt_count']:<12} {stats['pred_count']:<12} "
              f"{stats['correct']:<12} {stats['accuracy']:<12.2f}%")
    
    print(f"\n{'='*80}")
    print(f"INTERPRETATION EXAMPLE:")
    print(f"{'='*80}")
    normal_stats = accuracy_results['per_class']['Normal']
    print(f"  - GT says 'Normal' for {normal_stats['gt_count']} images")
    print(f"  - Model says 'Normal' for {normal_stats['pred_count']} images")
    print(f"  - Model correctly predicts {normal_stats['correct']} as 'Normal'")
    print(f"  - Accuracy for Normal class: {normal_stats['correct']}/{normal_stats['gt_count']} = {normal_stats['accuracy']:.1f}%")
    
    # Manual Review Recommendations
    print(f"\n{'='*80}")
    print(f"MANUAL REVIEW RECOMMENDATIONS")
    print(f"{'='*80}")
    print(f"\nSamples Requiring Manual Review: {accuracy_results['manual_review']['count']}/{accuracy_results['overall']['total']} "
          f"({accuracy_results['manual_review']['percentage']:.1f}%)")
    print(f"\nCriteria for Manual Review:")
    print(f"  1. All Critical cases (high-risk, requires expert verification)")
    print(f"  2. Classification mismatches (GT ≠ Predicted severity)")
    print(f"\nReason: Critical cases need expert confirmation, and mismatches may")
    print(f"indicate borderline cases or segmentation issues requiring review.")
    
    # Breakdown of manual review cases
    review_df = df_progression[df_progression['Manual_Review_Needed'] == True]
    critical_cases = len(review_df[review_df['GT_Severity'] == 'Critical'])
    mismatch_cases = len(review_df[review_df['Severity_Match'] == False])
    overlap = len(review_df[(review_df['GT_Severity'] == 'Critical') & (review_df['Severity_Match'] == False)])
    
    print(f"\nBreakdown:")
    print(f"  - Critical cases: {critical_cases} samples")
    print(f"  - Classification mismatches: {mismatch_cases} samples")
    print(f"  - Overlap (Critical + Mismatch): {overlap} samples")
    
    # Save progression data
    df_progression.to_csv('results/glaucoma_progression_analysis.csv', index=False)
    print(f"\n✓ Saved: results/glaucoma_progression_analysis.csv")
    
    # Plot CDR analysis
    plot_cdr_distribution(df_progression, save_dir='results')
    
    results['glaucoma'] = {
        'mean_cdr_error': df_progression['CDR_Error'].mean(),
        'median_cdr_error': df_progression['CDR_Error'].median(),
        'classification_accuracy': accuracy_results['overall']['accuracy'] / 100,
        'df_progression': df_progression,
        'accuracy_breakdown': accuracy_results
    }
    
    # MC Dropout (on ROI data)
    if run_mc_dropout:
        print(f"\n{'='*80}")
        print(f"MC DROPOUT UNCERTAINTY ESTIMATION")
        print(f"{'='*80}")
        mean_pred, std_pred = mc_dropout_predict(model, X_test_roi[:100], num_samples=15, verbose=True)
        results['mc_dropout'] = {}
        for cidx, cname in enumerate(class_names):
            mean_std = np.mean(std_pred[:, :, :, cidx])
            results['mc_dropout'][cname] = {'mean_uncertainty': mean_std}
            print(f"  {cname} uncertainty: {mean_std:.4f}")
    
    return results

# ============================================================================
# MAIN EXECUTION
# ============================================================================

if __name__ == "__main__":
    # Setup
    gpu_available = configure_gpu()
    root_dir = "/kaggle/input/refuge/REFUGE/"
    train_aug = setup_augmentations()
    save_dir = "results"
    os.makedirs(save_dir, exist_ok=True)
    
    print(f"\n{'='*100}")
    print(f"{'MOBILENET-UNET WITH MSCA+LBFR+PPM + ROI EXTRACTION + GLAUCOMA PROGRESSION SCORING':^100s}")
    print(f"{'='*100}")
    print(f"\nModel Architecture:")
    print(f"  - Base: MobileNetV2 Encoder + Deeper Decoder")
    print(f"  - Triple Attention: MSCA + LBFR + PPM (12 modules total)")
    print(f"  - Loss: Focal + Enhanced IoU (Combined)")
    print(f"  - Uncertainty: MC Dropout (15 forward passes)")
    print(f"\nROI Extraction:")
    print(f"  - Automatically crops around the optic disc region from GT masks")
    print(f"  - Padding factor: 1.5× (50% margin around disc bounding box)")
    print(f"  - ROI resized to 512×512 → model sees zoomed-in disc/cup detail")
    print(f"  - Predictions mapped back to full image for CDR analysis")
    print(f"\nGlaucoma Severity Classification:")
    print(f"  - Normal:   CDR < 0.3  (Green)")
    print(f"  - Suspect:  0.3 ≤ CDR < 0.6  (Amber)")
    print(f"  - Moderate: 0.6 ≤ CDR < 0.8  (Orange)")
    print(f"  - Critical: CDR ≥ 0.8  (Red)")
    print(f"  CDR Method: Area-based (sqrt of area ratio) - Robust & Clinically Relevant")
    print(f"\nManual Review: Recommended for Critical cases and classification mismatches")
    
    # Load data (full images)
    all_images, all_masks = load_all_data(root_dir)
    (X_train, y_train), (X_val, y_val), (X_test, y_test) = create_new_split(all_images, all_masks)
    
    # ---- ROI EXTRACTION ----
    print(f"\n{'='*80}")
    print(f"ROI EXTRACTION")
    print(f"{'='*80}")
    
    ROI_PADDING = 1.5  # 50% margin around disc bounding box
    ROI_SIZE = (512, 512)
    
    print(f"  Padding factor: {ROI_PADDING}× | ROI size: {ROI_SIZE}")
    
    print(f"\n  Extracting ROIs for training set ({X_train.shape[0]} images)...")
    X_train_roi, y_train_roi, roi_coords_train = extract_roi_batch(X_train, y_train, ROI_PADDING, ROI_SIZE)
    print(f"  ✓ Train ROIs: {X_train_roi.shape}")
    
    print(f"  Extracting ROIs for validation set ({X_val.shape[0]} images)...")
    X_val_roi, y_val_roi, roi_coords_val = extract_roi_batch(X_val, y_val, ROI_PADDING, ROI_SIZE)
    print(f"  ✓ Val ROIs: {X_val_roi.shape}")
    
    print(f"  Extracting ROIs for test set ({X_test.shape[0]} images)...")
    X_test_roi, y_test_roi, roi_coords_test = extract_roi_batch(X_test, y_test, ROI_PADDING, ROI_SIZE)
    print(f"  ✓ Test ROIs: {X_test_roi.shape}")
    
    # Visualize ROI extraction for verification
    print(f"\n  Visualizing ROI extraction...")
    visualize_roi_extraction(X_test, y_test, num_samples=4)
    
    # Free full-image training/val data to save memory (keep test full for CDR analysis)
    del X_train, X_val
    gc.collect()
    print(f"  ✓ Freed full-image train/val data to save memory")
    
    # Train model on ROI data
    model, history, params = train_model(
        X_train_roi, y_train_roi, X_val_roi, y_val_roi,
        X_test_roi, y_test, roi_coords_test,
        "MSCA_LBFR_PPM_ROI_GlaucomaScoring",
        augment=train_aug, save_dir=save_dir
    )
    
    # Evaluate with ROI-aware glaucoma analysis
    results = evaluate_model(
        model, X_test_roi, y_test_roi, y_test, roi_coords_test,
        "MSCA+LBFR+PPM+ROI+GlaucomaScoring",
        run_mc_dropout=True, save_predictions=True
    )
    
    print(f"\n{'='*100}")
    print(f"{'✓ TRAINING AND EVALUATION COMPLETED!':^100s}")
    print(f"{'='*100}")
    print(f"\nModel: MSCA + LBFR + PPM + ROI Extraction + Focal + EIoU + MC Dropout + Glaucoma Scoring")
    print(f"Parameters: {params:,}")
    print(f"ROI Extraction: Padding={ROI_PADDING}x, Size={ROI_SIZE}")
    print(f"Results saved in: {save_dir}/")
    print(f"\nGenerated Files:")
    print(f"  - Training history: {save_dir}/MSCA_LBFR_PPM_ROI_GlaucomaScoring_history.png")
    print(f"  - Predictions with CDR: {save_dir}/MSCA_LBFR_PPM_ROI_GlaucomaScoring_predictions_cdr.png")
    print(f"  - CDR Analysis: {save_dir}/cdr_analysis.png")
    print(f"  - Progression CSV: {save_dir}/glaucoma_progression_analysis.csv")
    print(f"  - Confusion Matrices: {save_dir}/MSCA+LBFR+PPM+ROI+GlaucomaScoring_confusion_matrices.png")
    print(f"\n{'='*100}\n")
# Out:
# 2026-02-25 06:48:32.507681: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772002112.686167      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772002112.736132      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772002113.184848      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772002113.184886      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772002113.184888      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772002113.184891      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Configuring GPU settings...
# ✓ GPU configured: 1 device(s) available
#
# ====================================================================================================
#                   MOBILENET-UNET WITH MSCA+LBFR+PPM + GLAUCOMA PROGRESSION SCORING
# ====================================================================================================
#
# Model Architecture:
#   - Base: MobileNetV2 Encoder + Deeper Decoder
#   - Triple Attention: MSCA + LBFR + PPM (12 modules total)
#   - Loss: Focal + Enhanced IoU (Combined)
#   - Uncertainty: MC Dropout (15 forward passes)
#
# Glaucoma Severity Classification:
#   - Normal:   CDR < 0.3  (Green)
#   - Suspect:  0.3 ≤ CDR < 0.6  (Amber)
#   - Moderate: 0.6 ≤ CDR < 0.8  (Orange)
#   - Critical: CDR ≥ 0.8  (Red)
#   CDR Method: Area-based (sqrt of area ratio) - Robust & Clinically Relevant
#
# Manual Review: Recommended for Critical cases and classification mismatches
# Loading train data...
#   train: 400 samples
# Loading val data...
#   val: 400 samples
# Loading test data...
#   test: 400 samples
# Split - Train: 600, Val: 200, Test: 400
#
# ================================================================================
# TRAINING: MSCA_LBFR_PPM_GlaucomaScoring
# ================================================================================
#   Architecture: Deeper Decoder + MSCA + LBFR + PPM + Focal-EIoU + MC Dropout
#   Loss: Focal + Enhanced IoU (Combined)
# I0000 00:00:1772002262.032124      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# Model Configuration:
#   Total Parameters: 47,631,627
#   Dropout Layers: 5
#   Triple Attention Modules: MSCA + LBFR + PPM per decoder block
#   MSCA Modules: 4 (local multi-scale with dilation rates [1,2,3,5])
#   LBFR Modules: 4 (channel + spatial attention + recalibration)
#   PPM Modules: 4 (global pyramid pooling [1×1, 2×2, 3×3, 6×6])
#   Enhancement Strategy: Sequential MSCA → LBFR → PPM per block
#   Total Attention Blocks: 12 (4 MSCA + 4 LBFR + 4 PPM)
#   Context Coverage: Local Multi-scale + Attention + Global Multi-scale
# Epoch 1/80
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1772002333.242271     123 service.cc:152] XLA service 0x78f124004c10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1772002333.242313     123 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1772002351.067824     123 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-02-25 06:52:48.181167: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-25 06:52:48.437998: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-25 06:52:50.089050: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-25 06:52:50.325640: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-25 06:53:05.427793: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-25 06:53:05.664144: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1772002465.143638     123 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.6236 - dice_class_0: 0.7292 - dice_class_1: 0.2665 - dice_class_2: 0.0699 - dice_coef_multiclass: 0.3769 - iou_class_0: 0.6232 - iou_class_1: 0.1837 - iou_class_2: 0.0404 - iou_coef_multiclass: 0.2331 - loss: 5.3211
# 2026-02-25 06:55:40.657189: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-02-25 06:55:40.914274: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Epoch 1: val_loss improved from inf to 1.58456, saving model to results/MSCA_LBFR_PPM_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 298s 613ms/step - accuracy: 0.6250 - dice_class_0: 0.7303 - dice_class_1: 0.2681 - dice_class_2: 0.0709 - dice_coef_multiclass: 0.3772 - iou_class_0: 0.6246 - iou_class_1: 0.1850 - iou_class_2: 0.0410 - iou_coef_multiclass: 0.2333 - loss: 5.3217 - val_accuracy: 0.9875 - val_dice_class_0: 0.9955 - val_dice_class_1: 0.5104 - val_dice_class_2: 0.0788 - val_dice_coef_multiclass: 0.5281 - val_iou_class_0: 0.9910 - val_iou_class_1: 0.3499 - val_iou_class_2: 0.0415 - val_iou_coef_multiclass: 0.3588 - val_loss: 1.5846 - learning_rate: 2.0000e-04
# Epoch 2/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.9908 - dice_class_0: 0.9963 - dice_class_1: 0.7817 - dice_class_2: 0.5761 - dice_coef_multiclass: 0.5267 - iou_class_0: 0.9927 - iou_class_1: 0.6440 - iou_class_2: 0.4111 - iou_coef_multiclass: 0.3579 - loss: 4.7526
# Epoch 2: val_loss did not improve from 1.58456
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 436ms/step - accuracy: 0.9908 - dice_class_0: 0.9963 - dice_class_1: 0.7819 - dice_class_2: 0.5766 - dice_coef_multiclass: 0.5269 - iou_class_0: 0.9927 - iou_class_1: 0.6441 - iou_class_2: 0.4115 - iou_coef_multiclass: 0.3581 - loss: 4.7537 - val_accuracy: 0.9877 - val_dice_class_0: 0.9956 - val_dice_class_1: 0.5263 - val_dice_class_2: 0.0071 - val_dice_coef_multiclass: 0.6540 - val_iou_class_0: 0.9912 - val_iou_class_1: 0.3669 - val_iou_class_2: 0.0036 - val_iou_coef_multiclass: 0.4859 - val_loss: 22.8991 - learning_rate: 2.0000e-04
# Epoch 3/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9946 - dice_class_0: 0.9981 - dice_class_1: 0.8327 - dice_class_2: 0.7348 - dice_coef_multiclass: 0.6413 - iou_class_0: 0.9962 - iou_class_1: 0.7154 - iou_class_2: 0.5883 - iou_coef_multiclass: 0.4726 - loss: 5.3660
# Epoch 3: val_loss did not improve from 1.58456
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 435ms/step - accuracy: 0.9946 - dice_class_0: 0.9981 - dice_class_1: 0.8327 - dice_class_2: 0.7350 - dice_coef_multiclass: 0.6415 - iou_class_0: 0.9962 - iou_class_1: 0.7155 - iou_class_2: 0.5886 - iou_coef_multiclass: 0.4728 - loss: 5.3644 - val_accuracy: 0.9873 - val_dice_class_0: 0.9953 - val_dice_class_1: 0.5949 - val_dice_class_2: 0.1956 - val_dice_coef_multiclass: 0.7545 - val_iou_class_0: 0.9907 - val_iou_class_1: 0.4281 - val_iou_class_2: 0.1130 - val_iou_coef_multiclass: 0.6059 - val_loss: 9.5106 - learning_rate: 2.0000e-04
# Epoch 4/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9960 - dice_class_0: 0.9987 - dice_class_1: 0.8530 - dice_class_2: 0.8120 - dice_coef_multiclass: 0.7474 - iou_class_0: 0.9973 - iou_class_1: 0.7454 - iou_class_2: 0.6866 - iou_coef_multiclass: 0.5972 - loss: 4.7013
# Epoch 4: val_loss did not improve from 1.58456
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 434ms/step - accuracy: 0.9960 - dice_class_0: 0.9987 - dice_class_1: 0.8530 - dice_class_2: 0.8120 - dice_coef_multiclass: 0.7476 - iou_class_0: 0.9973 - iou_class_1: 0.7455 - iou_class_2: 0.6866 - iou_coef_multiclass: 0.5974 - loss: 4.7009 - val_accuracy: 0.9939 - val_dice_class_0: 0.9979 - val_dice_class_1: 0.7950 - val_dice_class_2: 0.6840 - val_dice_coef_multiclass: 0.8482 - val_iou_class_0: 0.9959 - val_iou_class_1: 0.6627 - val_iou_class_2: 0.5232 - val_iou_coef_multiclass: 0.7364 - val_loss: 5.7494 - learning_rate: 2.0000e-04
# Epoch 5/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9962 - dice_class_0: 0.9987 - dice_class_1: 0.8622 - dice_class_2: 0.8304 - dice_coef_multiclass: 0.8386 - iou_class_0: 0.9975 - iou_class_1: 0.7592 - iou_class_2: 0.7127 - iou_coef_multiclass: 0.7225 - loss: 4.7579
# Epoch 5: val_loss did not improve from 1.58456
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 434ms/step - accuracy: 0.9962 - dice_class_0: 0.9987 - dice_class_1: 0.8622 - dice_class_2: 0.8304 - dice_coef_multiclass: 0.8387 - iou_class_0: 0.9975 - iou_class_1: 0.7592 - iou_class_2: 0.7127 - iou_coef_multiclass: 0.7227 - loss: 4.7572 - val_accuracy: 0.9952 - val_dice_class_0: 0.9991 - val_dice_class_1: 0.8265 - val_dice_class_2: 0.4627 - val_dice_coef_multiclass: 0.9341 - val_iou_class_0: 0.9982 - val_iou_class_1: 0.7067 - val_iou_class_2: 0.3053 - val_iou_coef_multiclass: 0.8764 - val_loss: 10.2427 - learning_rate: 2.0000e-04
# Epoch 6/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9965 - dice_class_0: 0.9989 - dice_class_1: 0.8714 - dice_class_2: 0.8460 - dice_coef_multiclass: 0.9045 - iou_class_0: 0.9977 - iou_class_1: 0.7737 - iou_class_2: 0.7355 - iou_coef_multiclass: 0.8258 - loss: 5.3701
# Epoch 6: val_loss did not improve from 1.58456
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 435ms/step - accuracy: 0.9965 - dice_class_0: 0.9989 - dice_class_1: 0.8714 - dice_class_2: 0.8460 - dice_coef_multiclass: 0.9046 - iou_class_0: 0.9977 - iou_class_1: 0.7737 - iou_class_2: 0.7356 - iou_coef_multiclass: 0.8259 - loss: 5.3698 - val_accuracy: 0.9965 - val_dice_class_0: 0.9989 - val_dice_class_1: 0.8679 - val_dice_class_2: 0.8404 - val_dice_coef_multiclass: 0.9476 - val_iou_class_0: 0.9978 - val_iou_class_1: 0.7684 - val_iou_class_2: 0.7278 - val_iou_coef_multiclass: 0.9004 - val_loss: 7.6966 - learning_rate: 1.0000e-04
# Epoch 7/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9968 - dice_class_0: 0.9989 - dice_class_1: 0.8763 - dice_class_2: 0.8614 - dice_coef_multiclass: 0.9350 - iou_class_0: 0.9979 - iou_class_1: 0.7807 - iou_class_2: 0.7584 - iou_coef_multiclass: 0.8779 - loss: 5.3073
# Epoch 7: val_loss did not improve from 1.58456
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 435ms/step - accuracy: 0.9968 - dice_class_0: 0.9989 - dice_class_1: 0.8763 - dice_class_2: 0.8615 - dice_coef_multiclass: 0.9350 - iou_class_0: 0.9979 - iou_class_1: 0.7807 - iou_class_2: 0.7584 - iou_coef_multiclass: 0.8780 - loss: 5.3061 - val_accuracy: 0.9968 - val_dice_class_0: 0.9990 - val_dice_class_1: 0.8762 - val_dice_class_2: 0.8497 - val_dice_coef_multiclass: 0.9668 - val_iou_class_0: 0.9980 - val_iou_class_1: 0.7812 - val_iou_class_2: 0.7407 - val_iou_coef_multiclass: 0.9357 - val_loss: 7.8303 - learning_rate: 1.0000e-04
# Epoch 8/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9970 - dice_class_0: 0.9990 - dice_class_1: 0.8840 - dice_class_2: 0.8686 - dice_coef_multiclass: 0.9592 - iou_class_0: 0.9980 - iou_class_1: 0.7928 - iou_class_2: 0.7692 - iou_coef_multiclass: 0.9216 - loss: 5.2088
# Epoch 8: val_loss did not improve from 1.58456
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 435ms/step - accuracy: 0.9970 - dice_class_0: 0.9990 - dice_class_1: 0.8839 - dice_class_2: 0.8686 - dice_coef_multiclass: 0.9592 - iou_class_0: 0.9980 - iou_class_1: 0.7928 - iou_class_2: 0.7692 - iou_coef_multiclass: 0.9216 - loss: 5.2069 - val_accuracy: 0.9965 - val_dice_class_0: 0.9991 - val_dice_class_1: 0.8603 - val_dice_class_2: 0.7602 - val_dice_coef_multiclass: 0.9862 - val_iou_class_0: 0.9982 - val_iou_class_1: 0.7571 - val_iou_class_2: 0.6171 - val_iou_coef_multiclass: 0.9727 - val_loss: 5.9222 - learning_rate: 1.0000e-04
# Epoch 9/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9969 - dice_class_0: 0.9990 - dice_class_1: 0.8811 - dice_class_2: 0.8630 - dice_coef_multiclass: 0.9745 - iou_class_0: 0.9980 - iou_class_1: 0.7882 - iou_class_2: 0.7608 - iou_coef_multiclass: 0.9504 - loss: 4.3852
# Epoch 9: val_loss improved from 1.58456 to 1.35415, saving model to results/MSCA_LBFR_PPM_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 69s 462ms/step - accuracy: 0.9969 - dice_class_0: 0.9990 - dice_class_1: 0.8811 - dice_class_2: 0.8630 - dice_coef_multiclass: 0.9746 - iou_class_0: 0.9980 - iou_class_1: 0.7882 - iou_class_2: 0.7608 - iou_coef_multiclass: 0.9504 - loss: 4.3822 - val_accuracy: 0.9964 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8545 - val_dice_class_2: 0.7191 - val_dice_coef_multiclass: 0.9866 - val_iou_class_0: 0.9984 - val_iou_class_1: 0.7496 - val_iou_class_2: 0.5673 - val_iou_coef_multiclass: 0.9736 - val_loss: 1.3541 - learning_rate: 1.0000e-04
# Epoch 10/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.9973 - dice_class_0: 0.9991 - dice_class_1: 0.8925 - dice_class_2: 0.8729 - dice_coef_multiclass: 0.9861 - iou_class_0: 0.9983 - iou_class_1: 0.8067 - iou_class_2: 0.7761 - iou_coef_multiclass: 0.9725 - loss: 2.8594
# Epoch 10: val_loss improved from 1.35415 to 0.26733, saving model to results/MSCA_LBFR_PPM_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 69s 462ms/step - accuracy: 0.9973 - dice_class_0: 0.9991 - dice_class_1: 0.8925 - dice_class_2: 0.8729 - dice_coef_multiclass: 0.9861 - iou_class_0: 0.9983 - iou_class_1: 0.8067 - iou_class_2: 0.7761 - iou_coef_multiclass: 0.9725 - loss: 2.8566 - val_accuracy: 0.9974 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8952 - val_dice_class_2: 0.8546 - val_dice_coef_multiclass: 0.9943 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.8117 - val_iou_class_2: 0.7486 - val_iou_coef_multiclass: 0.9888 - val_loss: 0.2673 - learning_rate: 1.0000e-04
# Epoch 11/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9973 - dice_class_0: 0.9992 - dice_class_1: 0.8932 - dice_class_2: 0.8678 - dice_coef_multiclass: 0.9918 - iou_class_0: 0.9984 - iou_class_1: 0.8078 - iou_class_2: 0.7679 - iou_coef_multiclass: 0.9838 - loss: 1.6184
# Epoch 11: val_loss did not improve from 0.26733
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 435ms/step - accuracy: 0.9973 - dice_class_0: 0.9992 - dice_class_1: 0.8932 - dice_class_2: 0.8679 - dice_coef_multiclass: 0.9918 - iou_class_0: 0.9984 - iou_class_1: 0.8078 - iou_class_2: 0.7679 - iou_coef_multiclass: 0.9838 - loss: 1.6161 - val_accuracy: 0.9971 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8842 - val_dice_class_2: 0.8424 - val_dice_coef_multiclass: 0.9944 - val_iou_class_0: 0.9984 - val_iou_class_1: 0.7938 - val_iou_class_2: 0.7304 - val_iou_coef_multiclass: 0.9889 - val_loss: 0.3971 - learning_rate: 1.0000e-04
# Epoch 12/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.9972 - dice_class_0: 0.9992 - dice_class_1: 0.8904 - dice_class_2: 0.8740 - dice_coef_multiclass: 0.9941 - iou_class_0: 0.9983 - iou_class_1: 0.8031 - iou_class_2: 0.7773 - iou_coef_multiclass: 0.9883 - loss: 0.6205
# Epoch 12: val_loss improved from 0.26733 to 0.25206, saving model to results/MSCA_LBFR_PPM_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 69s 462ms/step - accuracy: 0.9972 - dice_class_0: 0.9992 - dice_class_1: 0.8904 - dice_class_2: 0.8740 - dice_coef_multiclass: 0.9941 - iou_class_0: 0.9983 - iou_class_1: 0.8031 - iou_class_2: 0.7774 - iou_coef_multiclass: 0.9883 - loss: 0.6200 - val_accuracy: 0.9971 - val_dice_class_0: 0.9991 - val_dice_class_1: 0.8763 - val_dice_class_2: 0.8370 - val_dice_coef_multiclass: 0.9954 - val_iou_class_0: 0.9983 - val_iou_class_1: 0.7822 - val_iou_class_2: 0.7239 - val_iou_coef_multiclass: 0.9909 - val_loss: 0.2521 - learning_rate: 1.0000e-04
# Epoch 13/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9974 - dice_class_0: 0.9992 - dice_class_1: 0.8954 - dice_class_2: 0.8798 - dice_coef_multiclass: 0.9954 - iou_class_0: 0.9984 - iou_class_1: 0.8115 - iou_class_2: 0.7867 - iou_coef_multiclass: 0.9908 - loss: 0.5092
# Epoch 13: val_loss improved from 0.25206 to 0.22627, saving model to results/MSCA_LBFR_PPM_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 69s 461ms/step - accuracy: 0.9974 - dice_class_0: 0.9992 - dice_class_1: 0.8954 - dice_class_2: 0.8798 - dice_coef_multiclass: 0.9954 - iou_class_0: 0.9984 - iou_class_1: 0.8115 - iou_class_2: 0.7867 - iou_coef_multiclass: 0.9908 - loss: 0.5087 - val_accuracy: 0.9971 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8804 - val_dice_class_2: 0.8271 - val_dice_coef_multiclass: 0.9960 - val_iou_class_0: 0.9984 - val_iou_class_1: 0.7880 - val_iou_class_2: 0.7096 - val_iou_coef_multiclass: 0.9921 - val_loss: 0.2263 - learning_rate: 1.0000e-04
# Epoch 14/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9974 - dice_class_0: 0.9992 - dice_class_1: 0.8969 - dice_class_2: 0.8760 - dice_coef_multiclass: 0.9960 - iou_class_0: 0.9985 - iou_class_1: 0.8136 - iou_class_2: 0.7808 - iou_coef_multiclass: 0.9921 - loss: 0.2877
# Epoch 14: val_loss improved from 0.22627 to 0.20574, saving model to results/MSCA_LBFR_PPM_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 69s 460ms/step - accuracy: 0.9974 - dice_class_0: 0.9992 - dice_class_1: 0.8969 - dice_class_2: 0.8760 - dice_coef_multiclass: 0.9960 - iou_class_0: 0.9985 - iou_class_1: 0.8136 - iou_class_2: 0.7808 - iou_coef_multiclass: 0.9921 - loss: 0.2877 - val_accuracy: 0.9973 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8879 - val_dice_class_2: 0.8500 - val_dice_coef_multiclass: 0.9965 - val_iou_class_0: 0.9984 - val_iou_class_1: 0.7993 - val_iou_class_2: 0.7414 - val_iou_coef_multiclass: 0.9930 - val_loss: 0.2057 - learning_rate: 1.0000e-04
# Epoch 15/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.9976 - dice_class_0: 0.9993 - dice_class_1: 0.9046 - dice_class_2: 0.8887 - dice_coef_multiclass: 0.9966 - iou_class_0: 0.9986 - iou_class_1: 0.8264 - iou_class_2: 0.8006 - iou_coef_multiclass: 0.9932 - loss: 0.3663
# Epoch 15: val_loss improved from 0.20574 to 0.19045, saving model to results/MSCA_LBFR_PPM_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 469ms/step - accuracy: 0.9976 - dice_class_0: 0.9993 - dice_class_1: 0.9046 - dice_class_2: 0.8886 - dice_coef_multiclass: 0.9966 - iou_class_0: 0.9986 - iou_class_1: 0.8264 - iou_class_2: 0.8005 - iou_coef_multiclass: 0.9932 - loss: 0.3662 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8986 - val_dice_class_2: 0.8569 - val_dice_coef_multiclass: 0.9968 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8168 - val_iou_class_2: 0.7522 - val_iou_coef_multiclass: 0.9937 - val_loss: 0.1905 - learning_rate: 1.0000e-04
# Epoch 16/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9040 - dice_class_2: 0.8859 - dice_coef_multiclass: 0.9969 - iou_class_0: 0.9986 - iou_class_1: 0.8254 - iou_class_2: 0.7962 - iou_coef_multiclass: 0.9937 - loss: 0.2193
# Epoch 16: val_loss improved from 0.19045 to 0.17065, saving model to results/MSCA_LBFR_PPM_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 69s 462ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9039 - dice_class_2: 0.8859 - dice_coef_multiclass: 0.9969 - iou_class_0: 0.9986 - iou_class_1: 0.8254 - iou_class_2: 0.7962 - iou_coef_multiclass: 0.9937 - loss: 0.2192 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9038 - val_dice_class_2: 0.8879 - val_dice_coef_multiclass: 0.9971 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8253 - val_iou_class_2: 0.8000 - val_iou_coef_multiclass: 0.9942 - val_loss: 0.1707 - learning_rate: 1.0000e-04
# Epoch 17/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9976 - dice_class_0: 0.9993 - dice_class_1: 0.9032 - dice_class_2: 0.8890 - dice_coef_multiclass: 0.9970 - iou_class_0: 0.9985 - iou_class_1: 0.8239 - iou_class_2: 0.8011 - iou_coef_multiclass: 0.9939 - loss: 0.1806
# Epoch 17: val_loss improved from 0.17065 to 0.16954, saving model to results/MSCA_LBFR_PPM_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 69s 461ms/step - accuracy: 0.9976 - dice_class_0: 0.9993 - dice_class_1: 0.9032 - dice_class_2: 0.8890 - dice_coef_multiclass: 0.9970 - iou_class_0: 0.9985 - iou_class_1: 0.8240 - iou_class_2: 0.8011 - iou_coef_multiclass: 0.9939 - loss: 0.1806 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9003 - val_dice_class_2: 0.8819 - val_dice_coef_multiclass: 0.9971 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8197 - val_iou_class_2: 0.7905 - val_iou_coef_multiclass: 0.9941 - val_loss: 0.1695 - learning_rate: 1.0000e-04
# Epoch 18/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9073 - dice_class_2: 0.8933 - dice_coef_multiclass: 0.9972 - iou_class_0: 0.9986 - iou_class_1: 0.8309 - iou_class_2: 0.8086 - iou_coef_multiclass: 0.9944 - loss: 0.1867
# Epoch 18: val_loss did not improve from 0.16954
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 435ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9073 - dice_class_2: 0.8933 - dice_coef_multiclass: 0.9972 - iou_class_0: 0.9986 - iou_class_1: 0.8308 - iou_class_2: 0.8085 - iou_coef_multiclass: 0.9944 - loss: 0.1867 - val_accuracy: 0.9975 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8960 - val_dice_class_2: 0.8616 - val_dice_coef_multiclass: 0.9970 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8131 - val_iou_class_2: 0.7595 - val_iou_coef_multiclass: 0.9941 - val_loss: 0.1850 - learning_rate: 1.0000e-04
# Epoch 19/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9054 - dice_class_2: 0.8934 - dice_coef_multiclass: 0.9972 - iou_class_0: 0.9985 - iou_class_1: 0.8277 - iou_class_2: 0.8086 - iou_coef_multiclass: 0.9944 - loss: 0.1697
# Epoch 19: val_loss did not improve from 0.16954
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 435ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9054 - dice_class_2: 0.8933 - dice_coef_multiclass: 0.9972 - iou_class_0: 0.9985 - iou_class_1: 0.8277 - iou_class_2: 0.8086 - iou_coef_multiclass: 0.9944 - loss: 0.1696 - val_accuracy: 0.9974 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8934 - val_dice_class_2: 0.8444 - val_dice_coef_multiclass: 0.9971 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8084 - val_iou_class_2: 0.7330 - val_iou_coef_multiclass: 0.9942 - val_loss: 0.1854 - learning_rate: 1.0000e-04
# Epoch 20/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9051 - dice_class_2: 0.8920 - dice_coef_multiclass: 0.9973 - iou_class_0: 0.9986 - iou_class_1: 0.8273 - iou_class_2: 0.8062 - iou_coef_multiclass: 0.9946 - loss: 0.1564
# Epoch 20: val_loss improved from 0.16954 to 0.16599, saving model to results/MSCA_LBFR_PPM_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 69s 459ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9051 - dice_class_2: 0.8920 - dice_coef_multiclass: 0.9973 - iou_class_0: 0.9986 - iou_class_1: 0.8273 - iou_class_2: 0.8062 - iou_coef_multiclass: 0.9946 - loss: 0.1564 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9040 - val_dice_class_2: 0.8655 - val_dice_coef_multiclass: 0.9974 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8259 - val_iou_class_2: 0.7651 - val_iou_coef_multiclass: 0.9947 - val_loss: 0.1660 - learning_rate: 1.0000e-04
# Epoch 21/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9103 - dice_class_2: 0.8946 - dice_coef_multiclass: 0.9975 - iou_class_0: 0.9987 - iou_class_1: 0.8360 - iou_class_2: 0.8109 - iou_coef_multiclass: 0.9949 - loss: 0.1765
# Epoch 21: val_loss improved from 0.16599 to 0.15394, saving model to results/MSCA_LBFR_PPM_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 69s 462ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9103 - dice_class_2: 0.8946 - dice_coef_multiclass: 0.9975 - iou_class_0: 0.9987 - iou_class_1: 0.8360 - iou_class_2: 0.8108 - iou_coef_multiclass: 0.9949 - loss: 0.1765 - val_accuracy: 0.9977 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9035 - val_dice_class_2: 0.8888 - val_dice_coef_multiclass: 0.9975 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8247 - val_iou_class_2: 0.8011 - val_iou_coef_multiclass: 0.9950 - val_loss: 0.1539 - learning_rate: 1.0000e-04
# Epoch 22/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9075 - dice_class_2: 0.8921 - dice_coef_multiclass: 0.9974 - iou_class_0: 0.9987 - iou_class_1: 0.8312 - iou_class_2: 0.8061 - iou_coef_multiclass: 0.9949 - loss: 0.1509
# Epoch 22: val_loss improved from 0.15394 to 0.15298, saving model to results/MSCA_LBFR_PPM_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 69s 461ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9075 - dice_class_2: 0.8921 - dice_coef_multiclass: 0.9974 - iou_class_0: 0.9987 - iou_class_1: 0.8312 - iou_class_2: 0.8061 - iou_coef_multiclass: 0.9949 - loss: 0.1508 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9109 - val_dice_class_2: 0.8777 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8369 - val_iou_class_2: 0.7844 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1530 - learning_rate: 1.0000e-04
# Epoch 23/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9064 - dice_class_2: 0.8919 - dice_coef_multiclass: 0.9974 - iou_class_0: 0.9986 - iou_class_1: 0.8294 - iou_class_2: 0.8067 - iou_coef_multiclass: 0.9948 - loss: 0.1607
# Epoch 23: val_loss did not improve from 0.15298
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 435ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9064 - dice_class_2: 0.8919 - dice_coef_multiclass: 0.9974 - iou_class_0: 0.9986 - iou_class_1: 0.8294 - iou_class_2: 0.8066 - iou_coef_multiclass: 0.9948 - loss: 0.1608 - val_accuracy: 0.9975 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8955 - val_dice_class_2: 0.8678 - val_dice_coef_multiclass: 0.9973 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8125 - val_iou_class_2: 0.7690 - val_iou_coef_multiclass: 0.9946 - val_loss: 0.1654 - learning_rate: 1.0000e-04
# Epoch 24/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9068 - dice_class_2: 0.8950 - dice_coef_multiclass: 0.9974 - iou_class_0: 0.9986 - iou_class_1: 0.8300 - iou_class_2: 0.8110 - iou_coef_multiclass: 0.9949 - loss: 0.1489
# Epoch 24: val_loss improved from 0.15298 to 0.15159, saving model to results/MSCA_LBFR_PPM_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 69s 461ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9068 - dice_class_2: 0.8950 - dice_coef_multiclass: 0.9974 - iou_class_0: 0.9986 - iou_class_1: 0.8300 - iou_class_2: 0.8110 - iou_coef_multiclass: 0.9949 - loss: 0.1489 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9034 - val_dice_class_2: 0.8847 - val_dice_coef_multiclass: 0.9975 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8245 - val_iou_class_2: 0.7948 - val_iou_coef_multiclass: 0.9951 - val_loss: 0.1516 - learning_rate: 1.0000e-04
# Epoch 25/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9074 - dice_class_2: 0.8939 - dice_coef_multiclass: 0.9975 - iou_class_0: 0.9986 - iou_class_1: 0.8312 - iou_class_2: 0.8095 - iou_coef_multiclass: 0.9949 - loss: 0.1476
# Epoch 25: val_loss improved from 0.15159 to 0.14660, saving model to results/MSCA_LBFR_PPM_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 69s 460ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9075 - dice_class_2: 0.8939 - dice_coef_multiclass: 0.9975 - iou_class_0: 0.9986 - iou_class_1: 0.8312 - iou_class_2: 0.8095 - iou_coef_multiclass: 0.9949 - loss: 0.1476 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9079 - val_dice_class_2: 0.8912 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8322 - val_iou_class_2: 0.8054 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1466 - learning_rate: 1.0000e-04
# Epoch 26/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9084 - dice_class_2: 0.8941 - dice_coef_multiclass: 0.9975 - iou_class_0: 0.9986 - iou_class_1: 0.8327 - iou_class_2: 0.8098 - iou_coef_multiclass: 0.9951 - loss: 0.1450
# Epoch 26: val_loss did not improve from 0.14660
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 435ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9084 - dice_class_2: 0.8941 - dice_coef_multiclass: 0.9975 - iou_class_0: 0.9986 - iou_class_1: 0.8327 - iou_class_2: 0.8098 - iou_coef_multiclass: 0.9951 - loss: 0.1450 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9032 - val_dice_class_2: 0.8874 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8240 - val_iou_class_2: 0.7985 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1516 - learning_rate: 1.0000e-04
# Epoch 27/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9118 - dice_class_2: 0.8998 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9986 - iou_class_1: 0.8384 - iou_class_2: 0.8188 - iou_coef_multiclass: 0.9953 - loss: 0.1391
# Epoch 27: val_loss did not improve from 0.14660
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 434ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9118 - dice_class_2: 0.8998 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9986 - iou_class_1: 0.8384 - iou_class_2: 0.8188 - iou_coef_multiclass: 0.9953 - loss: 0.1391 - val_accuracy: 0.9977 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9032 - val_dice_class_2: 0.8855 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8250 - val_iou_class_2: 0.7964 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1511 - learning_rate: 1.0000e-04
# Epoch 28/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9092 - dice_class_2: 0.8971 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9986 - iou_class_1: 0.8340 - iou_class_2: 0.8144 - iou_coef_multiclass: 0.9951 - loss: 0.1517
# Epoch 28: val_loss improved from 0.14660 to 0.14085, saving model to results/MSCA_LBFR_PPM_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 69s 460ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9093 - dice_class_2: 0.8971 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9986 - iou_class_1: 0.8340 - iou_class_2: 0.8144 - iou_coef_multiclass: 0.9951 - loss: 0.1517 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9099 - val_dice_class_2: 0.8955 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8352 - val_iou_class_2: 0.8122 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1409 - learning_rate: 1.0000e-04
# Epoch 29/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9128 - dice_class_2: 0.9007 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9987 - iou_class_1: 0.8401 - iou_class_2: 0.8206 - iou_coef_multiclass: 0.9954 - loss: 0.1376
# Epoch 29: val_loss did not improve from 0.14085
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 435ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9128 - dice_class_2: 0.9007 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9987 - iou_class_1: 0.8401 - iou_class_2: 0.8206 - iou_coef_multiclass: 0.9954 - loss: 0.1376 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9109 - val_dice_class_2: 0.8927 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8371 - val_iou_class_2: 0.8073 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1414 - learning_rate: 1.0000e-04
# Epoch 30/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9143 - dice_class_2: 0.9087 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9987 - iou_class_1: 0.8426 - iou_class_2: 0.8337 - iou_coef_multiclass: 0.9954 - loss: 0.1303
# Epoch 30: val_loss did not improve from 0.14085
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 435ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9143 - dice_class_2: 0.9087 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9987 - iou_class_1: 0.8425 - iou_class_2: 0.8336 - iou_coef_multiclass: 0.9954 - loss: 0.1304 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8999 - val_dice_class_2: 0.8821 - val_dice_coef_multiclass: 0.9975 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8188 - val_iou_class_2: 0.7903 - val_iou_coef_multiclass: 0.9949 - val_loss: 0.1534 - learning_rate: 1.0000e-04
# Epoch 31/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9127 - dice_class_2: 0.8996 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9987 - iou_class_1: 0.8399 - iou_class_2: 0.8183 - iou_coef_multiclass: 0.9954 - loss: 0.1376
# Epoch 31: val_loss did not improve from 0.14085
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 435ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9127 - dice_class_2: 0.8996 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9987 - iou_class_1: 0.8399 - iou_class_2: 0.8183 - iou_coef_multiclass: 0.9954 - loss: 0.1376 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9076 - val_dice_class_2: 0.8951 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8312 - val_iou_class_2: 0.8112 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1504 - learning_rate: 1.0000e-04
# Epoch 32/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9979 - dice_class_0: 0.9994 - dice_class_1: 0.9162 - dice_class_2: 0.9056 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9987 - iou_class_1: 0.8457 - iou_class_2: 0.8283 - iou_coef_multiclass: 0.9956 - loss: 0.1377
# Epoch 32: val_loss did not improve from 0.14085
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 435ms/step - accuracy: 0.9979 - dice_class_0: 0.9994 - dice_class_1: 0.9162 - dice_class_2: 0.9056 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9987 - iou_class_1: 0.8457 - iou_class_2: 0.8283 - iou_coef_multiclass: 0.9956 - loss: 0.1377 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9025 - val_dice_class_2: 0.8874 - val_dice_coef_multiclass: 0.9975 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8231 - val_iou_class_2: 0.7998 - val_iou_coef_multiclass: 0.9951 - val_loss: 0.1497 - learning_rate: 1.0000e-04
# Epoch 33/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9131 - dice_class_2: 0.9006 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9987 - iou_class_1: 0.8405 - iou_class_2: 0.8207 - iou_coef_multiclass: 0.9954 - loss: 0.1342
# Epoch 33: val_loss did not improve from 0.14085
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 434ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9131 - dice_class_2: 0.9007 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9987 - iou_class_1: 0.8406 - iou_class_2: 0.8208 - iou_coef_multiclass: 0.9954 - loss: 0.1342 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9068 - val_dice_class_2: 0.8964 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8301 - val_iou_class_2: 0.8133 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1420 - learning_rate: 5.0000e-05
# Epoch 34/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9182 - dice_class_2: 0.9095 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9987 - iou_class_1: 0.8493 - iou_class_2: 0.8350 - iou_coef_multiclass: 0.9957 - loss: 0.1259
# Epoch 34: val_loss did not improve from 0.14085
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 434ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9182 - dice_class_2: 0.9095 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9987 - iou_class_1: 0.8492 - iou_class_2: 0.8350 - iou_coef_multiclass: 0.9957 - loss: 0.1259 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9080 - val_dice_class_2: 0.8893 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8321 - val_iou_class_2: 0.8023 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1443 - learning_rate: 5.0000e-05
# Epoch 35/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9184 - dice_class_2: 0.9085 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9987 - iou_class_1: 0.8495 - iou_class_2: 0.8333 - iou_coef_multiclass: 0.9957 - loss: 0.1268
# Epoch 35: val_loss improved from 0.14085 to 0.13879, saving model to results/MSCA_LBFR_PPM_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 69s 461ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9184 - dice_class_2: 0.9085 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9987 - iou_class_1: 0.8495 - iou_class_2: 0.8333 - iou_coef_multiclass: 0.9957 - loss: 0.1267 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9122 - val_dice_class_2: 0.8983 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8392 - val_iou_class_2: 0.8165 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1388 - learning_rate: 5.0000e-05
# Epoch 36/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9179 - dice_class_2: 0.9078 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9987 - iou_class_1: 0.8486 - iou_class_2: 0.8318 - iou_coef_multiclass: 0.9957 - loss: 0.1268
# Epoch 36: val_loss improved from 0.13879 to 0.13630, saving model to results/MSCA_LBFR_PPM_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 69s 460ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9179 - dice_class_2: 0.9078 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9987 - iou_class_1: 0.8486 - iou_class_2: 0.8319 - iou_coef_multiclass: 0.9957 - loss: 0.1268 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9117 - val_dice_class_2: 0.8982 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8385 - val_iou_class_2: 0.8173 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1363 - learning_rate: 5.0000e-05
# Epoch 37/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9144 - dice_class_2: 0.9072 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9987 - iou_class_1: 0.8430 - iou_class_2: 0.8311 - iou_coef_multiclass: 0.9955 - loss: 0.1293
# Epoch 37: val_loss did not improve from 0.13630
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 435ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9144 - dice_class_2: 0.9072 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9987 - iou_class_1: 0.8430 - iou_class_2: 0.8311 - iou_coef_multiclass: 0.9955 - loss: 0.1293 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9106 - val_dice_class_2: 0.8848 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8365 - val_iou_class_2: 0.7950 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1435 - learning_rate: 5.0000e-05
# Epoch 38/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9206 - dice_class_2: 0.9151 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8532 - iou_class_2: 0.8443 - iou_coef_multiclass: 0.9958 - loss: 0.1215
# Epoch 38: val_loss did not improve from 0.13630
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 434ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9206 - dice_class_2: 0.9151 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8532 - iou_class_2: 0.8443 - iou_coef_multiclass: 0.9958 - loss: 0.1215 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9128 - val_dice_class_2: 0.8882 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8402 - val_iou_class_2: 0.8012 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1468 - learning_rate: 5.0000e-05
# Epoch 39/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9212 - dice_class_2: 0.9126 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9988 - iou_class_1: 0.8543 - iou_class_2: 0.8402 - iou_coef_multiclass: 0.9958 - loss: 0.1206
# Epoch 39: val_loss did not improve from 0.13630
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 435ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9212 - dice_class_2: 0.9126 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9988 - iou_class_1: 0.8543 - iou_class_2: 0.8402 - iou_coef_multiclass: 0.9958 - loss: 0.1207 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9135 - val_dice_class_2: 0.8918 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8413 - val_iou_class_2: 0.8064 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1371 - learning_rate: 5.0000e-05
# Epoch 40/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9184 - dice_class_2: 0.9091 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8495 - iou_class_2: 0.8341 - iou_coef_multiclass: 0.9957 - loss: 0.1255
# Epoch 40: val_loss did not improve from 0.13630
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 435ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9184 - dice_class_2: 0.9091 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8495 - iou_class_2: 0.8341 - iou_coef_multiclass: 0.9957 - loss: 0.1255 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9131 - val_dice_class_2: 0.9000 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8406 - val_iou_class_2: 0.8198 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1573 - learning_rate: 5.0000e-05
# Epoch 41/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9230 - dice_class_2: 0.9131 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8574 - iou_class_2: 0.8412 - iou_coef_multiclass: 0.9959 - loss: 0.1207
# Epoch 41: val_loss improved from 0.13630 to 0.13421, saving model to results/MSCA_LBFR_PPM_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 69s 461ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9230 - dice_class_2: 0.9131 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8574 - iou_class_2: 0.8413 - iou_coef_multiclass: 0.9959 - loss: 0.1207 - val_accuracy: 0.9980 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9134 - val_dice_class_2: 0.8997 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8413 - val_iou_class_2: 0.8192 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1342 - learning_rate: 2.5000e-05
# Epoch 42/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9243 - dice_class_2: 0.9175 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8595 - iou_class_2: 0.8484 - iou_coef_multiclass: 0.9960 - loss: 0.1157
# Epoch 42: val_loss did not improve from 0.13421
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 435ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9243 - dice_class_2: 0.9175 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8595 - iou_class_2: 0.8484 - iou_coef_multiclass: 0.9960 - loss: 0.1158 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9103 - val_dice_class_2: 0.8949 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8361 - val_iou_class_2: 0.8116 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1509 - learning_rate: 2.5000e-05
# Epoch 43/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9226 - dice_class_2: 0.9088 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8568 - iou_class_2: 0.8342 - iou_coef_multiclass: 0.9959 - loss: 0.1220
# Epoch 43: val_loss improved from 0.13421 to 0.13292, saving model to results/MSCA_LBFR_PPM_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 69s 462ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9226 - dice_class_2: 0.9089 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8568 - iou_class_2: 0.8343 - iou_coef_multiclass: 0.9959 - loss: 0.1220 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9157 - val_dice_class_2: 0.8996 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8452 - val_iou_class_2: 0.8189 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1329 - learning_rate: 2.5000e-05
# Epoch 44/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9209 - dice_class_2: 0.9184 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8538 - iou_class_2: 0.8498 - iou_coef_multiclass: 0.9959 - loss: 0.1177
# Epoch 44: val_loss did not improve from 0.13292
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 436ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9209 - dice_class_2: 0.9184 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8538 - iou_class_2: 0.8498 - iou_coef_multiclass: 0.9959 - loss: 0.1177 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9107 - val_dice_class_2: 0.8935 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8369 - val_iou_class_2: 0.8095 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1394 - learning_rate: 2.5000e-05
# Epoch 45/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9220 - dice_class_2: 0.9182 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9987 - iou_class_1: 0.8556 - iou_class_2: 0.8497 - iou_coef_multiclass: 0.9959 - loss: 0.1158
# Epoch 45: val_loss did not improve from 0.13292
# ...
# Epoch 70/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9271 - dice_class_2: 0.9247 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8644 - iou_class_2: 0.8605 - iou_coef_multiclass: 0.9962 - loss: 0.1092
# Epoch 70: val_loss did not improve from 0.12653
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 434ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9271 - dice_class_2: 0.9247 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8644 - iou_class_2: 0.8605 - iou_coef_multiclass: 0.9962 - loss: 0.1091 - val_accuracy: 0.9980 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9160 - val_dice_class_2: 0.8965 - val_dice_coef_multiclass: 0.9979 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8455 - val_iou_class_2: 0.8136 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1337 - learning_rate: 1.5625e-06
# Epoch 71/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9277 - dice_class_2: 0.9267 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9989 - iou_class_1: 0.8654 - iou_class_2: 0.8639 - iou_coef_multiclass: 0.9963 - loss: 0.1073
# Epoch 71: val_loss did not improve from 0.12653
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 434ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9277 - dice_class_2: 0.9267 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9989 - iou_class_1: 0.8654 - iou_class_2: 0.8638 - iou_coef_multiclass: 0.9963 - loss: 0.1073 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9121 - val_dice_class_2: 0.9027 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8393 - val_iou_class_2: 0.8236 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1345 - learning_rate: 1.5625e-06
# Epoch 72/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9270 - dice_class_2: 0.9223 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8643 - iou_class_2: 0.8565 - iou_coef_multiclass: 0.9962 - loss: 0.1101
# Epoch 72: val_loss did not improve from 0.12653
#
# Epoch 72: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 434ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9270 - dice_class_2: 0.9223 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8643 - iou_class_2: 0.8566 - iou_coef_multiclass: 0.9962 - loss: 0.1101 - val_accuracy: 0.9980 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9148 - val_dice_class_2: 0.8985 - val_dice_coef_multiclass: 0.9979 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8435 - val_iou_class_2: 0.8169 - val_iou_coef_multiclass: 0.9958 - val_loss: 0.1339 - learning_rate: 1.5625e-06
# Epoch 73/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9270 - dice_class_2: 0.9257 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8644 - iou_class_2: 0.8622 - iou_coef_multiclass: 0.9962 - loss: 0.1086
# Epoch 73: val_loss improved from 0.12653 to 0.12530, saving model to results/MSCA_LBFR_PPM_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 69s 459ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9270 - dice_class_2: 0.9257 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8644 - iou_class_2: 0.8622 - iou_coef_multiclass: 0.9962 - loss: 0.1086 - val_accuracy: 0.9980 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9186 - val_dice_class_2: 0.9056 - val_dice_coef_multiclass: 0.9979 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8500 - val_iou_class_2: 0.8288 - val_iou_coef_multiclass: 0.9959 - val_loss: 0.1253 - learning_rate: 7.8125e-07
# Epoch 74/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9285 - dice_class_2: 0.9262 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9989 - iou_class_1: 0.8668 - iou_class_2: 0.8630 - iou_coef_multiclass: 0.9963 - loss: 0.1068
# Epoch 74: val_loss did not improve from 0.12530
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 434ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9285 - dice_class_2: 0.9262 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9989 - iou_class_1: 0.8668 - iou_class_2: 0.8630 - iou_coef_multiclass: 0.9963 - loss: 0.1068 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9150 - val_dice_class_2: 0.8977 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8439 - val_iou_class_2: 0.8158 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1350 - learning_rate: 7.8125e-07
# Epoch 75/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9260 - dice_class_2: 0.9261 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8625 - iou_class_2: 0.8632 - iou_coef_multiclass: 0.9962 - loss: 0.1095
# Epoch 75: val_loss did not improve from 0.12530
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 433ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9260 - dice_class_2: 0.9261 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8625 - iou_class_2: 0.8632 - iou_coef_multiclass: 0.9962 - loss: 0.1095 - val_accuracy: 0.9980 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9155 - val_dice_class_2: 0.9002 - val_dice_coef_multiclass: 0.9979 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8449 - val_iou_class_2: 0.8198 - val_iou_coef_multiclass: 0.9958 - val_loss: 0.1320 - learning_rate: 7.8125e-07
# Epoch 76/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9261 - dice_class_2: 0.9257 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8627 - iou_class_2: 0.8625 - iou_coef_multiclass: 0.9962 - loss: 0.1093
# Epoch 76: val_loss did not improve from 0.12530
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 434ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9261 - dice_class_2: 0.9257 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8627 - iou_class_2: 0.8625 - iou_coef_multiclass: 0.9962 - loss: 0.1093 - val_accuracy: 0.9981 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9182 - val_dice_class_2: 0.9076 - val_dice_coef_multiclass: 0.9980 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8492 - val_iou_class_2: 0.8317 - val_iou_coef_multiclass: 0.9959 - val_loss: 0.1269 - learning_rate: 7.8125e-07
# Epoch 77/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9261 - dice_class_2: 0.9282 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8628 - iou_class_2: 0.8666 - iou_coef_multiclass: 0.9962 - loss: 0.1077
# Epoch 77: val_loss did not improve from 0.12530
#
# Epoch 77: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 434ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9261 - dice_class_2: 0.9282 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8628 - iou_class_2: 0.8666 - iou_coef_multiclass: 0.9962 - loss: 0.1077 - val_accuracy: 0.9980 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9147 - val_dice_class_2: 0.8988 - val_dice_coef_multiclass: 0.9979 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8438 - val_iou_class_2: 0.8179 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1333 - learning_rate: 7.8125e-07
# Epoch 78/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9272 - dice_class_2: 0.9237 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8646 - iou_class_2: 0.8588 - iou_coef_multiclass: 0.9962 - loss: 0.1097
# Epoch 78: val_loss did not improve from 0.12530
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 434ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9272 - dice_class_2: 0.9237 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8646 - iou_class_2: 0.8588 - iou_coef_multiclass: 0.9962 - loss: 0.1096 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9136 - val_dice_class_2: 0.8956 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8417 - val_iou_class_2: 0.8123 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1363 - learning_rate: 3.9062e-07
# Epoch 79/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9296 - dice_class_2: 0.9276 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8687 - iou_class_2: 0.8656 - iou_coef_multiclass: 0.9963 - loss: 0.1058
# Epoch 79: val_loss did not improve from 0.12530
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 433ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9295 - dice_class_2: 0.9276 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8687 - iou_class_2: 0.8656 - iou_coef_multiclass: 0.9963 - loss: 0.1058 - val_accuracy: 0.9980 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9150 - val_dice_class_2: 0.9006 - val_dice_coef_multiclass: 0.9979 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8438 - val_iou_class_2: 0.8202 - val_iou_coef_multiclass: 0.9958 - val_loss: 0.1309 - learning_rate: 3.9062e-07
# Epoch 80/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9272 - dice_class_2: 0.9281 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8646 - iou_class_2: 0.8664 - iou_coef_multiclass: 0.9962 - loss: 0.1070
# Epoch 80: val_loss did not improve from 0.12530
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 65s 433ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9272 - dice_class_2: 0.9280 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8646 - iou_class_2: 0.8664 - iou_coef_multiclass: 0.9962 - loss: 0.1070 - val_accuracy: 0.9980 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9172 - val_dice_class_2: 0.9011 - val_dice_coef_multiclass: 0.9979 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8476 - val_iou_class_2: 0.8215 - val_iou_coef_multiclass: 0.9958 - val_loss: 0.1315 - learning_rate: 3.9062e-07
# Restoring model weights from the end of the best epoch: 73.
# ✓ Training completed
#
# Generating visualizations...
#   ✓ Saved: results/MSCA_LBFR_PPM_GlaucomaScoring_history.png
#   ✓ Saved: results/MSCA_LBFR_PPM_GlaucomaScoring_predictions_cdr.png
# ================================================================================
# EVALUATION: MSCA+LBFR+PPM+GlaucomaScoring
# ================================================================================
#
# Saving all 400 test predictions to results/MSCA+LBFR+PPM+GlaucomaScoring_all_preds...
#   Processed 50/400
#   Processed 100/400
#   Processed 150/400
#   Processed 200/400
#   Processed 250/400
#   Processed 300/400
#   Processed 350/400
#   Processed 400/400
# ✓ Saved comparison masks to results/MSCA+LBFR+PPM+GlaucomaScoring_all_preds
#   ✓ Saved: results/MSCA+LBFR+PPM+GlaucomaScoring_confusion_matrices.png
# Confusion Matrix:
# [[103069493     68255         0]
#  [    56197   1169781     34479]
#  [        1     53505    405889]]
#
# Normalized Confusion Matrix:
# [[0.999 0.001 0.   ]
#  [0.045 0.928 0.027]
#  [0.    0.116 0.884]]
#
# Precision, Recall, F1 Score per class:
#   Background: Precision=0.9995, Recall=0.9993, F1=0.9994
#   Disc: Precision=0.9057, Recall=0.9281, F1=0.9168
#   Cup: Precision=0.9217, Recall=0.8835, F1=0.9022
#
# Macro-averaged metrics:
#   Precision: 0.9423
#   Recall: 0.9370
#   F1 Score: 0.9395
#   Background: Dice=0.9994, IoU=0.9988
#   Disc: Dice=0.9168, IoU=0.8463
#   Cup: Dice=0.9022, IoU=0.8218
#
# ================================================================================
# GLAUCOMA PROGRESSION ANALYSIS (Using Area-based CDR)
# ================================================================================
#
# --------------------------------------------------------------------------------
# CDR Statistics:
# --------------------------------------------------------------------------------
#   Mean GT CDR:   0.5984 ± 0.1782
#   Mean Pred CDR: 0.5759 ± 0.1522
#   Mean CDR Error: 0.0585 ± 0.0688
#
# ================================================================================
# PROGRESSION CLASSIFICATION ACCURACY
# ================================================================================
#
# Overall Accuracy: 80.75%
#   - Correctly Classified: 323/400 samples
#   - Incorrectly Classified: 77/400 samples
#
# --------------------------------------------------------------------------------
# Per-Class Results:
# --------------------------------------------------------------------------------
# Severity     GT Count     Pred Count   Correct      Accuracy
# --------------------------------------------------------------------------------
# Normal       0            0            0            0.00        %
# Suspect      257          282          238          92.61       %
# Moderate     106          89           60           56.60       %
# Critical     37           29           25           67.57       %
#
# ================================================================================
# INTERPRETATION EXAMPLE:
# ================================================================================
#   - GT says 'Normal' for 0 images
#   - Model says 'Normal' for 0 images
#   - Model correctly predicts 0 as 'Normal'
#   - Accuracy for Normal class: 0/0 = 0.0%
#
# ================================================================================
# MANUAL REVIEW RECOMMENDATIONS
# ================================================================================
#
# Samples Requiring Manual Review: 102/400 (25.5%)
#
# Criteria for Manual Review:
#   1. All Critical cases (high-risk, requires expert verification)
#   2. Classification mismatches (GT ≠ Predicted severity)
#
# Reason: Critical cases need expert confirmation, and mismatches may
# indicate borderline cases or segmentation issues requiring review.
#
# Breakdown:
#   - Critical cases: 37 samples
#   - Classification mismatches: 77 samples
#   - Overlap (Critical + Mismatch): 12 samples
#
# ✓ Saved: results/glaucoma_progression_analysis.csv
#   ✓ Saved: results/cdr_analysis.png
# ================================================================================
# MC DROPOUT UNCERTAINTY ESTIMATION
# ================================================================================
#
# Running MC Dropout with 15 stochastic forward passes...
#   Completed: 5/15 forward passes
#   Completed: 10/15 forward passes
#   Completed: 15/15 forward passes
# ✓ MC Dropout completed
#   Background uncertainty: 0.0003
#   Disc uncertainty: 0.0003
#   Cup uncertainty: 0.0001
#
# ====================================================================================================
#                                 ✓ TRAINING AND EVALUATION COMPLETED!
# ====================================================================================================
#
# Model: MSCA + LBFR + PPM + Focal + EIoU + MC Dropout + Glaucoma Scoring
# Parameters: 47,631,627
# Results saved in: results/
#
# Generated Files:
#   - Training history: results/MSCA_LBFR_PPM_GlaucomaScoring_history.png
#   - Predictions with CDR: results/MSCA_LBFR_PPM_GlaucomaScoring_predictions_cdr.png
#   - CDR Analysis: results/cdr_analysis.png
#   - Progression CSV: results/glaucoma_progression_analysis.csv
#   - Confusion Matrices: results/MSCA+LBFR+PPM+GlaucomaScoring_confusion_matrices.png
#
# ====================================================================================================
