# %%
"""
V8: ENHANCED ONLINE AUGMENTATION + POST-PROCESSING + TTA (Phases 1-3)
====================================================================
Based on V5 (best model) with three enhancement phases:

Phase 1 — Enhanced Online Augmentation:
  - NO offline augmentation (keeps ~600 training images = same ~1hr training time)
  - Stronger ONLINE augmentation (matching MBG-Net / GDCSeg-Net)
  - ROI padding factor: 1.2× (same as V5 — proven to work well)

Phase 2 — Post-Processing (on-the-go during evaluation):
  - Largest connected component selection
  - Morphological closing (hole filling)
  - Contour-based hole filling
  - Median filter for smoother boundaries
  - Anatomical constraint: cup ⊂ disc

Phase 3 — Test-Time Augmentation:
  - 4-pass flip ensemble (orig, hflip, vflip, both)
  - Average softmax → argmax → post-process

Training config UNCHANGED from V5:
  - Adam lr=2e-4, ReduceLROnPlateau, 80 epochs, patience=15
  - Focal loss alpha=[0.25, 1.0, 1.0] + Enhanced IoU
  - No label smoothing, no cosine annealing

Architecture UNCHANGED:
  - MobileNetV2 encoder + Deeper Decoder
  - MSCA + LBFR + PPM triple attention (12 modules)
  - MC Dropout (15 forward passes)
"""

import os
import gc
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import albumentations as A
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, backend as K
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
from PIL import Image
import cv2

warnings.filterwarnings('ignore')

# Set plot style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# ============================================================================
# GPU CONFIGURATION
# ============================================================================

def configure_gpu():
    """Configure GPU settings for optimal performance"""
    print("Configuring GPU settings...")
    physical_devices = tf.config.list_physical_devices('GPU')
    if physical_devices:
        try:
            for device in physical_devices:
                tf.config.experimental.set_memory_growth(device, True)
            print(f"✓ GPU configured: {len(physical_devices)} device(s) available")
            return True
        except RuntimeError as e:
            print(f"GPU configuration error: {e}")
            return False
    else:
        print("⚠ No GPU detected, running on CPU")
        return False

# ============================================================================
# DATA LOADING
# ============================================================================

def load_images_masks(images_folder, masks_folder, img_size=(512,512)):
    """Load images and masks from folders"""
    images, masks = [], []
    image_files = sorted(os.listdir(images_folder))
    mask_files = sorted(os.listdir(masks_folder))
    mask_dict = {os.path.splitext(f)[0]: f for f in mask_files}
    
    for img_file in image_files:
        img_path = os.path.join(images_folder, img_file)
        img = np.array(Image.open(img_path).resize(img_size)) / 255.0
        images.append(img)
        
        img_name = os.path.splitext(img_file)[0]
        if img_name in mask_dict:
            mask_path = os.path.join(masks_folder, mask_dict[img_name])
            mask = np.array(Image.open(mask_path).resize(img_size, Image.NEAREST))
            masks.append(mask)
        else:
            print(f"Warning: No mask found for {img_file}")
    
    return np.array(images, dtype=np.float32), np.array(masks, dtype=np.uint8)

def load_all_data(root_dir):
    """Load all data from existing splits and merge"""
    all_images, all_masks = [], []
    for split in ["train", "val", "test"]:
        print(f"Loading {split} data...")
        imgs, msks = load_images_masks(
            os.path.join(root_dir, split, "Images"),
            os.path.join(root_dir, split, "Masks")
        )
        all_images.append(imgs)
        all_masks.append(msks)
        print(f"  {split}: {imgs.shape[0]} samples")
    
    all_images = np.concatenate(all_images, axis=0)
    all_masks = np.concatenate(all_masks, axis=0)
    return all_images, all_masks

def create_new_split(all_images, all_masks):
    """Create new split: 600 train, 200 val, 400 test"""
    X_temp, X_test, y_temp, y_test = train_test_split(
        all_images, all_masks, test_size=400, random_state=42
    )
    X_train, X_val, y_train, y_val = train_test_split(
        X_temp, y_temp, test_size=200, random_state=42
    )
    print(f"Split - Train: {X_train.shape[0]}, Val: {X_val.shape[0]}, Test: {X_test.shape[0]}")
    return (X_train, y_train), (X_val, y_val), (X_test, y_test)


def load_all_data_with_highres_roi(root_dir, roi_size=(512, 512), padding_factor=1.2):
    """
    Load images at ORIGINAL resolution, extract ROI, resize to roi_size.
    
    Padding factor=1.2 (same as V5 — proven to give best disc Dice).
    1.2× gives 20% margin around the disc bounding box.
    """
    all_roi_images, all_roi_masks, all_full_masks_512 = [], [], []
    
    for split in ["train", "val", "test"]:
        images_folder = os.path.join(root_dir, split, "Images")
        masks_folder = os.path.join(root_dir, split, "Masks")
        image_files = sorted(os.listdir(images_folder))
        mask_files = sorted(os.listdir(masks_folder))
        mask_dict = {os.path.splitext(f)[0]: f for f in mask_files}
        
        count = 0
        for img_file in image_files:
            img_name = os.path.splitext(img_file)[0]
            if img_name not in mask_dict:
                continue
            
            # Load at ORIGINAL resolution
            img_highres = np.array(Image.open(
                os.path.join(images_folder, img_file))) / 255.0
            mask_highres = np.array(Image.open(
                os.path.join(masks_folder, mask_dict[img_name])))
            
            # Extract ROI from HIGH-RES image
            roi_img, roi_msk, _ = extract_roi(
                img_highres, mask_highres, padding_factor, roi_size)
            
            all_roi_images.append(roi_img)
            all_roi_masks.append(roi_msk)
            
            # Save 512x512 full mask for CDR evaluation
            full_msk_512 = np.array(Image.fromarray(
                mask_highres).resize((512, 512), Image.NEAREST))
            all_full_masks_512.append(full_msk_512)
            
            # Free high-res data immediately
            del img_highres, mask_highres
            count += 1
        
        print(f"  {split}: {count} samples (original resolution -> ROI extracted)")
    
    return (np.array(all_roi_images, dtype=np.float32),
            np.array(all_roi_masks, dtype=np.uint8),
            np.array(all_full_masks_512, dtype=np.uint8))

# ============================================================================
# ROI EXTRACTION
# ============================================================================

def find_disc_region(mask, disc_class=1, cup_class=2):
    """
    Find the bounding box of the optic disc+cup region from a segmentation mask.
    
    Args:
        mask: Segmentation mask (H, W) with class labels
        disc_class: Class label for optic disc (default=1)
        cup_class: Class label for optic cup (default=2)
    
    Returns:
        (center_y, center_x, radius) or None if no disc found
    """
    # Use both disc and cup pixels to define the ROI region
    roi_mask = ((mask == disc_class) | (mask == cup_class)).astype(np.uint8)
    
    if roi_mask.sum() == 0:
        return None
    
    coords = np.where(roi_mask > 0)
    y_min, y_max = coords[0].min(), coords[0].max()
    x_min, x_max = coords[1].min(), coords[1].max()
    
    center_y = (y_min + y_max) // 2
    center_x = (x_min + x_max) // 2
    
    height = y_max - y_min
    width = x_max - x_min
    radius = max(height, width) // 2
    
    return center_y, center_x, radius


def extract_roi(image, mask, padding_factor=1.2, roi_size=(512, 512)):
    """
    Extract ROI around the optic disc from image and mask.
    
    Padding factor=1.2 (same as V5).
    """
    result = find_disc_region(mask)
    
    if result is None:
        # No disc found — return the full image (fallback)
        h, w = image.shape[:2]
        return image.copy(), mask.copy(), (0, 0, h, w)
    
    center_y, center_x, radius = result
    h, w = image.shape[:2]
    
    # Expand ROI with padding factor; enforce a minimum size
    roi_half = int(radius * padding_factor)
    roi_half = max(roi_half, 60)  # minimum half-size to avoid too-small crops
    
    # Calculate crop bounds (keep square, clamp to image boundaries)
    y1 = max(0, center_y - roi_half)
    y2 = min(h, center_y + roi_half)
    x1 = max(0, center_x - roi_half)
    x2 = min(w, center_x + roi_half)
    
    # Make the crop square by expanding the shorter side if possible
    crop_h = y2 - y1
    crop_w = x2 - x1
    if crop_h > crop_w:
        diff = crop_h - crop_w
        x1 = max(0, x1 - diff // 2)
        x2 = min(w, x1 + crop_h)
        x1 = max(0, x2 - crop_h)  # re-adjust if x2 hit boundary
    elif crop_w > crop_h:
        diff = crop_w - crop_h
        y1 = max(0, y1 - diff // 2)
        y2 = min(h, y1 + crop_w)
        y1 = max(0, y2 - crop_w)  # re-adjust if y2 hit boundary
    
    # Crop
    roi_image = image[y1:y2, x1:x2]
    roi_mask = mask[y1:y2, x1:x2]
    
    # Resize to model input size
    roi_image_pil = Image.fromarray((roi_image * 255).astype(np.uint8))
    roi_image_resized = np.array(roi_image_pil.resize(roi_size, Image.BILINEAR)) / 255.0
    
    roi_mask_pil = Image.fromarray(roi_mask)
    roi_mask_resized = np.array(roi_mask_pil.resize(roi_size, Image.NEAREST))
    
    return roi_image_resized.astype(np.float32), roi_mask_resized.astype(np.uint8), (y1, x1, y2, x2)


def extract_roi_batch(images, masks, padding_factor=1.2, roi_size=(512, 512)):
    """Extract ROI for an entire batch of images and masks."""
    roi_images, roi_masks, roi_coords_list = [], [], []
    
    for i in range(len(images)):
        roi_img, roi_msk, coords = extract_roi(
            images[i], masks[i], padding_factor=padding_factor, roi_size=roi_size
        )
        roi_images.append(roi_img)
        roi_masks.append(roi_msk)
        roi_coords_list.append(coords)
    
    return (np.array(roi_images, dtype=np.float32),
            np.array(roi_masks, dtype=np.uint8),
            roi_coords_list)


def map_roi_prediction_to_full(pred_mask_roi, roi_coords, full_size=(512, 512)):
    """Map a prediction made on an ROI crop back to the full image coordinates."""
    y1, x1, y2, x2 = roi_coords
    crop_h = y2 - y1
    crop_w = x2 - x1
    
    # Resize prediction back to the original crop dimensions
    pred_pil = Image.fromarray(pred_mask_roi.astype(np.uint8))
    pred_resized = np.array(pred_pil.resize((crop_w, crop_h), Image.NEAREST))
    
    # Place into full-size mask
    full_mask = np.zeros(full_size, dtype=np.uint8)
    full_mask[y1:y2, x1:x2] = pred_resized
    
    return full_mask


def visualize_roi_extraction(images, masks, num_samples=4):
    """Visualize ROI extraction to verify correctness"""
    fig, axes = plt.subplots(num_samples, 4, figsize=(16, 4 * num_samples))
    
    for i in range(min(num_samples, len(images))):
        roi_img, roi_msk, coords = extract_roi(images[i], masks[i])
        y1, x1, y2, x2 = coords
        
        # Original image
        axes[i, 0].imshow(images[i])
        axes[i, 0].set_title('Original Image', fontsize=11, fontweight='bold')
        rect = plt.Rectangle((x1, y1), x2 - x1, y2 - y1,
                              linewidth=2, edgecolor='lime', facecolor='none')
        axes[i, 0].add_patch(rect)
        axes[i, 0].axis('off')
        
        # Original mask
        axes[i, 1].imshow(masks[i], cmap='jet', vmin=0, vmax=2)
        axes[i, 1].set_title('Original Mask', fontsize=11, fontweight='bold')
        rect2 = plt.Rectangle((x1, y1), x2 - x1, y2 - y1,
                               linewidth=2, edgecolor='lime', facecolor='none')
        axes[i, 1].add_patch(rect2)
        axes[i, 1].axis('off')
        
        # ROI image
        axes[i, 2].imshow(roi_img)
        axes[i, 2].set_title(f'ROI Image ({roi_img.shape[0]}×{roi_img.shape[1]})',
                             fontsize=11, fontweight='bold')
        axes[i, 2].axis('off')
        
        # ROI mask
        axes[i, 3].imshow(roi_msk, cmap='jet', vmin=0, vmax=2)
        axes[i, 3].set_title(f'ROI Mask ({roi_msk.shape[0]}×{roi_msk.shape[1]})',
                             fontsize=11, fontweight='bold')
        axes[i, 3].axis('off')
    
    plt.suptitle('ROI Extraction Verification — green box shows crop region',
                 fontsize=14, fontweight='bold', y=1.01)
    plt.tight_layout()
    plt.show()
    plt.close()

# ============================================================================
# OFFLINE DATA AUGMENTATION (Phase 1)
# ============================================================================

def setup_offline_augmentation():
    """Aggressive augmentation for OFFLINE dataset expansion (2× copies).
    Applied to both image AND mask (geometric transforms synced by Albumentations)."""
    return A.Compose([
        # --- Strong geometric transforms ---
        A.HorizontalFlip(p=0.5),
        A.VerticalFlip(p=0.5),
        A.RandomRotate90(p=0.5),
        A.ShiftScaleRotate(shift_limit=0.08, scale_limit=0.15, rotate_limit=30,
                           border_mode=0, p=0.7),
        A.OneOf([
            A.ElasticTransform(alpha=50, sigma=6, p=1.0),
            A.GridDistortion(num_steps=5, distort_limit=0.3, p=1.0),
            A.OpticalDistortion(distort_limit=0.05, shift_limit=0.05, p=1.0),
        ], p=0.5),
        # --- Colour/intensity ---
        A.RandomBrightnessContrast(brightness_limit=0.25, contrast_limit=0.25, p=0.8),
        A.HueSaturationValue(hue_shift_limit=15, sat_shift_limit=25, val_shift_limit=15, p=0.6),
        A.OneOf([
            A.GaussianBlur(blur_limit=(3, 5), p=1.0),
            A.GaussNoise(var_limit=(10.0, 50.0), p=1.0),
        ], p=0.4),
        A.CLAHE(clip_limit=4.0, tile_grid_size=(8, 8), p=0.3),
        A.RandomGamma(gamma_limit=(80, 120), p=0.3),
        A.CoarseDropout(max_holes=8, max_height=32, max_width=32,
                        fill_value=0, p=0.3),
    ])


def offline_augment_dataset(images, masks, n_copies=2):
    """
    Expand the training dataset by generating n_copies augmented versions
    of every image+mask pair BEFORE training.

    Args:
        images: Training images (N, H, W, 3) float32 [0, 1]
        masks:  Training masks  (N, H, W)   uint8
        n_copies: Number of augmented copies per original image (default=2)

    Returns:
        aug_images: (N + N*n_copies, H, W, 3) float32
        aug_masks:  (N + N*n_copies, H, W)   uint8
    """
    aug_pipeline = setup_offline_augmentation()

    n_orig = len(images)
    target_total = n_orig + n_orig * n_copies

    print(f"\n{'='*80}")
    print(f"OFFLINE DATA AUGMENTATION")
    print(f"{'='*80}")
    print(f"  Original training images: {n_orig}")
    print(f"  Augmented copies per image: {n_copies}")
    print(f"  Target total: {n_orig} original + {n_orig * n_copies} augmented = {target_total}")

    # Estimate memory
    est_mem_gb = target_total * 512 * 512 * 3 * 4 / (1024**3)
    print(f"  Estimated memory for images: {est_mem_gb:.2f} GB")

    # Start with originals
    aug_images_list = list(images)
    aug_masks_list = list(masks)

    generated = 0
    for i in range(n_orig):
        img = images[i]
        msk = masks[i]

        # Convert image to uint8 for albumentations, then back to float32
        img_uint8 = (img * 255).astype(np.uint8)

        for _ in range(n_copies):
            augmented = aug_pipeline(image=img_uint8, mask=msk)
            aug_img = augmented['image'].astype(np.float32) / 255.0
            aug_msk = augmented['mask']

            aug_images_list.append(aug_img)
            aug_masks_list.append(aug_msk)
            generated += 1

        if (i + 1) % 50 == 0:
            print(f"  Processed {i + 1}/{n_orig} originals ({generated} augmented copies generated)")

    aug_images = np.array(aug_images_list, dtype=np.float32)
    aug_masks = np.array(aug_masks_list, dtype=np.uint8)

    del aug_images_list, aug_masks_list
    gc.collect()

    print(f"\n  ✓ Augmentation complete!")
    print(f"  Final dataset: {aug_images.shape[0]} images ({n_orig} orig + {generated} augmented)")
    print(f"  Actual memory: {aug_images.nbytes / (1024**3):.2f} GB (images) + {aug_masks.nbytes / (1024**3):.4f} GB (masks)")

    return aug_images, aug_masks

# ============================================================================
# ONLINE DATA AUGMENTATION (Phase 1 — enhanced from V5)
# ============================================================================

def setup_augmentations():
    """V8 ENHANCED online augmentation — stronger than V5, matching MBG-Net / GDCSeg-Net.
    
    Changes from V5:
    - VerticalFlip: 0.3 → 0.5
    - Added RandomRotate90
    - Rotation range: ±20° → ±30° (GDCSeg-Net)
    - Added GridDistortion + OpticalDistortion (MBG-Net elastic transforms)
    - Added GaussNoise + MedianBlur
    - Added CLAHE (fundus contrast normalization)
    - Added CoarseDropout / Random Erasing (MBG-Net)
    """
    return A.Compose([
        # --- Geometric (stronger than V5) ---
        A.HorizontalFlip(p=0.5),
        A.VerticalFlip(p=0.5),
        A.RandomRotate90(p=0.5),
        A.ShiftScaleRotate(shift_limit=0.08, scale_limit=0.15, rotate_limit=30,
                           border_mode=0, p=0.7),
        A.OneOf([
            A.ElasticTransform(alpha=50, sigma=6, p=1.0),
            A.GridDistortion(num_steps=5, distort_limit=0.3, p=1.0),
            A.OpticalDistortion(distort_limit=0.05, shift_limit=0.05, p=1.0),
        ], p=0.4),
        # --- Colour/intensity (fundus-specific, stronger than V5) ---
        A.RandomBrightnessContrast(brightness_limit=0.25, contrast_limit=0.25, p=0.8),
        A.HueSaturationValue(hue_shift_limit=15, sat_shift_limit=25, val_shift_limit=15, p=0.6),
        A.OneOf([
            A.GaussianBlur(blur_limit=(3, 5), p=1.0),
            A.GaussNoise(var_limit=(10.0, 50.0), p=1.0),
            A.MedianBlur(blur_limit=5, p=1.0),
        ], p=0.4),
        A.CLAHE(clip_limit=4.0, tile_grid_size=(8, 8), p=0.3),
        A.RandomGamma(gamma_limit=(80, 120), p=0.3),
        # --- Regularization ---
        A.CoarseDropout(max_holes=8, max_height=32, max_width=32,
                        fill_value=0, p=0.3),
    ])

def data_generator(images, masks, batch_size, augment=None):
    idxs = np.arange(len(images))
    while True:
        np.random.shuffle(idxs)
        for i in range(0, len(images), batch_size):
            batch_idxs = idxs[i:i+batch_size]
            batch_x, batch_y = [], []
            
            for idx in batch_idxs:
                img, mask = images[idx], masks[idx]
                
                if augment:
                    # Convert to uint8 for albumentations
                    img_uint8 = (img * 255).astype(np.uint8)
                    aug = augment(image=img_uint8, mask=mask)
                    img_aug = aug['image'].astype(np.float32) / 255.0
                    mask_aug = aug['mask']
                else:
                    img_aug, mask_aug = img, mask
                
                mask_cat = to_categorical(mask_aug, num_classes=3)
                batch_x.append(img_aug)
                batch_y.append(mask_cat)
            
            yield np.stack(batch_x).astype(np.float32), np.stack(batch_y).astype(np.float32)

# ============================================================================
# POST-PROCESSING PIPELINE (Phase 2)
# ============================================================================

def postprocess_prediction(pred_mask):
    """
    MBG-Net-style post-processing pipeline.
    Applied on-the-go during evaluation, before computing Dice/IoU metrics.
    
    Steps:
    1. Largest connected component selection (remove spurious regions)
    2. Morphological closing (fill small boundary gaps)
    3. Contour-based hole filling (fill remaining holes inside disc/cup)
    4. Median filter (smoother, more natural boundaries)
    5. Anatomical constraint: cup ⊂ disc
    
    Args:
        pred_mask: (H, W) uint8 with class labels {0: bg, 1: disc, 2: cup}
    
    Returns:
        cleaned_mask: (H, W) uint8, post-processed prediction
    """
    cleaned = pred_mask.copy()
    
    # Process disc first (class 1 = disc ring + cup combined for connected component)
    # Then process cup (class 2)
    for class_id in [1, 2]:
        if class_id == 1:
            # For disc: consider both disc AND cup as part of the disc region
            binary = ((cleaned == 1) | (cleaned == 2)).astype(np.uint8)
        else:
            binary = (cleaned == class_id).astype(np.uint8)
        
        if binary.sum() == 0:
            continue
        
        # 1. Keep only largest connected component
        num_labels, labels, stats, _ = cv2.connectedComponentsWithStats(binary, connectivity=8)
        if num_labels > 2:  # more than background + one region
            largest = 1 + np.argmax(stats[1:, cv2.CC_STAT_AREA])
            binary = (labels == largest).astype(np.uint8)
        
        # 2. Morphological closing (fill small boundary gaps)
        kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (5, 5))
        binary = cv2.morphologyEx(binary, cv2.MORPH_CLOSE, kernel)
        
        # 3. Contour-based hole filling
        contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        if contours:
            cv2.drawContours(binary, contours, -1, 1, cv2.FILLED)
        
        # 4. Median filter for smoother boundaries
        binary = cv2.medianBlur(binary, 5)
        
        # Update the mask
        if class_id == 1:
            # For disc: set the entire disc region, preserving cup inside
            cup_preserved = (cleaned == 2).astype(np.uint8)
            cleaned[cleaned == 1] = 0  # clear old disc ring
            cleaned[cleaned == 2] = 0  # clear old cup temporarily
            cleaned[binary == 1] = 1   # write cleaned disc region
            # Restore cup where it was AND inside the new disc
            cup_in_disc = cup_preserved & binary
            cleaned[cup_in_disc == 1] = 2
        else:
            # For cup: only keep cup inside the disc region
            disc_region = ((cleaned == 1) | (cleaned == 2)).astype(np.uint8)
            binary = binary & disc_region  # cup must be inside disc
            cleaned[cleaned == 2] = 0  # clear old cup
            cleaned[binary == 1] = 2   # write cleaned cup
    
    # 5. Final anatomical constraint: cup ⊂ disc
    # Ensure any cup pixel that's outside disc gets converted to disc
    cup_mask = (cleaned == 2).astype(np.uint8)
    disc_full = ((cleaned == 1) | (cleaned == 2)).astype(np.uint8)
    # If cup exists outside disc (shouldn't after above, but safety check)
    cup_outside = cup_mask & (~disc_full.astype(bool)).astype(np.uint8)
    if cup_outside.sum() > 0:
        cleaned[cup_outside == 1] = 1  # convert to disc
    
    return cleaned


def postprocess_batch(pred_masks):
    """Apply post-processing to a batch of predictions."""
    return np.array([postprocess_prediction(mask) for mask in pred_masks], dtype=np.uint8)

# ============================================================================
# TEST-TIME AUGMENTATION (Phase 3)
# ============================================================================

def predict_with_tta(model, images, batch_size=4):
    """
    4-pass TTA: average softmax over geometric augmentations.
    
    Augmentations:
    1. Original
    2. Horizontal flip
    3. Vertical flip
    4. Both flips
    
    Args:
        model: Trained model
        images: (N, H, W, 3) input images
        batch_size: Batch size for prediction
    
    Returns:
        pred_labels: (N, H, W) argmax class labels
    """
    print(f"\nRunning TTA with 4 geometric passes...")
    
    # Pass 1: Original
    print(f"  Pass 1/4: Original")
    pred_orig = model.predict(images, verbose=0, batch_size=batch_size)
    
    # Pass 2: Horizontal flip
    print(f"  Pass 2/4: Horizontal flip")
    images_hflip = np.flip(images, axis=2).copy()
    pred_hflip = model.predict(images_hflip, verbose=0, batch_size=batch_size)
    pred_hflip = np.flip(pred_hflip, axis=2)  # un-flip
    del images_hflip
    
    # Pass 3: Vertical flip
    print(f"  Pass 3/4: Vertical flip")
    images_vflip = np.flip(images, axis=1).copy()
    pred_vflip = model.predict(images_vflip, verbose=0, batch_size=batch_size)
    pred_vflip = np.flip(pred_vflip, axis=1)  # un-flip
    del images_vflip
    
    # Pass 4: Both flips
    print(f"  Pass 4/4: Both flips")
    images_hvflip = np.flip(np.flip(images, axis=2), axis=1).copy()
    pred_hvflip = model.predict(images_hvflip, verbose=0, batch_size=batch_size)
    pred_hvflip = np.flip(np.flip(pred_hvflip, axis=2), axis=1)  # un-flip
    del images_hvflip
    
    # Average softmax probabilities
    avg_pred = (pred_orig + pred_hflip + pred_vflip + pred_hvflip) / 4.0
    del pred_orig, pred_hflip, pred_vflip, pred_hvflip
    gc.collect()
    
    pred_labels = np.argmax(avg_pred, axis=-1)
    print(f"  ✓ TTA completed")
    
    return pred_labels, avg_pred

# ============================================================================
# MSCA MODULE (FROM ODFORMER)
# ============================================================================

def msca_block(x, channels, dilation_rates=[1, 2, 3, 5], block_name='msca'):
    """Multi-scale Context Aggregator (MSCA) from ODFormer"""
    multi_scale_features = []
    filters_per_branch = channels // len(dilation_rates)
    
    for i, rate in enumerate(dilation_rates):
        branch = layers.Conv2D(
            filters_per_branch, (3, 3), padding='same',
            dilation_rate=rate, use_bias=False,
            name=f'{block_name}_dil{rate}_conv'
        )(x)
        branch = layers.BatchNormalization(name=f'{block_name}_dil{rate}_bn')(branch)
        branch = layers.Activation('relu', name=f'{block_name}_dil{rate}_relu')(branch)
        multi_scale_features.append(branch)
    
    concat = layers.Concatenate(name=f'{block_name}_concat')(multi_scale_features)
    fused = layers.Conv2D(channels, (1, 1), use_bias=False, name=f'{block_name}_fusion')(concat)
    fused = layers.BatchNormalization(name=f'{block_name}_fusion_bn')(fused)
    fused = layers.Activation('relu', name=f'{block_name}_fusion_relu')(fused)
    output = layers.Add(name=f'{block_name}_residual')([x, fused])
    
    return output

# ============================================================================
# LBFR MODULE (FROM ODFORMER)
# ============================================================================

def lbfr_block(x, channels, reduction=16, block_name='lbfr'):
    """Lightweight Bidirectional Feature Recalibrator (LBFR) from ODFormer"""
    # Channel Attention
    avg_pool = layers.GlobalAveragePooling2D(name=f'{block_name}_avg_pool')(x)
    avg_pool = layers.Reshape((1, 1, channels), name=f'{block_name}_avg_reshape')(avg_pool)
    max_pool = layers.GlobalMaxPooling2D(name=f'{block_name}_max_pool')(x)
    max_pool = layers.Reshape((1, 1, channels), name=f'{block_name}_max_reshape')(max_pool)
    
    fc1 = layers.Conv2D(channels // reduction, (1, 1), use_bias=False, name=f'{block_name}_fc1')
    fc2 = layers.Conv2D(channels, (1, 1), use_bias=False, name=f'{block_name}_fc2')
    
    avg_out = fc1(avg_pool)
    avg_out = layers.Activation('relu', name=f'{block_name}_fc1_relu_avg')(avg_out)
    avg_out = fc2(avg_out)
    max_out = fc1(max_pool)
    max_out = layers.Activation('relu', name=f'{block_name}_fc1_relu_max')(max_out)
    max_out = fc2(max_out)
    
    channel_att = layers.Add(name=f'{block_name}_channel_add')([avg_out, max_out])
    channel_att = layers.Activation('sigmoid', name=f'{block_name}_channel_sigmoid')(channel_att)
    x_channel = layers.Multiply(name=f'{block_name}_channel_multiply')([x, channel_att])
    
    # Spatial Attention
    avg_spatial = layers.Lambda(lambda x: K.mean(x, axis=-1, keepdims=True),
                                name=f'{block_name}_spatial_avg')(x_channel)
    max_spatial = layers.Lambda(lambda x: K.max(x, axis=-1, keepdims=True),
                                name=f'{block_name}_spatial_max')(x_channel)
    spatial_concat = layers.Concatenate(name=f'{block_name}_spatial_concat')([avg_spatial, max_spatial])
    spatial_att = layers.Conv2D(1, (7, 7), padding='same', use_bias=False,
                                name=f'{block_name}_spatial_conv')(spatial_concat)
    spatial_att = layers.Activation('sigmoid', name=f'{block_name}_spatial_sigmoid')(spatial_att)
    x_spatial = layers.Multiply(name=f'{block_name}_spatial_multiply')([x_channel, spatial_att])
    
    # Recalibration
    recalibrated = layers.Conv2D(channels, (1, 1), use_bias=False,
                                 name=f'{block_name}_recalibrate')(x_spatial)
    recalibrated = layers.BatchNormalization(name=f'{block_name}_recalibrate_bn')(recalibrated)
    output = layers.Add(name=f'{block_name}_residual')([x, recalibrated])
    
    return output

# ============================================================================
# PPM MODULE (FROM PSPNET/ODFORMER)
# ============================================================================

def ppm_block(x, channels, pool_scales=[1, 2, 3, 6], block_name='ppm'):
    """Pyramid Pooling Module (PPM) from PSPNet"""
    h, w = x.shape[1], x.shape[2]
    ppm_features = [x]
    filters_per_scale = channels // len(pool_scales)
    
    for i, scale in enumerate(pool_scales):
        pool_h = max(h // scale, 1)
        pool_w = max(w // scale, 1)
        
        pooled = layers.AveragePooling2D(
            pool_size=(h // pool_h, w // pool_w),
            strides=(h // pool_h, w // pool_w),
            name=f'{block_name}pool{scale}x{scale}'
        )(x)
        conv = layers.Conv2D(filters_per_scale, (1, 1), use_bias=False,
                             name=f'{block_name}conv{scale}x{scale}')(pooled)
        conv = layers.BatchNormalization(name=f'{block_name}bn{scale}x{scale}')(conv)
        conv = layers.Activation('relu', name=f'{block_name}relu{scale}x{scale}')(conv)
        upsampled = layers.Resizing(h, w, interpolation='bilinear',
                                    name=f'{block_name}upsample{scale}x{scale}')(conv)
        ppm_features.append(upsampled)
    
    concat = layers.Concatenate(name=f'{block_name}_concat')(ppm_features)
    fused = layers.Conv2D(channels, (3, 3), padding='same', use_bias=False,
                          name=f'{block_name}_fusion')(concat)
    fused = layers.BatchNormalization(name=f'{block_name}_fusion_bn')(fused)
    fused = layers.Activation('relu', name=f'{block_name}_fusion_relu')(fused)
    
    return fused

# ============================================================================
# LOSS FUNCTIONS (unchanged from V5)
# ============================================================================

def focal_loss(y_true, y_pred, gamma=2.0, alpha=None, epsilon=1e-7):
    if alpha is None:
        alpha = [0.25, 1.0, 1.0]
    
    y_pred = K.clip(y_pred, epsilon, 1.0 - epsilon)
    focal_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        
        bce = -(y_true_c * K.log(y_pred_c) + (1 - y_true_c) * K.log(1 - y_pred_c))
        pt = y_true_c * y_pred_c + (1 - y_true_c) * (1 - y_pred_c)
        focal_weight = K.pow(1 - pt, gamma)
        
        focal_loss_value += alpha[c] * K.mean(focal_weight * bce)
    
    return focal_loss_value

def enhanced_iou_loss(y_true, y_pred, smooth=1e-7):
    eiou_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        
        intersection = K.sum(y_true_c * y_pred_c, axis=[1, 2])
        union = K.sum(y_true_c, axis=[1, 2]) + K.sum(y_pred_c, axis=[1, 2]) - intersection
        iou = (intersection + smooth) / (union + smooth)
        
        binary_true = K.cast(y_true_c > 0.5, 'float32')
        binary_pred = K.cast(y_pred_c > 0.5, 'float32')

        _h = tf.cast(tf.shape(y_true_c)[1], 'float32')
        _w = tf.cast(tf.shape(y_true_c)[2], 'float32')
        row_coords = tf.reshape(tf.range(tf.shape(y_true_c)[1], dtype=tf.float32) / _h, [1, -1, 1])
        col_coords = tf.reshape(tf.range(tf.shape(y_true_c)[2], dtype=tf.float32) / _w, [1, 1, -1])

        rp_t = K.max(binary_true, axis=2, keepdims=True)
        rp_p = K.max(binary_pred, axis=2, keepdims=True)
        cp_t = K.max(binary_true, axis=1, keepdims=True)
        cp_p = K.max(binary_pred, axis=1, keepdims=True)

        y_min_t = K.min(row_coords + (1.0 - rp_t), axis=[1, 2])
        y_max_t = K.max(row_coords * rp_t,          axis=[1, 2])
        x_min_t = K.min(col_coords + (1.0 - cp_t), axis=[1, 2])
        x_max_t = K.max(col_coords * cp_t,          axis=[1, 2])

        y_min_p = K.min(row_coords + (1.0 - rp_p), axis=[1, 2])
        y_max_p = K.max(row_coords * rp_p,          axis=[1, 2])
        x_min_p = K.min(col_coords + (1.0 - cp_p), axis=[1, 2])
        x_max_p = K.max(col_coords * cp_p,          axis=[1, 2])

        y_true_bbox = K.stack([y_min_t, x_min_t, y_max_t, x_max_t], axis=-1)
        y_pred_bbox = K.stack([y_min_p, x_min_p, y_max_p, x_max_p], axis=-1)
        
        center_true = K.stack([
            (y_true_bbox[:, 0] + y_true_bbox[:, 2]) / 2.0,
            (y_true_bbox[:, 1] + y_true_bbox[:, 3]) / 2.0
        ], axis=-1)
        center_pred = K.stack([
            (y_pred_bbox[:, 0] + y_pred_bbox[:, 2]) / 2.0,
            (y_pred_bbox[:, 1] + y_pred_bbox[:, 3]) / 2.0
        ], axis=-1)
        
        center_distance = K.sum(K.square(center_true - center_pred), axis=-1)
        diag_length = K.square(y_true_bbox[:, 2] - y_true_bbox[:, 0]) + \
                     K.square(y_true_bbox[:, 3] - y_true_bbox[:, 1])
        diag_length = K.maximum(diag_length, 1e-7)
        
        eiou = iou - (center_distance / diag_length)
        eiou_loss_value += K.mean(1.0 - eiou)
    
    return eiou_loss_value / 3.0

def focal_eiou_combined_loss(y_true, y_pred, focal_weight=1.0, eiou_weight=1.0, gamma=2.0, alpha=None):
    fl = focal_loss(y_true, y_pred, gamma=gamma, alpha=alpha)
    eiou = enhanced_iou_loss(y_true, y_pred)
    return focal_weight * fl + eiou_weight * eiou

# ============================================================================
# MODEL ARCHITECTURE (unchanged from V5)
# ============================================================================

def enhanced_decoder_block_with_triple_attention(x, skip_connection, filters, block_name, dropout_rate=0.3):
    """Enhanced decoder block with MSCA + LBFR + PPM triple attention"""
    x = layers.UpSampling2D((2, 2), name=f'{block_name}_upsample')(x)
    
    if skip_connection.shape[-1] != x.shape[-1]:
        skip_connection = layers.Conv2D(x.shape[-1], (1, 1), padding='same',
                                       name=f'{block_name}_skip_adjust')(skip_connection)
    
    x = layers.Concatenate(name=f'{block_name}_concat')([x, skip_connection])
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv1')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn1')(x)
    x = layers.Dropout(dropout_rate, name=f'{block_name}_dropout')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv2')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn2')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv3')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn3')(x)
    
    residual = x
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv4')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn4')(x)
    
    x = layers.Add(name=f'{block_name}_residual')([x, residual])
    x = layers.Conv2D(filters, (1, 1), activation='relu', padding='same', name=f'{block_name}_conv_final')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn_final')(x)
    
    x = msca_block(x, filters, dilation_rates=[1, 2, 3, 5], block_name=f'{block_name}_msca')
    x = lbfr_block(x, filters, reduction=16, block_name=f'{block_name}_lbfr')
    x = ppm_block(x, filters, pool_scales=[1, 2, 3, 6], block_name=f'{block_name}_ppm')
    
    return x

def build_unet_with_triple_attention(input_shape=(512, 512, 3), num_classes=3, dropout_rate=0.3):
    """Build MobileNetV2-UNet with MSCA + LBFR + PPM triple attention"""
    inputs = layers.Input(input_shape, dtype='float32')
    backbone = MobileNetV2(input_tensor=inputs, weights='imagenet', include_top=False)
    
    skip_1 = backbone.get_layer('block_1_expand_relu').output
    skip_2 = backbone.get_layer('block_3_expand_relu').output
    skip_3 = backbone.get_layer('block_6_expand_relu').output
    skip_4 = backbone.get_layer('block_13_expand_relu').output
    bridge = backbone.output
    
    bridge = layers.Conv2D(1024, (3, 3), activation='relu', padding='same')(bridge)
    bridge = layers.BatchNormalization()(bridge)
    bridge = layers.Dropout(dropout_rate, name='bridge_dropout')(bridge)
    
    x = enhanced_decoder_block_with_triple_attention(bridge, skip_4, 512, 'decoder_1', dropout_rate)
    x = enhanced_decoder_block_with_triple_attention(x, skip_3, 256, 'decoder_2', dropout_rate)
    x = enhanced_decoder_block_with_triple_attention(x, skip_2, 128, 'decoder_3', dropout_rate * 0.7)
    x = enhanced_decoder_block_with_triple_attention(x, skip_1, 64, 'decoder_4', dropout_rate * 0.5)
    
    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    
    outputs = layers.Conv2D(num_classes, (1, 1), activation='softmax', dtype='float32')(x)
    
    model = models.Model(inputs, outputs)
    
    dropout_layers = [layer for layer in model.layers if isinstance(layer, layers.Dropout)]
    print(f"\nModel Configuration:")
    print(f"  Total Parameters: {model.count_params():,}")
    print(f"  Dropout Layers: {len(dropout_layers)}")
    print(f"  Triple Attention: MSCA + LBFR + PPM per decoder block (12 total)")
    
    return model

# ============================================================================
# METRICS
# ============================================================================

def dice_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    return (2. * intersection + smooth) / (K.sum(y_true_class) + K.sum(y_pred_class) + smooth)

def dice_class_0(y_true, y_pred): return dice_coef_class(y_true, y_pred, 0)
def dice_class_1(y_true, y_pred): return dice_coef_class(y_true, y_pred, 1)
def dice_class_2(y_true, y_pred): return dice_coef_class(y_true, y_pred, 2)

def iou_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    union = K.sum(y_true_class) + K.sum(y_pred_class) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_class_0(y_true, y_pred): return iou_coef_class(y_true, y_pred, 0)
def iou_class_1(y_true, y_pred): return iou_coef_class(y_true, y_pred, 1)
def iou_class_2(y_true, y_pred): return iou_coef_class(y_true, y_pred, 2)

def mc_dropout_predict(model, X, num_samples=15, batch_size=4, verbose=True):
    """MC Dropout prediction for uncertainty estimation - Memory Optimized"""
    if verbose:
        print(f"\nRunning MC Dropout with {num_samples} stochastic forward passes...")
    
    sum_preds = None
    sum_sq_preds = None
    num_batches = int(np.ceil(len(X) / batch_size))
    
    for i in range(num_samples):
        if verbose and (i + 1) % 5 == 0:
            print(f"  Completed: {i+1}/{num_samples} forward passes")
        
        batch_preds = []
        for batch_idx in range(num_batches):
            start_idx = batch_idx * batch_size
            end_idx = min(start_idx + batch_size, len(X))
            X_batch = X[start_idx:end_idx]
            pred_batch = model(X_batch, training=True)
            batch_preds.append(pred_batch.numpy())
        
        current_pass_preds = np.concatenate(batch_preds, axis=0)
        
        if sum_preds is None:
            sum_preds = current_pass_preds.astype(np.float32)
            sum_sq_preds = np.square(current_pass_preds).astype(np.float32)
        else:
            sum_preds += current_pass_preds
            sum_sq_preds += np.square(current_pass_preds)
        
        del current_pass_preds, batch_preds
        if (i + 1) % 5 == 0:
            gc.collect()
    
    mean_pred = sum_preds / num_samples
    mean_sq_pred = sum_sq_preds / num_samples
    var_pred = np.maximum(mean_sq_pred - np.square(mean_pred), 0)
    std_pred = np.sqrt(var_pred)
    
    del sum_preds, sum_sq_preds
    gc.collect()
    
    if verbose:
        print(f"✓ MC Dropout completed")
    
    return mean_pred, std_pred

# ============================================================================
# GLAUCOMA PROGRESSION SCORING
# ============================================================================

def calculate_cdr(mask, disc_class=1, cup_class=2, method='vertical'):
    """Calculate Cup-to-Disc Ratio (CDR) from segmentation mask"""
    disc_mask = (mask == disc_class).astype(np.uint8)
    cup_mask = (mask == cup_class).astype(np.uint8)
    
    disc_area = disc_mask.sum()
    cup_area = cup_mask.sum()
    
    if disc_area == 0 or cup_area == 0:
        return {'vCDR': 0.0, 'hCDR': 0.0, 'avgCDR': 0.0, 'area_CDR': 0.0, 'valid': False,
                'method': method, 'disc_area': 0, 'cup_area': 0}
    
    disc_coords = np.where(disc_mask > 0)
    cup_coords = np.where(cup_mask > 0)
    
    disc_v_diameter = disc_coords[0].max() - disc_coords[0].min() + 1
    cup_v_diameter = cup_coords[0].max() - cup_coords[0].min() + 1
    disc_h_diameter = disc_coords[1].max() - disc_coords[1].min() + 1
    cup_h_diameter = cup_coords[1].max() - cup_coords[1].min() + 1
    
    vCDR = cup_v_diameter / disc_v_diameter if disc_v_diameter > 0 else 0.0
    hCDR = cup_h_diameter / disc_h_diameter if disc_h_diameter > 0 else 0.0
    area_CDR = np.sqrt(cup_area / disc_area)
    
    if method == 'vertical':
        avgCDR = vCDR
    elif method == 'area_sqrt':
        avgCDR = area_CDR
    else:
        avgCDR = (vCDR + hCDR) / 2.0
    
    return {
        'vCDR': float(vCDR), 'hCDR': float(hCDR), 'avgCDR': float(avgCDR),
        'area_CDR': float(area_CDR), 'valid': True, 'method': method,
        'disc_area': int(disc_area), 'cup_area': int(cup_area),
        'disc_v_diameter': int(disc_v_diameter), 'cup_v_diameter': int(cup_v_diameter)
    }

def classify_glaucoma_severity(cdr):
    """Classify glaucoma severity based on CDR"""
    if cdr < 0.3:
        return 0, 'Normal', '#4CAF50'
    elif cdr < 0.6:
        return 1, 'Suspect', '#FFC107'
    elif cdr < 0.8:
        return 2, 'Moderate', '#FF9800'
    else:
        return 3, 'Critical', '#F44336'

def analyze_glaucoma_progression(masks, predictions, cdr_method='area_sqrt'):
    """Analyze glaucoma progression for a batch of samples"""
    results = []
    
    for i, (gt_mask, pred_mask) in enumerate(zip(masks, predictions)):
        gt_cdr = calculate_cdr(gt_mask, method=cdr_method)
        pred_cdr = calculate_cdr(pred_mask, method=cdr_method)
        
        if gt_cdr['valid']:
            gt_class, gt_label, gt_color = classify_glaucoma_severity(gt_cdr['avgCDR'])
        else:
            gt_class, gt_label, gt_color = -1, 'Invalid', '#9E9E9E'
        
        if pred_cdr['valid']:
            pred_class, pred_label, pred_color = classify_glaucoma_severity(pred_cdr['avgCDR'])
        else:
            pred_class, pred_label, pred_color = -1, 'Invalid', '#9E9E9E'
        
        cdr_error = abs(gt_cdr['avgCDR'] - pred_cdr['avgCDR']) if gt_cdr['valid'] and pred_cdr['valid'] else np.nan
        severity_match = (gt_label == pred_label)
        manual_review = (gt_label == 'Critical') or (not severity_match)
        
        results.append({
            'Sample': i + 1,
            'GT_vCDR': gt_cdr['vCDR'], 'GT_hCDR': gt_cdr['hCDR'],
            'GT_avgCDR': gt_cdr['avgCDR'], 'GT_area_CDR': gt_cdr['area_CDR'],
            'GT_Severity': gt_label,
            'Pred_vCDR': pred_cdr['vCDR'], 'Pred_hCDR': pred_cdr['hCDR'],
            'Pred_avgCDR': pred_cdr['avgCDR'], 'Pred_area_CDR': pred_cdr['area_CDR'],
            'Pred_Severity': pred_label,
            'CDR_Error': cdr_error, 'Severity_Match': severity_match,
            'Manual_Review_Needed': manual_review
        })
    
    return pd.DataFrame(results)

def calculate_progression_accuracy(df_progression):
    """Calculate simple accuracy metrics"""
    results = {}
    total = len(df_progression)
    correct = df_progression['Severity_Match'].sum()
    overall_accuracy = (correct / total) * 100
    
    results['overall'] = {'total': total, 'correct': correct, 'accuracy': overall_accuracy}
    
    severity_classes = ['Normal', 'Suspect', 'Moderate', 'Critical']
    results['per_class'] = {}
    
    for severity in severity_classes:
        gt_count = len(df_progression[df_progression['GT_Severity'] == severity])
        pred_count = len(df_progression[df_progression['Pred_Severity'] == severity])
        correct_count = len(df_progression[
            (df_progression['GT_Severity'] == severity) &
            (df_progression['Pred_Severity'] == severity)
        ])
        class_accuracy = (correct_count / gt_count * 100) if gt_count > 0 else 0.0
        results['per_class'][severity] = {
            'gt_count': gt_count, 'pred_count': pred_count,
            'correct': correct_count, 'accuracy': class_accuracy
        }
    
    manual_review_needed = df_progression['Manual_Review_Needed'].sum()
    results['manual_review'] = {
        'count': manual_review_needed, 'percentage': (manual_review_needed / total) * 100
    }
    
    return results

# ============================================================================
# VISUALIZATION FUNCTIONS
# ============================================================================

def plot_sample_predictions_with_cdr(model, X_test_roi, y_test_full, roi_coords_test,
                                     model_name, num_samples=6, save_dir='results',
                                     use_postprocessing=True):
    """Visualize predictions with CDR and glaucoma severity (ROI-aware)"""
    os.makedirs(save_dir, exist_ok=True)
    
    y_pred = model.predict(X_test_roi[:num_samples], verbose=0, batch_size=4)
    y_pred_labels_roi = np.argmax(y_pred, axis=-1)
    
    if use_postprocessing:
        y_pred_labels_roi = postprocess_batch(y_pred_labels_roi)
    
    colors = {0: [0, 0, 0], 1: [0, 255, 0], 2: [255, 0, 0]}
    
    fig, axes = plt.subplots(num_samples, 4, figsize=(18, 4*num_samples))
    
    for i in range(num_samples):
        axes[i, 0].imshow(X_test_roi[i])
        axes[i, 0].set_title('ROI Image', fontsize=12, fontweight='bold')
        axes[i, 0].axis('off')
        
        gt_mask_full = y_test_full[i]
        h, w = gt_mask_full.shape
        gt_colored = np.zeros((h, w, 3), dtype=np.uint8)
        for class_id, color in colors.items():
            gt_colored[gt_mask_full == class_id] = color
        axes[i, 1].imshow(gt_colored)
        
        gt_cdr = calculate_cdr(gt_mask_full)
        gt_class, gt_label, gt_color = classify_glaucoma_severity(gt_cdr['avgCDR']) if gt_cdr['valid'] else (-1, 'Invalid', '#9E9E9E')
        axes[i, 1].set_title(f'Ground Truth\nCDR: {gt_cdr["avgCDR"]:.3f} | {gt_label}',
                            fontsize=12, fontweight='bold', color=gt_color)
        axes[i, 1].axis('off')
        
        pred_full = map_roi_prediction_to_full(y_pred_labels_roi[i], roi_coords_test[i], full_size=(h, w))
        pred_colored = np.zeros((h, w, 3), dtype=np.uint8)
        for class_id, color in colors.items():
            pred_colored[pred_full == class_id] = color
        axes[i, 2].imshow(pred_colored)
        
        pred_cdr = calculate_cdr(pred_full)
        pred_class, pred_label, pred_color = classify_glaucoma_severity(pred_cdr['avgCDR']) if pred_cdr['valid'] else (-1, 'Invalid', '#9E9E9E')
        pp_tag = " [PP]" if use_postprocessing else ""
        axes[i, 2].set_title(f'Prediction{pp_tag}\nCDR: {pred_cdr["avgCDR"]:.3f} | {pred_label}',
                            fontsize=12, fontweight='bold', color=pred_color)
        axes[i, 2].axis('off')
        
        overlay = X_test_roi[i].copy()
        for class_id, color in colors.items():
            if class_id > 0:
                mask = (y_pred_labels_roi[i] == class_id).astype(np.float32)
                mask_rgb = np.stack([mask * color[0]/255, mask * color[1]/255, mask * color[2]/255], axis=-1)
                overlay = overlay * 0.6 + mask_rgb * 0.4
        axes[i, 3].imshow(overlay)
        axes[i, 3].set_title('ROI Overlay', fontsize=12, fontweight='bold')
        axes[i, 3].axis('off')
        
        roi_gt_cat = to_categorical(y_test_full[i], num_classes=3)
        roi_pred_cat = to_categorical(pred_full, num_classes=3)
        disc_dice = 2 * np.sum(roi_gt_cat[:,:,1] * roi_pred_cat[:,:,1]) / (np.sum(roi_gt_cat[:,:,1]) + np.sum(roi_pred_cat[:,:,1]) + 1e-7)
        cup_dice = 2 * np.sum(roi_gt_cat[:,:,2] * roi_pred_cat[:,:,2]) / (np.sum(roi_gt_cat[:,:,2]) + np.sum(roi_pred_cat[:,:,2]) + 1e-7)
        cdr_error = abs(gt_cdr['avgCDR'] - pred_cdr['avgCDR']) if gt_cdr['valid'] and pred_cdr['valid'] else np.nan
        
        info_text = f'Sample {i+1}\nDisc Dice: {disc_dice:.3f} | Cup Dice: {cup_dice:.3f}\n'
        info_text += f'CDR Error: {cdr_error:.3f}' if not np.isnan(cdr_error) else 'CDR Error: N/A'
        axes[i, 0].text(0.5, -0.15, info_text, transform=axes[i, 0].transAxes,
                       ha='center', fontsize=10, bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
    
    plt.suptitle(f'{model_name} - ROI Predictions with Glaucoma Severity Assessment',
                 fontsize=16, fontweight='bold', y=0.995)
    plt.tight_layout()
    plt.savefig(f'{save_dir}/{model_name}_predictions_cdr.png', dpi=150, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_predictions_cdr.png")
    plt.show()
    plt.close()

def plot_cdr_distribution(df_progression, save_dir='results'):
    """Plot CDR distribution and severity classification"""
    os.makedirs(save_dir, exist_ok=True)
    
    fig, axes = plt.subplots(2, 2, figsize=(16, 12))
    
    axes[0, 0].scatter(df_progression['GT_avgCDR'], df_progression['Pred_avgCDR'],
                      alpha=0.6, s=100, c='blue', edgecolors='black')
    axes[0, 0].plot([0, 1], [0, 1], 'r--', linewidth=2, label='Perfect Prediction')
    axes[0, 0].set_xlabel('Ground Truth CDR', fontsize=12, fontweight='bold')
    axes[0, 0].set_ylabel('Predicted CDR', fontsize=12, fontweight='bold')
    axes[0, 0].set_title('CDR: Ground Truth vs Prediction', fontsize=14, fontweight='bold')
    axes[0, 0].legend(fontsize=10)
    axes[0, 0].grid(True, alpha=0.3)
    axes[0, 0].axhspan(0, 0.3, alpha=0.1, color='green')
    axes[0, 0].axhspan(0.3, 0.6, alpha=0.1, color='yellow')
    axes[0, 0].axhspan(0.6, 0.8, alpha=0.1, color='orange')
    axes[0, 0].axhspan(0.8, 1.0, alpha=0.1, color='red')
    
    valid_errors = df_progression['CDR_Error'].dropna()
    axes[0, 1].hist(valid_errors, bins=30, color='steelblue', edgecolor='black', alpha=0.7)
    axes[0, 1].axvline(valid_errors.mean(), color='red', linestyle='--', linewidth=2,
                      label=f'Mean Error: {valid_errors.mean():.4f}')
    axes[0, 1].set_xlabel('CDR Error (|GT - Pred|)', fontsize=12, fontweight='bold')
    axes[0, 1].set_ylabel('Frequency', fontsize=12, fontweight='bold')
    axes[0, 1].set_title('CDR Error Distribution', fontsize=14, fontweight='bold')
    axes[0, 1].legend(fontsize=10)
    axes[0, 1].grid(True, alpha=0.3)
    
    severity_order = ['Normal', 'Suspect', 'Moderate', 'Critical']
    gt_severity = pd.Categorical(df_progression['GT_Severity'], categories=severity_order, ordered=True)
    pred_severity = pd.Categorical(df_progression['Pred_Severity'], categories=severity_order, ordered=True)
    cm = confusion_matrix(gt_severity, pred_severity, labels=severity_order)
    sns.heatmap(cm, annot=True, fmt='d', cmap='YlOrRd',
                xticklabels=severity_order, yticklabels=severity_order,
                ax=axes[1, 0], cbar_kws={'label': 'Count'})
    axes[1, 0].set_title('Glaucoma Severity Classification', fontsize=14, fontweight='bold')
    axes[1, 0].set_ylabel('Ground Truth', fontsize=12, fontweight='bold')
    axes[1, 0].set_xlabel('Predicted', fontsize=12, fontweight='bold')
    
    severity_counts_gt = df_progression['GT_Severity'].value_counts()
    severity_counts_pred = df_progression['Pred_Severity'].value_counts()
    x = np.arange(len(severity_order))
    width = 0.35
    counts_gt = [severity_counts_gt.get(s, 0) for s in severity_order]
    counts_pred = [severity_counts_pred.get(s, 0) for s in severity_order]
    axes[1, 1].bar(x - width/2, counts_gt, width, label='Ground Truth',
                  color=['#4CAF50', '#FFC107', '#FF9800', '#F44336'], alpha=0.7)
    axes[1, 1].bar(x + width/2, counts_pred, width, label='Predicted',
                  color=['#4CAF50', '#FFC107', '#FF9800', '#F44336'], alpha=0.4)
    axes[1, 1].set_xlabel('Severity Level', fontsize=12, fontweight='bold')
    axes[1, 1].set_ylabel('Count', fontsize=12, fontweight='bold')
    axes[1, 1].set_title('Severity Distribution', fontsize=14, fontweight='bold')
    axes[1, 1].set_xticks(x)
    axes[1, 1].set_xticklabels(severity_order, rotation=15)
    axes[1, 1].legend(fontsize=10)
    axes[1, 1].grid(True, alpha=0.3, axis='y')
    
    plt.tight_layout()
    plt.savefig(f'{save_dir}/cdr_analysis.png', dpi=150, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/cdr_analysis.png")
    plt.show()
    plt.close()

def plot_training_history(history, model_name, save_dir='results'):
    """Plot training history - Loss and Accuracy"""
    os.makedirs(save_dir, exist_ok=True)
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    
    axes[0].plot(history.history['loss'], label='Training Loss', linewidth=2)
    axes[0].plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
    axes[0].set_title(f'{model_name} - Loss Over Epochs', fontsize=14, fontweight='bold')
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('Loss', fontsize=12)
    axes[0].legend(fontsize=10)
    axes[0].grid(True, alpha=0.3)
    
    axes[1].plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
    axes[1].plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
    axes[1].set_title(f'{model_name} - Accuracy Over Epochs', fontsize=14, fontweight='bold')
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('Accuracy', fontsize=12)
    axes[1].legend(fontsize=10)
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(f'{save_dir}/{model_name}_history.png', dpi=150, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_history.png")
    plt.show()
    plt.close()

def plot_confusion_matrices(y_true, y_pred, model_name, save_dir='results'):
    """Plot confusion matrices"""
    os.makedirs(save_dir, exist_ok=True)
    
    y_true_labels = np.argmax(y_true, axis=-1).flatten()
    y_pred_labels = np.argmax(y_pred, axis=-1).flatten()
    
    cm = confusion_matrix(y_true_labels, y_pred_labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    class_names = ['Background', 'Disc', 'Cup']
    
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[0], cbar_kws={'label': 'Count'})
    axes[0].set_title(f'{model_name}\nConfusion Matrix', fontsize=14, fontweight='bold')
    axes[0].set_ylabel('True Label', fontsize=12)
    axes[0].set_xlabel('Predicted Label', fontsize=12)
    
    sns.heatmap(cm_normalized, annot=True, fmt='.3f', cmap='Greens',
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[1], cbar_kws={'label': 'Proportion'})
    axes[1].set_title(f'{model_name}\nNormalized Confusion Matrix', fontsize=14, fontweight='bold')
    axes[1].set_ylabel('True Label', fontsize=12)
    axes[1].set_xlabel('Predicted Label', fontsize=12)
    
    plt.tight_layout()
    plt.savefig(f"{save_dir}/{model_name}_confusion_matrices.png", dpi=300, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_confusion_matrices.png")
    plt.show()
    plt.close()
    
    print(f"\nConfusion Matrix:\n{cm}")
    print(f"\nNormalized Confusion Matrix:\n{np.round(cm_normalized, 3)}")
    
    return cm, cm_normalized

# ============================================================================
# TRAINING AND EVALUATION
# ============================================================================

def train_model(X_train_roi, y_train_roi, X_val_roi, y_val_roi,
                X_test_roi, y_test_full, roi_coords_test,
                model_name, augment=None, save_dir='results'):
    """Train model — same config as V5 (Adam 2e-4, ReduceLROnPlateau, 80 epochs)"""
    print(f"\n{'='*80}")
    print(f"TRAINING: {model_name}")
    print(f"{'='*80}")
    print(f"  Architecture: Deeper Decoder + MSCA + LBFR + PPM + Focal-EIoU + MC Dropout")
    print(f"  Loss: Focal + Enhanced IoU (Combined)")
    print(f"  ROI Extraction: ENABLED (padding=1.5×, training on disc-centered crops)")
    
    K.clear_session()
    
    model = build_unet_with_triple_attention(dropout_rate=0.3)
    
    model.compile(
        optimizer=optimizers.Adam(learning_rate=2e-4, clipnorm=1.0),
        loss=focal_eiou_combined_loss,
        metrics=[dice_coef_multiclass, dice_class_0, dice_class_1, dice_class_2,
                "accuracy", iou_coef_multiclass, iou_class_0, iou_class_1, iou_class_2]
    )
    
    checkpoint = ModelCheckpoint(f"{save_dir}/{model_name}.keras", save_best_only=True,
                                verbose=1, monitor='val_loss', mode='min')
    reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=4,
                                  verbose=1, mode='min', min_lr=1e-7)
    early_stop = EarlyStopping(monitor="val_loss", patience=15, verbose=1,
                              restore_best_weights=True, mode='min')
    
    batch_size = 4
    steps_train = X_train_roi.shape[0] // batch_size
    steps_val = X_val_roi.shape[0] // batch_size
    
    history = model.fit(
        data_generator(X_train_roi, y_train_roi, batch_size, augment),
        validation_data=data_generator(X_val_roi, y_val_roi, batch_size, None),
        steps_per_epoch=steps_train,
        validation_steps=steps_val,
        epochs=80,
        callbacks=[checkpoint, reduce_lr, early_stop],
        verbose=1
    )
    
    print(f"✓ Training completed")
    
    print("\nGenerating visualizations...")
    plot_training_history(history, model_name, save_dir)
    plot_sample_predictions_with_cdr(model, X_test_roi, y_test_full, roi_coords_test,
                                     model_name, num_samples=8, save_dir=save_dir)
    
    return model, history, model.count_params()

def save_segmentation_masks(X_test_roi, y_test_full, y_pred_labels_roi,
                            roi_coords_test, save_dir='results/predictions'):
    """Save all test predictions (masks only) with visible pixel values — ROI-aware"""
    os.makedirs(save_dir, exist_ok=True)
    
    print(f"\nSaving all {len(X_test_roi)} test predictions to {save_dir}...")
    
    for i in range(len(X_test_roi)):
        h, w = y_test_full[i].shape
        pred_full = map_roi_prediction_to_full(y_pred_labels_roi[i], roi_coords_test[i], full_size=(h, w))
        
        visible_pred = np.zeros((h, w), dtype=np.uint8)
        visible_pred[pred_full == 1] = 127
        visible_pred[pred_full == 2] = 255
        
        gt_mask = y_test_full[i].astype(np.uint8)
        visible_gt = np.zeros_like(gt_mask)
        visible_gt[gt_mask == 1] = 127
        visible_gt[gt_mask == 2] = 255
        
        combined = np.hstack((visible_gt, visible_pred))
        Image.fromarray(combined).save(f"{save_dir}/test_{i+1:04d}_comparison.png")
            
        if (i + 1) % 50 == 0:
            print(f"  Processed {i+1}/{len(X_test_roi)}")
            
    print(f"✓ Saved comparison masks to {save_dir}")

def compute_dice_iou_per_class(y_true_masks, y_pred_masks, class_names=None):
    """Compute per-class Dice and IoU from label masks (not one-hot)."""
    if class_names is None:
        class_names = ["Background", "Disc", "Cup"]
    
    results = {}
    for cidx, cname in enumerate(class_names):
        y_true_c = (y_true_masks == cidx).astype(np.float32)
        y_pred_c = (y_pred_masks == cidx).astype(np.float32)
        
        intersection = np.sum(y_true_c * y_pred_c)
        dice = (2. * intersection + 1e-7) / (np.sum(y_true_c) + np.sum(y_pred_c) + 1e-7)
        union = np.sum(y_true_c) + np.sum(y_pred_c) - intersection
        iou = (intersection + 1e-7) / (union + 1e-7)
        
        results[cname] = {'dice': dice, 'iou': iou}
    
    return results

def evaluate_model(model, X_test_roi, y_test_roi, y_test_full, roi_coords_test,
                   model_name, run_mc_dropout=True, save_predictions=True):
    """
    Evaluate model with three stages:
    1. Raw predictions (no post-processing, no TTA)
    2. Post-processed predictions
    3. TTA + post-processed predictions
    """
    print(f"\n{'='*80}")
    print(f"EVALUATION: {model_name}")
    print(f"{'='*80}")
    
    class_names = ["Background", "Disc", "Cup"]
    
    # ---- STAGE 1: Raw predictions ----
    print(f"\n{'─'*80}")
    print(f"STAGE 1: RAW PREDICTIONS (no post-processing, no TTA)")
    print(f"{'─'*80}")
    
    y_test_roi_cat = np.array([to_categorical(mask, num_classes=3) for mask in y_test_roi])
    y_pred = model.predict(X_test_roi, verbose=0, batch_size=4)
    y_pred_labels_roi_raw = np.argmax(y_pred, axis=-1)
    
    # Confusion matrices (on raw)
    plot_confusion_matrices(y_test_roi_cat, y_pred, model_name + "_raw", save_dir='results')
    
    raw_metrics = compute_dice_iou_per_class(y_test_roi, y_pred_labels_roi_raw)
    print(f"\nRaw per-class metrics (ROI-level):")
    for cname in class_names:
        print(f"  {cname}: Dice={raw_metrics[cname]['dice']:.4f}, IoU={raw_metrics[cname]['iou']:.4f}")
    
    # ---- STAGE 2: Post-processed predictions ----
    print(f"\n{'─'*80}")
    print(f"STAGE 2: POST-PROCESSED PREDICTIONS")
    print(f"{'─'*80}")
    
    y_pred_labels_roi_pp = postprocess_batch(y_pred_labels_roi_raw)
    
    pp_metrics = compute_dice_iou_per_class(y_test_roi, y_pred_labels_roi_pp)
    print(f"\nPost-processed per-class metrics (ROI-level):")
    for cname in class_names:
        delta = pp_metrics[cname]['dice'] - raw_metrics[cname]['dice']
        print(f"  {cname}: Dice={pp_metrics[cname]['dice']:.4f} ({delta:+.4f}), IoU={pp_metrics[cname]['iou']:.4f}")
    
    # ---- STAGE 3: TTA + Post-processing ----
    print(f"\n{'─'*80}")
    print(f"STAGE 3: TTA + POST-PROCESSING")
    print(f"{'─'*80}")
    
    y_pred_labels_tta, _ = predict_with_tta(model, X_test_roi, batch_size=4)
    y_pred_labels_tta_pp = postprocess_batch(y_pred_labels_tta)
    
    tta_metrics = compute_dice_iou_per_class(y_test_roi, y_pred_labels_tta_pp)
    print(f"\nTTA + Post-processed per-class metrics (ROI-level):")
    for cname in class_names:
        delta = tta_metrics[cname]['dice'] - raw_metrics[cname]['dice']
        print(f"  {cname}: Dice={tta_metrics[cname]['dice']:.4f} ({delta:+.4f} vs raw), IoU={tta_metrics[cname]['iou']:.4f}")
    
    # ---- SUMMARY TABLE ----
    print(f"\n{'='*80}")
    print(f"RESULTS COMPARISON TABLE")
    print(f"{'='*80}")
    print(f"{'Stage':<30} {'BG Dice':<12} {'Disc Dice':<12} {'Cup Dice':<12}")
    print(f"{'─'*66}")
    print(f"{'Raw (no PP, no TTA)':<30} {raw_metrics['Background']['dice']:<12.4f} {raw_metrics['Disc']['dice']:<12.4f} {raw_metrics['Cup']['dice']:<12.4f}")
    print(f"{'+ Post-Processing':<30} {pp_metrics['Background']['dice']:<12.4f} {pp_metrics['Disc']['dice']:<12.4f} {pp_metrics['Cup']['dice']:<12.4f}")
    print(f"{'+ TTA + Post-Processing':<30} {tta_metrics['Background']['dice']:<12.4f} {tta_metrics['Disc']['dice']:<12.4f} {tta_metrics['Cup']['dice']:<12.4f}")
    
    # ---- Use best result (TTA+PP) for downstream analysis ----
    y_pred_labels_best = y_pred_labels_tta_pp
    
    # Map predictions back to full image
    y_pred_labels_full = []
    for i in range(len(X_test_roi)):
        h, w = y_test_full[i].shape
        pred_full = map_roi_prediction_to_full(y_pred_labels_best[i], roi_coords_test[i], full_size=(h, w))
        y_pred_labels_full.append(pred_full)
    y_pred_labels_full = np.array(y_pred_labels_full)
    
    if save_predictions:
        save_segmentation_masks(X_test_roi, y_test_full, y_pred_labels_best,
                                roi_coords_test, save_dir=f'results/{model_name}_all_preds')
    
    # Classification metrics
    y_true_labels = y_test_roi.flatten()
    y_pred_labels_flat = y_pred_labels_best.flatten()
    
    precision = precision_score(y_true_labels, y_pred_labels_flat, average=None, zero_division=0)
    recall = recall_score(y_true_labels, y_pred_labels_flat, average=None, zero_division=0)
    f1 = f1_score(y_true_labels, y_pred_labels_flat, average=None, zero_division=0)
    
    print(f"\nPrecision, Recall, F1 Score per class (TTA+PP):")
    for idx, cname in enumerate(class_names):
        print(f"  {cname}: Precision={precision[idx]:.4f}, Recall={recall[idx]:.4f}, F1={f1[idx]:.4f}")
    
    print(f"\nMacro-averaged metrics:")
    print(f"  Precision: {np.mean(precision):.4f}")
    print(f"  Recall: {np.mean(recall):.4f}")
    print(f"  F1 Score: {np.mean(f1):.4f}")
    
    # ---- Glaucoma Progression Analysis ----
    print(f"\n{'='*80}")
    print(f"GLAUCOMA PROGRESSION ANALYSIS")
    print(f"{'='*80}")
    
    df_progression = analyze_glaucoma_progression(y_test_full, y_pred_labels_full, cdr_method='area_sqrt')
    
    print(f"\nCDR Statistics:")
    print(f"  Mean GT CDR:   {df_progression['GT_avgCDR'].mean():.4f} ± {df_progression['GT_avgCDR'].std():.4f}")
    print(f"  Mean Pred CDR: {df_progression['Pred_avgCDR'].mean():.4f} ± {df_progression['Pred_avgCDR'].std():.4f}")
    print(f"  Mean CDR Error: {df_progression['CDR_Error'].mean():.4f} ± {df_progression['CDR_Error'].std():.4f}")
    
    accuracy_results = calculate_progression_accuracy(df_progression)
    
    print(f"\nOverall Accuracy: {accuracy_results['overall']['accuracy']:.2f}%")
    print(f"  Correctly Classified: {accuracy_results['overall']['correct']}/{accuracy_results['overall']['total']}")
    
    print(f"\n{'Severity':<12} {'GT Count':<12} {'Pred Count':<12} {'Correct':<12} {'Accuracy':<12}")
    print(f"{'─'*60}")
    for severity in ['Normal', 'Suspect', 'Moderate', 'Critical']:
        stats = accuracy_results['per_class'][severity]
        print(f"{severity:<12} {stats['gt_count']:<12} {stats['pred_count']:<12} "
              f"{stats['correct']:<12} {stats['accuracy']:<12.2f}%")
    
    print(f"\nManual Review: {accuracy_results['manual_review']['count']}/{accuracy_results['overall']['total']} "
          f"({accuracy_results['manual_review']['percentage']:.1f}%)")
    
    df_progression.to_csv('results/glaucoma_progression_analysis.csv', index=False)
    print(f"\n✓ Saved: results/glaucoma_progression_analysis.csv")
    
    plot_cdr_distribution(df_progression, save_dir='results')
    
    results = {
        'raw': raw_metrics,
        'postprocessed': pp_metrics,
        'tta_pp': tta_metrics,
        'glaucoma': {
            'mean_cdr_error': df_progression['CDR_Error'].mean(),
            'median_cdr_error': df_progression['CDR_Error'].median(),
            'classification_accuracy': accuracy_results['overall']['accuracy'] / 100,
            'df_progression': df_progression,
            'accuracy_breakdown': accuracy_results
        }
    }
    
    # MC Dropout
    if run_mc_dropout:
        print(f"\n{'='*80}")
        print(f"MC DROPOUT UNCERTAINTY ESTIMATION")
        print(f"{'='*80}")
        mean_pred, std_pred = mc_dropout_predict(model, X_test_roi[:100], num_samples=15, verbose=True)
        results['mc_dropout'] = {}
        for cidx, cname in enumerate(class_names):
            mean_std = np.mean(std_pred[:, :, :, cidx])
            results['mc_dropout'][cname] = {'mean_uncertainty': mean_std}
            print(f"  {cname} uncertainty: {mean_std:.4f}")
    
    return results

# ============================================================================
# MAIN EXECUTION
# ============================================================================

if __name__ == "__main__":
    # Setup
    gpu_available = configure_gpu()
    root_dir = "/kaggle/input/datasets/arnavpal66/refuge/REFUGE"
    train_aug = setup_augmentations()
    save_dir = "results"
    os.makedirs(save_dir, exist_ok=True)
    
    MODEL_NAME = "V8_Boosted_P1P2P3"
    PADDING_FACTOR = 1.2
    
    print(f"\n{'='*100}")
    print(f"{'V8: ENHANCED ONLINE AUG + POST-PROCESSING + TTA (Phases 1-3)':^100s}")
    print(f"{'='*100}")
    print(f"\nPhase 1 — Enhanced Online Augmentation:")
    print(f"  - NO offline augmentation (keeps ~1hr training time)")
    print(f"  - Enhanced online pipeline (RandomRotate90, GridDistortion, GaussNoise, CLAHE, CoarseDropout)")
    print(f"  - ROI padding: {PADDING_FACTOR}× (same as V5)")
    print(f"\nPhase 2 — Post-Processing:")
    print(f"  - Largest connected component → Morphological closing → Hole filling → Median filter")
    print(f"  - Anatomical constraint: cup ⊂ disc")
    print(f"\nPhase 3 — Test-Time Augmentation:")
    print(f"  - 4-pass flip ensemble (orig, hflip, vflip, both)")
    print(f"\nTraining Config (same as V5):")
    print(f"  - Adam lr=2e-4, ReduceLROnPlateau, 80 epochs, patience=15")
    print(f"  - Focal loss alpha=[0.25, 1.0, 1.0] + Enhanced IoU")
    
    # Load data with HIGH-RES ROI extraction (padding=1.5×)
    print(f"\n{'='*80}")
    print(f"HIGH-RES ROI DATA LOADING")
    print(f"{'='*80}")
    print(f"  Loading at original resolution, extracting ROI, resizing to 512x512")
    print(f"  Padding factor: {PADDING_FACTOR}× ({int(PADDING_FACTOR*100 - 100)}% margin around disc)")
    
    all_roi_images, all_roi_masks, all_full_masks = load_all_data_with_highres_roi(
        root_dir, padding_factor=PADDING_FACTOR)
    
    # Split: 600 train, 200 val, 400 test (same as V5)
    X_temp, X_test_roi, y_temp_roi, y_test_roi, temp_full, y_test_full = train_test_split(
        all_roi_images, all_roi_masks, all_full_masks, test_size=400, random_state=42
    )
    X_train_roi, X_val_roi, y_train_roi, y_val_roi, train_full, val_full = train_test_split(
        X_temp, y_temp_roi, temp_full, test_size=200, random_state=42
    )
    
    del all_roi_images, all_roi_masks, all_full_masks, X_temp, y_temp_roi, temp_full
    gc.collect()
    
    # NO offline augmentation — keeps training at ~1hr
    # Enhanced online augmentation handles diversity during training
    
    # Create dummy roi_coords
    roi_coords_test = [(0, 0, 512, 512)] * len(X_test_roi)
    
    print(f"\n  Split - Train: {X_train_roi.shape[0]}, Val: {X_val_roi.shape[0]}, Test: {X_test_roi.shape[0]}")
    print(f"  ROI shape: {X_train_roi.shape[1:]} per image")
    
    # Train model on ROI data
    model, history, params = train_model(
        X_train_roi, y_train_roi, X_val_roi, y_val_roi,
        X_test_roi, y_test_full, roi_coords_test,
        MODEL_NAME,
        augment=train_aug, save_dir=save_dir
    )
    
    # Evaluate with 3-stage comparison (raw → PP → TTA+PP)
    results = evaluate_model(
        model, X_test_roi, y_test_roi, y_test_full, roi_coords_test,
        MODEL_NAME,
        run_mc_dropout=True, save_predictions=True
    )
    
    print(f"\n{'='*100}")
    print(f"{'✓ TRAINING AND EVALUATION COMPLETED!':^100s}")
    print(f"{'='*100}")
    print(f"\nModel: V8 — Enhanced Online Aug + Post-Processing + TTA (Phases 1-3)")
    print(f"Parameters: {params:,}")
    print(f"ROI Extraction: Padding={PADDING_FACTOR}×, Size=(512, 512)")
    print(f"Results saved in: {save_dir}/")
    print(f"\n{'='*100}\n")
# Out:
# 2026-06-07 18:02:05.763948: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780855325.959338      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780855326.019170      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1780855326.480478      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780855326.480519      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780855326.480521      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780855326.480524      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Configuring GPU settings...
# ✓ GPU configured: 1 device(s) available
#
# ====================================================================================================
#                     V8: ENHANCED ONLINE AUG + POST-PROCESSING + TTA (Phases 1-3)
# ====================================================================================================
#
# Phase 1 — Enhanced Online Augmentation:
#   - NO offline augmentation (keeps ~1hr training time)
#   - Enhanced online pipeline (RandomRotate90, GridDistortion, GaussNoise, CLAHE, CoarseDropout)
#   - ROI padding: 1.2× (same as V5)
#
# Phase 2 — Post-Processing:
#   - Largest connected component → Morphological closing → Hole filling → Median filter
#   - Anatomical constraint: cup ⊂ disc
#
# Phase 3 — Test-Time Augmentation:
#   - 4-pass flip ensemble (orig, hflip, vflip, both)
#
# Training Config (same as V5):
#   - Adam lr=2e-4, ReduceLROnPlateau, 80 epochs, patience=15
#   - Focal loss alpha=[0.25, 1.0, 1.0] + Enhanced IoU
#
# ================================================================================
# HIGH-RES ROI DATA LOADING
# ================================================================================
#   Loading at original resolution, extracting ROI, resizing to 512x512
#   Padding factor: 1.2× (20% margin around disc)
#   train: 400 samples (original resolution -> ROI extracted)
#   val: 400 samples (original resolution -> ROI extracted)
#   test: 400 samples (original resolution -> ROI extracted)
#
#   Split - Train: 600, Val: 200, Test: 400
#   ROI shape: (512, 512, 3) per image
#
# ================================================================================
# TRAINING: V8_Boosted_P1P2P3
# ================================================================================
#   Architecture: Deeper Decoder + MSCA + LBFR + PPM + Focal-EIoU + MC Dropout
#   Loss: Focal + Enhanced IoU (Combined)
#   ROI Extraction: ENABLED (padding=1.5×, training on disc-centered crops)
# I0000 00:00:1780855475.077926      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# Model Configuration:
#   Total Parameters: 47,631,627
#   Dropout Layers: 5
#   Triple Attention: MSCA + LBFR + PPM per decoder block (12 total)
# Epoch 1/80
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780855550.766269      73 service.cc:152] XLA service 0x7979dc003fb0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1780855550.766329      73 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1780855569.096110      73 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-06-07 18:06:26.700880: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 18:06:26.956237: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 18:06:28.643908: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 18:06:28.879102: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 18:06:44.172639: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 18:06:44.408004: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1780855683.333790      73 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.6366 - dice_class_0: 0.7445 - dice_class_1: 0.5900 - dice_class_2: 0.4325 - dice_coef_multiclass: 0.5467 - iou_class_0: 0.6243 - iou_class_1: 0.4424 - iou_class_2: 0.3053 - iou_coef_multiclass: 0.3905 - loss: 1.0381
# 2026-06-07 18:09:19.121855: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-06-07 18:09:19.377213: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Epoch 1: val_loss improved from None to 2.75374, saving model to results/V8_Boosted_P1P2P3.keras
#
# Epoch 1: finished saving model to results/V8_Boosted_P1P2P3.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 304s 614ms/step - accuracy: 0.7720 - dice_class_0: 0.8561 - dice_class_1: 0.7184 - dice_class_2: 0.6114 - dice_coef_multiclass: 0.6691 - iou_class_0: 0.7656 - iou_class_1: 0.5778 - iou_class_2: 0.4704 - iou_coef_multiclass: 0.5160 - loss: 0.7965 - val_accuracy: 0.7145 - val_dice_class_0: 0.8731 - val_dice_class_1: 0.4118 - val_dice_class_2: 0.5952 - val_dice_coef_multiclass: 0.6928 - val_iou_class_0: 0.7752 - val_iou_class_1: 0.2598 - val_iou_class_2: 0.4270 - val_iou_coef_multiclass: 0.5303 - val_loss: 2.7537 - learning_rate: 2.0000e-04
# Epoch 2/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.8757 - dice_class_0: 0.9291 - dice_class_1: 0.8239 - dice_class_2: 0.7925 - dice_coef_multiclass: 0.7982 - iou_class_0: 0.8683 - iou_class_1: 0.7034 - iou_class_2: 0.6603 - iou_coef_multiclass: 0.6651 - loss: 0.5927
# Epoch 2: val_loss improved from 2.75374 to 2.74097, saving model to results/V8_Boosted_P1P2P3.keras
#
# Epoch 2: finished saving model to results/V8_Boosted_P1P2P3.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 68s 456ms/step - accuracy: 0.8810 - dice_class_0: 0.9302 - dice_class_1: 0.8337 - dice_class_2: 0.8054 - dice_coef_multiclass: 0.8133 - iou_class_0: 0.8701 - iou_class_1: 0.7171 - iou_class_2: 0.6782 - iou_coef_multiclass: 0.6861 - loss: 0.5635 - val_accuracy: 0.7961 - val_dice_class_0: 0.9255 - val_dice_class_1: 0.6755 - val_dice_class_2: 0.6492 - val_dice_coef_multiclass: 0.7849 - val_iou_class_0: 0.8619 - val_iou_class_1: 0.5126 - val_iou_class_2: 0.4851 - val_iou_coef_multiclass: 0.6471 - val_loss: 2.7410 - learning_rate: 2.0000e-04
# Epoch 3/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.8869 - dice_class_0: 0.9348 - dice_class_1: 0.8397 - dice_class_2: 0.8155 - dice_coef_multiclass: 0.8279 - iou_class_0: 0.8782 - iou_class_1: 0.7257 - iou_class_2: 0.6911 - iou_coef_multiclass: 0.7069 - loss: 0.5388
# Epoch 3: val_loss improved from 2.74097 to 1.31934, saving model to results/V8_Boosted_P1P2P3.keras
#
# Epoch 3: finished saving model to results/V8_Boosted_P1P2P3.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 68s 455ms/step - accuracy: 0.8927 - dice_class_0: 0.9383 - dice_class_1: 0.8498 - dice_class_2: 0.8200 - dice_coef_multiclass: 0.8350 - iou_class_0: 0.8842 - iou_class_1: 0.7405 - iou_class_2: 0.6977 - iou_coef_multiclass: 0.7174 - loss: 0.5166 - val_accuracy: 0.8012 - val_dice_class_0: 0.8862 - val_dice_class_1: 0.6271 - val_dice_class_2: 0.7669 - val_dice_coef_multiclass: 0.7937 - val_iou_class_0: 0.7967 - val_iou_class_1: 0.4595 - val_iou_class_2: 0.6258 - val_iou_coef_multiclass: 0.6588 - val_loss: 1.3193 - learning_rate: 2.0000e-04
# Epoch 4/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.8987 - dice_class_0: 0.9407 - dice_class_1: 0.8596 - dice_class_2: 0.8313 - dice_coef_multiclass: 0.8455 - iou_class_0: 0.8886 - iou_class_1: 0.7553 - iou_class_2: 0.7142 - iou_coef_multiclass: 0.7326 - loss: 0.4733
# Epoch 4: val_loss did not improve from 1.31934
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 429ms/step - accuracy: 0.8974 - dice_class_0: 0.9403 - dice_class_1: 0.8571 - dice_class_2: 0.8299 - dice_coef_multiclass: 0.8437 - iou_class_0: 0.8878 - iou_class_1: 0.7517 - iou_class_2: 0.7123 - iou_coef_multiclass: 0.7302 - loss: 0.4763 - val_accuracy: 0.7865 - val_dice_class_0: 0.8820 - val_dice_class_1: 0.5819 - val_dice_class_2: 0.7522 - val_dice_coef_multiclass: 0.7752 - val_iou_class_0: 0.7896 - val_iou_class_1: 0.4126 - val_iou_class_2: 0.6062 - val_iou_coef_multiclass: 0.6335 - val_loss: 1.5778 - learning_rate: 2.0000e-04
# Epoch 5/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.9026 - dice_class_0: 0.9452 - dice_class_1: 0.8628 - dice_class_2: 0.8347 - dice_coef_multiclass: 0.8531 - iou_class_0: 0.8965 - iou_class_1: 0.7602 - iou_class_2: 0.7189 - iou_coef_multiclass: 0.7442 - loss: 0.4495
# Epoch 5: val_loss improved from 1.31934 to 1.19913, saving model to results/V8_Boosted_P1P2P3.keras
#
# Epoch 5: finished saving model to results/V8_Boosted_P1P2P3.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 69s 457ms/step - accuracy: 0.9036 - dice_class_0: 0.9450 - dice_class_1: 0.8648 - dice_class_2: 0.8362 - dice_coef_multiclass: 0.8537 - iou_class_0: 0.8962 - iou_class_1: 0.7633 - iou_class_2: 0.7213 - iou_coef_multiclass: 0.7451 - loss: 0.4461 - val_accuracy: 0.7942 - val_dice_class_0: 0.8743 - val_dice_class_1: 0.6143 - val_dice_class_2: 0.7788 - val_dice_coef_multiclass: 0.7876 - val_iou_class_0: 0.7779 - val_iou_class_1: 0.4491 - val_iou_class_2: 0.6407 - val_iou_coef_multiclass: 0.6510 - val_loss: 1.1991 - learning_rate: 2.0000e-04
# Epoch 6/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9034 - dice_class_0: 0.9453 - dice_class_1: 0.8655 - dice_class_2: 0.8344 - dice_coef_multiclass: 0.8559 - iou_class_0: 0.8966 - iou_class_1: 0.7642 - iou_class_2: 0.7186 - iou_coef_multiclass: 0.7483 - loss: 0.4444
# Epoch 6: val_loss did not improve from 1.19913
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 429ms/step - accuracy: 0.9060 - dice_class_0: 0.9467 - dice_class_1: 0.8681 - dice_class_2: 0.8381 - dice_coef_multiclass: 0.8591 - iou_class_0: 0.8990 - iou_class_1: 0.7684 - iou_class_2: 0.7243 - iou_coef_multiclass: 0.7533 - loss: 0.4341 - val_accuracy: 0.6885 - val_dice_class_0: 0.9091 - val_dice_class_1: 0.4231 - val_dice_class_2: 0.4955 - val_dice_coef_multiclass: 0.6597 - val_iou_class_0: 0.8339 - val_iou_class_1: 0.2693 - val_iou_class_2: 0.3318 - val_iou_coef_multiclass: 0.4929 - val_loss: 3.3501 - learning_rate: 2.0000e-04
# Epoch 7/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9126 - dice_class_0: 0.9482 - dice_class_1: 0.8778 - dice_class_2: 0.8581 - dice_coef_multiclass: 0.8660 - iou_class_0: 0.9020 - iou_class_1: 0.7833 - iou_class_2: 0.7528 - iou_coef_multiclass: 0.7640 - loss: 0.4062
# Epoch 7: val_loss did not improve from 1.19913
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 429ms/step - accuracy: 0.9110 - dice_class_0: 0.9483 - dice_class_1: 0.8750 - dice_class_2: 0.8532 - dice_coef_multiclass: 0.8648 - iou_class_0: 0.9021 - iou_class_1: 0.7789 - iou_class_2: 0.7460 - iou_coef_multiclass: 0.7621 - loss: 0.4168 - val_accuracy: 0.8175 - val_dice_class_0: 0.9337 - val_dice_class_1: 0.7159 - val_dice_class_2: 0.6680 - val_dice_coef_multiclass: 0.7828 - val_iou_class_0: 0.8759 - val_iou_class_1: 0.5597 - val_iou_class_2: 0.5076 - val_iou_coef_multiclass: 0.6439 - val_loss: 1.2730 - learning_rate: 2.0000e-04
# Epoch 8/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.9093 - dice_class_0: 0.9495 - dice_class_1: 0.8725 - dice_class_2: 0.8427 - dice_coef_multiclass: 0.8642 - iou_class_0: 0.9041 - iou_class_1: 0.7752 - iou_class_2: 0.7309 - iou_coef_multiclass: 0.7611 - loss: 0.4167
# Epoch 8: val_loss improved from 1.19913 to 0.88032, saving model to results/V8_Boosted_P1P2P3.keras
#
# Epoch 8: finished saving model to results/V8_Boosted_P1P2P3.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 69s 457ms/step - accuracy: 0.9114 - dice_class_0: 0.9506 - dice_class_1: 0.8754 - dice_class_2: 0.8456 - dice_coef_multiclass: 0.8671 - iou_class_0: 0.9061 - iou_class_1: 0.7797 - iou_class_2: 0.7350 - iou_coef_multiclass: 0.7657 - loss: 0.4076 - val_accuracy: 0.8747 - val_dice_class_0: 0.9553 - val_dice_class_1: 0.7922 - val_dice_class_2: 0.7498 - val_dice_coef_multiclass: 0.8492 - val_iou_class_0: 0.9146 - val_iou_class_1: 0.6586 - val_iou_class_2: 0.6055 - val_iou_coef_multiclass: 0.7387 - val_loss: 0.8803 - learning_rate: 2.0000e-04
# Epoch 9/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9125 - dice_class_0: 0.9508 - dice_class_1: 0.8775 - dice_class_2: 0.8500 - dice_coef_multiclass: 0.8691 - iou_class_0: 0.9065 - iou_class_1: 0.7831 - iou_class_2: 0.7416 - iou_coef_multiclass: 0.7688 - loss: 0.4111
# Epoch 9: val_loss did not improve from 0.88032
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 429ms/step - accuracy: 0.9136 - dice_class_0: 0.9515 - dice_class_1: 0.8789 - dice_class_2: 0.8509 - dice_coef_multiclass: 0.8702 - iou_class_0: 0.9077 - iou_class_1: 0.7851 - iou_class_2: 0.7427 - iou_coef_multiclass: 0.7705 - loss: 0.4048 - val_accuracy: 0.7454 - val_dice_class_0: 0.8794 - val_dice_class_1: 0.6418 - val_dice_class_2: 0.5956 - val_dice_coef_multiclass: 0.7235 - val_iou_class_0: 0.7882 - val_iou_class_1: 0.4812 - val_iou_class_2: 0.4335 - val_iou_coef_multiclass: 0.5719 - val_loss: 1.3317 - learning_rate: 2.0000e-04
# Epoch 10/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9111 - dice_class_0: 0.9510 - dice_class_1: 0.8740 - dice_class_2: 0.8485 - dice_coef_multiclass: 0.8645 - iou_class_0: 0.9068 - iou_class_1: 0.7780 - iou_class_2: 0.7395 - iou_coef_multiclass: 0.7619 - loss: 0.4158
# Epoch 10: val_loss did not improve from 0.88032
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 429ms/step - accuracy: 0.9114 - dice_class_0: 0.9500 - dice_class_1: 0.8756 - dice_class_2: 0.8502 - dice_coef_multiclass: 0.8660 - iou_class_0: 0.9050 - iou_class_1: 0.7804 - iou_class_2: 0.7421 - iou_coef_multiclass: 0.7641 - loss: 0.4106 - val_accuracy: 0.8288 - val_dice_class_0: 0.9515 - val_dice_class_1: 0.7141 - val_dice_class_2: 0.6625 - val_dice_coef_multiclass: 0.8050 - val_iou_class_0: 0.9079 - val_iou_class_1: 0.5604 - val_iou_class_2: 0.5019 - val_iou_coef_multiclass: 0.6752 - val_loss: 0.9564 - learning_rate: 2.0000e-04
# Epoch 11/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.9162 - dice_class_0: 0.9550 - dice_class_1: 0.8833 - dice_class_2: 0.8491 - dice_coef_multiclass: 0.8740 - iou_class_0: 0.9141 - iou_class_1: 0.7924 - iou_class_2: 0.7409 - iou_coef_multiclass: 0.7766 - loss: 0.3935
# Epoch 11: val_loss did not improve from 0.88032
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 430ms/step - accuracy: 0.9187 - dice_class_0: 0.9554 - dice_class_1: 0.8859 - dice_class_2: 0.8557 - dice_coef_multiclass: 0.8781 - iou_class_0: 0.9148 - iou_class_1: 0.7964 - iou_class_2: 0.7501 - iou_coef_multiclass: 0.7831 - loss: 0.3801 - val_accuracy: 0.5293 - val_dice_class_0: 0.6956 - val_dice_class_1: 0.3959 - val_dice_class_2: 0.4262 - val_dice_coef_multiclass: 0.5211 - val_iou_class_0: 0.5374 - val_iou_class_1: 0.2513 - val_iou_class_2: 0.2738 - val_iou_coef_multiclass: 0.3551 - val_loss: 2.3418 - learning_rate: 2.0000e-04
# Epoch 12/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.9197 - dice_class_0: 0.9554 - dice_class_1: 0.8880 - dice_class_2: 0.8593 - dice_coef_multiclass: 0.8783 - iou_class_0: 0.9149 - iou_class_1: 0.7996 - iou_class_2: 0.7555 - iou_coef_multiclass: 0.7834 - loss: 0.3762
# Epoch 12: val_loss improved from 0.88032 to 0.41535, saving model to results/V8_Boosted_P1P2P3.keras
#
# Epoch 12: finished saving model to results/V8_Boosted_P1P2P3.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 68s 457ms/step - accuracy: 0.9176 - dice_class_0: 0.9541 - dice_class_1: 0.8849 - dice_class_2: 0.8558 - dice_coef_multiclass: 0.8764 - iou_class_0: 0.9125 - iou_class_1: 0.7948 - iou_class_2: 0.7506 - iou_coef_multiclass: 0.7804 - loss: 0.3852 - val_accuracy: 0.9190 - val_dice_class_0: 0.9609 - val_dice_class_1: 0.8813 - val_dice_class_2: 0.8487 - val_dice_coef_multiclass: 0.8813 - val_iou_class_0: 0.9249 - val_iou_class_1: 0.7892 - val_iou_class_2: 0.7397 - val_iou_coef_multiclass: 0.7883 - val_loss: 0.4154 - learning_rate: 2.0000e-04
# Epoch 13/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9174 - dice_class_0: 0.9531 - dice_class_1: 0.8858 - dice_class_2: 0.8566 - dice_coef_multiclass: 0.8746 - iou_class_0: 0.9107 - iou_class_1: 0.7960 - iou_class_2: 0.7508 - iou_coef_multiclass: 0.7775 - loss: 0.3848
# Epoch 13: val_loss did not improve from 0.41535
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 428ms/step - accuracy: 0.9198 - dice_class_0: 0.9548 - dice_class_1: 0.8876 - dice_class_2: 0.8620 - dice_coef_multiclass: 0.8788 - iou_class_0: 0.9138 - iou_class_1: 0.7988 - iou_class_2: 0.7592 - iou_coef_multiclass: 0.7842 - loss: 0.3740 - val_accuracy: 0.8814 - val_dice_class_0: 0.9442 - val_dice_class_1: 0.8246 - val_dice_class_2: 0.7782 - val_dice_coef_multiclass: 0.8589 - val_iou_class_0: 0.8950 - val_iou_class_1: 0.7060 - val_iou_class_2: 0.6449 - val_iou_coef_multiclass: 0.7548 - val_loss: 0.6013 - learning_rate: 2.0000e-04
# Epoch 14/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.9181 - dice_class_0: 0.9532 - dice_class_1: 0.8862 - dice_class_2: 0.8598 - dice_coef_multiclass: 0.8780 - iou_class_0: 0.9109 - iou_class_1: 0.7967 - iou_class_2: 0.7560 - iou_coef_multiclass: 0.7829 - loss: 0.3810
# Epoch 14: val_loss did not improve from 0.41535
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 430ms/step - accuracy: 0.9188 - dice_class_0: 0.9548 - dice_class_1: 0.8864 - dice_class_2: 0.8575 - dice_coef_multiclass: 0.8782 - iou_class_0: 0.9138 - iou_class_1: 0.7971 - iou_class_2: 0.7527 - iou_coef_multiclass: 0.7833 - loss: 0.3801 - val_accuracy: 0.8887 - val_dice_class_0: 0.9599 - val_dice_class_1: 0.8274 - val_dice_class_2: 0.7750 - val_dice_coef_multiclass: 0.8610 - val_iou_class_0: 0.9230 - val_iou_class_1: 0.7075 - val_iou_class_2: 0.6381 - val_iou_coef_multiclass: 0.7566 - val_loss: 0.5262 - learning_rate: 2.0000e-04
# Epoch 15/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.9166 - dice_class_0: 0.9521 - dice_class_1: 0.8824 - dice_class_2: 0.8592 - dice_coef_multiclass: 0.8759 - iou_class_0: 0.9090 - iou_class_1: 0.7906 - iou_class_2: 0.7553 - iou_coef_multiclass: 0.7795 - loss: 0.3877
# Epoch 15: val_loss did not improve from 0.41535
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 430ms/step - accuracy: 0.9194 - dice_class_0: 0.9539 - dice_class_1: 0.8878 - dice_class_2: 0.8636 - dice_coef_multiclass: 0.8800 - iou_class_0: 0.9121 - iou_class_1: 0.7992 - iou_class_2: 0.7618 - iou_coef_multiclass: 0.7860 - loss: 0.3734 - val_accuracy: 0.9182 - val_dice_class_0: 0.9597 - val_dice_class_1: 0.8844 - val_dice_class_2: 0.8299 - val_dice_coef_multiclass: 0.8756 - val_iou_class_0: 0.9227 - val_iou_class_1: 0.7940 - val_iou_class_2: 0.7122 - val_iou_coef_multiclass: 0.7792 - val_loss: 0.4233 - learning_rate: 2.0000e-04
# Epoch 16/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9199 - dice_class_0: 0.9548 - dice_class_1: 0.8874 - dice_class_2: 0.8650 - dice_coef_multiclass: 0.8777 - iou_class_0: 0.9137 - iou_class_1: 0.7985 - iou_class_2: 0.7640 - iou_coef_multiclass: 0.7823 - loss: 0.3733
# Epoch 16: val_loss improved from 0.41535 to 0.38084, saving model to results/V8_Boosted_P1P2P3.keras
#
# Epoch 16: finished saving model to results/V8_Boosted_P1P2P3.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 464ms/step - accuracy: 0.9206 - dice_class_0: 0.9553 - dice_class_1: 0.8894 - dice_class_2: 0.8639 - dice_coef_multiclass: 0.8799 - iou_class_0: 0.9146 - iou_class_1: 0.8017 - iou_class_2: 0.7621 - iou_coef_multiclass: 0.7859 - loss: 0.3686 - val_accuracy: 0.9222 - val_dice_class_0: 0.9626 - val_dice_class_1: 0.8867 - val_dice_class_2: 0.8520 - val_dice_coef_multiclass: 0.8957 - val_iou_class_0: 0.9279 - val_iou_class_1: 0.7976 - val_iou_class_2: 0.7457 - val_iou_coef_multiclass: 0.8116 - val_loss: 0.3808 - learning_rate: 2.0000e-04
# Epoch 17/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.9228 - dice_class_0: 0.9578 - dice_class_1: 0.8922 - dice_class_2: 0.8601 - dice_coef_multiclass: 0.8863 - iou_class_0: 0.9192 - iou_class_1: 0.8063 - iou_class_2: 0.7563 - iou_coef_multiclass: 0.7960 - loss: 0.3662
# Epoch 17: val_loss did not improve from 0.38084
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 430ms/step - accuracy: 0.9242 - dice_class_0: 0.9578 - dice_class_1: 0.8937 - dice_class_2: 0.8679 - dice_coef_multiclass: 0.8874 - iou_class_0: 0.9192 - iou_class_1: 0.8087 - iou_class_2: 0.7683 - iou_coef_multiclass: 0.7978 - loss: 0.3559 - val_accuracy: 0.8973 - val_dice_class_0: 0.9500 - val_dice_class_1: 0.8508 - val_dice_class_2: 0.8161 - val_dice_coef_multiclass: 0.8741 - val_iou_class_0: 0.9049 - val_iou_class_1: 0.7428 - val_iou_class_2: 0.6944 - val_iou_coef_multiclass: 0.7772 - val_loss: 0.5006 - learning_rate: 2.0000e-04
# Epoch 18/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.9254 - dice_class_0: 0.9579 - dice_class_1: 0.8960 - dice_class_2: 0.8711 - dice_coef_multiclass: 0.8876 - iou_class_0: 0.9194 - iou_class_1: 0.8124 - iou_class_2: 0.7730 - iou_coef_multiclass: 0.7982 - loss: 0.3482
# Epoch 18: val_loss improved from 0.38084 to 0.34982, saving model to results/V8_Boosted_P1P2P3.keras
#
# Epoch 18: finished saving model to results/V8_Boosted_P1P2P3.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 69s 457ms/step - accuracy: 0.9232 - dice_class_0: 0.9567 - dice_class_1: 0.8925 - dice_class_2: 0.8671 - dice_coef_multiclass: 0.8849 - iou_class_0: 0.9173 - iou_class_1: 0.8070 - iou_class_2: 0.7670 - iou_coef_multiclass: 0.7939 - loss: 0.3600 - val_accuracy: 0.9238 - val_dice_class_0: 0.9596 - val_dice_class_1: 0.8830 - val_dice_class_2: 0.8726 - val_dice_coef_multiclass: 0.9012 - val_iou_class_0: 0.9225 - val_iou_class_1: 0.7920 - val_iou_class_2: 0.7772 - val_iou_coef_multiclass: 0.8206 - val_loss: 0.3498 - learning_rate: 2.0000e-04
# Epoch 19/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.9220 - dice_class_0: 0.9564 - dice_class_1: 0.8892 - dice_class_2: 0.8665 - dice_coef_multiclass: 0.8841 - iou_class_0: 0.9168 - iou_class_1: 0.8017 - iou_class_2: 0.7663 - iou_coef_multiclass: 0.7926 - loss: 0.3657
# Epoch 19: val_loss did not improve from 0.34982
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 429ms/step - accuracy: 0.9241 - dice_class_0: 0.9571 - dice_class_1: 0.8938 - dice_class_2: 0.8688 - dice_coef_multiclass: 0.8865 - iou_class_0: 0.9179 - iou_class_1: 0.8088 - iou_class_2: 0.7699 - iou_coef_multiclass: 0.7964 - loss: 0.3574 - val_accuracy: 0.9303 - val_dice_class_0: 0.9640 - val_dice_class_1: 0.9055 - val_dice_class_2: 0.8517 - val_dice_coef_multiclass: 0.9122 - val_iou_class_0: 0.9306 - val_iou_class_1: 0.8278 - val_iou_class_2: 0.7436 - val_iou_coef_multiclass: 0.8388 - val_loss: 0.4110 - learning_rate: 2.0000e-04
# Epoch 20/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.9248 - dice_class_0: 0.9588 - dice_class_1: 0.8932 - dice_class_2: 0.8649 - dice_coef_multiclass: 0.8878 - iou_class_0: 0.9211 - iou_class_1: 0.8079 - iou_class_2: 0.7636 - iou_coef_multiclass: 0.7986 - loss: 0.3566
# Epoch 20: val_loss did not improve from 0.34982
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 430ms/step - accuracy: 0.9255 - dice_class_0: 0.9586 - dice_class_1: 0.8952 - dice_class_2: 0.8681 - dice_coef_multiclass: 0.8883 - iou_class_0: 0.9207 - iou_class_1: 0.8112 - iou_class_2: 0.7690 - iou_coef_multiclass: 0.7994 - loss: 0.3535 - val_accuracy: 0.9159 - val_dice_class_0: 0.9527 - val_dice_class_1: 0.8812 - val_dice_class_2: 0.8654 - val_dice_coef_multiclass: 0.8990 - val_iou_class_0: 0.9097 - val_iou_class_1: 0.7881 - val_iou_class_2: 0.7649 - val_iou_coef_multiclass: 0.8167 - val_loss: 0.4154 - learning_rate: 2.0000e-04
# Epoch 21/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9253 - dice_class_0: 0.9586 - dice_class_1: 0.8946 - dice_class_2: 0.8700 - dice_coef_multiclass: 0.8880 - iou_class_0: 0.9207 - iou_class_1: 0.8101 - iou_class_2: 0.7715 - iou_coef_multiclass: 0.7988 - loss: 0.3525
# Epoch 21: val_loss did not improve from 0.34982
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 429ms/step - accuracy: 0.9255 - dice_class_0: 0.9581 - dice_class_1: 0.8963 - dice_class_2: 0.8705 - dice_coef_multiclass: 0.8888 - iou_class_0: 0.9198 - iou_class_1: 0.8128 - iou_class_2: 0.7722 - iou_coef_multiclass: 0.8001 - loss: 0.3508 - val_accuracy: 0.9200 - val_dice_class_0: 0.9584 - val_dice_class_1: 0.8841 - val_dice_class_2: 0.8619 - val_dice_coef_multiclass: 0.8807 - val_iou_class_0: 0.9203 - val_iou_class_1: 0.7938 - val_iou_class_2: 0.7608 - val_iou_coef_multiclass: 0.7876 - val_loss: 0.3725 - learning_rate: 2.0000e-04
# Epoch 22/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9253 - dice_class_0: 0.9597 - dice_class_1: 0.8944 - dice_class_2: 0.8625 - dice_coef_multiclass: 0.8874 - iou_class_0: 0.9227 - iou_class_1: 0.8099 - iou_class_2: 0.7602 - iou_coef_multiclass: 0.7980 - loss: 0.3555
# Epoch 22: val_loss did not improve from 0.34982
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 429ms/step - accuracy: 0.9256 - dice_class_0: 0.9594 - dice_class_1: 0.8951 - dice_class_2: 0.8653 - dice_coef_multiclass: 0.8883 - iou_class_0: 0.9221 - iou_class_1: 0.8111 - iou_class_2: 0.7644 - iou_coef_multiclass: 0.7994 - loss: 0.3538 - val_accuracy: 0.9313 - val_dice_class_0: 0.9664 - val_dice_class_1: 0.9001 - val_dice_class_2: 0.8711 - val_dice_coef_multiclass: 0.9007 - val_iou_class_0: 0.9350 - val_iou_class_1: 0.8190 - val_iou_class_2: 0.7735 - val_iou_coef_multiclass: 0.8195 - val_loss: 0.3566 - learning_rate: 2.0000e-04
# Epoch 23/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9291 - dice_class_0: 0.9610 - dice_class_1: 0.9002 - dice_class_2: 0.8747 - dice_coef_multiclass: 0.8939 - iou_class_0: 0.9251 - iou_class_1: 0.8193 - iou_class_2: 0.7789 - iou_coef_multiclass: 0.8085 - loss: 0.3365
# Epoch 23: val_loss improved from 0.34982 to 0.34430, saving model to results/V8_Boosted_P1P2P3.keras
#
# Epoch 23: finished saving model to results/V8_Boosted_P1P2P3.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 68s 455ms/step - accuracy: 0.9307 - dice_class_0: 0.9619 - dice_class_1: 0.9031 - dice_class_2: 0.8765 - dice_coef_multiclass: 0.8954 - iou_class_0: 0.9266 - iou_class_1: 0.8241 - iou_class_2: 0.7817 - iou_coef_multiclass: 0.8108 - loss: 0.3303 - val_accuracy: 0.9251 - val_dice_class_0: 0.9574 - val_dice_class_1: 0.8988 - val_dice_class_2: 0.8644 - val_dice_coef_multiclass: 0.9011 - val_iou_class_0: 0.9185 - val_iou_class_1: 0.8167 - val_iou_class_2: 0.7627 - val_iou_coef_multiclass: 0.8202 - val_loss: 0.3443 - learning_rate: 1.0000e-04
# Epoch 24/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9351 - dice_class_0: 0.9646 - dice_class_1: 0.9090 - dice_class_2: 0.8815 - dice_coef_multiclass: 0.9037 - iou_class_0: 0.9318 - iou_class_1: 0.8338 - iou_class_2: 0.7894 - iou_coef_multiclass: 0.8245 - loss: 0.3140
# Epoch 24: val_loss improved from 0.34430 to 0.30227, saving model to results/V8_Boosted_P1P2P3.keras
#
# Epoch 24: finished saving model to results/V8_Boosted_P1P2P3.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 68s 457ms/step - accuracy: 0.9330 - dice_class_0: 0.9634 - dice_class_1: 0.9058 - dice_class_2: 0.8792 - dice_coef_multiclass: 0.8997 - iou_class_0: 0.9296 - iou_class_1: 0.8286 - iou_class_2: 0.7859 - iou_coef_multiclass: 0.8179 - loss: 0.3234 - val_accuracy: 0.9389 - val_dice_class_0: 0.9681 - val_dice_class_1: 0.9119 - val_dice_class_2: 0.8876 - val_dice_coef_multiclass: 0.9001 - val_iou_class_0: 0.9382 - val_iou_class_1: 0.8385 - val_iou_class_2: 0.7991 - val_iou_coef_multiclass: 0.8186 - val_loss: 0.3023 - learning_rate: 1.0000e-04
# Epoch 25/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9308 - dice_class_0: 0.9627 - dice_class_1: 0.9027 - dice_class_2: 0.8785 - dice_coef_multiclass: 0.8957 - iou_class_0: 0.9282 - iou_class_1: 0.8233 - iou_class_2: 0.7848 - iou_coef_multiclass: 0.8113 - loss: 0.3279
# Epoch 25: val_loss did not improve from 0.30227
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 428ms/step - accuracy: 0.9330 - dice_class_0: 0.9639 - dice_class_1: 0.9063 - dice_class_2: 0.8783 - dice_coef_multiclass: 0.8995 - iou_class_0: 0.9304 - iou_class_1: 0.8294 - iou_class_2: 0.7844 - iou_coef_multiclass: 0.8175 - loss: 0.3199 - val_accuracy: 0.9312 - val_dice_class_0: 0.9648 - val_dice_class_1: 0.9001 - val_dice_class_2: 0.8789 - val_dice_coef_multiclass: 0.9001 - val_iou_class_0: 0.9320 - val_iou_class_1: 0.8191 - val_iou_class_2: 0.7855 - val_iou_coef_multiclass: 0.8186 - val_loss: 0.3320 - learning_rate: 1.0000e-04
# Epoch 26/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9350 - dice_class_0: 0.9652 - dice_class_1: 0.9067 - dice_class_2: 0.8814 - dice_coef_multiclass: 0.9028 - iou_class_0: 0.9329 - iou_class_1: 0.8300 - iou_class_2: 0.7895 - iou_coef_multiclass: 0.8231 - loss: 0.3156
# Epoch 26: val_loss did not improve from 0.30227
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 428ms/step - accuracy: 0.9326 - dice_class_0: 0.9631 - dice_class_1: 0.9045 - dice_class_2: 0.8805 - dice_coef_multiclass: 0.8998 - iou_class_0: 0.9290 - iou_class_1: 0.8267 - iou_class_2: 0.7879 - iou_coef_multiclass: 0.8183 - loss: 0.3238 - val_accuracy: 0.9263 - val_dice_class_0: 0.9614 - val_dice_class_1: 0.8936 - val_dice_class_2: 0.8707 - val_dice_coef_multiclass: 0.8819 - val_iou_class_0: 0.9258 - val_iou_class_1: 0.8083 - val_iou_class_2: 0.7723 - val_iou_coef_multiclass: 0.7890 - val_loss: 0.3649 - learning_rate: 1.0000e-04
# Epoch 27/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9317 - dice_class_0: 0.9617 - dice_class_1: 0.9041 - dice_class_2: 0.8804 - dice_coef_multiclass: 0.8937 - iou_class_0: 0.9264 - iou_class_1: 0.8255 - iou_class_2: 0.7875 - iou_coef_multiclass: 0.8080 - loss: 0.3298
# Epoch 27: val_loss did not improve from 0.30227
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 428ms/step - accuracy: 0.9330 - dice_class_0: 0.9630 - dice_class_1: 0.9062 - dice_class_2: 0.8801 - dice_coef_multiclass: 0.8982 - iou_class_0: 0.9287 - iou_class_1: 0.8290 - iou_class_2: 0.7871 - iou_coef_multiclass: 0.8154 - loss: 0.3209 - val_accuracy: 0.9373 - val_dice_class_0: 0.9665 - val_dice_class_1: 0.9096 - val_dice_class_2: 0.8873 - val_dice_coef_multiclass: 0.9167 - val_iou_class_0: 0.9352 - val_iou_class_1: 0.8348 - val_iou_class_2: 0.7986 - val_iou_coef_multiclass: 0.8464 - val_loss: 0.3074 - learning_rate: 1.0000e-04
# Epoch 28/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9331 - dice_class_0: 0.9626 - dice_class_1: 0.9055 - dice_class_2: 0.8835 - dice_coef_multiclass: 0.9007 - iou_class_0: 0.9280 - iou_class_1: 0.8280 - iou_class_2: 0.7929 - iou_coef_multiclass: 0.8196 - loss: 0.3211
# Epoch 28: val_loss did not improve from 0.30227
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 429ms/step - accuracy: 0.9333 - dice_class_0: 0.9631 - dice_class_1: 0.9065 - dice_class_2: 0.8816 - dice_coef_multiclass: 0.9006 - iou_class_0: 0.9290 - iou_class_1: 0.8296 - iou_class_2: 0.7897 - iou_coef_multiclass: 0.8193 - loss: 0.3206 - val_accuracy: 0.9281 - val_dice_class_0: 0.9664 - val_dice_class_1: 0.8943 - val_dice_class_2: 0.8622 - val_dice_coef_multiclass: 0.8975 - val_iou_class_0: 0.9350 - val_iou_class_1: 0.8099 - val_iou_class_2: 0.7602 - val_iou_coef_multiclass: 0.8144 - val_loss: 0.3496 - learning_rate: 1.0000e-04
# Epoch 29/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9367 - dice_class_0: 0.9653 - dice_class_1: 0.9114 - dice_class_2: 0.8848 - dice_coef_multiclass: 0.9038 - iou_class_0: 0.9330 - iou_class_1: 0.8376 - iou_class_2: 0.7945 - iou_coef_multiclass: 0.8246 - loss: 0.3082
# Epoch 29: val_loss did not improve from 0.30227
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 428ms/step - accuracy: 0.9375 - dice_class_0: 0.9657 - dice_class_1: 0.9116 - dice_class_2: 0.8879 - dice_coef_multiclass: 0.9057 - iou_class_0: 0.9337 - iou_class_1: 0.8379 - iou_class_2: 0.7995 - iou_coef_multiclass: 0.8278 - loss: 0.3016 - val_accuracy: 0.9351 - val_dice_class_0: 0.9684 - val_dice_class_1: 0.9054 - val_dice_class_2: 0.8792 - val_dice_coef_multiclass: 0.9043 - val_iou_class_0: 0.9388 - val_iou_class_1: 0.8280 - val_iou_class_2: 0.7871 - val_iou_coef_multiclass: 0.8257 - val_loss: 0.3162 - learning_rate: 5.0000e-05
# Epoch 30/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9404 - dice_class_0: 0.9683 - dice_class_1: 0.9160 - dice_class_2: 0.8882 - dice_coef_multiclass: 0.9099 - iou_class_0: 0.9386 - iou_class_1: 0.8454 - iou_class_2: 0.7999 - iou_coef_multiclass: 0.8348 - loss: 0.2918
# Epoch 30: val_loss did not improve from 0.30227
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 428ms/step - accuracy: 0.9385 - dice_class_0: 0.9671 - dice_class_1: 0.9137 - dice_class_2: 0.8858 - dice_coef_multiclass: 0.9077 - iou_class_0: 0.9363 - iou_class_1: 0.8415 - iou_class_2: 0.7960 - iou_coef_multiclass: 0.8311 - loss: 0.2991 - val_accuracy: 0.9363 - val_dice_class_0: 0.9669 - val_dice_class_1: 0.9108 - val_dice_class_2: 0.8779 - val_dice_coef_multiclass: 0.9067 - val_iou_class_0: 0.9361 - val_iou_class_1: 0.8371 - val_iou_class_2: 0.7843 - val_iou_coef_multiclass: 0.8296 - val_loss: 0.3039 - learning_rate: 5.0000e-05
# Epoch 31/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9374 - dice_class_0: 0.9652 - dice_class_1: 0.9127 - dice_class_2: 0.8899 - dice_coef_multiclass: 0.9052 - iou_class_0: 0.9329 - iou_class_1: 0.8399 - iou_class_2: 0.8029 - iou_coef_multiclass: 0.8270 - loss: 0.3034
# Epoch 31: val_loss did not improve from 0.30227
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 428ms/step - accuracy: 0.9371 - dice_class_0: 0.9651 - dice_class_1: 0.9123 - dice_class_2: 0.8892 - dice_coef_multiclass: 0.9048 - iou_class_0: 0.9327 - iou_class_1: 0.8393 - iou_class_2: 0.8018 - iou_coef_multiclass: 0.8264 - loss: 0.3046 - val_accuracy: 0.9357 - val_dice_class_0: 0.9652 - val_dice_class_1: 0.9087 - val_dice_class_2: 0.8874 - val_dice_coef_multiclass: 0.9086 - val_iou_class_0: 0.9329 - val_iou_class_1: 0.8334 - val_iou_class_2: 0.7994 - val_iou_coef_multiclass: 0.8327 - val_loss: 0.3100 - learning_rate: 5.0000e-05
# Epoch 32/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9342 - dice_class_0: 0.9637 - dice_class_1: 0.9080 - dice_class_2: 0.8837 - dice_coef_multiclass: 0.9023 - iou_class_0: 0.9302 - iou_class_1: 0.8323 - iou_class_2: 0.7930 - iou_coef_multiclass: 0.8224 - loss: 0.3180
# Epoch 32: val_loss improved from 0.30227 to 0.29037, saving model to results/V8_Boosted_P1P2P3.keras
#
# Epoch 32: finished saving model to results/V8_Boosted_P1P2P3.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 68s 456ms/step - accuracy: 0.9359 - dice_class_0: 0.9647 - dice_class_1: 0.9103 - dice_class_2: 0.8855 - dice_coef_multiclass: 0.9037 - iou_class_0: 0.9321 - iou_class_1: 0.8361 - iou_class_2: 0.7959 - iou_coef_multiclass: 0.8247 - loss: 0.3106 - val_accuracy: 0.9414 - val_dice_class_0: 0.9691 - val_dice_class_1: 0.9179 - val_dice_class_2: 0.8868 - val_dice_coef_multiclass: 0.9153 - val_iou_class_0: 0.9401 - val_iou_class_1: 0.8488 - val_iou_class_2: 0.7980 - val_iou_coef_multiclass: 0.8440 - val_loss: 0.2904 - learning_rate: 5.0000e-05
# Epoch 33/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9383 - dice_class_0: 0.9648 - dice_class_1: 0.9140 - dice_class_2: 0.8933 - dice_coef_multiclass: 0.9080 - iou_class_0: 0.9322 - iou_class_1: 0.8422 - iou_class_2: 0.8086 - iou_coef_multiclass: 0.8316 - loss: 0.2958
# Epoch 33: val_loss did not improve from 0.29037
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 429ms/step - accuracy: 0.9381 - dice_class_0: 0.9654 - dice_class_1: 0.9133 - dice_class_2: 0.8917 - dice_coef_multiclass: 0.9074 - iou_class_0: 0.9331 - iou_class_1: 0.8410 - iou_class_2: 0.8058 - iou_coef_multiclass: 0.8306 - loss: 0.2977 - val_accuracy: 0.9398 - val_dice_class_0: 0.9697 - val_dice_class_1: 0.9155 - val_dice_class_2: 0.8820 - val_dice_coef_multiclass: 0.9116 - val_iou_class_0: 0.9412 - val_iou_class_1: 0.8449 - val_iou_class_2: 0.7910 - val_iou_coef_multiclass: 0.8378 - val_loss: 0.2984 - learning_rate: 5.0000e-05
# Epoch 34/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9385 - dice_class_0: 0.9670 - dice_class_1: 0.9127 - dice_class_2: 0.8895 - dice_coef_multiclass: 0.9075 - iou_class_0: 0.9361 - iou_class_1: 0.8401 - iou_class_2: 0.8025 - iou_coef_multiclass: 0.8308 - loss: 0.2982
# Epoch 34: val_loss did not improve from 0.29037
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 428ms/step - accuracy: 0.9389 - dice_class_0: 0.9667 - dice_class_1: 0.9142 - dice_class_2: 0.8891 - dice_coef_multiclass: 0.9081 - iou_class_0: 0.9356 - iou_class_1: 0.8425 - iou_class_2: 0.8017 - iou_coef_multiclass: 0.8319 - loss: 0.2978 - val_accuracy: 0.9341 - val_dice_class_0: 0.9629 - val_dice_class_1: 0.9090 - val_dice_class_2: 0.8822 - val_dice_coef_multiclass: 0.9073 - val_iou_class_0: 0.9286 - val_iou_class_1: 0.8337 - val_iou_class_2: 0.7906 - val_iou_coef_multiclass: 0.8304 - val_loss: 0.3126 - learning_rate: 5.0000e-05
# Epoch 35/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9362 - dice_class_0: 0.9641 - dice_class_1: 0.9110 - dice_class_2: 0.8898 - dice_coef_multiclass: 0.9055 - iou_class_0: 0.9309 - iou_class_1: 0.8371 - iou_class_2: 0.8028 - iou_coef_multiclass: 0.8275 - loss: 0.3012
# Epoch 35: val_loss did not improve from 0.29037
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 428ms/step - accuracy: 0.9380 - dice_class_0: 0.9661 - dice_class_1: 0.9131 - dice_class_2: 0.8880 - dice_coef_multiclass: 0.9074 - iou_class_0: 0.9344 - iou_class_1: 0.8406 - iou_class_2: 0.8000 - iou_coef_multiclass: 0.8307 - loss: 0.2989 - val_accuracy: 0.9353 - val_dice_class_0: 0.9650 - val_dice_class_1: 0.9069 - val_dice_class_2: 0.8904 - val_dice_coef_multiclass: 0.9070 - val_iou_class_0: 0.9325 - val_iou_class_1: 0.8303 - val_iou_class_2: 0.8044 - val_iou_coef_multiclass: 0.8301 - val_loss: 0.3024 - learning_rate: 5.0000e-05
# Epoch 36/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9399 - dice_class_0: 0.9671 - dice_class_1: 0.9151 - dice_class_2: 0.8924 - dice_coef_multiclass: 0.9095 - iou_class_0: 0.9365 - iou_class_1: 0.8441 - iou_class_2: 0.8067 - iou_coef_multiclass: 0.8343 - loss: 0.2919
# Epoch 36: val_loss did not improve from 0.29037
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 428ms/step - accuracy: 0.9398 - dice_class_0: 0.9673 - dice_class_1: 0.9150 - dice_class_2: 0.8906 - dice_coef_multiclass: 0.9099 - iou_class_0: 0.9368 - iou_class_1: 0.8438 - iou_class_2: 0.8040 - iou_coef_multiclass: 0.8349 - loss: 0.2935 - val_accuracy: 0.9371 - val_dice_class_0: 0.9673 - val_dice_class_1: 0.9110 - val_dice_class_2: 0.8833 - val_dice_coef_multiclass: 0.9055 - val_iou_class_0: 0.9368 - val_iou_class_1: 0.8372 - val_iou_class_2: 0.7927 - val_iou_coef_multiclass: 0.8276 - val_loss: 0.3086 - learning_rate: 5.0000e-05
# Epoch 37/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9409 - dice_class_0: 0.9668 - dice_class_1: 0.9174 - dice_class_2: 0.8947 - dice_coef_multiclass: 0.9097 - iou_class_0: 0.9358 - iou_class_1: 0.8478 - iou_class_2: 0.8105 - iou_coef_multiclass: 0.8345 - loss: 0.2873
# Epoch 37: val_loss improved from 0.29037 to 0.28195, saving model to results/V8_Boosted_P1P2P3.keras
#
# Epoch 37: finished saving model to results/V8_Boosted_P1P2P3.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 68s 456ms/step - accuracy: 0.9401 - dice_class_0: 0.9668 - dice_class_1: 0.9160 - dice_class_2: 0.8936 - dice_coef_multiclass: 0.9097 - iou_class_0: 0.9359 - iou_class_1: 0.8455 - iou_class_2: 0.8087 - iou_coef_multiclass: 0.8345 - loss: 0.2912 - val_accuracy: 0.9412 - val_dice_class_0: 0.9694 - val_dice_class_1: 0.9149 - val_dice_class_2: 0.8947 - val_dice_coef_multiclass: 0.9117 - val_iou_class_0: 0.9407 - val_iou_class_1: 0.8438 - val_iou_class_2: 0.8105 - val_iou_coef_multiclass: 0.8379 - val_loss: 0.2820 - learning_rate: 2.5000e-05
# Epoch 38/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9390 - dice_class_0: 0.9669 - dice_class_1: 0.9147 - dice_class_2: 0.8901 - dice_coef_multiclass: 0.9089 - iou_class_0: 0.9360 - iou_class_1: 0.8434 - iou_class_2: 0.8036 - iou_coef_multiclass: 0.8334 - loss: 0.2954
# Epoch 38: val_loss did not improve from 0.28195
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 428ms/step - accuracy: 0.9396 - dice_class_0: 0.9671 - dice_class_1: 0.9151 - dice_class_2: 0.8902 - dice_coef_multiclass: 0.9091 - iou_class_0: 0.9365 - iou_class_1: 0.8440 - iou_class_2: 0.8035 - iou_coef_multiclass: 0.8336 - loss: 0.2955 - val_accuracy: 0.9420 - val_dice_class_0: 0.9702 - val_dice_class_1: 0.9180 - val_dice_class_2: 0.8881 - val_dice_coef_multiclass: 0.9126 - val_iou_class_0: 0.9423 - val_iou_class_1: 0.8489 - val_iou_class_2: 0.7998 - val_iou_coef_multiclass: 0.8393 - val_loss: 0.2864 - learning_rate: 2.5000e-05
# Epoch 39/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9415 - dice_class_0: 0.9682 - dice_class_1: 0.9180 - dice_class_2: 0.8927 - dice_coef_multiclass: 0.9116 - iou_class_0: 0.9384 - iou_class_1: 0.8489 - iou_class_2: 0.8073 - iou_coef_multiclass: 0.8377 - loss: 0.2886
# Epoch 39: val_loss did not improve from 0.28195
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 428ms/step - accuracy: 0.9414 - dice_class_0: 0.9682 - dice_class_1: 0.9176 - dice_class_2: 0.8923 - dice_coef_multiclass: 0.9119 - iou_class_0: 0.9385 - iou_class_1: 0.8483 - iou_class_2: 0.8067 - iou_coef_multiclass: 0.8383 - loss: 0.2882 - val_accuracy: 0.9415 - val_dice_class_0: 0.9706 - val_dice_class_1: 0.9180 - val_dice_class_2: 0.8823 - val_dice_coef_multiclass: 0.9146 - val_iou_class_0: 0.9428 - val_iou_class_1: 0.8491 - val_iou_class_2: 0.7909 - val_iou_coef_multiclass: 0.8428 - val_loss: 0.2928 - learning_rate: 2.5000e-05
# Epoch 40/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9419 - dice_class_0: 0.9678 - dice_class_1: 0.9193 - dice_class_2: 0.8960 - dice_coef_multiclass: 0.9119 - iou_class_0: 0.9377 - iou_class_1: 0.8513 - iou_class_2: 0.8129 - iou_coef_multiclass: 0.8384 - loss: 0.2843
# Epoch 40: val_loss did not improve from 0.28195
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 427ms/step - accuracy: 0.9417 - dice_class_0: 0.9676 - dice_class_1: 0.9185 - dice_class_2: 0.8967 - dice_coef_multiclass: 0.9122 - iou_class_0: 0.9373 - iou_class_1: 0.8497 - iou_class_2: 0.8137 - iou_coef_multiclass: 0.8387 - loss: 0.2823 - val_accuracy: 0.9408 - val_dice_class_0: 0.9704 - val_dice_class_1: 0.9147 - val_dice_class_2: 0.8871 - val_dice_coef_multiclass: 0.9138 - val_iou_class_0: 0.9427 - val_iou_class_1: 0.8436 - val_iou_class_2: 0.7991 - val_iou_coef_multiclass: 0.8416 - val_loss: 0.2917 - learning_rate: 2.5000e-05
# Epoch 41/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9410 - dice_class_0: 0.9675 - dice_class_1: 0.9167 - dice_class_2: 0.8958 - dice_coef_multiclass: 0.9120 - iou_class_0: 0.9372 - iou_class_1: 0.8468 - iou_class_2: 0.8122 - iou_coef_multiclass: 0.8384 - loss: 0.2839
# Epoch 41: val_loss did not improve from 0.28195
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 429ms/step - accuracy: 0.9407 - dice_class_0: 0.9671 - dice_class_1: 0.9172 - dice_class_2: 0.8951 - dice_coef_multiclass: 0.9111 - iou_class_0: 0.9364 - iou_class_1: 0.8475 - iou_class_2: 0.8112 - iou_coef_multiclass: 0.8369 - loss: 0.2867 - val_accuracy: 0.9424 - val_dice_class_0: 0.9704 - val_dice_class_1: 0.9181 - val_dice_class_2: 0.8914 - val_dice_coef_multiclass: 0.9148 - val_iou_class_0: 0.9425 - val_iou_class_1: 0.8492 - val_iou_class_2: 0.8055 - val_iou_coef_multiclass: 0.8432 - val_loss: 0.2825 - learning_rate: 2.5000e-05
# Epoch 42/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9397 - dice_class_0: 0.9664 - dice_class_1: 0.9154 - dice_class_2: 0.8929 - dice_coef_multiclass: 0.9096 - iou_class_0: 0.9351 - iou_class_1: 0.8445 - iou_class_2: 0.8079 - iou_coef_multiclass: 0.8344 - loss: 0.2919
# Epoch 42: val_loss improved from 0.28195 to 0.27240, saving model to results/V8_Boosted_P1P2P3.keras
#
# Epoch 42: finished saving model to results/V8_Boosted_P1P2P3.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 68s 456ms/step - accuracy: 0.9419 - dice_class_0: 0.9678 - dice_class_1: 0.9184 - dice_class_2: 0.8963 - dice_coef_multiclass: 0.9124 - iou_class_0: 0.9377 - iou_class_1: 0.8496 - iou_class_2: 0.8134 - iou_coef_multiclass: 0.8391 - loss: 0.2831 - val_accuracy: 0.9435 - val_dice_class_0: 0.9704 - val_dice_class_1: 0.9196 - val_dice_class_2: 0.8964 - val_dice_coef_multiclass: 0.9190 - val_iou_class_0: 0.9426 - val_iou_class_1: 0.8518 - val_iou_class_2: 0.8131 - val_iou_coef_multiclass: 0.8504 - val_loss: 0.2724 - learning_rate: 1.2500e-05
# Epoch 43/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9438 - dice_class_0: 0.9692 - dice_class_1: 0.9204 - dice_class_2: 0.9003 - dice_coef_multiclass: 0.9154 - iou_class_0: 0.9403 - iou_class_1: 0.8530 - iou_class_2: 0.8197 - iou_coef_multiclass: 0.8441 - loss: 0.2722
# Epoch 43: val_loss did not improve from 0.27240
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 429ms/step - accuracy: 0.9428 - dice_class_0: 0.9688 - dice_class_1: 0.9196 - dice_class_2: 0.8962 - dice_coef_multiclass: 0.9143 - iou_class_0: 0.9395 - iou_class_1: 0.8516 - iou_class_2: 0.8132 - iou_coef_multiclass: 0.8423 - loss: 0.2781 - val_accuracy: 0.9427 - val_dice_class_0: 0.9703 - val_dice_class_1: 0.9182 - val_dice_class_2: 0.8924 - val_dice_coef_multiclass: 0.9159 - val_iou_class_0: 0.9424 - val_iou_class_1: 0.8493 - val_iou_class_2: 0.8075 - val_iou_coef_multiclass: 0.8450 - val_loss: 0.2815 - learning_rate: 1.2500e-05
# Epoch 44/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9414 - dice_class_0: 0.9678 - dice_class_1: 0.9173 - dice_class_2: 0.8958 - dice_coef_multiclass: 0.9124 - iou_class_0: 0.9378 - iou_class_1: 0.8476 - iou_class_2: 0.8123 - iou_coef_multiclass: 0.8391 - loss: 0.2849
# Epoch 44: val_loss improved from 0.27240 to 0.26419, saving model to results/V8_Boosted_P1P2P3.keras
#
# Epoch 44: finished saving model to results/V8_Boosted_P1P2P3.keras
# ...
# Epoch 48: val_loss did not improve from 0.26419
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 428ms/step - accuracy: 0.9434 - dice_class_0: 0.9691 - dice_class_1: 0.9201 - dice_class_2: 0.8970 - dice_coef_multiclass: 0.9149 - iou_class_0: 0.9402 - iou_class_1: 0.8526 - iou_class_2: 0.8144 - iou_coef_multiclass: 0.8433 - loss: 0.2770 - val_accuracy: 0.9451 - val_dice_class_0: 0.9724 - val_dice_class_1: 0.9211 - val_dice_class_2: 0.8942 - val_dice_coef_multiclass: 0.9177 - val_iou_class_0: 0.9463 - val_iou_class_1: 0.8543 - val_iou_class_2: 0.8100 - val_iou_coef_multiclass: 0.8480 - val_loss: 0.2757 - learning_rate: 1.2500e-05
# Epoch 49/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9439 - dice_class_0: 0.9688 - dice_class_1: 0.9216 - dice_class_2: 0.9000 - dice_coef_multiclass: 0.9150 - iou_class_0: 0.9396 - iou_class_1: 0.8552 - iou_class_2: 0.8194 - iou_coef_multiclass: 0.8436 - loss: 0.2727
# Epoch 49: val_loss did not improve from 0.26419
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 429ms/step - accuracy: 0.9432 - dice_class_0: 0.9686 - dice_class_1: 0.9202 - dice_class_2: 0.8984 - dice_coef_multiclass: 0.9146 - iou_class_0: 0.9392 - iou_class_1: 0.8527 - iou_class_2: 0.8166 - iou_coef_multiclass: 0.8428 - loss: 0.2773 - val_accuracy: 0.9447 - val_dice_class_0: 0.9713 - val_dice_class_1: 0.9211 - val_dice_class_2: 0.8960 - val_dice_coef_multiclass: 0.9192 - val_iou_class_0: 0.9443 - val_iou_class_1: 0.8541 - val_iou_class_2: 0.8129 - val_iou_coef_multiclass: 0.8507 - val_loss: 0.2711 - learning_rate: 6.2500e-06
# Epoch 50/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9464 - dice_class_0: 0.9701 - dice_class_1: 0.9240 - dice_class_2: 0.9048 - dice_coef_multiclass: 0.9181 - iou_class_0: 0.9420 - iou_class_1: 0.8592 - iou_class_2: 0.8270 - iou_coef_multiclass: 0.8487 - loss: 0.2618
# Epoch 50: val_loss did not improve from 0.26419
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 428ms/step - accuracy: 0.9443 - dice_class_0: 0.9692 - dice_class_1: 0.9215 - dice_class_2: 0.9003 - dice_coef_multiclass: 0.9164 - iou_class_0: 0.9404 - iou_class_1: 0.8547 - iou_class_2: 0.8197 - iou_coef_multiclass: 0.8460 - loss: 0.2719 - val_accuracy: 0.9435 - val_dice_class_0: 0.9707 - val_dice_class_1: 0.9206 - val_dice_class_2: 0.8918 - val_dice_coef_multiclass: 0.9188 - val_iou_class_0: 0.9432 - val_iou_class_1: 0.8534 - val_iou_class_2: 0.8060 - val_iou_coef_multiclass: 0.8500 - val_loss: 0.2791 - learning_rate: 6.2500e-06
# Epoch 51/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9445 - dice_class_0: 0.9691 - dice_class_1: 0.9228 - dice_class_2: 0.9002 - dice_coef_multiclass: 0.9159 - iou_class_0: 0.9402 - iou_class_1: 0.8569 - iou_class_2: 0.8194 - iou_coef_multiclass: 0.8449 - loss: 0.2709
# Epoch 51: val_loss did not improve from 0.26419
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 428ms/step - accuracy: 0.9437 - dice_class_0: 0.9692 - dice_class_1: 0.9214 - dice_class_2: 0.8982 - dice_coef_multiclass: 0.9152 - iou_class_0: 0.9403 - iou_class_1: 0.8546 - iou_class_2: 0.8161 - iou_coef_multiclass: 0.8438 - loss: 0.2749 - val_accuracy: 0.9429 - val_dice_class_0: 0.9705 - val_dice_class_1: 0.9186 - val_dice_class_2: 0.8924 - val_dice_coef_multiclass: 0.9179 - val_iou_class_0: 0.9428 - val_iou_class_1: 0.8500 - val_iou_class_2: 0.8072 - val_iou_coef_multiclass: 0.8484 - val_loss: 0.2799 - learning_rate: 6.2500e-06
# Epoch 52/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9440 - dice_class_0: 0.9694 - dice_class_1: 0.9218 - dice_class_2: 0.8973 - dice_coef_multiclass: 0.9154 - iou_class_0: 0.9408 - iou_class_1: 0.8554 - iou_class_2: 0.8150 - iou_coef_multiclass: 0.8442 - loss: 0.2761
# Epoch 52: val_loss did not improve from 0.26419
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 428ms/step - accuracy: 0.9430 - dice_class_0: 0.9688 - dice_class_1: 0.9201 - dice_class_2: 0.8967 - dice_coef_multiclass: 0.9148 - iou_class_0: 0.9396 - iou_class_1: 0.8524 - iou_class_2: 0.8139 - iou_coef_multiclass: 0.8432 - loss: 0.2775 - val_accuracy: 0.9428 - val_dice_class_0: 0.9708 - val_dice_class_1: 0.9187 - val_dice_class_2: 0.8901 - val_dice_coef_multiclass: 0.9175 - val_iou_class_0: 0.9434 - val_iou_class_1: 0.8502 - val_iou_class_2: 0.8031 - val_iou_coef_multiclass: 0.8477 - val_loss: 0.2825 - learning_rate: 6.2500e-06
# Epoch 53/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9458 - dice_class_0: 0.9700 - dice_class_1: 0.9237 - dice_class_2: 0.9035 - dice_coef_multiclass: 0.9169 - iou_class_0: 0.9419 - iou_class_1: 0.8586 - iou_class_2: 0.8248 - iou_coef_multiclass: 0.8468 - loss: 0.2660
# Epoch 53: val_loss did not improve from 0.26419
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 428ms/step - accuracy: 0.9437 - dice_class_0: 0.9690 - dice_class_1: 0.9211 - dice_class_2: 0.8997 - dice_coef_multiclass: 0.9151 - iou_class_0: 0.9400 - iou_class_1: 0.8541 - iou_class_2: 0.8188 - iou_coef_multiclass: 0.8437 - loss: 0.2741 - val_accuracy: 0.9428 - val_dice_class_0: 0.9706 - val_dice_class_1: 0.9186 - val_dice_class_2: 0.8921 - val_dice_coef_multiclass: 0.9170 - val_iou_class_0: 0.9429 - val_iou_class_1: 0.8498 - val_iou_class_2: 0.8066 - val_iou_coef_multiclass: 0.8468 - val_loss: 0.2808 - learning_rate: 3.1250e-06
# Epoch 54/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9430 - dice_class_0: 0.9690 - dice_class_1: 0.9192 - dice_class_2: 0.8966 - dice_coef_multiclass: 0.9147 - iou_class_0: 0.9400 - iou_class_1: 0.8510 - iou_class_2: 0.8135 - iou_coef_multiclass: 0.8429 - loss: 0.2776
# Epoch 54: val_loss did not improve from 0.26419
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 427ms/step - accuracy: 0.9443 - dice_class_0: 0.9696 - dice_class_1: 0.9209 - dice_class_2: 0.8997 - dice_coef_multiclass: 0.9159 - iou_class_0: 0.9410 - iou_class_1: 0.8539 - iou_class_2: 0.8185 - iou_coef_multiclass: 0.8450 - loss: 0.2716 - val_accuracy: 0.9428 - val_dice_class_0: 0.9705 - val_dice_class_1: 0.9186 - val_dice_class_2: 0.8900 - val_dice_coef_multiclass: 0.9182 - val_iou_class_0: 0.9428 - val_iou_class_1: 0.8498 - val_iou_class_2: 0.8033 - val_iou_coef_multiclass: 0.8489 - val_loss: 0.2819 - learning_rate: 3.1250e-06
# Epoch 55/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9419 - dice_class_0: 0.9686 - dice_class_1: 0.9198 - dice_class_2: 0.8934 - dice_coef_multiclass: 0.9138 - iou_class_0: 0.9392 - iou_class_1: 0.8521 - iou_class_2: 0.8086 - iou_coef_multiclass: 0.8415 - loss: 0.2848
# Epoch 55: val_loss did not improve from 0.26419
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 429ms/step - accuracy: 0.9425 - dice_class_0: 0.9688 - dice_class_1: 0.9198 - dice_class_2: 0.8949 - dice_coef_multiclass: 0.9141 - iou_class_0: 0.9396 - iou_class_1: 0.8520 - iou_class_2: 0.8110 - iou_coef_multiclass: 0.8420 - loss: 0.2822 - val_accuracy: 0.9427 - val_dice_class_0: 0.9708 - val_dice_class_1: 0.9177 - val_dice_class_2: 0.8927 - val_dice_coef_multiclass: 0.9176 - val_iou_class_0: 0.9433 - val_iou_class_1: 0.8486 - val_iou_class_2: 0.8077 - val_iou_coef_multiclass: 0.8480 - val_loss: 0.2814 - learning_rate: 3.1250e-06
# Epoch 56/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9421 - dice_class_0: 0.9680 - dice_class_1: 0.9189 - dice_class_2: 0.8981 - dice_coef_multiclass: 0.9134 - iou_class_0: 0.9381 - iou_class_1: 0.8505 - iou_class_2: 0.8161 - iou_coef_multiclass: 0.8408 - loss: 0.2781
# Epoch 56: val_loss did not improve from 0.26419
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 428ms/step - accuracy: 0.9434 - dice_class_0: 0.9692 - dice_class_1: 0.9201 - dice_class_2: 0.8975 - dice_coef_multiclass: 0.9150 - iou_class_0: 0.9404 - iou_class_1: 0.8525 - iou_class_2: 0.8152 - iou_coef_multiclass: 0.8434 - loss: 0.2765 - val_accuracy: 0.9431 - val_dice_class_0: 0.9706 - val_dice_class_1: 0.9188 - val_dice_class_2: 0.8948 - val_dice_coef_multiclass: 0.9177 - val_iou_class_0: 0.9430 - val_iou_class_1: 0.8505 - val_iou_class_2: 0.8106 - val_iou_coef_multiclass: 0.8482 - val_loss: 0.2785 - learning_rate: 3.1250e-06
# Epoch 57/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9443 - dice_class_0: 0.9690 - dice_class_1: 0.9218 - dice_class_2: 0.9010 - dice_coef_multiclass: 0.9152 - iou_class_0: 0.9400 - iou_class_1: 0.8554 - iou_class_2: 0.8208 - iou_coef_multiclass: 0.8439 - loss: 0.2727
# Epoch 57: val_loss did not improve from 0.26419
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 428ms/step - accuracy: 0.9448 - dice_class_0: 0.9698 - dice_class_1: 0.9223 - dice_class_2: 0.8996 - dice_coef_multiclass: 0.9161 - iou_class_0: 0.9415 - iou_class_1: 0.8561 - iou_class_2: 0.8186 - iou_coef_multiclass: 0.8453 - loss: 0.2716 - val_accuracy: 0.9427 - val_dice_class_0: 0.9706 - val_dice_class_1: 0.9188 - val_dice_class_2: 0.8895 - val_dice_coef_multiclass: 0.9177 - val_iou_class_0: 0.9429 - val_iou_class_1: 0.8502 - val_iou_class_2: 0.8020 - val_iou_coef_multiclass: 0.8481 - val_loss: 0.2827 - learning_rate: 1.5625e-06
# Epoch 58/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9475 - dice_class_0: 0.9710 - dice_class_1: 0.9259 - dice_class_2: 0.9066 - dice_coef_multiclass: 0.9187 - iou_class_0: 0.9437 - iou_class_1: 0.8625 - iou_class_2: 0.8300 - iou_coef_multiclass: 0.8498 - loss: 0.2584
# Epoch 58: val_loss did not improve from 0.26419
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 428ms/step - accuracy: 0.9448 - dice_class_0: 0.9694 - dice_class_1: 0.9224 - dice_class_2: 0.9020 - dice_coef_multiclass: 0.9166 - iou_class_0: 0.9408 - iou_class_1: 0.8565 - iou_class_2: 0.8224 - iou_coef_multiclass: 0.8462 - loss: 0.2708 - val_accuracy: 0.9448 - val_dice_class_0: 0.9719 - val_dice_class_1: 0.9206 - val_dice_class_2: 0.8948 - val_dice_coef_multiclass: 0.9201 - val_iou_class_0: 0.9453 - val_iou_class_1: 0.8533 - val_iou_class_2: 0.8109 - val_iou_coef_multiclass: 0.8521 - val_loss: 0.2732 - learning_rate: 1.5625e-06
# Epoch 59/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9472 - dice_class_0: 0.9706 - dice_class_1: 0.9258 - dice_class_2: 0.9065 - dice_coef_multiclass: 0.9186 - iou_class_0: 0.9430 - iou_class_1: 0.8621 - iou_class_2: 0.8298 - iou_coef_multiclass: 0.8496 - loss: 0.2580
# Epoch 59: val_loss did not improve from 0.26419
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 64s 428ms/step - accuracy: 0.9459 - dice_class_0: 0.9701 - dice_class_1: 0.9240 - dice_class_2: 0.9035 - dice_coef_multiclass: 0.9179 - iou_class_0: 0.9419 - iou_class_1: 0.8591 - iou_class_2: 0.8252 - iou_coef_multiclass: 0.8483 - loss: 0.2635 - val_accuracy: 0.9422 - val_dice_class_0: 0.9701 - val_dice_class_1: 0.9173 - val_dice_class_2: 0.8938 - val_dice_coef_multiclass: 0.9183 - val_iou_class_0: 0.9421 - val_iou_class_1: 0.8480 - val_iou_class_2: 0.8095 - val_iou_coef_multiclass: 0.8493 - val_loss: 0.2827 - learning_rate: 1.5625e-06
# Epoch 59: early stopping
# Restoring model weights from the end of the best epoch: 44.
# ✓ Training completed
#
# Generating visualizations...
#   ✓ Saved: results/V8_Boosted_P1P2P3_history.png
#   ✓ Saved: results/V8_Boosted_P1P2P3_predictions_cdr.png
# ================================================================================
# EVALUATION: V8_Boosted_P1P2P3
# ================================================================================
#
# ────────────────────────────────────────────────────────────────────────────────
# STAGE 1: RAW PREDICTIONS (no post-processing, no TTA)
# ────────────────────────────────────────────────────────────────────────────────
#   ✓ Saved: results/V8_Boosted_P1P2P3_raw_confusion_matrices.png
# Confusion Matrix:
# [[52859481  1622505        0]
#  [ 1435146 34689484  1068758]
#  [     604  1604546 11577076]]
#
# Normalized Confusion Matrix:
# [[0.97  0.03  0.   ]
#  [0.039 0.933 0.029]
#  [0.    0.122 0.878]]
#
# Raw per-class metrics (ROI-level):
#   Background: Dice=0.9719, IoU=0.9453
#   Disc: Dice=0.9237, IoU=0.8582
#   Cup: Dice=0.8965, IoU=0.8124
#
# ────────────────────────────────────────────────────────────────────────────────
# STAGE 2: POST-PROCESSED PREDICTIONS
# ────────────────────────────────────────────────────────────────────────────────
#
# Post-processed per-class metrics (ROI-level):
#   Background: Dice=0.9718 (-0.0000), IoU=0.9452
#   Disc: Dice=0.9237 (+0.0000), IoU=0.8582
#   Cup: Dice=0.8965 (-0.0000), IoU=0.8124
#
# ────────────────────────────────────────────────────────────────────────────────
# STAGE 3: TTA + POST-PROCESSING
# ────────────────────────────────────────────────────────────────────────────────
#
# Running TTA with 4 geometric passes...
#   Pass 1/4: Original
#   Pass 2/4: Horizontal flip
#   Pass 3/4: Vertical flip
#   Pass 4/4: Both flips
#   ✓ TTA completed
#
# TTA + Post-processed per-class metrics (ROI-level):
#   Background: Dice=0.9726 (+0.0007 vs raw), IoU=0.9467
#   Disc: Dice=0.9258 (+0.0021 vs raw), IoU=0.8618
#   Cup: Dice=0.8994 (+0.0029 vs raw), IoU=0.8172
#
# ================================================================================
# RESULTS COMPARISON TABLE
# ================================================================================
# Stage                          BG Dice      Disc Dice    Cup Dice
# ──────────────────────────────────────────────────────────────────
# Raw (no PP, no TTA)            0.9719       0.9237       0.8965
# + Post-Processing              0.9718       0.9237       0.8965
# + TTA + Post-Processing        0.9726       0.9258       0.8994
#
# Saving all 400 test predictions to results/V8_Boosted_P1P2P3_all_preds...
#   Processed 50/400
#   Processed 100/400
#   Processed 150/400
#   Processed 200/400
#   Processed 250/400
#   Processed 300/400
#   Processed 350/400
#   Processed 400/400
# ✓ Saved comparison masks to results/V8_Boosted_P1P2P3_all_preds
#
# Precision, Recall, F1 Score per class (TTA+PP):
#   Background: Precision=0.9729, Recall=0.9724, F1=0.9726
#   Disc: Precision=0.9182, Recall=0.9335, F1=0.9258
#   Cup: Precision=0.9205, Recall=0.8793, F1=0.8994
#
# Macro-averaged metrics:
#   Precision: 0.9372
#   Recall: 0.9284
#   F1 Score: 0.9326
#
# ================================================================================
# GLAUCOMA PROGRESSION ANALYSIS
# ================================================================================
#
# CDR Statistics:
#   Mean GT CDR:   0.5984 ± 0.1782
#   Mean Pred CDR: 0.5790 ± 0.1657
#   Mean CDR Error: 0.0586 ± 0.0589
#
# Overall Accuracy: 82.50%
#   Correctly Classified: 330/400
#
# Severity     GT Count     Pred Count   Correct      Accuracy
# ────────────────────────────────────────────────────────────
# Normal       0            0            0            0.00        %
# Suspect      257          293          246          95.72       %
# Moderate     106          75           57           53.77       %
# Critical     37           32           27           72.97       %
#
# Manual Review: 97/400 (24.2%)
#
# ✓ Saved: results/glaucoma_progression_analysis.csv
#   ✓ Saved: results/cdr_analysis.png
# ================================================================================
# MC DROPOUT UNCERTAINTY ESTIMATION
# ================================================================================
#
# Running MC Dropout with 15 stochastic forward passes...
#   Completed: 5/15 forward passes
#   Completed: 10/15 forward passes
#   Completed: 15/15 forward passes
# ✓ MC Dropout completed
#   Background uncertainty: 0.0020
#   Disc uncertainty: 0.0033
#   Cup uncertainty: 0.0015
#
# ====================================================================================================
#                                 ✓ TRAINING AND EVALUATION COMPLETED!
# ====================================================================================================
#
# Model: V8 — Enhanced Online Aug + Post-Processing + TTA (Phases 1-3)
# Parameters: 47,631,627
# ROI Extraction: Padding=1.2×, Size=(512, 512)
# Results saved in: results/
#
# ====================================================================================================
