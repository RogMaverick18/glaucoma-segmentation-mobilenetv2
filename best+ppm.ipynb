# %%
"""
MOBILENET-UNET WITH PPM (PYRAMID POOLING MODULE)
=================================================
Enhanced with PPM from PSPNet for multi-scale global context aggregation

PPM Module:
- Multi-scale adaptive pooling (scales: 1×1, 2×2, 3×3, 6×6)
- Captures global context at different pyramid levels
- Feature fusion with concatenation
- From PSPNet architecture, used in ODFormer

Configuration:
- Base: Deeper Decoder + Focal-EIoU + MC Dropout
- Enhancement: PPM on decoder outputs
- PPM Placement: After each decoder block (4 total)
"""

import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, backend as K
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import albumentations as A
import warnings
import gc
warnings.filterwarnings('ignore')

# Set plot style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# ============================================================================
# GPU CONFIGURATION
# ============================================================================

def configure_gpu():
    """Configure GPU settings for optimal performance"""
    print("Configuring GPU settings...")
    physical_devices = tf.config.list_physical_devices('GPU')
    if physical_devices:
        try:
            for gpu in physical_devices:
                tf.config.experimental.set_memory_growth(gpu, True)
            tf.config.set_visible_devices(physical_devices[0], 'GPU')
            print(f"✓ GPU found: {physical_devices}")
            return True
        except RuntimeError as e:
            print(f"✗ GPU configuration error: {e}")
            return False
    else:
        print("✗ No GPU found, using CPU")
        return False

# ============================================================================
# DATA LOADING
# ============================================================================

def load_images_masks(images_folder, masks_folder, img_size=(256,256)):
    """Load images and masks from folders"""
    images, masks = [], []
    image_files = sorted(os.listdir(images_folder))
    mask_files = sorted(os.listdir(masks_folder))
    mask_dict = {os.path.splitext(f)[0]: f for f in mask_files}
    
    for img_file in image_files:
        base = os.path.splitext(img_file)[0]
        if base in mask_dict:
            img = cv2.imread(os.path.join(images_folder, img_file))
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, img_size) / 255.0
            
            mask = cv2.imread(os.path.join(masks_folder, mask_dict[base]), cv2.IMREAD_GRAYSCALE)
            mask = cv2.resize(mask, img_size)
            unique_vals = np.unique(mask)
            if len(unique_vals) > 3 or np.max(unique_vals) > 2:
                mask = np.clip(mask // 85, 0, 2).astype(np.uint8)
            
            images.append(img)
            masks.append(mask)
    
    return np.array(images, dtype=np.float32), np.array(masks, dtype=np.uint8)

def load_all_data(root_dir):
    """Load all data from existing splits and merge"""
    all_images, all_masks = [], []
    for split in ["train", "val", "test"]:
        print(f"Loading {split} data...")
        imgs, msks = load_images_masks(
            os.path.join(root_dir, split, "Images"),
            os.path.join(root_dir, split, "Masks")
        )
        all_images.append(imgs)
        all_masks.append(msks)
        print(f"  {split}: {imgs.shape[0]} samples")
    
    all_images = np.concatenate(all_images, axis=0)
    all_masks = np.concatenate(all_masks, axis=0)
    return all_images, all_masks

def create_new_split(all_images, all_masks):
    """Create new split: 600 train, 200 val, 400 test"""
    X_temp, X_test, y_temp, y_test = train_test_split(
        all_images, all_masks, test_size=400, random_state=42
    )
    X_train, X_val, y_train, y_val = train_test_split(
        X_temp, y_temp, test_size=200, random_state=42
    )
    print(f"Split - Train: {X_train.shape[0]}, Val: {X_val.shape[0]}, Test: {X_test.shape[0]}")
    return (X_train, y_train), (X_val, y_val), (X_test, y_test)

# ============================================================================
# DATA AUGMENTATION
# ============================================================================

def setup_augmentations():
    return A.Compose([
        A.RandomBrightnessContrast(brightness_limit=0.15, contrast_limit=0.15, p=0.7),
        A.HueSaturationValue(hue_shift_limit=10, sat_shift_limit=15, val_shift_limit=10, p=0.5),
        A.GaussianBlur(blur_limit=3, p=0.3),
        A.RandomGamma(gamma_limit=(80, 120), p=0.3),
    ])

def data_generator(images, masks, batch_size, augment=None):
    idxs = np.arange(len(images))
    while True:
        np.random.shuffle(idxs)
        for i in range(0, len(images), batch_size):
            batch_idxs = idxs[i:i+batch_size]
            batch_x, batch_y = [], []
            
            for idx in batch_idxs:
                img, mask = images[idx], masks[idx]
                
                if augment:
                    aug = augment(image=img, mask=mask)
                    img_aug, mask_aug = aug['image'], aug['mask']
                else:
                    img_aug, mask_aug = img, mask
                
                mask_cat = to_categorical(mask_aug, num_classes=3)
                batch_x.append(img_aug)
                batch_y.append(mask_cat)
            
            yield np.stack(batch_x).astype(np.float32), np.stack(batch_y).astype(np.float32)

# ============================================================================
# PPM MODULE (FROM PSPNET/ODFORMER)
# ============================================================================

def ppm_block(x, channels, pool_scales=[1, 2, 3, 6], block_name='ppm'):
    """
    Pyramid Pooling Module (PPM) from PSPNet
    
    Features:
    - Multi-scale adaptive pooling at different pyramid levels
    - Captures global context at scales: 1×1, 2×2, 3×3, 6×6
    - Lightweight 1×1 convolutions for each scale
    - Feature fusion through concatenation
    
    Args:
        x: Input feature map
        channels: Number of output channels
        pool_scales: List of pooling scales for pyramid levels
        block_name: Name prefix for layers
    """
    h, w = x.shape[1], x.shape[2]
    
    # Store original features
    ppm_features = [x]
    
    # Multi-scale pooling branches
    filters_per_scale = channels // len(pool_scales)
    
    for i, scale in enumerate(pool_scales):
        # Global average pooling to fixed scale size
        pool_h = max(h // scale, 1)
        pool_w = max(w // scale, 1)
        
        pooled = layers.AveragePooling2D(
            pool_size=(h // pool_h, w // pool_w),
            strides=(h // pool_h, w // pool_w),
            name=f'{block_name}_pool_{scale}x{scale}'
        )(x)
        
        # 1×1 convolution to reduce channels
        conv = layers.Conv2D(
            filters_per_scale,
            (1, 1),
            use_bias=False,
            name=f'{block_name}_conv_{scale}x{scale}'
        )(pooled)
        conv = layers.BatchNormalization(name=f'{block_name}_bn_{scale}x{scale}')(conv)
        conv = layers.Activation('relu', name=f'{block_name}_relu_{scale}x{scale}')(conv)
        
        # Upsample back to original size using exact target dimensions
        upsampled = layers.Resizing(
            h, w,
            interpolation='bilinear',
            name=f'{block_name}_upsample_{scale}x{scale}'
        )(conv)
        
        ppm_features.append(upsampled)
    
    # Concatenate all pyramid features
    concat = layers.Concatenate(name=f'{block_name}_concat')(ppm_features)
    
    # Fusion convolution
    fused = layers.Conv2D(
        channels,
        (3, 3),
        padding='same',
        use_bias=False,
        name=f'{block_name}_fusion'
    )(concat)
    fused = layers.BatchNormalization(name=f'{block_name}_fusion_bn')(fused)
    fused = layers.Activation('relu', name=f'{block_name}_fusion_relu')(fused)
    
    return fused

# ============================================================================
# LOSS FUNCTIONS
# ============================================================================

def focal_loss(y_true, y_pred, gamma=2.0, alpha=None, epsilon=1e-7):
    if alpha is None:
        alpha = [0.25, 1.0, 1.0]
    
    y_pred = K.clip(y_pred, epsilon, 1.0 - epsilon)
    focal_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        pt = y_pred_c
        focal_weight = K.pow(1.0 - pt, gamma)
        cross_entropy = -K.log(pt)
        focal_loss_c = alpha[c] * focal_weight * cross_entropy * y_true_c
        focal_loss_value += K.mean(focal_loss_c)
    
    return focal_loss_value

def enhanced_iou_loss(y_true, y_pred, smooth=1e-7):
    eiou_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        
        intersection = K.sum(y_true_c * y_pred_c, axis=[1, 2])
        union = K.sum(y_true_c, axis=[1, 2]) + K.sum(y_pred_c, axis=[1, 2]) - intersection
        iou = (intersection + smooth) / (union + smooth)
        
        height = K.cast(K.shape(y_true_c)[1], 'float32')
        width = K.cast(K.shape(y_true_c)[2], 'float32')
        
        y_coords = K.arange(0, height)
        x_coords = K.arange(0, width)
        y_grid = K.tile(K.reshape(y_coords, (-1, 1)), (1, K.cast(width, 'int32')))
        x_grid = K.tile(K.reshape(x_coords, (1, -1)), (K.cast(height, 'int32'), 1))
        y_grid = K.cast(y_grid, 'float32')
        x_grid = K.cast(x_grid, 'float32')
        
        true_mass = K.sum(y_true_c, axis=[1, 2]) + smooth
        true_center_y = K.sum(y_true_c * y_grid, axis=[1, 2]) / true_mass
        true_center_x = K.sum(y_true_c * x_grid, axis=[1, 2]) / true_mass
        
        pred_mass = K.sum(y_pred_c, axis=[1, 2]) + smooth
        pred_center_y = K.sum(y_pred_c * y_grid, axis=[1, 2]) / pred_mass
        pred_center_x = K.sum(y_pred_c * x_grid, axis=[1, 2]) / pred_mass
        
        center_distance = K.square(true_center_y - pred_center_y) + K.square(true_center_x - pred_center_x)
        diagonal = K.square(height) + K.square(width)
        center_penalty = center_distance / (diagonal + smooth)
        
        true_width = K.sqrt(K.sum(K.sum(y_true_c, axis=1), axis=1) + smooth)
        true_height = K.sqrt(K.sum(K.sum(y_true_c, axis=2), axis=1) + smooth)
        pred_width = K.sqrt(K.sum(K.sum(y_pred_c, axis=1), axis=1) + smooth)
        pred_height = K.sqrt(K.sum(K.sum(y_pred_c, axis=2), axis=1) + smooth)
        
        width_diff = K.square(pred_width - true_width)
        height_diff = K.square(pred_height - true_height)
        aspect_penalty = width_diff / (K.square(width) + smooth) + height_diff / (K.square(height) + smooth)
        
        eiou_c = 1.0 - iou + center_penalty + aspect_penalty
        eiou_loss_value += K.mean(eiou_c)
    
    return eiou_loss_value / 3.0

def focal_eiou_combined_loss(y_true, y_pred, focal_weight=1.0, eiou_weight=1.0, gamma=2.0, alpha=None):
    fl = focal_loss(y_true, y_pred, gamma=gamma, alpha=alpha)
    eiou = enhanced_iou_loss(y_true, y_pred)
    return focal_weight * fl + eiou_weight * eiou

# ============================================================================
# MODEL ARCHITECTURE WITH PPM
# ============================================================================

def enhanced_decoder_block_with_ppm(x, skip_connection, filters, block_name, dropout_rate=0.3):
    """Enhanced decoder block with PPM for multi-scale global context"""
    x = layers.UpSampling2D((2, 2), name=f'{block_name}_upsample')(x)
    
    if skip_connection.shape[-1] != x.shape[-1]:
        skip_connection = layers.Conv2D(x.shape[-1], (1, 1), activation='relu', 
                                      padding='same', name=f'{block_name}_skip_align')(skip_connection)
        skip_connection = layers.BatchNormalization(name=f'{block_name}_skip_bn')(skip_connection)
    
    x = layers.Concatenate(name=f'{block_name}_concat')([x, skip_connection])
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv1')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn1')(x)
    x = layers.Dropout(dropout_rate, name=f'{block_name}_dropout')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv2')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn2')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv3')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn3')(x)
    
    residual = x
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv4')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn4')(x)
    
    x = layers.Add(name=f'{block_name}_residual')([x, residual])
    x = layers.Conv2D(filters, (1, 1), activation='relu', padding='same', name=f'{block_name}_conv_final')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn_final')(x)
    
    # Apply PPM for multi-scale global context aggregation
    x = ppm_block(x, filters, pool_scales=[1, 2, 3, 6], block_name=f'{block_name}_ppm')
    
    return x

def build_unet_with_ppm(input_shape=(256, 256, 3), num_classes=3, dropout_rate=0.3):
    """Build MobileNetV2-UNet with PPM modules"""
    inputs = layers.Input(input_shape, dtype='float32')
    backbone = MobileNetV2(input_tensor=inputs, weights='imagenet', include_top=False)
    
    skip_1 = backbone.get_layer('block_1_expand_relu').output
    skip_2 = backbone.get_layer('block_3_expand_relu').output
    skip_3 = backbone.get_layer('block_6_expand_relu').output
    skip_4 = backbone.get_layer('block_13_expand_relu').output
    bridge = backbone.output
    
    # Deeper bridge
    bridge = layers.Conv2D(1024, (3, 3), activation='relu', padding='same')(bridge)
    bridge = layers.BatchNormalization()(bridge)
    bridge = layers.Dropout(dropout_rate, name='bridge_dropout')(bridge)
    
    # Decoder with PPM modules
    x = enhanced_decoder_block_with_ppm(bridge, skip_4, 512, 'decoder_1', dropout_rate)
    x = enhanced_decoder_block_with_ppm(x, skip_3, 256, 'decoder_2', dropout_rate)
    x = enhanced_decoder_block_with_ppm(x, skip_2, 128, 'decoder_3', dropout_rate * 0.7)
    x = enhanced_decoder_block_with_ppm(x, skip_1, 64, 'decoder_4', dropout_rate * 0.5)
    
    # Final upsampling
    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    
    outputs = layers.Conv2D(num_classes, (1, 1), activation='softmax', dtype='float32')(x)
    
    model = models.Model(inputs, outputs)
    
    # Print configuration
    dropout_layers = [layer for layer in model.layers if isinstance(layer, layers.Dropout)]
    print(f"\nModel Configuration:")
    print(f"  Total Parameters: {model.count_params():,}")
    print(f"  Dropout Layers: {len(dropout_layers)}")
    print(f"  PPM Modules: 4 (one per decoder block)")
    print(f"  PPM Pyramid Scales: [1×1, 2×2, 3×3, 6×6]")
    print(f"  Enhancement: Pyramid Pooling for Multi-scale Global Context")
    
    return model

# ============================================================================
# METRICS
# ============================================================================

def dice_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    return (2. * intersection + smooth) / (K.sum(y_true_class) + K.sum(y_pred_class) + smooth)

def dice_class_0(y_true, y_pred): return dice_coef_class(y_true, y_pred, 0)
def dice_class_1(y_true, y_pred): return dice_coef_class(y_true, y_pred, 1)
def dice_class_2(y_true, y_pred): return dice_coef_class(y_true, y_pred, 2)

def iou_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    union = K.sum(y_true_class) + K.sum(y_pred_class) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_class_0(y_true, y_pred): return iou_coef_class(y_true, y_pred, 0)
def iou_class_1(y_true, y_pred): return iou_coef_class(y_true, y_pred, 1)
def iou_class_2(y_true, y_pred): return iou_coef_class(y_true, y_pred, 2)

def mc_dropout_predict(model, X, num_samples=15, batch_size=4, verbose=True):
    """MC Dropout prediction for uncertainty estimation"""
    if verbose:
        print(f"\nRunning MC Dropout with {num_samples} stochastic forward passes...")
    
    predictions = []
    num_batches = int(np.ceil(len(X) / batch_size))
    
    for i in range(num_samples):
        if verbose and (i + 1) % 5 == 0:
            print(f"  Completed: {i+1}/{num_samples} forward passes")
        
        batch_preds = []
        for batch_idx in range(num_batches):
            start_idx = batch_idx * batch_size
            end_idx = min(start_idx + batch_size, len(X))
            X_batch = X[start_idx:end_idx]
            
            pred_batch = model(X_batch, training=True)
            batch_preds.append(pred_batch.numpy())
        
        pred = np.concatenate(batch_preds, axis=0)
        predictions.append(pred)
        
        if (i + 1) % 5 == 0:
            gc.collect()
    
    all_preds = np.array(predictions)
    mean_pred = np.mean(all_preds, axis=0)
    std_pred = np.std(all_preds, axis=0)
    
    del all_preds
    gc.collect()
    
    if verbose:
        print(f"✓ MC Dropout completed")
    
    return mean_pred, std_pred

# ============================================================================
# VISUALIZATION FUNCTIONS
# ============================================================================

def plot_sample_predictions(model, X_test, y_test, model_name, num_samples=6, save_dir='results'):
    """Visualize sample predictions with original image, GT, segmented mask, and overlay"""
    os.makedirs(save_dir, exist_ok=True)
    
    y_pred = model.predict(X_test[:num_samples], verbose=0, batch_size=4)
    y_pred_labels = np.argmax(y_pred, axis=-1)
    
    colors = {0: [0, 0, 0], 1: [0, 255, 0], 2: [255, 0, 0]}
    
    fig, axes = plt.subplots(num_samples, 4, figsize=(16, 4*num_samples))
    
    for i in range(num_samples):
        # Original image
        axes[i, 0].imshow(X_test[i])
        axes[i, 0].set_title('Original Image', fontsize=12, fontweight='bold')
        axes[i, 0].axis('off')
        
        # Ground truth
        gt_colored = np.zeros((256, 256, 3), dtype=np.uint8)
        for class_id, color in colors.items():
            gt_colored[y_test[i] == class_id] = color
        axes[i, 1].imshow(gt_colored)
        axes[i, 1].set_title('Ground Truth (GT)', fontsize=12, fontweight='bold')
        axes[i, 1].axis('off')
        
        # Segmented mask
        pred_colored = np.zeros((256, 256, 3), dtype=np.uint8)
        for class_id, color in colors.items():
            pred_colored[y_pred_labels[i] == class_id] = color
        axes[i, 2].imshow(pred_colored)
        axes[i, 2].set_title('Segmented Mask', fontsize=12, fontweight='bold')
        axes[i, 2].axis('off')
        
        # Overlay
        overlay = X_test[i].copy()
        for class_id, color in colors.items():
            if class_id > 0:
                mask = (y_pred_labels[i] == class_id).astype(np.float32)
                mask_rgb = np.stack([mask * color[0]/255, mask * color[1]/255, mask * color[2]/255], axis=-1)
                overlay = overlay * 0.6 + mask_rgb * 0.4
        axes[i, 3].imshow(overlay)
        axes[i, 3].set_title('Overlay', fontsize=12, fontweight='bold')
        axes[i, 3].axis('off')
        
        # Calculate dice
        y_test_cat = to_categorical(y_test[i], num_classes=3)
        y_pred_cat = to_categorical(y_pred_labels[i], num_classes=3)
        
        disc_dice = 2 * np.sum(y_test_cat[:,:,1] * y_pred_cat[:,:,1]) / (np.sum(y_test_cat[:,:,1]) + np.sum(y_pred_cat[:,:,1]) + 1e-7)
        cup_dice = 2 * np.sum(y_test_cat[:,:,2] * y_pred_cat[:,:,2]) / (np.sum(y_test_cat[:,:,2]) + np.sum(y_pred_cat[:,:,2]) + 1e-7)
        
        axes[i, 0].text(0.5, -0.1, f'Sample {i+1}\nDisc: {disc_dice:.3f} | Cup: {cup_dice:.3f}', 
                       transform=axes[i, 0].transAxes, ha='center', fontsize=10, 
                       bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
    
    plt.suptitle(f'{model_name} - Predictions: Original | GT | Segmented | Overlay', 
                 fontsize=16, fontweight='bold', y=0.995)
    plt.tight_layout()
    plt.savefig(f'{save_dir}/{model_name}_predictions.png', dpi=150, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_predictions.png")
    plt.show()
    plt.close()

def plot_training_history(history, model_name, save_dir='results'):
    """Plot training history"""
    os.makedirs(save_dir, exist_ok=True)
    
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    
    # Loss curves
    axes[0, 0].plot(history.history['loss'], label='Train Loss', linewidth=2)
    axes[0, 0].plot(history.history['val_loss'], label='Val Loss', linewidth=2)
    axes[0, 0].set_title('Loss Curves', fontsize=14, fontweight='bold')
    axes[0, 0].set_xlabel('Epoch', fontsize=12)
    axes[0, 0].set_ylabel('Loss', fontsize=12)
    axes[0, 0].legend(fontsize=10)
    axes[0, 0].grid(True, alpha=0.3)
    
    # Overall Dice
    axes[0, 1].plot(history.history['dice_coef_multiclass'], label='Train Dice', linewidth=2)
    axes[0, 1].plot(history.history['val_dice_coef_multiclass'], label='Val Dice', linewidth=2)
    axes[0, 1].set_title('Overall Dice Coefficient', fontsize=14, fontweight='bold')
    axes[0, 1].set_xlabel('Epoch', fontsize=12)
    axes[0, 1].set_ylabel('Dice', fontsize=12)
    axes[0, 1].legend(fontsize=10)
    axes[0, 1].grid(True, alpha=0.3)
    
    # Disc Dice
    axes[1, 0].plot(history.history['dice_class_1'], label='Train Disc Dice', linewidth=2, color='green')
    axes[1, 0].plot(history.history['val_dice_class_1'], label='Val Disc Dice', linewidth=2, color='darkgreen')
    axes[1, 0].set_title('Disc Segmentation (Class 1)', fontsize=14, fontweight='bold')
    axes[1, 0].set_xlabel('Epoch', fontsize=12)
    axes[1, 0].set_ylabel('Dice', fontsize=12)
    axes[1, 0].legend(fontsize=10)
    axes[1, 0].grid(True, alpha=0.3)
    
    # Cup Dice
    axes[1, 1].plot(history.history['dice_class_2'], label='Train Cup Dice', linewidth=2, color='red')
    axes[1, 1].plot(history.history['val_dice_class_2'], label='Val Cup Dice', linewidth=2, color='darkred')
    axes[1, 1].set_title('Cup Segmentation (Class 2)', fontsize=14, fontweight='bold')
    axes[1, 1].set_xlabel('Epoch', fontsize=12)
    axes[1, 1].set_ylabel('Dice', fontsize=12)
    axes[1, 1].legend(fontsize=10)
    axes[1, 1].grid(True, alpha=0.3)
    
    plt.suptitle(f'{model_name} - Training History', fontsize=16, fontweight='bold')
    plt.tight_layout()
    plt.savefig(f'{save_dir}/{model_name}_history.png', dpi=150, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_history.png")
    plt.show()
    plt.close()

def plot_training_curves(history, model_name, save_dir='results'):
    """Plot training loss and accuracy curves"""
    os.makedirs(save_dir, exist_ok=True)
    
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    
    # Loss
    axes[0].plot(history.history['loss'], label='Training Loss', linewidth=2)
    axes[0].plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
    axes[0].set_title(f'{model_name} - Loss Over Epochs', fontsize=14, fontweight='bold')
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('Loss', fontsize=12)
    axes[0].legend(fontsize=10)
    axes[0].grid(True, alpha=0.3)
    
    # Accuracy
    axes[1].plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
    axes[1].plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
    axes[1].set_title(f'{model_name} - Accuracy Over Epochs', fontsize=14, fontweight='bold')
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('Accuracy', fontsize=12)
    axes[1].legend(fontsize=10)
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(f"{save_dir}/{model_name}_training_curves.png", dpi=300, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_training_curves.png")
    plt.show()
    plt.close()

def plot_confusion_matrices(y_true, y_pred, model_name, save_dir='results'):
    """Plot confusion matrices"""
    os.makedirs(save_dir, exist_ok=True)
    
    y_true_labels = np.argmax(y_true, axis=-1).flatten()
    y_pred_labels = np.argmax(y_pred, axis=-1).flatten()
    
    cm = confusion_matrix(y_true_labels, y_pred_labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    class_names = ['Background', 'Disc', 'Cup']
    
    # Regular confusion matrix
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[0], cbar_kws={'label': 'Count'})
    axes[0].set_title(f'{model_name}\nConfusion Matrix', fontsize=14, fontweight='bold')
    axes[0].set_ylabel('True Label', fontsize=12)
    axes[0].set_xlabel('Predicted Label', fontsize=12)
    
    # Normalized confusion matrix
    sns.heatmap(cm_normalized, annot=True, fmt='.3f', cmap='Greens',
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[1], cbar_kws={'label': 'Proportion'})
    axes[1].set_title(f'{model_name}\nNormalized Confusion Matrix', fontsize=14, fontweight='bold')
    axes[1].set_ylabel('True Label', fontsize=12)
    axes[1].set_xlabel('Predicted Label', fontsize=12)
    
    plt.tight_layout()
    plt.savefig(f"{save_dir}/{model_name}_confusion_matrices.png", dpi=300, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_confusion_matrices.png")
    plt.show()
    plt.close()
    
    print(f"\nConfusion Matrix:\n{cm}")
    print(f"\nNormalized Confusion Matrix:\n{np.round(cm_normalized, 3)}")
    
    return cm, cm_normalized

# ============================================================================
# TRAINING AND EVALUATION
# ============================================================================

def train_model(X_train, y_train, X_val, y_val, X_test, y_test, model_name, 
               augment=None, save_dir='results'):
    """Train model with PPM enhancement"""
    print(f"\n{'='*80}")
    print(f"TRAINING: {model_name}")
    print(f"{'='*80}")
    print(f"  Loss: Focal + EIoU")
    print(f"  Architecture: Deeper Decoder + MC Dropout + PPM")
    print(f"  PPM: Pyramid Pooling Module from PSPNet")
    
    K.clear_session()
    
    # Build model
    model = build_unet_with_ppm(dropout_rate=0.3)
    param_count = model.count_params()
    
    # Compile
    model.compile(
        optimizer=optimizers.Adam(learning_rate=5e-4),
        loss=focal_eiou_combined_loss,
        metrics=[dice_coef_multiclass, dice_class_0, dice_class_1, dice_class_2,
                "accuracy", iou_coef_multiclass, iou_class_0, iou_class_1, iou_class_2]
    )
    
    # Callbacks
    checkpoint = ModelCheckpoint(f"{save_dir}/{model_name}.keras", save_best_only=True, 
                                verbose=1, monitor='val_loss', mode='min')
    reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=3, 
                                  verbose=1, mode='min', min_lr=1e-7)
    early_stop = EarlyStopping(monitor="val_loss", patience=10, verbose=1, 
                              restore_best_weights=True, mode='min')
    
    # Training
    batch_size = 4
    steps_train = X_train.shape[0] // batch_size
    steps_val = X_val.shape[0] // batch_size
    
    history = model.fit(
        data_generator(X_train, y_train, batch_size, augment),
        validation_data=data_generator(X_val, y_val, batch_size, None),
        steps_per_epoch=steps_train,
        validation_steps=steps_val,
        epochs=50,
        callbacks=[checkpoint, reduce_lr, early_stop],
        verbose=1
    )
    
    print(f"✓ Training completed")
    
    # Visualizations
    print("\nGenerating visualizations...")
    plot_training_curves(history, model_name, save_dir)
    plot_training_history(history, model_name, save_dir)
    plot_sample_predictions(model, X_test, y_test, model_name, num_samples=6, save_dir=save_dir)
    
    return model, history, param_count

def evaluate_model(model, X_test, y_test, model_name, run_mc_dropout=True):
    """Evaluate model"""
    print(f"\n{'='*80}")
    print(f"EVALUATION: {model_name}")
    print(f"{'='*80}")
    
    y_test_cat = np.array([to_categorical(mask, num_classes=3) for mask in y_test])
    
    # Predict
    y_pred = model.predict(X_test, verbose=0, batch_size=8)
    
    # Confusion matrices
    plot_confusion_matrices(y_test_cat, y_pred, model_name, save_dir='results')
    
    # Classification metrics
    y_true_labels = np.argmax(y_test_cat, axis=-1).flatten()
    y_pred_labels = np.argmax(y_pred, axis=-1).flatten()
    
    precision = precision_score(y_true_labels, y_pred_labels, average=None, zero_division=0)
    recall = recall_score(y_true_labels, y_pred_labels, average=None, zero_division=0)
    f1 = f1_score(y_true_labels, y_pred_labels, average=None, zero_division=0)
    
    print(f"\nPrecision, Recall, F1 Score per class:")
    class_names = ["Background", "Disc", "Cup"]
    for idx, cname in enumerate(class_names):
        print(f"  {cname}: Precision={precision[idx]:.4f}, Recall={recall[idx]:.4f}, F1={f1[idx]:.4f}")
    
    print(f"\nMacro-averaged metrics:")
    print(f"  Precision: {np.mean(precision):.4f}")
    print(f"  Recall: {np.mean(recall):.4f}")
    print(f"  F1 Score: {np.mean(f1):.4f}")
    
    # Per-class Dice and IoU
    results = {'standard': {}}
    for cidx, cname in enumerate(class_names):
        y_true_c = (np.argmax(y_test_cat, axis=-1) == cidx).astype(np.float32)
        y_pred_c = (np.argmax(y_pred, axis=-1) == cidx).astype(np.float32)
        
        intersection = np.sum(y_true_c * y_pred_c)
        dice = (2. * intersection + 1e-7) / (np.sum(y_true_c) + np.sum(y_pred_c) + 1e-7)
        union = np.sum(y_true_c) + np.sum(y_pred_c) - intersection
        iou = (intersection + 1e-7) / (union + 1e-7)
        
        results['standard'][cname] = {'dice': dice, 'iou': iou}
        print(f"  {cname}: Dice={dice:.4f}, IoU={iou:.4f}")
    
    # MC Dropout
    if run_mc_dropout:
        print("\nMC Dropout Evaluation:")
        mean_pred, std_pred = mc_dropout_predict(model, X_test[:100], num_samples=10, verbose=True)
        results['mc_dropout'] = {}
        for cidx, cname in enumerate(class_names):
            mean_std = np.mean(std_pred[:, :, :, cidx])
            results['mc_dropout'][cname] = {'mean_uncertainty': mean_std}
            print(f"  {cname} uncertainty: {mean_std:.4f}")
    
    return results

# ============================================================================
# MAIN EXECUTION
# ============================================================================

if __name__ == "__main__":
    # Setup
    gpu_available = configure_gpu()
    root_dir = "/kaggle/input/refuge/REFUGE/"
    train_aug = setup_augmentations()
    save_dir = "results"
    os.makedirs(save_dir, exist_ok=True)
    
    print(f"\n{'='*100}")
    print(f"{'MOBILENET-UNET WITH PPM (PYRAMID POOLING MODULE)':^100s}")
    print(f"{'='*100}")
    
    # Load data
    all_images, all_masks = load_all_data(root_dir)
    (X_train, y_train), (X_val, y_val), (X_test, y_test) = create_new_split(all_images, all_masks)
    
    # Train model
    model, history, params = train_model(
        X_train, y_train, X_val, y_val, X_test, y_test,
        "Deeper_Focal_MC_PPM",
        augment=train_aug, save_dir=save_dir
    )
    
    # Evaluate
    results = evaluate_model(model, X_test, y_test, "Deeper+Focal+MC+PPM", run_mc_dropout=True)
    
    print(f"\n{'='*100}")
    print(f"{'✓ TRAINING AND EVALUATION COMPLETED!':^100s}")
    print(f"{'='*100}")
    print(f"\nModel: Deeper + Focal + EIoU + MC Dropout + PPM")
    print(f"Enhancement: Pyramid Pooling Module from PSPNet")
    print(f"PPM Pyramid Scales: [1×1, 2×2, 3×3, 6×6]")
    print(f"Parameters: {params:,}")
    print(f"Results saved in: {save_dir}/")
    print(f"\n{'='*100}\n")
# Out:
# Configuring GPU settings...
# ✓ GPU found: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
#
# ====================================================================================================
#                           MOBILENET-UNET WITH PPM (PYRAMID POOLING MODULE)
# ====================================================================================================
# Loading train data...
#   train: 400 samples
# Loading val data...
#   val: 400 samples
# Loading test data...
#   test: 400 samples
# Split - Train: 600, Val: 200, Test: 400
#
# ================================================================================
# TRAINING: Deeper_Focal_MC_PPM
# ================================================================================
#   Loss: Focal + EIoU
#   Architecture: Deeper Decoder + MC Dropout + PPM
#   PPM: Pyramid Pooling Module from PSPNet
#
# Model Configuration:
#   Total Parameters: 43,754,115
#   Dropout Layers: 5
#   PPM Modules: 4 (one per decoder block)
#   PPM Pyramid Scales: [1×1, 2×2, 3×3, 6×6]
#   Enhancement: Pyramid Pooling for Multi-scale Global Context
# Epoch 1/50
# E0000 00:00:1763477190.160221     108 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763477190.394017     108 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.8571 - dice_class_0: 0.9122 - dice_class_1: 0.3008 - dice_class_2: 0.3264 - dice_coef_multiclass: 0.6181 - iou_class_0: 0.8578 - iou_class_1: 0.1869 - iou_class_2: 0.2173 - iou_coef_multiclass: 0.4600 - loss: 1.1455
# Epoch 1: val_loss improved from inf to 0.94131, saving model to results/Deeper_Focal_MC_PPM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 142s 255ms/step - accuracy: 0.8577 - dice_class_0: 0.9126 - dice_class_1: 0.3016 - dice_class_2: 0.3275 - dice_coef_multiclass: 0.6188 - iou_class_0: 0.8584 - iou_class_1: 0.1876 - iou_class_2: 0.2181 - iou_coef_multiclass: 0.4608 - loss: 1.1444 - val_accuracy: 0.9552 - val_dice_class_0: 0.9830 - val_dice_class_1: 7.6468e-04 - val_dice_class_2: 0.1639 - val_dice_coef_multiclass: 0.8833 - val_iou_class_0: 0.9666 - val_iou_class_1: 3.8345e-04 - val_iou_class_2: 0.0896 - val_iou_coef_multiclass: 0.7911 - val_loss: 0.9413 - learning_rate: 5.0000e-04
# Epoch 2/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9849 - dice_class_0: 0.9931 - dice_class_1: 0.6712 - dice_class_2: 0.5773 - dice_coef_multiclass: 0.8921 - iou_class_0: 0.9863 - iou_class_1: 0.5093 - iou_class_2: 0.4089 - iou_coef_multiclass: 0.8063 - loss: 0.7219
# Epoch 2: val_loss improved from 0.94131 to 0.54526, saving model to results/Deeper_Focal_MC_PPM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 185ms/step - accuracy: 0.9849 - dice_class_0: 0.9931 - dice_class_1: 0.6714 - dice_class_2: 0.5772 - dice_coef_multiclass: 0.8923 - iou_class_0: 0.9864 - iou_class_1: 0.5096 - iou_class_2: 0.4088 - iou_coef_multiclass: 0.8066 - loss: 0.7216 - val_accuracy: 0.9785 - val_dice_class_0: 0.9903 - val_dice_class_1: 0.5586 - val_dice_class_2: 0.4629 - val_dice_coef_multiclass: 0.9759 - val_iou_class_0: 0.9807 - val_iou_class_1: 0.3895 - val_iou_class_2: 0.3025 - val_iou_coef_multiclass: 0.9529 - val_loss: 0.5453 - learning_rate: 5.0000e-04
# Epoch 3/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9925 - dice_class_0: 0.9969 - dice_class_1: 0.7891 - dice_class_2: 0.7319 - dice_coef_multiclass: 0.9731 - iou_class_0: 0.9938 - iou_class_1: 0.6550 - iou_class_2: 0.5913 - iou_coef_multiclass: 0.9477 - loss: 0.4906
# Epoch 3: val_loss improved from 0.54526 to 0.25168, saving model to results/Deeper_Focal_MC_PPM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 181ms/step - accuracy: 0.9925 - dice_class_0: 0.9969 - dice_class_1: 0.7891 - dice_class_2: 0.7324 - dice_coef_multiclass: 0.9731 - iou_class_0: 0.9938 - iou_class_1: 0.6551 - iou_class_2: 0.5920 - iou_coef_multiclass: 0.9478 - loss: 0.4901 - val_accuracy: 0.9952 - val_dice_class_0: 0.9983 - val_dice_class_1: 0.8207 - val_dice_class_2: 0.8196 - val_dice_coef_multiclass: 0.9946 - val_iou_class_0: 0.9965 - val_iou_class_1: 0.6975 - val_iou_class_2: 0.6992 - val_iou_coef_multiclass: 0.9893 - val_loss: 0.2517 - learning_rate: 5.0000e-04
# Epoch 4/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9964 - dice_class_0: 0.9988 - dice_class_1: 0.8635 - dice_class_2: 0.8569 - dice_coef_multiclass: 0.9941 - iou_class_0: 0.9975 - iou_class_1: 0.7612 - iou_class_2: 0.7521 - iou_coef_multiclass: 0.9883 - loss: 0.2543
# Epoch 4: val_loss did not improve from 0.25168
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 157ms/step - accuracy: 0.9964 - dice_class_0: 0.9988 - dice_class_1: 0.8636 - dice_class_2: 0.8569 - dice_coef_multiclass: 0.9941 - iou_class_0: 0.9975 - iou_class_1: 0.7613 - iou_class_2: 0.7521 - iou_coef_multiclass: 0.9883 - loss: 0.2541 - val_accuracy: 0.9956 - val_dice_class_0: 0.9984 - val_dice_class_1: 0.8111 - val_dice_class_2: 0.8127 - val_dice_coef_multiclass: 0.9954 - val_iou_class_0: 0.9969 - val_iou_class_1: 0.6861 - val_iou_class_2: 0.6906 - val_iou_coef_multiclass: 0.9909 - val_loss: 0.2600 - learning_rate: 5.0000e-04
# Epoch 5/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9970 - dice_class_0: 0.9990 - dice_class_1: 0.8815 - dice_class_2: 0.8749 - dice_coef_multiclass: 0.9964 - iou_class_0: 0.9981 - iou_class_1: 0.7894 - iou_class_2: 0.7790 - iou_coef_multiclass: 0.9928 - loss: 0.1839
# Epoch 5: val_loss improved from 0.25168 to 0.21486, saving model to results/Deeper_Focal_MC_PPM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 183ms/step - accuracy: 0.9970 - dice_class_0: 0.9990 - dice_class_1: 0.8816 - dice_class_2: 0.8748 - dice_coef_multiclass: 0.9964 - iou_class_0: 0.9981 - iou_class_1: 0.7895 - iou_class_2: 0.7789 - iou_coef_multiclass: 0.9928 - loss: 0.1838 - val_accuracy: 0.9966 - val_dice_class_0: 0.9991 - val_dice_class_1: 0.8482 - val_dice_class_2: 0.8282 - val_dice_coef_multiclass: 0.9964 - val_iou_class_0: 0.9982 - val_iou_class_1: 0.7373 - val_iou_class_2: 0.7095 - val_iou_coef_multiclass: 0.9929 - val_loss: 0.2149 - learning_rate: 5.0000e-04
# Epoch 6/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9973 - dice_class_0: 0.9991 - dice_class_1: 0.8921 - dice_class_2: 0.8801 - dice_coef_multiclass: 0.9969 - iou_class_0: 0.9983 - iou_class_1: 0.8061 - iou_class_2: 0.7875 - iou_coef_multiclass: 0.9937 - loss: 0.1653
# Epoch 6: val_loss did not improve from 0.21486
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 158ms/step - accuracy: 0.9973 - dice_class_0: 0.9991 - dice_class_1: 0.8921 - dice_class_2: 0.8800 - dice_coef_multiclass: 0.9969 - iou_class_0: 0.9983 - iou_class_1: 0.8061 - iou_class_2: 0.7875 - iou_coef_multiclass: 0.9937 - loss: 0.1653 - val_accuracy: 0.9954 - val_dice_class_0: 0.9982 - val_dice_class_1: 0.8015 - val_dice_class_2: 0.8014 - val_dice_coef_multiclass: 0.9951 - val_iou_class_0: 0.9965 - val_iou_class_1: 0.6788 - val_iou_class_2: 0.6838 - val_iou_coef_multiclass: 0.9903 - val_loss: 0.2646 - learning_rate: 5.0000e-04
# Epoch 7/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9974 - dice_class_0: 0.9992 - dice_class_1: 0.8968 - dice_class_2: 0.8823 - dice_coef_multiclass: 0.9972 - iou_class_0: 0.9983 - iou_class_1: 0.8140 - iou_class_2: 0.7924 - iou_coef_multiclass: 0.9943 - loss: 0.1536
# Epoch 7: val_loss did not improve from 0.21486
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 157ms/step - accuracy: 0.9974 - dice_class_0: 0.9992 - dice_class_1: 0.8968 - dice_class_2: 0.8823 - dice_coef_multiclass: 0.9972 - iou_class_0: 0.9983 - iou_class_1: 0.8140 - iou_class_2: 0.7924 - iou_coef_multiclass: 0.9943 - loss: 0.1536 - val_accuracy: 0.9966 - val_dice_class_0: 0.9991 - val_dice_class_1: 0.8484 - val_dice_class_2: 0.8237 - val_dice_coef_multiclass: 0.9962 - val_iou_class_0: 0.9982 - val_iou_class_1: 0.7382 - val_iou_class_2: 0.7028 - val_iou_coef_multiclass: 0.9924 - val_loss: 0.2184 - learning_rate: 5.0000e-04
# Epoch 8/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9976 - dice_class_0: 0.9993 - dice_class_1: 0.9041 - dice_class_2: 0.8905 - dice_coef_multiclass: 0.9974 - iou_class_0: 0.9985 - iou_class_1: 0.8257 - iou_class_2: 0.8039 - iou_coef_multiclass: 0.9949 - loss: 0.1434
# Epoch 8: val_loss improved from 0.21486 to 0.19686, saving model to results/Deeper_Focal_MC_PPM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 182ms/step - accuracy: 0.9976 - dice_class_0: 0.9993 - dice_class_1: 0.9040 - dice_class_2: 0.8905 - dice_coef_multiclass: 0.9974 - iou_class_0: 0.9985 - iou_class_1: 0.8256 - iou_class_2: 0.8039 - iou_coef_multiclass: 0.9949 - loss: 0.1434 - val_accuracy: 0.9965 - val_dice_class_0: 0.9988 - val_dice_class_1: 0.8473 - val_dice_class_2: 0.8522 - val_dice_coef_multiclass: 0.9964 - val_iou_class_0: 0.9975 - val_iou_class_1: 0.7373 - val_iou_class_2: 0.7479 - val_iou_coef_multiclass: 0.9929 - val_loss: 0.1969 - learning_rate: 5.0000e-04
# Epoch 9/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9117 - dice_class_2: 0.9000 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9986 - iou_class_1: 0.8381 - iou_class_2: 0.8191 - iou_coef_multiclass: 0.9953 - loss: 0.1314
# Epoch 9: val_loss improved from 0.19686 to 0.16561, saving model to results/Deeper_Focal_MC_PPM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 184ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9116 - dice_class_2: 0.8999 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9986 - iou_class_1: 0.8381 - iou_class_2: 0.8190 - iou_coef_multiclass: 0.9953 - loss: 0.1314 - val_accuracy: 0.9972 - val_dice_class_0: 0.9991 - val_dice_class_1: 0.8824 - val_dice_class_2: 0.8621 - val_dice_coef_multiclass: 0.9971 - val_iou_class_0: 0.9982 - val_iou_class_1: 0.7914 - val_iou_class_2: 0.7608 - val_iou_coef_multiclass: 0.9942 - val_loss: 0.1656 - learning_rate: 5.0000e-04
# Epoch 10/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9976 - dice_class_0: 0.9992 - dice_class_1: 0.9039 - dice_class_2: 0.8980 - dice_coef_multiclass: 0.9975 - iou_class_0: 0.9984 - iou_class_1: 0.8258 - iou_class_2: 0.8158 - iou_coef_multiclass: 0.9950 - loss: 0.1363
# Epoch 10: val_loss improved from 0.16561 to 0.15029, saving model to results/Deeper_Focal_MC_PPM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 182ms/step - accuracy: 0.9976 - dice_class_0: 0.9992 - dice_class_1: 0.9039 - dice_class_2: 0.8980 - dice_coef_multiclass: 0.9975 - iou_class_0: 0.9984 - iou_class_1: 0.8259 - iou_class_2: 0.8158 - iou_coef_multiclass: 0.9950 - loss: 0.1363 - val_accuracy: 0.9975 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8940 - val_dice_class_2: 0.8809 - val_dice_coef_multiclass: 0.9975 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.8094 - val_iou_class_2: 0.7885 - val_iou_coef_multiclass: 0.9950 - val_loss: 0.1503 - learning_rate: 5.0000e-04
# Epoch 11/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9136 - dice_class_2: 0.9017 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9986 - iou_class_1: 0.8418 - iou_class_2: 0.8221 - iou_coef_multiclass: 0.9954 - loss: 0.1283
# Epoch 11: val_loss did not improve from 0.15029
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 158ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9136 - dice_class_2: 0.9016 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9986 - iou_class_1: 0.8417 - iou_class_2: 0.8220 - iou_coef_multiclass: 0.9954 - loss: 0.1283 - val_accuracy: 0.9968 - val_dice_class_0: 0.9989 - val_dice_class_1: 0.8607 - val_dice_class_2: 0.8523 - val_dice_coef_multiclass: 0.9967 - val_iou_class_0: 0.9978 - val_iou_class_1: 0.7581 - val_iou_class_2: 0.7497 - val_iou_coef_multiclass: 0.9934 - val_loss: 0.1904 - learning_rate: 5.0000e-04
# Epoch 12/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9975 - dice_class_0: 0.9992 - dice_class_1: 0.9013 - dice_class_2: 0.8925 - dice_coef_multiclass: 0.9974 - iou_class_0: 0.9984 - iou_class_1: 0.8211 - iou_class_2: 0.8070 - iou_coef_multiclass: 0.9948 - loss: 0.1412
# Epoch 12: val_loss did not improve from 0.15029
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 158ms/step - accuracy: 0.9975 - dice_class_0: 0.9992 - dice_class_1: 0.9013 - dice_class_2: 0.8925 - dice_coef_multiclass: 0.9974 - iou_class_0: 0.9984 - iou_class_1: 0.8212 - iou_class_2: 0.8070 - iou_coef_multiclass: 0.9948 - loss: 0.1412 - val_accuracy: 0.9972 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8796 - val_dice_class_2: 0.8538 - val_dice_coef_multiclass: 0.9971 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.7862 - val_iou_class_2: 0.7467 - val_iou_coef_multiclass: 0.9943 - val_loss: 0.1799 - learning_rate: 5.0000e-04
# Epoch 13/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9109 - dice_class_2: 0.9043 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9986 - iou_class_1: 0.8368 - iou_class_2: 0.8265 - iou_coef_multiclass: 0.9955 - loss: 0.1272
# Epoch 13: val_loss did not improve from 0.15029
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 158ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9109 - dice_class_2: 0.9043 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9986 - iou_class_1: 0.8368 - iou_class_2: 0.8265 - iou_coef_multiclass: 0.9955 - loss: 0.1272 - val_accuracy: 0.9975 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8948 - val_dice_class_2: 0.8698 - val_dice_coef_multiclass: 0.9974 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.8112 - val_iou_class_2: 0.7718 - val_iou_coef_multiclass: 0.9948 - val_loss: 0.1552 - learning_rate: 5.0000e-04
# Epoch 14/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9240 - dice_class_2: 0.9172 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8591 - iou_class_2: 0.8479 - iou_coef_multiclass: 0.9961 - loss: 0.1107
# Epoch 14: val_loss improved from 0.15029 to 0.14442, saving model to results/Deeper_Focal_MC_PPM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 189ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9240 - dice_class_2: 0.9172 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8591 - iou_class_2: 0.8479 - iou_coef_multiclass: 0.9961 - loss: 0.1107 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8989 - val_dice_class_2: 0.8847 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8173 - val_iou_class_2: 0.7945 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1444 - learning_rate: 1.5000e-04
# Epoch 15/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9242 - dice_class_2: 0.9206 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8593 - iou_class_2: 0.8535 - iou_coef_multiclass: 0.9961 - loss: 0.1082
# Epoch 15: val_loss improved from 0.14442 to 0.13470, saving model to results/Deeper_Focal_MC_PPM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 181ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9242 - dice_class_2: 0.9206 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8593 - iou_class_2: 0.8535 - iou_coef_multiclass: 0.9961 - loss: 0.1082 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9072 - val_dice_class_2: 0.8897 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8311 - val_iou_class_2: 0.8027 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1347 - learning_rate: 1.5000e-04
# Epoch 16/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9245 - dice_class_2: 0.9185 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8602 - iou_class_2: 0.8504 - iou_coef_multiclass: 0.9962 - loss: 0.1086
# Epoch 16: val_loss improved from 0.13470 to 0.13310, saving model to results/Deeper_Focal_MC_PPM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 185ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9245 - dice_class_2: 0.9186 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8602 - iou_class_2: 0.8504 - iou_coef_multiclass: 0.9962 - loss: 0.1086 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9094 - val_dice_class_2: 0.8917 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8346 - val_iou_class_2: 0.8052 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1331 - learning_rate: 1.5000e-04
# Epoch 17/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9255 - dice_class_2: 0.9217 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8617 - iou_class_2: 0.8554 - iou_coef_multiclass: 0.9962 - loss: 0.1065
# Epoch 17: val_loss did not improve from 0.13310
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 160ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9255 - dice_class_2: 0.9217 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8617 - iou_class_2: 0.8555 - iou_coef_multiclass: 0.9962 - loss: 0.1065 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9082 - val_dice_class_2: 0.8854 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8327 - val_iou_class_2: 0.7961 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1364 - learning_rate: 1.5000e-04
# Epoch 18/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9284 - dice_class_2: 0.9252 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8666 - iou_class_2: 0.8616 - iou_coef_multiclass: 0.9963 - loss: 0.1022
# Epoch 18: val_loss did not improve from 0.13310
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 159ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9284 - dice_class_2: 0.9252 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8666 - iou_class_2: 0.8616 - iou_coef_multiclass: 0.9963 - loss: 0.1022 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9067 - val_dice_class_2: 0.8934 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8300 - val_iou_class_2: 0.8082 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1352 - learning_rate: 1.5000e-04
# Epoch 19/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9278 - dice_class_2: 0.9294 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8657 - iou_class_2: 0.8691 - iou_coef_multiclass: 0.9963 - loss: 0.1005
# Epoch 19: val_loss did not improve from 0.13310
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 4.500000213738531e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 157ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9278 - dice_class_2: 0.9294 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8657 - iou_class_2: 0.8690 - iou_coef_multiclass: 0.9963 - loss: 0.1005 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8992 - val_dice_class_2: 0.8823 - val_dice_coef_multiclass: 0.9975 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8182 - val_iou_class_2: 0.7913 - val_iou_coef_multiclass: 0.9951 - val_loss: 0.1439 - learning_rate: 1.5000e-04
# Epoch 20/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9312 - dice_class_2: 0.9332 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8717 - iou_class_2: 0.8753 - iou_coef_multiclass: 0.9965 - loss: 0.0956
# Epoch 20: val_loss improved from 0.13310 to 0.13225, saving model to results/Deeper_Focal_MC_PPM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 184ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9312 - dice_class_2: 0.9332 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8717 - iou_class_2: 0.8753 - iou_coef_multiclass: 0.9965 - loss: 0.0956 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9121 - val_dice_class_2: 0.8898 - val_dice_coef_multiclass: 0.9979 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8389 - val_iou_class_2: 0.8024 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1322 - learning_rate: 4.5000e-05
# Epoch 21/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9341 - dice_class_2: 0.9355 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8766 - iou_class_2: 0.8794 - iou_coef_multiclass: 0.9966 - loss: 0.0920
# Epoch 21: val_loss did not improve from 0.13225
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 159ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9341 - dice_class_2: 0.9355 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8766 - iou_class_2: 0.8793 - iou_coef_multiclass: 0.9966 - loss: 0.0920 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9065 - val_dice_class_2: 0.8906 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8299 - val_iou_class_2: 0.8041 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1342 - learning_rate: 4.5000e-05
# Epoch 22/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9345 - dice_class_2: 0.9336 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8774 - iou_class_2: 0.8760 - iou_coef_multiclass: 0.9966 - loss: 0.0928
# Epoch 22: val_loss did not improve from 0.13225
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 159ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9345 - dice_class_2: 0.9336 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8774 - iou_class_2: 0.8760 - iou_coef_multiclass: 0.9966 - loss: 0.0928 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9073 - val_dice_class_2: 0.8880 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8313 - val_iou_class_2: 0.7995 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1370 - learning_rate: 4.5000e-05
# Epoch 23/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9345 - dice_class_2: 0.9355 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8774 - iou_class_2: 0.8796 - iou_coef_multiclass: 0.9966 - loss: 0.0920
# Epoch 23: val_loss improved from 0.13225 to 0.13043, saving model to results/Deeper_Focal_MC_PPM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 28s 184ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9345 - dice_class_2: 0.9355 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8774 - iou_class_2: 0.8796 - iou_coef_multiclass: 0.9966 - loss: 0.0920 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9109 - val_dice_class_2: 0.8950 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8371 - val_iou_class_2: 0.8108 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1304 - learning_rate: 4.5000e-05
# Epoch 24/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9357 - dice_class_2: 0.9376 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8793 - iou_class_2: 0.8831 - iou_coef_multiclass: 0.9966 - loss: 0.0900
# Epoch 24: val_loss did not improve from 0.13043
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 159ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9356 - dice_class_2: 0.9376 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8793 - iou_class_2: 0.8830 - iou_coef_multiclass: 0.9966 - loss: 0.0900 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9042 - val_dice_class_2: 0.8900 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8268 - val_iou_class_2: 0.8030 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1367 - learning_rate: 4.5000e-05
# Epoch 25/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9357 - dice_class_2: 0.9352 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8794 - iou_class_2: 0.8787 - iou_coef_multiclass: 0.9967 - loss: 0.0920
# Epoch 25: val_loss did not improve from 0.13043
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 158ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9357 - dice_class_2: 0.9352 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8794 - iou_class_2: 0.8787 - iou_coef_multiclass: 0.9967 - loss: 0.0920 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9029 - val_dice_class_2: 0.8877 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8242 - val_iou_class_2: 0.7989 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1394 - learning_rate: 4.5000e-05
# Epoch 26/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9353 - dice_class_2: 0.9363 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8788 - iou_class_2: 0.8809 - iou_coef_multiclass: 0.9967 - loss: 0.0904
# Epoch 26: val_loss did not improve from 0.13043
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.3500000204658135e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 159ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9353 - dice_class_2: 0.9363 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8788 - iou_class_2: 0.8809 - iou_coef_multiclass: 0.9967 - loss: 0.0904 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9073 - val_dice_class_2: 0.8879 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8313 - val_iou_class_2: 0.7997 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1373 - learning_rate: 4.5000e-05
# Epoch 27/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9377 - dice_class_2: 0.9386 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8829 - iou_class_2: 0.8847 - iou_coef_multiclass: 0.9967 - loss: 0.0872
# Epoch 27: val_loss did not improve from 0.13043
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 158ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9377 - dice_class_2: 0.9386 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8829 - iou_class_2: 0.8847 - iou_coef_multiclass: 0.9967 - loss: 0.0872 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9084 - val_dice_class_2: 0.8875 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8328 - val_iou_class_2: 0.7995 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1366 - learning_rate: 1.3500e-05
# Epoch 28/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9383 - dice_class_2: 0.9401 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8840 - iou_class_2: 0.8874 - iou_coef_multiclass: 0.9968 - loss: 0.0859
# Epoch 28: val_loss did not improve from 0.13043
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 159ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9383 - dice_class_2: 0.9401 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8840 - iou_class_2: 0.8874 - iou_coef_multiclass: 0.9968 - loss: 0.0859 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9121 - val_dice_class_2: 0.8940 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8389 - val_iou_class_2: 0.8096 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1309 - learning_rate: 1.3500e-05
# Epoch 29/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9373 - dice_class_2: 0.9379 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8822 - iou_class_2: 0.8837 - iou_coef_multiclass: 0.9968 - loss: 0.0876
# Epoch 29: val_loss did not improve from 0.13043
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 4.050000006827758e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 159ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9373 - dice_class_2: 0.9379 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8822 - iou_class_2: 0.8837 - iou_coef_multiclass: 0.9968 - loss: 0.0876 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9028 - val_dice_class_2: 0.8893 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8242 - val_iou_class_2: 0.8016 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1386 - learning_rate: 1.3500e-05
# Epoch 30/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9371 - dice_class_2: 0.9399 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8819 - iou_class_2: 0.8871 - iou_coef_multiclass: 0.9967 - loss: 0.0871
# Epoch 30: val_loss did not improve from 0.13043
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 158ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9371 - dice_class_2: 0.9398 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8819 - iou_class_2: 0.8871 - iou_coef_multiclass: 0.9967 - loss: 0.0871 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9100 - val_dice_class_2: 0.8882 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8354 - val_iou_class_2: 0.8000 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1345 - learning_rate: 4.0500e-06
# Epoch 31/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9385 - dice_class_2: 0.9405 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8845 - iou_class_2: 0.8883 - iou_coef_multiclass: 0.9969 - loss: 0.0858
# Epoch 31: val_loss did not improve from 0.13043
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 158ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9385 - dice_class_2: 0.9405 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8844 - iou_class_2: 0.8882 - iou_coef_multiclass: 0.9969 - loss: 0.0858 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9010 - val_dice_class_2: 0.8796 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8207 - val_iou_class_2: 0.7866 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1434 - learning_rate: 4.0500e-06
# Epoch 32/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9375 - dice_class_2: 0.9378 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8827 - iou_class_2: 0.8835 - iou_coef_multiclass: 0.9968 - loss: 0.0883
# Epoch 32: val_loss improved from 0.13043 to 0.12807, saving model to results/Deeper_Focal_MC_PPM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 183ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9375 - dice_class_2: 0.9379 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8827 - iou_class_2: 0.8835 - iou_coef_multiclass: 0.9968 - loss: 0.0883 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9141 - val_dice_class_2: 0.8949 - val_dice_coef_multiclass: 0.9979 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8423 - val_iou_class_2: 0.8105 - val_iou_coef_multiclass: 0.9958 - val_loss: 0.1281 - learning_rate: 4.0500e-06
# Epoch 33/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9395 - dice_class_2: 0.9381 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8862 - iou_class_2: 0.8843 - iou_coef_multiclass: 0.9969 - loss: 0.0862
# Epoch 33: val_loss did not improve from 0.12807
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 159ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9395 - dice_class_2: 0.9382 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8862 - iou_class_2: 0.8844 - iou_coef_multiclass: 0.9969 - loss: 0.0862 - val_accuracy: 0.9977 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9068 - val_dice_class_2: 0.8852 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8306 - val_iou_class_2: 0.7955 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1393 - learning_rate: 4.0500e-06
# Epoch 34/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9381 - dice_class_2: 0.9417 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8837 - iou_class_2: 0.8904 - iou_coef_multiclass: 0.9968 - loss: 0.0855
# Epoch 34: val_loss did not improve from 0.12807
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 158ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9381 - dice_class_2: 0.9416 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8837 - iou_class_2: 0.8903 - iou_coef_multiclass: 0.9968 - loss: 0.0855 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9104 - val_dice_class_2: 0.8940 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8363 - val_iou_class_2: 0.8092 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1318 - learning_rate: 4.0500e-06
# Epoch 35/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9390 - dice_class_2: 0.9420 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8852 - iou_class_2: 0.8908 - iou_coef_multiclass: 0.9968 - loss: 0.0846
# Epoch 35: val_loss did not improve from 0.12807
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1.2149999747634864e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 158ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9390 - dice_class_2: 0.9420 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8852 - iou_class_2: 0.8908 - iou_coef_multiclass: 0.9968 - loss: 0.0846 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9114 - val_dice_class_2: 0.8910 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8378 - val_iou_class_2: 0.8045 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1323 - learning_rate: 4.0500e-06
# Epoch 36/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9402 - dice_class_2: 0.9411 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8874 - iou_class_2: 0.8894 - iou_coef_multiclass: 0.9969 - loss: 0.0845
# Epoch 36: val_loss did not improve from 0.12807
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 158ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9402 - dice_class_2: 0.9411 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8874 - iou_class_2: 0.8894 - iou_coef_multiclass: 0.9969 - loss: 0.0845 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9079 - val_dice_class_2: 0.8928 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8323 - val_iou_class_2: 0.8077 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1332 - learning_rate: 1.2150e-06
# Epoch 37/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9383 - dice_class_2: 0.9395 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8840 - iou_class_2: 0.8864 - iou_coef_multiclass: 0.9968 - loss: 0.0870
# Epoch 37: val_loss did not improve from 0.12807
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 159ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9383 - dice_class_2: 0.9395 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8840 - iou_class_2: 0.8864 - iou_coef_multiclass: 0.9968 - loss: 0.0870 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9076 - val_dice_class_2: 0.8853 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8316 - val_iou_class_2: 0.7958 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1376 - learning_rate: 1.2150e-06
# Epoch 38/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9371 - dice_class_2: 0.9389 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8819 - iou_class_2: 0.8855 - iou_coef_multiclass: 0.9968 - loss: 0.0880
# Epoch 38: val_loss did not improve from 0.12807
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 3.644999992502562e-07.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 159ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9371 - dice_class_2: 0.9389 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8819 - iou_class_2: 0.8855 - iou_coef_multiclass: 0.9968 - loss: 0.0880 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9089 - val_dice_class_2: 0.8878 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8339 - val_iou_class_2: 0.7992 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1352 - learning_rate: 1.2150e-06
# Epoch 39/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9387 - dice_class_2: 0.9406 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8847 - iou_class_2: 0.8885 - iou_coef_multiclass: 0.9968 - loss: 0.0859
# Epoch 39: val_loss did not improve from 0.12807
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 158ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9387 - dice_class_2: 0.9406 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8847 - iou_class_2: 0.8885 - iou_coef_multiclass: 0.9968 - loss: 0.0859 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9069 - val_dice_class_2: 0.8911 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8303 - val_iou_class_2: 0.8047 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1351 - learning_rate: 3.6450e-07
# Epoch 40/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9377 - dice_class_2: 0.9391 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8829 - iou_class_2: 0.8857 - iou_coef_multiclass: 0.9968 - loss: 0.0868
# Epoch 40: val_loss did not improve from 0.12807
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 158ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9377 - dice_class_2: 0.9391 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8829 - iou_class_2: 0.8857 - iou_coef_multiclass: 0.9968 - loss: 0.0868 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9085 - val_dice_class_2: 0.8929 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8335 - val_iou_class_2: 0.8078 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1327 - learning_rate: 3.6450e-07
# Epoch 41/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9404 - dice_class_2: 0.9425 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8876 - iou_class_2: 0.8916 - iou_coef_multiclass: 0.9969 - loss: 0.0838
# Epoch 41: val_loss did not improve from 0.12807
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.0935000318568199e-07.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 158ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9404 - dice_class_2: 0.9425 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8876 - iou_class_2: 0.8916 - iou_coef_multiclass: 0.9969 - loss: 0.0838 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9092 - val_dice_class_2: 0.8861 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8342 - val_iou_class_2: 0.7974 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1369 - learning_rate: 3.6450e-07
# Epoch 42/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9383 - dice_class_2: 0.9396 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8843 - iou_class_2: 0.8867 - iou_coef_multiclass: 0.9969 - loss: 0.0863
# Epoch 42: val_loss did not improve from 0.12807
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 158ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9383 - dice_class_2: 0.9396 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8843 - iou_class_2: 0.8867 - iou_coef_multiclass: 0.9969 - loss: 0.0863 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9102 - val_dice_class_2: 0.8905 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8358 - val_iou_class_2: 0.8036 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1327 - learning_rate: 1.0935e-07
# Epoch 42: early stopping
# Restoring model weights from the end of the best epoch: 32.
# ✓ Training completed
#
# Generating visualizations...
#   ✓ Saved: results/Deeper_Focal_MC_PPM_training_curves.png
#   ✓ Saved: results/Deeper_Focal_MC_PPM_history.png
#   ✓ Saved: results/Deeper_Focal_MC_PPM_predictions.png
# ================================================================================
# EVALUATION: Deeper+Focal+MC+PPM
# ================================================================================
#   ✓ Saved: results/Deeper+Focal+MC+PPM_confusion_matrices.png
# Confusion Matrix:
# [[25768490    16500        0]
#  [   16420   290241     8410]
#  [      51    15503    98785]]
#
# Normalized Confusion Matrix:
# [[0.999 0.001 0.   ]
#  [0.052 0.921 0.027]
#  [0.    0.136 0.864]]
#
# Precision, Recall, F1 Score per class:
#   Background: Precision=0.9994, Recall=0.9994, F1=0.9994
#   Disc: Precision=0.9007, Recall=0.9212, F1=0.9108
#   Cup: Precision=0.9215, Recall=0.8640, F1=0.8918
#
# Macro-averaged metrics:
#   Precision: 0.9405
#   Recall: 0.9282
#   F1 Score: 0.9340
#   Background: Dice=0.9994, IoU=0.9987
#   Disc: Dice=0.9108, IoU=0.8363
#   Cup: Dice=0.8918, IoU=0.8048
#
# MC Dropout Evaluation:
#
# Running MC Dropout with 10 stochastic forward passes...
#   Completed: 5/10 forward passes
#   Completed: 10/10 forward passes
# ✓ MC Dropout completed
#   Background uncertainty: 0.0003
#   Disc uncertainty: 0.0004
#   Cup uncertainty: 0.0002
#
# ====================================================================================================
#                                 ✓ TRAINING AND EVALUATION COMPLETED!
# ====================================================================================================
#
# Model: Deeper + Focal + EIoU + MC Dropout + PPM
# Enhancement: Pyramid Pooling Module from PSPNet
# PPM Pyramid Scales: [1×1, 2×2, 3×3, 6×6]
# Parameters: 43,754,115
# Results saved in: results/
#
# ====================================================================================================
