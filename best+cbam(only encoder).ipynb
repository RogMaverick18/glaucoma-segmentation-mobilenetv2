# %%
"""
COMBINED ADVANCED MOBILENET-UNET WITH ENCODER-ONLY CBAM ATTENTION
===================================================================
This combines:
1. Deeper decoder architecture with enhanced blocks
2. Focal-EIoU loss
3. MC Dropout for uncertainty estimation
4. CBAM (Convolutional Block Attention Module) - ENCODER-ONLY VERSION
   - Applied ONLY to: Encoder outputs (4 locations + bridge)
   - REMOVED from: decoder blocks, final layer
   - Each encoder output gets attention ONCE, then flows to both skip and next encoder

STRATEGY: Place CBAM after each encoder block to refine encoder features.
These refined features naturally flow to skip connections and next encoder layers
without double attention.
"""

import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, backend as K
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import albumentations as A
import warnings
import gc
warnings.filterwarnings('ignore')

plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# ============================================================================
# HELPER FUNCTIONS
# ============================================================================

def configure_gpu():
    """Configure GPU settings for optimal performance"""
    print("Configuring GPU settings...")
    physical_devices = tf.config.list_physical_devices('GPU')
    if physical_devices:
        try:
            for gpu in physical_devices:
                tf.config.experimental.set_memory_growth(gpu, True)
            tf.config.set_visible_devices(physical_devices[0], 'GPU')
            print(f"✓ GPU found: {physical_devices}")
            print("  GPU device name:", tf.test.gpu_device_name())
            return True
        except RuntimeError as e:
            print(f"✗ GPU error: {e}")
            return False
    else:
        print("✗ No GPU found, using CPU")
        return False

def load_images_masks(images_folder, masks_folder, img_size=(256,256)):
    """Load images and masks from folders"""
    images, masks = [], []
    image_files = sorted(os.listdir(images_folder))
    mask_files = sorted(os.listdir(masks_folder))
    mask_dict = {os.path.splitext(f)[0]: f for f in mask_files}
    
    for img_file in image_files:
        base = os.path.splitext(img_file)[0]
        if base in mask_dict:
            img = cv2.imread(os.path.join(images_folder, img_file))
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, img_size) / 255.0
            
            mask = cv2.imread(os.path.join(masks_folder, mask_dict[base]), cv2.IMREAD_GRAYSCALE)
            mask = cv2.resize(mask, img_size)
            unique_vals = np.unique(mask)
            if len(unique_vals) > 3 or np.max(unique_vals) > 2:
                mask = np.clip(mask // 85, 0, 2).astype(np.uint8)
            
            images.append(img)
            masks.append(mask)
    
    return np.array(images, dtype=np.float32), np.array(masks, dtype=np.uint8)

def load_all_data(root_dir):
    """Load all data from existing splits and merge"""
    all_images, all_masks = [], []
    for split in ["train", "val", "test"]:
        print(f"Loading {split} data...")
        imgs, msks = load_images_masks(
            os.path.join(root_dir, split, "Images"),
            os.path.join(root_dir, split, "Masks")
        )
        all_images.append(imgs)
        all_masks.append(msks)
        print(f"  {split}: {imgs.shape[0]} samples")
    
    return np.concatenate(all_images), np.concatenate(all_masks)

def create_new_split(all_images, all_masks):
    """Create new split: 600 train, 200 val, 400 test"""
    X_temp, X_test, y_temp, y_test = train_test_split(
        all_images, all_masks, test_size=400, random_state=42
    )
    X_train, X_val, y_train, y_val = train_test_split(
        X_temp, y_temp, test_size=200, random_state=42
    )
    print(f"Split - Train: {X_train.shape[0]}, Val: {X_val.shape[0]}, Test: {X_test.shape[0]}")
    return (X_train, y_train), (X_val, y_val), (X_test, y_test)

def setup_augmentations():
    return A.Compose([
        A.RandomBrightnessContrast(brightness_limit=0.15, contrast_limit=0.15, p=0.7),
        A.HueSaturationValue(hue_shift_limit=10, sat_shift_limit=15, val_shift_limit=10, p=0.5),
        A.GaussianBlur(blur_limit=3, p=0.3),
        A.RandomGamma(gamma_limit=(80, 120), p=0.3),
    ])

def data_generator(images, masks, batch_size, augment=None):
    idxs = np.arange(len(images))
    while True:
        np.random.shuffle(idxs)
        for i in range(0, len(images), batch_size):
            batch_idxs = idxs[i:i+batch_size]
            batch_x, batch_y = [], []
            
            for idx in batch_idxs:
                img, mask = images[idx], masks[idx]
                
                if augment:
                    aug = augment(image=img, mask=mask)
                    img_aug, mask_aug = aug['image'], aug['mask']
                else:
                    img_aug, mask_aug = img, mask
                
                mask_cat = to_categorical(mask_aug, num_classes=3)
                batch_x.append(img_aug)
                batch_y.append(mask_cat)
            
            batch_x = np.stack(batch_x).astype(np.float32)
            batch_y = np.stack(batch_y).astype(np.float32)
            
            yield batch_x, batch_y

# ============================================================================
# CBAM ATTENTION MODULES
# ============================================================================

def channel_attention(input_feature, ratio=8, name=""):
    """Channel Attention Module (CAM)"""
    channel = input_feature.shape[-1]
    
    shared_layer_one = layers.Dense(channel//ratio, activation='relu', name=f'channel_attention_dense1_{name}')
    shared_layer_two = layers.Dense(channel, activation='sigmoid', name=f'channel_attention_dense2_{name}')
    
    avg_pool = layers.GlobalAveragePooling2D()(input_feature)
    avg_pool = layers.Reshape((1, 1, channel))(avg_pool)
    avg_pool = shared_layer_one(avg_pool)
    avg_pool = shared_layer_two(avg_pool)
    
    max_pool = layers.GlobalMaxPooling2D()(input_feature)
    max_pool = layers.Reshape((1, 1, channel))(max_pool)
    max_pool = shared_layer_one(max_pool)
    max_pool = shared_layer_two(max_pool)
    
    cbam_feature = layers.Add()([avg_pool, max_pool])
    cbam_feature = layers.Multiply()([input_feature, cbam_feature])
    
    return cbam_feature

def spatial_attention(input_feature, name=""):
    """Spatial Attention Module (SAM)"""
    kernel_size = 7
    
    avg_pool = layers.Lambda(lambda x: tf.reduce_mean(x, axis=3, keepdims=True))(input_feature)
    max_pool = layers.Lambda(lambda x: tf.reduce_max(x, axis=3, keepdims=True))(input_feature)
    concat = layers.Concatenate(axis=3)([avg_pool, max_pool])
    
    cbam_feature = layers.Conv2D(filters=1, kernel_size=kernel_size, strides=1, 
                                padding='same', activation='sigmoid', 
                                name=f'spatial_attention_conv_{name}')(concat)
    cbam_feature = layers.Multiply()([input_feature, cbam_feature])
    
    return cbam_feature

def cbam_block(cbam_feature, ratio=8, name=""):
    """CBAM: Convolutional Block Attention Module (Channel + Spatial)"""
    cbam_feature = channel_attention(cbam_feature, ratio, name=f"{name}_channel")
    cbam_feature = spatial_attention(cbam_feature, name=f"{name}_spatial")
    return cbam_feature

# ============================================================================
# LOSS FUNCTIONS
# ============================================================================

def focal_loss(y_true, y_pred, gamma=2.0, alpha=None, epsilon=1e-7):
    if alpha is None:
        alpha = [0.25, 1.0, 1.0]
    
    y_pred = K.clip(y_pred, epsilon, 1.0 - epsilon)
    focal_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        pt = y_pred_c
        focal_weight = K.pow(1.0 - pt, gamma)
        cross_entropy = -K.log(pt)
        focal_loss_c = alpha[c] * focal_weight * cross_entropy * y_true_c
        focal_loss_value += K.mean(focal_loss_c)
    
    return focal_loss_value

def enhanced_iou_loss(y_true, y_pred, smooth=1e-7):
    eiou_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        
        intersection = K.sum(y_true_c * y_pred_c, axis=[1, 2])
        union = K.sum(y_true_c, axis=[1, 2]) + K.sum(y_pred_c, axis=[1, 2]) - intersection
        iou = (intersection + smooth) / (union + smooth)
        
        height = K.cast(K.shape(y_true_c)[1], 'float32')
        width = K.cast(K.shape(y_true_c)[2], 'float32')
        
        y_coords = K.arange(0, height)
        x_coords = K.arange(0, width)
        y_grid = K.tile(K.reshape(y_coords, (-1, 1)), (1, K.cast(width, 'int32')))
        x_grid = K.tile(K.reshape(x_coords, (1, -1)), (K.cast(height, 'int32'), 1))
        y_grid = K.cast(y_grid, 'float32')
        x_grid = K.cast(x_grid, 'float32')
        
        true_mass = K.sum(y_true_c, axis=[1, 2]) + smooth
        true_center_y = K.sum(y_true_c * y_grid, axis=[1, 2]) / true_mass
        true_center_x = K.sum(y_true_c * x_grid, axis=[1, 2]) / true_mass
        
        pred_mass = K.sum(y_pred_c, axis=[1, 2]) + smooth
        pred_center_y = K.sum(y_pred_c * y_grid, axis=[1, 2]) / pred_mass
        pred_center_x = K.sum(y_pred_c * x_grid, axis=[1, 2]) / pred_mass
        
        center_distance = K.square(true_center_y - pred_center_y) + K.square(true_center_x - pred_center_x)
        diagonal = K.square(height) + K.square(width)
        center_penalty = center_distance / (diagonal + smooth)
        
        true_width = K.sqrt(K.sum(K.sum(y_true_c, axis=1), axis=1) + smooth)
        true_height = K.sqrt(K.sum(K.sum(y_true_c, axis=2), axis=1) + smooth)
        pred_width = K.sqrt(K.sum(K.sum(y_pred_c, axis=1), axis=1) + smooth)
        pred_height = K.sqrt(K.sum(K.sum(y_pred_c, axis=2), axis=1) + smooth)
        
        width_diff = K.square(pred_width - true_width)
        height_diff = K.square(pred_height - true_height)
        aspect_penalty = width_diff / (K.square(width) + smooth) + height_diff / (K.square(height) + smooth)
        
        eiou_c = 1.0 - iou + center_penalty + aspect_penalty
        eiou_loss_value += K.mean(eiou_c)
    
    return eiou_loss_value / 3.0

def focal_eiou_combined_loss(y_true, y_pred, focal_weight=1.0, eiou_weight=1.0, gamma=2.0, alpha=None):
    fl = focal_loss(y_true, y_pred, gamma=gamma, alpha=alpha)
    eiou = enhanced_iou_loss(y_true, y_pred)
    return focal_weight * fl + eiou_weight * eiou

# ============================================================================
# ENHANCED DECODER BLOCK (WITHOUT CBAM - for encoder-only version)
# ============================================================================

def enhanced_decoder_block_no_cbam(x, skip_connection, filters, block_name, dropout_rate=0.3):
    """Enhanced decoder block WITHOUT CBAM attention"""
    x = layers.UpSampling2D((2, 2), name=f'{block_name}_upsample')(x)
    
    if skip_connection.shape[-1] != x.shape[-1]:
        skip_connection = layers.Conv2D(x.shape[-1], (1, 1), activation='relu', 
                                      padding='same', name=f'{block_name}_skip_align')(skip_connection)
        skip_connection = layers.BatchNormalization(name=f'{block_name}_skip_bn')(skip_connection)
    
    x = layers.Concatenate(name=f'{block_name}_concat')([x, skip_connection])
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv1')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn1')(x)
    x = layers.Dropout(dropout_rate, name=f'{block_name}_dropout')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv2')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn2')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv3')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn3')(x)
    
    residual = x
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv4')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn4')(x)
    
    x = layers.Add(name=f'{block_name}_residual')([x, residual])
    x = layers.Conv2D(filters, (1, 1), activation='relu', padding='same', name=f'{block_name}_conv_final')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn_final')(x)
    
    # NO CBAM in decoder blocks for encoder-only version
    
    return x

# ============================================================================
# MODEL: ENCODER-ONLY CBAM VERSION (5 blocks: 4 encoder outputs + bridge)
# ============================================================================

def build_combined_unet_encoder_only_cbam(input_shape=(256, 256, 3), num_classes=3, 
                                          use_deeper=False, dropout_rate=0.3):
    """
    Combined MobileNet-UNet with ENCODER-ONLY CBAM
    
    CBAM Placement (ENCODER-ONLY VERSION):
    - Encoder_1 output (128x128): YES ✅ (then flows to skip_1)
    - Encoder_2 output (64x64): YES ✅ (then flows to skip_2)
    - Encoder_3 output (32x32): YES ✅ (then flows to skip_3)
    - Encoder_4 output (16x16): YES ✅ (then flows to skip_4)
    - Bridge output (8x8): YES ✅
    - Decoder blocks: NO CBAM ❌
    - Final layer: NO CBAM ❌
    Total: 5 CBAM blocks (on encoder outputs only)
    
    Rationale: Apply attention once to each encoder output. The refined features
    naturally flow to skip connections without double attention.
    """
    
    print(f"\nBuilding Combined UNet with ENCODER-ONLY CBAM...")
    print(f"  Deeper Architecture: {use_deeper}")
    print(f"  MC Dropout Rate: {dropout_rate}")
    print(f"  CBAM Attention: ENCODER-ONLY (5 blocks on encoder outputs)")
    
    inputs = layers.Input(input_shape, dtype='float32')
    backbone = MobileNetV2(input_tensor=inputs, weights='imagenet', include_top=False)
    
    # Get encoder outputs (RAW, before CBAM)
    enc_1_raw = backbone.get_layer('block_1_expand_relu').output  # 128x128
    enc_2_raw = backbone.get_layer('block_3_expand_relu').output  # 64x64
    enc_3_raw = backbone.get_layer('block_6_expand_relu').output  # 32x32
    enc_4_raw = backbone.get_layer('block_13_expand_relu').output # 16x16
    bridge_raw = backbone.output  # 8x8
    
    print("  Applying CBAM to encoder outputs...")
    print("    encoder_1 (128x128): WITH CBAM ✓ → flows to skip_1")
    print("    encoder_2 (64x64): WITH CBAM ✓ → flows to skip_2")
    print("    encoder_3 (32x32): WITH CBAM ✓ → flows to skip_3")
    print("    encoder_4 (16x16): WITH CBAM ✓ → flows to skip_4")
    print("    bridge (8x8): WITH CBAM ✓")
    
    # Apply CBAM to ALL encoder outputs (these become the skip connections)
    skip_1 = cbam_block(enc_1_raw, ratio=8, name="enc1")
    skip_2 = cbam_block(enc_2_raw, ratio=8, name="enc2")
    skip_3 = cbam_block(enc_3_raw, ratio=8, name="enc3")
    skip_4 = cbam_block(enc_4_raw, ratio=8, name="enc4")
    bridge = cbam_block(bridge_raw, ratio=8, name="bridge")
    
    # Deeper bridge (if enabled) - applied AFTER CBAM
    if use_deeper:
        bridge = layers.Conv2D(1024, (3, 3), activation='relu', padding='same')(bridge)
        bridge = layers.BatchNormalization()(bridge)
    
    if dropout_rate > 0:
        bridge = layers.Dropout(dropout_rate, name='bridge_dropout')(bridge)
    
    if use_deeper:
        print("  Building deeper decoder WITHOUT CBAM (attention only on encoder outputs)...")
        # All decoder blocks WITHOUT CBAM (use attention-refined skip connections)
        x = enhanced_decoder_block_no_cbam(bridge, skip_4, 512, 'decoder_1', dropout_rate)
        x = enhanced_decoder_block_no_cbam(x, skip_3, 256, 'decoder_2', dropout_rate)
        x = enhanced_decoder_block_no_cbam(x, skip_2, 128, 'decoder_3', dropout_rate * 0.7)
        x = enhanced_decoder_block_no_cbam(x, skip_1, 64, 'decoder_4', dropout_rate * 0.5)
    else:
        print("  Building baseline decoder WITHOUT CBAM...")
        # Baseline decoder without CBAM
        x = layers.UpSampling2D((2, 2))(bridge)
        x = layers.Concatenate()([x, skip_4])
        x = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        if dropout_rate > 0:
            x = layers.Dropout(dropout_rate)(x)
        x = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        
        x = layers.UpSampling2D((2, 2))(x)
        x = layers.Concatenate()([x, skip_3])
        x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        if dropout_rate > 0:
            x = layers.Dropout(dropout_rate)(x)
        x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        
        x = layers.UpSampling2D((2, 2))(x)
        x = layers.Concatenate()([x, skip_2])
        x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        if dropout_rate > 0:
            x = layers.Dropout(dropout_rate * 0.7)(x)
        x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        
        x = layers.UpSampling2D((2, 2))(x)
        x = layers.Concatenate()([x, skip_1])
        x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        if dropout_rate > 0:
            x = layers.Dropout(dropout_rate * 0.5)(x)
        x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
    
    # Final upsampling - NO CBAM
    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    
    outputs = layers.Conv2D(num_classes, (1, 1), activation='softmax', dtype='float32')(x)
    
    model = models.Model(inputs, outputs)
    
    # Print configuration
    if dropout_rate > 0:
        dropout_layers = [layer for layer in model.layers if isinstance(layer, layers.Dropout)]
        print(f"\n  MC Dropout Configuration:")
        print(f"    Total Dropout Layers: {len(dropout_layers)}")
        print(f"    Dropout Rates: {[f'{layer.rate:.2f}' for layer in dropout_layers]}")
    
    cbam_count = sum(1 for layer in model.layers if 'channel_attention' in layer.name or 'spatial_attention' in layer.name)
    print(f"\n  CBAM Configuration (ENCODER-ONLY):")
    print(f"    Total CBAM Components: {cbam_count}")
    print(f"    CBAM Locations: Encoder outputs ONLY (5 blocks)")
    print(f"    Removed CBAM from: Decoder blocks, Final layer")
    print(f"    Note: Each encoder output gets CBAM once, then flows to skip connection")
    
    return model

# ============================================================================
# METRICS
# ============================================================================

def dice_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    return (2. * intersection + smooth) / (K.sum(y_true_class) + K.sum(y_pred_class) + smooth)

def dice_class_0(y_true, y_pred): return dice_coef_class(y_true, y_pred, 0)
def dice_class_1(y_true, y_pred): return dice_coef_class(y_true, y_pred, 1)
def dice_class_2(y_true, y_pred): return dice_coef_class(y_true, y_pred, 2)

def iou_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    union = K.sum(y_true_class) + K.sum(y_pred_class) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_class_0(y_true, y_pred): return iou_coef_class(y_true, y_pred, 0)
def iou_class_1(y_true, y_pred): return iou_coef_class(y_true, y_pred, 1)
def iou_class_2(y_true, y_pred): return iou_coef_class(y_true, y_pred, 2)

# ============================================================================
# MC DROPOUT
# ============================================================================

def mc_dropout_predict(model, X, num_samples=15, batch_size=4, verbose=True):
    """MC Dropout prediction using training=True flag"""
    if verbose:
        print(f"\nRunning MC Dropout with {num_samples} stochastic forward passes...")
    
    predictions = []
    num_batches = int(np.ceil(len(X) / batch_size))
    
    for i in range(num_samples):
        if verbose and (i + 1) % 5 == 0:
            print(f"  Completed: {i+1}/{num_samples} forward passes")
        
        batch_preds = []
        for batch_idx in range(num_batches):
            start_idx = batch_idx * batch_size
            end_idx = min(start_idx + batch_size, len(X))
            X_batch = X[start_idx:end_idx]
            
            pred_batch = model(X_batch, training=True)
            batch_preds.append(pred_batch.numpy())
        
        pred = np.concatenate(batch_preds, axis=0)
        predictions.append(pred)
        
        if (i + 1) % 5 == 0:
            gc.collect()
    
    all_preds = np.array(predictions)
    mean_pred = np.mean(all_preds, axis=0)
    std_pred = np.std(all_preds, axis=0)
    
    del all_preds
    gc.collect()
    
    if verbose:
        print(f"✓ MC Dropout completed")
    
    return mean_pred, std_pred

# ============================================================================
# VISUALIZATION FUNCTIONS
# ============================================================================

def plot_training_history(history, model_name, save_dir='results'):
    """Plot training history: loss and accuracy curves"""
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    
    # Plot loss
    axes[0].plot(history.history['loss'], label='Training Loss', linewidth=2)
    axes[0].plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
    axes[0].set_title(f'{model_name} - Loss Over Epochs', fontsize=14, fontweight='bold')
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('Loss', fontsize=12)
    axes[0].legend(fontsize=10)
    axes[0].grid(True, alpha=0.3)
    
    # Plot accuracy
    axes[1].plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
    axes[1].plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
    axes[1].set_title(f'{model_name} - Accuracy Over Epochs', fontsize=14, fontweight='bold')
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('Accuracy', fontsize=12)
    axes[1].legend(fontsize=10)
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(f"{save_dir}/{model_name}_training_curves.png", dpi=300, bbox_inches='tight')
    print(f"\u2713 Training curves saved: {save_dir}/{model_name}_training_curves.png")
    plt.show()
    plt.close()

def plot_confusion_matrices(y_true, y_pred, model_name, save_dir='results'):
    """Plot confusion matrix and normalized confusion matrix"""
    # Convert to class labels
    y_true_labels = np.argmax(y_true, axis=-1).flatten()
    y_pred_labels = np.argmax(y_pred, axis=-1).flatten()
    
    # Compute confusion matrices
    cm = confusion_matrix(y_true_labels, y_pred_labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    class_names = ['Background', 'Disc', 'Cup']
    
    # Plot regular confusion matrix
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[0], cbar_kws={'label': 'Count'})
    axes[0].set_title(f'{model_name}\\nConfusion Matrix', fontsize=14, fontweight='bold')
    axes[0].set_ylabel('True Label', fontsize=12)
    axes[0].set_xlabel('Predicted Label', fontsize=12)
    
    # Plot normalized confusion matrix
    sns.heatmap(cm_normalized, annot=True, fmt='.3f', cmap='Greens',
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[1], cbar_kws={'label': 'Proportion'})
    axes[1].set_title(f'{model_name}\\nNormalized Confusion Matrix', fontsize=14, fontweight='bold')
    axes[1].set_ylabel('True Label', fontsize=12)
    axes[1].set_xlabel('Predicted Label', fontsize=12)
    
    plt.tight_layout()
    plt.savefig(f"{save_dir}/{model_name}_confusion_matrices.png", dpi=300, bbox_inches='tight')
    print(f"\u2713 Confusion matrices saved: {save_dir}/{model_name}_confusion_matrices.png")
    plt.show()
    plt.close()
    
    # Print metrics
    print(f"\nConfusion Matrix:")
    print(cm)
    print(f"\nNormalized Confusion Matrix:")
    print(np.round(cm_normalized, 3))
    
    return cm, cm_normalized

# ============================================================================
# TRAINING
# ============================================================================

def train_model(X_train, y_train, X_val, y_val, X_test, y_test, model_name, 
               use_focal_eiou=False, use_deeper=False, dropout_rate=0.0,
               augment=None, save_dir='results'):
    """Train model with encoder-only CBAM"""
    print(f"\n{'='*80}")
    print(f"TRAINING: {model_name}")
    print(f"{'='*80}")
    print(f"  Focal-EIoU Loss: {'✓' if use_focal_eiou else '✗'}")
    print(f"  Deeper Decoder: {'✓' if use_deeper else '✗'}")
    print(f"  MC Dropout: {'✓ (rate=' + str(dropout_rate) + ')' if dropout_rate > 0 else '✗'}")
    print(f"  CBAM Attention: ✓ ENCODER-ONLY (5 encoder outputs)")
    
    K.clear_session()
    
    model = build_combined_unet_encoder_only_cbam(use_deeper=use_deeper, dropout_rate=dropout_rate)
    
    param_count = model.count_params()
    print(f"  Total Parameters: {param_count:,}")
    
    if use_focal_eiou:
        loss_fn = focal_eiou_combined_loss
    else:
        loss_fn = "categorical_crossentropy"
    
    initial_lr = 5e-4 if use_deeper else 1e-3
    model.compile(
        optimizer=optimizers.Adam(learning_rate=initial_lr),
        loss=loss_fn,
        metrics=[dice_coef_multiclass, dice_class_0, dice_class_1, dice_class_2,
                "accuracy", iou_coef_multiclass, iou_class_0, iou_class_1, iou_class_2]
    )
    
    checkpoint = ModelCheckpoint(f"{save_dir}/{model_name}.keras", save_best_only=True, verbose=1, 
                                monitor='val_loss', mode='min')
    reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=5, 
                                  verbose=1, mode='min', min_lr=1e-7)
    early_stop = EarlyStopping(monitor="val_loss", patience=15, verbose=1, 
                              restore_best_weights=True, mode='min')
    
    batch_size = 4 if use_deeper else 6
    steps_train = X_train.shape[0] // batch_size
    steps_val = X_val.shape[0] // batch_size
    
    try:
        history = model.fit(
            data_generator(X_train, y_train, batch_size, augment),
            validation_data=data_generator(X_val, y_val, batch_size, None),
            steps_per_epoch=steps_train,
            validation_steps=steps_val,
            epochs=50,
            callbacks=[checkpoint, reduce_lr, early_stop],
            verbose=1
        )
    except Exception as e:
        print(f"✗ Error: {e}. Retrying with smaller batch...")
        batch_size = 2 if use_deeper else 4
        steps_train = X_train.shape[0] // batch_size
        steps_val = X_val.shape[0] // batch_size
        
        history = model.fit(
            data_generator(X_train, y_train, batch_size, augment),
            validation_data=data_generator(X_val, y_val, batch_size, None),
            steps_per_epoch=steps_train,
            validation_steps=steps_val,
            epochs=50,
            callbacks=[checkpoint, reduce_lr, early_stop],
            verbose=1
        )
    
    print(f"Training completed")
    
    # Plot training curves
    plot_training_history(history, model_name, save_dir)
    
    return model, history, param_count

# ============================================================================
# EVALUATION
# ============================================================================

def evaluate_model(model, X_test, y_test, model_name, run_mc_dropout=False, save_dir='results'):
    """Evaluate model"""
    print(f"\n{'='*80}")
    print(f"EVALUATION: {model_name}")
    print(f"{'='*80}")
    
    y_test_cat = np.array([to_categorical(mask, num_classes=3) for mask in y_test])
    
    test_metrics = model.evaluate(X_test, y_test_cat, verbose=0, batch_size=4)
    y_pred = model.predict(X_test, verbose=0, batch_size=4)
    
    # Plot confusion matrices
    plot_confusion_matrices(y_test_cat, y_pred, model_name, save_dir)
    
    # Calculate precision, recall, F1 score
    y_true_labels = np.argmax(y_test_cat, axis=-1).flatten()
    y_pred_labels = np.argmax(y_pred, axis=-1).flatten()
    
    precision = precision_score(y_true_labels, y_pred_labels, average=None, zero_division=0)
    recall = recall_score(y_true_labels, y_pred_labels, average=None, zero_division=0)
    f1 = f1_score(y_true_labels, y_pred_labels, average=None, zero_division=0)
    
    print(f"\nPrecision, Recall, F1 Score per class:")
    class_names = ["Background", "Disc", "Cup"]
    for idx, cname in enumerate(class_names):
        print(f"  {cname}: Precision={precision[idx]:.4f}, Recall={recall[idx]:.4f}, F1={f1[idx]:.4f}")
    
    print(f"\nMacro-averaged metrics:")
    print(f"  Precision: {np.mean(precision):.4f}")
    print(f"  Recall: {np.mean(recall):.4f}")
    print(f"  F1 Score: {np.mean(f1):.4f}")
    
    class_names = ["Background", "Disc", "Cup"]
    results = {'standard': {}}
    
    for cidx, cname in enumerate(class_names):
        y_true_c = (np.argmax(y_test_cat, axis=-1) == cidx).astype(np.float32)
        y_pred_c = (np.argmax(y_pred, axis=-1) == cidx).astype(np.float32)
        
        intersection = np.sum(y_true_c * y_pred_c)
        dice = (2. * intersection + 1e-7) / (np.sum(y_true_c) + np.sum(y_pred_c) + 1e-7)
        union = np.sum(y_true_c) + np.sum(y_pred_c) - intersection
        iou = (intersection + 1e-7) / (union + 1e-7)
        
        results['standard'][cname] = {'dice': dice, 'iou': iou}
        print(f"  {cname}: Dice={dice:.4f}, IoU={iou:.4f}")
    
    if run_mc_dropout:
        print("\nMC Dropout Evaluation:")
        mean_pred, std_pred = mc_dropout_predict(model, X_test[:100], num_samples=10, verbose=True)
        results['mc_dropout'] = {}
        for cidx, cname in enumerate(class_names):
            mean_std = np.mean(std_pred[:, :, :, cidx])
            results['mc_dropout'][cname] = {'mean_uncertainty': mean_std}
            print(f"  {cname} uncertainty: {mean_std:.4f}")
    
    return results

# ============================================================================
# MAIN
# ============================================================================

if __name__ == "__main__":
    gpu_available = configure_gpu()
    root_dir = "/kaggle/input/refuge/REFUGE/"
    train_aug = setup_augmentations()
    save_dir = "results"
    os.makedirs(save_dir, exist_ok=True)
    
    print(f"\n{'='*100}")
    print(f"{'EXPERIMENT: DEEPER + FOCAL-EIOU + MC DROPOUT + ENCODER-ONLY CBAM':^100s}")
    print(f"{'='*100}")
    
    all_images, all_masks = load_all_data(root_dir)
    (X_train, y_train), (X_val, y_val), (X_test, y_test) = create_new_split(all_images, all_masks)
    
    all_results = {}
    all_params = {}
    
    print(f"\n{'='*80}")
    print("EXPERIMENT: FULL COMBINATION + ENCODER-ONLY CBAM (5 blocks on encoder outputs)")
    print(f"{'='*80}")
    
    model, history, params = train_model(
        X_train, y_train, X_val, y_val, X_test, y_test,
        "FULL_with_ENCODER_ONLY_CBAM",
        use_focal_eiou=True, use_deeper=True, dropout_rate=0.3,
        augment=train_aug, save_dir=save_dir
    )
    
    all_results['FULL + ENCODER-ONLY CBAM'] = evaluate_model(model, X_test, y_test, "Full with Encoder-Only CBAM", run_mc_dropout=True, save_dir=save_dir)
    all_params['FULL + ENCODER-ONLY CBAM'] = params
    
    print(f"\n{'='*100}")
    print(f"{'✓ EXPERIMENT COMPLETED!':^100s}")
    print(f"{'='*100}")
    
    print("\nFinal Results:")
    for model_name, results in all_results.items():
        disc_dice = results['standard']['Disc']['dice']
        cup_dice = results['standard']['Cup']['dice']
        print(f"\n{model_name}:")
        print(f"  Parameters: {all_params[model_name]:,}")
        print(f"  Disc Dice: {disc_dice:.4f}")
        print(f"  Cup Dice: {cup_dice:.4f}")
        print(f"  Overall: {(disc_dice + cup_dice)/2:.4f}")
    
    print(f"\n{'='*100}\n")
# Out:
# 2025-11-17 12:30:09.544642: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763382609.752415      38 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763382609.807959      38 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Configuring GPU settings...
# ✓ GPU found: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
#   GPU device name: /device:GPU:0
#
# ====================================================================================================
#                   EXPERIMENT: DEEPER + FOCAL-EIOU + MC DROPOUT + ENCODER-ONLY CBAM
# ====================================================================================================
# Loading train data...
# I0000 00:00:1763382625.739240      38 gpu_device.cc:2022] Created device /device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
#   train: 400 samples
# Loading val data...
#   val: 400 samples
# Loading test data...
#   test: 400 samples
# Split - Train: 600, Val: 200, Test: 400
#
# ================================================================================
# EXPERIMENT: FULL COMBINATION + ENCODER-ONLY CBAM (5 blocks on encoder outputs)
# ================================================================================
#
# ================================================================================
# TRAINING: FULL_with_ENCODER_ONLY_CBAM
# ================================================================================
#   Focal-EIoU Loss: ✓
#   Deeper Decoder: ✓
#   MC Dropout: ✓ (rate=0.3)
#   CBAM Attention: ✓ ENCODER-ONLY (5 encoder outputs)
#
# Building Combined UNet with ENCODER-ONLY CBAM...
#   Deeper Architecture: True
#   MC Dropout Rate: 0.3
#   CBAM Attention: ENCODER-ONLY (5 blocks on encoder outputs)
# I0000 00:00:1763382688.844290      38 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
#   Applying CBAM to encoder outputs...
#     encoder_1 (128x128): WITH CBAM ✓ → flows to skip_1
#     encoder_2 (64x64): WITH CBAM ✓ → flows to skip_2
#     encoder_3 (32x32): WITH CBAM ✓ → flows to skip_3
#     encoder_4 (16x16): WITH CBAM ✓ → flows to skip_4
#     bridge (8x8): WITH CBAM ✓
#   Building deeper decoder WITHOUT CBAM (attention only on encoder outputs)...
#
#   MC Dropout Configuration:
#     Total Dropout Layers: 5
#     Dropout Rates: ['0.30', '0.30', '0.30', '0.21', '0.15']
#
#   CBAM Configuration (ENCODER-ONLY):
#     Total CBAM Components: 15
#     CBAM Locations: Encoder outputs ONLY (5 blocks)
#     Removed CBAM from: Decoder blocks, Final layer
#     Note: Each encoder output gets CBAM once, then flows to skip connection
#   Total Parameters: 37,643,712
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763382767.614385     102 service.cc:148] XLA service 0x7f192004b320 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1763382767.615316     102 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1763382774.449139     102 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1763382783.110483     102 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763382783.368955     102 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#   1/150 ━━━━━━━━━━━━━━━━━━━━ 5:12:53 126s/step - accuracy: 0.3819 - dice_class_0: 0.5510 - dice_class_1: 0.0262 - dice_class_2: 0.0109 - dice_coef_multiclass: 0.3584 - iou_class_0: 0.3803 - iou_class_1: 0.0133 - iou_class_2: 0.0055 - iou_coef_multiclass: 0.2183 - loss: 1.6260
# I0000 00:00:1763382818.679391     102 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8750 - dice_class_0: 0.9225 - dice_class_1: 0.3686 - dice_class_2: 0.3295 - dice_coef_multiclass: 0.6451 - iou_class_0: 0.8761 - iou_class_1: 0.2387 - iou_class_2: 0.2237 - iou_coef_multiclass: 0.4895 - loss: 1.1095
# E0000 00:00:1763382844.595862     101 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763382844.853862     101 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Epoch 1: val_loss improved from inf to 0.68498, saving model to results/FULL_with_ENCODER_ONLY_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 161s 236ms/step - accuracy: 0.8755 - dice_class_0: 0.9228 - dice_class_1: 0.3694 - dice_class_2: 0.3307 - dice_coef_multiclass: 0.6458 - iou_class_0: 0.8766 - iou_class_1: 0.2393 - iou_class_2: 0.2245 - iou_coef_multiclass: 0.4904 - loss: 1.1084 - val_accuracy: 0.9871 - val_dice_class_0: 0.9947 - val_dice_class_1: 0.5546 - val_dice_class_2: 0.2894 - val_dice_coef_multiclass: 0.9261 - val_iou_class_0: 0.9895 - val_iou_class_1: 0.3885 - val_iou_class_2: 0.1738 - val_iou_coef_multiclass: 0.8625 - val_loss: 0.6850 - learning_rate: 5.0000e-04
# Epoch 2/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9875 - dice_class_0: 0.9944 - dice_class_1: 0.6950 - dice_class_2: 0.6577 - dice_coef_multiclass: 0.9075 - iou_class_0: 0.9888 - iou_class_1: 0.5377 - iou_class_2: 0.4924 - iou_coef_multiclass: 0.8318 - loss: 0.6852
# Epoch 2: val_loss improved from 0.68498 to 0.60480, saving model to results/FULL_with_ENCODER_ONLY_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 151ms/step - accuracy: 0.9875 - dice_class_0: 0.9944 - dice_class_1: 0.6953 - dice_class_2: 0.6577 - dice_coef_multiclass: 0.9077 - iou_class_0: 0.9888 - iou_class_1: 0.5381 - iou_class_2: 0.4923 - iou_coef_multiclass: 0.8321 - loss: 0.6848 - val_accuracy: 0.9835 - val_dice_class_0: 0.9926 - val_dice_class_1: 0.5570 - val_dice_class_2: 0.3406 - val_dice_coef_multiclass: 0.9787 - val_iou_class_0: 0.9852 - val_iou_class_1: 0.3896 - val_iou_class_2: 0.2081 - val_iou_coef_multiclass: 0.9584 - val_loss: 0.6048 - learning_rate: 5.0000e-04
# Epoch 3/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9947 - dice_class_0: 0.9980 - dice_class_1: 0.8247 - dice_class_2: 0.8175 - dice_coef_multiclass: 0.9826 - iou_class_0: 0.9960 - iou_class_1: 0.7042 - iou_class_2: 0.6943 - iou_coef_multiclass: 0.9659 - loss: 0.4139
# Epoch 3: val_loss did not improve from 0.60480
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9947 - dice_class_0: 0.9980 - dice_class_1: 0.8248 - dice_class_2: 0.8176 - dice_coef_multiclass: 0.9827 - iou_class_0: 0.9960 - iou_class_1: 0.7043 - iou_class_2: 0.6944 - iou_coef_multiclass: 0.9660 - loss: 0.4135 - val_accuracy: 0.9743 - val_dice_class_0: 0.9870 - val_dice_class_1: 0.0114 - val_dice_class_2: 0.0046 - val_dice_coef_multiclass: 0.9741 - val_iou_class_0: 0.9743 - val_iou_class_1: 0.0059 - val_iou_class_2: 0.0023 - val_iou_coef_multiclass: 0.9494 - val_loss: 0.9531 - learning_rate: 5.0000e-04
# Epoch 4/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9969 - dice_class_0: 0.9990 - dice_class_1: 0.8762 - dice_class_2: 0.8623 - dice_coef_multiclass: 0.9956 - iou_class_0: 0.9980 - iou_class_1: 0.7811 - iou_class_2: 0.7600 - iou_coef_multiclass: 0.9912 - loss: 0.2160
# Epoch 4: val_loss did not improve from 0.60480
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9969 - dice_class_0: 0.9990 - dice_class_1: 0.8762 - dice_class_2: 0.8623 - dice_coef_multiclass: 0.9956 - iou_class_0: 0.9980 - iou_class_1: 0.7812 - iou_class_2: 0.7600 - iou_coef_multiclass: 0.9912 - loss: 0.2159 - val_accuracy: 0.9551 - val_dice_class_0: 0.9771 - val_dice_class_1: 0.0381 - val_dice_class_2: 0.0400 - val_dice_coef_multiclass: 0.9550 - val_iou_class_0: 0.9554 - val_iou_class_1: 0.0199 - val_iou_class_2: 0.0221 - val_iou_coef_multiclass: 0.9142 - val_loss: 1.0334 - learning_rate: 5.0000e-04
# Epoch 5/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9972 - dice_class_0: 0.9991 - dice_class_1: 0.8894 - dice_class_2: 0.8734 - dice_coef_multiclass: 0.9967 - iou_class_0: 0.9982 - iou_class_1: 0.8019 - iou_class_2: 0.7771 - iou_coef_multiclass: 0.9935 - loss: 0.1749
# Epoch 5: val_loss improved from 0.60480 to 0.37596, saving model to results/FULL_with_ENCODER_ONLY_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 149ms/step - accuracy: 0.9972 - dice_class_0: 0.9991 - dice_class_1: 0.8895 - dice_class_2: 0.8734 - dice_coef_multiclass: 0.9967 - iou_class_0: 0.9982 - iou_class_1: 0.8019 - iou_class_2: 0.7771 - iou_coef_multiclass: 0.9935 - loss: 0.1749 - val_accuracy: 0.9928 - val_dice_class_0: 0.9971 - val_dice_class_1: 0.6622 - val_dice_class_2: 0.7013 - val_dice_coef_multiclass: 0.9928 - val_iou_class_0: 0.9942 - val_iou_class_1: 0.5058 - val_iou_class_2: 0.5558 - val_iou_coef_multiclass: 0.9857 - val_loss: 0.3760 - learning_rate: 5.0000e-04
# Epoch 6/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9975 - dice_class_0: 0.9992 - dice_class_1: 0.8996 - dice_class_2: 0.8799 - dice_coef_multiclass: 0.9972 - iou_class_0: 0.9984 - iou_class_1: 0.8187 - iou_class_2: 0.7882 - iou_coef_multiclass: 0.9944 - loss: 0.1552
# Epoch 6: val_loss did not improve from 0.37596
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9975 - dice_class_0: 0.9992 - dice_class_1: 0.8996 - dice_class_2: 0.8799 - dice_coef_multiclass: 0.9972 - iou_class_0: 0.9984 - iou_class_1: 0.8186 - iou_class_2: 0.7882 - iou_coef_multiclass: 0.9944 - loss: 0.1552 - val_accuracy: 0.9909 - val_dice_class_0: 0.9959 - val_dice_class_1: 0.5673 - val_dice_class_2: 0.6194 - val_dice_coef_multiclass: 0.9908 - val_iou_class_0: 0.9918 - val_iou_class_1: 0.4134 - val_iou_class_2: 0.4692 - val_iou_coef_multiclass: 0.9819 - val_loss: 0.4708 - learning_rate: 5.0000e-04
# Epoch 7/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9063 - dice_class_2: 0.8866 - dice_coef_multiclass: 0.9975 - iou_class_0: 0.9985 - iou_class_1: 0.8293 - iou_class_2: 0.7982 - iou_coef_multiclass: 0.9950 - loss: 0.1428
# Epoch 7: val_loss improved from 0.37596 to 0.24034, saving model to results/FULL_with_ENCODER_ONLY_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 151ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9062 - dice_class_2: 0.8866 - dice_coef_multiclass: 0.9975 - iou_class_0: 0.9985 - iou_class_1: 0.8292 - iou_class_2: 0.7982 - iou_coef_multiclass: 0.9950 - loss: 0.1428 - val_accuracy: 0.9951 - val_dice_class_0: 0.9982 - val_dice_class_1: 0.8196 - val_dice_class_2: 0.7772 - val_dice_coef_multiclass: 0.9951 - val_iou_class_0: 0.9964 - val_iou_class_1: 0.7024 - val_iou_class_2: 0.6475 - val_iou_coef_multiclass: 0.9902 - val_loss: 0.2403 - learning_rate: 5.0000e-04
# Epoch 8/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9094 - dice_class_2: 0.8951 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9986 - iou_class_1: 0.8344 - iou_class_2: 0.8110 - iou_coef_multiclass: 0.9952 - loss: 0.1351
# Epoch 8: val_loss improved from 0.24034 to 0.21302, saving model to results/FULL_with_ENCODER_ONLY_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 151ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9094 - dice_class_2: 0.8950 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9986 - iou_class_1: 0.8344 - iou_class_2: 0.8110 - iou_coef_multiclass: 0.9952 - loss: 0.1351 - val_accuracy: 0.9962 - val_dice_class_0: 0.9986 - val_dice_class_1: 0.8416 - val_dice_class_2: 0.8315 - val_dice_coef_multiclass: 0.9961 - val_iou_class_0: 0.9971 - val_iou_class_1: 0.7328 - val_iou_class_2: 0.7223 - val_iou_coef_multiclass: 0.9922 - val_loss: 0.2130 - learning_rate: 5.0000e-04
# Epoch 9/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9104 - dice_class_2: 0.9016 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9986 - iou_class_1: 0.8362 - iou_class_2: 0.8218 - iou_coef_multiclass: 0.9954 - loss: 0.1295
# Epoch 9: val_loss improved from 0.21302 to 0.18908, saving model to results/FULL_with_ENCODER_ONLY_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 149ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9104 - dice_class_2: 0.9016 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9986 - iou_class_1: 0.8362 - iou_class_2: 0.8218 - iou_coef_multiclass: 0.9954 - loss: 0.1295 - val_accuracy: 0.9968 - val_dice_class_0: 0.9990 - val_dice_class_1: 0.8724 - val_dice_class_2: 0.8323 - val_dice_coef_multiclass: 0.9968 - val_iou_class_0: 0.9979 - val_iou_class_1: 0.7763 - val_iou_class_2: 0.7199 - val_iou_coef_multiclass: 0.9936 - val_loss: 0.1891 - learning_rate: 5.0000e-04
# Epoch 10/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9123 - dice_class_2: 0.8985 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9987 - iou_class_1: 0.8395 - iou_class_2: 0.8168 - iou_coef_multiclass: 0.9954 - loss: 0.1288
# Epoch 10: val_loss improved from 0.18908 to 0.18709, saving model to results/FULL_with_ENCODER_ONLY_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 151ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9123 - dice_class_2: 0.8985 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9987 - iou_class_1: 0.8395 - iou_class_2: 0.8168 - iou_coef_multiclass: 0.9954 - loss: 0.1288 - val_accuracy: 0.9968 - val_dice_class_0: 0.9989 - val_dice_class_1: 0.8713 - val_dice_class_2: 0.8415 - val_dice_coef_multiclass: 0.9967 - val_iou_class_0: 0.9979 - val_iou_class_1: 0.7743 - val_iou_class_2: 0.7331 - val_iou_coef_multiclass: 0.9934 - val_loss: 0.1871 - learning_rate: 5.0000e-04
# Epoch 11/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9160 - dice_class_2: 0.9094 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9987 - iou_class_1: 0.8455 - iou_class_2: 0.8347 - iou_coef_multiclass: 0.9957 - loss: 0.1205
# Epoch 11: val_loss improved from 0.18709 to 0.17483, saving model to results/FULL_with_ENCODER_ONLY_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 151ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9160 - dice_class_2: 0.9094 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9987 - iou_class_1: 0.8455 - iou_class_2: 0.8347 - iou_coef_multiclass: 0.9957 - loss: 0.1205 - val_accuracy: 0.9969 - val_dice_class_0: 0.9989 - val_dice_class_1: 0.8727 - val_dice_class_2: 0.8606 - val_dice_coef_multiclass: 0.9969 - val_iou_class_0: 0.9978 - val_iou_class_1: 0.7794 - val_iou_class_2: 0.7630 - val_iou_coef_multiclass: 0.9937 - val_loss: 0.1748 - learning_rate: 5.0000e-04
# Epoch 12/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9160 - dice_class_2: 0.9115 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9986 - iou_class_1: 0.8455 - iou_class_2: 0.8386 - iou_coef_multiclass: 0.9956 - loss: 0.1185
# Epoch 12: val_loss improved from 0.17483 to 0.15284, saving model to results/FULL_with_ENCODER_ONLY_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 158ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9160 - dice_class_2: 0.9115 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9986 - iou_class_1: 0.8455 - iou_class_2: 0.8386 - iou_coef_multiclass: 0.9956 - loss: 0.1185 - val_accuracy: 0.9972 - val_dice_class_0: 0.9991 - val_dice_class_1: 0.8896 - val_dice_class_2: 0.8776 - val_dice_coef_multiclass: 0.9971 - val_iou_class_0: 0.9981 - val_iou_class_1: 0.8023 - val_iou_class_2: 0.7837 - val_iou_coef_multiclass: 0.9943 - val_loss: 0.1528 - learning_rate: 5.0000e-04
# Epoch 13/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9980 - dice_class_0: 0.9993 - dice_class_1: 0.9192 - dice_class_2: 0.9149 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8509 - iou_class_2: 0.8439 - iou_coef_multiclass: 0.9959 - loss: 0.1147
# Epoch 13: val_loss did not improve from 0.15284
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9980 - dice_class_0: 0.9993 - dice_class_1: 0.9192 - dice_class_2: 0.9148 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8509 - iou_class_2: 0.8439 - iou_coef_multiclass: 0.9959 - loss: 0.1148 - val_accuracy: 0.9968 - val_dice_class_0: 0.9989 - val_dice_class_1: 0.8695 - val_dice_class_2: 0.8527 - val_dice_coef_multiclass: 0.9967 - val_iou_class_0: 0.9978 - val_iou_class_1: 0.7724 - val_iou_class_2: 0.7536 - val_iou_coef_multiclass: 0.9935 - val_loss: 0.1808 - learning_rate: 5.0000e-04
# Epoch 14/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9980 - dice_class_0: 0.9993 - dice_class_1: 0.9164 - dice_class_2: 0.9143 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8464 - iou_class_2: 0.8429 - iou_coef_multiclass: 0.9958 - loss: 0.1156
# Epoch 14: val_loss did not improve from 0.15284
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9980 - dice_class_0: 0.9993 - dice_class_1: 0.9164 - dice_class_2: 0.9142 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8464 - iou_class_2: 0.8429 - iou_coef_multiclass: 0.9958 - loss: 0.1156 - val_accuracy: 0.9367 - val_dice_class_0: 0.9670 - val_dice_class_1: 0.3026 - val_dice_class_2: 0.8696 - val_dice_coef_multiclass: 0.9369 - val_iou_class_0: 0.9368 - val_iou_class_1: 0.1867 - val_iou_class_2: 0.7725 - val_iou_coef_multiclass: 0.8829 - val_loss: 0.4186 - learning_rate: 5.0000e-04
# Epoch 15/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9241 - dice_class_2: 0.9194 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8594 - iou_class_2: 0.8517 - iou_coef_multiclass: 0.9961 - loss: 0.1080
# Epoch 15: val_loss did not improve from 0.15284
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9241 - dice_class_2: 0.9194 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8594 - iou_class_2: 0.8516 - iou_coef_multiclass: 0.9961 - loss: 0.1080 - val_accuracy: 0.9975 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8936 - val_dice_class_2: 0.8835 - val_dice_coef_multiclass: 0.9946 - val_iou_class_0: 0.9984 - val_iou_class_1: 0.8091 - val_iou_class_2: 0.7932 - val_iou_coef_multiclass: 0.9892 - val_loss: 0.1865 - learning_rate: 5.0000e-04
# Epoch 16/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9227 - dice_class_2: 0.9178 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8572 - iou_class_2: 0.8493 - iou_coef_multiclass: 0.9961 - loss: 0.1089
# Epoch 16: val_loss did not improve from 0.15284
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9227 - dice_class_2: 0.9178 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8572 - iou_class_2: 0.8493 - iou_coef_multiclass: 0.9961 - loss: 0.1089 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9018 - val_dice_class_2: 0.8822 - val_dice_coef_multiclass: 0.9969 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8223 - val_iou_class_2: 0.7915 - val_iou_coef_multiclass: 0.9939 - val_loss: 0.1558 - learning_rate: 5.0000e-04
# Epoch 17/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9244 - dice_class_2: 0.9247 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8598 - iou_class_2: 0.8603 - iou_coef_multiclass: 0.9962 - loss: 0.1041
# Epoch 17: val_loss did not improve from 0.15284
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9244 - dice_class_2: 0.9247 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8599 - iou_class_2: 0.8603 - iou_coef_multiclass: 0.9962 - loss: 0.1041 - val_accuracy: 0.9973 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8876 - val_dice_class_2: 0.8447 - val_dice_coef_multiclass: 0.9972 - val_iou_class_0: 0.9984 - val_iou_class_1: 0.7993 - val_iou_class_2: 0.7343 - val_iou_coef_multiclass: 0.9945 - val_loss: 0.1675 - learning_rate: 5.0000e-04
# Epoch 18/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9322 - dice_class_2: 0.9308 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8731 - iou_class_2: 0.8712 - iou_coef_multiclass: 0.9965 - loss: 0.0956
# Epoch 18: val_loss improved from 0.15284 to 0.13625, saving model to results/FULL_with_ENCODER_ONLY_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 152ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9322 - dice_class_2: 0.9308 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8732 - iou_class_2: 0.8712 - iou_coef_multiclass: 0.9965 - loss: 0.0956 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9071 - val_dice_class_2: 0.8883 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8309 - val_iou_class_2: 0.8007 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1363 - learning_rate: 1.5000e-04
# Epoch 19/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9367 - dice_class_2: 0.9397 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8812 - iou_class_2: 0.8867 - iou_coef_multiclass: 0.9968 - loss: 0.0872
# Epoch 19: val_loss did not improve from 0.13625
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 130ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9367 - dice_class_2: 0.9397 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8812 - iou_class_2: 0.8867 - iou_coef_multiclass: 0.9968 - loss: 0.0872 - val_accuracy: 0.9975 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8985 - val_dice_class_2: 0.8678 - val_dice_coef_multiclass: 0.9975 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.8175 - val_iou_class_2: 0.7694 - val_iou_coef_multiclass: 0.9950 - val_loss: 0.1507 - learning_rate: 1.5000e-04
# Epoch 20/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9393 - dice_class_2: 0.9386 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8859 - iou_class_2: 0.8848 - iou_coef_multiclass: 0.9969 - loss: 0.0861
# Epoch 20: val_loss did not improve from 0.13625
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9393 - dice_class_2: 0.9386 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8858 - iou_class_2: 0.8848 - iou_coef_multiclass: 0.9969 - loss: 0.0861 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9031 - val_dice_class_2: 0.8836 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8247 - val_iou_class_2: 0.7937 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1415 - learning_rate: 1.5000e-04
# Epoch 21/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9353 - dice_class_2: 0.9372 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8788 - iou_class_2: 0.8823 - iou_coef_multiclass: 0.9967 - loss: 0.0891
# Epoch 21: val_loss did not improve from 0.13625
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 130ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9354 - dice_class_2: 0.9372 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8789 - iou_class_2: 0.8823 - iou_coef_multiclass: 0.9967 - loss: 0.0890 - val_accuracy: 0.9974 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8948 - val_dice_class_2: 0.8749 - val_dice_coef_multiclass: 0.9974 - val_iou_class_0: 0.9984 - val_iou_class_1: 0.8118 - val_iou_class_2: 0.7813 - val_iou_coef_multiclass: 0.9948 - val_loss: 0.1512 - learning_rate: 1.5000e-04
# Epoch 22/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9393 - dice_class_2: 0.9431 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8859 - iou_class_2: 0.8929 - iou_coef_multiclass: 0.9968 - loss: 0.0829
# Epoch 22: val_loss did not improve from 0.13625
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 130ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9393 - dice_class_2: 0.9431 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8859 - iou_class_2: 0.8929 - iou_coef_multiclass: 0.9968 - loss: 0.0829 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9005 - val_dice_class_2: 0.8819 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8208 - val_iou_class_2: 0.7913 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1421 - learning_rate: 1.5000e-04
# Epoch 23/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9401 - dice_class_2: 0.9428 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8872 - iou_class_2: 0.8922 - iou_coef_multiclass: 0.9970 - loss: 0.0827
# Epoch 23: val_loss did not improve from 0.13625
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 4.500000213738531e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 130ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9401 - dice_class_2: 0.9428 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8872 - iou_class_2: 0.8922 - iou_coef_multiclass: 0.9970 - loss: 0.0828 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9014 - val_dice_class_2: 0.8834 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8218 - val_iou_class_2: 0.7943 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1429 - learning_rate: 1.5000e-04
# Epoch 24/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9442 - dice_class_2: 0.9477 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9990 - iou_class_1: 0.8945 - iou_class_2: 0.9011 - iou_coef_multiclass: 0.9972 - loss: 0.0767
# Epoch 24: val_loss did not improve from 0.13625
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9442 - dice_class_2: 0.9477 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9990 - iou_class_1: 0.8945 - iou_class_2: 0.9011 - iou_coef_multiclass: 0.9972 - loss: 0.0767 - val_accuracy: 0.9975 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8973 - val_dice_class_2: 0.8769 - val_dice_coef_multiclass: 0.9975 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.8152 - val_iou_class_2: 0.7836 - val_iou_coef_multiclass: 0.9950 - val_loss: 0.1486 - learning_rate: 4.5000e-05
# Epoch 25/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9436 - dice_class_2: 0.9507 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9990 - iou_class_1: 0.8936 - iou_class_2: 0.9064 - iou_coef_multiclass: 0.9971 - loss: 0.0755
# Epoch 25: val_loss did not improve from 0.13625
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 130ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9436 - dice_class_2: 0.9507 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9990 - iou_class_1: 0.8936 - iou_class_2: 0.9064 - iou_coef_multiclass: 0.9971 - loss: 0.0755 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9058 - val_dice_class_2: 0.8885 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8290 - val_iou_class_2: 0.8009 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1376 - learning_rate: 4.5000e-05
# Epoch 26/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9456 - dice_class_2: 0.9515 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9990 - iou_class_1: 0.8970 - iou_class_2: 0.9078 - iou_coef_multiclass: 0.9973 - loss: 0.0731
# Epoch 26: val_loss did not improve from 0.13625
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 130ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9456 - dice_class_2: 0.9515 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9990 - iou_class_1: 0.8970 - iou_class_2: 0.9078 - iou_coef_multiclass: 0.9973 - loss: 0.0731 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8987 - val_dice_class_2: 0.8818 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8179 - val_iou_class_2: 0.7908 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1441 - learning_rate: 4.5000e-05
# Epoch 27/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9472 - dice_class_2: 0.9513 - dice_coef_multiclass: 0.9987 - iou_class_0: 0.9991 - iou_class_1: 0.8999 - iou_class_2: 0.9075 - iou_coef_multiclass: 0.9973 - loss: 0.0728
# Epoch 27: val_loss did not improve from 0.13625
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 130ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9472 - dice_class_2: 0.9513 - dice_coef_multiclass: 0.9987 - iou_class_0: 0.9991 - iou_class_1: 0.8998 - iou_class_2: 0.9075 - iou_coef_multiclass: 0.9973 - loss: 0.0728 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9026 - val_dice_class_2: 0.8796 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8237 - val_iou_class_2: 0.7868 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1436 - learning_rate: 4.5000e-05
# Epoch 28/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9459 - dice_class_2: 0.9503 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9991 - iou_class_1: 0.8976 - iou_class_2: 0.9056 - iou_coef_multiclass: 0.9972 - loss: 0.0736
# Epoch 28: val_loss did not improve from 0.13625
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.3500000204658135e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9459 - dice_class_2: 0.9503 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9991 - iou_class_1: 0.8976 - iou_class_2: 0.9056 - iou_coef_multiclass: 0.9972 - loss: 0.0736 - val_accuracy: 0.9975 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8971 - val_dice_class_2: 0.8840 - val_dice_coef_multiclass: 0.9975 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.8154 - val_iou_class_2: 0.7945 - val_iou_coef_multiclass: 0.9950 - val_loss: 0.1434 - learning_rate: 4.5000e-05
# Epoch 29/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9463 - dice_class_2: 0.9514 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9991 - iou_class_1: 0.8984 - iou_class_2: 0.9077 - iou_coef_multiclass: 0.9973 - loss: 0.0723
# Epoch 29: val_loss did not improve from 0.13625
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 130ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9463 - dice_class_2: 0.9514 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9991 - iou_class_1: 0.8983 - iou_class_2: 0.9077 - iou_coef_multiclass: 0.9973 - loss: 0.0723 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9060 - val_dice_class_2: 0.8913 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8297 - val_iou_class_2: 0.8050 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1364 - learning_rate: 1.3500e-05
# Epoch 30/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9453 - dice_class_2: 0.9502 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9991 - iou_class_1: 0.8965 - iou_class_2: 0.9055 - iou_coef_multiclass: 0.9972 - loss: 0.0750
# Epoch 30: val_loss did not improve from 0.13625
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 130ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9453 - dice_class_2: 0.9502 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9991 - iou_class_1: 0.8965 - iou_class_2: 0.9055 - iou_coef_multiclass: 0.9972 - loss: 0.0750 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9037 - val_dice_class_2: 0.8849 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8260 - val_iou_class_2: 0.7953 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1407 - learning_rate: 1.3500e-05
# Epoch 31/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9475 - dice_class_2: 0.9522 - dice_coef_multiclass: 0.9987 - iou_class_0: 0.9991 - iou_class_1: 0.9004 - iou_class_2: 0.9091 - iou_coef_multiclass: 0.9973 - loss: 0.0714
# Epoch 31: val_loss did not improve from 0.13625
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9475 - dice_class_2: 0.9522 - dice_coef_multiclass: 0.9987 - iou_class_0: 0.9991 - iou_class_1: 0.9004 - iou_class_2: 0.9091 - iou_coef_multiclass: 0.9973 - loss: 0.0714 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9015 - val_dice_class_2: 0.8837 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8225 - val_iou_class_2: 0.7939 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1434 - learning_rate: 1.3500e-05
# Epoch 32/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9987 - dice_class_0: 0.9996 - dice_class_1: 0.9474 - dice_class_2: 0.9506 - dice_coef_multiclass: 0.9987 - iou_class_0: 0.9991 - iou_class_1: 0.9003 - iou_class_2: 0.9062 - iou_coef_multiclass: 0.9973 - loss: 0.0719
# Epoch 32: val_loss did not improve from 0.13625
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9987 - dice_class_0: 0.9996 - dice_class_1: 0.9474 - dice_class_2: 0.9506 - dice_coef_multiclass: 0.9987 - iou_class_0: 0.9991 - iou_class_1: 0.9003 - iou_class_2: 0.9062 - iou_coef_multiclass: 0.9973 - loss: 0.0719 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9011 - val_dice_class_2: 0.8870 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8214 - val_iou_class_2: 0.7984 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1408 - learning_rate: 1.3500e-05
# Epoch 33/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9474 - dice_class_2: 0.9543 - dice_coef_multiclass: 0.9987 - iou_class_0: 0.9991 - iou_class_1: 0.9005 - iou_class_2: 0.9128 - iou_coef_multiclass: 0.9973 - loss: 0.0706
# Epoch 33: val_loss did not improve from 0.13625
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 4.050000006827758e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9474 - dice_class_2: 0.9542 - dice_coef_multiclass: 0.9987 - iou_class_0: 0.9991 - iou_class_1: 0.9005 - iou_class_2: 0.9128 - iou_coef_multiclass: 0.9973 - loss: 0.0706 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9034 - val_dice_class_2: 0.8828 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8250 - val_iou_class_2: 0.7924 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1420 - learning_rate: 1.3500e-05
# Epoch 33: early stopping
# Restoring model weights from the end of the best epoch: 18.
# Training completed
# ✓ Training curves saved: results/FULL_with_ENCODER_ONLY_CBAM_training_curves.png
# ================================================================================
# EVALUATION: Full with Encoder-Only CBAM
# ================================================================================
# ✓ Confusion matrices saved: results/Full with Encoder-Only CBAM_confusion_matrices.png
# Confusion Matrix:
# [[25770761    14229        0]
#  [   17847   286754    10470]
#  [      54    13532   100753]]
#
# Normalized Confusion Matrix:
# [[0.999 0.001 0.   ]
#  [0.057 0.91  0.033]
#  [0.    0.118 0.881]]
#
# Precision, Recall, F1 Score per class:
#   Background: Precision=0.9993, Recall=0.9994, F1=0.9994
#   Disc: Precision=0.9117, Recall=0.9101, F1=0.9109
#   Cup: Precision=0.9059, Recall=0.8812, F1=0.8934
#
# Macro-averaged metrics:
#   Precision: 0.9390
#   Recall: 0.9303
#   F1 Score: 0.9346
#   Background: Dice=0.9994, IoU=0.9988
#   Disc: Dice=0.9109, IoU=0.8364
#   Cup: Dice=0.8934, IoU=0.8073
#
# MC Dropout Evaluation:
#
# Running MC Dropout with 10 stochastic forward passes...
#   Completed: 5/10 forward passes
#   Completed: 10/10 forward passes
# ✓ MC Dropout completed
#   Background uncertainty: 0.0002
#   Disc uncertainty: 0.0004
#   Cup uncertainty: 0.0002
#
# ====================================================================================================
#                                       ✓ EXPERIMENT COMPLETED!
# ====================================================================================================
#
# Final Results:
#
# FULL + ENCODER-ONLY CBAM:
#   Parameters: 37,643,712
#   Disc Dice: 0.9109
#   Cup Dice: 0.8934
#   Overall: 0.9021
#
# ====================================================================================================
