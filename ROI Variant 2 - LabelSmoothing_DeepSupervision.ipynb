# %%
"""
V2+DS: LABEL SMOOTHING + DEEP SUPERVISION + HIGH-RES ROI
====================================================================
Enhanced with three complementary modules from ODFormer/PSPNet for comprehensive feature enhancement
Plus glaucoma progression analysis with CDR-based severity classification

Triple Enhancement Strategy:
- MSCA (Multi-scale Context Aggregator): Multi-scale dilated convolutions [1,2,3,5]
- LBFR (Lightweight Bidirectional Feature Recalibrator): Channel + Spatial attention
- PPM (Pyramid Pooling Module): Multi-scale global context aggregation [1×1, 2×2, 3×3, 6×6]
- Sequential application: MSCA → LBFR → PPM on each decoder block
- Combines local multi-scale context + attention + global context

ROI Extraction:
- Automatically crops around the optic disc region from ground truth masks
- Resizes the ROI to 512×512 so the model sees a zoomed-in view of the disc/cup
- Dramatically reduces irrelevant background, improving segmentation accuracy
- For evaluation, predictions are mapped back to full image coordinates for CDR analysis

Glaucoma Scoring:
- CDR-based severity classification: Normal, Suspect, Moderate, Critical
- Area-based CDR calculation (robust & clinically relevant)
- Progression analysis with accuracy metrics
- Manual review recommendations for high-risk cases

Configuration:
- Base: Deeper Decoder + Focal-EIoU + MC Dropout
- Enhancement: MSCA + LBFR + PPM on decoder outputs
- Placement: All three modules after each decoder block (4 total)
- Total Attention Blocks: 12 (4 MSCA + 4 LBFR + 4 PPM)
"""

import os
import gc
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import albumentations as A
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, backend as K
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
from PIL import Image
import cv2

warnings.filterwarnings('ignore')

# Set plot style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# ============================================================================
# GPU CONFIGURATION
# ============================================================================

def configure_gpu():
    """Configure GPU settings for optimal performance"""
    print("Configuring GPU settings...")
    physical_devices = tf.config.list_physical_devices('GPU')
    if physical_devices:
        try:
            for device in physical_devices:
                tf.config.experimental.set_memory_growth(device, True)
            print(f"✓ GPU configured: {len(physical_devices)} device(s) available")
            return True
        except RuntimeError as e:
            print(f"GPU configuration error: {e}")
            return False
    else:
        print("⚠ No GPU detected, running on CPU")
        return False

# ============================================================================
# DATA LOADING
# ============================================================================

def load_images_masks(images_folder, masks_folder, img_size=(512,512)):
    """Load images and masks from folders"""
    images, masks = [], []
    image_files = sorted(os.listdir(images_folder))
    mask_files = sorted(os.listdir(masks_folder))
    mask_dict = {os.path.splitext(f)[0]: f for f in mask_files}
    
    for img_file in image_files:
        img_path = os.path.join(images_folder, img_file)
        img = np.array(Image.open(img_path).resize(img_size)) / 255.0
        images.append(img)
        
        img_name = os.path.splitext(img_file)[0]
        if img_name in mask_dict:
            mask_path = os.path.join(masks_folder, mask_dict[img_name])
            mask = np.array(Image.open(mask_path).resize(img_size, Image.NEAREST))
            masks.append(mask)
        else:
            print(f"Warning: No mask found for {img_file}")
    
    return np.array(images, dtype=np.float32), np.array(masks, dtype=np.uint8)

def load_all_data(root_dir):
    """Load all data from existing splits and merge"""
    all_images, all_masks = [], []
    for split in ["train", "val", "test"]:
        print(f"Loading {split} data...")
        imgs, msks = load_images_masks(
            os.path.join(root_dir, split, "Images"),
            os.path.join(root_dir, split, "Masks")
        )
        all_images.append(imgs)
        all_masks.append(msks)
        print(f"  {split}: {imgs.shape[0]} samples")
    
    all_images = np.concatenate(all_images, axis=0)
    all_masks = np.concatenate(all_masks, axis=0)
    return all_images, all_masks

def create_new_split(all_images, all_masks):
    """Create new split: 600 train, 200 val, 400 test"""
    X_temp, X_test, y_temp, y_test = train_test_split(
        all_images, all_masks, test_size=400, random_state=42
    )
    X_train, X_val, y_train, y_val = train_test_split(
        X_temp, y_temp, test_size=200, random_state=42
    )
    print(f"Split - Train: {X_train.shape[0]}, Val: {X_val.shape[0]}, Test: {X_test.shape[0]}")
    return (X_train, y_train), (X_val, y_val), (X_test, y_test)


def load_all_data_with_highres_roi(root_dir, roi_size=(512, 512), padding_factor=1.2):
    """
    Load images at ORIGINAL resolution, extract ROI, resize to roi_size.
    
    KEY FIX: The original code loaded images at 512x512 first, then cropped ROI
    from the already-downsampled image. A ~200x200 crop from 512x512, upscaled
    back to 512x512 = BLURRY, detail-lost input.
    
    V5 FIX: Load at original resolution (~2000x2000), crop ROI (~600x600 real
    pixels), resize to 512x512. The model gets SHARP, high-resolution detail.
    Memory efficient: only one full-res image in memory at a time.
    """
    all_roi_images, all_roi_masks, all_full_masks_512 = [], [], []
    
    for split in ["train", "val", "test"]:
        images_folder = os.path.join(root_dir, split, "Images")
        masks_folder = os.path.join(root_dir, split, "Masks")
        image_files = sorted(os.listdir(images_folder))
        mask_files = sorted(os.listdir(masks_folder))
        mask_dict = {os.path.splitext(f)[0]: f for f in mask_files}
        
        count = 0
        for img_file in image_files:
            img_name = os.path.splitext(img_file)[0]
            if img_name not in mask_dict:
                continue
            
            # Load at ORIGINAL resolution - this is the key fix
            img_highres = np.array(Image.open(
                os.path.join(images_folder, img_file))) / 255.0
            mask_highres = np.array(Image.open(
                os.path.join(masks_folder, mask_dict[img_name])))
            
            # Extract ROI from HIGH-RES image
            roi_img, roi_msk, _ = extract_roi(
                img_highres, mask_highres, padding_factor, roi_size)
            
            all_roi_images.append(roi_img)
            all_roi_masks.append(roi_msk)
            
            # Save 512x512 full mask for CDR evaluation
            full_msk_512 = np.array(Image.fromarray(
                mask_highres).resize((512, 512), Image.NEAREST))
            all_full_masks_512.append(full_msk_512)
            
            # Free high-res data immediately
            del img_highres, mask_highres
            count += 1
        
        print(f"  {split}: {count} samples (original resolution -> ROI extracted)")
    
    return (np.array(all_roi_images, dtype=np.float32),
            np.array(all_roi_masks, dtype=np.uint8),
            np.array(all_full_masks_512, dtype=np.uint8))

# ============================================================================
# ROI EXTRACTION
# ============================================================================

def find_disc_region(mask, disc_class=1, cup_class=2):
    """
    Find the bounding box of the optic disc+cup region from a segmentation mask.
    
    Args:
        mask: Segmentation mask (H, W) with class labels
        disc_class: Class label for optic disc (default=1)
        cup_class: Class label for optic cup (default=2)
    
    Returns:
        (center_y, center_x, radius) or None if no disc found
    """
    # Use both disc and cup pixels to define the ROI region
    roi_mask = ((mask == disc_class) | (mask == cup_class)).astype(np.uint8)
    
    if roi_mask.sum() == 0:
        return None
    
    coords = np.where(roi_mask > 0)
    y_min, y_max = coords[0].min(), coords[0].max()
    x_min, x_max = coords[1].min(), coords[1].max()
    
    center_y = (y_min + y_max) // 2
    center_x = (x_min + x_max) // 2
    
    height = y_max - y_min
    width = x_max - x_min
    radius = max(height, width) // 2
    
    return center_y, center_x, radius


def extract_roi(image, mask, padding_factor=1.2, roi_size=(512, 512)):
    """
    Extract ROI around the optic disc from image and mask.
    
    Crops a square region centered on the disc with padding, then resizes to roi_size.
    This lets the model see a zoomed-in view of the disc/cup instead of the full fundus.
    
    Args:
        image: Input image (H, W, 3), float32 [0, 1]
        mask: Segmentation mask (H, W), uint8
        padding_factor: How much to expand the ROI beyond the disc boundary (1.5 = 50% extra)
        roi_size: Output size for the ROI crop (default 512×512)
    
    Returns:
        roi_image: Cropped and resized image (roi_size[0], roi_size[1], 3)
        roi_mask: Cropped and resized mask (roi_size[0], roi_size[1])
        roi_coords: (y1, x1, y2, x2) crop coordinates in original image space
    """
    result = find_disc_region(mask)
    
    if result is None:
        # No disc found — return the full image (fallback)
        h, w = image.shape[:2]
        return image.copy(), mask.copy(), (0, 0, h, w)
    
    center_y, center_x, radius = result
    h, w = image.shape[:2]
    
    # Expand ROI with padding factor; enforce a minimum size
    roi_half = int(radius * padding_factor)
    roi_half = max(roi_half, 60)  # minimum half-size to avoid too-small crops
    
    # Calculate crop bounds (keep square, clamp to image boundaries)
    y1 = max(0, center_y - roi_half)
    y2 = min(h, center_y + roi_half)
    x1 = max(0, center_x - roi_half)
    x2 = min(w, center_x + roi_half)
    
    # Make the crop square by expanding the shorter side if possible
    crop_h = y2 - y1
    crop_w = x2 - x1
    if crop_h > crop_w:
        diff = crop_h - crop_w
        x1 = max(0, x1 - diff // 2)
        x2 = min(w, x1 + crop_h)
        x1 = max(0, x2 - crop_h)  # re-adjust if x2 hit boundary
    elif crop_w > crop_h:
        diff = crop_w - crop_h
        y1 = max(0, y1 - diff // 2)
        y2 = min(h, y1 + crop_w)
        y1 = max(0, y2 - crop_w)  # re-adjust if y2 hit boundary
    
    # Crop
    roi_image = image[y1:y2, x1:x2]
    roi_mask = mask[y1:y2, x1:x2]
    
    # Resize to model input size
    roi_image_pil = Image.fromarray((roi_image * 255).astype(np.uint8))
    roi_image_resized = np.array(roi_image_pil.resize(roi_size, Image.BILINEAR)) / 255.0
    
    roi_mask_pil = Image.fromarray(roi_mask)
    roi_mask_resized = np.array(roi_mask_pil.resize(roi_size, Image.NEAREST))
    
    return roi_image_resized.astype(np.float32), roi_mask_resized.astype(np.uint8), (y1, x1, y2, x2)


def extract_roi_batch(images, masks, padding_factor=1.2, roi_size=(512, 512)):
    """
    Extract ROI for an entire batch of images and masks.
    
    Args:
        images: (N, H, W, 3) float32
        masks: (N, H, W) uint8
        padding_factor: ROI padding factor
        roi_size: Output ROI size
    
    Returns:
        roi_images: (N, roi_size[0], roi_size[1], 3) float32
        roi_masks: (N, roi_size[0], roi_size[1]) uint8
        roi_coords_list: List of (y1, x1, y2, x2) tuples
    """
    roi_images, roi_masks, roi_coords_list = [], [], []
    
    for i in range(len(images)):
        roi_img, roi_msk, coords = extract_roi(
            images[i], masks[i], padding_factor=padding_factor, roi_size=roi_size
        )
        roi_images.append(roi_img)
        roi_masks.append(roi_msk)
        roi_coords_list.append(coords)
    
    return (np.array(roi_images, dtype=np.float32),
            np.array(roi_masks, dtype=np.uint8),
            roi_coords_list)


def map_roi_prediction_to_full(pred_mask_roi, roi_coords, full_size=(512, 512)):
    """
    Map a prediction made on an ROI crop back to the full image coordinates.
    
    Args:
        pred_mask_roi: Predicted mask on the ROI (roi_H, roi_W) with class labels
        roi_coords: (y1, x1, y2, x2) crop coordinates from extract_roi
        full_size: Size of the original full image (H, W)
    
    Returns:
        full_mask: (full_H, full_W) prediction mapped to full image (background=0 outside ROI)
    """
    y1, x1, y2, x2 = roi_coords
    crop_h = y2 - y1
    crop_w = x2 - x1
    
    # Resize prediction back to the original crop dimensions
    pred_arr = np.asarray(pred_mask_roi)
    pred_arr = np.squeeze(pred_arr)
    if pred_arr.ndim == 3:
        pred_arr = np.argmax(pred_arr, axis=-1)
    pred_pil = Image.fromarray(pred_arr.astype(np.uint8))
    pred_resized = np.array(pred_pil.resize((crop_w, crop_h), Image.NEAREST))
    
    # Place into full-size mask
    full_mask = np.zeros(full_size, dtype=np.uint8)
    full_mask[y1:y2, x1:x2] = pred_resized
    
    return full_mask


def visualize_roi_extraction(images, masks, num_samples=4):
    """Visualize ROI extraction to verify correctness"""
    fig, axes = plt.subplots(num_samples, 4, figsize=(16, 4 * num_samples))
    
    for i in range(min(num_samples, len(images))):
        roi_img, roi_msk, coords = extract_roi(images[i], masks[i])
        y1, x1, y2, x2 = coords
        
        # Original image
        axes[i, 0].imshow(images[i])
        axes[i, 0].set_title('Original Image', fontsize=11, fontweight='bold')
        # Draw ROI rectangle
        rect = plt.Rectangle((x1, y1), x2 - x1, y2 - y1,
                              linewidth=2, edgecolor='lime', facecolor='none')
        axes[i, 0].add_patch(rect)
        axes[i, 0].axis('off')
        
        # Original mask
        axes[i, 1].imshow(masks[i], cmap='jet', vmin=0, vmax=2)
        axes[i, 1].set_title('Original Mask', fontsize=11, fontweight='bold')
        rect2 = plt.Rectangle((x1, y1), x2 - x1, y2 - y1,
                               linewidth=2, edgecolor='lime', facecolor='none')
        axes[i, 1].add_patch(rect2)
        axes[i, 1].axis('off')
        
        # ROI image
        axes[i, 2].imshow(roi_img)
        axes[i, 2].set_title(f'ROI Image ({roi_img.shape[0]}×{roi_img.shape[1]})',
                             fontsize=11, fontweight='bold')
        axes[i, 2].axis('off')
        
        # ROI mask
        axes[i, 3].imshow(roi_msk, cmap='jet', vmin=0, vmax=2)
        axes[i, 3].set_title(f'ROI Mask ({roi_msk.shape[0]}×{roi_msk.shape[1]})',
                             fontsize=11, fontweight='bold')
        axes[i, 3].axis('off')
    
    plt.suptitle('ROI Extraction Verification — green box shows crop region',
                 fontsize=14, fontweight='bold', y=1.01)
    plt.tight_layout()
    plt.show()
    plt.close()

# ============================================================================
# DATA AUGMENTATION
# ============================================================================

def setup_augmentations():
    return A.Compose([
        # --- Geometric (most impactful for segmentation) ---
        A.HorizontalFlip(p=0.5),
        A.VerticalFlip(p=0.3),
        A.ShiftScaleRotate(shift_limit=0.05, scale_limit=0.10, rotate_limit=20,
                           border_mode=0, p=0.6),
        A.ElasticTransform(alpha=30, sigma=5, p=0.2),
        # --- Colour (keep existing, slightly widened) ---
        A.RandomBrightnessContrast(brightness_limit=0.20, contrast_limit=0.20, p=0.7),
        A.HueSaturationValue(hue_shift_limit=10, sat_shift_limit=20, val_shift_limit=10, p=0.5),
        A.GaussianBlur(blur_limit=3, p=0.3),
        A.RandomGamma(gamma_limit=(80, 120), p=0.3),
    ])

def smooth_labels(y_cat, smoothing=0.05):
    """Apply label smoothing to one-hot labels."""
    num_classes = y_cat.shape[-1]
    return y_cat * (1.0 - smoothing) + smoothing / num_classes

def data_generator(images, masks, batch_size, augment=None, num_outputs=5, label_smoothing=0.05):
    idxs = np.arange(len(images))
    while True:
        np.random.shuffle(idxs)
        for i in range(0, len(images), batch_size):
            batch_idxs = idxs[i:i+batch_size]
            batch_x, batch_y = [], []
            
            for idx in batch_idxs:
                img, mask = images[idx], masks[idx]
                
                if augment:
                    aug = augment(image=img, mask=mask)
                    img_aug, mask_aug = aug['image'], aug['mask']
                else:
                    img_aug, mask_aug = img, mask
                
                mask_cat = to_categorical(mask_aug, num_classes=3)
                if label_smoothing > 0:
                    mask_cat = smooth_labels(mask_cat, label_smoothing)
                batch_x.append(img_aug)
                batch_y.append(mask_cat)
            
            batch_x_arr = np.stack(batch_x).astype(np.float32)
            batch_y_arr = np.stack(batch_y).astype(np.float32)
            yield batch_x_arr, tuple(batch_y_arr for _ in range(num_outputs))

# ============================================================================
# MSCA MODULE (FROM ODFORMER)
# ============================================================================

def msca_block(x, channels, dilation_rates=[1, 2, 3, 5], block_name='msca'):
    """
    Multi-scale Context Aggregator (MSCA) from ODFormer
    
    Features:
    - Multi-scale feature extraction using dilated convolutions
    - Parallel branches with different dilation rates [1, 2, 3, 5]
    - Feature fusion through concatenation and 1×1 convolution
    - Residual connection for gradient flow
    
    Args:
        x: Input feature map
        channels: Number of output channels
        dilation_rates: List of dilation rates for multi-scale context
        block_name: Name prefix for layers
    """
    multi_scale_features = []
    filters_per_branch = channels // len(dilation_rates)
    
    # Multi-scale branches with different dilation rates
    for i, rate in enumerate(dilation_rates):
        branch = layers.Conv2D(
            filters_per_branch,
            (3, 3),
            padding='same',
            dilation_rate=rate,
            use_bias=False,
            name=f'{block_name}_dil{rate}_conv'
        )(x)
        branch = layers.BatchNormalization(name=f'{block_name}_dil{rate}_bn')(branch)
        branch = layers.Activation('relu', name=f'{block_name}_dil{rate}_relu')(branch)
        multi_scale_features.append(branch)
    
    # Concatenate all branches
    concat = layers.Concatenate(name=f'{block_name}_concat')(multi_scale_features)
    
    # Fusion layer to combine multi-scale features
    fused = layers.Conv2D(channels, (1, 1), use_bias=False, name=f'{block_name}_fusion')(concat)
    fused = layers.BatchNormalization(name=f'{block_name}_fusion_bn')(fused)
    fused = layers.Activation('relu', name=f'{block_name}_fusion_relu')(fused)
    
    # Residual connection
    output = layers.Add(name=f'{block_name}_residual')([x, fused])
    
    return output

# ============================================================================
# LBFR MODULE (FROM ODFORMER)
# ============================================================================

def lbfr_block(x, channels, reduction=16, block_name='lbfr'):
    """
    Lightweight Bidirectional Feature Recalibrator (LBFR) from ODFormer
    
    Features:
    - Channel attention using both avg and max pooling
    - Spatial attention using 2-channel feature concatenation
    - Recalibration layer with BatchNormalization
    - Residual connection for gradient flow
    
    Args:
        x: Input feature map
        channels: Number of channels
        reduction: Channel reduction ratio for attention bottleneck
        block_name: Name prefix for layers
    """
    # Channel Attention
    # Average pooling branch
    avg_pool = layers.GlobalAveragePooling2D(name=f'{block_name}_avg_pool')(x)
    avg_pool = layers.Reshape((1, 1, channels), name=f'{block_name}_avg_reshape')(avg_pool)
    
    # Max pooling branch
    max_pool = layers.GlobalMaxPooling2D(name=f'{block_name}_max_pool')(x)
    max_pool = layers.Reshape((1, 1, channels), name=f'{block_name}_max_reshape')(max_pool)
    
    # Shared MLP for channel attention
    fc1 = layers.Conv2D(channels // reduction, (1, 1), use_bias=False, name=f'{block_name}_fc1')
    fc2 = layers.Conv2D(channels, (1, 1), use_bias=False, name=f'{block_name}_fc2')
    
    avg_out = fc1(avg_pool)
    avg_out = layers.Activation('relu', name=f'{block_name}_fc1_relu_avg')(avg_out)
    avg_out = fc2(avg_out)
    
    max_out = fc1(max_pool)
    max_out = layers.Activation('relu', name=f'{block_name}_fc1_relu_max')(max_out)
    max_out = fc2(max_out)
    
    # Combine and apply channel attention
    channel_att = layers.Add(name=f'{block_name}_channel_add')([avg_out, max_out])
    channel_att = layers.Activation('sigmoid', name=f'{block_name}_channel_sigmoid')(channel_att)
    x_channel = layers.Multiply(name=f'{block_name}_channel_multiply')([x, channel_att])
    
    # Spatial Attention
    # Average and max across channels
    avg_spatial = layers.Lambda(lambda x: K.mean(x, axis=-1, keepdims=True), 
                                name=f'{block_name}_spatial_avg')(x_channel)
    max_spatial = layers.Lambda(lambda x: K.max(x, axis=-1, keepdims=True),
                                name=f'{block_name}_spatial_max')(x_channel)
    
    # Concatenate and apply spatial attention
    spatial_concat = layers.Concatenate(name=f'{block_name}_spatial_concat')([avg_spatial, max_spatial])
    spatial_att = layers.Conv2D(1, (7, 7), padding='same', use_bias=False,
                                name=f'{block_name}_spatial_conv')(spatial_concat)
    spatial_att = layers.Activation('sigmoid', name=f'{block_name}_spatial_sigmoid')(spatial_att)
    x_spatial = layers.Multiply(name=f'{block_name}_spatial_multiply')([x_channel, spatial_att])
    
    # Recalibration
    recalibrated = layers.Conv2D(channels, (1, 1), use_bias=False, 
                                 name=f'{block_name}_recalibrate')(x_spatial)
    recalibrated = layers.BatchNormalization(name=f'{block_name}_recalibrate_bn')(recalibrated)
    
    # Residual connection
    output = layers.Add(name=f'{block_name}_residual')([x, recalibrated])
    
    return output

# ============================================================================
# PPM MODULE (FROM PSPNET/ODFORMER)
# ============================================================================

def ppm_block(x, channels, pool_scales=[1, 2, 3, 6], block_name='ppm'):
    """
    Pyramid Pooling Module (PPM) from PSPNet
    
    Features:
    - Multi-scale adaptive pooling at different pyramid levels
    - Captures global context at scales: 1×1, 2×2, 3×3, 6×6
    - Lightweight 1×1 convolutions for each scale
    - Feature fusion through concatenation
    
    Args:
        x: Input feature map
        channels: Number of output channels
        pool_scales: List of pooling scales for pyramid levels
        block_name: Name prefix for layers
    """
    h, w = x.shape[1], x.shape[2]
    
    # Store original features
    ppm_features = [x]
    
    # Multi-scale pooling branches
    filters_per_scale = channels // len(pool_scales)
    
    for i, scale in enumerate(pool_scales):
        # Global average pooling to fixed scale size
        pool_h = max(h // scale, 1)
        pool_w = max(w // scale, 1)
        
        pooled = layers.AveragePooling2D(
            pool_size=(h // pool_h, w // pool_w),
            strides=(h // pool_h, w // pool_w),
            name=f'{block_name}pool{scale}x{scale}'
        )(x)
        
        # 1×1 convolution to reduce channels
        conv = layers.Conv2D(
            filters_per_scale,
            (1, 1),
            use_bias=False,
            name=f'{block_name}conv{scale}x{scale}'
        )(pooled)
        conv = layers.BatchNormalization(name=f'{block_name}bn{scale}x{scale}')(conv)
        conv = layers.Activation('relu', name=f'{block_name}relu{scale}x{scale}')(conv)
        
        # Upsample back to original size using exact target dimensions
        upsampled = layers.Resizing(
            h, w,
            interpolation='bilinear',
            name=f'{block_name}upsample{scale}x{scale}'
        )(conv)
        
        ppm_features.append(upsampled)
    
    # Concatenate all pyramid features
    concat = layers.Concatenate(name=f'{block_name}_concat')(ppm_features)
    
    # Fusion convolution
    fused = layers.Conv2D(
        channels,
        (3, 3),
        padding='same',
        use_bias=False,
        name=f'{block_name}_fusion'
    )(concat)
    fused = layers.BatchNormalization(name=f'{block_name}_fusion_bn')(fused)
    fused = layers.Activation('relu', name=f'{block_name}_fusion_relu')(fused)
    
    return fused

# ============================================================================
# LOSS FUNCTIONS
# ============================================================================

def focal_loss(y_true, y_pred, gamma=2.0, alpha=None, epsilon=1e-7):
    if alpha is None:
        alpha = [0.25, 1.0, 1.0]
    
    y_pred = K.clip(y_pred, epsilon, 1.0 - epsilon)
    focal_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        
        bce = -(y_true_c * K.log(y_pred_c) + (1 - y_true_c) * K.log(1 - y_pred_c))
        pt = y_true_c * y_pred_c + (1 - y_true_c) * (1 - y_pred_c)
        focal_weight = K.pow(1 - pt, gamma)
        
        focal_loss_value += alpha[c] * K.mean(focal_weight * bce)
    
    return focal_loss_value

def enhanced_iou_loss(y_true, y_pred, smooth=1e-7):
    eiou_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        
        intersection = K.sum(y_true_c * y_pred_c, axis=[1, 2])
        union = K.sum(y_true_c, axis=[1, 2]) + K.sum(y_pred_c, axis=[1, 2]) - intersection
        iou = (intersection + smooth) / (union + smooth)
        
        # Fix: K.min/max on the binary mask values gives the min/max VALUE (always
        # 0 or 1), not the spatial INDEX of the mask boundary.  Use coordinate
        # grids so that the reduction over the spatial axis returns the actual
        # normalised row/col position of the bounding-box edges.
        binary_true = K.cast(y_true_c > 0.5, 'float32')   # [batch, H, W]
        binary_pred = K.cast(y_pred_c > 0.5, 'float32')

        _h = tf.cast(tf.shape(y_true_c)[1], 'float32')
        _w = tf.cast(tf.shape(y_true_c)[2], 'float32')
        row_coords = tf.reshape(tf.range(tf.shape(y_true_c)[1], dtype=tf.float32) / _h, [1, -1, 1])  # [1,H,1]
        col_coords = tf.reshape(tf.range(tf.shape(y_true_c)[2], dtype=tf.float32) / _w, [1, 1, -1])  # [1,1,W]

        # Presence along each axis (1 if that row/col contains any mask pixel)
        rp_t = K.max(binary_true, axis=2, keepdims=True)   # [batch, H, 1]
        rp_p = K.max(binary_pred, axis=2, keepdims=True)
        cp_t = K.max(binary_true, axis=1, keepdims=True)   # [batch, 1, W]
        cp_p = K.max(binary_pred, axis=1, keepdims=True)

        # y_min: smallest row index with mask present; add 1 where absent so min ignores them
        y_min_t = K.min(row_coords + (1.0 - rp_t), axis=[1, 2])   # [batch]
        y_max_t = K.max(row_coords * rp_t,          axis=[1, 2])
        x_min_t = K.min(col_coords + (1.0 - cp_t), axis=[1, 2])
        x_max_t = K.max(col_coords * cp_t,          axis=[1, 2])

        y_min_p = K.min(row_coords + (1.0 - rp_p), axis=[1, 2])
        y_max_p = K.max(row_coords * rp_p,          axis=[1, 2])
        x_min_p = K.min(col_coords + (1.0 - cp_p), axis=[1, 2])
        x_max_p = K.max(col_coords * cp_p,          axis=[1, 2])

        # Bboxes now have correct shape [batch, 4] where indices are [y_min, x_min, y_max, x_max]
        y_true_bbox = K.stack([y_min_t, x_min_t, y_max_t, x_max_t], axis=-1)
        y_pred_bbox = K.stack([y_min_p, x_min_p, y_max_p, x_max_p], axis=-1)
        
        center_true = K.stack([
            (y_true_bbox[:, 0] + y_true_bbox[:, 2]) / 2.0,
            (y_true_bbox[:, 1] + y_true_bbox[:, 3]) / 2.0
        ], axis=-1)
        
        center_pred = K.stack([
            (y_pred_bbox[:, 0] + y_pred_bbox[:, 2]) / 2.0,
            (y_pred_bbox[:, 1] + y_pred_bbox[:, 3]) / 2.0
        ], axis=-1)
        
        center_distance = K.sum(K.square(center_true - center_pred), axis=-1)
        
        diag_length = K.square(y_true_bbox[:, 2] - y_true_bbox[:, 0]) + \
                     K.square(y_true_bbox[:, 3] - y_true_bbox[:, 1])
        
        diag_length = K.maximum(diag_length, 1e-7)
        
        eiou = iou - (center_distance / diag_length)
        eiou_loss_value += K.mean(1.0 - eiou)
    
    return eiou_loss_value / 3.0

def focal_eiou_combined_loss(y_true, y_pred, focal_weight=1.0, eiou_weight=1.0, gamma=2.0, alpha=None):
    fl = focal_loss(y_true, y_pred, gamma=gamma, alpha=alpha)
    eiou = enhanced_iou_loss(y_true, y_pred)
    return focal_weight * fl + eiou_weight * eiou

# ============================================================================
# MODEL ARCHITECTURE WITH MSCA + LBFR + PPM
# ============================================================================

def enhanced_decoder_block_with_triple_attention(x, skip_connection, filters, block_name, dropout_rate=0.3):
    """
    Enhanced decoder block with MSCA + LBFR + PPM triple attention
    
    Sequential enhancement strategy:
    1. Standard decoder convolutions with residual connection
    2. MSCA for multi-scale local context aggregation (dilated convs)
    3. LBFR for bidirectional feature recalibration (channel + spatial attention)
    4. PPM for multi-scale global context aggregation (pyramid pooling)
    
    This combines three complementary attention mechanisms:
    - MSCA: Local multi-scale receptive fields
    - LBFR: Channel and spatial recalibration
    - PPM: Global multi-scale context
    """
    x = layers.UpSampling2D((2, 2), name=f'{block_name}_upsample')(x)
    
    if skip_connection.shape[-1] != x.shape[-1]:
        skip_connection = layers.Conv2D(x.shape[-1], (1, 1), padding='same', 
                                       name=f'{block_name}_skip_adjust')(skip_connection)
    
    x = layers.Concatenate(name=f'{block_name}_concat')([x, skip_connection])
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv1')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn1')(x)
    x = layers.Dropout(dropout_rate, name=f'{block_name}_dropout')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv2')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn2')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv3')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn3')(x)
    
    residual = x
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv4')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn4')(x)
    
    x = layers.Add(name=f'{block_name}_residual')([x, residual])
    x = layers.Conv2D(filters, (1, 1), activation='relu', padding='same', name=f'{block_name}_conv_final')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn_final')(x)
    
    # Apply MSCA for local multi-scale context aggregation
    x = msca_block(x, filters, dilation_rates=[1, 2, 3, 5], block_name=f'{block_name}_msca')
    
    # Apply LBFR for bidirectional feature recalibration
    x = lbfr_block(x, filters, reduction=16, block_name=f'{block_name}_lbfr')
    
    # Apply PPM for global multi-scale context aggregation
    x = ppm_block(x, filters, pool_scales=[1, 2, 3, 6], block_name=f'{block_name}_ppm')
    
    return x

def build_unet_with_triple_attention(input_shape=(512, 512, 3), num_classes=3, dropout_rate=0.3):
    # Build MobileNetV2-UNet with MSCA + LBFR + PPM triple attention + deep supervision
    inputs = layers.Input(input_shape, dtype='float32')
    backbone = MobileNetV2(input_tensor=inputs, weights='imagenet', include_top=False)

    skip_1 = backbone.get_layer('block_1_expand_relu').output  # 128×128
    skip_2 = backbone.get_layer('block_3_expand_relu').output  # 64×64
    skip_3 = backbone.get_layer('block_6_expand_relu').output  # 32×32
    skip_4 = backbone.get_layer('block_13_expand_relu').output # 16×16
    bridge = backbone.output  # 8×8

    bridge = layers.Conv2D(1024, (3, 3), activation='relu', padding='same')(bridge)
    bridge = layers.BatchNormalization()(bridge)
    bridge = layers.Dropout(dropout_rate, name='bridge_dropout')(bridge)

    d1 = enhanced_decoder_block_with_triple_attention(bridge, skip_4, 512, 'decoder_1', dropout_rate)
    d2 = enhanced_decoder_block_with_triple_attention(d1, skip_3, 256, 'decoder_2', dropout_rate)
    d3 = enhanced_decoder_block_with_triple_attention(d2, skip_2, 128, 'decoder_3', dropout_rate * 0.7)
    d4 = enhanced_decoder_block_with_triple_attention(d3, skip_1, 64, 'decoder_4', dropout_rate * 0.5)

    # Auxiliary outputs for deep supervision (all resized to full resolution)
    ds1 = layers.Conv2D(num_classes, (1, 1), activation='softmax', dtype='float32', name='ds1_out')(d1)
    ds1 = layers.UpSampling2D((16, 16), interpolation='bilinear')(ds1)

    ds2 = layers.Conv2D(num_classes, (1, 1), activation='softmax', dtype='float32', name='ds2_out')(d2)
    ds2 = layers.UpSampling2D((8, 8), interpolation='bilinear')(ds2)

    ds3 = layers.Conv2D(num_classes, (1, 1), activation='softmax', dtype='float32', name='ds3_out')(d3)
    ds3 = layers.UpSampling2D((4, 4), interpolation='bilinear')(ds3)

    ds4 = layers.Conv2D(num_classes, (1, 1), activation='softmax', dtype='float32', name='ds4_out')(d4)
    ds4 = layers.UpSampling2D((2, 2), interpolation='bilinear')(ds4)

    x = layers.UpSampling2D((2, 2))(d4)
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    main_out = layers.Conv2D(num_classes, (1, 1), activation='softmax', dtype='float32', name='main_output')(x)

    model = models.Model(inputs, [main_out, ds1, ds2, ds3, ds4])

    dropout_layers = [layer for layer in model.layers if isinstance(layer, layers.Dropout)]
    print(f"\nModel Configuration:")
    print(f"  Total Parameters: {model.count_params():,}")
    print(f"  Dropout Layers: {len(dropout_layers)}")
    print(f"  Deep Supervision Heads: 4")
    print(f"  Triple Attention Modules: MSCA + LBFR + PPM per decoder block")
    print(f"  Total Attention Blocks: 12 (4 MSCA + 4 LBFR + 4 PPM)")

    return model

# ============================================================================
# METRICS
# ============================================================================

def dice_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    return (2. * intersection + smooth) / (K.sum(y_true_class) + K.sum(y_pred_class) + smooth)

def dice_class_0(y_true, y_pred): return dice_coef_class(y_true, y_pred, 0)
def dice_class_1(y_true, y_pred): return dice_coef_class(y_true, y_pred, 1)
def dice_class_2(y_true, y_pred): return dice_coef_class(y_true, y_pred, 2)

def iou_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    union = K.sum(y_true_class) + K.sum(y_pred_class) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_class_0(y_true, y_pred): return iou_coef_class(y_true, y_pred, 0)
def iou_class_1(y_true, y_pred): return iou_coef_class(y_true, y_pred, 1)
def iou_class_2(y_true, y_pred): return iou_coef_class(y_true, y_pred, 2)

def mc_dropout_predict(model, X, num_samples=15, batch_size=4, verbose=True):
    """MC Dropout prediction for uncertainty estimation - Memory Optimized"""
    if verbose:
        print(f"\nRunning MC Dropout with {num_samples} stochastic forward passes...")
    
    # Initialize accumulators
    sum_preds = None
    sum_sq_preds = None
    
    num_batches = int(np.ceil(len(X) / batch_size))
    
    for i in range(num_samples):
        if verbose and (i + 1) % 5 == 0:
            print(f"  Completed: {i+1}/{num_samples} forward passes")
        
        batch_preds = []
        for batch_idx in range(num_batches):
            start_idx = batch_idx * batch_size
            end_idx = min(start_idx + batch_size, len(X))
            X_batch = X[start_idx:end_idx]
            
            # Predict with training=True for dropout
            pred_batch = model(X_batch, training=True)
            if isinstance(pred_batch, (list, tuple)):
                pred_batch = pred_batch[0]  # main_output
            batch_preds.append(pred_batch.numpy())
        
        # Concatenate batches for current pass
        current_pass_preds = np.concatenate(batch_preds, axis=0)
        
        # Accumulate sums
        if sum_preds is None:
            sum_preds = current_pass_preds.astype(np.float32)
            sum_sq_preds = np.square(current_pass_preds).astype(np.float32)
        else:
            sum_preds += current_pass_preds
            sum_sq_preds += np.square(current_pass_preds)
        
        # Free memory
        del current_pass_preds, batch_preds
        if (i + 1) % 5 == 0:
            gc.collect()
    
    # Calculate Mean and Std
    mean_pred = sum_preds / num_samples
    
    # Var = E[X^2] - (E[X])^2
    # Std = sqrt(Var)
    mean_sq_pred = sum_sq_preds / num_samples
    var_pred = mean_sq_pred - np.square(mean_pred)
    # Ensure non-negative variance due to float precision
    var_pred = np.maximum(var_pred, 0)
    std_pred = np.sqrt(var_pred)
    
    # Cleanup
    del sum_preds, sum_sq_preds
    gc.collect()
    
    if verbose:
        print(f"✓ MC Dropout completed")
    
    return mean_pred, std_pred

# ============================================================================
# GLAUCOMA PROGRESSION SCORING
# ============================================================================

def calculate_cdr(mask, disc_class=1, cup_class=2, method='vertical'):
    """
    Calculate Cup-to-Disc Ratio (CDR) from segmentation mask
    
    Methods:
    - 'vertical': Vertical diameter ratio (clinical standard, most accurate)
    - 'area_sqrt': Square root of area ratio (robust alternative)
    
    Args:
        mask: Segmentation mask (H, W) with class labels
        disc_class: Class label for optic disc (default=1)
        cup_class: Class label for optic cup (default=2)
        method: Calculation method (default='vertical')
    
    Returns:
        dict with vCDR, hCDR, avgCDR, area_CDR
    """
    disc_mask = (mask == disc_class).astype(np.uint8)
    cup_mask = (mask == cup_class).astype(np.uint8)
    
    # Check if disc and cup are present
    disc_area = disc_mask.sum()
    cup_area = cup_mask.sum()
    
    if disc_area == 0 or cup_area == 0:
        return {'vCDR': 0.0, 'hCDR': 0.0, 'avgCDR': 0.0, 'area_CDR': 0.0, 'valid': False, 
                'method': method, 'disc_area': 0, 'cup_area': 0}
    
    # Find coordinates
    disc_coords = np.where(disc_mask > 0)
    cup_coords = np.where(cup_mask > 0)
    
    # Calculate diameters using bounding box
    disc_v_diameter = disc_coords[0].max() - disc_coords[0].min() + 1
    cup_v_diameter = cup_coords[0].max() - cup_coords[0].min() + 1
    disc_h_diameter = disc_coords[1].max() - disc_coords[1].min() + 1
    cup_h_diameter = cup_coords[1].max() - cup_coords[1].min() + 1
    
    # Calculate CDRs
    vCDR = cup_v_diameter / disc_v_diameter if disc_v_diameter > 0 else 0.0
    hCDR = cup_h_diameter / disc_h_diameter if disc_h_diameter > 0 else 0.0
    
    # Calculate area-based CDR
    area_CDR = np.sqrt(cup_area / disc_area)
    
    # Choose primary CDR based on method
    if method == 'vertical':
        avgCDR = vCDR  # Use vertical CDR (clinical standard)
    elif method == 'area_sqrt':
        avgCDR = area_CDR  # Use area-based
    else:
        avgCDR = (vCDR + hCDR) / 2.0  # Average of both
    
    return {
        'vCDR': float(vCDR),
        'hCDR': float(hCDR),
        'avgCDR': float(avgCDR),
        'area_CDR': float(area_CDR),
        'valid': True,
        'method': method,
        'disc_area': int(disc_area),
        'cup_area': int(cup_area),
        'disc_v_diameter': int(disc_v_diameter),
        'cup_v_diameter': int(cup_v_diameter)
    }

def classify_glaucoma_severity(cdr):
    """
    Classify glaucoma severity based on CDR
    
    Classification:
    - Normal: CDR < 0.3
    - Suspect: 0.3 ≤ CDR < 0.6
    - Moderate: 0.6 ≤ CDR < 0.8
    - Critical: CDR ≥ 0.8
    
    Args:
        cdr: Cup-to-Disc Ratio (float)
    
    Returns:
        tuple: (severity_class, severity_label, color)
    """
    if cdr < 0.3:
        return 0, 'Normal', '#4CAF50'  # Green
    elif cdr < 0.6:
        return 1, 'Suspect', '#FFC107'  # Amber
    elif cdr < 0.8:
        return 2, 'Moderate', '#FF9800'  # Orange
    else:
        return 3, 'Critical', '#F44336'  # Red

def analyze_glaucoma_progression(masks, predictions, cdr_method='area_sqrt'):
    """
    Analyze glaucoma progression for a batch of samples
    
    Args:
        masks: Ground truth masks (N, H, W)
        predictions: Predicted masks (N, H, W)
        cdr_method: CDR calculation method (default='area_sqrt' for robustness)
    
    Returns:
        DataFrame with CDR metrics and classifications
    """
    results = []
    
    for i, (gt_mask, pred_mask) in enumerate(zip(masks, predictions)):
        # Calculate CDR for ground truth
        gt_cdr = calculate_cdr(gt_mask, method=cdr_method)
        
        # Calculate CDR for prediction
        pred_cdr = calculate_cdr(pred_mask, method=cdr_method)
        
        # Classify severity
        if gt_cdr['valid']:
            gt_class, gt_label, gt_color = classify_glaucoma_severity(gt_cdr['avgCDR'])
        else:
            gt_class, gt_label, gt_color = -1, 'Invalid', '#9E9E9E'
        
        if pred_cdr['valid']:
            pred_class, pred_label, pred_color = classify_glaucoma_severity(pred_cdr['avgCDR'])
        else:
            pred_class, pred_label, pred_color = -1, 'Invalid', '#9E9E9E'
        
        # Calculate CDR error
        cdr_error = abs(gt_cdr['avgCDR'] - pred_cdr['avgCDR']) if gt_cdr['valid'] and pred_cdr['valid'] else np.nan
        
        # Check if classification matches
        severity_match = (gt_label == pred_label)
        
        # Manual review needed: Critical cases or mismatches
        manual_review = (gt_label == 'Critical') or (not severity_match)
        
        results.append({
            'Sample': i + 1,
            'GT_vCDR': gt_cdr['vCDR'],
            'GT_hCDR': gt_cdr['hCDR'],
            'GT_avgCDR': gt_cdr['avgCDR'],
            'GT_area_CDR': gt_cdr['area_CDR'],
            'GT_Severity': gt_label,
            'Pred_vCDR': pred_cdr['vCDR'],
            'Pred_hCDR': pred_cdr['hCDR'],
            'Pred_avgCDR': pred_cdr['avgCDR'],
            'Pred_area_CDR': pred_cdr['area_CDR'],
            'Pred_Severity': pred_label,
            'CDR_Error': cdr_error,
            'Severity_Match': severity_match,
            'Manual_Review_Needed': manual_review
        })
    
    return pd.DataFrame(results)

def calculate_progression_accuracy(df_progression):
    """
    Calculate simple accuracy metrics: GT progression vs Predicted progression
    
    Returns accuracy % like: "GT says Normal for 250 images, model says 230 are Normal"
    """
    results = {}
    
    # Overall accuracy
    total = len(df_progression)
    correct = df_progression['Severity_Match'].sum()
    overall_accuracy = (correct / total) * 100
    
    results['overall'] = {
        'total': total,
        'correct': correct,
        'accuracy': overall_accuracy
    }
    
    # Per-class accuracy
    severity_classes = ['Normal', 'Suspect', 'Moderate', 'Critical']
    results['per_class'] = {}
    
    for severity in severity_classes:
        gt_count = len(df_progression[df_progression['GT_Severity'] == severity])
        pred_count = len(df_progression[df_progression['Pred_Severity'] == severity])
        
        # Correctly predicted: GT is this class AND model predicted it as this class
        correct_count = len(df_progression[
            (df_progression['GT_Severity'] == severity) & 
            (df_progression['Pred_Severity'] == severity)
        ])
        
        class_accuracy = (correct_count / gt_count * 100) if gt_count > 0 else 0.0
        
        results['per_class'][severity] = {
            'gt_count': gt_count,
            'pred_count': pred_count,
            'correct': correct_count,
            'accuracy': class_accuracy
        }
    
    # Manual review statistics
    manual_review_needed = df_progression['Manual_Review_Needed'].sum()
    manual_review_pct = (manual_review_needed / total) * 100
    
    results['manual_review'] = {
        'count': manual_review_needed,
        'percentage': manual_review_pct
    }
    
    return results

# ============================================================================
# VISUALIZATION FUNCTIONS
# ============================================================================

def plot_sample_predictions(model, X_test, y_test, model_name, num_samples=6, save_dir='results'):
    """Visualize sample predictions with original image, GT, segmented mask, and overlay"""
    os.makedirs(save_dir, exist_ok=True)
    
    y_pred_raw = model.predict(X_test[:num_samples], verbose=0, batch_size=4)
    y_pred = y_pred_raw[0] if isinstance(y_pred_raw, (list, tuple)) else y_pred_raw
    y_pred_labels = np.argmax(y_pred, axis=-1)
    
    colors = {0: [0, 0, 0], 1: [0, 255, 0], 2: [255, 0, 0]}
    
    fig, axes = plt.subplots(num_samples, 4, figsize=(16, 4*num_samples))
    
    for i in range(num_samples):
        # Original image
        axes[i, 0].imshow(X_test[i])
        axes[i, 0].set_title('Original Image', fontsize=12, fontweight='bold')
        axes[i, 0].axis('off')
        
        # Ground truth
        gt_colored = np.zeros((512, 512, 3), dtype=np.uint8)
        for class_id, color in colors.items():
            gt_colored[y_test[i] == class_id] = color
        axes[i, 1].imshow(gt_colored)
        axes[i, 1].set_title('Ground Truth (GT)', fontsize=12, fontweight='bold')
        axes[i, 1].axis('off')
        
        # Segmented mask
        pred_colored = np.zeros((512, 512, 3), dtype=np.uint8)
        for class_id, color in colors.items():
            pred_colored[y_pred_labels[i] == class_id] = color
        axes[i, 2].imshow(pred_colored)
        axes[i, 2].set_title('Segmented Mask', fontsize=12, fontweight='bold')
        axes[i, 2].axis('off')
        
        # Overlay
        overlay = X_test[i].copy()
        for class_id, color in colors.items():
            if class_id > 0:
                mask = (y_pred_labels[i] == class_id).astype(np.float32)
                mask_rgb = np.stack([mask * color[0]/255, mask * color[1]/255, mask * color[2]/255], axis=-1)
                overlay = overlay * 0.6 + mask_rgb * 0.4
        axes[i, 3].imshow(overlay)
        axes[i, 3].set_title('Overlay', fontsize=12, fontweight='bold')
        axes[i, 3].axis('off')
        
        # Calculate dice
        y_test_cat = to_categorical(y_test[i], num_classes=3)
        y_pred_cat = to_categorical(y_pred_labels[i], num_classes=3)
        
        disc_dice = 2 * np.sum(y_test_cat[:,:,1] * y_pred_cat[:,:,1]) / (np.sum(y_test_cat[:,:,1]) + np.sum(y_pred_cat[:,:,1]) + 1e-7)
        cup_dice = 2 * np.sum(y_test_cat[:,:,2] * y_pred_cat[:,:,2]) / (np.sum(y_test_cat[:,:,2]) + np.sum(y_pred_cat[:,:,2]) + 1e-7)
        
        axes[i, 0].text(0.5, -0.1, f'Sample {i+1}\nDisc: {disc_dice:.3f} | Cup: {cup_dice:.3f}', 
                       transform=axes[i, 0].transAxes, ha='center', fontsize=10, 
                       bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
    
    plt.suptitle(f'{model_name} - Predictions: Original | GT | Segmented | Overlay', 
                 fontsize=16, fontweight='bold', y=0.995)
    plt.tight_layout()
    plt.savefig(f'{save_dir}/{model_name}_predictions.png', dpi=150, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_predictions.png")
    plt.show()
    plt.close()

def plot_sample_predictions_with_cdr(model, X_test_roi, y_test_full, roi_coords_test,
                                     model_name, num_samples=6, save_dir='results'):
    """Visualize predictions with CDR and glaucoma severity (ROI-aware)"""
    os.makedirs(save_dir, exist_ok=True)
    
    y_pred_raw = model.predict(X_test_roi[:num_samples], verbose=0, batch_size=4)
    y_pred = y_pred_raw[0] if isinstance(y_pred_raw, (list, tuple)) else y_pred_raw
    y_pred_labels_roi = np.argmax(y_pred, axis=-1)
    
    colors = {0: [0, 0, 0], 1: [0, 255, 0], 2: [255, 0, 0]}
    
    fig, axes = plt.subplots(num_samples, 4, figsize=(18, 4*num_samples))
    
    for i in range(num_samples):
        # ROI image
        axes[i, 0].imshow(X_test_roi[i])
        axes[i, 0].set_title('ROI Image', fontsize=12, fontweight='bold')
        axes[i, 0].axis('off')
        
        # Ground truth (on full image for CDR)
        gt_mask_full = y_test_full[i]
        h, w = gt_mask_full.shape
        gt_colored = np.zeros((h, w, 3), dtype=np.uint8)
        for class_id, color in colors.items():
            gt_colored[gt_mask_full == class_id] = color
        axes[i, 1].imshow(gt_colored)
        
        gt_cdr = calculate_cdr(gt_mask_full)
        gt_class, gt_label, gt_color = classify_glaucoma_severity(gt_cdr['avgCDR']) if gt_cdr['valid'] else (-1, 'Invalid', '#9E9E9E')
        
        axes[i, 1].set_title(f'Ground Truth\nCDR: {gt_cdr["avgCDR"]:.3f} | {gt_label}', 
                            fontsize=12, fontweight='bold', color=gt_color)
        axes[i, 1].axis('off')
        
        # Map ROI prediction back to full image
        pred_full = map_roi_prediction_to_full(y_pred_labels_roi[i], roi_coords_test[i], full_size=(h, w))
        pred_colored = np.zeros((h, w, 3), dtype=np.uint8)
        for class_id, color in colors.items():
            pred_colored[pred_full == class_id] = color
        axes[i, 2].imshow(pred_colored)
        
        pred_cdr = calculate_cdr(pred_full)
        pred_class, pred_label, pred_color = classify_glaucoma_severity(pred_cdr['avgCDR']) if pred_cdr['valid'] else (-1, 'Invalid', '#9E9E9E')
        
        axes[i, 2].set_title(f'Prediction\nCDR: {pred_cdr["avgCDR"]:.3f} | {pred_label}', 
                            fontsize=12, fontweight='bold', color=pred_color)
        axes[i, 2].axis('off')
        
        # Overlay on ROI
        overlay = X_test_roi[i].copy()
        for class_id, color in colors.items():
            if class_id > 0:
                mask = (y_pred_labels_roi[i] == class_id).astype(np.float32)
                mask_rgb = np.stack([mask * color[0]/255, mask * color[1]/255, mask * color[2]/255], axis=-1)
                overlay = overlay * 0.6 + mask_rgb * 0.4
        axes[i, 3].imshow(overlay)
        axes[i, 3].set_title('ROI Overlay', fontsize=12, fontweight='bold')
        axes[i, 3].axis('off')
        
        # Calculate dice on ROI
        roi_gt_cat = to_categorical(y_test_full[i], num_classes=3)  # use full GT for fair CDR
        roi_pred_cat = to_categorical(pred_full, num_classes=3)
        
        disc_dice = 2 * np.sum(roi_gt_cat[:,:,1] * roi_pred_cat[:,:,1]) / (np.sum(roi_gt_cat[:,:,1]) + np.sum(roi_pred_cat[:,:,1]) + 1e-7)
        cup_dice = 2 * np.sum(roi_gt_cat[:,:,2] * roi_pred_cat[:,:,2]) / (np.sum(roi_gt_cat[:,:,2]) + np.sum(roi_pred_cat[:,:,2]) + 1e-7)
        
        cdr_error = abs(gt_cdr['avgCDR'] - pred_cdr['avgCDR']) if gt_cdr['valid'] and pred_cdr['valid'] else np.nan
        
        info_text = f'Sample {i+1}\n'
        info_text += f'Disc Dice: {disc_dice:.3f} | Cup Dice: {cup_dice:.3f}\n'
        info_text += f'CDR Error: {cdr_error:.3f}' if not np.isnan(cdr_error) else 'CDR Error: N/A'
        
        axes[i, 0].text(0.5, -0.15, info_text, transform=axes[i, 0].transAxes, 
                       ha='center', fontsize=10, bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
    
    plt.suptitle(f'{model_name} - ROI Predictions with Glaucoma Severity Assessment', 
                 fontsize=16, fontweight='bold', y=0.995)
    plt.tight_layout()
    plt.savefig(f'{save_dir}/{model_name}_predictions_cdr.png', dpi=150, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_predictions_cdr.png")
    plt.show()
    plt.close()

def plot_cdr_distribution(df_progression, save_dir='results'):
    """Plot CDR distribution and severity classification"""
    os.makedirs(save_dir, exist_ok=True)
    
    fig, axes = plt.subplots(2, 2, figsize=(16, 12))
    
    # CDR scatter plot (GT vs Pred)
    axes[0, 0].scatter(df_progression['GT_avgCDR'], df_progression['Pred_avgCDR'], 
                      alpha=0.6, s=100, c='blue', edgecolors='black')
    axes[0, 0].plot([0, 1], [0, 1], 'r--', linewidth=2, label='Perfect Prediction')
    axes[0, 0].set_xlabel('Ground Truth CDR', fontsize=12, fontweight='bold')
    axes[0, 0].set_ylabel('Predicted CDR', fontsize=12, fontweight='bold')
    axes[0, 0].set_title('CDR: Ground Truth vs Prediction', fontsize=14, fontweight='bold')
    axes[0, 0].legend(fontsize=10)
    axes[0, 0].grid(True, alpha=0.3)
    
    # Add severity zones
    axes[0, 0].axhspan(0, 0.3, alpha=0.1, color='green', label='Normal')
    axes[0, 0].axhspan(0.3, 0.6, alpha=0.1, color='yellow', label='Suspect')
    axes[0, 0].axhspan(0.6, 0.8, alpha=0.1, color='orange', label='Moderate')
    axes[0, 0].axhspan(0.8, 1.0, alpha=0.1, color='red', label='Critical')
    
    # CDR error histogram
    valid_errors = df_progression['CDR_Error'].dropna()
    axes[0, 1].hist(valid_errors, bins=30, color='steelblue', edgecolor='black', alpha=0.7)
    axes[0, 1].axvline(valid_errors.mean(), color='red', linestyle='--', linewidth=2, 
                      label=f'Mean Error: {valid_errors.mean():.4f}')
    axes[0, 1].set_xlabel('CDR Error (|GT - Pred|)', fontsize=12, fontweight='bold')
    axes[0, 1].set_ylabel('Frequency', fontsize=12, fontweight='bold')
    axes[0, 1].set_title('CDR Error Distribution', fontsize=14, fontweight='bold')
    axes[0, 1].legend(fontsize=10)
    axes[0, 1].grid(True, alpha=0.3)
    
    # Severity classification confusion matrix
    severity_order = ['Normal', 'Suspect', 'Moderate', 'Critical']
    gt_severity = pd.Categorical(df_progression['GT_Severity'], categories=severity_order, ordered=True)
    pred_severity = pd.Categorical(df_progression['Pred_Severity'], categories=severity_order, ordered=True)
    
    cm = confusion_matrix(gt_severity, pred_severity, labels=severity_order)
    
    sns.heatmap(cm, annot=True, fmt='d', cmap='YlOrRd', 
                xticklabels=severity_order, yticklabels=severity_order,
                ax=axes[1, 0], cbar_kws={'label': 'Count'})
    axes[1, 0].set_title('Glaucoma Severity Classification', fontsize=14, fontweight='bold')
    axes[1, 0].set_ylabel('Ground Truth', fontsize=12, fontweight='bold')
    axes[1, 0].set_xlabel('Predicted', fontsize=12, fontweight='bold')
    
    # Severity distribution
    severity_counts_gt = df_progression['GT_Severity'].value_counts()
    severity_counts_pred = df_progression['Pred_Severity'].value_counts()
    
    x = np.arange(len(severity_order))
    width = 0.35
    
    counts_gt = [severity_counts_gt.get(s, 0) for s in severity_order]
    counts_pred = [severity_counts_pred.get(s, 0) for s in severity_order]
    
    bars1 = axes[1, 1].bar(x - width/2, counts_gt, width, label='Ground Truth', 
                          color=['#4CAF50', '#FFC107', '#FF9800', '#F44336'], alpha=0.7)
    bars2 = axes[1, 1].bar(x + width/2, counts_pred, width, label='Predicted', 
                          color=['#4CAF50', '#FFC107', '#FF9800', '#F44336'], alpha=0.4)
    
    axes[1, 1].set_xlabel('Severity Level', fontsize=12, fontweight='bold')
    axes[1, 1].set_ylabel('Count', fontsize=12, fontweight='bold')
    axes[1, 1].set_title('Severity Distribution', fontsize=14, fontweight='bold')
    axes[1, 1].set_xticks(x)
    axes[1, 1].set_xticklabels(severity_order, rotation=15)
    axes[1, 1].legend(fontsize=10)
    axes[1, 1].grid(True, alpha=0.3, axis='y')
    
    plt.tight_layout()
    plt.savefig(f'{save_dir}/cdr_analysis.png', dpi=150, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/cdr_analysis.png")
    plt.show()
    plt.close()

def _get_accuracy_history_keys(history_dict):
    """Resolve train/val accuracy keys for single- and multi-output Keras models."""
    train_candidates = [
        'accuracy',
        'acc',
        'main_output_accuracy',
        'main_output_acc'
    ]
    val_candidates = [
        'val_accuracy',
        'val_acc',
        'val_main_output_accuracy',
        'val_main_output_acc'
    ]

    train_key = next((k for k in train_candidates if k in history_dict), None)
    val_key = next((k for k in val_candidates if k in history_dict), None)

    # Fallback: scan for any non-validation accuracy-like key
    if train_key is None:
        train_key = next((k for k in history_dict.keys() if ('acc' in k or 'accuracy' in k) and not k.startswith('val_')), None)

    # Fallback: infer validation key from resolved train key
    if val_key is None and train_key is not None:
        inferred_val = f'val_{train_key}'
        if inferred_val in history_dict:
            val_key = inferred_val

    return train_key, val_key

def plot_training_history(history, model_name, save_dir='results'):
    """Plot training history - Loss and Accuracy only"""
    os.makedirs(save_dir, exist_ok=True)

    fig, axes = plt.subplots(1, 2, figsize=(15, 5))

    # Loss curves
    axes[0].plot(history.history['loss'], label='Training Loss', linewidth=2)
    axes[0].plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
    axes[0].set_title(f'{model_name} - Loss Over Epochs', fontsize=14, fontweight='bold')
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('Loss', fontsize=12)
    axes[0].legend(fontsize=10)
    axes[0].grid(True, alpha=0.3)

    # Accuracy curves (supports multi-output key names like main_output_accuracy)
    train_acc_key, val_acc_key = _get_accuracy_history_keys(history.history)
    if train_acc_key is not None:
        axes[1].plot(history.history[train_acc_key], label='Training Accuracy', linewidth=2)
    if val_acc_key is not None:
        axes[1].plot(history.history[val_acc_key], label='Validation Accuracy', linewidth=2)

    if train_acc_key is None and val_acc_key is None:
        axes[1].text(0.5, 0.5, 'Accuracy metric not found in history',
                     ha='center', va='center', transform=axes[1].transAxes, fontsize=11)

    axes[1].set_title(f'{model_name} - Accuracy Over Epochs', fontsize=14, fontweight='bold')
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('Accuracy', fontsize=12)
    axes[1].legend(fontsize=10)
    axes[1].grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(f'{save_dir}/{model_name}_history.png', dpi=150, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_history.png")
    plt.show()
    plt.close()

def plot_training_curves(history, model_name, save_dir='results'):
    """Plot training loss and accuracy curves"""
    os.makedirs(save_dir, exist_ok=True)

    fig, axes = plt.subplots(1, 2, figsize=(15, 5))

    # Loss
    axes[0].plot(history.history['loss'], label='Training Loss', linewidth=2)
    axes[0].plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
    axes[0].set_title(f'{model_name} - Loss Over Epochs', fontsize=14, fontweight='bold')
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('Loss', fontsize=12)
    axes[0].legend(fontsize=10)
    axes[0].grid(True, alpha=0.3)

    # Accuracy
    train_acc_key, val_acc_key = _get_accuracy_history_keys(history.history)
    if train_acc_key is not None:
        axes[1].plot(history.history[train_acc_key], label='Training Accuracy', linewidth=2)
    if val_acc_key is not None:
        axes[1].plot(history.history[val_acc_key], label='Validation Accuracy', linewidth=2)

    if train_acc_key is None and val_acc_key is None:
        axes[1].text(0.5, 0.5, 'Accuracy metric not found in history',
                     ha='center', va='center', transform=axes[1].transAxes, fontsize=11)

    axes[1].set_title(f'{model_name} - Accuracy Over Epochs', fontsize=14, fontweight='bold')
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('Accuracy', fontsize=12)
    axes[1].legend(fontsize=10)
    axes[1].grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig(f"{save_dir}/{model_name}_training_curves.png", dpi=300, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_training_curves.png")
    plt.show()
    plt.close()

def plot_confusion_matrices(y_true, y_pred, model_name, save_dir='results'):
    """Plot confusion matrices"""
    os.makedirs(save_dir, exist_ok=True)
    
    y_true_labels = np.argmax(y_true, axis=-1).flatten()
    y_pred_labels = np.argmax(y_pred, axis=-1).flatten()
    
    cm = confusion_matrix(y_true_labels, y_pred_labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    class_names = ['Background', 'Disc', 'Cup']
    
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[0], cbar_kws={'label': 'Count'})
    axes[0].set_title(f'{model_name}\nConfusion Matrix', fontsize=14, fontweight='bold')
    axes[0].set_ylabel('True Label', fontsize=12)
    axes[0].set_xlabel('Predicted Label', fontsize=12)
    
    sns.heatmap(cm_normalized, annot=True, fmt='.3f', cmap='Greens',
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[1], cbar_kws={'label': 'Proportion'})
    axes[1].set_title(f'{model_name}\nNormalized Confusion Matrix', fontsize=14, fontweight='bold')
    axes[1].set_ylabel('True Label', fontsize=12)
    axes[1].set_xlabel('Predicted Label', fontsize=12)
    
    plt.tight_layout()
    plt.savefig(f"{save_dir}/{model_name}_confusion_matrices.png", dpi=300, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_confusion_matrices.png")
    plt.show()
    plt.close()
    
    print(f"\nConfusion Matrix:\n{cm}")
    print(f"\nNormalized Confusion Matrix:\n{np.round(cm_normalized, 3)}")
    
    return cm, cm_normalized

# ============================================================================
# TRAINING AND EVALUATION
# ============================================================================

def train_model(X_train_roi, y_train_roi, X_val_roi, y_val_roi,
                X_test_roi, y_test_full, roi_coords_test,
                model_name, augment=None, save_dir='results'):
    """Train model with MSCA + LBFR + PPM triple enhancement on ROI-cropped data"""
    print(f"\n{'='*80}")
    print(f"TRAINING: {model_name}")
    print(f"{'='*80}")
    print(f"  Architecture: Deeper Decoder + MSCA + LBFR + PPM + Focal-EIoU + MC Dropout")
    print(f"  Loss: Focal + Enhanced IoU (Combined) + Deep Supervision")
    print(f"  Label Smoothing: 0.05")
    print(f"  ROI Extraction: ENABLED (training on disc-centered crops)")
    
    K.clear_session()
    
    # Build model
    model = build_unet_with_triple_attention(dropout_rate=0.3)
    param_count = model.count_params()
    
    # Compile
    ds_weights = [1.0, 0.125, 0.25, 0.5, 0.5]
    model.compile(
        optimizer=optimizers.Adam(learning_rate=2e-4, clipnorm=1.0),
        loss=[focal_eiou_combined_loss] * 5,
        loss_weights=ds_weights,
        metrics={'main_output': [dice_coef_multiclass, dice_class_0, dice_class_1, dice_class_2,
                                 "accuracy", iou_coef_multiclass, iou_class_0, iou_class_1, iou_class_2]}
    )
    
    # Callbacks
    checkpoint = ModelCheckpoint(f"{save_dir}/{model_name}.keras", save_best_only=True, 
                                verbose=1, monitor='val_loss', mode='min')
    reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=4,
                                  verbose=1, mode='min', min_lr=1e-7)
    early_stop = EarlyStopping(monitor="val_loss", patience=15, verbose=1,
                              restore_best_weights=True, mode='min')
    
    # Training on ROI data
    batch_size = 4
    steps_train = X_train_roi.shape[0] // batch_size
    steps_val = X_val_roi.shape[0] // batch_size
    
    history = model.fit(
        data_generator(X_train_roi, y_train_roi, batch_size, augment, num_outputs=5, label_smoothing=0.05),
        validation_data=data_generator(X_val_roi, y_val_roi, batch_size, None, num_outputs=5, label_smoothing=0.0),
        steps_per_epoch=steps_train,
        validation_steps=steps_val,
        epochs=80,
        callbacks=[checkpoint, reduce_lr, early_stop],
        verbose=1
    )
    
    print(f"✓ Training completed")
    
    # Visualizations
    print("\nGenerating visualizations...")
    plot_training_history(history, model_name, save_dir)
    plot_sample_predictions_with_cdr(model, X_test_roi, y_test_full, roi_coords_test,
                                     model_name, num_samples=8, save_dir=save_dir)
    
    return model, history, param_count

def save_segmentation_masks(X_test_roi, y_test_full, y_pred_labels_roi,
                            roi_coords_test, save_dir='results/predictions'):
    """Save all test predictions (masks only) with visible pixel values — ROI-aware"""
    os.makedirs(save_dir, exist_ok=True)
    
    print(f"\nSaving all {len(X_test_roi)} test predictions to {save_dir}...")
    
    for i in range(len(X_test_roi)):
        h, w = y_test_full[i].shape
        
        # Map ROI prediction back to full image
        pred_full = map_roi_prediction_to_full(y_pred_labels_roi[i], roi_coords_test[i], full_size=(h, w))
        
        # Process Predicted Mask (0, 1, 2)
        visible_pred = np.zeros((h, w), dtype=np.uint8)
        visible_pred[pred_full == 1] = 127  # Disc
        visible_pred[pred_full == 2] = 255  # Cup
        
        # Process Ground Truth Mask
        gt_mask = y_test_full[i].astype(np.uint8)
        visible_gt = np.zeros_like(gt_mask)
        visible_gt[gt_mask == 1] = 127  # Disc
        visible_gt[gt_mask == 2] = 255  # Cup
        
        # Combine side by side (GT left, Pred right)
        combined = np.hstack((visible_gt, visible_pred))
        
        # Save as PNG
        Image.fromarray(combined).save(f"{save_dir}/test_{i+1:04d}_comparison.png")
            
        if (i + 1) % 50 == 0:
            print(f"  Processed {i+1}/{len(X_test_roi)}")
            
    print(f"✓ Saved comparison masks to {save_dir}")

def evaluate_model(model, X_test_roi, y_test_roi, y_test_full, roi_coords_test,
                   model_name, run_mc_dropout=True, save_predictions=True):
    """Evaluate model with glaucoma progression analysis — ROI-aware"""
    print(f"\n{'='*80}")
    print(f"EVALUATION: {model_name}")
    print(f"{'='*80}")
    
    # --- ROI-level metrics (what the model actually sees) ---
    y_test_roi_cat = np.array([to_categorical(mask, num_classes=3) for mask in y_test_roi])
    
    y_pred_raw = model.predict(X_test_roi, verbose=0, batch_size=4)
    y_pred = y_pred_raw[0] if isinstance(y_pred_raw, (list, tuple)) else y_pred_raw
    y_pred_labels_roi = np.argmax(y_pred, axis=-1)
    
    # --- Map predictions back to full image for CDR / progression analysis ---
    y_pred_labels_full = []
    for i in range(len(X_test_roi)):
        h, w = y_test_full[i].shape
        pred_full = map_roi_prediction_to_full(y_pred_labels_roi[i], roi_coords_test[i], full_size=(h, w))
        y_pred_labels_full.append(pred_full)
    y_pred_labels_full = np.array(y_pred_labels_full)
    
    if save_predictions:
        save_segmentation_masks(X_test_roi, y_test_full, y_pred_labels_roi,
                                roi_coords_test, save_dir=f'results/{model_name}_all_preds')
    
    # Confusion matrices (on ROI crops — where the model is evaluated)
    plot_confusion_matrices(y_test_roi_cat, y_pred, model_name, save_dir='results')
    
    # Classification metrics on ROI
    y_true_labels = np.argmax(y_test_roi_cat, axis=-1).flatten()
    y_pred_labels_flat = y_pred_labels_roi.flatten()
    
    precision = precision_score(y_true_labels, y_pred_labels_flat, average=None, zero_division=0)
    recall = recall_score(y_true_labels, y_pred_labels_flat, average=None, zero_division=0)
    f1 = f1_score(y_true_labels, y_pred_labels_flat, average=None, zero_division=0)
    
    print(f"\nPrecision, Recall, F1 Score per class (ROI-level):")
    class_names = ["Background", "Disc", "Cup"]
    for idx, cname in enumerate(class_names):
        print(f"  {cname}: Precision={precision[idx]:.4f}, Recall={recall[idx]:.4f}, F1={f1[idx]:.4f}")
    
    print(f"\nMacro-averaged metrics:")
    print(f"  Precision: {np.mean(precision):.4f}")
    print(f"  Recall: {np.mean(recall):.4f}")
    print(f"  F1 Score: {np.mean(f1):.4f}")
    
    # Per-class Dice and IoU (on ROI)
    results = {'standard': {}}
    for cidx, cname in enumerate(class_names):
        y_true_c = (np.argmax(y_test_roi_cat, axis=-1) == cidx).astype(np.float32)
        y_pred_c = (y_pred_labels_roi == cidx).astype(np.float32)
        
        intersection = np.sum(y_true_c * y_pred_c)
        dice = (2. * intersection + 1e-7) / (np.sum(y_true_c) + np.sum(y_pred_c) + 1e-7)
        union = np.sum(y_true_c) + np.sum(y_pred_c) - intersection
        iou = (intersection + 1e-7) / (union + 1e-7)
        
        results['standard'][cname] = {'dice': dice, 'iou': iou}
        print(f"  {cname}: Dice={dice:.4f}, IoU={iou:.4f}")
    
    # Glaucoma Progression Analysis (on full-image mapped predictions)
    print(f"\n{'='*80}")
    print(f"GLAUCOMA PROGRESSION ANALYSIS (Using Area-based CDR on full-image mapped predictions)")
    print(f"{'='*80}")
    
    df_progression = analyze_glaucoma_progression(y_test_full, y_pred_labels_full, cdr_method='area_sqrt')
    
    # CDR Statistics
    print(f"\n{'-'*80}")
    print(f"CDR Statistics:")
    print(f"{'-'*80}")
    print(f"  Mean GT CDR:   {df_progression['GT_avgCDR'].mean():.4f} ± {df_progression['GT_avgCDR'].std():.4f}")
    print(f"  Mean Pred CDR: {df_progression['Pred_avgCDR'].mean():.4f} ± {df_progression['Pred_avgCDR'].std():.4f}")
    print(f"  Mean CDR Error: {df_progression['CDR_Error'].mean():.4f} ± {df_progression['CDR_Error'].std():.4f}")
    
    # Calculate progression accuracy
    accuracy_results = calculate_progression_accuracy(df_progression)
    
    # Overall Accuracy
    print(f"\n{'='*80}")
    print(f"PROGRESSION CLASSIFICATION ACCURACY")
    print(f"{'='*80}")
    print(f"\nOverall Accuracy: {accuracy_results['overall']['accuracy']:.2f}%")
    print(f"  - Correctly Classified: {accuracy_results['overall']['correct']}/{accuracy_results['overall']['total']} samples")
    print(f"  - Incorrectly Classified: {accuracy_results['overall']['total'] - accuracy_results['overall']['correct']}/{accuracy_results['overall']['total']} samples")
    
    # Per-Class Results
    print(f"\n{'-'*80}")
    print(f"Per-Class Results:")
    print(f"{'-'*80}")
    print(f"{'Severity':<12} {'GT Count':<12} {'Pred Count':<12} {'Correct':<12} {'Accuracy':<12}")
    print(f"{'-'*80}")
    
    for severity in ['Normal', 'Suspect', 'Moderate', 'Critical']:
        stats = accuracy_results['per_class'][severity]
        print(f"{severity:<12} {stats['gt_count']:<12} {stats['pred_count']:<12} "
              f"{stats['correct']:<12} {stats['accuracy']:<12.2f}%")
    
    print(f"\n{'='*80}")
    print(f"INTERPRETATION EXAMPLE:")
    print(f"{'='*80}")
    normal_stats = accuracy_results['per_class']['Normal']
    print(f"  - GT says 'Normal' for {normal_stats['gt_count']} images")
    print(f"  - Model says 'Normal' for {normal_stats['pred_count']} images")
    print(f"  - Model correctly predicts {normal_stats['correct']} as 'Normal'")
    print(f"  - Accuracy for Normal class: {normal_stats['correct']}/{normal_stats['gt_count']} = {normal_stats['accuracy']:.1f}%")
    
    # Manual Review Recommendations
    print(f"\n{'='*80}")
    print(f"MANUAL REVIEW RECOMMENDATIONS")
    print(f"{'='*80}")
    print(f"\nSamples Requiring Manual Review: {accuracy_results['manual_review']['count']}/{accuracy_results['overall']['total']} "
          f"({accuracy_results['manual_review']['percentage']:.1f}%)")
    print(f"\nCriteria for Manual Review:")
    print(f"  1. All Critical cases (high-risk, requires expert verification)")
    print(f"  2. Classification mismatches (GT ≠ Predicted severity)")
    print(f"\nReason: Critical cases need expert confirmation, and mismatches may")
    print(f"indicate borderline cases or segmentation issues requiring review.")
    
    # Breakdown of manual review cases
    review_df = df_progression[df_progression['Manual_Review_Needed'] == True]
    critical_cases = len(review_df[review_df['GT_Severity'] == 'Critical'])
    mismatch_cases = len(review_df[review_df['Severity_Match'] == False])
    overlap = len(review_df[(review_df['GT_Severity'] == 'Critical') & (review_df['Severity_Match'] == False)])
    
    print(f"\nBreakdown:")
    print(f"  - Critical cases: {critical_cases} samples")
    print(f"  - Classification mismatches: {mismatch_cases} samples")
    print(f"  - Overlap (Critical + Mismatch): {overlap} samples")
    
    # Save progression data
    df_progression.to_csv('results/glaucoma_progression_analysis.csv', index=False)
    print(f"\n✓ Saved: results/glaucoma_progression_analysis.csv")
    
    # Plot CDR analysis
    plot_cdr_distribution(df_progression, save_dir='results')
    
    results['glaucoma'] = {
        'mean_cdr_error': df_progression['CDR_Error'].mean(),
        'median_cdr_error': df_progression['CDR_Error'].median(),
        'classification_accuracy': accuracy_results['overall']['accuracy'] / 100,
        'df_progression': df_progression,
        'accuracy_breakdown': accuracy_results
    }
    
    # MC Dropout (on ROI data)
    if run_mc_dropout:
        print(f"\n{'='*80}")
        print(f"MC DROPOUT UNCERTAINTY ESTIMATION")
        print(f"{'='*80}")
        mean_pred, std_pred = mc_dropout_predict(model, X_test_roi[:100], num_samples=15, verbose=True)
        results['mc_dropout'] = {}
        for cidx, cname in enumerate(class_names):
            mean_std = np.mean(std_pred[:, :, :, cidx])
            results['mc_dropout'][cname] = {'mean_uncertainty': mean_std}
            print(f"  {cname} uncertainty: {mean_std:.4f}")
    
    return results

# ============================================================================
# MAIN EXECUTION
# ============================================================================

if __name__ == "__main__":
    # Setup
    gpu_available = configure_gpu()
    root_dir = "/kaggle/input/datasets/arnavpal66/refuge/REFUGE"
    train_aug = setup_augmentations()
    save_dir = "results"
    os.makedirs(save_dir, exist_ok=True)
    
    print(f"\n{'='*100}")
    print(f"{'V2+DS: LABEL SMOOTHING + DEEP SUPERVISION + HIGH-RES ROI':^100s}")
    print(f"{'='*100}")
    print(f"\nModel Architecture:")
    print(f"  - Base: MobileNetV2 Encoder + Deeper Decoder")
    print(f"  - Triple Attention: MSCA + LBFR + PPM (12 modules total)")
    print(f"  - Loss: Focal + Enhanced IoU (Combined)")
    print(f"  - Uncertainty: MC Dropout (15 forward passes)")
    print(f"  - Deep Supervision: Enabled (4 auxiliary heads)")
    print(f"  - Label Smoothing: 0.05")
    print(f"\nROI Extraction:")
    print(f"  - Automatically crops around the optic disc region from GT masks")
    print(f"  - Padding factor: 1.5× (50% margin around disc bounding box)")
    print(f"  - ROI resized to 512×512 → model sees zoomed-in disc/cup detail")
    print(f"  - Predictions mapped back to full image for CDR analysis")
    print(f"\nGlaucoma Severity Classification:")
    print(f"  - Normal:   CDR < 0.3  (Green)")
    print(f"  - Suspect:  0.3 ≤ CDR < 0.6  (Amber)")
    print(f"  - Moderate: 0.6 ≤ CDR < 0.8  (Orange)")
    print(f"  - Critical: CDR ≥ 0.8  (Red)")
    print(f"  CDR Method: Area-based (sqrt of area ratio) - Robust & Clinically Relevant")
    print(f"\nManual Review: Recommended for Critical cases and classification mismatches")
    
    # Load data with HIGH-RES ROI extraction
    # KEY FIX: loads at original resolution (~2000x2000), crops ROI, resizes to 512x512
    # This avoids the V1 bug of cropping from already-downsampled 512x512 images
    print(f"\n{'='*80}")
    print(f"HIGH-RES ROI DATA LOADING")
    print(f"{'='*80}")
    print(f"  Loading at original resolution, extracting ROI, resizing to 512x512")
    print(f"  Padding factor: 1.2x (20% margin around disc)")
    
    all_roi_images, all_roi_masks, all_full_masks = load_all_data_with_highres_roi(root_dir)
    
    # Split: 600 train, 200 val, 400 test (same random_state=42 as original)
    X_temp, X_test_roi, y_temp_roi, y_test_roi, temp_full, y_test_full = train_test_split(
        all_roi_images, all_roi_masks, all_full_masks, test_size=400, random_state=42
    )
    X_train_roi, X_val_roi, y_train_roi, y_val_roi, train_full, val_full = train_test_split(
        X_temp, y_temp_roi, temp_full, test_size=200, random_state=42
    )
    
    del all_roi_images, all_roi_masks, all_full_masks, X_temp, y_temp_roi, temp_full
    gc.collect()
    
    # Create dummy roi_coords (CDR computed on ROI directly in high-res mode)
    roi_coords_test = [(0, 0, 512, 512)] * len(X_test_roi)
    
    print(f"\n  Split - Train: {X_train_roi.shape[0]}, Val: {X_val_roi.shape[0]}, Test: {X_test_roi.shape[0]}")
    print(f"  ROI shape: {X_train_roi.shape[1:]} per image")
    
        # Train model on ROI data
    model, history, params = train_model(
        X_train_roi, y_train_roi, X_val_roi, y_val_roi,
        X_test_roi, y_test_full, roi_coords_test,
        "V2_LabelSmoothing_DeepSupervision",
        augment=train_aug, save_dir=save_dir
    )
    
    # Evaluate with ROI-aware glaucoma analysis
    results = evaluate_model(
        model, X_test_roi, y_test_roi, y_test_full, roi_coords_test,
        "V2_LabelSmoothing_DeepSupervision",
        run_mc_dropout=True, save_predictions=True
    )
    
    print(f"\n{'='*100}")
    print(f"{'TRAINING AND EVALUATION COMPLETED!':^100s}")
    print(f"{'='*100}")
    print(f"\nModel: V2+DS - Label Smoothing + Deep Supervision + High-Res ROI")
    print(f"Parameters: {params:,}")
    print(f"ROI Extraction: Padding=1.2x, Size=(512, 512)")
    print(f"Results saved in: {save_dir}/")
    print(f"\nGenerated Files:")
    print(f"  - Training history: {save_dir}/V5_OrigConfig_HighResROI_history.png")
    print(f"  - Predictions with CDR: {save_dir}/V5_OrigConfig_HighResROI_predictions_cdr.png")
    print(f"  - CDR Analysis: {save_dir}/cdr_analysis.png")
    print(f"  - Progression CSV: {save_dir}/glaucoma_progression_analysis.csv")
    print(f"  - Confusion Matrices: {save_dir}/V5_OrigConfig_HighResROI_confusion_matrices.png")
    print(f"\n{'='*100}\n")
# Out:
# 2026-03-22 20:57:16.067291: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774213036.238389      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774213036.287471      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774213036.684928      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774213036.684969      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774213036.684972      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774213036.684974      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Configuring GPU settings...
# ✓ GPU configured: 1 device(s) available
#
# ====================================================================================================
#                       V2+DS: LABEL SMOOTHING + DEEP SUPERVISION + HIGH-RES ROI
# ====================================================================================================
#
# Model Architecture:
#   - Base: MobileNetV2 Encoder + Deeper Decoder
#   - Triple Attention: MSCA + LBFR + PPM (12 modules total)
#   - Loss: Focal + Enhanced IoU (Combined)
#   - Uncertainty: MC Dropout (15 forward passes)
#   - Deep Supervision: Enabled (4 auxiliary heads)
#   - Label Smoothing: 0.05
#
# ROI Extraction:
#   - Automatically crops around the optic disc region from GT masks
#   - Padding factor: 1.5× (50% margin around disc bounding box)
#   - ROI resized to 512×512 → model sees zoomed-in disc/cup detail
#   - Predictions mapped back to full image for CDR analysis
#
# Glaucoma Severity Classification:
#   - Normal:   CDR < 0.3  (Green)
#   - Suspect:  0.3 ≤ CDR < 0.6  (Amber)
#   - Moderate: 0.6 ≤ CDR < 0.8  (Orange)
#   - Critical: CDR ≥ 0.8  (Red)
#   CDR Method: Area-based (sqrt of area ratio) - Robust & Clinically Relevant
#
# Manual Review: Recommended for Critical cases and classification mismatches
#
# ================================================================================
# HIGH-RES ROI DATA LOADING
# ================================================================================
#   Loading at original resolution, extracting ROI, resizing to 512x512
#   Padding factor: 1.2x (20% margin around disc)
#   train: 400 samples (original resolution -> ROI extracted)
#   val: 400 samples (original resolution -> ROI extracted)
#   test: 400 samples (original resolution -> ROI extracted)
#
#   Split - Train: 600, Val: 200, Test: 400
#   ROI shape: (512, 512, 3) per image
#
# ================================================================================
# TRAINING: V2_LabelSmoothing_DeepSupervision
# ================================================================================
#   Architecture: Deeper Decoder + MSCA + LBFR + PPM + Focal-EIoU + MC Dropout
#   Loss: Focal + Enhanced IoU (Combined) + Deep Supervision
#   Label Smoothing: 0.05
#   ROI Extraction: ENABLED (training on disc-centered crops)
# I0000 00:00:1774213201.307248      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15511 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# Model Configuration:
#   Total Parameters: 47,634,519
#   Dropout Layers: 5
#   Deep Supervision Heads: 4
#   Triple Attention Modules: MSCA + LBFR + PPM per decoder block
#   Total Attention Blocks: 12 (4 MSCA + 4 LBFR + 4 PPM)
# Epoch 1/80
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1774213282.458599      73 service.cc:152] XLA service 0x7b9be4003430 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1774213282.458642      73 service.cc:160]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1774213301.889443      73 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-03-22 21:02:00.841052: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-22 21:02:01.097808: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-22 21:02:02.726512: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-22 21:02:02.963363: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-22 21:02:18.566524: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-22 21:02:18.803890: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1774213428.574309      73 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - loss: 2.0742 - main_output_accuracy: 0.7299 - main_output_dice_class_0: 0.8135 - main_output_dice_class_1: 0.6844 - main_output_dice_class_2: 0.5694 - main_output_dice_coef_multiclass: 0.6305 - main_output_iou_class_0: 0.7174 - main_output_iou_class_1: 0.5511 - main_output_iou_class_2: 0.4355 - main_output_iou_coef_multiclass: 0.4806 - main_output_loss: 0.8823 - up_sampling2d_1_loss: 0.9379 - up_sampling2d_2_loss: 0.8228 - up_sampling2d_3_loss: 0.8915 - up_sampling2d_loss: 0.8027
# 2026-03-22 21:05:13.446979: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-22 21:05:13.702862: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Epoch 1: val_loss improved from inf to 28.18825, saving model to results/V2_LabelSmoothing_DeepSupervision.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 336s 701ms/step - loss: 2.0706 - main_output_accuracy: 0.7306 - main_output_dice_class_0: 0.8141 - main_output_dice_class_1: 0.6852 - main_output_dice_class_2: 0.5704 - main_output_dice_coef_multiclass: 0.6313 - main_output_iou_class_0: 0.7182 - main_output_iou_class_1: 0.5519 - main_output_iou_class_2: 0.4366 - main_output_iou_coef_multiclass: 0.4814 - main_output_loss: 0.8807 - up_sampling2d_1_loss: 0.9359 - up_sampling2d_2_loss: 0.8214 - up_sampling2d_3_loss: 0.8900 - up_sampling2d_loss: 0.8015 - val_loss: 28.1883 - val_main_output_accuracy: 0.3107 - val_main_output_dice_class_0: 0.5053 - val_main_output_dice_class_1: 0.0012 - val_main_output_dice_class_2: 0.0037 - val_main_output_dice_coef_multiclass: 0.3069 - val_main_output_iou_class_0: 0.3382 - val_main_output_iou_class_1: 6.1862e-04 - val_main_output_iou_class_2: 0.0019 - val_main_output_iou_coef_multiclass: 0.1814 - val_main_output_loss: 11.0272 - val_up_sampling2d_1_loss: 12.0844 - val_up_sampling2d_2_loss: 15.6523 - val_up_sampling2d_3_loss: 12.1882 - val_up_sampling2d_loss: 1.7579 - learning_rate: 2.0000e-04
# Epoch 2/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - loss: 1.0814 - main_output_accuracy: 0.9129 - main_output_dice_class_0: 0.9540 - main_output_dice_class_1: 0.8788 - main_output_dice_class_2: 0.8368 - main_output_dice_coef_multiclass: 0.8398 - main_output_iou_class_0: 0.9122 - main_output_iou_class_1: 0.7847 - main_output_iou_class_2: 0.7213 - main_output_iou_coef_multiclass: 0.7241 - main_output_loss: 0.4585 - up_sampling2d_1_loss: 0.4418 - up_sampling2d_2_loss: 0.4458 - up_sampling2d_3_loss: 0.4638 - up_sampling2d_loss: 0.4612
# Epoch 2: val_loss improved from 28.18825 to 18.30412, saving model to results/V2_LabelSmoothing_DeepSupervision.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 75s 498ms/step - loss: 1.0812 - main_output_accuracy: 0.9130 - main_output_dice_class_0: 0.9540 - main_output_dice_class_1: 0.8788 - main_output_dice_class_2: 0.8368 - main_output_dice_coef_multiclass: 0.8399 - main_output_iou_class_0: 0.9122 - main_output_iou_class_1: 0.7848 - main_output_iou_class_2: 0.7213 - main_output_iou_coef_multiclass: 0.7241 - main_output_loss: 0.4584 - up_sampling2d_1_loss: 0.4417 - up_sampling2d_2_loss: 0.4457 - up_sampling2d_3_loss: 0.4638 - up_sampling2d_loss: 0.4610 - val_loss: 18.3041 - val_main_output_accuracy: 0.4916 - val_main_output_dice_class_0: 0.7846 - val_main_output_dice_class_1: 0.1157 - val_main_output_dice_class_2: 0.3703 - val_main_output_dice_coef_multiclass: 0.4873 - val_main_output_iou_class_0: 0.6468 - val_main_output_iou_class_1: 0.0625 - val_main_output_iou_class_2: 0.2292 - val_main_output_iou_coef_multiclass: 0.3231 - val_main_output_loss: 8.6236 - val_up_sampling2d_1_loss: 4.4954 - val_up_sampling2d_2_loss: 7.7569 - val_up_sampling2d_3_loss: 9.0053 - val_up_sampling2d_loss: 1.4046 - learning_rate: 2.0000e-04
# Epoch 3/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - loss: 0.9745 - main_output_accuracy: 0.9240 - main_output_dice_class_0: 0.9601 - main_output_dice_class_1: 0.8938 - main_output_dice_class_2: 0.8571 - main_output_dice_coef_multiclass: 0.8554 - main_output_iou_class_0: 0.9235 - main_output_iou_class_1: 0.8088 - main_output_iou_class_2: 0.7519 - main_output_iou_coef_multiclass: 0.7475 - main_output_loss: 0.4149 - up_sampling2d_1_loss: 0.3994 - up_sampling2d_2_loss: 0.4022 - up_sampling2d_3_loss: 0.4151 - up_sampling2d_loss: 0.4086
# Epoch 3: val_loss improved from 18.30412 to 16.17125, saving model to results/V2_LabelSmoothing_DeepSupervision.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 74s 496ms/step - loss: 0.9745 - main_output_accuracy: 0.9240 - main_output_dice_class_0: 0.9601 - main_output_dice_class_1: 0.8938 - main_output_dice_class_2: 0.8571 - main_output_dice_coef_multiclass: 0.8554 - main_output_iou_class_0: 0.9235 - main_output_iou_class_1: 0.8088 - main_output_iou_class_2: 0.7519 - main_output_iou_coef_multiclass: 0.7475 - main_output_loss: 0.4149 - up_sampling2d_1_loss: 0.3994 - up_sampling2d_2_loss: 0.4022 - up_sampling2d_3_loss: 0.4151 - up_sampling2d_loss: 0.4086 - val_loss: 16.1713 - val_main_output_accuracy: 0.4310 - val_main_output_dice_class_0: 0.5847 - val_main_output_dice_class_1: 0.3155 - val_main_output_dice_class_2: 0.3568 - val_main_output_dice_coef_multiclass: 0.4196 - val_main_output_iou_class_0: 0.4144 - val_main_output_iou_class_1: 0.1899 - val_main_output_iou_class_2: 0.2192 - val_main_output_iou_coef_multiclass: 0.2668 - val_main_output_loss: 7.2746 - val_up_sampling2d_1_loss: 5.0295 - val_up_sampling2d_2_loss: 6.7542 - val_up_sampling2d_3_loss: 7.7535 - val_up_sampling2d_loss: 3.0837 - learning_rate: 2.0000e-04
# Epoch 4/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - loss: 0.9698 - main_output_accuracy: 0.9229 - main_output_dice_class_0: 0.9583 - main_output_dice_class_1: 0.8922 - main_output_dice_class_2: 0.8598 - main_output_dice_coef_multiclass: 0.8548 - main_output_iou_class_0: 0.9201 - main_output_iou_class_1: 0.8062 - main_output_iou_class_2: 0.7564 - main_output_iou_coef_multiclass: 0.7466 - main_output_loss: 0.4137 - up_sampling2d_1_loss: 0.3971 - up_sampling2d_2_loss: 0.4016 - up_sampling2d_3_loss: 0.4110 - up_sampling2d_loss: 0.4043
# Epoch 4: val_loss improved from 16.17125 to 3.55830, saving model to results/V2_LabelSmoothing_DeepSupervision.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 74s 497ms/step - loss: 0.9697 - main_output_accuracy: 0.9229 - main_output_dice_class_0: 0.9583 - main_output_dice_class_1: 0.8922 - main_output_dice_class_2: 0.8598 - main_output_dice_coef_multiclass: 0.8548 - main_output_iou_class_0: 0.9201 - main_output_iou_class_1: 0.8062 - main_output_iou_class_2: 0.7564 - main_output_iou_coef_multiclass: 0.7466 - main_output_loss: 0.4137 - up_sampling2d_1_loss: 0.3971 - up_sampling2d_2_loss: 0.4016 - up_sampling2d_3_loss: 0.4110 - up_sampling2d_loss: 0.4042 - val_loss: 3.5583 - val_main_output_accuracy: 0.7317 - val_main_output_dice_class_0: 0.8208 - val_main_output_dice_class_1: 0.6625 - val_main_output_dice_class_2: 0.6498 - val_main_output_dice_coef_multiclass: 0.7070 - val_main_output_iou_class_0: 0.6979 - val_main_output_iou_class_1: 0.4989 - val_main_output_iou_class_2: 0.4870 - val_main_output_iou_coef_multiclass: 0.5489 - val_main_output_loss: 1.7238 - val_up_sampling2d_1_loss: 1.0037 - val_up_sampling2d_2_loss: 1.2920 - val_up_sampling2d_3_loss: 1.6789 - val_up_sampling2d_loss: 0.7855 - learning_rate: 2.0000e-04
# Epoch 5/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - loss: 0.9183 - main_output_accuracy: 0.9294 - main_output_dice_class_0: 0.9635 - main_output_dice_class_1: 0.9002 - main_output_dice_class_2: 0.8673 - main_output_dice_coef_multiclass: 0.8639 - main_output_iou_class_0: 0.9297 - main_output_iou_class_1: 0.8191 - main_output_iou_class_2: 0.7681 - main_output_iou_coef_multiclass: 0.7605 - main_output_loss: 0.3907 - up_sampling2d_1_loss: 0.3763 - up_sampling2d_2_loss: 0.3817 - up_sampling2d_3_loss: 0.3895 - up_sampling2d_loss: 0.3833
# Epoch 5: val_loss did not improve from 3.55830
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 470ms/step - loss: 0.9183 - main_output_accuracy: 0.9294 - main_output_dice_class_0: 0.9635 - main_output_dice_class_1: 0.9002 - main_output_dice_class_2: 0.8673 - main_output_dice_coef_multiclass: 0.8639 - main_output_iou_class_0: 0.9297 - main_output_iou_class_1: 0.8191 - main_output_iou_class_2: 0.7681 - main_output_iou_coef_multiclass: 0.7605 - main_output_loss: 0.3907 - up_sampling2d_1_loss: 0.3763 - up_sampling2d_2_loss: 0.3817 - up_sampling2d_3_loss: 0.3895 - up_sampling2d_loss: 0.3833 - val_loss: 4.0969 - val_main_output_accuracy: 0.7412 - val_main_output_dice_class_0: 0.8265 - val_main_output_dice_class_1: 0.6839 - val_main_output_dice_class_2: 0.6463 - val_main_output_dice_coef_multiclass: 0.7300 - val_main_output_iou_class_0: 0.7051 - val_main_output_iou_class_1: 0.5230 - val_main_output_iou_class_2: 0.4847 - val_main_output_iou_coef_multiclass: 0.5770 - val_main_output_loss: 1.9128 - val_up_sampling2d_1_loss: 1.2066 - val_up_sampling2d_2_loss: 1.6892 - val_up_sampling2d_3_loss: 1.8657 - val_up_sampling2d_loss: 0.8408 - learning_rate: 2.0000e-04
# Epoch 6/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - loss: 0.8966 - main_output_accuracy: 0.9304 - main_output_dice_class_0: 0.9629 - main_output_dice_class_1: 0.9023 - main_output_dice_class_2: 0.8714 - main_output_dice_coef_multiclass: 0.8669 - main_output_iou_class_0: 0.9287 - main_output_iou_class_1: 0.8226 - main_output_iou_class_2: 0.7735 - main_output_iou_coef_multiclass: 0.7652 - main_output_loss: 0.3819 - up_sampling2d_1_loss: 0.3682 - up_sampling2d_2_loss: 0.3725 - up_sampling2d_3_loss: 0.3792 - up_sampling2d_loss: 0.3741
# Epoch 6: val_loss improved from 3.55830 to 2.94830, saving model to results/V2_LabelSmoothing_DeepSupervision.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 75s 497ms/step - loss: 0.8965 - main_output_accuracy: 0.9304 - main_output_dice_class_0: 0.9629 - main_output_dice_class_1: 0.9023 - main_output_dice_class_2: 0.8714 - main_output_dice_coef_multiclass: 0.8669 - main_output_iou_class_0: 0.9287 - main_output_iou_class_1: 0.8226 - main_output_iou_class_2: 0.7735 - main_output_iou_coef_multiclass: 0.7652 - main_output_loss: 0.3819 - up_sampling2d_1_loss: 0.3682 - up_sampling2d_2_loss: 0.3725 - up_sampling2d_3_loss: 0.3792 - up_sampling2d_loss: 0.3741 - val_loss: 2.9483 - val_main_output_accuracy: 0.7927 - val_main_output_dice_class_0: 0.9004 - val_main_output_dice_class_1: 0.7270 - val_main_output_dice_class_2: 0.6305 - val_main_output_dice_coef_multiclass: 0.7574 - val_main_output_iou_class_0: 0.8206 - val_main_output_iou_class_1: 0.5766 - val_main_output_iou_class_2: 0.4668 - val_main_output_iou_coef_multiclass: 0.6126 - val_main_output_loss: 1.2725 - val_up_sampling2d_1_loss: 1.1171 - val_up_sampling2d_2_loss: 1.2341 - val_up_sampling2d_3_loss: 1.2839 - val_up_sampling2d_loss: 1.1003 - learning_rate: 2.0000e-04
# Epoch 7/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - loss: 0.9072 - main_output_accuracy: 0.9297 - main_output_dice_class_0: 0.9629 - main_output_dice_class_1: 0.9009 - main_output_dice_class_2: 0.8699 - main_output_dice_coef_multiclass: 0.8668 - main_output_iou_class_0: 0.9286 - main_output_iou_class_1: 0.8206 - main_output_iou_class_2: 0.7715 - main_output_iou_coef_multiclass: 0.7652 - main_output_loss: 0.3879 - up_sampling2d_1_loss: 0.3705 - up_sampling2d_2_loss: 0.3759 - up_sampling2d_3_loss: 0.3831 - up_sampling2d_loss: 0.3774
# Epoch 7: val_loss did not improve from 2.94830
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 469ms/step - loss: 0.9071 - main_output_accuracy: 0.9297 - main_output_dice_class_0: 0.9629 - main_output_dice_class_1: 0.9009 - main_output_dice_class_2: 0.8699 - main_output_dice_coef_multiclass: 0.8669 - main_output_iou_class_0: 0.9287 - main_output_iou_class_1: 0.8207 - main_output_iou_class_2: 0.7716 - main_output_iou_coef_multiclass: 0.7652 - main_output_loss: 0.3879 - up_sampling2d_1_loss: 0.3704 - up_sampling2d_2_loss: 0.3758 - up_sampling2d_3_loss: 0.3830 - up_sampling2d_loss: 0.3774 - val_loss: 4.7826 - val_main_output_accuracy: 0.7185 - val_main_output_dice_class_0: 0.9052 - val_main_output_dice_class_1: 0.5545 - val_main_output_dice_class_2: 0.5266 - val_main_output_dice_coef_multiclass: 0.6809 - val_main_output_iou_class_0: 0.8273 - val_main_output_iou_class_1: 0.3856 - val_main_output_iou_class_2: 0.3603 - val_main_output_iou_coef_multiclass: 0.5169 - val_main_output_loss: 2.2294 - val_up_sampling2d_1_loss: 1.4533 - val_up_sampling2d_2_loss: 1.8263 - val_up_sampling2d_3_loss: 2.2538 - val_up_sampling2d_loss: 1.1986 - learning_rate: 2.0000e-04
# Epoch 8/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - loss: 0.8775 - main_output_accuracy: 0.9326 - main_output_dice_class_0: 0.9650 - main_output_dice_class_1: 0.9045 - main_output_dice_class_2: 0.8751 - main_output_dice_coef_multiclass: 0.8709 - main_output_iou_class_0: 0.9324 - main_output_iou_class_1: 0.8263 - main_output_iou_class_2: 0.7794 - main_output_iou_coef_multiclass: 0.7715 - main_output_loss: 0.3743 - up_sampling2d_1_loss: 0.3591 - up_sampling2d_2_loss: 0.3647 - up_sampling2d_3_loss: 0.3713 - up_sampling2d_loss: 0.3636
# Epoch 8: val_loss improved from 2.94830 to 1.52002, saving model to results/V2_LabelSmoothing_DeepSupervision.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 74s 496ms/step - loss: 0.8775 - main_output_accuracy: 0.9326 - main_output_dice_class_0: 0.9650 - main_output_dice_class_1: 0.9045 - main_output_dice_class_2: 0.8751 - main_output_dice_coef_multiclass: 0.8709 - main_output_iou_class_0: 0.9324 - main_output_iou_class_1: 0.8263 - main_output_iou_class_2: 0.7794 - main_output_iou_coef_multiclass: 0.7715 - main_output_loss: 0.3743 - up_sampling2d_1_loss: 0.3590 - up_sampling2d_2_loss: 0.3647 - up_sampling2d_3_loss: 0.3713 - up_sampling2d_loss: 0.3636 - val_loss: 1.5200 - val_main_output_accuracy: 0.8814 - val_main_output_dice_class_0: 0.9281 - val_main_output_dice_class_1: 0.8457 - val_main_output_dice_class_2: 0.8070 - val_main_output_dice_coef_multiclass: 0.8695 - val_main_output_iou_class_0: 0.8663 - val_main_output_iou_class_1: 0.7344 - val_main_output_iou_class_2: 0.6808 - val_main_output_iou_coef_multiclass: 0.7699 - val_main_output_loss: 0.6617 - val_up_sampling2d_1_loss: 0.5894 - val_up_sampling2d_2_loss: 0.6247 - val_up_sampling2d_3_loss: 0.6606 - val_up_sampling2d_loss: 0.5462 - learning_rate: 2.0000e-04
# Epoch 9/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - loss: 0.8557 - main_output_accuracy: 0.9351 - main_output_dice_class_0: 0.9649 - main_output_dice_class_1: 0.9092 - main_output_dice_class_2: 0.8828 - main_output_dice_coef_multiclass: 0.8738 - main_output_iou_class_0: 0.9323 - main_output_iou_class_1: 0.8345 - main_output_iou_class_2: 0.7922 - main_output_iou_coef_multiclass: 0.7762 - main_output_loss: 0.3642 - up_sampling2d_1_loss: 0.3525 - up_sampling2d_2_loss: 0.3556 - up_sampling2d_3_loss: 0.3605 - up_sampling2d_loss: 0.3620
# Epoch 9: val_loss improved from 1.52002 to 1.04781, saving model to results/V2_LabelSmoothing_DeepSupervision.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 74s 496ms/step - loss: 0.8557 - main_output_accuracy: 0.9351 - main_output_dice_class_0: 0.9649 - main_output_dice_class_1: 0.9092 - main_output_dice_class_2: 0.8827 - main_output_dice_coef_multiclass: 0.8738 - main_output_iou_class_0: 0.9323 - main_output_iou_class_1: 0.8344 - main_output_iou_class_2: 0.7921 - main_output_iou_coef_multiclass: 0.7762 - main_output_loss: 0.3642 - up_sampling2d_1_loss: 0.3526 - up_sampling2d_2_loss: 0.3556 - up_sampling2d_3_loss: 0.3605 - up_sampling2d_loss: 0.3620 - val_loss: 1.0478 - val_main_output_accuracy: 0.9164 - val_main_output_dice_class_0: 0.9656 - val_main_output_dice_class_1: 0.8749 - val_main_output_dice_class_2: 0.8290 - val_main_output_dice_coef_multiclass: 0.8889 - val_main_output_iou_class_0: 0.9336 - val_main_output_iou_class_1: 0.7786 - val_main_output_iou_class_2: 0.7101 - val_main_output_iou_coef_multiclass: 0.8003 - val_main_output_loss: 0.4544 - val_up_sampling2d_1_loss: 0.3858 - val_up_sampling2d_2_loss: 0.4126 - val_up_sampling2d_3_loss: 0.4573 - val_up_sampling2d_loss: 0.4959 - learning_rate: 2.0000e-04
# Epoch 10/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - loss: 0.8378 - main_output_accuracy: 0.9372 - main_output_dice_class_0: 0.9680 - main_output_dice_class_1: 0.9111 - main_output_dice_class_2: 0.8796 - main_output_dice_coef_multiclass: 0.8774 - main_output_iou_class_0: 0.9380 - main_output_iou_class_1: 0.8374 - main_output_iou_class_2: 0.7866 - main_output_iou_coef_multiclass: 0.7817 - main_output_loss: 0.3569 - up_sampling2d_1_loss: 0.3456 - up_sampling2d_2_loss: 0.3480 - up_sampling2d_3_loss: 0.3531 - up_sampling2d_loss: 0.3521
# Epoch 10: val_loss did not improve from 1.04781
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 470ms/step - loss: 0.8378 - main_output_accuracy: 0.9372 - main_output_dice_class_0: 0.9680 - main_output_dice_class_1: 0.9111 - main_output_dice_class_2: 0.8796 - main_output_dice_coef_multiclass: 0.8774 - main_output_iou_class_0: 0.9380 - main_output_iou_class_1: 0.8374 - main_output_iou_class_2: 0.7867 - main_output_iou_coef_multiclass: 0.7817 - main_output_loss: 0.3568 - up_sampling2d_1_loss: 0.3455 - up_sampling2d_2_loss: 0.3480 - up_sampling2d_3_loss: 0.3531 - up_sampling2d_loss: 0.3521 - val_loss: 1.3158 - val_main_output_accuracy: 0.8954 - val_main_output_dice_class_0: 0.9483 - val_main_output_dice_class_1: 0.8515 - val_main_output_dice_class_2: 0.8166 - val_main_output_dice_coef_multiclass: 0.8661 - val_main_output_iou_class_0: 0.9018 - val_main_output_iou_class_1: 0.7430 - val_main_output_iou_class_2: 0.6943 - val_main_output_iou_coef_multiclass: 0.7645 - val_main_output_loss: 0.5863 - val_up_sampling2d_1_loss: 0.4650 - val_up_sampling2d_2_loss: 0.5322 - val_up_sampling2d_3_loss: 0.5625 - val_up_sampling2d_loss: 0.5272 - learning_rate: 2.0000e-04
# Epoch 11/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - loss: 0.8165 - main_output_accuracy: 0.9388 - main_output_dice_class_0: 0.9680 - main_output_dice_class_1: 0.9146 - main_output_dice_class_2: 0.8848 - main_output_dice_coef_multiclass: 0.8794 - main_output_iou_class_0: 0.9381 - main_output_iou_class_1: 0.8430 - main_output_iou_class_2: 0.7944 - main_output_iou_coef_multiclass: 0.7849 - main_output_loss: 0.3477 - up_sampling2d_1_loss: 0.3358 - up_sampling2d_2_loss: 0.3387 - up_sampling2d_3_loss: 0.3447 - up_sampling2d_loss: 0.3446
# Epoch 11: val_loss improved from 1.04781 to 0.94649, saving model to results/V2_LabelSmoothing_DeepSupervision.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 74s 496ms/step - loss: 0.8165 - main_output_accuracy: 0.9388 - main_output_dice_class_0: 0.9680 - main_output_dice_class_1: 0.9146 - main_output_dice_class_2: 0.8848 - main_output_dice_coef_multiclass: 0.8794 - main_output_iou_class_0: 0.9381 - main_output_iou_class_1: 0.8430 - main_output_iou_class_2: 0.7944 - main_output_iou_coef_multiclass: 0.7849 - main_output_loss: 0.3477 - up_sampling2d_1_loss: 0.3358 - up_sampling2d_2_loss: 0.3387 - up_sampling2d_3_loss: 0.3447 - up_sampling2d_loss: 0.3446 - val_loss: 0.9465 - val_main_output_accuracy: 0.9199 - val_main_output_dice_class_0: 0.9689 - val_main_output_dice_class_1: 0.8841 - val_main_output_dice_class_2: 0.8160 - val_main_output_dice_coef_multiclass: 0.8864 - val_main_output_iou_class_0: 0.9397 - val_main_output_iou_class_1: 0.7937 - val_main_output_iou_class_2: 0.6927 - val_main_output_iou_coef_multiclass: 0.7965 - val_main_output_loss: 0.3955 - val_up_sampling2d_1_loss: 0.3997 - val_up_sampling2d_2_loss: 0.3943 - val_up_sampling2d_3_loss: 0.4003 - val_up_sampling2d_loss: 0.4300 - learning_rate: 2.0000e-04
# Epoch 12/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - loss: 0.8296 - main_output_accuracy: 0.9382 - main_output_dice_class_0: 0.9679 - main_output_dice_class_1: 0.9119 - main_output_dice_class_2: 0.8838 - main_output_dice_coef_multiclass: 0.8789 - main_output_iou_class_0: 0.9379 - main_output_iou_class_1: 0.8387 - main_output_iou_class_2: 0.7929 - main_output_iou_coef_multiclass: 0.7841 - main_output_loss: 0.3532 - up_sampling2d_1_loss: 0.3422 - up_sampling2d_2_loss: 0.3451 - up_sampling2d_3_loss: 0.3495 - up_sampling2d_loss: 0.3477
# Epoch 12: val_loss did not improve from 0.94649
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 469ms/step - loss: 0.8295 - main_output_accuracy: 0.9382 - main_output_dice_class_0: 0.9679 - main_output_dice_class_1: 0.9119 - main_output_dice_class_2: 0.8838 - main_output_dice_coef_multiclass: 0.8789 - main_output_iou_class_0: 0.9379 - main_output_iou_class_1: 0.8387 - main_output_iou_class_2: 0.7929 - main_output_iou_coef_multiclass: 0.7841 - main_output_loss: 0.3532 - up_sampling2d_1_loss: 0.3422 - up_sampling2d_2_loss: 0.3451 - up_sampling2d_3_loss: 0.3494 - up_sampling2d_loss: 0.3477 - val_loss: 1.0093 - val_main_output_accuracy: 0.9209 - val_main_output_dice_class_0: 0.9688 - val_main_output_dice_class_1: 0.8831 - val_main_output_dice_class_2: 0.8339 - val_main_output_dice_coef_multiclass: 0.9038 - val_main_output_iou_class_0: 0.9397 - val_main_output_iou_class_1: 0.7926 - val_main_output_iou_class_2: 0.7183 - val_main_output_iou_coef_multiclass: 0.8250 - val_main_output_loss: 0.4359 - val_up_sampling2d_1_loss: 0.3841 - val_up_sampling2d_2_loss: 0.4125 - val_up_sampling2d_3_loss: 0.4348 - val_up_sampling2d_loss: 0.4289 - learning_rate: 2.0000e-04
# Epoch 13/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - loss: 0.7657 - main_output_accuracy: 0.9445 - main_output_dice_class_0: 0.9699 - main_output_dice_class_1: 0.9224 - main_output_dice_class_2: 0.8959 - main_output_dice_coef_multiclass: 0.8881 - main_output_iou_class_0: 0.9417 - main_output_iou_class_1: 0.8563 - main_output_iou_class_2: 0.8123 - main_output_iou_coef_multiclass: 0.7987 - main_output_loss: 0.3265 - up_sampling2d_1_loss: 0.3152 - up_sampling2d_2_loss: 0.3175 - up_sampling2d_3_loss: 0.3225 - up_sampling2d_loss: 0.3234
# Epoch 13: val_loss did not improve from 0.94649
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 469ms/step - loss: 0.7658 - main_output_accuracy: 0.9445 - main_output_dice_class_0: 0.9699 - main_output_dice_class_1: 0.9224 - main_output_dice_class_2: 0.8959 - main_output_dice_coef_multiclass: 0.8880 - main_output_iou_class_0: 0.9417 - main_output_iou_class_1: 0.8562 - main_output_iou_class_2: 0.8123 - main_output_iou_coef_multiclass: 0.7987 - main_output_loss: 0.3265 - up_sampling2d_1_loss: 0.3153 - up_sampling2d_2_loss: 0.3175 - up_sampling2d_3_loss: 0.3226 - up_sampling2d_loss: 0.3235 - val_loss: 1.4097 - val_main_output_accuracy: 0.8947 - val_main_output_dice_class_0: 0.9696 - val_main_output_dice_class_1: 0.8305 - val_main_output_dice_class_2: 0.7663 - val_main_output_dice_coef_multiclass: 0.8737 - val_main_output_iou_class_0: 0.9410 - val_main_output_iou_class_1: 0.7130 - val_main_output_iou_class_2: 0.6248 - val_main_output_iou_coef_multiclass: 0.7766 - val_main_output_loss: 0.6319 - val_up_sampling2d_1_loss: 0.4812 - val_up_sampling2d_2_loss: 0.5557 - val_up_sampling2d_3_loss: 0.6208 - val_up_sampling2d_loss: 0.5539 - learning_rate: 2.0000e-04
# Epoch 14/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - loss: 0.8037 - main_output_accuracy: 0.9406 - main_output_dice_class_0: 0.9681 - main_output_dice_class_1: 0.9162 - main_output_dice_class_2: 0.8926 - main_output_dice_coef_multiclass: 0.8819 - main_output_iou_class_0: 0.9383 - main_output_iou_class_1: 0.8457 - main_output_iou_class_2: 0.8069 - main_output_iou_coef_multiclass: 0.7888 - main_output_loss: 0.3423 - up_sampling2d_1_loss: 0.3300 - up_sampling2d_2_loss: 0.3343 - up_sampling2d_3_loss: 0.3386 - up_sampling2d_loss: 0.3395
# Epoch 14: val_loss improved from 0.94649 to 0.86604, saving model to results/V2_LabelSmoothing_DeepSupervision.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 74s 495ms/step - loss: 0.8038 - main_output_accuracy: 0.9406 - main_output_dice_class_0: 0.9681 - main_output_dice_class_1: 0.9162 - main_output_dice_class_2: 0.8926 - main_output_dice_coef_multiclass: 0.8819 - main_output_iou_class_0: 0.9383 - main_output_iou_class_1: 0.8457 - main_output_iou_class_2: 0.8068 - main_output_iou_coef_multiclass: 0.7888 - main_output_loss: 0.3424 - up_sampling2d_1_loss: 0.3300 - up_sampling2d_2_loss: 0.3344 - up_sampling2d_3_loss: 0.3386 - up_sampling2d_loss: 0.3395 - val_loss: 0.8660 - val_main_output_accuracy: 0.9407 - val_main_output_dice_class_0: 0.9736 - val_main_output_dice_class_1: 0.9178 - val_main_output_dice_class_2: 0.8611 - val_main_output_dice_coef_multiclass: 0.9235 - val_main_output_iou_class_0: 0.9485 - val_main_output_iou_class_1: 0.8489 - val_main_output_iou_class_2: 0.7584 - val_main_output_iou_coef_multiclass: 0.8582 - val_main_output_loss: 0.3695 - val_up_sampling2d_1_loss: 0.3458 - val_up_sampling2d_2_loss: 0.3595 - val_up_sampling2d_3_loss: 0.3739 - val_up_sampling2d_loss: 0.3472 - learning_rate: 2.0000e-04
# Epoch 15/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - loss: 0.7979 - main_output_accuracy: 0.9416 - main_output_dice_class_0: 0.9689 - main_output_dice_class_1: 0.9170 - main_output_dice_class_2: 0.8950 - main_output_dice_coef_multiclass: 0.8839 - main_output_iou_class_0: 0.9398 - main_output_iou_class_1: 0.8472 - main_output_iou_class_2: 0.8112 - main_output_iou_coef_multiclass: 0.7921 - main_output_loss: 0.3392 - up_sampling2d_1_loss: 0.3293 - up_sampling2d_2_loss: 0.3323 - up_sampling2d_3_loss: 0.3355 - up_sampling2d_loss: 0.3397
# Epoch 15: val_loss improved from 0.86604 to 0.79756, saving model to results/V2_LabelSmoothing_DeepSupervision.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 74s 496ms/step - loss: 0.7979 - main_output_accuracy: 0.9416 - main_output_dice_class_0: 0.9689 - main_output_dice_class_1: 0.9170 - main_output_dice_class_2: 0.8950 - main_output_dice_coef_multiclass: 0.8839 - main_output_iou_class_0: 0.9398 - main_output_iou_class_1: 0.8472 - main_output_iou_class_2: 0.8112 - main_output_iou_coef_multiclass: 0.7921 - main_output_loss: 0.3392 - up_sampling2d_1_loss: 0.3294 - up_sampling2d_2_loss: 0.3323 - up_sampling2d_3_loss: 0.3355 - up_sampling2d_loss: 0.3397 - val_loss: 0.7976 - val_main_output_accuracy: 0.9389 - val_main_output_dice_class_0: 0.9691 - val_main_output_dice_class_1: 0.9131 - val_main_output_dice_class_2: 0.8835 - val_main_output_dice_coef_multiclass: 0.9220 - val_main_output_iou_class_0: 0.9401 - val_main_output_iou_class_1: 0.8406 - val_main_output_iou_class_2: 0.7924 - val_main_output_iou_coef_multiclass: 0.8554 - val_main_output_loss: 0.3404 - val_up_sampling2d_1_loss: 0.3326 - val_up_sampling2d_2_loss: 0.3244 - val_up_sampling2d_3_loss: 0.3392 - val_up_sampling2d_loss: 0.3376 - learning_rate: 2.0000e-04
# Epoch 16/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - loss: 0.7797 - main_output_accuracy: 0.9431 - main_output_dice_class_0: 0.9696 - main_output_dice_class_1: 0.9207 - main_output_dice_class_2: 0.8920 - main_output_dice_coef_multiclass: 0.8860 - main_output_iou_class_0: 0.9410 - main_output_iou_class_1: 0.8534 - main_output_iou_class_2: 0.8059 - main_output_iou_coef_multiclass: 0.7954 - main_output_loss: 0.3318 - up_sampling2d_1_loss: 0.3214 - up_sampling2d_2_loss: 0.3247 - up_sampling2d_3_loss: 0.3280 - up_sampling2d_loss: 0.3297
# Epoch 16: val_loss improved from 0.79756 to 0.77188, saving model to results/V2_LabelSmoothing_DeepSupervision.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 74s 496ms/step - loss: 0.7797 - main_output_accuracy: 0.9431 - main_output_dice_class_0: 0.9696 - main_output_dice_class_1: 0.9207 - main_output_dice_class_2: 0.8920 - main_output_dice_coef_multiclass: 0.8860 - main_output_iou_class_0: 0.9410 - main_output_iou_class_1: 0.8534 - main_output_iou_class_2: 0.8059 - main_output_iou_coef_multiclass: 0.7954 - main_output_loss: 0.3318 - up_sampling2d_1_loss: 0.3215 - up_sampling2d_2_loss: 0.3247 - up_sampling2d_3_loss: 0.3281 - up_sampling2d_loss: 0.3297 - val_loss: 0.7719 - val_main_output_accuracy: 0.9396 - val_main_output_dice_class_0: 0.9725 - val_main_output_dice_class_1: 0.9149 - val_main_output_dice_class_2: 0.8664 - val_main_output_dice_coef_multiclass: 0.9235 - val_main_output_iou_class_0: 0.9464 - val_main_output_iou_class_1: 0.8438 - val_main_output_iou_class_2: 0.7659 - val_main_output_iou_coef_multiclass: 0.8580 - val_main_output_loss: 0.3259 - val_up_sampling2d_1_loss: 0.3261 - val_up_sampling2d_2_loss: 0.3197 - val_up_sampling2d_3_loss: 0.3273 - val_up_sampling2d_loss: 0.3273 - learning_rate: 2.0000e-04
# Epoch 17/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - loss: 0.7952 - main_output_accuracy: 0.9414 - main_output_dice_class_0: 0.9689 - main_output_dice_class_1: 0.9186 - main_output_dice_class_2: 0.8898 - main_output_dice_coef_multiclass: 0.8845 - main_output_iou_class_0: 0.9397 - main_output_iou_class_1: 0.8499 - main_output_iou_class_2: 0.8026 - main_output_iou_coef_multiclass: 0.7930 - main_output_loss: 0.3382 - up_sampling2d_1_loss: 0.3285 - up_sampling2d_2_loss: 0.3306 - up_sampling2d_3_loss: 0.3340 - up_sampling2d_loss: 0.3408
# Epoch 17: val_loss improved from 0.77188 to 0.77017, saving model to results/V2_LabelSmoothing_DeepSupervision.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 74s 494ms/step - loss: 0.7952 - main_output_accuracy: 0.9414 - main_output_dice_class_0: 0.9689 - main_output_dice_class_1: 0.9186 - main_output_dice_class_2: 0.8898 - main_output_dice_coef_multiclass: 0.8845 - main_output_iou_class_0: 0.9397 - main_output_iou_class_1: 0.8499 - main_output_iou_class_2: 0.8026 - main_output_iou_coef_multiclass: 0.7930 - main_output_loss: 0.3382 - up_sampling2d_1_loss: 0.3284 - up_sampling2d_2_loss: 0.3306 - up_sampling2d_3_loss: 0.3340 - up_sampling2d_loss: 0.3407 - val_loss: 0.7702 - val_main_output_accuracy: 0.9400 - val_main_output_dice_class_0: 0.9728 - val_main_output_dice_class_1: 0.9149 - val_main_output_dice_class_2: 0.8733 - val_main_output_dice_coef_multiclass: 0.9187 - val_main_output_iou_class_0: 0.9470 - val_main_output_iou_class_1: 0.8438 - val_main_output_iou_class_2: 0.7776 - val_main_output_iou_coef_multiclass: 0.8499 - val_main_output_loss: 0.3262 - val_up_sampling2d_1_loss: 0.3141 - val_up_sampling2d_2_loss: 0.3174 - val_up_sampling2d_3_loss: 0.3267 - val_up_sampling2d_loss: 0.3474 - learning_rate: 2.0000e-04
# Epoch 18/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - loss: 0.7837 - main_output_accuracy: 0.9437 - main_output_dice_class_0: 0.9700 - main_output_dice_class_1: 0.9205 - main_output_dice_class_2: 0.8966 - main_output_dice_coef_multiclass: 0.8869 - main_output_iou_class_0: 0.9419 - main_output_iou_class_1: 0.8532 - main_output_iou_class_2: 0.8137 - main_output_iou_coef_multiclass: 0.7969 - main_output_loss: 0.3333 - up_sampling2d_1_loss: 0.3236 - up_sampling2d_2_loss: 0.3264 - up_sampling2d_3_loss: 0.3295 - up_sampling2d_loss: 0.3331
# Epoch 18: val_loss improved from 0.77017 to 0.73571, saving model to results/V2_LabelSmoothing_DeepSupervision.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 74s 496ms/step - loss: 0.7837 - main_output_accuracy: 0.9437 - main_output_dice_class_0: 0.9700 - main_output_dice_class_1: 0.9205 - main_output_dice_class_2: 0.8966 - main_output_dice_coef_multiclass: 0.8869 - main_output_iou_class_0: 0.9419 - main_output_iou_class_1: 0.8532 - main_output_iou_class_2: 0.8137 - main_output_iou_coef_multiclass: 0.7969 - main_output_loss: 0.3333 - up_sampling2d_1_loss: 0.3235 - up_sampling2d_2_loss: 0.3263 - up_sampling2d_3_loss: 0.3294 - up_sampling2d_loss: 0.3331 - val_loss: 0.7357 - val_main_output_accuracy: 0.9438 - val_main_output_dice_class_0: 0.9738 - val_main_output_dice_class_1: 0.9207 - val_main_output_dice_class_2: 0.8779 - val_main_output_dice_coef_multiclass: 0.9211 - val_main_output_iou_class_0: 0.9489 - val_main_output_iou_class_1: 0.8534 - val_main_output_iou_class_2: 0.7837 - val_main_output_iou_coef_multiclass: 0.8539 - val_main_output_loss: 0.3110 - val_up_sampling2d_1_loss: 0.3042 - val_up_sampling2d_2_loss: 0.3035 - val_up_sampling2d_3_loss: 0.3124 - val_up_sampling2d_loss: 0.3259 - learning_rate: 2.0000e-04
# Epoch 19/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - loss: 0.7504 - main_output_accuracy: 0.9467 - main_output_dice_class_0: 0.9721 - main_output_dice_class_1: 0.9248 - main_output_dice_class_2: 0.9006 - main_output_dice_coef_multiclass: 0.8912 - main_output_iou_class_0: 0.9457 - main_output_iou_class_1: 0.8605 - main_output_iou_class_2: 0.8200 - main_output_iou_coef_multiclass: 0.8038 - main_output_loss: 0.3188 - up_sampling2d_1_loss: 0.3104 - up_sampling2d_2_loss: 0.3122 - up_sampling2d_3_loss: 0.3153 - up_sampling2d_loss: 0.3218
# Epoch 19: val_loss did not improve from 0.73571
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 469ms/step - loss: 0.7504 - main_output_accuracy: 0.9467 - main_output_dice_class_0: 0.9721 - main_output_dice_class_1: 0.9248 - main_output_dice_class_2: 0.9006 - main_output_dice_coef_multiclass: 0.8911 - main_output_iou_class_0: 0.9457 - main_output_iou_class_1: 0.8604 - main_output_iou_class_2: 0.8200 - main_output_iou_coef_multiclass: 0.8038 - main_output_loss: 0.3188 - up_sampling2d_1_loss: 0.3104 - up_sampling2d_2_loss: 0.3123 - up_sampling2d_3_loss: 0.3153 - up_sampling2d_loss: 0.3218 - val_loss: 0.8212 - val_main_output_accuracy: 0.9345 - val_main_output_dice_class_0: 0.9673 - val_main_output_dice_class_1: 0.9030 - val_main_output_dice_class_2: 0.8753 - val_main_output_dice_coef_multiclass: 0.9193 - val_main_output_iou_class_0: 0.9366 - val_main_output_iou_class_1: 0.8238 - val_main_output_iou_class_2: 0.7798 - val_main_output_iou_coef_multiclass: 0.8508 - val_main_output_loss: 0.3512 - val_up_sampling2d_1_loss: 0.3388 - val_up_sampling2d_2_loss: 0.3426 - val_up_sampling2d_3_loss: 0.3476 - val_up_sampling2d_loss: 0.3224 - learning_rate: 2.0000e-04
# Epoch 20/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - loss: 0.7369 - main_output_accuracy: 0.9478 - main_output_dice_class_0: 0.9713 - main_output_dice_class_1: 0.9263 - main_output_dice_class_2: 0.9070 - main_output_dice_coef_multiclass: 0.8931 - main_output_iou_class_0: 0.9443 - main_output_iou_class_1: 0.8630 - main_output_iou_class_2: 0.8305 - main_output_iou_coef_multiclass: 0.8070 - main_output_loss: 0.3133 - up_sampling2d_1_loss: 0.3046 - up_sampling2d_2_loss: 0.3060 - up_sampling2d_3_loss: 0.3094 - up_sampling2d_loss: 0.3182
# Epoch 20: val_loss did not improve from 0.73571
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 469ms/step - loss: 0.7369 - main_output_accuracy: 0.9478 - main_output_dice_class_0: 0.9713 - main_output_dice_class_1: 0.9263 - main_output_dice_class_2: 0.9069 - main_output_dice_coef_multiclass: 0.8931 - main_output_iou_class_0: 0.9443 - main_output_iou_class_1: 0.8630 - main_output_iou_class_2: 0.8305 - main_output_iou_coef_multiclass: 0.8070 - main_output_loss: 0.3133 - up_sampling2d_1_loss: 0.3047 - up_sampling2d_2_loss: 0.3060 - up_sampling2d_3_loss: 0.3094 - up_sampling2d_loss: 0.3182 - val_loss: 0.8743 - val_main_output_accuracy: 0.9337 - val_main_output_dice_class_0: 0.9722 - val_main_output_dice_class_1: 0.9033 - val_main_output_dice_class_2: 0.8619 - val_main_output_dice_coef_multiclass: 0.9190 - val_main_output_iou_class_0: 0.9459 - val_main_output_iou_class_1: 0.8243 - val_main_output_iou_class_2: 0.7585 - val_main_output_iou_coef_multiclass: 0.8503 - val_main_output_loss: 0.3787 - val_up_sampling2d_1_loss: 0.3421 - val_up_sampling2d_2_loss: 0.3600 - val_up_sampling2d_3_loss: 0.3763 - val_up_sampling2d_loss: 0.3354 - learning_rate: 2.0000e-04
# Epoch 21/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - loss: 0.7312 - main_output_accuracy: 0.9478 - main_output_dice_class_0: 0.9716 - main_output_dice_class_1: 0.9271 - main_output_dice_class_2: 0.9053 - main_output_dice_coef_multiclass: 0.8930 - main_output_iou_class_0: 0.9449 - main_output_iou_class_1: 0.8644 - main_output_iou_class_2: 0.8276 - main_output_iou_coef_multiclass: 0.8068 - main_output_loss: 0.3113 - up_sampling2d_1_loss: 0.3014 - up_sampling2d_2_loss: 0.3039 - up_sampling2d_3_loss: 0.3076 - up_sampling2d_loss: 0.3114
# Epoch 21: val_loss did not improve from 0.73571
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 469ms/step - loss: 0.7312 - main_output_accuracy: 0.9478 - main_output_dice_class_0: 0.9716 - main_output_dice_class_1: 0.9271 - main_output_dice_class_2: 0.9053 - main_output_dice_coef_multiclass: 0.8930 - main_output_iou_class_0: 0.9449 - main_output_iou_class_1: 0.8644 - main_output_iou_class_2: 0.8276 - main_output_iou_coef_multiclass: 0.8068 - main_output_loss: 0.3113 - up_sampling2d_1_loss: 0.3014 - up_sampling2d_2_loss: 0.3039 - up_sampling2d_3_loss: 0.3076 - up_sampling2d_loss: 0.3114 - val_loss: 0.9604 - val_main_output_accuracy: 0.9159 - val_main_output_dice_class_0: 0.9683 - val_main_output_dice_class_1: 0.8690 - val_main_output_dice_class_2: 0.8174 - val_main_output_dice_coef_multiclass: 0.8930 - val_main_output_iou_class_0: 0.9387 - val_main_output_iou_class_1: 0.7710 - val_main_output_iou_class_2: 0.6967 - val_main_output_iou_coef_multiclass: 0.8075 - val_main_output_loss: 0.4122 - val_up_sampling2d_1_loss: 0.3982 - val_up_sampling2d_2_loss: 0.3950 - val_up_sampling2d_3_loss: 0.4046 - val_up_sampling2d_loss: 0.3910 - learning_rate: 2.0000e-04
# Epoch 22/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - loss: 0.7548 - main_output_accuracy: 0.9458 - main_output_dice_class_0: 0.9721 - main_output_dice_class_1: 0.9237 - main_output_dice_class_2: 0.8953 - main_output_dice_coef_multiclass: 0.8906 - main_output_iou_class_0: 0.9458 - main_output_iou_class_1: 0.8587 - main_output_iou_class_2: 0.8115 - main_output_iou_coef_multiclass: 0.8029 - main_output_loss: 0.3212 - up_sampling2d_1_loss: 0.3115 - up_sampling2d_2_loss: 0.3143 - up_sampling2d_3_loss: 0.3164 - up_sampling2d_loss: 0.3226
# Epoch 22: val_loss improved from 0.73571 to 0.72966, saving model to results/V2_LabelSmoothing_DeepSupervision.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 74s 495ms/step - loss: 0.7548 - main_output_accuracy: 0.9458 - main_output_dice_class_0: 0.9721 - main_output_dice_class_1: 0.9237 - main_output_dice_class_2: 0.8953 - main_output_dice_coef_multiclass: 0.8906 - main_output_iou_class_0: 0.9458 - main_output_iou_class_1: 0.8587 - main_output_iou_class_2: 0.8116 - main_output_iou_coef_multiclass: 0.8029 - main_output_loss: 0.3212 - up_sampling2d_1_loss: 0.3115 - up_sampling2d_2_loss: 0.3143 - up_sampling2d_3_loss: 0.3164 - up_sampling2d_loss: 0.3225 - val_loss: 0.7297 - val_main_output_accuracy: 0.9392 - val_main_output_dice_class_0: 0.9762 - val_main_output_dice_class_1: 0.9089 - val_main_output_dice_class_2: 0.8718 - val_main_output_dice_coef_multiclass: 0.9173 - val_main_output_iou_class_0: 0.9536 - val_main_output_iou_class_1: 0.8340 - val_main_output_iou_class_2: 0.7755 - val_main_output_iou_coef_multiclass: 0.8475 - val_main_output_loss: 0.3066 - val_up_sampling2d_1_loss: 0.3038 - val_up_sampling2d_2_loss: 0.3047 - val_up_sampling2d_3_loss: 0.3057 - val_up_sampling2d_loss: 0.3357 - learning_rate: 2.0000e-04
# Epoch 23/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - loss: 0.7435 - main_output_accuracy: 0.9474 - main_output_dice_class_0: 0.9720 - main_output_dice_class_1: 0.9262 - main_output_dice_class_2: 0.9028 - main_output_dice_coef_multiclass: 0.8927 - main_output_iou_class_0: 0.9456 - main_output_iou_class_1: 0.8627 - main_output_iou_class_2: 0.8241 - main_output_iou_coef_multiclass: 0.8062 - main_output_loss: 0.3152 - up_sampling2d_1_loss: 0.3084 - up_sampling2d_2_loss: 0.3103 - up_sampling2d_3_loss: 0.3125 - up_sampling2d_loss: 0.3187
# Epoch 23: val_loss did not improve from 0.72966
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 470ms/step - loss: 0.7435 - main_output_accuracy: 0.9474 - main_output_dice_class_0: 0.9720 - main_output_dice_class_1: 0.9262 - main_output_dice_class_2: 0.9028 - main_output_dice_coef_multiclass: 0.8926 - main_output_iou_class_0: 0.9456 - main_output_iou_class_1: 0.8627 - main_output_iou_class_2: 0.8241 - main_output_iou_coef_multiclass: 0.8062 - main_output_loss: 0.3152 - up_sampling2d_1_loss: 0.3084 - up_sampling2d_2_loss: 0.3103 - up_sampling2d_3_loss: 0.3125 - up_sampling2d_loss: 0.3186 - val_loss: 1.1644 - val_main_output_accuracy: 0.9125 - val_main_output_dice_class_0: 0.9613 - val_main_output_dice_class_1: 0.8796 - val_main_output_dice_class_2: 0.8090 - val_main_output_dice_coef_multiclass: 0.8800 - val_main_output_iou_class_0: 0.9258 - val_main_output_iou_class_1: 0.7889 - val_main_output_iou_class_2: 0.6862 - val_main_output_iou_coef_multiclass: 0.7872 - val_main_output_loss: 0.5119 - val_up_sampling2d_1_loss: 0.4460 - val_up_sampling2d_2_loss: 0.4680 - val_up_sampling2d_3_loss: 0.4975 - val_up_sampling2d_loss: 0.4659 - learning_rate: 2.0000e-04
# Epoch 24/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - loss: 0.7509 - main_output_accuracy: 0.9456 - main_output_dice_class_0: 0.9709 - main_output_dice_class_1: 0.9238 - main_output_dice_class_2: 0.9012 - main_output_dice_coef_multiclass: 0.8906 - main_output_iou_class_0: 0.9436 - main_output_iou_class_1: 0.8588 - main_output_iou_class_2: 0.8209 - main_output_iou_coef_multiclass: 0.8029 - main_output_loss: 0.3195 - up_sampling2d_1_loss: 0.3099 - up_sampling2d_2_loss: 0.3125 - up_sampling2d_3_loss: 0.3151 - up_sampling2d_loss: 0.3211
# Epoch 24: val_loss did not improve from 0.72966
# ...
# Epoch 47/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - loss: 0.5693 - main_output_accuracy: 0.9647 - main_output_dice_class_0: 0.9797 - main_output_dice_class_1: 0.9501 - main_output_dice_class_2: 0.9409 - main_output_dice_coef_multiclass: 0.9175 - main_output_iou_class_0: 0.9603 - main_output_iou_class_1: 0.9050 - main_output_iou_class_2: 0.8887 - main_output_iou_coef_multiclass: 0.8477 - main_output_loss: 0.2395 - up_sampling2d_1_loss: 0.2392 - up_sampling2d_2_loss: 0.2379 - up_sampling2d_3_loss: 0.2381 - up_sampling2d_loss: 0.2561
# Epoch 47: val_loss did not improve from 0.64086
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 468ms/step - loss: 0.5693 - main_output_accuracy: 0.9647 - main_output_dice_class_0: 0.9797 - main_output_dice_class_1: 0.9501 - main_output_dice_class_2: 0.9409 - main_output_dice_coef_multiclass: 0.9175 - main_output_iou_class_0: 0.9603 - main_output_iou_class_1: 0.9050 - main_output_iou_class_2: 0.8887 - main_output_iou_coef_multiclass: 0.8477 - main_output_loss: 0.2395 - up_sampling2d_1_loss: 0.2392 - up_sampling2d_2_loss: 0.2378 - up_sampling2d_3_loss: 0.2380 - up_sampling2d_loss: 0.2561 - val_loss: 0.7239 - val_main_output_accuracy: 0.9506 - val_main_output_dice_class_0: 0.9775 - val_main_output_dice_class_1: 0.9291 - val_main_output_dice_class_2: 0.8931 - val_main_output_dice_coef_multiclass: 0.9386 - val_main_output_iou_class_0: 0.9561 - val_main_output_iou_class_1: 0.8682 - val_main_output_iou_class_2: 0.8084 - val_main_output_iou_coef_multiclass: 0.8844 - val_main_output_loss: 0.3014 - val_up_sampling2d_1_loss: 0.3087 - val_up_sampling2d_2_loss: 0.3076 - val_up_sampling2d_3_loss: 0.3067 - val_up_sampling2d_loss: 0.3054 - learning_rate: 1.2500e-05
# Epoch 48/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - loss: 0.5670 - main_output_accuracy: 0.9654 - main_output_dice_class_0: 0.9806 - main_output_dice_class_1: 0.9512 - main_output_dice_class_2: 0.9400 - main_output_dice_coef_multiclass: 0.9175 - main_output_iou_class_0: 0.9619 - main_output_iou_class_1: 0.9070 - main_output_iou_class_2: 0.8872 - main_output_iou_coef_multiclass: 0.8476 - main_output_loss: 0.2385 - up_sampling2d_1_loss: 0.2376 - up_sampling2d_2_loss: 0.2370 - up_sampling2d_3_loss: 0.2375 - up_sampling2d_loss: 0.2548
# Epoch 48: val_loss did not improve from 0.64086
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 468ms/step - loss: 0.5670 - main_output_accuracy: 0.9654 - main_output_dice_class_0: 0.9806 - main_output_dice_class_1: 0.9512 - main_output_dice_class_2: 0.9400 - main_output_dice_coef_multiclass: 0.9175 - main_output_iou_class_0: 0.9619 - main_output_iou_class_1: 0.9070 - main_output_iou_class_2: 0.8872 - main_output_iou_coef_multiclass: 0.8476 - main_output_loss: 0.2385 - up_sampling2d_1_loss: 0.2376 - up_sampling2d_2_loss: 0.2370 - up_sampling2d_3_loss: 0.2375 - up_sampling2d_loss: 0.2548 - val_loss: 0.7318 - val_main_output_accuracy: 0.9494 - val_main_output_dice_class_0: 0.9768 - val_main_output_dice_class_1: 0.9277 - val_main_output_dice_class_2: 0.8917 - val_main_output_dice_coef_multiclass: 0.9379 - val_main_output_iou_class_0: 0.9547 - val_main_output_iou_class_1: 0.8658 - val_main_output_iou_class_2: 0.8066 - val_main_output_iou_coef_multiclass: 0.8832 - val_main_output_loss: 0.3049 - val_up_sampling2d_1_loss: 0.3115 - val_up_sampling2d_2_loss: 0.3115 - val_up_sampling2d_3_loss: 0.3098 - val_up_sampling2d_loss: 0.3069 - learning_rate: 1.2500e-05
# Epoch 49/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - loss: 0.5593 - main_output_accuracy: 0.9657 - main_output_dice_class_0: 0.9800 - main_output_dice_class_1: 0.9515 - main_output_dice_class_2: 0.9432 - main_output_dice_coef_multiclass: 0.9183 - main_output_iou_class_0: 0.9609 - main_output_iou_class_1: 0.9076 - main_output_iou_class_2: 0.8927 - main_output_iou_coef_multiclass: 0.8490 - main_output_loss: 0.2354 - up_sampling2d_1_loss: 0.2345 - up_sampling2d_2_loss: 0.2336 - up_sampling2d_3_loss: 0.2343 - up_sampling2d_loss: 0.2498
# Epoch 49: val_loss did not improve from 0.64086
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 469ms/step - loss: 0.5593 - main_output_accuracy: 0.9657 - main_output_dice_class_0: 0.9800 - main_output_dice_class_1: 0.9515 - main_output_dice_class_2: 0.9432 - main_output_dice_coef_multiclass: 0.9183 - main_output_iou_class_0: 0.9609 - main_output_iou_class_1: 0.9076 - main_output_iou_class_2: 0.8927 - main_output_iou_coef_multiclass: 0.8490 - main_output_loss: 0.2354 - up_sampling2d_1_loss: 0.2345 - up_sampling2d_2_loss: 0.2336 - up_sampling2d_3_loss: 0.2343 - up_sampling2d_loss: 0.2498 - val_loss: 0.7224 - val_main_output_accuracy: 0.9510 - val_main_output_dice_class_0: 0.9777 - val_main_output_dice_class_1: 0.9303 - val_main_output_dice_class_2: 0.8938 - val_main_output_dice_coef_multiclass: 0.9397 - val_main_output_iou_class_0: 0.9564 - val_main_output_iou_class_1: 0.8702 - val_main_output_iou_class_2: 0.8105 - val_main_output_iou_coef_multiclass: 0.8865 - val_main_output_loss: 0.3011 - val_up_sampling2d_1_loss: 0.3066 - val_up_sampling2d_2_loss: 0.3079 - val_up_sampling2d_3_loss: 0.3059 - val_up_sampling2d_loss: 0.3017 - learning_rate: 1.2500e-05
# Epoch 50/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - loss: 0.5589 - main_output_accuracy: 0.9656 - main_output_dice_class_0: 0.9799 - main_output_dice_class_1: 0.9512 - main_output_dice_class_2: 0.9452 - main_output_dice_coef_multiclass: 0.9182 - main_output_iou_class_0: 0.9606 - main_output_iou_class_1: 0.9070 - main_output_iou_class_2: 0.8964 - main_output_iou_coef_multiclass: 0.8488 - main_output_loss: 0.2350 - up_sampling2d_1_loss: 0.2343 - up_sampling2d_2_loss: 0.2335 - up_sampling2d_3_loss: 0.2337 - up_sampling2d_loss: 0.2535
# Epoch 50: val_loss did not improve from 0.64086
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 468ms/step - loss: 0.5589 - main_output_accuracy: 0.9656 - main_output_dice_class_0: 0.9799 - main_output_dice_class_1: 0.9512 - main_output_dice_class_2: 0.9452 - main_output_dice_coef_multiclass: 0.9182 - main_output_iou_class_0: 0.9606 - main_output_iou_class_1: 0.9070 - main_output_iou_class_2: 0.8964 - main_output_iou_coef_multiclass: 0.8488 - main_output_loss: 0.2350 - up_sampling2d_1_loss: 0.2343 - up_sampling2d_2_loss: 0.2335 - up_sampling2d_3_loss: 0.2337 - up_sampling2d_loss: 0.2535 - val_loss: 0.7356 - val_main_output_accuracy: 0.9499 - val_main_output_dice_class_0: 0.9772 - val_main_output_dice_class_1: 0.9283 - val_main_output_dice_class_2: 0.8931 - val_main_output_dice_coef_multiclass: 0.9383 - val_main_output_iou_class_0: 0.9554 - val_main_output_iou_class_1: 0.8668 - val_main_output_iou_class_2: 0.8085 - val_main_output_iou_coef_multiclass: 0.8841 - val_main_output_loss: 0.3066 - val_up_sampling2d_1_loss: 0.3125 - val_up_sampling2d_2_loss: 0.3127 - val_up_sampling2d_3_loss: 0.3117 - val_up_sampling2d_loss: 0.3092 - learning_rate: 6.2500e-06
# Epoch 51/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - loss: 0.5549 - main_output_accuracy: 0.9664 - main_output_dice_class_0: 0.9803 - main_output_dice_class_1: 0.9525 - main_output_dice_class_2: 0.9455 - main_output_dice_coef_multiclass: 0.9186 - main_output_iou_class_0: 0.9615 - main_output_iou_class_1: 0.9094 - main_output_iou_class_2: 0.8969 - main_output_iou_coef_multiclass: 0.8496 - main_output_loss: 0.2333 - up_sampling2d_1_loss: 0.2326 - up_sampling2d_2_loss: 0.2319 - up_sampling2d_3_loss: 0.2323 - up_sampling2d_loss: 0.2510
# Epoch 51: val_loss did not improve from 0.64086
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 468ms/step - loss: 0.5549 - main_output_accuracy: 0.9664 - main_output_dice_class_0: 0.9803 - main_output_dice_class_1: 0.9525 - main_output_dice_class_2: 0.9455 - main_output_dice_coef_multiclass: 0.9186 - main_output_iou_class_0: 0.9615 - main_output_iou_class_1: 0.9094 - main_output_iou_class_2: 0.8969 - main_output_iou_coef_multiclass: 0.8496 - main_output_loss: 0.2333 - up_sampling2d_1_loss: 0.2326 - up_sampling2d_2_loss: 0.2319 - up_sampling2d_3_loss: 0.2323 - up_sampling2d_loss: 0.2510 - val_loss: 0.7314 - val_main_output_accuracy: 0.9499 - val_main_output_dice_class_0: 0.9772 - val_main_output_dice_class_1: 0.9284 - val_main_output_dice_class_2: 0.8928 - val_main_output_dice_coef_multiclass: 0.9384 - val_main_output_iou_class_0: 0.9554 - val_main_output_iou_class_1: 0.8668 - val_main_output_iou_class_2: 0.8080 - val_main_output_iou_coef_multiclass: 0.8842 - val_main_output_loss: 0.3050 - val_up_sampling2d_1_loss: 0.3107 - val_up_sampling2d_2_loss: 0.3108 - val_up_sampling2d_3_loss: 0.3104 - val_up_sampling2d_loss: 0.3055 - learning_rate: 6.2500e-06
# Epoch 52/80
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - loss: 0.5579 - main_output_accuracy: 0.9657 - main_output_dice_class_0: 0.9801 - main_output_dice_class_1: 0.9518 - main_output_dice_class_2: 0.9435 - main_output_dice_coef_multiclass: 0.9184 - main_output_iou_class_0: 0.9611 - main_output_iou_class_1: 0.9081 - main_output_iou_class_2: 0.8933 - main_output_iou_coef_multiclass: 0.8491 - main_output_loss: 0.2344 - up_sampling2d_1_loss: 0.2346 - up_sampling2d_2_loss: 0.2331 - up_sampling2d_3_loss: 0.2337 - up_sampling2d_loss: 0.2509
# Epoch 52: val_loss did not improve from 0.64086
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 70s 468ms/step - loss: 0.5578 - main_output_accuracy: 0.9657 - main_output_dice_class_0: 0.9801 - main_output_dice_class_1: 0.9518 - main_output_dice_class_2: 0.9435 - main_output_dice_coef_multiclass: 0.9184 - main_output_iou_class_0: 0.9611 - main_output_iou_class_1: 0.9082 - main_output_iou_class_2: 0.8933 - main_output_iou_coef_multiclass: 0.8491 - main_output_loss: 0.2344 - up_sampling2d_1_loss: 0.2346 - up_sampling2d_2_loss: 0.2331 - up_sampling2d_3_loss: 0.2337 - up_sampling2d_loss: 0.2509 - val_loss: 0.7209 - val_main_output_accuracy: 0.9504 - val_main_output_dice_class_0: 0.9769 - val_main_output_dice_class_1: 0.9295 - val_main_output_dice_class_2: 0.8938 - val_main_output_dice_coef_multiclass: 0.9391 - val_main_output_iou_class_0: 0.9550 - val_main_output_iou_class_1: 0.8688 - val_main_output_iou_class_2: 0.8096 - val_main_output_iou_coef_multiclass: 0.8853 - val_main_output_loss: 0.3010 - val_up_sampling2d_1_loss: 0.3054 - val_up_sampling2d_2_loss: 0.3061 - val_up_sampling2d_3_loss: 0.3060 - val_up_sampling2d_loss: 0.3003 - learning_rate: 6.2500e-06
# Epoch 52: early stopping
# Restoring model weights from the end of the best epoch: 37.
# ✓ Training completed
#
# Generating visualizations...
#   ✓ Saved: results/V2_LabelSmoothing_DeepSupervision_history.png
#   ✓ Saved: results/V2_LabelSmoothing_DeepSupervision_predictions_cdr.png
# ================================================================================
# EVALUATION: V2_LabelSmoothing_DeepSupervision
# ================================================================================
#
# Saving all 400 test predictions to results/V2_LabelSmoothing_DeepSupervision_all_preds...
#   Processed 50/400
#   Processed 100/400
#   Processed 150/400
#   Processed 200/400
#   Processed 250/400
#   Processed 300/400
#   Processed 350/400
#   Processed 400/400
# ✓ Saved comparison masks to results/V2_LabelSmoothing_DeepSupervision_all_preds
#   ✓ Saved: results/V2_LabelSmoothing_DeepSupervision_confusion_matrices.png
# Confusion Matrix:
# [[53073897  1401749     6340]
#  [ 1014018 34996287  1183083]
#  [     603  1469906 11711717]]
#
# Normalized Confusion Matrix:
# [[0.974 0.026 0.   ]
#  [0.027 0.941 0.032]
#  [0.    0.112 0.888]]
#
# Precision, Recall, F1 Score per class (ROI-level):
#   Background: Precision=0.9812, Recall=0.9742, F1=0.9777
#   Disc: Precision=0.9242, Recall=0.9409, F1=0.9325
#   Cup: Precision=0.9078, Recall=0.8884, F1=0.8980
#
# Macro-averaged metrics:
#   Precision: 0.9377
#   Recall: 0.9345
#   F1 Score: 0.9361
#   Background: Dice=0.9777, IoU=0.9563
#   Disc: Dice=0.9325, IoU=0.8735
#   Cup: Dice=0.8980, IoU=0.8149
#
# ================================================================================
# GLAUCOMA PROGRESSION ANALYSIS (Using Area-based CDR on full-image mapped predictions)
# ================================================================================
#
# --------------------------------------------------------------------------------
# CDR Statistics:
# --------------------------------------------------------------------------------
#   Mean GT CDR:   0.5984 ± 0.1782
#   Mean Pred CDR: 0.5862 ± 0.1659
#   Mean CDR Error: 0.0581 ± 0.0666
#
# ================================================================================
# PROGRESSION CLASSIFICATION ACCURACY
# ================================================================================
#
# Overall Accuracy: 82.75%
#   - Correctly Classified: 331/400 samples
#   - Incorrectly Classified: 69/400 samples
#
# --------------------------------------------------------------------------------
# Per-Class Results:
# --------------------------------------------------------------------------------
# Severity     GT Count     Pred Count   Correct      Accuracy
# --------------------------------------------------------------------------------
# Normal       0            0            0            0.00        %
# Suspect      257          279          240          93.39       %
# Moderate     106          93           66           62.26       %
# Critical     37           28           25           67.57       %
#
# ================================================================================
# INTERPRETATION EXAMPLE:
# ================================================================================
#   - GT says 'Normal' for 0 images
#   - Model says 'Normal' for 0 images
#   - Model correctly predicts 0 as 'Normal'
#   - Accuracy for Normal class: 0/0 = 0.0%
#
# ================================================================================
# MANUAL REVIEW RECOMMENDATIONS
# ================================================================================
#
# Samples Requiring Manual Review: 94/400 (23.5%)
#
# Criteria for Manual Review:
#   1. All Critical cases (high-risk, requires expert verification)
#   2. Classification mismatches (GT ≠ Predicted severity)
#
# Reason: Critical cases need expert confirmation, and mismatches may
# indicate borderline cases or segmentation issues requiring review.
#
# Breakdown:
#   - Critical cases: 37 samples
#   - Classification mismatches: 69 samples
#   - Overlap (Critical + Mismatch): 12 samples
#
# ✓ Saved: results/glaucoma_progression_analysis.csv
#   ✓ Saved: results/cdr_analysis.png
# ================================================================================
# MC DROPOUT UNCERTAINTY ESTIMATION
# ================================================================================
#
# Running MC Dropout with 15 stochastic forward passes...
#   Completed: 5/15 forward passes
#   Completed: 10/15 forward passes
#   Completed: 15/15 forward passes
# ✓ MC Dropout completed
#   Background uncertainty: 0.0021
#   Disc uncertainty: 0.0032
#   Cup uncertainty: 0.0012
#
# ====================================================================================================
#                                  TRAINING AND EVALUATION COMPLETED!
# ====================================================================================================
#
# Model: V2+DS - Label Smoothing + Deep Supervision + High-Res ROI
# Parameters: 47,634,519
# ROI Extraction: Padding=1.2x, Size=(512, 512)
# Results saved in: results/
#
# Generated Files:
#   - Training history: results/V5_OrigConfig_HighResROI_history.png
#   - Predictions with CDR: results/V5_OrigConfig_HighResROI_predictions_cdr.png
#   - CDR Analysis: results/cdr_analysis.png
#   - Progression CSV: results/glaucoma_progression_analysis.csv
#   - Confusion Matrices: results/V5_OrigConfig_HighResROI_confusion_matrices.png
#
# ====================================================================================================
