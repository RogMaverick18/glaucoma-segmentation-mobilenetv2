# %%
"""
MOBILENET-UNET WITH MSCA + LBFR (DUAL ATTENTION MODULES)
=========================================================
Enhanced with both MSCA and LBFR from ODFormer for comprehensive feature enhancement

Dual Enhancement Strategy:
- MSCA (Multi-scale Context Aggregator): Multi-scale dilated convolutions [1,2,3,5]
- LBFR (Lightweight Bidirectional Feature Recalibrator): Channel + Spatial attention
- Sequential application: MSCA → LBFR on each decoder block
- From ODFormer architecture combining both attention mechanisms

Configuration:
- Base: Deeper Decoder + Focal-EIoU + MC Dropout
- Enhancement: MSCA + LBFR on decoder outputs
- Placement: Both modules after each decoder block (4 total)
"""

import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, backend as K
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import albumentations as A
import warnings
import gc
warnings.filterwarnings('ignore')

# Set plot style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# ============================================================================
# GPU CONFIGURATION
# ============================================================================

def configure_gpu():
    """Configure GPU settings for optimal performance"""
    print("Configuring GPU settings...")
    physical_devices = tf.config.list_physical_devices('GPU')
    if physical_devices:
        try:
            for gpu in physical_devices:
                tf.config.experimental.set_memory_growth(gpu, True)
            tf.config.set_visible_devices(physical_devices[0], 'GPU')
            print(f"✓ GPU found: {physical_devices}")
            return True
        except RuntimeError as e:
            print(f"✗ GPU configuration error: {e}")
            return False
    else:
        print("✗ No GPU found, using CPU")
        return False

# ============================================================================
# DATA LOADING
# ============================================================================

def load_images_masks(images_folder, masks_folder, img_size=(256,256)):
    """Load images and masks from folders"""
    images, masks = [], []
    image_files = sorted(os.listdir(images_folder))
    mask_files = sorted(os.listdir(masks_folder))
    mask_dict = {os.path.splitext(f)[0]: f for f in mask_files}
    
    for img_file in image_files:
        base = os.path.splitext(img_file)[0]
        if base in mask_dict:
            img = cv2.imread(os.path.join(images_folder, img_file))
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, img_size) / 255.0
            
            mask = cv2.imread(os.path.join(masks_folder, mask_dict[base]), cv2.IMREAD_GRAYSCALE)
            mask = cv2.resize(mask, img_size)
            unique_vals = np.unique(mask)
            if len(unique_vals) > 3 or np.max(unique_vals) > 2:
                mask = np.clip(mask // 85, 0, 2).astype(np.uint8)
            
            images.append(img)
            masks.append(mask)
    
    return np.array(images, dtype=np.float32), np.array(masks, dtype=np.uint8)

def load_all_data(root_dir):
    """Load all data from existing splits and merge"""
    all_images, all_masks = [], []
    for split in ["train", "val", "test"]:
        print(f"Loading {split} data...")
        imgs, msks = load_images_masks(
            os.path.join(root_dir, split, "Images"),
            os.path.join(root_dir, split, "Masks")
        )
        all_images.append(imgs)
        all_masks.append(msks)
        print(f"  {split}: {imgs.shape[0]} samples")
    
    all_images = np.concatenate(all_images, axis=0)
    all_masks = np.concatenate(all_masks, axis=0)
    return all_images, all_masks

def create_new_split(all_images, all_masks):
    """Create new split: 600 train, 200 val, 400 test"""
    X_temp, X_test, y_temp, y_test = train_test_split(
        all_images, all_masks, test_size=400, random_state=42
    )
    X_train, X_val, y_train, y_val = train_test_split(
        X_temp, y_temp, test_size=200, random_state=42
    )
    print(f"Split - Train: {X_train.shape[0]}, Val: {X_val.shape[0]}, Test: {X_test.shape[0]}")
    return (X_train, y_train), (X_val, y_val), (X_test, y_test)

# ============================================================================
# DATA AUGMENTATION
# ============================================================================

def setup_augmentations():
    return A.Compose([
        A.RandomBrightnessContrast(brightness_limit=0.15, contrast_limit=0.15, p=0.7),
        A.HueSaturationValue(hue_shift_limit=10, sat_shift_limit=15, val_shift_limit=10, p=0.5),
        A.GaussianBlur(blur_limit=3, p=0.3),
        A.RandomGamma(gamma_limit=(80, 120), p=0.3),
    ])

def data_generator(images, masks, batch_size, augment=None):
    idxs = np.arange(len(images))
    while True:
        np.random.shuffle(idxs)
        for i in range(0, len(images), batch_size):
            batch_idxs = idxs[i:i+batch_size]
            batch_x, batch_y = [], []
            
            for idx in batch_idxs:
                img, mask = images[idx], masks[idx]
                
                if augment:
                    aug = augment(image=img, mask=mask)
                    img_aug, mask_aug = aug['image'], aug['mask']
                else:
                    img_aug, mask_aug = img, mask
                
                mask_cat = to_categorical(mask_aug, num_classes=3)
                batch_x.append(img_aug)
                batch_y.append(mask_cat)
            
            yield np.stack(batch_x).astype(np.float32), np.stack(batch_y).astype(np.float32)

# ============================================================================
# MSCA MODULE (FROM ODFORMER)
# ============================================================================

def msca_block(x, channels, dilation_rates=[1, 2, 3, 5], block_name='msca'):
    """
    Multi-scale Context Aggregator (MSCA) from ODFormer
    
    Features:
    - Multi-scale feature extraction using dilated convolutions
    - Parallel branches with different dilation rates [1, 2, 3, 5]
    - Feature fusion through concatenation and 1×1 convolution
    - Residual connection for gradient flow
    
    Args:
        x: Input feature map
        channels: Number of output channels
        dilation_rates: List of dilation rates for multi-scale context
        block_name: Name prefix for layers
    """
    multi_scale_features = []
    filters_per_branch = channels // len(dilation_rates)
    
    # Multi-scale branches with different dilation rates
    for i, rate in enumerate(dilation_rates):
        branch = layers.Conv2D(
            filters_per_branch, 
            (3, 3), 
            padding='same',
            dilation_rate=rate,
            use_bias=False,
            name=f'{block_name}_conv_d{rate}'
        )(x)
        branch = layers.BatchNormalization(name=f'{block_name}_bn_d{rate}')(branch)
        branch = layers.Activation('relu', name=f'{block_name}_relu_d{rate}')(branch)
        multi_scale_features.append(branch)
    
    # Concatenate all branches
    concat = layers.Concatenate(name=f'{block_name}_concat')(multi_scale_features)
    
    # Fusion layer to combine multi-scale features
    fused = layers.Conv2D(channels, (1, 1), use_bias=False, name=f'{block_name}_fusion')(concat)
    fused = layers.BatchNormalization(name=f'{block_name}_fusion_bn')(fused)
    fused = layers.Activation('relu', name=f'{block_name}_fusion_relu')(fused)
    
    # Residual connection
    output = layers.Add(name=f'{block_name}_residual')([x, fused])
    
    return output

# ============================================================================
# LBFR MODULE (FROM ODFORMER)
# ============================================================================

def lbfr_block(x, channels, reduction=16, block_name='lbfr'):
    """
    Lightweight Bidirectional Feature Recalibrator (LBFR) from ODFormer
    
    Features:
    - Channel attention using both avg and max pooling
    - Spatial attention using 2-channel feature concatenation
    - Recalibration layer with BatchNormalization
    - Residual connection for gradient flow
    
    Args:
        x: Input feature map
        channels: Number of channels
        reduction: Channel reduction ratio for attention bottleneck
        block_name: Name prefix for layers
    """
    # Channel Attention
    # Average pooling branch
    avg_pool = layers.GlobalAveragePooling2D(name=f'{block_name}_avg_pool')(x)
    avg_pool = layers.Reshape((1, 1, channels), name=f'{block_name}_avg_reshape')(avg_pool)
    
    # Max pooling branch
    max_pool = layers.GlobalMaxPooling2D(name=f'{block_name}_max_pool')(x)
    max_pool = layers.Reshape((1, 1, channels), name=f'{block_name}_max_reshape')(max_pool)
    
    # Shared MLP for channel attention
    fc1 = layers.Conv2D(channels // reduction, (1, 1), use_bias=False, name=f'{block_name}_fc1')
    fc2 = layers.Conv2D(channels, (1, 1), use_bias=False, name=f'{block_name}_fc2')
    
    avg_out = fc1(avg_pool)
    avg_out = layers.Activation('relu', name=f'{block_name}_fc1_relu_avg')(avg_out)
    avg_out = fc2(avg_out)
    
    max_out = fc1(max_pool)
    max_out = layers.Activation('relu', name=f'{block_name}_fc1_relu_max')(max_out)
    max_out = fc2(max_out)
    
    # Combine and apply channel attention
    channel_att = layers.Add(name=f'{block_name}_channel_add')([avg_out, max_out])
    channel_att = layers.Activation('sigmoid', name=f'{block_name}_channel_sigmoid')(channel_att)
    x_channel = layers.Multiply(name=f'{block_name}_channel_multiply')([x, channel_att])
    
    # Spatial Attention
    # Average and max across channels
    avg_spatial = layers.Lambda(lambda x: K.mean(x, axis=-1, keepdims=True), 
                                name=f'{block_name}_spatial_avg')(x_channel)
    max_spatial = layers.Lambda(lambda x: K.max(x, axis=-1, keepdims=True),
                                name=f'{block_name}_spatial_max')(x_channel)
    
    # Concatenate and apply spatial attention
    spatial_concat = layers.Concatenate(name=f'{block_name}_spatial_concat')([avg_spatial, max_spatial])
    spatial_att = layers.Conv2D(1, (7, 7), padding='same', use_bias=False,
                                name=f'{block_name}_spatial_conv')(spatial_concat)
    spatial_att = layers.Activation('sigmoid', name=f'{block_name}_spatial_sigmoid')(spatial_att)
    x_spatial = layers.Multiply(name=f'{block_name}_spatial_multiply')([x_channel, spatial_att])
    
    # Recalibration
    recalibrated = layers.Conv2D(channels, (1, 1), use_bias=False, 
                                 name=f'{block_name}_recalibrate')(x_spatial)
    recalibrated = layers.BatchNormalization(name=f'{block_name}_recalibrate_bn')(recalibrated)
    
    # Residual connection
    output = layers.Add(name=f'{block_name}_residual')([x, recalibrated])
    
    return output

# ============================================================================
# LOSS FUNCTIONS
# ============================================================================

def focal_loss(y_true, y_pred, gamma=2.0, alpha=None, epsilon=1e-7):
    if alpha is None:
        alpha = [0.25, 1.0, 1.0]
    
    y_pred = K.clip(y_pred, epsilon, 1.0 - epsilon)
    focal_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        pt = y_pred_c
        focal_weight = K.pow(1.0 - pt, gamma)
        cross_entropy = -K.log(pt)
        focal_loss_c = alpha[c] * focal_weight * cross_entropy * y_true_c
        focal_loss_value += K.mean(focal_loss_c)
    
    return focal_loss_value

def enhanced_iou_loss(y_true, y_pred, smooth=1e-7):
    eiou_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        
        intersection = K.sum(y_true_c * y_pred_c, axis=[1, 2])
        union = K.sum(y_true_c, axis=[1, 2]) + K.sum(y_pred_c, axis=[1, 2]) - intersection
        iou = (intersection + smooth) / (union + smooth)
        
        height = K.cast(K.shape(y_true_c)[1], 'float32')
        width = K.cast(K.shape(y_true_c)[2], 'float32')
        
        y_coords = K.arange(0, height)
        x_coords = K.arange(0, width)
        y_grid = K.tile(K.reshape(y_coords, (-1, 1)), (1, K.cast(width, 'int32')))
        x_grid = K.tile(K.reshape(x_coords, (1, -1)), (K.cast(height, 'int32'), 1))
        y_grid = K.cast(y_grid, 'float32')
        x_grid = K.cast(x_grid, 'float32')
        
        true_mass = K.sum(y_true_c, axis=[1, 2]) + smooth
        true_center_y = K.sum(y_true_c * y_grid, axis=[1, 2]) / true_mass
        true_center_x = K.sum(y_true_c * x_grid, axis=[1, 2]) / true_mass
        
        pred_mass = K.sum(y_pred_c, axis=[1, 2]) + smooth
        pred_center_y = K.sum(y_pred_c * y_grid, axis=[1, 2]) / pred_mass
        pred_center_x = K.sum(y_pred_c * x_grid, axis=[1, 2]) / pred_mass
        
        center_distance = K.square(true_center_y - pred_center_y) + K.square(true_center_x - pred_center_x)
        diagonal = K.square(height) + K.square(width)
        center_penalty = center_distance / (diagonal + smooth)
        
        true_width = K.sqrt(K.sum(K.sum(y_true_c, axis=1), axis=1) + smooth)
        true_height = K.sqrt(K.sum(K.sum(y_true_c, axis=2), axis=1) + smooth)
        pred_width = K.sqrt(K.sum(K.sum(y_pred_c, axis=1), axis=1) + smooth)
        pred_height = K.sqrt(K.sum(K.sum(y_pred_c, axis=2), axis=1) + smooth)
        
        width_diff = K.square(pred_width - true_width)
        height_diff = K.square(pred_height - true_height)
        aspect_penalty = width_diff / (K.square(width) + smooth) + height_diff / (K.square(height) + smooth)
        
        eiou_c = 1.0 - iou + center_penalty + aspect_penalty
        eiou_loss_value += K.mean(eiou_c)
    
    return eiou_loss_value / 3.0

def focal_eiou_combined_loss(y_true, y_pred, focal_weight=1.0, eiou_weight=1.0, gamma=2.0, alpha=None):
    fl = focal_loss(y_true, y_pred, gamma=gamma, alpha=alpha)
    eiou = enhanced_iou_loss(y_true, y_pred)
    return focal_weight * fl + eiou_weight * eiou

# ============================================================================
# MODEL ARCHITECTURE WITH MSCA + LBFR
# ============================================================================

def enhanced_decoder_block_with_msca_lbfr(x, skip_connection, filters, block_name, dropout_rate=0.3):
    """
    Enhanced decoder block with both MSCA and LBFR modules
    
    Sequential enhancement strategy:
    1. Standard decoder convolutions with residual connection
    2. MSCA for multi-scale context aggregation
    3. LBFR for bidirectional feature recalibration
    
    This combines both attention mechanisms for comprehensive feature enhancement
    """
    x = layers.UpSampling2D((2, 2), name=f'{block_name}_upsample')(x)
    
    if skip_connection.shape[-1] != x.shape[-1]:
        skip_connection = layers.Conv2D(x.shape[-1], (1, 1), use_bias=False,
                                      name=f'{block_name}_skip_align')(skip_connection)
        skip_connection = layers.BatchNormalization(name=f'{block_name}_skip_bn')(skip_connection)
    
    x = layers.Concatenate(name=f'{block_name}_concat')([x, skip_connection])
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv1')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn1')(x)
    x = layers.Dropout(dropout_rate, name=f'{block_name}_dropout')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv2')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn2')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv3')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn3')(x)
    
    residual = x
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv4')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn4')(x)
    
    x = layers.Add(name=f'{block_name}_residual')([x, residual])
    x = layers.Conv2D(filters, (1, 1), activation='relu', padding='same', name=f'{block_name}_conv_final')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn_final')(x)
    
    # Apply MSCA for multi-scale context aggregation
    x = msca_block(x, filters, dilation_rates=[1, 2, 3, 5], block_name=f'{block_name}_msca')
    
    # Apply LBFR for bidirectional feature recalibration
    x = lbfr_block(x, filters, reduction=16, block_name=f'{block_name}_lbfr')
    
    return x

def build_unet_with_msca_lbfr(input_shape=(256, 256, 3), num_classes=3, dropout_rate=0.3):
    """Build MobileNetV2-UNet with both MSCA and LBFR modules"""
    inputs = layers.Input(input_shape, dtype='float32')
    backbone = MobileNetV2(input_tensor=inputs, weights='imagenet', include_top=False)
    
    skip_1 = backbone.get_layer('block_1_expand_relu').output  # 128×128
    skip_2 = backbone.get_layer('block_3_expand_relu').output  # 64×64
    skip_3 = backbone.get_layer('block_6_expand_relu').output  # 32×32
    skip_4 = backbone.get_layer('block_13_expand_relu').output # 16×16
    bridge = backbone.output  # 8×8
    
    # Deeper bridge
    bridge = layers.Conv2D(1024, (3, 3), activation='relu', padding='same')(bridge)
    bridge = layers.BatchNormalization()(bridge)
    bridge = layers.Dropout(dropout_rate, name='bridge_dropout')(bridge)
    
    # Decoder with MSCA + LBFR modules
    x = enhanced_decoder_block_with_msca_lbfr(bridge, skip_4, 512, 'decoder_1', dropout_rate)
    x = enhanced_decoder_block_with_msca_lbfr(x, skip_3, 256, 'decoder_2', dropout_rate)
    x = enhanced_decoder_block_with_msca_lbfr(x, skip_2, 128, 'decoder_3', dropout_rate * 0.7)
    x = enhanced_decoder_block_with_msca_lbfr(x, skip_1, 64, 'decoder_4', dropout_rate * 0.5)
    
    # Final upsampling
    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    
    outputs = layers.Conv2D(num_classes, (1, 1), activation='softmax', dtype='float32')(x)
    
    model = models.Model(inputs, outputs)
    
    # Print configuration
    dropout_layers = [layer for layer in model.layers if isinstance(layer, layers.Dropout)]
    print(f"\nModel Configuration:")
    print(f"  Total Parameters: {model.count_params():,}")
    print(f"  Dropout Layers: {len(dropout_layers)}")
    print(f"  Dual Attention Modules: MSCA + LBFR per decoder block")
    print(f"  MSCA Modules: 4 (multi-scale context with dilation rates [1,2,3,5])")
    print(f"  LBFR Modules: 4 (channel + spatial attention + recalibration)")
    print(f"  Enhancement Strategy: Sequential MSCA → LBFR per block")
    print(f"  Total Attention Blocks: 8 (4 MSCA + 4 LBFR)")
    
    return model

# ============================================================================
# METRICS
# ============================================================================

def dice_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    return (2. * intersection + smooth) / (K.sum(y_true_class) + K.sum(y_pred_class) + smooth)

def dice_class_0(y_true, y_pred): return dice_coef_class(y_true, y_pred, 0)
def dice_class_1(y_true, y_pred): return dice_coef_class(y_true, y_pred, 1)
def dice_class_2(y_true, y_pred): return dice_coef_class(y_true, y_pred, 2)

def iou_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    union = K.sum(y_true_class) + K.sum(y_pred_class) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_class_0(y_true, y_pred): return iou_coef_class(y_true, y_pred, 0)
def iou_class_1(y_true, y_pred): return iou_coef_class(y_true, y_pred, 1)
def iou_class_2(y_true, y_pred): return iou_coef_class(y_true, y_pred, 2)

def mc_dropout_predict(model, X, num_samples=15, batch_size=4, verbose=True):
    """MC Dropout prediction for uncertainty estimation"""
    if verbose:
        print(f"\nRunning MC Dropout with {num_samples} stochastic forward passes...")
    
    predictions = []
    num_batches = int(np.ceil(len(X) / batch_size))
    
    for i in range(num_samples):
        if verbose and (i + 1) % 5 == 0:
            print(f"  Completed: {i+1}/{num_samples} forward passes")
        
        batch_preds = []
        for batch_idx in range(num_batches):
            start_idx = batch_idx * batch_size
            end_idx = min(start_idx + batch_size, len(X))
            X_batch = X[start_idx:end_idx]
            
            pred_batch = model(X_batch, training=True)
            batch_preds.append(pred_batch.numpy())
        
        pred = np.concatenate(batch_preds, axis=0)
        predictions.append(pred)
        
        if (i + 1) % 5 == 0:
            gc.collect()
    
    all_preds = np.array(predictions)
    mean_pred = np.mean(all_preds, axis=0)
    std_pred = np.std(all_preds, axis=0)
    
    del all_preds
    gc.collect()
    
    if verbose:
        print(f"✓ MC Dropout completed")
    
    return mean_pred, std_pred

# ============================================================================
# VISUALIZATION FUNCTIONS
# ============================================================================

def plot_sample_predictions(model, X_test, y_test, model_name, num_samples=6, save_dir='results'):
    """Visualize sample predictions with original image, GT, segmented mask, and overlay"""
    os.makedirs(save_dir, exist_ok=True)
    
    y_pred = model.predict(X_test[:num_samples], verbose=0, batch_size=4)
    y_pred_labels = np.argmax(y_pred, axis=-1)
    
    colors = {0: [0, 0, 0], 1: [0, 255, 0], 2: [255, 0, 0]}
    
    fig, axes = plt.subplots(num_samples, 4, figsize=(16, 4*num_samples))
    
    for i in range(num_samples):
        # Original image
        axes[i, 0].imshow(X_test[i])
        axes[i, 0].set_title('Original Image', fontsize=12, fontweight='bold')
        axes[i, 0].axis('off')
        
        # Ground truth
        gt_colored = np.zeros((256, 256, 3), dtype=np.uint8)
        for class_id, color in colors.items():
            gt_colored[y_test[i] == class_id] = color
        axes[i, 1].imshow(gt_colored)
        axes[i, 1].set_title('Ground Truth (GT)', fontsize=12, fontweight='bold')
        axes[i, 1].axis('off')
        
        # Segmented mask
        pred_colored = np.zeros((256, 256, 3), dtype=np.uint8)
        for class_id, color in colors.items():
            pred_colored[y_pred_labels[i] == class_id] = color
        axes[i, 2].imshow(pred_colored)
        axes[i, 2].set_title('Segmented Mask', fontsize=12, fontweight='bold')
        axes[i, 2].axis('off')
        
        # Overlay
        overlay = X_test[i].copy()
        for class_id, color in colors.items():
            if class_id > 0:
                mask = (y_pred_labels[i] == class_id).astype(np.float32)
                mask_rgb = np.stack([mask * color[0]/255, mask * color[1]/255, mask * color[2]/255], axis=-1)
                overlay = overlay * 0.6 + mask_rgb * 0.4
        axes[i, 3].imshow(overlay)
        axes[i, 3].set_title('Overlay', fontsize=12, fontweight='bold')
        axes[i, 3].axis('off')
        
        # Calculate dice
        y_test_cat = to_categorical(y_test[i], num_classes=3)
        y_pred_cat = to_categorical(y_pred_labels[i], num_classes=3)
        
        disc_dice = 2 * np.sum(y_test_cat[:,:,1] * y_pred_cat[:,:,1]) / (np.sum(y_test_cat[:,:,1]) + np.sum(y_pred_cat[:,:,1]) + 1e-7)
        cup_dice = 2 * np.sum(y_test_cat[:,:,2] * y_pred_cat[:,:,2]) / (np.sum(y_test_cat[:,:,2]) + np.sum(y_pred_cat[:,:,2]) + 1e-7)
        
        axes[i, 0].text(0.5, -0.1, f'Sample {i+1}\nDisc: {disc_dice:.3f} | Cup: {cup_dice:.3f}', 
                       transform=axes[i, 0].transAxes, ha='center', fontsize=10, 
                       bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
    
    plt.suptitle(f'{model_name} - Predictions: Original | GT | Segmented | Overlay', 
                 fontsize=16, fontweight='bold', y=0.995)
    plt.tight_layout()
    plt.savefig(f'{save_dir}/{model_name}_predictions.png', dpi=150, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_predictions.png")
    plt.show()
    plt.close()

def plot_training_history(history, model_name, save_dir='results'):
    """Plot training history"""
    os.makedirs(save_dir, exist_ok=True)
    
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    
    # Loss curves
    axes[0, 0].plot(history.history['loss'], label='Train Loss', linewidth=2)
    axes[0, 0].plot(history.history['val_loss'], label='Val Loss', linewidth=2)
    axes[0, 0].set_title('Loss Curves', fontsize=14, fontweight='bold')
    axes[0, 0].set_xlabel('Epoch', fontsize=12)
    axes[0, 0].set_ylabel('Loss', fontsize=12)
    axes[0, 0].legend(fontsize=10)
    axes[0, 0].grid(True, alpha=0.3)
    
    # Overall Dice
    axes[0, 1].plot(history.history['dice_coef_multiclass'], label='Train Dice', linewidth=2)
    axes[0, 1].plot(history.history['val_dice_coef_multiclass'], label='Val Dice', linewidth=2)
    axes[0, 1].set_title('Overall Dice Coefficient', fontsize=14, fontweight='bold')
    axes[0, 1].set_xlabel('Epoch', fontsize=12)
    axes[0, 1].set_ylabel('Dice', fontsize=12)
    axes[0, 1].legend(fontsize=10)
    axes[0, 1].grid(True, alpha=0.3)
    
    # Disc Dice
    axes[1, 0].plot(history.history['dice_class_1'], label='Train Disc Dice', linewidth=2, color='green')
    axes[1, 0].plot(history.history['val_dice_class_1'], label='Val Disc Dice', linewidth=2, color='darkgreen')
    axes[1, 0].set_title('Disc Segmentation (Class 1)', fontsize=14, fontweight='bold')
    axes[1, 0].set_xlabel('Epoch', fontsize=12)
    axes[1, 0].set_ylabel('Dice', fontsize=12)
    axes[1, 0].legend(fontsize=10)
    axes[1, 0].grid(True, alpha=0.3)
    
    # Cup Dice
    axes[1, 1].plot(history.history['dice_class_2'], label='Train Cup Dice', linewidth=2, color='red')
    axes[1, 1].plot(history.history['val_dice_class_2'], label='Val Cup Dice', linewidth=2, color='darkred')
    axes[1, 1].set_title('Cup Segmentation (Class 2)', fontsize=14, fontweight='bold')
    axes[1, 1].set_xlabel('Epoch', fontsize=12)
    axes[1, 1].set_ylabel('Dice', fontsize=12)
    axes[1, 1].legend(fontsize=10)
    axes[1, 1].grid(True, alpha=0.3)
    
    plt.suptitle(f'{model_name} - Training History', fontsize=16, fontweight='bold')
    plt.tight_layout()
    plt.savefig(f'{save_dir}/{model_name}_history.png', dpi=150, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_history.png")
    plt.show()
    plt.close()

def plot_training_curves(history, model_name, save_dir='results'):
    """Plot training loss and accuracy curves"""
    os.makedirs(save_dir, exist_ok=True)
    
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    
    # Loss
    axes[0].plot(history.history['loss'], label='Training Loss', linewidth=2)
    axes[0].plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
    axes[0].set_title(f'{model_name} - Loss Over Epochs', fontsize=14, fontweight='bold')
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('Loss', fontsize=12)
    axes[0].legend(fontsize=10)
    axes[0].grid(True, alpha=0.3)
    
    # Accuracy
    axes[1].plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
    axes[1].plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
    axes[1].set_title(f'{model_name} - Accuracy Over Epochs', fontsize=14, fontweight='bold')
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('Accuracy', fontsize=12)
    axes[1].legend(fontsize=10)
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(f"{save_dir}/{model_name}_training_curves.png", dpi=300, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_training_curves.png")
    plt.show()
    plt.close()

def plot_confusion_matrices(y_true, y_pred, model_name, save_dir='results'):
    """Plot confusion matrices"""
    os.makedirs(save_dir, exist_ok=True)
    
    y_true_labels = np.argmax(y_true, axis=-1).flatten()
    y_pred_labels = np.argmax(y_pred, axis=-1).flatten()
    
    cm = confusion_matrix(y_true_labels, y_pred_labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    class_names = ['Background', 'Disc', 'Cup']
    
    # Regular confusion matrix
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[0], cbar_kws={'label': 'Count'})
    axes[0].set_title(f'{model_name}\nConfusion Matrix', fontsize=14, fontweight='bold')
    axes[0].set_ylabel('True Label', fontsize=12)
    axes[0].set_xlabel('Predicted Label', fontsize=12)
    
    # Normalized confusion matrix
    sns.heatmap(cm_normalized, annot=True, fmt='.3f', cmap='Greens',
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[1], cbar_kws={'label': 'Proportion'})
    axes[1].set_title(f'{model_name}\nNormalized Confusion Matrix', fontsize=14, fontweight='bold')
    axes[1].set_ylabel('True Label', fontsize=12)
    axes[1].set_xlabel('Predicted Label', fontsize=12)
    
    plt.tight_layout()
    plt.savefig(f"{save_dir}/{model_name}_confusion_matrices.png", dpi=300, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_confusion_matrices.png")
    plt.show()
    plt.close()
    
    print(f"\nConfusion Matrix:\n{cm}")
    print(f"\nNormalized Confusion Matrix:\n{np.round(cm_normalized, 3)}")
    
    return cm, cm_normalized

# ============================================================================
# TRAINING AND EVALUATION
# ============================================================================

def train_model(X_train, y_train, X_val, y_val, X_test, y_test, model_name, 
               augment=None, save_dir='results'):
    """Train model with MSCA + LBFR dual enhancement"""
    print(f"\n{'='*80}")
    print(f"TRAINING: {model_name}")
    print(f"{'='*80}")
    print(f"  Loss: Focal + EIoU")
    print(f"  Architecture: Deeper Decoder + MC Dropout + MSCA + LBFR")
    print(f"  MSCA: Multi-scale Context Aggregator (dilated convs [1,2,3,5])")
    print(f"  LBFR: Lightweight Bidirectional Feature Recalibrator")
    print(f"  Enhancement: Sequential MSCA → LBFR per decoder block")
    
    K.clear_session()
    
    # Build model
    model = build_unet_with_msca_lbfr(dropout_rate=0.3)
    param_count = model.count_params()
    
    # Compile
    model.compile(
        optimizer=optimizers.Adam(learning_rate=5e-4),
        loss=focal_eiou_combined_loss,
        metrics=[dice_coef_multiclass, dice_class_0, dice_class_1, dice_class_2,
                "accuracy", iou_coef_multiclass, iou_class_0, iou_class_1, iou_class_2]
    )
    
    # Callbacks
    checkpoint = ModelCheckpoint(f"{save_dir}/{model_name}.keras", save_best_only=True, 
                                verbose=1, monitor='val_loss', mode='min')
    reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=3, 
                                  verbose=1, mode='min', min_lr=1e-7)
    early_stop = EarlyStopping(monitor="val_loss", patience=10, verbose=1, 
                              restore_best_weights=True, mode='min')
    
    # Training
    batch_size = 4
    steps_train = X_train.shape[0] // batch_size
    steps_val = X_val.shape[0] // batch_size
    
    history = model.fit(
        data_generator(X_train, y_train, batch_size, augment),
        validation_data=data_generator(X_val, y_val, batch_size, None),
        steps_per_epoch=steps_train,
        validation_steps=steps_val,
        epochs=50,
        callbacks=[checkpoint, reduce_lr, early_stop],
        verbose=1
    )
    
    print(f"✓ Training completed")
    
    # Visualizations
    print("\nGenerating visualizations...")
    plot_training_curves(history, model_name, save_dir)
    plot_training_history(history, model_name, save_dir)
    plot_sample_predictions(model, X_test, y_test, model_name, num_samples=6, save_dir=save_dir)
    
    return model, history, param_count

def evaluate_model(model, X_test, y_test, model_name, run_mc_dropout=True):
    """Evaluate model"""
    print(f"\n{'='*80}")
    print(f"EVALUATION: {model_name}")
    print(f"{'='*80}")
    
    y_test_cat = np.array([to_categorical(mask, num_classes=3) for mask in y_test])
    
    # Predict
    y_pred = model.predict(X_test, verbose=0, batch_size=8)
    
    # Confusion matrices
    plot_confusion_matrices(y_test_cat, y_pred, model_name, save_dir='results')
    
    # Classification metrics
    y_true_labels = np.argmax(y_test_cat, axis=-1).flatten()
    y_pred_labels = np.argmax(y_pred, axis=-1).flatten()
    
    precision = precision_score(y_true_labels, y_pred_labels, average=None, zero_division=0)
    recall = recall_score(y_true_labels, y_pred_labels, average=None, zero_division=0)
    f1 = f1_score(y_true_labels, y_pred_labels, average=None, zero_division=0)
    
    print(f"\nPrecision, Recall, F1 Score per class:")
    class_names = ["Background", "Disc", "Cup"]
    for idx, cname in enumerate(class_names):
        print(f"  {cname}: Precision={precision[idx]:.4f}, Recall={recall[idx]:.4f}, F1={f1[idx]:.4f}")
    
    print(f"\nMacro-averaged metrics:")
    print(f"  Precision: {np.mean(precision):.4f}")
    print(f"  Recall: {np.mean(recall):.4f}")
    print(f"  F1 Score: {np.mean(f1):.4f}")
    
    # Per-class Dice and IoU
    results = {'standard': {}}
    for cidx, cname in enumerate(class_names):
        y_true_c = (np.argmax(y_test_cat, axis=-1) == cidx).astype(np.float32)
        y_pred_c = (np.argmax(y_pred, axis=-1) == cidx).astype(np.float32)
        
        intersection = np.sum(y_true_c * y_pred_c)
        dice = (2. * intersection + 1e-7) / (np.sum(y_true_c) + np.sum(y_pred_c) + 1e-7)
        union = np.sum(y_true_c) + np.sum(y_pred_c) - intersection
        iou = (intersection + 1e-7) / (union + 1e-7)
        
        results['standard'][cname] = {'dice': dice, 'iou': iou}
        print(f"  {cname}: Dice={dice:.4f}, IoU={iou:.4f}")
    
    # MC Dropout
    if run_mc_dropout:
        print("\nMC Dropout Evaluation:")
        mean_pred, std_pred = mc_dropout_predict(model, X_test[:100], num_samples=10, verbose=True)
        results['mc_dropout'] = {}
        for cidx, cname in enumerate(class_names):
            mean_std = np.mean(std_pred[:, :, :, cidx])
            results['mc_dropout'][cname] = {'mean_uncertainty': mean_std}
            print(f"  {cname} uncertainty: {mean_std:.4f}")
    
    return results

# ============================================================================
# MAIN EXECUTION
# ============================================================================

if __name__ == "__main__":
    # Setup
    gpu_available = configure_gpu()
    root_dir = "/kaggle/input/refuge/REFUGE/"
    train_aug = setup_augmentations()
    save_dir = "results"
    os.makedirs(save_dir, exist_ok=True)
    
    print(f"\n{'='*100}")
    print(f"{'MOBILENET-UNET WITH MSCA + LBFR (DUAL ATTENTION MODULES)':^100s}")
    print(f"{'='*100}")
    
    # Load data
    all_images, all_masks = load_all_data(root_dir)
    (X_train, y_train), (X_val, y_val), (X_test, y_test) = create_new_split(all_images, all_masks)
    
    # Train model
    model, history, params = train_model(
        X_train, y_train, X_val, y_val, X_test, y_test,
        "Deeper_Focal_MC_MSCA_LBFR",
        augment=train_aug, save_dir=save_dir
    )
    
    # Evaluate
    results = evaluate_model(model, X_test, y_test, "Deeper+Focal+MC+MSCA+LBFR", run_mc_dropout=True)
    
    print(f"\n{'='*100}")
    print(f"{'✓ TRAINING AND EVALUATION COMPLETED!':^100s}")
    print(f"{'='*100}")
    print(f"\nModel: Deeper + Focal + EIoU + MC Dropout + MSCA + LBFR")
    print(f"Dual Enhancement: MSCA (Multi-scale Context) + LBFR (Bidirectional Recalibration)")
    print(f"MSCA: Multi-scale dilated convolutions with rates [1, 2, 3, 5]")
    print(f"LBFR: Channel + Spatial attention + Recalibration")
    print(f"Total Attention Blocks: 8 (4 MSCA + 4 LBFR)")
    print(f"Parameters: {params:,}")
    print(f"Results saved in: {save_dir}/")
    print(f"\n{'='*100}\n")
# Out:
# 2025-11-18 15:08:32.740649: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763478512.933309      38 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763478512.989938      38 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Configuring GPU settings...
# ✓ GPU found: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
#
# ====================================================================================================
#                       MOBILENET-UNET WITH MSCA + LBFR (DUAL ATTENTION MODULES)
# ====================================================================================================
# Loading train data...
#   train: 400 samples
# Loading val data...
#   val: 400 samples
# Loading test data...
#   test: 400 samples
# Split - Train: 600, Val: 200, Test: 400
#
# ================================================================================
# TRAINING: Deeper_Focal_MC_MSCA_LBFR
# ================================================================================
#   Loss: Focal + EIoU
#   Architecture: Deeper Decoder + MC Dropout + MSCA + LBFR
#   MSCA: Multi-scale Context Aggregator (dilated convs [1,2,3,5])
#   LBFR: Lightweight Bidirectional Feature Recalibrator
#   Enhancement: Sequential MSCA → LBFR per decoder block
# I0000 00:00:1763478596.234604      38 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
#
# Model Configuration:
#   Total Parameters: 41,014,667
#   Dropout Layers: 5
#   Dual Attention Modules: MSCA + LBFR per decoder block
#   MSCA Modules: 4 (multi-scale context with dilation rates [1,2,3,5])
#   LBFR Modules: 4 (channel + spatial attention + recalibration)
#   Enhancement Strategy: Sequential MSCA → LBFR per block
#   Total Attention Blocks: 8 (4 MSCA + 4 LBFR)
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763478687.654015     102 service.cc:148] XLA service 0x7b1258004780 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1763478687.654915     102 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1763478695.752428     102 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1763478705.424289     102 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763478705.689779     102 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1763478749.580849     102 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.8260 - dice_class_0: 0.8874 - dice_class_1: 0.3370 - dice_class_2: 0.2207 - dice_coef_multiclass: 0.5684 - iou_class_0: 0.8268 - iou_class_1: 0.2178 - iou_class_2: 0.1352 - iou_coef_multiclass: 0.4085 - loss: 1.1989
# E0000 00:00:1763478781.382956     100 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763478781.640783     100 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763478781.905863     100 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-11-18 15:13:02.078272: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng12{k11=2} for conv (f32[4,128,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,512,64,64]{3,2,1,0}, f32[128,512,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# E0000 00:00:1763478782.172034     100 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-11-18 15:13:02.233466: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.155376676s
# Trying algorithm eng12{k11=2} for conv (f32[4,128,64,64]{3,2,1,0}, u8[0]{0}) custom-call(f32[4,512,64,64]{3,2,1,0}, f32[128,512,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# Epoch 1: val_loss improved from inf to 0.81281, saving model to results/Deeper_Focal_MC_MSCA_LBFR.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 192s 287ms/step - accuracy: 0.8267 - dice_class_0: 0.8879 - dice_class_1: 0.3379 - dice_class_2: 0.2215 - dice_coef_multiclass: 0.5692 - iou_class_0: 0.8275 - iou_class_1: 0.2185 - iou_class_2: 0.1357 - iou_coef_multiclass: 0.4094 - loss: 1.1977 - val_accuracy: 0.9391 - val_dice_class_0: 0.9704 - val_dice_class_1: 0.4362 - val_dice_class_2: 2.3401e-04 - val_dice_coef_multiclass: 0.9227 - val_iou_class_0: 0.9426 - val_iou_class_1: 0.2795 - val_iou_class_2: 1.1770e-04 - val_iou_coef_multiclass: 0.8565 - val_loss: 0.8128 - learning_rate: 5.0000e-04
# Epoch 2/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9824 - dice_class_0: 0.9918 - dice_class_1: 0.6859 - dice_class_2: 0.4501 - dice_coef_multiclass: 0.8881 - iou_class_0: 0.9837 - iou_class_1: 0.5259 - iou_class_2: 0.2939 - iou_coef_multiclass: 0.8002 - loss: 0.7307
# Epoch 2: val_loss did not improve from 0.81281
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 155ms/step - accuracy: 0.9824 - dice_class_0: 0.9918 - dice_class_1: 0.6862 - dice_class_2: 0.4502 - dice_coef_multiclass: 0.8883 - iou_class_0: 0.9837 - iou_class_1: 0.5261 - iou_class_2: 0.2940 - iou_coef_multiclass: 0.8005 - loss: 0.7303 - val_accuracy: 0.9120 - val_dice_class_0: 0.9576 - val_dice_class_1: 0.1268 - val_dice_class_2: 0.1699 - val_dice_coef_multiclass: 0.9100 - val_iou_class_0: 0.9186 - val_iou_class_1: 0.0679 - val_iou_class_2: 0.0933 - val_iou_coef_multiclass: 0.8349 - val_loss: 1.0275 - learning_rate: 5.0000e-04
# Epoch 3/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9919 - dice_class_0: 0.9967 - dice_class_1: 0.7936 - dice_class_2: 0.6842 - dice_coef_multiclass: 0.9746 - iou_class_0: 0.9934 - iou_class_1: 0.6606 - iou_class_2: 0.5330 - iou_coef_multiclass: 0.9506 - loss: 0.4820
# Epoch 3: val_loss improved from 0.81281 to 0.33127, saving model to results/Deeper_Focal_MC_MSCA_LBFR.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 182ms/step - accuracy: 0.9919 - dice_class_0: 0.9967 - dice_class_1: 0.7937 - dice_class_2: 0.6848 - dice_coef_multiclass: 0.9746 - iou_class_0: 0.9934 - iou_class_1: 0.6607 - iou_class_2: 0.5336 - iou_coef_multiclass: 0.9507 - loss: 0.4816 - val_accuracy: 0.9927 - val_dice_class_0: 0.9974 - val_dice_class_1: 0.7626 - val_dice_class_2: 0.6732 - val_dice_coef_multiclass: 0.9926 - val_iou_class_0: 0.9947 - val_iou_class_1: 0.6190 - val_iou_class_2: 0.5127 - val_iou_coef_multiclass: 0.9854 - val_loss: 0.3313 - learning_rate: 5.0000e-04
# Epoch 4/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9959 - dice_class_0: 0.9986 - dice_class_1: 0.8457 - dice_class_2: 0.8450 - dice_coef_multiclass: 0.9934 - iou_class_0: 0.9972 - iou_class_1: 0.7361 - iou_class_2: 0.7345 - iou_coef_multiclass: 0.9869 - loss: 0.2705
# Epoch 4: val_loss improved from 0.33127 to 0.31592, saving model to results/Deeper_Focal_MC_MSCA_LBFR.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 181ms/step - accuracy: 0.9959 - dice_class_0: 0.9986 - dice_class_1: 0.8458 - dice_class_2: 0.8451 - dice_coef_multiclass: 0.9934 - iou_class_0: 0.9972 - iou_class_1: 0.7362 - iou_class_2: 0.7346 - iou_coef_multiclass: 0.9869 - loss: 0.2703 - val_accuracy: 0.9948 - val_dice_class_0: 0.9987 - val_dice_class_1: 0.7582 - val_dice_class_2: 0.7469 - val_dice_coef_multiclass: 0.9947 - val_iou_class_0: 0.9973 - val_iou_class_1: 0.6139 - val_iou_class_2: 0.5990 - val_iou_coef_multiclass: 0.9895 - val_loss: 0.3159 - learning_rate: 5.0000e-04
# Epoch 5/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9966 - dice_class_0: 0.9989 - dice_class_1: 0.8673 - dice_class_2: 0.8599 - dice_coef_multiclass: 0.9960 - iou_class_0: 0.9977 - iou_class_1: 0.7676 - iou_class_2: 0.7565 - iou_coef_multiclass: 0.9920 - loss: 0.1987
# Epoch 5: val_loss improved from 0.31592 to 0.21236, saving model to results/Deeper_Focal_MC_MSCA_LBFR.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 181ms/step - accuracy: 0.9966 - dice_class_0: 0.9989 - dice_class_1: 0.8674 - dice_class_2: 0.8600 - dice_coef_multiclass: 0.9960 - iou_class_0: 0.9977 - iou_class_1: 0.7677 - iou_class_2: 0.7566 - iou_coef_multiclass: 0.9921 - loss: 0.1986 - val_accuracy: 0.9965 - val_dice_class_0: 0.9988 - val_dice_class_1: 0.8515 - val_dice_class_2: 0.8317 - val_dice_coef_multiclass: 0.9964 - val_iou_class_0: 0.9976 - val_iou_class_1: 0.7470 - val_iou_class_2: 0.7201 - val_iou_coef_multiclass: 0.9929 - val_loss: 0.2124 - learning_rate: 5.0000e-04
# Epoch 6/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9972 - dice_class_0: 0.9991 - dice_class_1: 0.8862 - dice_class_2: 0.8676 - dice_coef_multiclass: 0.9969 - iou_class_0: 0.9983 - iou_class_1: 0.7968 - iou_class_2: 0.7683 - iou_coef_multiclass: 0.9937 - loss: 0.1742
# Epoch 6: val_loss did not improve from 0.21236
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 155ms/step - accuracy: 0.9972 - dice_class_0: 0.9991 - dice_class_1: 0.8862 - dice_class_2: 0.8676 - dice_coef_multiclass: 0.9969 - iou_class_0: 0.9983 - iou_class_1: 0.7968 - iou_class_2: 0.7683 - iou_coef_multiclass: 0.9937 - loss: 0.1742 - val_accuracy: 0.9957 - val_dice_class_0: 0.9985 - val_dice_class_1: 0.8096 - val_dice_class_2: 0.8086 - val_dice_coef_multiclass: 0.9957 - val_iou_class_0: 0.9970 - val_iou_class_1: 0.6848 - val_iou_class_2: 0.6852 - val_iou_coef_multiclass: 0.9914 - val_loss: 0.2581 - learning_rate: 5.0000e-04
# Epoch 7/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9972 - dice_class_0: 0.9991 - dice_class_1: 0.8918 - dice_class_2: 0.8777 - dice_coef_multiclass: 0.9970 - iou_class_0: 0.9982 - iou_class_1: 0.8057 - iou_class_2: 0.7836 - iou_coef_multiclass: 0.9941 - loss: 0.1616
# Epoch 7: val_loss improved from 0.21236 to 0.18255, saving model to results/Deeper_Focal_MC_MSCA_LBFR.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 181ms/step - accuracy: 0.9972 - dice_class_0: 0.9991 - dice_class_1: 0.8918 - dice_class_2: 0.8777 - dice_coef_multiclass: 0.9970 - iou_class_0: 0.9982 - iou_class_1: 0.8057 - iou_class_2: 0.7835 - iou_coef_multiclass: 0.9941 - loss: 0.1616 - val_accuracy: 0.9970 - val_dice_class_0: 0.9991 - val_dice_class_1: 0.8701 - val_dice_class_2: 0.8631 - val_dice_coef_multiclass: 0.9970 - val_iou_class_0: 0.9981 - val_iou_class_1: 0.7718 - val_iou_class_2: 0.7614 - val_iou_coef_multiclass: 0.9939 - val_loss: 0.1825 - learning_rate: 5.0000e-04
# Epoch 8/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9974 - dice_class_0: 0.9992 - dice_class_1: 0.8953 - dice_class_2: 0.8879 - dice_coef_multiclass: 0.9973 - iou_class_0: 0.9983 - iou_class_1: 0.8113 - iou_class_2: 0.7993 - iou_coef_multiclass: 0.9945 - loss: 0.1528
# Epoch 8: val_loss improved from 0.18255 to 0.17960, saving model to results/Deeper_Focal_MC_MSCA_LBFR.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 181ms/step - accuracy: 0.9974 - dice_class_0: 0.9992 - dice_class_1: 0.8954 - dice_class_2: 0.8879 - dice_coef_multiclass: 0.9973 - iou_class_0: 0.9983 - iou_class_1: 0.8113 - iou_class_2: 0.7993 - iou_coef_multiclass: 0.9945 - loss: 0.1528 - val_accuracy: 0.9970 - val_dice_class_0: 0.9991 - val_dice_class_1: 0.8785 - val_dice_class_2: 0.8469 - val_dice_coef_multiclass: 0.9970 - val_iou_class_0: 0.9982 - val_iou_class_1: 0.7845 - val_iou_class_2: 0.7368 - val_iou_coef_multiclass: 0.9940 - val_loss: 0.1796 - learning_rate: 5.0000e-04
# Epoch 9/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9975 - dice_class_0: 0.9992 - dice_class_1: 0.9004 - dice_class_2: 0.8874 - dice_coef_multiclass: 0.9974 - iou_class_0: 0.9984 - iou_class_1: 0.8195 - iou_class_2: 0.7990 - iou_coef_multiclass: 0.9948 - loss: 0.1462
# Epoch 9: val_loss improved from 0.17960 to 0.14430, saving model to results/Deeper_Focal_MC_MSCA_LBFR.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 182ms/step - accuracy: 0.9975 - dice_class_0: 0.9992 - dice_class_1: 0.9004 - dice_class_2: 0.8874 - dice_coef_multiclass: 0.9974 - iou_class_0: 0.9984 - iou_class_1: 0.8195 - iou_class_2: 0.7990 - iou_coef_multiclass: 0.9948 - loss: 0.1462 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9033 - val_dice_class_2: 0.8846 - val_dice_coef_multiclass: 0.9975 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.8243 - val_iou_class_2: 0.7947 - val_iou_coef_multiclass: 0.9951 - val_loss: 0.1443 - learning_rate: 5.0000e-04
# Epoch 10/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9070 - dice_class_2: 0.8931 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9985 - iou_class_1: 0.8303 - iou_class_2: 0.8080 - iou_coef_multiclass: 0.9952 - loss: 0.1378
# Epoch 10: val_loss did not improve from 0.14430
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 156ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9070 - dice_class_2: 0.8931 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9985 - iou_class_1: 0.8303 - iou_class_2: 0.8080 - iou_coef_multiclass: 0.9952 - loss: 0.1378 - val_accuracy: 0.9975 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8934 - val_dice_class_2: 0.8784 - val_dice_coef_multiclass: 0.9974 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.8085 - val_iou_class_2: 0.7850 - val_iou_coef_multiclass: 0.9949 - val_loss: 0.1528 - learning_rate: 5.0000e-04
# Epoch 11/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9055 - dice_class_2: 0.8946 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9986 - iou_class_1: 0.8281 - iou_class_2: 0.8105 - iou_coef_multiclass: 0.9952 - loss: 0.1376
# Epoch 11: val_loss did not improve from 0.14430
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 156ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9056 - dice_class_2: 0.8946 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9986 - iou_class_1: 0.8281 - iou_class_2: 0.8105 - iou_coef_multiclass: 0.9952 - loss: 0.1376 - val_accuracy: 0.9971 - val_dice_class_0: 0.9991 - val_dice_class_1: 0.8798 - val_dice_class_2: 0.8496 - val_dice_coef_multiclass: 0.9971 - val_iou_class_0: 0.9982 - val_iou_class_1: 0.7868 - val_iou_class_2: 0.7414 - val_iou_coef_multiclass: 0.9943 - val_loss: 0.1782 - learning_rate: 5.0000e-04
# Epoch 12/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9086 - dice_class_2: 0.8980 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9986 - iou_class_1: 0.8330 - iou_class_2: 0.8160 - iou_coef_multiclass: 0.9953 - loss: 0.1321
# Epoch 12: val_loss did not improve from 0.14430
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 155ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9086 - dice_class_2: 0.8981 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9986 - iou_class_1: 0.8330 - iou_class_2: 0.8160 - iou_coef_multiclass: 0.9953 - loss: 0.1321 - val_accuracy: 0.9975 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8969 - val_dice_class_2: 0.8767 - val_dice_coef_multiclass: 0.9975 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8144 - val_iou_class_2: 0.7832 - val_iou_coef_multiclass: 0.9949 - val_loss: 0.1502 - learning_rate: 5.0000e-04
# Epoch 13/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9150 - dice_class_2: 0.9078 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9986 - iou_class_1: 0.8440 - iou_class_2: 0.8320 - iou_coef_multiclass: 0.9956 - loss: 0.1222
# Epoch 13: val_loss improved from 0.14430 to 0.14202, saving model to results/Deeper_Focal_MC_MSCA_LBFR.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 181ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9150 - dice_class_2: 0.9078 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9986 - iou_class_1: 0.8440 - iou_class_2: 0.8321 - iou_coef_multiclass: 0.9956 - loss: 0.1222 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9028 - val_dice_class_2: 0.8849 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8241 - val_iou_class_2: 0.7952 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1420 - learning_rate: 1.5000e-04
# Epoch 14/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9218 - dice_class_2: 0.9155 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8553 - iou_class_2: 0.8449 - iou_coef_multiclass: 0.9960 - loss: 0.1144
# Epoch 14: val_loss did not improve from 0.14202
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 156ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9218 - dice_class_2: 0.9155 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8553 - iou_class_2: 0.8449 - iou_coef_multiclass: 0.9960 - loss: 0.1144 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9021 - val_dice_class_2: 0.8644 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8224 - val_iou_class_2: 0.7632 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1520 - learning_rate: 1.5000e-04
# Epoch 15/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9203 - dice_class_2: 0.9138 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8530 - iou_class_2: 0.8420 - iou_coef_multiclass: 0.9959 - loss: 0.1157
# Epoch 15: val_loss did not improve from 0.14202
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 155ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9203 - dice_class_2: 0.9138 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8530 - iou_class_2: 0.8421 - iou_coef_multiclass: 0.9959 - loss: 0.1157 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9037 - val_dice_class_2: 0.8821 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8250 - val_iou_class_2: 0.7905 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1422 - learning_rate: 1.5000e-04
# Epoch 16/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9241 - dice_class_2: 0.9191 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8595 - iou_class_2: 0.8514 - iou_coef_multiclass: 0.9961 - loss: 0.1093
# Epoch 16: val_loss did not improve from 0.14202
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 4.500000213738531e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 156ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9241 - dice_class_2: 0.9191 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8595 - iou_class_2: 0.8514 - iou_coef_multiclass: 0.9961 - loss: 0.1093 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9016 - val_dice_class_2: 0.8765 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8215 - val_iou_class_2: 0.7818 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1485 - learning_rate: 1.5000e-04
# Epoch 17/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9296 - dice_class_2: 0.9275 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8687 - iou_class_2: 0.8654 - iou_coef_multiclass: 0.9964 - loss: 0.1017
# Epoch 17: val_loss improved from 0.14202 to 0.13207, saving model to results/Deeper_Focal_MC_MSCA_LBFR.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 180ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9296 - dice_class_2: 0.9275 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8687 - iou_class_2: 0.8653 - iou_coef_multiclass: 0.9964 - loss: 0.1017 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9120 - val_dice_class_2: 0.8908 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8389 - val_iou_class_2: 0.8043 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1321 - learning_rate: 4.5000e-05
# Epoch 18/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9297 - dice_class_2: 0.9291 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8689 - iou_class_2: 0.8682 - iou_coef_multiclass: 0.9964 - loss: 0.0992
# Epoch 18: val_loss did not improve from 0.13207
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 155ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9297 - dice_class_2: 0.9290 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8689 - iou_class_2: 0.8681 - iou_coef_multiclass: 0.9964 - loss: 0.0992 - val_accuracy: 0.9977 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9059 - val_dice_class_2: 0.8822 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8290 - val_iou_class_2: 0.7904 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1421 - learning_rate: 4.5000e-05
# Epoch 19/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9293 - dice_class_2: 0.9260 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8683 - iou_class_2: 0.8628 - iou_coef_multiclass: 0.9963 - loss: 0.1014
# Epoch 19: val_loss improved from 0.13207 to 0.13206, saving model to results/Deeper_Focal_MC_MSCA_LBFR.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 181ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9293 - dice_class_2: 0.9260 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8683 - iou_class_2: 0.8628 - iou_coef_multiclass: 0.9963 - loss: 0.1014 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9111 - val_dice_class_2: 0.8907 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8376 - val_iou_class_2: 0.8046 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1321 - learning_rate: 4.5000e-05
# Epoch 20/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9327 - dice_class_2: 0.9335 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8742 - iou_class_2: 0.8756 - iou_coef_multiclass: 0.9965 - loss: 0.0949
# Epoch 20: val_loss did not improve from 0.13206
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1.3500000204658135e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 156ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9327 - dice_class_2: 0.9334 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8742 - iou_class_2: 0.8756 - iou_coef_multiclass: 0.9965 - loss: 0.0949 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9125 - val_dice_class_2: 0.8886 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8397 - val_iou_class_2: 0.8013 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1346 - learning_rate: 4.5000e-05
# Epoch 21/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9317 - dice_class_2: 0.9342 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8725 - iou_class_2: 0.8772 - iou_coef_multiclass: 0.9965 - loss: 0.0956
# Epoch 21: val_loss did not improve from 0.13206
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 156ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9317 - dice_class_2: 0.9342 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8725 - iou_class_2: 0.8772 - iou_coef_multiclass: 0.9965 - loss: 0.0956 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9093 - val_dice_class_2: 0.8877 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8344 - val_iou_class_2: 0.7995 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1361 - learning_rate: 1.3500e-05
# Epoch 22/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9334 - dice_class_2: 0.9351 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8753 - iou_class_2: 0.8787 - iou_coef_multiclass: 0.9966 - loss: 0.0932
# Epoch 22: val_loss improved from 0.13206 to 0.13163, saving model to results/Deeper_Focal_MC_MSCA_LBFR.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 180ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9334 - dice_class_2: 0.9351 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8753 - iou_class_2: 0.8787 - iou_coef_multiclass: 0.9966 - loss: 0.0932 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9108 - val_dice_class_2: 0.8928 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8371 - val_iou_class_2: 0.8079 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1316 - learning_rate: 1.3500e-05
# Epoch 23/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9339 - dice_class_2: 0.9329 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8765 - iou_class_2: 0.8750 - iou_coef_multiclass: 0.9966 - loss: 0.0937
# Epoch 23: val_loss did not improve from 0.13163
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 156ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9339 - dice_class_2: 0.9329 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8765 - iou_class_2: 0.8750 - iou_coef_multiclass: 0.9966 - loss: 0.0937 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9134 - val_dice_class_2: 0.8929 - val_dice_coef_multiclass: 0.9979 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8410 - val_iou_class_2: 0.8081 - val_iou_coef_multiclass: 0.9958 - val_loss: 0.1317 - learning_rate: 1.3500e-05
# Epoch 24/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9323 - dice_class_2: 0.9319 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8737 - iou_class_2: 0.8737 - iou_coef_multiclass: 0.9965 - loss: 0.0952
# Epoch 24: val_loss improved from 0.13163 to 0.13080, saving model to results/Deeper_Focal_MC_MSCA_LBFR.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 181ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9323 - dice_class_2: 0.9320 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8737 - iou_class_2: 0.8737 - iou_coef_multiclass: 0.9965 - loss: 0.0952 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9142 - val_dice_class_2: 0.8944 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8427 - val_iou_class_2: 0.8107 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1308 - learning_rate: 1.3500e-05
# Epoch 25/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9308 - dice_class_2: 0.9317 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8709 - iou_class_2: 0.8731 - iou_coef_multiclass: 0.9965 - loss: 0.0973
# Epoch 25: val_loss did not improve from 0.13080
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 156ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9308 - dice_class_2: 0.9318 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8709 - iou_class_2: 0.8731 - iou_coef_multiclass: 0.9965 - loss: 0.0972 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9073 - val_dice_class_2: 0.8912 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8312 - val_iou_class_2: 0.8054 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1362 - learning_rate: 1.3500e-05
# Epoch 26/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9355 - dice_class_2: 0.9392 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8790 - iou_class_2: 0.8857 - iou_coef_multiclass: 0.9967 - loss: 0.0900
# Epoch 26: val_loss did not improve from 0.13080
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 156ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9355 - dice_class_2: 0.9391 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8790 - iou_class_2: 0.8857 - iou_coef_multiclass: 0.9967 - loss: 0.0900 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9094 - val_dice_class_2: 0.8822 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8347 - val_iou_class_2: 0.7914 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1400 - learning_rate: 1.3500e-05
# Epoch 27/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9358 - dice_class_2: 0.9380 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8795 - iou_class_2: 0.8836 - iou_coef_multiclass: 0.9967 - loss: 0.0897
# Epoch 27: val_loss improved from 0.13080 to 0.13072, saving model to results/Deeper_Focal_MC_MSCA_LBFR.keras
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 4.050000006827758e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 181ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9357 - dice_class_2: 0.9379 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8795 - iou_class_2: 0.8835 - iou_coef_multiclass: 0.9967 - loss: 0.0897 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9124 - val_dice_class_2: 0.8940 - val_dice_coef_multiclass: 0.9979 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8397 - val_iou_class_2: 0.8098 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1307 - learning_rate: 1.3500e-05
# Epoch 28/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9344 - dice_class_2: 0.9380 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8772 - iou_class_2: 0.8838 - iou_coef_multiclass: 0.9966 - loss: 0.0912
# Epoch 28: val_loss improved from 0.13072 to 0.12902, saving model to results/Deeper_Focal_MC_MSCA_LBFR.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 181ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9344 - dice_class_2: 0.9380 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8772 - iou_class_2: 0.8838 - iou_coef_multiclass: 0.9966 - loss: 0.0912 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9135 - val_dice_class_2: 0.8989 - val_dice_coef_multiclass: 0.9979 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8416 - val_iou_class_2: 0.8176 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1290 - learning_rate: 4.0500e-06
# Epoch 29/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9347 - dice_class_2: 0.9324 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8776 - iou_class_2: 0.8745 - iou_coef_multiclass: 0.9966 - loss: 0.0931
# Epoch 29: val_loss did not improve from 0.12902
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 156ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9347 - dice_class_2: 0.9324 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8776 - iou_class_2: 0.8745 - iou_coef_multiclass: 0.9966 - loss: 0.0931 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9085 - val_dice_class_2: 0.8851 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8331 - val_iou_class_2: 0.7956 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1378 - learning_rate: 4.0500e-06
# Epoch 30/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9327 - dice_class_2: 0.9350 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8743 - iou_class_2: 0.8788 - iou_coef_multiclass: 0.9966 - loss: 0.0934
# Epoch 30: val_loss did not improve from 0.12902
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 155ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9327 - dice_class_2: 0.9351 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8743 - iou_class_2: 0.8788 - iou_coef_multiclass: 0.9966 - loss: 0.0934 - val_accuracy: 0.9980 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9146 - val_dice_class_2: 0.8912 - val_dice_coef_multiclass: 0.9979 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8433 - val_iou_class_2: 0.8057 - val_iou_coef_multiclass: 0.9958 - val_loss: 0.1307 - learning_rate: 4.0500e-06
# Epoch 31/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9339 - dice_class_2: 0.9357 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8762 - iou_class_2: 0.8801 - iou_coef_multiclass: 0.9966 - loss: 0.0918
# Epoch 31: val_loss did not improve from 0.12902
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.2149999747634864e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 156ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9339 - dice_class_2: 0.9357 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8762 - iou_class_2: 0.8802 - iou_coef_multiclass: 0.9966 - loss: 0.0918 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9091 - val_dice_class_2: 0.8938 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8340 - val_iou_class_2: 0.8095 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1319 - learning_rate: 4.0500e-06
# Epoch 32/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9364 - dice_class_2: 0.9380 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8807 - iou_class_2: 0.8837 - iou_coef_multiclass: 0.9967 - loss: 0.0895
# Epoch 32: val_loss did not improve from 0.12902
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 156ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9364 - dice_class_2: 0.9380 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8807 - iou_class_2: 0.8837 - iou_coef_multiclass: 0.9967 - loss: 0.0895 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9082 - val_dice_class_2: 0.8845 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8323 - val_iou_class_2: 0.7941 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1403 - learning_rate: 1.2150e-06
# Epoch 33/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9363 - dice_class_2: 0.9382 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8805 - iou_class_2: 0.8842 - iou_coef_multiclass: 0.9967 - loss: 0.0897
# Epoch 33: val_loss improved from 0.12902 to 0.12810, saving model to results/Deeper_Focal_MC_MSCA_LBFR.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 181ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9363 - dice_class_2: 0.9382 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8805 - iou_class_2: 0.8842 - iou_coef_multiclass: 0.9967 - loss: 0.0897 - val_accuracy: 0.9980 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9153 - val_dice_class_2: 0.8980 - val_dice_coef_multiclass: 0.9979 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8444 - val_iou_class_2: 0.8166 - val_iou_coef_multiclass: 0.9958 - val_loss: 0.1281 - learning_rate: 1.2150e-06
# Epoch 34/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9358 - dice_class_2: 0.9375 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8796 - iou_class_2: 0.8832 - iou_coef_multiclass: 0.9966 - loss: 0.0901
# Epoch 34: val_loss did not improve from 0.12810
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 157ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9357 - dice_class_2: 0.9375 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8795 - iou_class_2: 0.8832 - iou_coef_multiclass: 0.9966 - loss: 0.0901 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9110 - val_dice_class_2: 0.8895 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8375 - val_iou_class_2: 0.8025 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1348 - learning_rate: 1.2150e-06
# Epoch 35/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9392 - dice_class_2: 0.9403 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8856 - iou_class_2: 0.8879 - iou_coef_multiclass: 0.9969 - loss: 0.0862
# Epoch 35: val_loss did not improve from 0.12810
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 155ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9392 - dice_class_2: 0.9403 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8856 - iou_class_2: 0.8879 - iou_coef_multiclass: 0.9969 - loss: 0.0863 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9111 - val_dice_class_2: 0.8917 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8373 - val_iou_class_2: 0.8061 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1332 - learning_rate: 1.2150e-06
# Epoch 36/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9362 - dice_class_2: 0.9364 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8803 - iou_class_2: 0.8811 - iou_coef_multiclass: 0.9967 - loss: 0.0901
# Epoch 36: val_loss did not improve from 0.12810
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 3.644999992502562e-07.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 156ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9362 - dice_class_2: 0.9364 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8803 - iou_class_2: 0.8811 - iou_coef_multiclass: 0.9967 - loss: 0.0901 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9094 - val_dice_class_2: 0.8901 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8350 - val_iou_class_2: 0.8049 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1342 - learning_rate: 1.2150e-06
# Epoch 37/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9378 - dice_class_2: 0.9397 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8833 - iou_class_2: 0.8868 - iou_coef_multiclass: 0.9968 - loss: 0.0871
# Epoch 37: val_loss did not improve from 0.12810
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 156ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9378 - dice_class_2: 0.9397 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8832 - iou_class_2: 0.8868 - iou_coef_multiclass: 0.9968 - loss: 0.0871 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9139 - val_dice_class_2: 0.8958 - val_dice_coef_multiclass: 0.9979 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8420 - val_iou_class_2: 0.8125 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1292 - learning_rate: 3.6450e-07
# Epoch 38/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9351 - dice_class_2: 0.9382 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8785 - iou_class_2: 0.8845 - iou_coef_multiclass: 0.9967 - loss: 0.0905
# Epoch 38: val_loss did not improve from 0.12810
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 157ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9351 - dice_class_2: 0.9382 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8785 - iou_class_2: 0.8845 - iou_coef_multiclass: 0.9967 - loss: 0.0905 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9081 - val_dice_class_2: 0.8854 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8325 - val_iou_class_2: 0.7956 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1370 - learning_rate: 3.6450e-07
# Epoch 39/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9352 - dice_class_2: 0.9367 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8786 - iou_class_2: 0.8816 - iou_coef_multiclass: 0.9967 - loss: 0.0907
# Epoch 39: val_loss did not improve from 0.12810
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.0935000318568199e-07.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 156ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9352 - dice_class_2: 0.9367 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8786 - iou_class_2: 0.8816 - iou_coef_multiclass: 0.9967 - loss: 0.0907 - val_accuracy: 0.9980 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9140 - val_dice_class_2: 0.8972 - val_dice_coef_multiclass: 0.9979 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8422 - val_iou_class_2: 0.8142 - val_iou_coef_multiclass: 0.9958 - val_loss: 0.1303 - learning_rate: 3.6450e-07
# Epoch 40/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9355 - dice_class_2: 0.9392 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8791 - iou_class_2: 0.8858 - iou_coef_multiclass: 0.9967 - loss: 0.0894
# Epoch 40: val_loss did not improve from 0.12810
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 156ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9355 - dice_class_2: 0.9392 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8791 - iou_class_2: 0.8858 - iou_coef_multiclass: 0.9967 - loss: 0.0894 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9112 - val_dice_class_2: 0.8877 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8376 - val_iou_class_2: 0.7997 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1345 - learning_rate: 1.0935e-07
# Epoch 41/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9348 - dice_class_2: 0.9379 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8779 - iou_class_2: 0.8839 - iou_coef_multiclass: 0.9966 - loss: 0.0904
# Epoch 41: val_loss did not improve from 0.12810
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 156ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9348 - dice_class_2: 0.9379 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8779 - iou_class_2: 0.8839 - iou_coef_multiclass: 0.9966 - loss: 0.0904 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9108 - val_dice_class_2: 0.8942 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8369 - val_iou_class_2: 0.8102 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1323 - learning_rate: 1.0935e-07
# Epoch 42/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9340 - dice_class_2: 0.9362 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8764 - iou_class_2: 0.8808 - iou_coef_multiclass: 0.9966 - loss: 0.0913
# Epoch 42: val_loss did not improve from 0.12810
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1e-07.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 156ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9340 - dice_class_2: 0.9362 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8764 - iou_class_2: 0.8809 - iou_coef_multiclass: 0.9966 - loss: 0.0913 - val_accuracy: 0.9977 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9063 - val_dice_class_2: 0.8837 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8297 - val_iou_class_2: 0.7937 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1404 - learning_rate: 1.0935e-07
# Epoch 43/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9355 - dice_class_2: 0.9384 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8791 - iou_class_2: 0.8844 - iou_coef_multiclass: 0.9967 - loss: 0.0901
# Epoch 43: val_loss did not improve from 0.12810
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 156ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9355 - dice_class_2: 0.9384 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8791 - iou_class_2: 0.8844 - iou_coef_multiclass: 0.9967 - loss: 0.0901 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9127 - val_dice_class_2: 0.8930 - val_dice_coef_multiclass: 0.9979 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8402 - val_iou_class_2: 0.8082 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1314 - learning_rate: 1.0000e-07
# Epoch 43: early stopping
# Restoring model weights from the end of the best epoch: 33.
# ✓ Training completed
#
# Generating visualizations...
#   ✓ Saved: results/Deeper_Focal_MC_MSCA_LBFR_training_curves.png
#   ✓ Saved: results/Deeper_Focal_MC_MSCA_LBFR_history.png
# E0000 00:00:1763479848.320762     100 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763479848.576748     100 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#   ✓ Saved: results/Deeper_Focal_MC_MSCA_LBFR_predictions.png
# ================================================================================
# EVALUATION: Deeper+Focal+MC+MSCA+LBFR
# ================================================================================
#   ✓ Saved: results/Deeper+Focal+MC+MSCA+LBFR_confusion_matrices.png
# Confusion Matrix:
# [[25768236    16754        0]
#  [   14284   290609    10178]
#  [      26    13238   101075]]
#
# Normalized Confusion Matrix:
# [[0.999 0.001 0.   ]
#  [0.045 0.922 0.032]
#  [0.    0.116 0.884]]
#
# Precision, Recall, F1 Score per class:
#   Background: Precision=0.9994, Recall=0.9994, F1=0.9994
#   Disc: Precision=0.9065, Recall=0.9224, F1=0.9143
#   Cup: Precision=0.9085, Recall=0.8840, F1=0.8961
#
# Macro-averaged metrics:
#   Precision: 0.9381
#   Recall: 0.9352
#   F1 Score: 0.9366
#   Background: Dice=0.9994, IoU=0.9988
#   Disc: Dice=0.9143, IoU=0.8422
#   Cup: Dice=0.8961, IoU=0.8117
#
# MC Dropout Evaluation:
#
# Running MC Dropout with 10 stochastic forward passes...
#   Completed: 5/10 forward passes
#   Completed: 10/10 forward passes
# ✓ MC Dropout completed
#   Background uncertainty: 0.0002
#   Disc uncertainty: 0.0004
#   Cup uncertainty: 0.0002
#
# ====================================================================================================
#                                 ✓ TRAINING AND EVALUATION COMPLETED!
# ====================================================================================================
#
# Model: Deeper + Focal + EIoU + MC Dropout + MSCA + LBFR
# Dual Enhancement: MSCA (Multi-scale Context) + LBFR (Bidirectional Recalibration)
# MSCA: Multi-scale dilated convolutions with rates [1, 2, 3, 5]
# LBFR: Channel + Spatial attention + Recalibration
# Total Attention Blocks: 8 (4 MSCA + 4 LBFR)
# Parameters: 41,014,667
# Results saved in: results/
#
# ====================================================================================================
