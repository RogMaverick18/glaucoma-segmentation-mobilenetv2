# %%
"""
COMBINED ADVANCED MOBILENET-UNET WITH SKIP-ONLY CBAM ATTENTION
================================================================
This combines:
1. Deeper decoder architecture with enhanced blocks
2. Focal-EIoU loss
3. MC Dropout for uncertainty estimation
4. CBAM (Convolutional Block Attention Module) - SKIP-ONLY VERSION
   - Applied ONLY to: Skip connections (4 locations)
   - REMOVED from: bridge, decoder blocks, final layer
   - This applies attention to encoder features before they merge with decoder

STRATEGY: Place CBAM only on skip connections to refine encoder features
before concatenation with decoder features, allowing better feature fusion.
"""

import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, backend as K
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import albumentations as A
import warnings
import gc
warnings.filterwarnings('ignore')

plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# ============================================================================
# HELPER FUNCTIONS
# ============================================================================

def configure_gpu():
    """Configure GPU settings for optimal performance"""
    print("Configuring GPU settings...")
    physical_devices = tf.config.list_physical_devices('GPU')
    if physical_devices:
        try:
            for gpu in physical_devices:
                tf.config.experimental.set_memory_growth(gpu, True)
            tf.config.set_visible_devices(physical_devices[0], 'GPU')
            print(f"✓ GPU found: {physical_devices}")
            print("  GPU device name:", tf.test.gpu_device_name())
            return True
        except RuntimeError as e:
            print(f"✗ GPU error: {e}")
            return False
    else:
        print("✗ No GPU found, using CPU")
        return False

def load_images_masks(images_folder, masks_folder, img_size=(256,256)):
    """Load images and masks from folders"""
    images, masks = [], []
    image_files = sorted(os.listdir(images_folder))
    mask_files = sorted(os.listdir(masks_folder))
    mask_dict = {os.path.splitext(f)[0]: f for f in mask_files}
    
    for img_file in image_files:
        base = os.path.splitext(img_file)[0]
        if base in mask_dict:
            img = cv2.imread(os.path.join(images_folder, img_file))
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, img_size) / 255.0
            
            mask = cv2.imread(os.path.join(masks_folder, mask_dict[base]), cv2.IMREAD_GRAYSCALE)
            mask = cv2.resize(mask, img_size)
            unique_vals = np.unique(mask)
            if len(unique_vals) > 3 or np.max(unique_vals) > 2:
                mask = np.clip(mask // 85, 0, 2).astype(np.uint8)
            
            images.append(img)
            masks.append(mask)
    
    return np.array(images, dtype=np.float32), np.array(masks, dtype=np.uint8)

def load_all_data(root_dir):
    """Load all data from existing splits and merge"""
    all_images, all_masks = [], []
    for split in ["train", "val", "test"]:
        print(f"Loading {split} data...")
        imgs, msks = load_images_masks(
            os.path.join(root_dir, split, "Images"),
            os.path.join(root_dir, split, "Masks")
        )
        all_images.append(imgs)
        all_masks.append(msks)
        print(f"  {split}: {imgs.shape[0]} samples")
    
    return np.concatenate(all_images), np.concatenate(all_masks)

def create_new_split(all_images, all_masks):
    """Create new split: 600 train, 200 val, 400 test"""
    X_temp, X_test, y_temp, y_test = train_test_split(
        all_images, all_masks, test_size=400, random_state=42
    )
    X_train, X_val, y_train, y_val = train_test_split(
        X_temp, y_temp, test_size=200, random_state=42
    )
    print(f"Split - Train: {X_train.shape[0]}, Val: {X_val.shape[0]}, Test: {X_test.shape[0]}")
    return (X_train, y_train), (X_val, y_val), (X_test, y_test)

def setup_augmentations():
    return A.Compose([
        A.RandomBrightnessContrast(brightness_limit=0.15, contrast_limit=0.15, p=0.7),
        A.HueSaturationValue(hue_shift_limit=10, sat_shift_limit=15, val_shift_limit=10, p=0.5),
        A.GaussianBlur(blur_limit=3, p=0.3),
        A.RandomGamma(gamma_limit=(80, 120), p=0.3),
    ])

def data_generator(images, masks, batch_size, augment=None):
    idxs = np.arange(len(images))
    while True:
        np.random.shuffle(idxs)
        for i in range(0, len(images), batch_size):
            batch_idxs = idxs[i:i+batch_size]
            batch_x, batch_y = [], []
            
            for idx in batch_idxs:
                img, mask = images[idx], masks[idx]
                
                if augment:
                    aug = augment(image=img, mask=mask)
                    img_aug, mask_aug = aug['image'], aug['mask']
                else:
                    img_aug, mask_aug = img, mask
                
                mask_cat = to_categorical(mask_aug, num_classes=3)
                batch_x.append(img_aug)
                batch_y.append(mask_cat)
            
            batch_x = np.stack(batch_x).astype(np.float32)
            batch_y = np.stack(batch_y).astype(np.float32)
            
            yield batch_x, batch_y

# ============================================================================
# CBAM ATTENTION MODULES
# ============================================================================

def channel_attention(input_feature, ratio=8, name=""):
    """Channel Attention Module (CAM)"""
    channel = input_feature.shape[-1]
    
    shared_layer_one = layers.Dense(channel//ratio, activation='relu', name=f'channel_attention_dense1_{name}')
    shared_layer_two = layers.Dense(channel, activation='sigmoid', name=f'channel_attention_dense2_{name}')
    
    avg_pool = layers.GlobalAveragePooling2D()(input_feature)
    avg_pool = layers.Reshape((1, 1, channel))(avg_pool)
    avg_pool = shared_layer_one(avg_pool)
    avg_pool = shared_layer_two(avg_pool)
    
    max_pool = layers.GlobalMaxPooling2D()(input_feature)
    max_pool = layers.Reshape((1, 1, channel))(max_pool)
    max_pool = shared_layer_one(max_pool)
    max_pool = shared_layer_two(max_pool)
    
    cbam_feature = layers.Add()([avg_pool, max_pool])
    cbam_feature = layers.Multiply()([input_feature, cbam_feature])
    
    return cbam_feature

def spatial_attention(input_feature, name=""):
    """Spatial Attention Module (SAM)"""
    kernel_size = 7
    
    avg_pool = layers.Lambda(lambda x: tf.reduce_mean(x, axis=3, keepdims=True))(input_feature)
    max_pool = layers.Lambda(lambda x: tf.reduce_max(x, axis=3, keepdims=True))(input_feature)
    concat = layers.Concatenate(axis=3)([avg_pool, max_pool])
    
    cbam_feature = layers.Conv2D(filters=1, kernel_size=kernel_size, strides=1, 
                                padding='same', activation='sigmoid', 
                                name=f'spatial_attention_conv_{name}')(concat)
    cbam_feature = layers.Multiply()([input_feature, cbam_feature])
    
    return cbam_feature

def cbam_block(cbam_feature, ratio=8, name=""):
    """CBAM: Convolutional Block Attention Module (Channel + Spatial)"""
    cbam_feature = channel_attention(cbam_feature, ratio, name=f"{name}_channel")
    cbam_feature = spatial_attention(cbam_feature, name=f"{name}_spatial")
    return cbam_feature

# ============================================================================
# LOSS FUNCTIONS
# ============================================================================

def focal_loss(y_true, y_pred, gamma=2.0, alpha=None, epsilon=1e-7):
    if alpha is None:
        alpha = [0.25, 1.0, 1.0]
    
    y_pred = K.clip(y_pred, epsilon, 1.0 - epsilon)
    focal_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        pt = y_pred_c
        focal_weight = K.pow(1.0 - pt, gamma)
        cross_entropy = -K.log(pt)
        focal_loss_c = alpha[c] * focal_weight * cross_entropy * y_true_c
        focal_loss_value += K.mean(focal_loss_c)
    
    return focal_loss_value

def enhanced_iou_loss(y_true, y_pred, smooth=1e-7):
    eiou_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        
        intersection = K.sum(y_true_c * y_pred_c, axis=[1, 2])
        union = K.sum(y_true_c, axis=[1, 2]) + K.sum(y_pred_c, axis=[1, 2]) - intersection
        iou = (intersection + smooth) / (union + smooth)
        
        height = K.cast(K.shape(y_true_c)[1], 'float32')
        width = K.cast(K.shape(y_true_c)[2], 'float32')
        
        y_coords = K.arange(0, height)
        x_coords = K.arange(0, width)
        y_grid = K.tile(K.reshape(y_coords, (-1, 1)), (1, K.cast(width, 'int32')))
        x_grid = K.tile(K.reshape(x_coords, (1, -1)), (K.cast(height, 'int32'), 1))
        y_grid = K.cast(y_grid, 'float32')
        x_grid = K.cast(x_grid, 'float32')
        
        true_mass = K.sum(y_true_c, axis=[1, 2]) + smooth
        true_center_y = K.sum(y_true_c * y_grid, axis=[1, 2]) / true_mass
        true_center_x = K.sum(y_true_c * x_grid, axis=[1, 2]) / true_mass
        
        pred_mass = K.sum(y_pred_c, axis=[1, 2]) + smooth
        pred_center_y = K.sum(y_pred_c * y_grid, axis=[1, 2]) / pred_mass
        pred_center_x = K.sum(y_pred_c * x_grid, axis=[1, 2]) / pred_mass
        
        center_distance = K.square(true_center_y - pred_center_y) + K.square(true_center_x - pred_center_x)
        diagonal = K.square(height) + K.square(width)
        center_penalty = center_distance / (diagonal + smooth)
        
        true_width = K.sqrt(K.sum(K.sum(y_true_c, axis=1), axis=1) + smooth)
        true_height = K.sqrt(K.sum(K.sum(y_true_c, axis=2), axis=1) + smooth)
        pred_width = K.sqrt(K.sum(K.sum(y_pred_c, axis=1), axis=1) + smooth)
        pred_height = K.sqrt(K.sum(K.sum(y_pred_c, axis=2), axis=1) + smooth)
        
        width_diff = K.square(pred_width - true_width)
        height_diff = K.square(pred_height - true_height)
        aspect_penalty = width_diff / (K.square(width) + smooth) + height_diff / (K.square(height) + smooth)
        
        eiou_c = 1.0 - iou + center_penalty + aspect_penalty
        eiou_loss_value += K.mean(eiou_c)
    
    return eiou_loss_value / 3.0

def focal_eiou_combined_loss(y_true, y_pred, focal_weight=1.0, eiou_weight=1.0, gamma=2.0, alpha=None):
    fl = focal_loss(y_true, y_pred, gamma=gamma, alpha=alpha)
    eiou = enhanced_iou_loss(y_true, y_pred)
    return focal_weight * fl + eiou_weight * eiou

# ============================================================================
# ENHANCED DECODER BLOCK (WITHOUT CBAM - for skip-only version)
# ============================================================================

def enhanced_decoder_block_no_cbam(x, skip_connection, filters, block_name, dropout_rate=0.3):
    """Enhanced decoder block WITHOUT CBAM attention"""
    x = layers.UpSampling2D((2, 2), name=f'{block_name}_upsample')(x)
    
    if skip_connection.shape[-1] != x.shape[-1]:
        skip_connection = layers.Conv2D(x.shape[-1], (1, 1), activation='relu', 
                                      padding='same', name=f'{block_name}_skip_align')(skip_connection)
        skip_connection = layers.BatchNormalization(name=f'{block_name}_skip_bn')(skip_connection)
    
    x = layers.Concatenate(name=f'{block_name}_concat')([x, skip_connection])
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv1')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn1')(x)
    x = layers.Dropout(dropout_rate, name=f'{block_name}_dropout')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv2')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn2')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv3')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn3')(x)
    
    residual = x
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv4')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn4')(x)
    
    x = layers.Add(name=f'{block_name}_residual')([x, residual])
    x = layers.Conv2D(filters, (1, 1), activation='relu', padding='same', name=f'{block_name}_conv_final')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn_final')(x)
    
    # NO CBAM in decoder blocks for skip-only version
    
    return x

# ============================================================================
# MODEL: SKIP-ONLY CBAM VERSION (4 blocks on skip connections)
# ============================================================================

def build_combined_unet_skip_only_cbam(input_shape=(256, 256, 3), num_classes=3, 
                                       use_deeper=False, dropout_rate=0.3):
    """
    Combined MobileNet-UNet with SKIP-ONLY CBAM
    
    CBAM Placement (SKIP-ONLY VERSION):
    - Skip_1 (128x128): YES ✅
    - Skip_2 (64x64): YES ✅
    - Skip_3 (32x32): YES ✅
    - Skip_4 (16x16): YES ✅
    - Bridge: NO CBAM ❌
    - Decoder blocks: NO CBAM ❌
    - Final layer: NO CBAM ❌
    Total: 4 CBAM blocks (on skip connections only)
    
    Rationale: Apply attention to encoder features before they merge with decoder,
    allowing the network to select important features for skip connections.
    """
    
    print(f"\nBuilding Combined UNet with SKIP-ONLY CBAM...")
    print(f"  Deeper Architecture: {use_deeper}")
    print(f"  MC Dropout Rate: {dropout_rate}")
    print(f"  CBAM Attention: SKIP-ONLY (4 blocks on skip connections)")
    
    inputs = layers.Input(input_shape, dtype='float32')
    backbone = MobileNetV2(input_tensor=inputs, weights='imagenet', include_top=False)
    
    # Get skip connections and apply CBAM
    skip_1_raw = backbone.get_layer('block_1_expand_relu').output  # 128x128
    skip_2_raw = backbone.get_layer('block_3_expand_relu').output  # 64x64
    skip_3_raw = backbone.get_layer('block_6_expand_relu').output  # 32x32
    skip_4_raw = backbone.get_layer('block_13_expand_relu').output # 16x16
    bridge = backbone.output  # 8x8
    
    print("  Applying CBAM to skip connections...")
    print("    skip_1 (128x128): WITH CBAM ✓")
    print("    skip_2 (64x64): WITH CBAM ✓")
    print("    skip_3 (32x32): WITH CBAM ✓")
    print("    skip_4 (16x16): WITH CBAM ✓")
    
    # Apply CBAM to ALL skip connections
    skip_1 = cbam_block(skip_1_raw, ratio=8, name="skip1")
    skip_2 = cbam_block(skip_2_raw, ratio=8, name="skip2")
    skip_3 = cbam_block(skip_3_raw, ratio=8, name="skip3")
    skip_4 = cbam_block(skip_4_raw, ratio=8, name="skip4")
    
    # Deeper bridge (if enabled) - NO CBAM on bridge
    if use_deeper:
        bridge = layers.Conv2D(1024, (3, 3), activation='relu', padding='same')(bridge)
        bridge = layers.BatchNormalization()(bridge)
    
    if dropout_rate > 0:
        bridge = layers.Dropout(dropout_rate, name='bridge_dropout')(bridge)
    
    # NO CBAM on bridge
    
    if use_deeper:
        print("  Building deeper decoder WITHOUT CBAM (attention only on skips)...")
        # All decoder blocks WITHOUT CBAM
        x = enhanced_decoder_block_no_cbam(bridge, skip_4, 512, 'decoder_1', dropout_rate)
        x = enhanced_decoder_block_no_cbam(x, skip_3, 256, 'decoder_2', dropout_rate)
        x = enhanced_decoder_block_no_cbam(x, skip_2, 128, 'decoder_3', dropout_rate * 0.7)
        x = enhanced_decoder_block_no_cbam(x, skip_1, 64, 'decoder_4', dropout_rate * 0.5)
    else:
        print("  Building baseline decoder WITHOUT CBAM...")
        # Baseline decoder without CBAM
        x = layers.UpSampling2D((2, 2))(bridge)
        x = layers.Concatenate()([x, skip_4])
        x = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        if dropout_rate > 0:
            x = layers.Dropout(dropout_rate)(x)
        x = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        
        x = layers.UpSampling2D((2, 2))(x)
        x = layers.Concatenate()([x, skip_3])
        x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        if dropout_rate > 0:
            x = layers.Dropout(dropout_rate)(x)
        x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        
        x = layers.UpSampling2D((2, 2))(x)
        x = layers.Concatenate()([x, skip_2])
        x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        if dropout_rate > 0:
            x = layers.Dropout(dropout_rate * 0.7)(x)
        x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        
        x = layers.UpSampling2D((2, 2))(x)
        x = layers.Concatenate()([x, skip_1])
        x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        if dropout_rate > 0:
            x = layers.Dropout(dropout_rate * 0.5)(x)
        x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
    
    # Final upsampling - NO CBAM
    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    
    outputs = layers.Conv2D(num_classes, (1, 1), activation='softmax', dtype='float32')(x)
    
    model = models.Model(inputs, outputs)
    
    # Print configuration
    if dropout_rate > 0:
        dropout_layers = [layer for layer in model.layers if isinstance(layer, layers.Dropout)]
        print(f"\n  MC Dropout Configuration:")
        print(f"    Total Dropout Layers: {len(dropout_layers)}")
        print(f"    Dropout Rates: {[f'{layer.rate:.2f}' for layer in dropout_layers]}")
    
    cbam_count = sum(1 for layer in model.layers if 'channel_attention' in layer.name or 'spatial_attention' in layer.name)
    print(f"\n  CBAM Configuration (SKIP-ONLY):")
    print(f"    Total CBAM Components: {cbam_count}")
    print(f"    CBAM Locations: Skip connections ONLY (4 blocks)")
    print(f"    Removed CBAM from: Bridge, Decoder blocks, Final layer")
    
    return model

# ============================================================================
# METRICS
# ============================================================================

def dice_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    return (2. * intersection + smooth) / (K.sum(y_true_class) + K.sum(y_pred_class) + smooth)

def dice_class_0(y_true, y_pred): return dice_coef_class(y_true, y_pred, 0)
def dice_class_1(y_true, y_pred): return dice_coef_class(y_true, y_pred, 1)
def dice_class_2(y_true, y_pred): return dice_coef_class(y_true, y_pred, 2)

def iou_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    union = K.sum(y_true_class) + K.sum(y_pred_class) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_class_0(y_true, y_pred): return iou_coef_class(y_true, y_pred, 0)
def iou_class_1(y_true, y_pred): return iou_coef_class(y_true, y_pred, 1)
def iou_class_2(y_true, y_pred): return iou_coef_class(y_true, y_pred, 2)

# ============================================================================
# VISUALIZATION FUNCTIONS
# ============================================================================

def plot_training_history(history, model_name, save_dir='results'):
    """Plot training history: loss and accuracy curves"""
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    
    axes[0].plot(history.history['loss'], label='Training Loss', linewidth=2)
    axes[0].plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
    axes[0].set_title(f'{model_name} - Loss Over Epochs', fontsize=14, fontweight='bold')
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('Loss', fontsize=12)
    axes[0].legend(fontsize=10)
    axes[0].grid(True, alpha=0.3)
    
    axes[1].plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
    axes[1].plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
    axes[1].set_title(f'{model_name} - Accuracy Over Epochs', fontsize=14, fontweight='bold')
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('Accuracy', fontsize=12)
    axes[1].legend(fontsize=10)
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(f"{save_dir}/{model_name}_training_curves.png", dpi=300, bbox_inches='tight')
    print(f"\u2713 Training curves saved: {save_dir}/{model_name}_training_curves.png")
    plt.show()
    plt.close()

def plot_confusion_matrices(y_true, y_pred, model_name, save_dir='results'):
    """Plot confusion matrix and normalized confusion matrix"""
    y_true_labels = np.argmax(y_true, axis=-1).flatten()
    y_pred_labels = np.argmax(y_pred, axis=-1).flatten()
    
    cm = confusion_matrix(y_true_labels, y_pred_labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    class_names = ['Background', 'Disc', 'Cup']
    
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[0], cbar_kws={'label': 'Count'})
    axes[0].set_title(f'{model_name}\\nConfusion Matrix', fontsize=14, fontweight='bold')
    axes[0].set_ylabel('True Label', fontsize=12)
    axes[0].set_xlabel('Predicted Label', fontsize=12)
    
    sns.heatmap(cm_normalized, annot=True, fmt='.3f', cmap='Greens',
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[1], cbar_kws={'label': 'Proportion'})
    axes[1].set_title(f'{model_name}\\nNormalized Confusion Matrix', fontsize=14, fontweight='bold')
    axes[1].set_ylabel('True Label', fontsize=12)
    axes[1].set_xlabel('Predicted Label', fontsize=12)
    
    plt.tight_layout()
    plt.savefig(f"{save_dir}/{model_name}_confusion_matrices.png", dpi=300, bbox_inches='tight')
    print(f"\u2713 Confusion matrices saved: {save_dir}/{model_name}_confusion_matrices.png")
    plt.show()
    plt.close()
    
    print(f"\\nConfusion Matrix:")
    print(cm)
    print(f"\\nNormalized Confusion Matrix:")
    print(np.round(cm_normalized, 3))
    
    return cm, cm_normalized

# ============================================================================
# MC DROPOUT
# ============================================================================

def mc_dropout_predict(model, X, num_samples=15, batch_size=4, verbose=True):
    """MC Dropout prediction using training=True flag"""
    if verbose:
        print(f"\nRunning MC Dropout with {num_samples} stochastic forward passes...")
    
    predictions = []
    num_batches = int(np.ceil(len(X) / batch_size))
    
    for i in range(num_samples):
        if verbose and (i + 1) % 5 == 0:
            print(f"  Completed: {i+1}/{num_samples} forward passes")
        
        batch_preds = []
        for batch_idx in range(num_batches):
            start_idx = batch_idx * batch_size
            end_idx = min(start_idx + batch_size, len(X))
            X_batch = X[start_idx:end_idx]
            
            pred_batch = model(X_batch, training=True)
            batch_preds.append(pred_batch.numpy())
        
        pred = np.concatenate(batch_preds, axis=0)
        predictions.append(pred)
        
        if (i + 1) % 5 == 0:
            gc.collect()
    
    all_preds = np.array(predictions)
    mean_pred = np.mean(all_preds, axis=0)
    std_pred = np.std(all_preds, axis=0)
    
    del all_preds
    gc.collect()
    
    if verbose:
        print(f"✓ MC Dropout completed")
    
    return mean_pred, std_pred

# ============================================================================
# TRAINING
# ============================================================================

def train_model(X_train, y_train, X_val, y_val, X_test, y_test, model_name, 
               use_focal_eiou=False, use_deeper=False, dropout_rate=0.0,
               augment=None, save_dir='results'):
    """Train model with skip-only CBAM"""
    print(f"\n{'='*80}")
    print(f"TRAINING: {model_name}")
    print(f"{'='*80}")
    print(f"  Focal-EIoU Loss: {'✓' if use_focal_eiou else '✗'}")
    print(f"  Deeper Decoder: {'✓' if use_deeper else '✗'}")
    print(f"  MC Dropout: {'✓ (rate=' + str(dropout_rate) + ')' if dropout_rate > 0 else '✗'}")
    print(f"  CBAM Attention: ✓ SKIP-ONLY (4 skip connections)")
    
    K.clear_session()
    
    model = build_combined_unet_skip_only_cbam(use_deeper=use_deeper, dropout_rate=dropout_rate)
    
    param_count = model.count_params()
    print(f"  Total Parameters: {param_count:,}")
    
    if use_focal_eiou:
        loss_fn = focal_eiou_combined_loss
    else:
        loss_fn = "categorical_crossentropy"
    
    initial_lr = 5e-4 if use_deeper else 1e-3
    model.compile(
        optimizer=optimizers.Adam(learning_rate=initial_lr),
        loss=loss_fn,
        metrics=[dice_coef_multiclass, dice_class_0, dice_class_1, dice_class_2,
                "accuracy", iou_coef_multiclass, iou_class_0, iou_class_1, iou_class_2]
    )
    
    checkpoint = ModelCheckpoint(f"{save_dir}/{model_name}.keras", save_best_only=True, verbose=1, 
                                monitor='val_loss', mode='min')
    reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=5, 
                                  verbose=1, mode='min', min_lr=1e-7)
    early_stop = EarlyStopping(monitor="val_loss", patience=25, verbose=1, 
                              restore_best_weights=True, mode='min')
    
    batch_size = 4 if use_deeper else 6
    steps_train = X_train.shape[0] // batch_size
    steps_val = X_val.shape[0] // batch_size
    
    try:
        history = model.fit(
            data_generator(X_train, y_train, batch_size, augment),
            validation_data=data_generator(X_val, y_val, batch_size, None),
            steps_per_epoch=steps_train,
            validation_steps=steps_val,
            epochs=50,
            callbacks=[checkpoint, reduce_lr, early_stop],
            verbose=1
        )
    except Exception as e:
        print(f"✗ Error: {e}. Retrying with smaller batch...")
        batch_size = 2 if use_deeper else 4
        steps_train = X_train.shape[0] // batch_size
        steps_val = X_val.shape[0] // batch_size
        
        history = model.fit(
            data_generator(X_train, y_train, batch_size, augment),
            validation_data=data_generator(X_val, y_val, batch_size, None),
            steps_per_epoch=steps_train,
            validation_steps=steps_val,
            epochs=50,
            callbacks=[checkpoint, reduce_lr, early_stop],
            verbose=1
        )
    
    print(f" Training completed")
    
    plot_training_history(history, model_name, save_dir)
    
    return model, history, param_count

# ============================================================================
# EVALUATION
# ============================================================================

def evaluate_model(model, X_test, y_test, model_name, run_mc_dropout=False, save_dir='results'):
    """Evaluate model"""
    print(f"\n{'='*80}")
    print(f"EVALUATION: {model_name}")
    print(f"{'='*80}")
    
    y_test_cat = np.array([to_categorical(mask, num_classes=3) for mask in y_test])
    
    test_metrics = model.evaluate(X_test, y_test_cat, verbose=0, batch_size=4)
    y_pred = model.predict(X_test, verbose=0, batch_size=4)
    
    plot_confusion_matrices(y_test_cat, y_pred, model_name, save_dir)
    
    # Calculate precision, recall, F1 score
    y_true_labels = np.argmax(y_test_cat, axis=-1).flatten()
    y_pred_labels = np.argmax(y_pred, axis=-1).flatten()
    
    precision = precision_score(y_true_labels, y_pred_labels, average=None, zero_division=0)
    recall = recall_score(y_true_labels, y_pred_labels, average=None, zero_division=0)
    f1 = f1_score(y_true_labels, y_pred_labels, average=None, zero_division=0)
    
    print(f"\nPrecision, Recall, F1 Score per class:")
    class_names = ["Background", "Disc", "Cup"]
    for idx, cname in enumerate(class_names):
        print(f"  {cname}: Precision={precision[idx]:.4f}, Recall={recall[idx]:.4f}, F1={f1[idx]:.4f}")
    
    print(f"\nMacro-averaged metrics:")
    print(f"  Precision: {np.mean(precision):.4f}")
    print(f"  Recall: {np.mean(recall):.4f}")
    print(f"  F1 Score: {np.mean(f1):.4f}")
    
    class_names = ["Background", "Disc", "Cup"]
    results = {'standard': {}}
    
    for cidx, cname in enumerate(class_names):
        y_true_c = (np.argmax(y_test_cat, axis=-1) == cidx).astype(np.float32)
        y_pred_c = (np.argmax(y_pred, axis=-1) == cidx).astype(np.float32)
        
        intersection = np.sum(y_true_c * y_pred_c)
        dice = (2. * intersection + 1e-7) / (np.sum(y_true_c) + np.sum(y_pred_c) + 1e-7)
        union = np.sum(y_true_c) + np.sum(y_pred_c) - intersection
        iou = (intersection + 1e-7) / (union + 1e-7)
        
        results['standard'][cname] = {'dice': dice, 'iou': iou}
        print(f"  {cname}: Dice={dice:.4f}, IoU={iou:.4f}")
    
    if run_mc_dropout:
        print("\nMC Dropout Evaluation:")
        mean_pred, std_pred = mc_dropout_predict(model, X_test[:100], num_samples=10, verbose=True)
        results['mc_dropout'] = {}
        for cidx, cname in enumerate(class_names):
            mean_std = np.mean(std_pred[:, :, :, cidx])
            results['mc_dropout'][cname] = {'mean_uncertainty': mean_std}
            print(f"  {cname} uncertainty: {mean_std:.4f}")
    
    return results

# ============================================================================
# MAIN
# ============================================================================

if __name__ == "__main__":
    gpu_available = configure_gpu()
    root_dir = "/kaggle/input/refuge/REFUGE/"
    train_aug = setup_augmentations()
    save_dir = "results"
    os.makedirs(save_dir, exist_ok=True)
    
    print(f"\n{'='*100}")
    print(f"{'EXPERIMENT: DEEPER + FOCAL-EIOU + MC DROPOUT + SKIP-ONLY CBAM':^100s}")
    print(f"{'='*100}")
    
    all_images, all_masks = load_all_data(root_dir)
    (X_train, y_train), (X_val, y_val), (X_test, y_test) = create_new_split(all_images, all_masks)
    
    all_results = {}
    all_params = {}
    
    print(f"\n{'='*80}")
    print("EXPERIMENT: FULL COMBINATION + SKIP-ONLY CBAM (4 blocks on skips)")
    print(f"{'='*80}")
    
    model, history, params = train_model(
        X_train, y_train, X_val, y_val, X_test, y_test,
        "FULL_with_SKIP_ONLY_CBAM",
        use_focal_eiou=True, use_deeper=True, dropout_rate=0.3,
        augment=train_aug, save_dir=save_dir
    )
    
    all_results['FULL + SKIP-ONLY CBAM'] = evaluate_model(model, X_test, y_test, "Full with Skip-Only CBAM", run_mc_dropout=True, save_dir=save_dir)
    all_params['FULL + SKIP-ONLY CBAM'] = params
    
    print(f"\n{'='*100}")
    print(f"{'✓ EXPERIMENT COMPLETED!':^100s}")
    print(f"{'='*100}")
    
    print("\nFinal Results:")
    for model_name, results in all_results.items():
        disc_dice = results['standard']['Disc']['dice']
        cup_dice = results['standard']['Cup']['dice']
        print(f"\n{model_name}:")
        print(f"  Parameters: {all_params[model_name]:,}")
        print(f"  Disc Dice: {disc_dice:.4f}")
        print(f"  Cup Dice: {cup_dice:.4f}")
        print(f"  Overall: {(disc_dice + cup_dice)/2:.4f}")
    
    print(f"\n{'='*100}\n")
# Out:
# Configuring GPU settings...
# ✓ GPU found: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
#   GPU device name: /device:GPU:0
#
# ====================================================================================================
#                    EXPERIMENT: DEEPER + FOCAL-EIOU + MC DROPOUT + SKIP-ONLY CBAM
# ====================================================================================================
# Loading train data...
# I0000 00:00:1763380441.886567      38 gpu_device.cc:2022] Created device /device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
#   train: 400 samples
# Loading val data...
#   val: 400 samples
# Loading test data...
#   test: 400 samples
# Split - Train: 600, Val: 200, Test: 400
#
# ================================================================================
# EXPERIMENT: FULL COMBINATION + SKIP-ONLY CBAM (4 blocks on skips)
# ================================================================================
#
# ================================================================================
# TRAINING: FULL_with_SKIP_ONLY_CBAM
# ================================================================================
#   Focal-EIoU Loss: ✓
#   Deeper Decoder: ✓
#   MC Dropout: ✓ (rate=0.3)
#   CBAM Attention: ✓ SKIP-ONLY (4 skip connections)
#
# Building Combined UNet with SKIP-ONLY CBAM...
#   Deeper Architecture: True
#   MC Dropout Rate: 0.3
#   CBAM Attention: SKIP-ONLY (4 blocks on skip connections)
#   Applying CBAM to skip connections...
#     skip_1 (128x128): WITH CBAM ✓
#     skip_2 (64x64): WITH CBAM ✓
#     skip_3 (32x32): WITH CBAM ✓
#     skip_4 (16x16): WITH CBAM ✓
#   Building deeper decoder WITHOUT CBAM (attention only on skips)...
#
#   MC Dropout Configuration:
#     Total Dropout Layers: 5
#     Dropout Rates: ['0.30', '0.30', '0.30', '0.21', '0.15']
#
#   CBAM Configuration (SKIP-ONLY):
#     Total CBAM Components: 12
#     CBAM Locations: Skip connections ONLY (4 blocks)
#     Removed CBAM from: Bridge, Decoder blocks, Final layer
#   Total Parameters: 37,232,573
# Epoch 1/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8361 - dice_class_0: 0.8948 - dice_class_1: 0.3443 - dice_class_2: 0.1768 - dice_coef_multiclass: 0.5704 - iou_class_0: 0.8368 - iou_class_1: 0.2221 - iou_class_2: 0.1038 - iou_coef_multiclass: 0.4100 - loss: 1.2050
# Epoch 1: val_loss improved from inf to 0.87897, saving model to results/FULL_with_SKIP_ONLY_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 150s 217ms/step - accuracy: 0.8367 - dice_class_0: 0.8953 - dice_class_1: 0.3452 - dice_class_2: 0.1777 - dice_coef_multiclass: 0.5712 - iou_class_0: 0.8374 - iou_class_1: 0.2228 - iou_class_2: 0.1044 - iou_coef_multiclass: 0.4109 - loss: 1.2039 - val_accuracy: 0.9562 - val_dice_class_0: 0.9795 - val_dice_class_1: 0.3597 - val_dice_class_2: 9.2286e-11 - val_dice_coef_multiclass: 0.9329 - val_iou_class_0: 0.9598 - val_iou_class_1: 0.2209 - val_iou_class_2: 9.2286e-11 - val_iou_coef_multiclass: 0.8744 - val_loss: 0.8790 - learning_rate: 5.0000e-04
# Epoch 2/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9837 - dice_class_0: 0.9924 - dice_class_1: 0.6850 - dice_class_2: 0.4957 - dice_coef_multiclass: 0.8897 - iou_class_0: 0.9850 - iou_class_1: 0.5245 - iou_class_2: 0.3313 - iou_coef_multiclass: 0.8027 - loss: 0.7279
# Epoch 2: val_loss improved from 0.87897 to 0.68491, saving model to results/FULL_with_SKIP_ONLY_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 155ms/step - accuracy: 0.9837 - dice_class_0: 0.9925 - dice_class_1: 0.6853 - dice_class_2: 0.4956 - dice_coef_multiclass: 0.8899 - iou_class_0: 0.9850 - iou_class_1: 0.5249 - iou_class_2: 0.3313 - iou_coef_multiclass: 0.8030 - loss: 0.7275 - val_accuracy: 0.9772 - val_dice_class_0: 0.9907 - val_dice_class_1: 0.5459 - val_dice_class_2: 0.0028 - val_dice_coef_multiclass: 0.9761 - val_iou_class_0: 0.9815 - val_iou_class_1: 0.3778 - val_iou_class_2: 0.0014 - val_iou_coef_multiclass: 0.9533 - val_loss: 0.6849 - learning_rate: 5.0000e-04
# Epoch 3/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9924 - dice_class_0: 0.9969 - dice_class_1: 0.8050 - dice_class_2: 0.6722 - dice_coef_multiclass: 0.9756 - iou_class_0: 0.9938 - iou_class_1: 0.6759 - iou_class_2: 0.5202 - iou_coef_multiclass: 0.9525 - loss: 0.4768
# Epoch 3: val_loss did not improve from 0.68491
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9924 - dice_class_0: 0.9969 - dice_class_1: 0.8050 - dice_class_2: 0.6728 - dice_coef_multiclass: 0.9757 - iou_class_0: 0.9938 - iou_class_1: 0.6760 - iou_class_2: 0.5209 - iou_coef_multiclass: 0.9526 - loss: 0.4764 - val_accuracy: 0.9586 - val_dice_class_0: 0.9825 - val_dice_class_1: 0.1940 - val_dice_class_2: 0.4100 - val_dice_coef_multiclass: 0.9586 - val_iou_class_0: 0.9656 - val_iou_class_1: 0.1080 - val_iou_class_2: 0.2605 - val_iou_coef_multiclass: 0.9205 - val_loss: 0.7940 - learning_rate: 5.0000e-04
# Epoch 4/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9962 - dice_class_0: 0.9987 - dice_class_1: 0.8575 - dice_class_2: 0.8419 - dice_coef_multiclass: 0.9941 - iou_class_0: 0.9974 - iou_class_1: 0.7521 - iou_class_2: 0.7298 - iou_coef_multiclass: 0.9884 - loss: 0.2560
# Epoch 4: val_loss improved from 0.68491 to 0.24287, saving model to results/FULL_with_SKIP_ONLY_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 152ms/step - accuracy: 0.9962 - dice_class_0: 0.9987 - dice_class_1: 0.8576 - dice_class_2: 0.8420 - dice_coef_multiclass: 0.9942 - iou_class_0: 0.9974 - iou_class_1: 0.7522 - iou_class_2: 0.7299 - iou_coef_multiclass: 0.9884 - loss: 0.2558 - val_accuracy: 0.9950 - val_dice_class_0: 0.9982 - val_dice_class_1: 0.8110 - val_dice_class_2: 0.8015 - val_dice_coef_multiclass: 0.9949 - val_iou_class_0: 0.9964 - val_iou_class_1: 0.6842 - val_iou_class_2: 0.6733 - val_iou_coef_multiclass: 0.9900 - val_loss: 0.2429 - learning_rate: 5.0000e-04
# Epoch 5/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9970 - dice_class_0: 0.9990 - dice_class_1: 0.8814 - dice_class_2: 0.8657 - dice_coef_multiclass: 0.9964 - iou_class_0: 0.9981 - iou_class_1: 0.7890 - iou_class_2: 0.7652 - iou_coef_multiclass: 0.9928 - loss: 0.1881
# Epoch 5: val_loss improved from 0.24287 to 0.20061, saving model to results/FULL_with_SKIP_ONLY_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 155ms/step - accuracy: 0.9970 - dice_class_0: 0.9990 - dice_class_1: 0.8815 - dice_class_2: 0.8657 - dice_coef_multiclass: 0.9964 - iou_class_0: 0.9981 - iou_class_1: 0.7890 - iou_class_2: 0.7653 - iou_coef_multiclass: 0.9928 - loss: 0.1880 - val_accuracy: 0.9960 - val_dice_class_0: 0.9987 - val_dice_class_1: 0.8456 - val_dice_class_2: 0.8419 - val_dice_coef_multiclass: 0.9960 - val_iou_class_0: 0.9973 - val_iou_class_1: 0.7344 - val_iou_class_2: 0.7299 - val_iou_coef_multiclass: 0.9920 - val_loss: 0.2006 - learning_rate: 5.0000e-04
# Epoch 6/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9973 - dice_class_0: 0.9992 - dice_class_1: 0.8939 - dice_class_2: 0.8771 - dice_coef_multiclass: 0.9970 - iou_class_0: 0.9983 - iou_class_1: 0.8092 - iou_class_2: 0.7828 - iou_coef_multiclass: 0.9940 - loss: 0.1616
# Epoch 6: val_loss did not improve from 0.20061
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9973 - dice_class_0: 0.9992 - dice_class_1: 0.8939 - dice_class_2: 0.8771 - dice_coef_multiclass: 0.9970 - iou_class_0: 0.9983 - iou_class_1: 0.8092 - iou_class_2: 0.7829 - iou_coef_multiclass: 0.9940 - loss: 0.1615 - val_accuracy: 0.9946 - val_dice_class_0: 0.9984 - val_dice_class_1: 0.8032 - val_dice_class_2: 0.6405 - val_dice_coef_multiclass: 0.9946 - val_iou_class_0: 0.9968 - val_iou_class_1: 0.6741 - val_iou_class_2: 0.4785 - val_iou_coef_multiclass: 0.9893 - val_loss: 0.3179 - learning_rate: 5.0000e-04
# Epoch 7/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9975 - dice_class_0: 0.9992 - dice_class_1: 0.8992 - dice_class_2: 0.8851 - dice_coef_multiclass: 0.9973 - iou_class_0: 0.9984 - iou_class_1: 0.8177 - iou_class_2: 0.7952 - iou_coef_multiclass: 0.9945 - loss: 0.1515
# Epoch 7: val_loss improved from 0.20061 to 0.18277, saving model to results/FULL_with_SKIP_ONLY_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 154ms/step - accuracy: 0.9975 - dice_class_0: 0.9992 - dice_class_1: 0.8992 - dice_class_2: 0.8851 - dice_coef_multiclass: 0.9973 - iou_class_0: 0.9984 - iou_class_1: 0.8177 - iou_class_2: 0.7952 - iou_coef_multiclass: 0.9945 - loss: 0.1515 - val_accuracy: 0.9968 - val_dice_class_0: 0.9991 - val_dice_class_1: 0.8768 - val_dice_class_2: 0.8319 - val_dice_coef_multiclass: 0.9968 - val_iou_class_0: 0.9981 - val_iou_class_1: 0.7827 - val_iou_class_2: 0.7155 - val_iou_coef_multiclass: 0.9936 - val_loss: 0.1828 - learning_rate: 5.0000e-04
# Epoch 8/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9974 - dice_class_0: 0.9992 - dice_class_1: 0.8975 - dice_class_2: 0.8884 - dice_coef_multiclass: 0.9973 - iou_class_0: 0.9984 - iou_class_1: 0.8153 - iou_class_2: 0.8009 - iou_coef_multiclass: 0.9946 - loss: 0.1480
# Epoch 8: val_loss did not improve from 0.18277
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9974 - dice_class_0: 0.9992 - dice_class_1: 0.8975 - dice_class_2: 0.8884 - dice_coef_multiclass: 0.9973 - iou_class_0: 0.9984 - iou_class_1: 0.8153 - iou_class_2: 0.8009 - iou_coef_multiclass: 0.9946 - loss: 0.1480 - val_accuracy: 0.9939 - val_dice_class_0: 0.9977 - val_dice_class_1: 0.8261 - val_dice_class_2: 0.6623 - val_dice_coef_multiclass: 0.9939 - val_iou_class_0: 0.9954 - val_iou_class_1: 0.7051 - val_iou_class_2: 0.4974 - val_iou_coef_multiclass: 0.9878 - val_loss: 0.3009 - learning_rate: 5.0000e-04
# Epoch 9/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9974 - dice_class_0: 0.9991 - dice_class_1: 0.8962 - dice_class_2: 0.8918 - dice_coef_multiclass: 0.9973 - iou_class_0: 0.9983 - iou_class_1: 0.8131 - iou_class_2: 0.8066 - iou_coef_multiclass: 0.9945 - loss: 0.1454
# Epoch 9: val_loss did not improve from 0.18277
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9974 - dice_class_0: 0.9991 - dice_class_1: 0.8962 - dice_class_2: 0.8917 - dice_coef_multiclass: 0.9973 - iou_class_0: 0.9983 - iou_class_1: 0.8131 - iou_class_2: 0.8065 - iou_coef_multiclass: 0.9945 - loss: 0.1454 - val_accuracy: 0.9957 - val_dice_class_0: 0.9989 - val_dice_class_1: 0.8204 - val_dice_class_2: 0.7779 - val_dice_coef_multiclass: 0.9956 - val_iou_class_0: 0.9978 - val_iou_class_1: 0.6971 - val_iou_class_2: 0.6398 - val_iou_coef_multiclass: 0.9912 - val_loss: 0.2525 - learning_rate: 5.0000e-04
# Epoch 10/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9092 - dice_class_2: 0.8945 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9986 - iou_class_1: 0.8344 - iou_class_2: 0.8101 - iou_coef_multiclass: 0.9952 - loss: 0.1347
# Epoch 10: val_loss improved from 0.18277 to 0.17691, saving model to results/FULL_with_SKIP_ONLY_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 155ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9092 - dice_class_2: 0.8945 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9986 - iou_class_1: 0.8343 - iou_class_2: 0.8102 - iou_coef_multiclass: 0.9952 - loss: 0.1347 - val_accuracy: 0.9969 - val_dice_class_0: 0.9991 - val_dice_class_1: 0.8729 - val_dice_class_2: 0.8524 - val_dice_coef_multiclass: 0.9969 - val_iou_class_0: 0.9981 - val_iou_class_1: 0.7762 - val_iou_class_2: 0.7465 - val_iou_coef_multiclass: 0.9938 - val_loss: 0.1769 - learning_rate: 5.0000e-04
# Epoch 11/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9086 - dice_class_2: 0.8995 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9986 - iou_class_1: 0.8333 - iou_class_2: 0.8188 - iou_coef_multiclass: 0.9953 - loss: 0.1318
# Epoch 11: val_loss did not improve from 0.17691
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 133ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9086 - dice_class_2: 0.8995 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9986 - iou_class_1: 0.8333 - iou_class_2: 0.8188 - iou_coef_multiclass: 0.9953 - loss: 0.1318 - val_accuracy: 0.9971 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8832 - val_dice_class_2: 0.8147 - val_dice_coef_multiclass: 0.9971 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.7921 - val_iou_class_2: 0.6902 - val_iou_coef_multiclass: 0.9942 - val_loss: 0.1877 - learning_rate: 5.0000e-04
# Epoch 12/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9121 - dice_class_2: 0.9038 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9987 - iou_class_1: 0.8391 - iou_class_2: 0.8252 - iou_coef_multiclass: 0.9956 - loss: 0.1263
# Epoch 12: val_loss improved from 0.17691 to 0.16038, saving model to results/FULL_with_SKIP_ONLY_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 153ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9121 - dice_class_2: 0.9038 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9987 - iou_class_1: 0.8391 - iou_class_2: 0.8252 - iou_coef_multiclass: 0.9956 - loss: 0.1263 - val_accuracy: 0.9974 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8941 - val_dice_class_2: 0.8599 - val_dice_coef_multiclass: 0.9974 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8095 - val_iou_class_2: 0.7561 - val_iou_coef_multiclass: 0.9947 - val_loss: 0.1604 - learning_rate: 5.0000e-04
# Epoch 13/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9138 - dice_class_2: 0.9096 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9986 - iou_class_1: 0.8421 - iou_class_2: 0.8350 - iou_coef_multiclass: 0.9956 - loss: 0.1210
# Epoch 13: val_loss improved from 0.16038 to 0.15811, saving model to results/FULL_with_SKIP_ONLY_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 154ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9138 - dice_class_2: 0.9096 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9986 - iou_class_1: 0.8421 - iou_class_2: 0.8350 - iou_coef_multiclass: 0.9956 - loss: 0.1210 - val_accuracy: 0.9973 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8933 - val_dice_class_2: 0.8596 - val_dice_coef_multiclass: 0.9973 - val_iou_class_0: 0.9984 - val_iou_class_1: 0.8086 - val_iou_class_2: 0.7557 - val_iou_coef_multiclass: 0.9945 - val_loss: 0.1581 - learning_rate: 5.0000e-04
# Epoch 14/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9135 - dice_class_2: 0.9087 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9986 - iou_class_1: 0.8413 - iou_class_2: 0.8334 - iou_coef_multiclass: 0.9956 - loss: 0.1237
# Epoch 14: val_loss improved from 0.15811 to 0.15204, saving model to results/FULL_with_SKIP_ONLY_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 154ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9135 - dice_class_2: 0.9086 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9986 - iou_class_1: 0.8413 - iou_class_2: 0.8334 - iou_coef_multiclass: 0.9956 - loss: 0.1237 - val_accuracy: 0.9973 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8892 - val_dice_class_2: 0.8826 - val_dice_coef_multiclass: 0.9972 - val_iou_class_0: 0.9983 - val_iou_class_1: 0.8014 - val_iou_class_2: 0.7906 - val_iou_coef_multiclass: 0.9945 - val_loss: 0.1520 - learning_rate: 5.0000e-04
# Epoch 15/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9200 - dice_class_2: 0.9122 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8525 - iou_class_2: 0.8395 - iou_coef_multiclass: 0.9959 - loss: 0.1154
# Epoch 15: val_loss improved from 0.15204 to 0.14059, saving model to results/FULL_with_SKIP_ONLY_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 154ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9200 - dice_class_2: 0.9122 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8525 - iou_class_2: 0.8395 - iou_coef_multiclass: 0.9959 - loss: 0.1154 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9065 - val_dice_class_2: 0.8835 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8298 - val_iou_class_2: 0.7931 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1406 - learning_rate: 5.0000e-04
# Epoch 16/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9184 - dice_class_2: 0.9107 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8496 - iou_class_2: 0.8370 - iou_coef_multiclass: 0.9958 - loss: 0.1178
# Epoch 16: val_loss did not improve from 0.14059
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9185 - dice_class_2: 0.9107 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8496 - iou_class_2: 0.8370 - iou_coef_multiclass: 0.9958 - loss: 0.1178 - val_accuracy: 0.9974 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8965 - val_dice_class_2: 0.8691 - val_dice_coef_multiclass: 0.9974 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8140 - val_iou_class_2: 0.7713 - val_iou_coef_multiclass: 0.9948 - val_loss: 0.1489 - learning_rate: 5.0000e-04
# Epoch 17/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9980 - dice_class_0: 0.9993 - dice_class_1: 0.9213 - dice_class_2: 0.9175 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9987 - iou_class_1: 0.8547 - iou_class_2: 0.8485 - iou_coef_multiclass: 0.9959 - loss: 0.1117
# Epoch 17: val_loss did not improve from 0.14059
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9980 - dice_class_0: 0.9993 - dice_class_1: 0.9213 - dice_class_2: 0.9175 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9987 - iou_class_1: 0.8546 - iou_class_2: 0.8485 - iou_coef_multiclass: 0.9959 - loss: 0.1118 - val_accuracy: 0.9950 - val_dice_class_0: 0.9980 - val_dice_class_1: 0.8491 - val_dice_class_2: 0.7660 - val_dice_coef_multiclass: 0.9949 - val_iou_class_0: 0.9961 - val_iou_class_1: 0.7397 - val_iou_class_2: 0.6238 - val_iou_coef_multiclass: 0.9899 - val_loss: 0.2375 - learning_rate: 5.0000e-04
# Epoch 18/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9977 - dice_class_0: 0.9992 - dice_class_1: 0.9101 - dice_class_2: 0.9120 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9985 - iou_class_1: 0.8362 - iou_class_2: 0.8393 - iou_coef_multiclass: 0.9954 - loss: 0.1220
# Epoch 18: val_loss did not improve from 0.14059
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9977 - dice_class_0: 0.9992 - dice_class_1: 0.9101 - dice_class_2: 0.9120 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9985 - iou_class_1: 0.8363 - iou_class_2: 0.8394 - iou_coef_multiclass: 0.9954 - loss: 0.1219 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9013 - val_dice_class_2: 0.8846 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8218 - val_iou_class_2: 0.7950 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1409 - learning_rate: 5.0000e-04
# Epoch 19/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9223 - dice_class_2: 0.9199 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9987 - iou_class_1: 0.8562 - iou_class_2: 0.8523 - iou_coef_multiclass: 0.9960 - loss: 0.1084
# Epoch 19: val_loss did not improve from 0.14059
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9223 - dice_class_2: 0.9199 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9987 - iou_class_1: 0.8562 - iou_class_2: 0.8523 - iou_coef_multiclass: 0.9960 - loss: 0.1084 - val_accuracy: 0.9975 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8917 - val_dice_class_2: 0.8846 - val_dice_coef_multiclass: 0.9974 - val_iou_class_0: 0.9983 - val_iou_class_1: 0.8058 - val_iou_class_2: 0.7944 - val_iou_coef_multiclass: 0.9949 - val_loss: 0.1498 - learning_rate: 5.0000e-04
# Epoch 20/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9235 - dice_class_2: 0.9227 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8583 - iou_class_2: 0.8572 - iou_coef_multiclass: 0.9961 - loss: 0.1061
# Epoch 20: val_loss did not improve from 0.14059
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 131ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9235 - dice_class_2: 0.9227 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8583 - iou_class_2: 0.8572 - iou_coef_multiclass: 0.9961 - loss: 0.1060 - val_accuracy: 0.9973 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8936 - val_dice_class_2: 0.8394 - val_dice_coef_multiclass: 0.9973 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.8090 - val_iou_class_2: 0.7248 - val_iou_coef_multiclass: 0.9946 - val_loss: 0.1736 - learning_rate: 5.0000e-04
# Epoch 21/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9300 - dice_class_2: 0.9285 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8696 - iou_class_2: 0.8671 - iou_coef_multiclass: 0.9965 - loss: 0.0990
# Epoch 21: val_loss improved from 0.14059 to 0.12995, saving model to results/FULL_with_SKIP_ONLY_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 155ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9300 - dice_class_2: 0.9285 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8696 - iou_class_2: 0.8671 - iou_coef_multiclass: 0.9965 - loss: 0.0990 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9102 - val_dice_class_2: 0.8940 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8358 - val_iou_class_2: 0.8095 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1300 - learning_rate: 1.5000e-04
# Epoch 22/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9347 - dice_class_2: 0.9367 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8777 - iou_class_2: 0.8814 - iou_coef_multiclass: 0.9967 - loss: 0.0902
# Epoch 22: val_loss did not improve from 0.12995
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9347 - dice_class_2: 0.9367 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8777 - iou_class_2: 0.8814 - iou_coef_multiclass: 0.9967 - loss: 0.0902 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9034 - val_dice_class_2: 0.8871 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8249 - val_iou_class_2: 0.7984 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1410 - learning_rate: 1.5000e-04
# Epoch 23/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9347 - dice_class_2: 0.9377 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8777 - iou_class_2: 0.8833 - iou_coef_multiclass: 0.9967 - loss: 0.0899
# Epoch 23: val_loss did not improve from 0.12995
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9347 - dice_class_2: 0.9377 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8777 - iou_class_2: 0.8833 - iou_coef_multiclass: 0.9967 - loss: 0.0899 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9094 - val_dice_class_2: 0.8926 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8344 - val_iou_class_2: 0.8072 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1325 - learning_rate: 1.5000e-04
# Epoch 24/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9386 - dice_class_2: 0.9390 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8846 - iou_class_2: 0.8856 - iou_coef_multiclass: 0.9969 - loss: 0.0858
# Epoch 24: val_loss did not improve from 0.12995
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9386 - dice_class_2: 0.9390 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8846 - iou_class_2: 0.8856 - iou_coef_multiclass: 0.9969 - loss: 0.0858 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9045 - val_dice_class_2: 0.8885 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8265 - val_iou_class_2: 0.8009 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1381 - learning_rate: 1.5000e-04
# Epoch 25/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9393 - dice_class_2: 0.9424 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8858 - iou_class_2: 0.8915 - iou_coef_multiclass: 0.9969 - loss: 0.0837
# Epoch 25: val_loss did not improve from 0.12995
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9393 - dice_class_2: 0.9424 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8858 - iou_class_2: 0.8915 - iou_coef_multiclass: 0.9969 - loss: 0.0837 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9107 - val_dice_class_2: 0.8897 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8368 - val_iou_class_2: 0.8025 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1334 - learning_rate: 1.5000e-04
# Epoch 26/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9388 - dice_class_2: 0.9424 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8850 - iou_class_2: 0.8914 - iou_coef_multiclass: 0.9969 - loss: 0.0836
# Epoch 26: val_loss did not improve from 0.12995
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 4.500000213738531e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9388 - dice_class_2: 0.9424 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8850 - iou_class_2: 0.8914 - iou_coef_multiclass: 0.9969 - loss: 0.0836 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9072 - val_dice_class_2: 0.8957 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8311 - val_iou_class_2: 0.8121 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1348 - learning_rate: 1.5000e-04
# Epoch 27/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9395 - dice_class_2: 0.9442 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8862 - iou_class_2: 0.8948 - iou_coef_multiclass: 0.9969 - loss: 0.0832
# Epoch 27: val_loss did not improve from 0.12995
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9395 - dice_class_2: 0.9442 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8862 - iou_class_2: 0.8948 - iou_coef_multiclass: 0.9969 - loss: 0.0832 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9065 - val_dice_class_2: 0.8906 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8299 - val_iou_class_2: 0.8040 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1372 - learning_rate: 4.5000e-05
# Epoch 28/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9424 - dice_class_2: 0.9468 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8915 - iou_class_2: 0.8995 - iou_coef_multiclass: 0.9971 - loss: 0.0790
# Epoch 28: val_loss did not improve from 0.12995
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9424 - dice_class_2: 0.9468 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8915 - iou_class_2: 0.8995 - iou_coef_multiclass: 0.9971 - loss: 0.0790 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9071 - val_dice_class_2: 0.8837 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8306 - val_iou_class_2: 0.7931 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1403 - learning_rate: 4.5000e-05
# Epoch 29/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9430 - dice_class_2: 0.9461 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8924 - iou_class_2: 0.8981 - iou_coef_multiclass: 0.9971 - loss: 0.0793
# Epoch 29: val_loss improved from 0.12995 to 0.12960, saving model to results/FULL_with_SKIP_ONLY_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 155ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9430 - dice_class_2: 0.9461 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8924 - iou_class_2: 0.8981 - iou_coef_multiclass: 0.9971 - loss: 0.0792 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9139 - val_dice_class_2: 0.8945 - val_dice_coef_multiclass: 0.9979 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8422 - val_iou_class_2: 0.8102 - val_iou_coef_multiclass: 0.9958 - val_loss: 0.1296 - learning_rate: 4.5000e-05
# Epoch 30/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9443 - dice_class_2: 0.9472 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9990 - iou_class_1: 0.8947 - iou_class_2: 0.9000 - iou_coef_multiclass: 0.9972 - loss: 0.0771
# Epoch 30: val_loss did not improve from 0.12960
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 133ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9443 - dice_class_2: 0.9472 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9990 - iou_class_1: 0.8947 - iou_class_2: 0.9000 - iou_coef_multiclass: 0.9972 - loss: 0.0771 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9070 - val_dice_class_2: 0.8959 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8307 - val_iou_class_2: 0.8127 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1355 - learning_rate: 4.5000e-05
# Epoch 31/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9419 - dice_class_2: 0.9477 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8904 - iou_class_2: 0.9010 - iou_coef_multiclass: 0.9970 - loss: 0.0785
# Epoch 31: val_loss did not improve from 0.12960
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9419 - dice_class_2: 0.9477 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8905 - iou_class_2: 0.9010 - iou_coef_multiclass: 0.9970 - loss: 0.0785 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9082 - val_dice_class_2: 0.8931 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8327 - val_iou_class_2: 0.8078 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1343 - learning_rate: 4.5000e-05
# Epoch 32/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9451 - dice_class_2: 0.9491 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9991 - iou_class_1: 0.8960 - iou_class_2: 0.9035 - iou_coef_multiclass: 0.9972 - loss: 0.0755
# Epoch 32: val_loss did not improve from 0.12960
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 133ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9450 - dice_class_2: 0.9491 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9991 - iou_class_1: 0.8960 - iou_class_2: 0.9035 - iou_coef_multiclass: 0.9972 - loss: 0.0755 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9076 - val_dice_class_2: 0.8883 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8313 - val_iou_class_2: 0.8006 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1369 - learning_rate: 4.5000e-05
# Epoch 33/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9463 - dice_class_2: 0.9509 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9991 - iou_class_1: 0.8982 - iou_class_2: 0.9068 - iou_coef_multiclass: 0.9973 - loss: 0.0735
# Epoch 33: val_loss did not improve from 0.12960
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 133ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9463 - dice_class_2: 0.9509 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9991 - iou_class_1: 0.8982 - iou_class_2: 0.9068 - iou_coef_multiclass: 0.9973 - loss: 0.0735 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9038 - val_dice_class_2: 0.8916 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8255 - val_iou_class_2: 0.8055 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1397 - learning_rate: 4.5000e-05
# Epoch 34/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9460 - dice_class_2: 0.9496 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9991 - iou_class_1: 0.8978 - iou_class_2: 0.9043 - iou_coef_multiclass: 0.9972 - loss: 0.0738
# Epoch 34: val_loss did not improve from 0.12960
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.3500000204658135e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 133ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9460 - dice_class_2: 0.9496 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9991 - iou_class_1: 0.8978 - iou_class_2: 0.9043 - iou_coef_multiclass: 0.9972 - loss: 0.0738 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9109 - val_dice_class_2: 0.8916 - val_dice_coef_multiclass: 0.9979 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8372 - val_iou_class_2: 0.8059 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1339 - learning_rate: 4.5000e-05
# Epoch 35/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9432 - dice_class_2: 0.9473 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9990 - iou_class_1: 0.8929 - iou_class_2: 0.9005 - iou_coef_multiclass: 0.9971 - loss: 0.0772
# Epoch 35: val_loss did not improve from 0.12960
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9432 - dice_class_2: 0.9473 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9990 - iou_class_1: 0.8929 - iou_class_2: 0.9005 - iou_coef_multiclass: 0.9971 - loss: 0.0772 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9057 - val_dice_class_2: 0.8940 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8288 - val_iou_class_2: 0.8095 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1361 - learning_rate: 1.3500e-05
# Epoch 36/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9459 - dice_class_2: 0.9508 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9991 - iou_class_1: 0.8975 - iou_class_2: 0.9066 - iou_coef_multiclass: 0.9972 - loss: 0.0738
# Epoch 36: val_loss did not improve from 0.12960
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9459 - dice_class_2: 0.9508 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9991 - iou_class_1: 0.8975 - iou_class_2: 0.9066 - iou_coef_multiclass: 0.9972 - loss: 0.0738 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9084 - val_dice_class_2: 0.8928 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8329 - val_iou_class_2: 0.8074 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1347 - learning_rate: 1.3500e-05
# Epoch 37/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9449 - dice_class_2: 0.9517 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9991 - iou_class_1: 0.8958 - iou_class_2: 0.9082 - iou_coef_multiclass: 0.9972 - loss: 0.0737
# Epoch 37: val_loss did not improve from 0.12960
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9449 - dice_class_2: 0.9517 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9991 - iou_class_1: 0.8959 - iou_class_2: 0.9082 - iou_coef_multiclass: 0.9972 - loss: 0.0737 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9095 - val_dice_class_2: 0.8929 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8351 - val_iou_class_2: 0.8073 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1356 - learning_rate: 1.3500e-05
# Epoch 38/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9451 - dice_class_2: 0.9510 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9990 - iou_class_1: 0.8961 - iou_class_2: 0.9069 - iou_coef_multiclass: 0.9972 - loss: 0.0733
# Epoch 38: val_loss did not improve from 0.12960
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 133ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9451 - dice_class_2: 0.9510 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9990 - iou_class_1: 0.8962 - iou_class_2: 0.9069 - iou_coef_multiclass: 0.9972 - loss: 0.0733 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9084 - val_dice_class_2: 0.8906 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8330 - val_iou_class_2: 0.8037 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1352 - learning_rate: 1.3500e-05
# Epoch 39/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9987 - dice_class_0: 0.9996 - dice_class_1: 0.9479 - dice_class_2: 0.9545 - dice_coef_multiclass: 0.9987 - iou_class_0: 0.9991 - iou_class_1: 0.9011 - iou_class_2: 0.9133 - iou_coef_multiclass: 0.9974 - loss: 0.0704
# Epoch 39: val_loss did not improve from 0.12960
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 4.050000006827758e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9987 - dice_class_0: 0.9996 - dice_class_1: 0.9479 - dice_class_2: 0.9545 - dice_coef_multiclass: 0.9987 - iou_class_0: 0.9991 - iou_class_1: 0.9011 - iou_class_2: 0.9133 - iou_coef_multiclass: 0.9974 - loss: 0.0704 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9120 - val_dice_class_2: 0.8918 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8388 - val_iou_class_2: 0.8059 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1331 - learning_rate: 1.3500e-05
# Epoch 40/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9483 - dice_class_2: 0.9519 - dice_coef_multiclass: 0.9987 - iou_class_0: 0.9991 - iou_class_1: 0.9019 - iou_class_2: 0.9086 - iou_coef_multiclass: 0.9973 - loss: 0.0715
# Epoch 40: val_loss did not improve from 0.12960
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9483 - dice_class_2: 0.9519 - dice_coef_multiclass: 0.9987 - iou_class_0: 0.9991 - iou_class_1: 0.9019 - iou_class_2: 0.9086 - iou_coef_multiclass: 0.9973 - loss: 0.0715 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9040 - val_dice_class_2: 0.8885 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8263 - val_iou_class_2: 0.8010 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1405 - learning_rate: 4.0500e-06
# Epoch 41/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9987 - dice_class_0: 0.9996 - dice_class_1: 0.9468 - dice_class_2: 0.9510 - dice_coef_multiclass: 0.9987 - iou_class_0: 0.9991 - iou_class_1: 0.8992 - iou_class_2: 0.9070 - iou_coef_multiclass: 0.9973 - loss: 0.0725
# Epoch 41: val_loss did not improve from 0.12960
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9987 - dice_class_0: 0.9996 - dice_class_1: 0.9468 - dice_class_2: 0.9510 - dice_coef_multiclass: 0.9987 - iou_class_0: 0.9991 - iou_class_1: 0.8992 - iou_class_2: 0.9070 - iou_coef_multiclass: 0.9973 - loss: 0.0725 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9112 - val_dice_class_2: 0.8967 - val_dice_coef_multiclass: 0.9979 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8379 - val_iou_class_2: 0.8141 - val_iou_coef_multiclass: 0.9958 - val_loss: 0.1307 - learning_rate: 4.0500e-06
# Epoch 42/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9460 - dice_class_2: 0.9483 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9991 - iou_class_1: 0.8978 - iou_class_2: 0.9023 - iou_coef_multiclass: 0.9972 - loss: 0.0747
# Epoch 42: val_loss did not improve from 0.12960
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9460 - dice_class_2: 0.9483 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9991 - iou_class_1: 0.8979 - iou_class_2: 0.9023 - iou_coef_multiclass: 0.9972 - loss: 0.0747 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9078 - val_dice_class_2: 0.8912 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8319 - val_iou_class_2: 0.8049 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1375 - learning_rate: 4.0500e-06
# Epoch 43/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9463 - dice_class_2: 0.9517 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9991 - iou_class_1: 0.8984 - iou_class_2: 0.9081 - iou_coef_multiclass: 0.9972 - loss: 0.0727
# Epoch 43: val_loss did not improve from 0.12960
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9463 - dice_class_2: 0.9517 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9991 - iou_class_1: 0.8984 - iou_class_2: 0.9081 - iou_coef_multiclass: 0.9972 - loss: 0.0727 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9102 - val_dice_class_2: 0.8925 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8358 - val_iou_class_2: 0.8074 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1337 - learning_rate: 4.0500e-06
# Epoch 44/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9457 - dice_class_2: 0.9504 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9991 - iou_class_1: 0.8973 - iou_class_2: 0.9058 - iou_coef_multiclass: 0.9972 - loss: 0.0738
# Epoch 44: val_loss did not improve from 0.12960
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1.2149999747634864e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9457 - dice_class_2: 0.9504 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9991 - iou_class_1: 0.8973 - iou_class_2: 0.9058 - iou_coef_multiclass: 0.9972 - loss: 0.0738 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9074 - val_dice_class_2: 0.8869 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8313 - val_iou_class_2: 0.7984 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1381 - learning_rate: 4.0500e-06
# Epoch 45/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9472 - dice_class_2: 0.9513 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9991 - iou_class_1: 0.9000 - iou_class_2: 0.9077 - iou_coef_multiclass: 0.9973 - loss: 0.0727
# Epoch 45: val_loss did not improve from 0.12960
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9472 - dice_class_2: 0.9513 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9991 - iou_class_1: 0.9000 - iou_class_2: 0.9077 - iou_coef_multiclass: 0.9973 - loss: 0.0727 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9074 - val_dice_class_2: 0.8927 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8317 - val_iou_class_2: 0.8071 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1351 - learning_rate: 1.2150e-06
# Epoch 46/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9987 - dice_class_0: 0.9996 - dice_class_1: 0.9479 - dice_class_2: 0.9530 - dice_coef_multiclass: 0.9987 - iou_class_0: 0.9991 - iou_class_1: 0.9013 - iou_class_2: 0.9104 - iou_coef_multiclass: 0.9974 - loss: 0.0708
# Epoch 46: val_loss did not improve from 0.12960
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9987 - dice_class_0: 0.9996 - dice_class_1: 0.9479 - dice_class_2: 0.9530 - dice_coef_multiclass: 0.9987 - iou_class_0: 0.9991 - iou_class_1: 0.9013 - iou_class_2: 0.9104 - iou_coef_multiclass: 0.9974 - loss: 0.0708 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9093 - val_dice_class_2: 0.8938 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8345 - val_iou_class_2: 0.8088 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1351 - learning_rate: 1.2150e-06
# Epoch 47/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9988 - dice_class_0: 0.9996 - dice_class_1: 0.9495 - dice_class_2: 0.9549 - dice_coef_multiclass: 0.9987 - iou_class_0: 0.9991 - iou_class_1: 0.9040 - iou_class_2: 0.9140 - iou_coef_multiclass: 0.9974 - loss: 0.0686
# Epoch 47: val_loss did not improve from 0.12960
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9988 - dice_class_0: 0.9996 - dice_class_1: 0.9494 - dice_class_2: 0.9549 - dice_coef_multiclass: 0.9987 - iou_class_0: 0.9991 - iou_class_1: 0.9039 - iou_class_2: 0.9140 - iou_coef_multiclass: 0.9974 - loss: 0.0686 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9065 - val_dice_class_2: 0.8927 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8298 - val_iou_class_2: 0.8072 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1375 - learning_rate: 1.2150e-06
# Epoch 48/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9472 - dice_class_2: 0.9510 - dice_coef_multiclass: 0.9987 - iou_class_0: 0.9991 - iou_class_1: 0.9000 - iou_class_2: 0.9071 - iou_coef_multiclass: 0.9973 - loss: 0.0724
# Epoch 48: val_loss did not improve from 0.12960
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 133ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9472 - dice_class_2: 0.9510 - dice_coef_multiclass: 0.9987 - iou_class_0: 0.9991 - iou_class_1: 0.9000 - iou_class_2: 0.9071 - iou_coef_multiclass: 0.9973 - loss: 0.0724 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9104 - val_dice_class_2: 0.8944 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8364 - val_iou_class_2: 0.8100 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1329 - learning_rate: 1.2150e-06
# Epoch 49/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9466 - dice_class_2: 0.9516 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9991 - iou_class_1: 0.8990 - iou_class_2: 0.9080 - iou_coef_multiclass: 0.9973 - loss: 0.0722
# Epoch 49: val_loss did not improve from 0.12960
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 3.644999992502562e-07.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9987 - dice_class_0: 0.9995 - dice_class_1: 0.9466 - dice_class_2: 0.9516 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9991 - iou_class_1: 0.8990 - iou_class_2: 0.9080 - iou_coef_multiclass: 0.9973 - loss: 0.0722 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9083 - val_dice_class_2: 0.8913 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8329 - val_iou_class_2: 0.8053 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1351 - learning_rate: 1.2150e-06
# Epoch 50/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9987 - dice_class_0: 0.9996 - dice_class_1: 0.9477 - dice_class_2: 0.9528 - dice_coef_multiclass: 0.9987 - iou_class_0: 0.9991 - iou_class_1: 0.9009 - iou_class_2: 0.9102 - iou_coef_multiclass: 0.9973 - loss: 0.0705
# Epoch 50: val_loss did not improve from 0.12960
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 132ms/step - accuracy: 0.9987 - dice_class_0: 0.9996 - dice_class_1: 0.9477 - dice_class_2: 0.9528 - dice_coef_multiclass: 0.9987 - iou_class_0: 0.9991 - iou_class_1: 0.9009 - iou_class_2: 0.9102 - iou_coef_multiclass: 0.9973 - loss: 0.0705 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9092 - val_dice_class_2: 0.8912 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8342 - val_iou_class_2: 0.8046 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1361 - learning_rate: 3.6450e-07
# Restoring model weights from the end of the best epoch: 29.
#  Training completed
# ✓ Training curves saved: results/FULL_with_SKIP_ONLY_CBAM_training_curves.png
# ================================================================================
# EVALUATION: Full with Skip-Only CBAM
# ================================================================================
# ✓ Confusion matrices saved: results/Full with Skip-Only CBAM_confusion_matrices.png
# \nConfusion Matrix:
# [[25770187    14803        0]
#  [   17666   289632     7773]
#  [     133    16424    97782]]
# \nNormalized Confusion Matrix:
# [[0.999 0.001 0.   ]
#  [0.056 0.919 0.025]
#  [0.001 0.144 0.855]]
#
# Precision, Recall, F1 Score per class:
#   Background: Precision=0.9993, Recall=0.9994, F1=0.9994
#   Disc: Precision=0.9027, Recall=0.9193, F1=0.9109
#   Cup: Precision=0.9264, Recall=0.8552, F1=0.8894
#
# Macro-averaged metrics:
#   Precision: 0.9428
#   Recall: 0.9246
#   F1 Score: 0.9332
#   Background: Dice=0.9994, IoU=0.9987
#   Disc: Dice=0.9109, IoU=0.8364
#   Cup: Dice=0.8894, IoU=0.8008
#
# MC Dropout Evaluation:
#
# Running MC Dropout with 10 stochastic forward passes...
#   Completed: 5/10 forward passes
#   Completed: 10/10 forward passes
# ✓ MC Dropout completed
#   Background uncertainty: 0.0002
#   Disc uncertainty: 0.0004
#   Cup uncertainty: 0.0002
#
# ====================================================================================================
#                                       ✓ EXPERIMENT COMPLETED!
# ====================================================================================================
#
# Final Results:
#
# FULL + SKIP-ONLY CBAM:
#   Parameters: 37,232,573
#   Disc Dice: 0.9109
#   Cup Dice: 0.8894
#   Overall: 0.9001
#
# ====================================================================================================
