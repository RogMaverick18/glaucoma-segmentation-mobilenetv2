# %%
"""
COMBINED ADVANCED MOBILENET-UNET WITH ECA ATTENTION
=====================================================
This combines:
1. Deeper decoder architecture with enhanced blocks
2. Focal-EIoU loss
3. MC Dropout for uncertainty estimation
4. ECA (Efficient Channel Attention) - Lightweight channel attention
   - Applied to: Skip connections (4 locations)
   - More efficient than CBAM (only channel attention, no spatial)
   - Uses 1D convolution for adaptive kernel size

STRATEGY: ECA is a lightweight alternative to CBAM that only uses channel attention
with adaptive kernel size, making it more parameter-efficient while maintaining effectiveness.
"""

import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, backend as K
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import albumentations as A
import warnings
import gc
warnings.filterwarnings('ignore')

plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# ============================================================================
# HELPER FUNCTIONS
# ============================================================================

def configure_gpu():
    """Configure GPU settings for optimal performance"""
    print("Configuring GPU settings...")
    physical_devices = tf.config.list_physical_devices('GPU')
    if physical_devices:
        try:
            for gpu in physical_devices:
                tf.config.experimental.set_memory_growth(gpu, True)
            tf.config.set_visible_devices(physical_devices[0], 'GPU')
            print(f"✓ GPU found: {physical_devices}")
            return True
        except RuntimeError as e:
            print(f"✗ GPU configuration error: {e}")
            return False
    else:
        print("✗ No GPU found, using CPU")
        return False

def load_images_masks(images_folder, masks_folder, img_size=(256,256)):
    """Load images and masks from folders"""
    images, masks = [], []
    image_files = sorted(os.listdir(images_folder))
    mask_files = sorted(os.listdir(masks_folder))
    mask_dict = {os.path.splitext(f)[0]: f for f in mask_files}
    
    for img_file in image_files:
        base = os.path.splitext(img_file)[0]
        if base in mask_dict:
            img = cv2.imread(os.path.join(images_folder, img_file))
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, img_size) / 255.0
            
            mask = cv2.imread(os.path.join(masks_folder, mask_dict[base]), cv2.IMREAD_GRAYSCALE)
            mask = cv2.resize(mask, img_size)
            unique_vals = np.unique(mask)
            if len(unique_vals) > 3 or np.max(unique_vals) > 2:
                mask = np.clip(mask // 85, 0, 2).astype(np.uint8)
            
            images.append(img)
            masks.append(mask)
    
    return np.array(images, dtype=np.float32), np.array(masks, dtype=np.uint8)

def load_all_data(root_dir):
    """Load all data from existing splits and merge"""
    all_images, all_masks = [], []
    for split in ["train", "val", "test"]:
        print(f"Loading {split} data...")
        imgs, msks = load_images_masks(
            os.path.join(root_dir, split, "Images"),
            os.path.join(root_dir, split, "Masks")
        )
        all_images.append(imgs)
        all_masks.append(msks)
        print(f"  {split}: {imgs.shape[0]} samples")
    
    all_images = np.concatenate(all_images, axis=0)
    all_masks = np.concatenate(all_masks, axis=0)
    return all_images, all_masks

def create_new_split(all_images, all_masks):
    """Create new split: 600 train, 200 val, 400 test"""
    X_temp, X_test, y_temp, y_test = train_test_split(
        all_images, all_masks, test_size=400, random_state=42
    )
    X_train, X_val, y_train, y_val = train_test_split(
        X_temp, y_temp, test_size=200, random_state=42
    )
    print(f"Split - Train: {X_train.shape[0]}, Val: {X_val.shape[0]}, Test: {X_test.shape[0]}")
    return (X_train, y_train), (X_val, y_val), (X_test, y_test)

def setup_augmentations():
    return A.Compose([
        A.RandomBrightnessContrast(brightness_limit=0.15, contrast_limit=0.15, p=0.7),
        A.HueSaturationValue(hue_shift_limit=10, sat_shift_limit=15, val_shift_limit=10, p=0.5),
        A.GaussianBlur(blur_limit=3, p=0.3),
        A.RandomGamma(gamma_limit=(80, 120), p=0.3),
    ])

def data_generator(images, masks, batch_size, augment=None):
    idxs = np.arange(len(images))
    while True:
        np.random.shuffle(idxs)
        for i in range(0, len(images), batch_size):
            batch_idxs = idxs[i:i+batch_size]
            batch_x, batch_y = [], []
            
            for idx in batch_idxs:
                img, mask = images[idx], masks[idx]
                
                if augment:
                    aug = augment(image=img, mask=mask)
                    img_aug, mask_aug = aug['image'], aug['mask']
                else:
                    img_aug, mask_aug = img, mask
                
                mask_cat = to_categorical(mask_aug, num_classes=3)
                batch_x.append(img_aug)
                batch_y.append(mask_cat)
            
            yield np.stack(batch_x).astype(np.float32), np.stack(batch_y).astype(np.float32)

# ============================================================================
# ECA ATTENTION MODULE
# ============================================================================

def eca_block(input_feature, b=1, gamma=2, name=""):
    """
    ECA (Efficient Channel Attention) Module
    
    Unlike CBAM which uses both channel and spatial attention, ECA only uses
    efficient channel attention with adaptive kernel size.
    
    Args:
        input_feature: Input tensor
        b: Parameter for adaptive kernel size calculation (default: 1)
        gamma: Parameter for adaptive kernel size calculation (default: 2)
        name: Name prefix for layers
    
    Paper: "ECA-Net: Efficient Channel Attention for Deep Convolutional Neural Networks"
    """
    channel = input_feature.shape[-1]
    
    # Adaptive kernel size calculation
    # k = |log2(channel) / gamma + b / gamma|_odd
    t = int(abs((np.log2(channel) / gamma) + (b / gamma)))
    k = t if t % 2 else t + 1  # Make it odd
    k = max(3, k)  # Minimum kernel size of 3
    
    # Global Average Pooling
    avg_pool = layers.GlobalAveragePooling2D()(input_feature)
    avg_pool = layers.Reshape((channel, 1))(avg_pool)
    
    # 1D Convolution with adaptive kernel size
    # This is the key difference from CBAM - uses 1D conv instead of FC layers
    eca_feature = layers.Conv1D(
        filters=1,
        kernel_size=k,
        padding='same',
        activation='sigmoid',
        name=f'eca_conv1d_{name}'
    )(avg_pool)
    
    eca_feature = layers.Reshape((1, 1, channel))(eca_feature)
    
    # Multiply input with attention weights
    output = layers.Multiply(name=f'eca_multiply_{name}')([input_feature, eca_feature])
    
    return output

# ============================================================================
# LOSS FUNCTIONS
# ============================================================================

def focal_loss(y_true, y_pred, gamma=2.0, alpha=None, epsilon=1e-7):
    if alpha is None:
        alpha = [0.25, 1.0, 1.0]
    
    y_pred = K.clip(y_pred, epsilon, 1.0 - epsilon)
    focal_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        pt = y_pred_c
        focal_weight = K.pow(1.0 - pt, gamma)
        cross_entropy = -K.log(pt)
        focal_loss_c = alpha[c] * focal_weight * cross_entropy * y_true_c
        focal_loss_value += K.mean(focal_loss_c)
    
    return focal_loss_value

def enhanced_iou_loss(y_true, y_pred, smooth=1e-7):
    eiou_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        
        intersection = K.sum(y_true_c * y_pred_c, axis=[1, 2])
        union = K.sum(y_true_c, axis=[1, 2]) + K.sum(y_pred_c, axis=[1, 2]) - intersection
        iou = (intersection + smooth) / (union + smooth)
        
        height = K.cast(K.shape(y_true_c)[1], 'float32')
        width = K.cast(K.shape(y_true_c)[2], 'float32')
        
        y_coords = K.arange(0, height)
        x_coords = K.arange(0, width)
        y_grid = K.tile(K.reshape(y_coords, (-1, 1)), (1, K.cast(width, 'int32')))
        x_grid = K.tile(K.reshape(x_coords, (1, -1)), (K.cast(height, 'int32'), 1))
        y_grid = K.cast(y_grid, 'float32')
        x_grid = K.cast(x_grid, 'float32')
        
        true_mass = K.sum(y_true_c, axis=[1, 2]) + smooth
        true_center_y = K.sum(y_true_c * y_grid, axis=[1, 2]) / true_mass
        true_center_x = K.sum(y_true_c * x_grid, axis=[1, 2]) / true_mass
        
        pred_mass = K.sum(y_pred_c, axis=[1, 2]) + smooth
        pred_center_y = K.sum(y_pred_c * y_grid, axis=[1, 2]) / pred_mass
        pred_center_x = K.sum(y_pred_c * x_grid, axis=[1, 2]) / pred_mass
        
        center_distance = K.square(true_center_y - pred_center_y) + K.square(true_center_x - pred_center_x)
        diagonal = K.square(height) + K.square(width)
        center_penalty = center_distance / (diagonal + smooth)
        
        true_width = K.sqrt(K.sum(K.sum(y_true_c, axis=1), axis=1) + smooth)
        true_height = K.sqrt(K.sum(K.sum(y_true_c, axis=2), axis=1) + smooth)
        pred_width = K.sqrt(K.sum(K.sum(y_pred_c, axis=1), axis=1) + smooth)
        pred_height = K.sqrt(K.sum(K.sum(y_pred_c, axis=2), axis=1) + smooth)
        
        width_diff = K.square(pred_width - true_width)
        height_diff = K.square(pred_height - true_height)
        aspect_penalty = width_diff / (K.square(width) + smooth) + height_diff / (K.square(height) + smooth)
        
        eiou_c = 1.0 - iou + center_penalty + aspect_penalty
        eiou_loss_value += K.mean(eiou_c)
    
    return eiou_loss_value / 3.0

def focal_eiou_combined_loss(y_true, y_pred, focal_weight=1.0, eiou_weight=1.0, gamma=2.0, alpha=None):
    fl = focal_loss(y_true, y_pred, gamma=gamma, alpha=alpha)
    eiou = enhanced_iou_loss(y_true, y_pred)
    return focal_weight * fl + eiou_weight * eiou

# ============================================================================
# ENHANCED DECODER BLOCK (WITHOUT ATTENTION)
# ============================================================================

def enhanced_decoder_block_no_attention(x, skip_connection, filters, block_name, dropout_rate=0.3):
    """Enhanced decoder block WITHOUT attention"""
    x = layers.UpSampling2D((2, 2), name=f'{block_name}_upsample')(x)
    
    if skip_connection.shape[-1] != x.shape[-1]:
        skip_connection = layers.Conv2D(x.shape[-1], (1, 1), activation='relu', 
                                      padding='same', name=f'{block_name}_skip_align')(skip_connection)
        skip_connection = layers.BatchNormalization(name=f'{block_name}_skip_bn')(skip_connection)
    
    x = layers.Concatenate(name=f'{block_name}_concat')([x, skip_connection])
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv1')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn1')(x)
    x = layers.Dropout(dropout_rate, name=f'{block_name}_dropout')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv2')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn2')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv3')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn3')(x)
    
    residual = x
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv4')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn4')(x)
    
    x = layers.Add(name=f'{block_name}_residual')([x, residual])
    x = layers.Conv2D(filters, (1, 1), activation='relu', padding='same', name=f'{block_name}_conv_final')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn_final')(x)
    
    return x

# ============================================================================
# MODEL: ECA ON SKIP CONNECTIONS
# ============================================================================

def build_combined_unet_eca(input_shape=(256, 256, 3), num_classes=3, 
                            use_deeper=False, dropout_rate=0.3):
    """
    Combined MobileNet-UNet with ECA (Efficient Channel Attention)
    
    ECA Placement:
    - Skip_1 (128x128): YES ✅
    - Skip_2 (64x64): YES ✅
    - Skip_3 (32x32): YES ✅
    - Skip_4 (16x16): YES ✅
    - Bridge: NO ❌
    - Decoder blocks: NO ❌
    Total: 4 ECA blocks (on skip connections)
    
    Advantage: ECA is more parameter-efficient than CBAM
    - Only channel attention (no spatial)
    - Uses 1D conv instead of FC layers
    - Adaptive kernel size based on channel dimension
    """
    
    print(f"\nBuilding Combined UNet with ECA...")
    print(f"  Deeper Architecture: {use_deeper}")
    print(f"  MC Dropout Rate: {dropout_rate}")
    print(f"  ECA Attention: SKIP-ONLY (4 blocks on skip connections)")
    
    inputs = layers.Input(input_shape, dtype='float32')
    backbone = MobileNetV2(input_tensor=inputs, weights='imagenet', include_top=False)
    
    # Get skip connections and apply ECA
    skip_1_raw = backbone.get_layer('block_1_expand_relu').output  # 128x128
    skip_2_raw = backbone.get_layer('block_3_expand_relu').output  # 64x64
    skip_3_raw = backbone.get_layer('block_6_expand_relu').output  # 32x32
    skip_4_raw = backbone.get_layer('block_13_expand_relu').output # 16x16
    bridge = backbone.output  # 8x8
    
    print("  Applying ECA to skip connections...")
    print(f"    skip_1 (128x128, {skip_1_raw.shape[-1]} channels): WITH ECA ✓")
    print(f"    skip_2 (64x64, {skip_2_raw.shape[-1]} channels): WITH ECA ✓")
    print(f"    skip_3 (32x32, {skip_3_raw.shape[-1]} channels): WITH ECA ✓")
    print(f"    skip_4 (16x16, {skip_4_raw.shape[-1]} channels): WITH ECA ✓")
    
    # Apply ECA to ALL skip connections
    skip_1 = eca_block(skip_1_raw, name="skip1")
    skip_2 = eca_block(skip_2_raw, name="skip2")
    skip_3 = eca_block(skip_3_raw, name="skip3")
    skip_4 = eca_block(skip_4_raw, name="skip4")
    
    # Deeper bridge (if enabled) - NO ECA on bridge
    if use_deeper:
        bridge = layers.Conv2D(1024, (3, 3), activation='relu', padding='same')(bridge)
        bridge = layers.BatchNormalization()(bridge)
    
    if dropout_rate > 0:
        bridge = layers.Dropout(dropout_rate, name='bridge_dropout')(bridge)
    
    if use_deeper:
        x = enhanced_decoder_block_no_attention(bridge, skip_4, 512, 'decoder_1', dropout_rate)
        x = enhanced_decoder_block_no_attention(x, skip_3, 256, 'decoder_2', dropout_rate)
        x = enhanced_decoder_block_no_attention(x, skip_2, 128, 'decoder_3', dropout_rate * 0.7)
        x = enhanced_decoder_block_no_attention(x, skip_1, 64, 'decoder_4', dropout_rate * 0.5)
    else:
        # Baseline decoder with skip connections
        x = layers.UpSampling2D((2, 2))(bridge)
        x = layers.Concatenate()([x, skip_4])
        x = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        if dropout_rate > 0:
            x = layers.Dropout(dropout_rate)(x)
        x = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        
        x = layers.UpSampling2D((2, 2))(x)
        x = layers.Concatenate()([x, skip_3])
        x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        if dropout_rate > 0:
            x = layers.Dropout(dropout_rate)(x)
        x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        
        x = layers.UpSampling2D((2, 2))(x)
        x = layers.Concatenate()([x, skip_2])
        x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        if dropout_rate > 0:
            x = layers.Dropout(dropout_rate * 0.7)(x)
        x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        
        x = layers.UpSampling2D((2, 2))(x)
        x = layers.Concatenate()([x, skip_1])
        x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        if dropout_rate > 0:
            x = layers.Dropout(dropout_rate * 0.5)(x)
        x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
    
    # Final upsampling
    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    
    outputs = layers.Conv2D(num_classes, (1, 1), activation='softmax', dtype='float32')(x)
    
    model = models.Model(inputs, outputs)
    
    # Print configuration
    if dropout_rate > 0:
        dropout_layers = [layer for layer in model.layers if isinstance(layer, layers.Dropout)]
        print(f"\n  MC Dropout Configuration:")
        print(f"    Total Dropout Layers: {len(dropout_layers)}")
        print(f"    Dropout Rates: {[f'{layer.rate:.2f}' for layer in dropout_layers]}")
    
    eca_count = sum(1 for layer in model.layers if 'eca_conv1d' in layer.name)
    print(f"\n  ECA Configuration:")
    print(f"    Total ECA Blocks: {eca_count}")
    print(f"    ECA Locations: Skip connections ONLY (4 blocks)")
    print(f"    Advantage: More parameter-efficient than CBAM")
    
    return model

# ============================================================================
# METRICS
# ============================================================================

def dice_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    return (2. * intersection + smooth) / (K.sum(y_true_class) + K.sum(y_pred_class) + smooth)

def dice_class_0(y_true, y_pred): return dice_coef_class(y_true, y_pred, 0)
def dice_class_1(y_true, y_pred): return dice_coef_class(y_true, y_pred, 1)
def dice_class_2(y_true, y_pred): return dice_coef_class(y_true, y_pred, 2)

def iou_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    union = K.sum(y_true_class) + K.sum(y_pred_class) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_class_0(y_true, y_pred): return iou_coef_class(y_true, y_pred, 0)
def iou_class_1(y_true, y_pred): return iou_coef_class(y_true, y_pred, 1)
def iou_class_2(y_true, y_pred): return iou_coef_class(y_true, y_pred, 2)

# ============================================================================
# MC DROPOUT
# ============================================================================

def mc_dropout_predict(model, X, num_samples=15, batch_size=4, verbose=True):
    """MC Dropout prediction using training=True flag"""
    if verbose:
        print(f"\nRunning MC Dropout with {num_samples} stochastic forward passes...")
    
    predictions = []
    num_batches = int(np.ceil(len(X) / batch_size))
    
    for i in range(num_samples):
        if verbose and (i + 1) % 5 == 0:
            print(f"  Completed: {i+1}/{num_samples} forward passes")
        
        batch_preds = []
        for batch_idx in range(num_batches):
            start_idx = batch_idx * batch_size
            end_idx = min(start_idx + batch_size, len(X))
            X_batch = X[start_idx:end_idx]
            
            pred_batch = model(X_batch, training=True)
            batch_preds.append(pred_batch.numpy())
        
        pred = np.concatenate(batch_preds, axis=0)
        predictions.append(pred)
        
        if (i + 1) % 5 == 0:
            gc.collect()
    
    all_preds = np.array(predictions)
    mean_pred = np.mean(all_preds, axis=0)
    std_pred = np.std(all_preds, axis=0)
    
    del all_preds
    gc.collect()
    
    if verbose:
        print(f"✓ MC Dropout completed")
    
    return mean_pred, std_pred

# ============================================================================
# VISUALIZATION FUNCTIONS
# ============================================================================

def plot_training_history(history, model_name, save_dir='results'):
    """Plot training history: loss and accuracy curves"""
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    
    axes[0].plot(history.history['loss'], label='Training Loss', linewidth=2)
    axes[0].plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
    axes[0].set_title(f'{model_name} - Loss Over Epochs', fontsize=14, fontweight='bold')
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('Loss', fontsize=12)
    axes[0].legend(fontsize=10)
    axes[0].grid(True, alpha=0.3)
    
    axes[1].plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
    axes[1].plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
    axes[1].set_title(f'{model_name} - Accuracy Over Epochs', fontsize=14, fontweight='bold')
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('Accuracy', fontsize=12)
    axes[1].legend(fontsize=10)
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(f"{save_dir}/{model_name}_training_curves.png", dpi=300, bbox_inches='tight')
    print(f"✓ Training curves saved: {save_dir}/{model_name}_training_curves.png")
    plt.show()
    plt.close()

def plot_confusion_matrices(y_true, y_pred, model_name, save_dir='results'):
    """Plot confusion matrix and normalized confusion matrix"""
    y_true_labels = np.argmax(y_true, axis=-1).flatten()
    y_pred_labels = np.argmax(y_pred, axis=-1).flatten()
    
    cm = confusion_matrix(y_true_labels, y_pred_labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    class_names = ['Background', 'Disc', 'Cup']
    
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[0], cbar_kws={'label': 'Count'})
    axes[0].set_title(f'{model_name}\nConfusion Matrix', fontsize=14, fontweight='bold')
    axes[0].set_ylabel('True Label', fontsize=12)
    axes[0].set_xlabel('Predicted Label', fontsize=12)
    
    sns.heatmap(cm_normalized, annot=True, fmt='.3f', cmap='Greens',
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[1], cbar_kws={'label': 'Proportion'})
    axes[1].set_title(f'{model_name}\nNormalized Confusion Matrix', fontsize=14, fontweight='bold')
    axes[1].set_ylabel('True Label', fontsize=12)
    axes[1].set_xlabel('Predicted Label', fontsize=12)
    
    plt.tight_layout()
    plt.savefig(f"{save_dir}/{model_name}_confusion_matrices.png", dpi=300, bbox_inches='tight')
    print(f"✓ Confusion matrices saved: {save_dir}/{model_name}_confusion_matrices.png")
    plt.show()
    plt.close()
    
    print(f"\nConfusion Matrix:\n{cm}")
    print(f"\nNormalized Confusion Matrix:\n{np.round(cm_normalized, 3)}")
    
    return cm, cm_normalized

# ============================================================================
# TRAINING
# ============================================================================

def train_model(X_train, y_train, X_val, y_val, X_test, y_test, model_name, 
               use_focal_eiou=False, use_deeper=False, dropout_rate=0.0,
               augment=None, save_dir='results'):
    """Train model with visualization"""
    print(f"\n{'='*80}")
    print(f"TRAINING: {model_name}")
    print(f"{'='*80}")
    print(f"  Focal-EIoU Loss: {'✓' if use_focal_eiou else '✗'}")
    print(f"  Deeper Decoder: {'✓' if use_deeper else '✗'}")
    print(f"  MC Dropout: {'✓ (rate=' + str(dropout_rate) + ')' if dropout_rate > 0 else '✗'}")
    
    K.clear_session()
    
    # Build model
    model = build_combined_unet_eca(use_deeper=use_deeper, dropout_rate=dropout_rate)
    param_count = model.count_params()
    print(f"  Total Parameters: {param_count:,}")
    
    # Choose loss
    if use_focal_eiou:
        loss_fn = focal_eiou_combined_loss
    else:
        loss_fn = "categorical_crossentropy"
    
    # Compile
    initial_lr = 5e-4 if use_deeper else 1e-3
    model.compile(
        optimizer=optimizers.Adam(learning_rate=initial_lr),
        loss=loss_fn,
        metrics=[dice_coef_multiclass, dice_class_0, dice_class_1, dice_class_2,
                "accuracy", iou_coef_multiclass, iou_class_0, iou_class_1, iou_class_2]
    )
    
    # Callbacks
    checkpoint = ModelCheckpoint(f"{save_dir}/{model_name}.keras", save_best_only=True, 
                                verbose=1, monitor='val_loss', mode='min')
    reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=3, 
                                  verbose=1, mode='min', min_lr=1e-7)
    early_stop = EarlyStopping(monitor="val_loss", patience=20, verbose=1, 
                              restore_best_weights=True, mode='min')
    
    # Training
    batch_size = 4 if use_deeper else 8
    steps_train = X_train.shape[0] // batch_size
    steps_val = X_val.shape[0] // batch_size
    
    try:
        history = model.fit(
            data_generator(X_train, y_train, batch_size, augment),
            validation_data=data_generator(X_val, y_val, batch_size, None),
            steps_per_epoch=steps_train,
            validation_steps=steps_val,
            epochs=50,
            callbacks=[checkpoint, reduce_lr, early_stop],
            verbose=1
        )
    except Exception as e:
        print(f"✗ Error: {e}. Retrying with smaller batch...")
        batch_size = 2 if use_deeper else 4
        steps_train = X_train.shape[0] // batch_size
        steps_val = X_val.shape[0] // batch_size
        
        history = model.fit(
            data_generator(X_train, y_train, batch_size, augment),
            validation_data=data_generator(X_val, y_val, batch_size, None),
            steps_per_epoch=steps_train,
            validation_steps=steps_val,
            epochs=50,
            callbacks=[checkpoint, reduce_lr, early_stop],
            verbose=1
        )
    
    print(f"✓ Training completed")
    
    return model, history, param_count

# ============================================================================
# EVALUATION
# ============================================================================

def evaluate_model(model, X_test, y_test, model_name, run_mc_dropout=False, history=None, save_dir='results'):
    """Evaluate model"""
    print(f"\n{'='*80}")
    print(f"EVALUATION: {model_name}")
    print(f"{'='*80}")
    
    y_test_cat = np.array([to_categorical(mask, num_classes=3) for mask in y_test])
    
    # Predict
    y_pred = model.predict(X_test, verbose=0, batch_size=8)
    
    # Classification metrics
    y_true_labels = np.argmax(y_test_cat, axis=-1).flatten()
    y_pred_labels = np.argmax(y_pred, axis=-1).flatten()
    
    precision = precision_score(y_true_labels, y_pred_labels, average=None, zero_division=0)
    recall = recall_score(y_true_labels, y_pred_labels, average=None, zero_division=0)
    f1 = f1_score(y_true_labels, y_pred_labels, average=None, zero_division=0)
    
    print(f"\nPrecision, Recall, F1 Score per class:")
    class_names = ["Background", "Disc", "Cup"]
    for idx, cname in enumerate(class_names):
        print(f"  {cname}: Precision={precision[idx]:.4f}, Recall={recall[idx]:.4f}, F1={f1[idx]:.4f}")
    
    print(f"\nMacro-averaged metrics:")
    print(f"  Precision: {np.mean(precision):.4f}")
    print(f"  Recall: {np.mean(recall):.4f}")
    print(f"  F1 Score: {np.mean(f1):.4f}")
    
    # Per-class Dice and IoU
    results = {'standard': {}}
    for cidx, cname in enumerate(class_names):
        y_true_c = (np.argmax(y_test_cat, axis=-1) == cidx).astype(np.float32)
        y_pred_c = (np.argmax(y_pred, axis=-1) == cidx).astype(np.float32)
        
        intersection = np.sum(y_true_c * y_pred_c)
        dice = (2. * intersection + 1e-7) / (np.sum(y_true_c) + np.sum(y_pred_c) + 1e-7)
        union = np.sum(y_true_c) + np.sum(y_pred_c) - intersection
        iou = (intersection + 1e-7) / (union + 1e-7)
        
        results['standard'][cname] = {'dice': dice, 'iou': iou}
        print(f"  {cname}: Dice={dice:.4f}, IoU={iou:.4f}")
    
    # MC Dropout
    if run_mc_dropout:
        print("\nMC Dropout Evaluation:")
        mean_pred, std_pred = mc_dropout_predict(model, X_test[:100], num_samples=10, verbose=True)
        results['mc_dropout'] = {}
        for cidx, cname in enumerate(class_names):
            mean_std = np.mean(std_pred[:, :, :, cidx])
            results['mc_dropout'][cname] = {'mean_uncertainty': mean_std}
            print(f"  {cname} uncertainty: {mean_std:.4f}")
    
    # Generate visualizations AFTER printing all metrics
    print("\n" + "="*80)
    print("GENERATING VISUALIZATIONS")
    print("="*80)
    
    if history is not None:
        plot_training_history(history, model_name, save_dir)
    
    plot_confusion_matrices(y_test_cat, y_pred, model_name, save_dir=save_dir)
    
    return results

# ============================================================================
# MAIN
# ============================================================================

if __name__ == "__main__":
    gpu_available = configure_gpu()
    root_dir = "/kaggle/input/refuge/REFUGE/"
    train_aug = setup_augmentations()
    save_dir = "results"
    os.makedirs(save_dir, exist_ok=True)
    
    print(f"\n{'='*100}")
    print(f"{'MOBILENET-UNET WITH ECA ATTENTION':^100s}")
    print(f"{'='*100}")
    
    # Load data
    all_images, all_masks = load_all_data(root_dir)
    (X_train, y_train), (X_val, y_val), (X_test, y_test) = create_new_split(all_images, all_masks)
    
    # Train model with ECA
    model, history, params = train_model(
        X_train, y_train, X_val, y_val, X_test, y_test,
        "Deeper_Focal_EIoU_MC_ECA",
        use_focal_eiou=True, use_deeper=True, dropout_rate=0.3,
        augment=train_aug, save_dir=save_dir
    )
    
    # Evaluate
    results = evaluate_model(model, X_test, y_test, "Deeper+Focal+EIoU+MC+ECA", 
                            run_mc_dropout=True, history=history, save_dir=save_dir)
    
    print(f"\n{'='*100}")
    print(f"{'✓ TRAINING AND EVALUATION COMPLETED!':^100s}")
    print(f"{'='*100}")
    print(f"\nModel: Deeper + Focal-EIoU + MC Dropout + ECA Attention")
    print(f"Attention: ECA on skip connections (4 blocks)")
    print(f"Parameters: {params:,}")
    print(f"Results saved in: {save_dir}/")
    print(f"\n{'='*100}\n")
# Out:
# Configuring GPU settings...
# ✓ GPU found: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
#
# ====================================================================================================
#                                  MOBILENET-UNET WITH ECA ATTENTION
# ====================================================================================================
# Loading train data...
#   train: 400 samples
# Loading val data...
#   val: 400 samples
# Loading test data...
#   test: 400 samples
# Split - Train: 600, Val: 200, Test: 400
#
# ================================================================================
# TRAINING: Deeper_Focal_EIoU_MC_ECA
# ================================================================================
#   Focal-EIoU Loss: ✓
#   Deeper Decoder: ✓
#   MC Dropout: ✓ (rate=0.3)
#
# Building Combined UNet with ECA...
#   Deeper Architecture: True
#   MC Dropout Rate: 0.3
#   ECA Attention: SKIP-ONLY (4 blocks on skip connections)
#   Applying ECA to skip connections...
#     skip_1 (128x128, 96 channels): WITH ECA ✓
#     skip_2 (64x64, 144 channels): WITH ECA ✓
#     skip_3 (32x32, 192 channels): WITH ECA ✓
#     skip_4 (16x16, 576 channels): WITH ECA ✓
#
#   MC Dropout Configuration:
#     Total Dropout Layers: 5
#     Dropout Rates: ['0.30', '0.30', '0.30', '0.21', '0.15']
#
#   ECA Configuration:
#     Total ECA Blocks: 4
#     ECA Locations: Skip connections ONLY (4 blocks)
#     Advantage: More parameter-efficient than CBAM
#   Total Parameters: 37,131,417
# Epoch 1/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8226 - dice_class_0: 0.8854 - dice_class_1: 0.3229 - dice_class_2: 0.1833 - dice_coef_multiclass: 0.5469 - iou_class_0: 0.8229 - iou_class_1: 0.2052 - iou_class_2: 0.1092 - iou_coef_multiclass: 0.3845 - loss: 1.2369
# Epoch 1: val_loss improved from inf to 0.59466, saving model to results/Deeper_Focal_EIoU_MC_ECA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 114s 198ms/step - accuracy: 0.8232 - dice_class_0: 0.8859 - dice_class_1: 0.3238 - dice_class_2: 0.1841 - dice_coef_multiclass: 0.5477 - iou_class_0: 0.8236 - iou_class_1: 0.2058 - iou_class_2: 0.1097 - iou_coef_multiclass: 0.3852 - loss: 1.2358 - val_accuracy: 0.9767 - val_dice_class_0: 0.9892 - val_dice_class_1: 0.4933 - val_dice_class_2: 0.4909 - val_dice_coef_multiclass: 0.9613 - val_iou_class_0: 0.9787 - val_iou_class_1: 0.3305 - val_iou_class_2: 0.3272 - val_iou_coef_multiclass: 0.9255 - val_loss: 0.5947 - learning_rate: 5.0000e-04
# Epoch 2/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9813 - dice_class_0: 0.9913 - dice_class_1: 0.6738 - dice_class_2: 0.4425 - dice_coef_multiclass: 0.8910 - iou_class_0: 0.9827 - iou_class_1: 0.5122 - iou_class_2: 0.2865 - iou_coef_multiclass: 0.8054 - loss: 0.7299
# Epoch 2: val_loss did not improve from 0.59466
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9813 - dice_class_0: 0.9913 - dice_class_1: 0.6742 - dice_class_2: 0.4427 - dice_coef_multiclass: 0.8912 - iou_class_0: 0.9827 - iou_class_1: 0.5126 - iou_class_2: 0.2867 - iou_coef_multiclass: 0.8058 - loss: 0.7294 - val_accuracy: 0.4979 - val_dice_class_0: 0.6664 - val_dice_class_1: 0.0079 - val_dice_class_2: 0.0219 - val_dice_coef_multiclass: 0.4963 - val_iou_class_0: 0.5009 - val_iou_class_1: 0.0040 - val_iou_class_2: 0.0111 - val_iou_coef_multiclass: 0.3312 - val_loss: 3.1569 - learning_rate: 5.0000e-04
# Epoch 3/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9932 - dice_class_0: 0.9972 - dice_class_1: 0.7981 - dice_class_2: 0.7583 - dice_coef_multiclass: 0.9805 - iou_class_0: 0.9945 - iou_class_1: 0.6677 - iou_class_2: 0.6158 - iou_coef_multiclass: 0.9618 - loss: 0.4376
# Epoch 3: val_loss did not improve from 0.59466
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9933 - dice_class_0: 0.9972 - dice_class_1: 0.7983 - dice_class_2: 0.7586 - dice_coef_multiclass: 0.9805 - iou_class_0: 0.9945 - iou_class_1: 0.6679 - iou_class_2: 0.6162 - iou_coef_multiclass: 0.9619 - loss: 0.4371 - val_accuracy: 0.9863 - val_dice_class_0: 0.9934 - val_dice_class_1: 0.2813 - val_dice_class_2: 0.2789 - val_dice_coef_multiclass: 0.9863 - val_iou_class_0: 0.9868 - val_iou_class_1: 0.1775 - val_iou_class_2: 0.1801 - val_iou_coef_multiclass: 0.9730 - val_loss: 0.8263 - learning_rate: 5.0000e-04
# Epoch 4/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9960 - dice_class_0: 0.9986 - dice_class_1: 0.8552 - dice_class_2: 0.8350 - dice_coef_multiclass: 0.9943 - iou_class_0: 0.9973 - iou_class_1: 0.7483 - iou_class_2: 0.7199 - iou_coef_multiclass: 0.9887 - loss: 0.2476
# Epoch 4: val_loss improved from 0.59466 to 0.20331, saving model to results/Deeper_Focal_EIoU_MC_ECA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 149ms/step - accuracy: 0.9960 - dice_class_0: 0.9986 - dice_class_1: 0.8553 - dice_class_2: 0.8351 - dice_coef_multiclass: 0.9943 - iou_class_0: 0.9973 - iou_class_1: 0.7484 - iou_class_2: 0.7200 - iou_coef_multiclass: 0.9887 - loss: 0.2474 - val_accuracy: 0.9965 - val_dice_class_0: 0.9988 - val_dice_class_1: 0.8536 - val_dice_class_2: 0.8496 - val_dice_coef_multiclass: 0.9965 - val_iou_class_0: 0.9977 - val_iou_class_1: 0.7464 - val_iou_class_2: 0.7423 - val_iou_coef_multiclass: 0.9930 - val_loss: 0.2033 - learning_rate: 5.0000e-04
# Epoch 5/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9971 - dice_class_0: 0.9991 - dice_class_1: 0.8844 - dice_class_2: 0.8713 - dice_coef_multiclass: 0.9965 - iou_class_0: 0.9981 - iou_class_1: 0.7938 - iou_class_2: 0.7743 - iou_coef_multiclass: 0.9931 - loss: 0.1791
# Epoch 5: val_loss did not improve from 0.20331
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9971 - dice_class_0: 0.9991 - dice_class_1: 0.8844 - dice_class_2: 0.8714 - dice_coef_multiclass: 0.9965 - iou_class_0: 0.9981 - iou_class_1: 0.7938 - iou_class_2: 0.7743 - iou_coef_multiclass: 0.9931 - loss: 0.1790 - val_accuracy: 0.9955 - val_dice_class_0: 0.9986 - val_dice_class_1: 0.8065 - val_dice_class_2: 0.7648 - val_dice_coef_multiclass: 0.9955 - val_iou_class_0: 0.9971 - val_iou_class_1: 0.6777 - val_iou_class_2: 0.6224 - val_iou_coef_multiclass: 0.9911 - val_loss: 0.2810 - learning_rate: 5.0000e-04
# Epoch 6/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9973 - dice_class_0: 0.9991 - dice_class_1: 0.8934 - dice_class_2: 0.8796 - dice_coef_multiclass: 0.9970 - iou_class_0: 0.9983 - iou_class_1: 0.8082 - iou_class_2: 0.7873 - iou_coef_multiclass: 0.9940 - loss: 0.1597
# Epoch 6: val_loss did not improve from 0.20331
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9973 - dice_class_0: 0.9991 - dice_class_1: 0.8934 - dice_class_2: 0.8797 - dice_coef_multiclass: 0.9970 - iou_class_0: 0.9983 - iou_class_1: 0.8082 - iou_class_2: 0.7873 - iou_coef_multiclass: 0.9940 - loss: 0.1597 - val_accuracy: 0.9938 - val_dice_class_0: 0.9975 - val_dice_class_1: 0.7304 - val_dice_class_2: 0.7323 - val_dice_coef_multiclass: 0.9938 - val_iou_class_0: 0.9951 - val_iou_class_1: 0.5833 - val_iou_class_2: 0.5949 - val_iou_coef_multiclass: 0.9876 - val_loss: 0.3524 - learning_rate: 5.0000e-04
# Epoch 7/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9976 - dice_class_0: 0.9992 - dice_class_1: 0.9037 - dice_class_2: 0.8895 - dice_coef_multiclass: 0.9974 - iou_class_0: 0.9985 - iou_class_1: 0.8251 - iou_class_2: 0.8019 - iou_coef_multiclass: 0.9948 - loss: 0.1428
# Epoch 7: val_loss improved from 0.20331 to 0.16828, saving model to results/Deeper_Focal_EIoU_MC_ECA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 149ms/step - accuracy: 0.9976 - dice_class_0: 0.9992 - dice_class_1: 0.9037 - dice_class_2: 0.8895 - dice_coef_multiclass: 0.9974 - iou_class_0: 0.9985 - iou_class_1: 0.8250 - iou_class_2: 0.8019 - iou_coef_multiclass: 0.9948 - loss: 0.1429 - val_accuracy: 0.9971 - val_dice_class_0: 0.9991 - val_dice_class_1: 0.8829 - val_dice_class_2: 0.8534 - val_dice_coef_multiclass: 0.9971 - val_iou_class_0: 0.9983 - val_iou_class_1: 0.7918 - val_iou_class_2: 0.7471 - val_iou_coef_multiclass: 0.9942 - val_loss: 0.1683 - learning_rate: 5.0000e-04
# Epoch 8/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9976 - dice_class_0: 0.9992 - dice_class_1: 0.9045 - dice_class_2: 0.8932 - dice_coef_multiclass: 0.9975 - iou_class_0: 0.9985 - iou_class_1: 0.8264 - iou_class_2: 0.8082 - iou_coef_multiclass: 0.9949 - loss: 0.1396
# Epoch 8: val_loss did not improve from 0.16828
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9976 - dice_class_0: 0.9992 - dice_class_1: 0.9045 - dice_class_2: 0.8932 - dice_coef_multiclass: 0.9975 - iou_class_0: 0.9985 - iou_class_1: 0.8264 - iou_class_2: 0.8083 - iou_coef_multiclass: 0.9949 - loss: 0.1396 - val_accuracy: 0.9972 - val_dice_class_0: 0.9991 - val_dice_class_1: 0.8819 - val_dice_class_2: 0.8559 - val_dice_coef_multiclass: 0.9972 - val_iou_class_0: 0.9983 - val_iou_class_1: 0.7903 - val_iou_class_2: 0.7505 - val_iou_coef_multiclass: 0.9944 - val_loss: 0.1714 - learning_rate: 5.0000e-04
# Epoch 9/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9976 - dice_class_0: 0.9992 - dice_class_1: 0.9056 - dice_class_2: 0.8969 - dice_coef_multiclass: 0.9975 - iou_class_0: 0.9985 - iou_class_1: 0.8282 - iou_class_2: 0.8140 - iou_coef_multiclass: 0.9950 - loss: 0.1351
# Epoch 9: val_loss improved from 0.16828 to 0.15155, saving model to results/Deeper_Focal_EIoU_MC_ECA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 150ms/step - accuracy: 0.9976 - dice_class_0: 0.9992 - dice_class_1: 0.9056 - dice_class_2: 0.8969 - dice_coef_multiclass: 0.9975 - iou_class_0: 0.9985 - iou_class_1: 0.8282 - iou_class_2: 0.8140 - iou_coef_multiclass: 0.9950 - loss: 0.1351 - val_accuracy: 0.9974 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8926 - val_dice_class_2: 0.8763 - val_dice_coef_multiclass: 0.9974 - val_iou_class_0: 0.9984 - val_iou_class_1: 0.8074 - val_iou_class_2: 0.7812 - val_iou_coef_multiclass: 0.9947 - val_loss: 0.1515 - learning_rate: 5.0000e-04
# Epoch 10/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9976 - dice_class_0: 0.9993 - dice_class_1: 0.9058 - dice_class_2: 0.8947 - dice_coef_multiclass: 0.9975 - iou_class_0: 0.9985 - iou_class_1: 0.8288 - iou_class_2: 0.8109 - iou_coef_multiclass: 0.9951 - loss: 0.1351
# Epoch 10: val_loss did not improve from 0.15155
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9976 - dice_class_0: 0.9993 - dice_class_1: 0.9058 - dice_class_2: 0.8947 - dice_coef_multiclass: 0.9975 - iou_class_0: 0.9985 - iou_class_1: 0.8288 - iou_class_2: 0.8109 - iou_coef_multiclass: 0.9951 - loss: 0.1351 - val_accuracy: 0.9964 - val_dice_class_0: 0.9989 - val_dice_class_1: 0.8470 - val_dice_class_2: 0.8092 - val_dice_coef_multiclass: 0.9964 - val_iou_class_0: 0.9978 - val_iou_class_1: 0.7365 - val_iou_class_2: 0.6834 - val_iou_coef_multiclass: 0.9928 - val_loss: 0.2157 - learning_rate: 5.0000e-04
# Epoch 11/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9977 - dice_class_0: 0.9992 - dice_class_1: 0.9061 - dice_class_2: 0.9021 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9985 - iou_class_1: 0.8290 - iou_class_2: 0.8227 - iou_coef_multiclass: 0.9952 - loss: 0.1316
# Epoch 11: val_loss did not improve from 0.15155
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9977 - dice_class_0: 0.9992 - dice_class_1: 0.9061 - dice_class_2: 0.9021 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9985 - iou_class_1: 0.8290 - iou_class_2: 0.8227 - iou_coef_multiclass: 0.9952 - loss: 0.1316 - val_accuracy: 0.9963 - val_dice_class_0: 0.9987 - val_dice_class_1: 0.8416 - val_dice_class_2: 0.8177 - val_dice_coef_multiclass: 0.9963 - val_iou_class_0: 0.9975 - val_iou_class_1: 0.7320 - val_iou_class_2: 0.6997 - val_iou_coef_multiclass: 0.9926 - val_loss: 0.2217 - learning_rate: 5.0000e-04
# Epoch 12/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9105 - dice_class_2: 0.9112 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9985 - iou_class_1: 0.8362 - iou_class_2: 0.8376 - iou_coef_multiclass: 0.9954 - loss: 0.1225
# Epoch 12: val_loss did not improve from 0.15155
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9105 - dice_class_2: 0.9111 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9985 - iou_class_1: 0.8362 - iou_class_2: 0.8375 - iou_coef_multiclass: 0.9954 - loss: 0.1225 - val_accuracy: 0.9964 - val_dice_class_0: 0.9989 - val_dice_class_1: 0.8492 - val_dice_class_2: 0.8146 - val_dice_coef_multiclass: 0.9964 - val_iou_class_0: 0.9977 - val_iou_class_1: 0.7415 - val_iou_class_2: 0.6918 - val_iou_coef_multiclass: 0.9929 - val_loss: 0.2165 - learning_rate: 5.0000e-04
# Epoch 13/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9194 - dice_class_2: 0.9146 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8514 - iou_class_2: 0.8441 - iou_coef_multiclass: 0.9958 - loss: 0.1146
# Epoch 13: val_loss improved from 0.15155 to 0.15083, saving model to results/Deeper_Focal_EIoU_MC_ECA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 150ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9194 - dice_class_2: 0.9147 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8514 - iou_class_2: 0.8442 - iou_coef_multiclass: 0.9958 - loss: 0.1146 - val_accuracy: 0.9975 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8966 - val_dice_class_2: 0.8709 - val_dice_coef_multiclass: 0.9975 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.8138 - val_iou_class_2: 0.7733 - val_iou_coef_multiclass: 0.9950 - val_loss: 0.1508 - learning_rate: 1.5000e-04
# Epoch 14/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9981 - dice_class_0: 0.9993 - dice_class_1: 0.9226 - dice_class_2: 0.9217 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9987 - iou_class_1: 0.8566 - iou_class_2: 0.8555 - iou_coef_multiclass: 0.9960 - loss: 0.1077
# Epoch 14: val_loss did not improve from 0.15083
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9981 - dice_class_0: 0.9993 - dice_class_1: 0.9226 - dice_class_2: 0.9216 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9987 - iou_class_1: 0.8566 - iou_class_2: 0.8554 - iou_coef_multiclass: 0.9960 - loss: 0.1077 - val_accuracy: 0.9973 - val_dice_class_0: 0.9991 - val_dice_class_1: 0.8874 - val_dice_class_2: 0.8622 - val_dice_coef_multiclass: 0.9972 - val_iou_class_0: 0.9983 - val_iou_class_1: 0.7993 - val_iou_class_2: 0.7619 - val_iou_coef_multiclass: 0.9944 - val_loss: 0.1605 - learning_rate: 1.5000e-04
# Epoch 15/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9269 - dice_class_2: 0.9255 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8639 - iou_class_2: 0.8618 - iou_coef_multiclass: 0.9962 - loss: 0.1029
# Epoch 15: val_loss did not improve from 0.15083
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9268 - dice_class_2: 0.9254 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8639 - iou_class_2: 0.8618 - iou_coef_multiclass: 0.9962 - loss: 0.1029 - val_accuracy: 0.9974 - val_dice_class_0: 0.9991 - val_dice_class_1: 0.8899 - val_dice_class_2: 0.8741 - val_dice_coef_multiclass: 0.9973 - val_iou_class_0: 0.9983 - val_iou_class_1: 0.8028 - val_iou_class_2: 0.7809 - val_iou_coef_multiclass: 0.9947 - val_loss: 0.1531 - learning_rate: 1.5000e-04
# Epoch 16/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9276 - dice_class_2: 0.9295 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8652 - iou_class_2: 0.8689 - iou_coef_multiclass: 0.9963 - loss: 0.1000
# Epoch 16: val_loss improved from 0.15083 to 0.15029, saving model to results/Deeper_Focal_EIoU_MC_ECA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 151ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9276 - dice_class_2: 0.9295 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8652 - iou_class_2: 0.8689 - iou_coef_multiclass: 0.9963 - loss: 0.1000 - val_accuracy: 0.9975 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.9000 - val_dice_class_2: 0.8703 - val_dice_coef_multiclass: 0.9975 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.8190 - val_iou_class_2: 0.7736 - val_iou_coef_multiclass: 0.9949 - val_loss: 0.1503 - learning_rate: 1.5000e-04
# Epoch 17/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9282 - dice_class_2: 0.9307 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8663 - iou_class_2: 0.8709 - iou_coef_multiclass: 0.9963 - loss: 0.0994
# Epoch 17: val_loss improved from 0.15029 to 0.14968, saving model to results/Deeper_Focal_EIoU_MC_ECA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 150ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9282 - dice_class_2: 0.9307 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8663 - iou_class_2: 0.8709 - iou_coef_multiclass: 0.9963 - loss: 0.0994 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8996 - val_dice_class_2: 0.8724 - val_dice_coef_multiclass: 0.9975 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8187 - val_iou_class_2: 0.7761 - val_iou_coef_multiclass: 0.9951 - val_loss: 0.1497 - learning_rate: 1.5000e-04
# Epoch 18/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9252 - dice_class_2: 0.9276 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9987 - iou_class_1: 0.8612 - iou_class_2: 0.8656 - iou_coef_multiclass: 0.9961 - loss: 0.1025
# Epoch 18: val_loss improved from 0.14968 to 0.14686, saving model to results/Deeper_Focal_EIoU_MC_ECA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 149ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9253 - dice_class_2: 0.9276 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9987 - iou_class_1: 0.8612 - iou_class_2: 0.8657 - iou_coef_multiclass: 0.9961 - loss: 0.1025 - val_accuracy: 0.9974 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8982 - val_dice_class_2: 0.8776 - val_dice_coef_multiclass: 0.9974 - val_iou_class_0: 0.9984 - val_iou_class_1: 0.8162 - val_iou_class_2: 0.7862 - val_iou_coef_multiclass: 0.9948 - val_loss: 0.1469 - learning_rate: 1.5000e-04
# Epoch 19/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9276 - dice_class_2: 0.9320 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8653 - iou_class_2: 0.8731 - iou_coef_multiclass: 0.9963 - loss: 0.0990
# Epoch 19: val_loss improved from 0.14686 to 0.14184, saving model to results/Deeper_Focal_EIoU_MC_ECA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 150ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9276 - dice_class_2: 0.9320 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8654 - iou_class_2: 0.8731 - iou_coef_multiclass: 0.9963 - loss: 0.0990 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9013 - val_dice_class_2: 0.8834 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8217 - val_iou_class_2: 0.7937 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1418 - learning_rate: 1.5000e-04
# Epoch 20/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9314 - dice_class_2: 0.9342 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9988 - iou_class_1: 0.8718 - iou_class_2: 0.8772 - iou_coef_multiclass: 0.9965 - loss: 0.0947
# Epoch 20: val_loss improved from 0.14184 to 0.14031, saving model to results/Deeper_Focal_EIoU_MC_ECA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 150ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9314 - dice_class_2: 0.9342 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9988 - iou_class_1: 0.8718 - iou_class_2: 0.8772 - iou_coef_multiclass: 0.9965 - loss: 0.0947 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9050 - val_dice_class_2: 0.8835 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8272 - val_iou_class_2: 0.7923 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1403 - learning_rate: 1.5000e-04
# Epoch 21/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9300 - dice_class_2: 0.9372 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8696 - iou_class_2: 0.8824 - iou_coef_multiclass: 0.9964 - loss: 0.0944
# Epoch 21: val_loss did not improve from 0.14031
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9300 - dice_class_2: 0.9372 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8696 - iou_class_2: 0.8824 - iou_coef_multiclass: 0.9964 - loss: 0.0944 - val_accuracy: 0.9976 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.9002 - val_dice_class_2: 0.8887 - val_dice_coef_multiclass: 0.9975 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.8200 - val_iou_class_2: 0.8010 - val_iou_coef_multiclass: 0.9950 - val_loss: 0.1431 - learning_rate: 1.5000e-04
# Epoch 22/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9332 - dice_class_2: 0.9365 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8751 - iou_class_2: 0.8811 - iou_coef_multiclass: 0.9966 - loss: 0.0926
# Epoch 22: val_loss did not improve from 0.14031
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9332 - dice_class_2: 0.9365 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8751 - iou_class_2: 0.8811 - iou_coef_multiclass: 0.9966 - loss: 0.0926 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9025 - val_dice_class_2: 0.8854 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8231 - val_iou_class_2: 0.7961 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1415 - learning_rate: 1.5000e-04
# Epoch 23/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9347 - dice_class_2: 0.9415 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8776 - iou_class_2: 0.8899 - iou_coef_multiclass: 0.9966 - loss: 0.0876
# Epoch 23: val_loss did not improve from 0.14031
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 4.500000213738531e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9347 - dice_class_2: 0.9415 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8776 - iou_class_2: 0.8898 - iou_coef_multiclass: 0.9966 - loss: 0.0876 - val_accuracy: 0.9966 - val_dice_class_0: 0.9988 - val_dice_class_1: 0.8703 - val_dice_class_2: 0.8700 - val_dice_coef_multiclass: 0.9966 - val_iou_class_0: 0.9976 - val_iou_class_1: 0.7713 - val_iou_class_2: 0.7717 - val_iou_coef_multiclass: 0.9932 - val_loss: 0.1733 - learning_rate: 1.5000e-04
# Epoch 24/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9368 - dice_class_2: 0.9431 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8813 - iou_class_2: 0.8927 - iou_coef_multiclass: 0.9968 - loss: 0.0858
# Epoch 24: val_loss did not improve from 0.14031
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9368 - dice_class_2: 0.9431 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8813 - iou_class_2: 0.8927 - iou_coef_multiclass: 0.9968 - loss: 0.0858 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9015 - val_dice_class_2: 0.8843 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8220 - val_iou_class_2: 0.7944 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1421 - learning_rate: 4.5000e-05
# Epoch 25/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9362 - dice_class_2: 0.9418 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8804 - iou_class_2: 0.8906 - iou_coef_multiclass: 0.9967 - loss: 0.0866
# Epoch 25: val_loss did not improve from 0.14031
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9362 - dice_class_2: 0.9419 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8804 - iou_class_2: 0.8907 - iou_coef_multiclass: 0.9967 - loss: 0.0866 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9013 - val_dice_class_2: 0.8789 - val_dice_coef_multiclass: 0.9975 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8215 - val_iou_class_2: 0.7854 - val_iou_coef_multiclass: 0.9951 - val_loss: 0.1474 - learning_rate: 4.5000e-05
# Epoch 26/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9366 - dice_class_2: 0.9449 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8811 - iou_class_2: 0.8961 - iou_coef_multiclass: 0.9967 - loss: 0.0845
# Epoch 26: val_loss did not improve from 0.14031
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.3500000204658135e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 127ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9366 - dice_class_2: 0.9449 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8811 - iou_class_2: 0.8961 - iou_coef_multiclass: 0.9967 - loss: 0.0845 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9057 - val_dice_class_2: 0.8833 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8289 - val_iou_class_2: 0.7926 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1405 - learning_rate: 4.5000e-05
# Epoch 27/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9385 - dice_class_2: 0.9452 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8844 - iou_class_2: 0.8964 - iou_coef_multiclass: 0.9968 - loss: 0.0837
# Epoch 27: val_loss improved from 0.14031 to 0.14018, saving model to results/Deeper_Focal_EIoU_MC_ECA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 150ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9385 - dice_class_2: 0.9452 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8844 - iou_class_2: 0.8964 - iou_coef_multiclass: 0.9968 - loss: 0.0837 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9061 - val_dice_class_2: 0.8859 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8289 - val_iou_class_2: 0.7965 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1402 - learning_rate: 1.3500e-05
# Epoch 28/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9412 - dice_class_2: 0.9492 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8892 - iou_class_2: 0.9038 - iou_coef_multiclass: 0.9970 - loss: 0.0782
# Epoch 28: val_loss did not improve from 0.14018
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9412 - dice_class_2: 0.9492 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8892 - iou_class_2: 0.9037 - iou_coef_multiclass: 0.9970 - loss: 0.0782 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9028 - val_dice_class_2: 0.8840 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8240 - val_iou_class_2: 0.7937 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1440 - learning_rate: 1.3500e-05
# Epoch 29/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9423 - dice_class_2: 0.9518 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8911 - iou_class_2: 0.9084 - iou_coef_multiclass: 0.9970 - loss: 0.0760
# Epoch 29: val_loss did not improve from 0.14018
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9423 - dice_class_2: 0.9518 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8911 - iou_class_2: 0.9083 - iou_coef_multiclass: 0.9970 - loss: 0.0760 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9053 - val_dice_class_2: 0.8855 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8277 - val_iou_class_2: 0.7958 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1408 - learning_rate: 1.3500e-05
# Epoch 30/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9400 - dice_class_2: 0.9497 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9989 - iou_class_1: 0.8871 - iou_class_2: 0.9046 - iou_coef_multiclass: 0.9970 - loss: 0.0787
# Epoch 30: val_loss did not improve from 0.14018
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 4.050000006827758e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9401 - dice_class_2: 0.9497 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9989 - iou_class_1: 0.8871 - iou_class_2: 0.9045 - iou_coef_multiclass: 0.9970 - loss: 0.0787 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9039 - val_dice_class_2: 0.8796 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8258 - val_iou_class_2: 0.7864 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1440 - learning_rate: 1.3500e-05
# Epoch 31/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9399 - dice_class_2: 0.9484 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8868 - iou_class_2: 0.9023 - iou_coef_multiclass: 0.9969 - loss: 0.0794
# Epoch 31: val_loss improved from 0.14018 to 0.13885, saving model to results/Deeper_Focal_EIoU_MC_ECA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 150ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9399 - dice_class_2: 0.9485 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8869 - iou_class_2: 0.9023 - iou_coef_multiclass: 0.9969 - loss: 0.0794 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9055 - val_dice_class_2: 0.8882 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8279 - val_iou_class_2: 0.7996 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1388 - learning_rate: 4.0500e-06
# Epoch 32/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9434 - dice_class_2: 0.9527 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8931 - iou_class_2: 0.9099 - iou_coef_multiclass: 0.9970 - loss: 0.0744
# Epoch 32: val_loss did not improve from 0.13885
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9434 - dice_class_2: 0.9527 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8931 - iou_class_2: 0.9099 - iou_coef_multiclass: 0.9970 - loss: 0.0744 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9024 - val_dice_class_2: 0.8831 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8231 - val_iou_class_2: 0.7919 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1449 - learning_rate: 4.0500e-06
# Epoch 33/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9418 - dice_class_2: 0.9511 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8902 - iou_class_2: 0.9071 - iou_coef_multiclass: 0.9970 - loss: 0.0768
# Epoch 33: val_loss did not improve from 0.13885
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9418 - dice_class_2: 0.9511 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8902 - iou_class_2: 0.9071 - iou_coef_multiclass: 0.9970 - loss: 0.0768 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9045 - val_dice_class_2: 0.8840 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8267 - val_iou_class_2: 0.7939 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1425 - learning_rate: 4.0500e-06
# Epoch 34/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9425 - dice_class_2: 0.9500 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8916 - iou_class_2: 0.9052 - iou_coef_multiclass: 0.9970 - loss: 0.0766
# Epoch 34: val_loss did not improve from 0.13885
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.2149999747634864e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9425 - dice_class_2: 0.9500 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8916 - iou_class_2: 0.9052 - iou_coef_multiclass: 0.9970 - loss: 0.0766 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9022 - val_dice_class_2: 0.8810 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8227 - val_iou_class_2: 0.7883 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1449 - learning_rate: 4.0500e-06
# Epoch 35/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9419 - dice_class_2: 0.9490 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8905 - iou_class_2: 0.9033 - iou_coef_multiclass: 0.9970 - loss: 0.0778
# Epoch 35: val_loss did not improve from 0.13885
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9419 - dice_class_2: 0.9490 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8905 - iou_class_2: 0.9033 - iou_coef_multiclass: 0.9970 - loss: 0.0778 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9020 - val_dice_class_2: 0.8802 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8227 - val_iou_class_2: 0.7881 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1450 - learning_rate: 1.2150e-06
# Epoch 36/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9400 - dice_class_2: 0.9513 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8871 - iou_class_2: 0.9075 - iou_coef_multiclass: 0.9970 - loss: 0.0773
# Epoch 36: val_loss did not improve from 0.13885
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9400 - dice_class_2: 0.9513 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8871 - iou_class_2: 0.9075 - iou_coef_multiclass: 0.9970 - loss: 0.0773 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9058 - val_dice_class_2: 0.8853 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8284 - val_iou_class_2: 0.7958 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1400 - learning_rate: 1.2150e-06
# Epoch 37/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9412 - dice_class_2: 0.9490 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8891 - iou_class_2: 0.9033 - iou_coef_multiclass: 0.9970 - loss: 0.0792
# Epoch 37: val_loss did not improve from 0.13885
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 3.644999992502562e-07.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9412 - dice_class_2: 0.9490 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8891 - iou_class_2: 0.9033 - iou_coef_multiclass: 0.9970 - loss: 0.0791 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9025 - val_dice_class_2: 0.8827 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8235 - val_iou_class_2: 0.7913 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1443 - learning_rate: 1.2150e-06
# Epoch 38/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9424 - dice_class_2: 0.9513 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8913 - iou_class_2: 0.9074 - iou_coef_multiclass: 0.9970 - loss: 0.0758
# Epoch 38: val_loss did not improve from 0.13885
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9424 - dice_class_2: 0.9513 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8913 - iou_class_2: 0.9074 - iou_coef_multiclass: 0.9970 - loss: 0.0758 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9066 - val_dice_class_2: 0.8882 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8298 - val_iou_class_2: 0.8002 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1389 - learning_rate: 3.6450e-07
# Epoch 39/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9424 - dice_class_2: 0.9524 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8913 - iou_class_2: 0.9096 - iou_coef_multiclass: 0.9970 - loss: 0.0758
# Epoch 39: val_loss did not improve from 0.13885
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9424 - dice_class_2: 0.9524 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8913 - iou_class_2: 0.9095 - iou_coef_multiclass: 0.9970 - loss: 0.0758 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9008 - val_dice_class_2: 0.8798 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8205 - val_iou_class_2: 0.7869 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1473 - learning_rate: 3.6450e-07
# Epoch 40/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9429 - dice_class_2: 0.9493 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8921 - iou_class_2: 0.9039 - iou_coef_multiclass: 0.9971 - loss: 0.0770
# Epoch 40: val_loss did not improve from 0.13885
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1.0935000318568199e-07.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9429 - dice_class_2: 0.9493 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8921 - iou_class_2: 0.9039 - iou_coef_multiclass: 0.9971 - loss: 0.0770 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9058 - val_dice_class_2: 0.8879 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8283 - val_iou_class_2: 0.7998 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1389 - learning_rate: 3.6450e-07
# Epoch 41/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9419 - dice_class_2: 0.9501 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8904 - iou_class_2: 0.9054 - iou_coef_multiclass: 0.9970 - loss: 0.0772
# Epoch 41: val_loss did not improve from 0.13885
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9419 - dice_class_2: 0.9501 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8904 - iou_class_2: 0.9054 - iou_coef_multiclass: 0.9970 - loss: 0.0772 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9039 - val_dice_class_2: 0.8828 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8256 - val_iou_class_2: 0.7910 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1441 - learning_rate: 1.0935e-07
# Epoch 42/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9412 - dice_class_2: 0.9490 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8892 - iou_class_2: 0.9031 - iou_coef_multiclass: 0.9970 - loss: 0.0790
# Epoch 42: val_loss did not improve from 0.13885
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9412 - dice_class_2: 0.9490 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8892 - iou_class_2: 0.9032 - iou_coef_multiclass: 0.9970 - loss: 0.0790 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9035 - val_dice_class_2: 0.8801 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8246 - val_iou_class_2: 0.7868 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1449 - learning_rate: 1.0935e-07
# Epoch 43/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9413 - dice_class_2: 0.9506 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8893 - iou_class_2: 0.9062 - iou_coef_multiclass: 0.9970 - loss: 0.0774
# Epoch 43: val_loss did not improve from 0.13885
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1e-07.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9413 - dice_class_2: 0.9506 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8893 - iou_class_2: 0.9062 - iou_coef_multiclass: 0.9970 - loss: 0.0774 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9059 - val_dice_class_2: 0.8877 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8287 - val_iou_class_2: 0.7993 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1402 - learning_rate: 1.0935e-07
# Epoch 44/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9424 - dice_class_2: 0.9512 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8913 - iou_class_2: 0.9074 - iou_coef_multiclass: 0.9970 - loss: 0.0765
# Epoch 44: val_loss did not improve from 0.13885
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9424 - dice_class_2: 0.9512 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8912 - iou_class_2: 0.9073 - iou_coef_multiclass: 0.9970 - loss: 0.0765 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9027 - val_dice_class_2: 0.8832 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8239 - val_iou_class_2: 0.7921 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1427 - learning_rate: 1.0000e-07
# Epoch 45/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9435 - dice_class_2: 0.9526 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8933 - iou_class_2: 0.9098 - iou_coef_multiclass: 0.9971 - loss: 0.0745
# Epoch 45: val_loss did not improve from 0.13885
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 127ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9435 - dice_class_2: 0.9526 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8933 - iou_class_2: 0.9097 - iou_coef_multiclass: 0.9971 - loss: 0.0745 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9046 - val_dice_class_2: 0.8843 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8266 - val_iou_class_2: 0.7936 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1418 - learning_rate: 1.0000e-07
# Epoch 46/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9416 - dice_class_2: 0.9507 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8899 - iou_class_2: 0.9064 - iou_coef_multiclass: 0.9970 - loss: 0.0770
# Epoch 46: val_loss did not improve from 0.13885
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9416 - dice_class_2: 0.9507 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8899 - iou_class_2: 0.9064 - iou_coef_multiclass: 0.9970 - loss: 0.0770 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9052 - val_dice_class_2: 0.8838 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8276 - val_iou_class_2: 0.7933 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1429 - learning_rate: 1.0000e-07
# Epoch 47/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9400 - dice_class_2: 0.9490 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8869 - iou_class_2: 0.9034 - iou_coef_multiclass: 0.9969 - loss: 0.0791
# Epoch 47: val_loss did not improve from 0.13885
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9400 - dice_class_2: 0.9491 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8870 - iou_class_2: 0.9034 - iou_coef_multiclass: 0.9969 - loss: 0.0791 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9028 - val_dice_class_2: 0.8820 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8239 - val_iou_class_2: 0.7902 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1439 - learning_rate: 1.0000e-07
# Epoch 48/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9416 - dice_class_2: 0.9489 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8898 - iou_class_2: 0.9030 - iou_coef_multiclass: 0.9970 - loss: 0.0777
# Epoch 48: val_loss did not improve from 0.13885
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9416 - dice_class_2: 0.9489 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8898 - iou_class_2: 0.9030 - iou_coef_multiclass: 0.9970 - loss: 0.0777 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9028 - val_dice_class_2: 0.8852 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8238 - val_iou_class_2: 0.7953 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1428 - learning_rate: 1.0000e-07
# Epoch 49/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9409 - dice_class_2: 0.9512 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9989 - iou_class_1: 0.8886 - iou_class_2: 0.9072 - iou_coef_multiclass: 0.9970 - loss: 0.0772
# Epoch 49: val_loss did not improve from 0.13885
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9409 - dice_class_2: 0.9512 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9989 - iou_class_1: 0.8886 - iou_class_2: 0.9072 - iou_coef_multiclass: 0.9970 - loss: 0.0772 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9043 - val_dice_class_2: 0.8839 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8264 - val_iou_class_2: 0.7932 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1422 - learning_rate: 1.0000e-07
# Epoch 50/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9405 - dice_class_2: 0.9483 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8880 - iou_class_2: 0.9022 - iou_coef_multiclass: 0.9970 - loss: 0.0790
# Epoch 50: val_loss did not improve from 0.13885
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 128ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9405 - dice_class_2: 0.9483 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8880 - iou_class_2: 0.9022 - iou_coef_multiclass: 0.9970 - loss: 0.0790 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9028 - val_dice_class_2: 0.8826 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8238 - val_iou_class_2: 0.7915 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1438 - learning_rate: 1.0000e-07
# Restoring model weights from the end of the best epoch: 31.
# ✓ Training completed
#
# ================================================================================
# EVALUATION: Deeper+Focal+EIoU+MC+ECA
# ================================================================================
#
# Precision, Recall, F1 Score per class:
#   Background: Precision=0.9994, Recall=0.9993, F1=0.9994
#   Disc: Precision=0.8998, Recall=0.9207, F1=0.9101
#   Cup: Precision=0.9188, Recall=0.8676, F1=0.8924
#
# Macro-averaged metrics:
#   Precision: 0.9393
#   Recall: 0.9292
#   F1 Score: 0.9340
#   Background: Dice=0.9994, IoU=0.9987
#   Disc: Dice=0.9101, IoU=0.8351
#   Cup: Dice=0.8924, IoU=0.8057
#
# MC Dropout Evaluation:
#
# Running MC Dropout with 10 stochastic forward passes...
#   Completed: 5/10 forward passes
#   Completed: 10/10 forward passes
# ✓ MC Dropout completed
#   Background uncertainty: 0.0003
#   Disc uncertainty: 0.0004
#   Cup uncertainty: 0.0002
#
# ================================================================================
# GENERATING VISUALIZATIONS
# ================================================================================
# ✓ Training curves saved: results/Deeper+Focal+EIoU+MC+ECA_training_curves.png
# ✓ Confusion matrices saved: results/Deeper+Focal+EIoU+MC+ECA_confusion_matrices.png
# Confusion Matrix:
# [[25767811    17179        0]
#  [   16228   290071     8772]
#  [      30    15114    99195]]
#
# Normalized Confusion Matrix:
# [[0.999 0.001 0.   ]
#  [0.052 0.921 0.028]
#  [0.    0.132 0.868]]
#
# ====================================================================================================
#                                 ✓ TRAINING AND EVALUATION COMPLETED!
# ====================================================================================================
#
# Model: Deeper + Focal-EIoU + MC Dropout + ECA Attention
# Attention: ECA on skip connections (4 blocks)
# Parameters: 37,131,417
# Results saved in: results/
#
# ====================================================================================================
