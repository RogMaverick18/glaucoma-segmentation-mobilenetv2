# %%
"""
COMBINED ADVANCED MOBILENET-UNET WITH CBAM ATTENTION
=====================================================
This combines:
1. Deeper decoder architecture with enhanced blocks
2. Focal-EIoU loss
3. MC Dropout for uncertainty estimation
4. CBAM (Convolutional Block Attention Module)
   - Applied to: skip connections, bridge, decoder blocks, and final layer
   - Same placement strategy as cbam.py
"""

import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, backend as K
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import albumentations as A
import warnings
import gc  # For memory management in MC Dropout
warnings.filterwarnings('ignore')

# Set plot style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# ============================================================================
# [Previous functions remain the same: GPU config, data loading, augmentation]
# ============================================================================

def configure_gpu():
    """Configure GPU settings for optimal performance"""
    print("Configuring GPU settings...")
    physical_devices = tf.config.list_physical_devices('GPU')
    if physical_devices:
        try:
            for gpu in physical_devices:
                tf.config.experimental.set_memory_growth(gpu, True)
            tf.config.set_visible_devices(physical_devices[0], 'GPU')
            print(f"✓ GPU found: {physical_devices}")
            print("  GPU device name:", tf.test.gpu_device_name())
            return True
        except RuntimeError as e:
            print(f"✗ GPU error: {e}")
            return False
    else:
        print("✗ No GPU found, using CPU")
        return False

def load_images_masks(images_folder, masks_folder, img_size=(256,256)):
    """Load images and masks from folders"""
    images, masks = [], []
    image_files = sorted(os.listdir(images_folder))
    mask_files = sorted(os.listdir(masks_folder))
    mask_dict = {os.path.splitext(f)[0]: f for f in mask_files}
    
    for img_file in image_files:
        base = os.path.splitext(img_file)[0]
        if base in mask_dict:
            img = cv2.imread(os.path.join(images_folder, img_file))
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, img_size) / 255.0
            
            mask = cv2.imread(os.path.join(masks_folder, mask_dict[base]), cv2.IMREAD_GRAYSCALE)
            mask = cv2.resize(mask, img_size)
            unique_vals = np.unique(mask)
            if len(unique_vals) > 3 or np.max(unique_vals) > 2:
                mask = np.clip(mask // 85, 0, 2).astype(np.uint8)
            
            images.append(img)
            masks.append(mask)
    
    return np.array(images, dtype=np.float32), np.array(masks, dtype=np.uint8)

def load_all_data(root_dir):
    """Load all data from existing splits and merge"""
    all_images, all_masks = [], []
    for split in ["train", "val", "test"]:
        print(f"Loading {split} data...")
        imgs, msks = load_images_masks(
            os.path.join(root_dir, split, "Images"),
            os.path.join(root_dir, split, "Masks")
        )
        all_images.append(imgs)
        all_masks.append(msks)
        print(f"  {split}: {imgs.shape[0]} samples")
    
    return np.concatenate(all_images), np.concatenate(all_masks)

def create_new_split(all_images, all_masks):
    """Create new split: 600 train, 200 val, 400 test"""
    X_temp, X_test, y_temp, y_test = train_test_split(
        all_images, all_masks, test_size=400, random_state=42
    )
    X_train, X_val, y_train, y_val = train_test_split(
        X_temp, y_temp, test_size=200, random_state=42
    )
    print(f"Split - Train: {X_train.shape[0]}, Val: {X_val.shape[0]}, Test: {X_test.shape[0]}")
    return (X_train, y_train), (X_val, y_val), (X_test, y_test)

def setup_augmentations():
    return A.Compose([
        A.RandomBrightnessContrast(brightness_limit=0.15, contrast_limit=0.15, p=0.7),
        A.HueSaturationValue(hue_shift_limit=10, sat_shift_limit=15, val_shift_limit=10, p=0.5),
        A.GaussianBlur(blur_limit=3, p=0.3),
        A.RandomGamma(gamma_limit=(80, 120), p=0.3),
    ])

def data_generator(images, masks, batch_size, augment=None):
    idxs = np.arange(len(images))
    while True:
        np.random.shuffle(idxs)
        for i in range(0, len(images), batch_size):
            batch_idxs = idxs[i:i+batch_size]
            batch_x, batch_y = [], []
            
            for idx in batch_idxs:
                img, mask = images[idx], masks[idx]
                
                if augment:
                    aug = augment(image=img, mask=mask)
                    img_aug, mask_aug = aug['image'], aug['mask']
                else:
                    img_aug, mask_aug = img, mask
                
                mask_cat = to_categorical(mask_aug, num_classes=3)
                batch_x.append(img_aug)
                batch_y.append(mask_cat)
            
            batch_x = np.stack(batch_x).astype(np.float32)
            batch_y = np.stack(batch_y).astype(np.float32)
            
            yield batch_x, batch_y

# ============================================================================
# CBAM ATTENTION MODULES (from cbam.py)
# ============================================================================

def channel_attention(input_feature, ratio=8, name=""):
    """Channel Attention Module (CAM)"""
    channel = input_feature.shape[-1]
    
    # Shared MLP layers
    shared_layer_one = layers.Dense(channel//ratio, activation='relu', name=f'channel_attention_dense1_{name}')
    shared_layer_two = layers.Dense(channel, activation='sigmoid', name=f'channel_attention_dense2_{name}')
    
    # Global Average Pooling
    avg_pool = layers.GlobalAveragePooling2D()(input_feature)
    avg_pool = layers.Reshape((1, 1, channel))(avg_pool)
    avg_pool = shared_layer_one(avg_pool)
    avg_pool = shared_layer_two(avg_pool)
    
    # Global Max Pooling
    max_pool = layers.GlobalMaxPooling2D()(input_feature)
    max_pool = layers.Reshape((1, 1, channel))(max_pool)
    max_pool = shared_layer_one(max_pool)
    max_pool = shared_layer_two(max_pool)
    
    # Combine and apply
    cbam_feature = layers.Add()([avg_pool, max_pool])
    cbam_feature = layers.Multiply()([input_feature, cbam_feature])
    
    return cbam_feature

def spatial_attention(input_feature, name=""):
    """Spatial Attention Module (SAM)"""
    kernel_size = 7
    
    # Channel-wise pooling
    avg_pool = layers.Lambda(lambda x: tf.reduce_mean(x, axis=3, keepdims=True))(input_feature)
    max_pool = layers.Lambda(lambda x: tf.reduce_max(x, axis=3, keepdims=True))(input_feature)
    concat = layers.Concatenate(axis=3)([avg_pool, max_pool])
    
    # Spatial attention map
    cbam_feature = layers.Conv2D(filters=1, kernel_size=kernel_size, strides=1, 
                                padding='same', activation='sigmoid', 
                                name=f'spatial_attention_conv_{name}')(concat)
    cbam_feature = layers.Multiply()([input_feature, cbam_feature])
    
    return cbam_feature

def cbam_block(cbam_feature, ratio=8, name=""):
    """CBAM: Convolutional Block Attention Module (Channel + Spatial)"""
    # Apply channel attention first
    cbam_feature = channel_attention(cbam_feature, ratio, name=f"{name}_channel")
    # Then apply spatial attention
    cbam_feature = spatial_attention(cbam_feature, name=f"{name}_spatial")
    return cbam_feature

# ============================================================================
# LOSS FUNCTIONS (Focal + EIoU)
# ============================================================================

def focal_loss(y_true, y_pred, gamma=2.0, alpha=None, epsilon=1e-7):
    if alpha is None:
        alpha = [0.25, 1.0, 1.0]
    
    y_pred = K.clip(y_pred, epsilon, 1.0 - epsilon)
    focal_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        pt = y_pred_c
        focal_weight = K.pow(1.0 - pt, gamma)
        cross_entropy = -K.log(pt)
        focal_loss_c = alpha[c] * focal_weight * cross_entropy * y_true_c
        focal_loss_value += K.mean(focal_loss_c)
    
    return focal_loss_value

def enhanced_iou_loss(y_true, y_pred, smooth=1e-7):
    eiou_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        
        intersection = K.sum(y_true_c * y_pred_c, axis=[1, 2])
        union = K.sum(y_true_c, axis=[1, 2]) + K.sum(y_pred_c, axis=[1, 2]) - intersection
        iou = (intersection + smooth) / (union + smooth)
        
        height = K.cast(K.shape(y_true_c)[1], 'float32')
        width = K.cast(K.shape(y_true_c)[2], 'float32')
        
        y_coords = K.arange(0, height)
        x_coords = K.arange(0, width)
        y_grid = K.tile(K.reshape(y_coords, (-1, 1)), (1, K.cast(width, 'int32')))
        x_grid = K.tile(K.reshape(x_coords, (1, -1)), (K.cast(height, 'int32'), 1))
        y_grid = K.cast(y_grid, 'float32')
        x_grid = K.cast(x_grid, 'float32')
        
        true_mass = K.sum(y_true_c, axis=[1, 2]) + smooth
        true_center_y = K.sum(y_true_c * y_grid, axis=[1, 2]) / true_mass
        true_center_x = K.sum(y_true_c * x_grid, axis=[1, 2]) / true_mass
        
        pred_mass = K.sum(y_pred_c, axis=[1, 2]) + smooth
        pred_center_y = K.sum(y_pred_c * y_grid, axis=[1, 2]) / pred_mass
        pred_center_x = K.sum(y_pred_c * x_grid, axis=[1, 2]) / pred_mass
        
        center_distance = K.square(true_center_y - pred_center_y) + K.square(true_center_x - pred_center_x)
        diagonal = K.square(height) + K.square(width)
        center_penalty = center_distance / (diagonal + smooth)
        
        true_width = K.sqrt(K.sum(K.sum(y_true_c, axis=1), axis=1) + smooth)
        true_height = K.sqrt(K.sum(K.sum(y_true_c, axis=2), axis=1) + smooth)
        pred_width = K.sqrt(K.sum(K.sum(y_pred_c, axis=1), axis=1) + smooth)
        pred_height = K.sqrt(K.sum(K.sum(y_pred_c, axis=2), axis=1) + smooth)
        
        width_diff = K.square(pred_width - true_width)
        height_diff = K.square(pred_height - true_height)
        aspect_penalty = width_diff / (K.square(width) + smooth) + height_diff / (K.square(height) + smooth)
        
        eiou_c = 1.0 - iou + center_penalty + aspect_penalty
        eiou_loss_value += K.mean(eiou_c)
    
    return eiou_loss_value / 3.0

def focal_eiou_combined_loss(y_true, y_pred, focal_weight=1.0, eiou_weight=1.0, gamma=2.0, alpha=None):
    fl = focal_loss(y_true, y_pred, gamma=gamma, alpha=alpha)
    eiou = enhanced_iou_loss(y_true, y_pred)
    return focal_weight * fl + eiou_weight * eiou

# ============================================================================
# ENHANCED DECODER BLOCK WITH CBAM (Combining deeper architecture + CBAM)
# ============================================================================

def enhanced_decoder_block_with_cbam(x, skip_connection, filters, block_name, dropout_rate=0.3):
    """
    Enhanced decoder block with residual connections, dropout, and CBAM attention
    
    Architecture:
    - Upsample
    - Concatenate with skip
    - Conv + BN + Dropout (MC Dropout compatible)
    - Conv + BN
    - Conv + BN (for residual path)
    - Residual Add
    - Conv + BN
    - CBAM Attention (Channel + Spatial)
    """
    x = layers.UpSampling2D((2, 2), name=f'{block_name}_upsample')(x)
    
    if skip_connection.shape[-1] != x.shape[-1]:
        skip_connection = layers.Conv2D(x.shape[-1], (1, 1), activation='relu', 
                                      padding='same', name=f'{block_name}_skip_align')(skip_connection)
        skip_connection = layers.BatchNormalization(name=f'{block_name}_skip_bn')(skip_connection)
    
    x = layers.Concatenate(name=f'{block_name}_concat')([x, skip_connection])
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv1')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn1')(x)
    # MC Dropout after first conv
    x = layers.Dropout(dropout_rate, name=f'{block_name}_dropout')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv2')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn2')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv3')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn3')(x)
    
    residual = x
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv4')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn4')(x)
    
    x = layers.Add(name=f'{block_name}_residual')([x, residual])
    x = layers.Conv2D(filters, (1, 1), activation='relu', padding='same', name=f'{block_name}_conv_final')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn_final')(x)
    
    # Apply CBAM attention at the end of the block
    x = cbam_block(x, ratio=8, name=block_name)
    
    return x

# ============================================================================
# COMBINED MODEL: Deeper + Focal-EIoU + MC Dropout + CBAM
# ============================================================================

def build_combined_unet_with_cbam(input_shape=(256, 256, 3), num_classes=3, 
                                   use_deeper=False, dropout_rate=0.3):
    """
    Combined MobileNet-UNet with:
    1. Deeper decoder architecture (enhanced blocks with residual connections)
    2. Focal-EIoU loss (applied during training)
    3. MC Dropout (for uncertainty estimation)
    4. CBAM attention (applied to skip connections, bridge, decoder blocks, and final layer)
    
    CBAM Placement (matching cbam.py):
    - Skip connections (4 locations)
    - Bridge (1 location)
    - Decoder blocks (4 locations)
    - Final layer (1 location)
    Total: 10 CBAM blocks
    """
    
    print(f"\nBuilding Combined UNet with CBAM...")
    print(f"  Deeper Architecture: {use_deeper}")
    print(f"  MC Dropout Rate: {dropout_rate}")
    print(f"  CBAM Attention: Enabled (10 blocks)")
    
    inputs = layers.Input(input_shape, dtype='float32')
    backbone = MobileNetV2(input_tensor=inputs, weights='imagenet', include_top=False)
    
    skip_1 = backbone.get_layer('block_1_expand_relu').output  # 128x128
    skip_2 = backbone.get_layer('block_3_expand_relu').output  # 64x64
    skip_3 = backbone.get_layer('block_6_expand_relu').output  # 32x32
    skip_4 = backbone.get_layer('block_13_expand_relu').output # 16x16
    bridge = backbone.output  # 8x8
    
    # Apply CBAM to skip connections (matching cbam.py)
    print("  Applying CBAM to skip connections...")
    skip_1_att = cbam_block(skip_1, ratio=8, name="skip1")
    skip_2_att = cbam_block(skip_2, ratio=8, name="skip2")
    skip_3_att = cbam_block(skip_3, ratio=8, name="skip3")
    skip_4_att = cbam_block(skip_4, ratio=8, name="skip4")
    
    # Deeper bridge (if enabled)
    if use_deeper:
        bridge = layers.Conv2D(1024, (3, 3), activation='relu', padding='same')(bridge)
        bridge = layers.BatchNormalization()(bridge)
    
    # Apply dropout to bridge
    if dropout_rate > 0:
        bridge = layers.Dropout(dropout_rate, name='bridge_dropout')(bridge)
    
    # Apply CBAM to bridge (matching cbam.py)
    bridge_att = cbam_block(bridge, ratio=8, name="bridge")
    
    if use_deeper:
        print("  Building deeper decoder with CBAM...")
        # Decoder with enhanced blocks + CBAM
        # decoder_1 and decoder_2: full dropout_rate (0.3)
        # decoder_3: 0.7x (0.21)
        # decoder_4: 0.5x (0.15)
        x = enhanced_decoder_block_with_cbam(bridge_att, skip_4_att, 512, 'decoder_1', dropout_rate)
        x = enhanced_decoder_block_with_cbam(x, skip_3_att, 256, 'decoder_2', dropout_rate)
        x = enhanced_decoder_block_with_cbam(x, skip_2_att, 128, 'decoder_3', dropout_rate * 0.7)
        x = enhanced_decoder_block_with_cbam(x, skip_1_att, 64, 'decoder_4', dropout_rate * 0.5)
    else:
        print("  Building baseline decoder with CBAM...")
        # Baseline decoder with CBAM
        x = layers.UpSampling2D((2, 2))(bridge_att)
        x = layers.Concatenate()([x, skip_4_att])
        x = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        if dropout_rate > 0:
            x = layers.Dropout(dropout_rate)(x)
        x = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = cbam_block(x, ratio=8, name="dec1")
        
        x = layers.UpSampling2D((2, 2))(x)
        x = layers.Concatenate()([x, skip_3_att])
        x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        if dropout_rate > 0:
            x = layers.Dropout(dropout_rate)(x)
        x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = cbam_block(x, ratio=8, name="dec2")
        
        x = layers.UpSampling2D((2, 2))(x)
        x = layers.Concatenate()([x, skip_2_att])
        x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        if dropout_rate > 0:
            x = layers.Dropout(dropout_rate * 0.7)(x)
        x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = cbam_block(x, ratio=8, name="dec3")
        
        x = layers.UpSampling2D((2, 2))(x)
        x = layers.Concatenate()([x, skip_1_att])
        x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        if dropout_rate > 0:
            x = layers.Dropout(dropout_rate * 0.5)(x)
        x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = cbam_block(x, ratio=8, name="dec4")
    
    # Final upsampling
    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    
    # Apply CBAM to final layer (matching cbam.py)
    x = cbam_block(x, ratio=4, name="final")
    
    outputs = layers.Conv2D(num_classes, (1, 1), activation='softmax', dtype='float32')(x)
    
    model = models.Model(inputs, outputs)
    
    # Print dropout and CBAM configuration
    if dropout_rate > 0:
        dropout_layers = [layer for layer in model.layers if isinstance(layer, layers.Dropout)]
        print(f"\n  MC Dropout Configuration:")
        print(f"    Total Dropout Layers: {len(dropout_layers)}")
        print(f"    Dropout Rates: {[f'{layer.rate:.2f}' for layer in dropout_layers]}")
    
    # Count CBAM blocks
    cbam_count = sum(1 for layer in model.layers if 'channel_attention' in layer.name or 'spatial_attention' in layer.name)
    print(f"\n  CBAM Configuration:")
    print(f"    Total CBAM Components: {cbam_count}")
    print(f"    CBAM Locations: Skip connections (4), Bridge (1), Decoder blocks (4), Final (1)")
    
    return model

# ============================================================================
# METRICS
# ============================================================================

def dice_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    return (2. * intersection + smooth) / (K.sum(y_true_class) + K.sum(y_pred_class) + smooth)

def dice_class_0(y_true, y_pred): return dice_coef_class(y_true, y_pred, 0)
def dice_class_1(y_true, y_pred): return dice_coef_class(y_true, y_pred, 1)
def dice_class_2(y_true, y_pred): return dice_coef_class(y_true, y_pred, 2)

def iou_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    union = K.sum(y_true_class) + K.sum(y_pred_class) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_class_0(y_true, y_pred): return iou_coef_class(y_true, y_pred, 0)
def iou_class_1(y_true, y_pred): return iou_coef_class(y_true, y_pred, 1)
def iou_class_2(y_true, y_pred): return iou_coef_class(y_true, y_pred, 2)

# ============================================================================
# VISUALIZATION FUNCTIONS
# ============================================================================

def plot_training_history(history, model_name, save_dir='results'):
    """Plot training history: loss and accuracy curves"""
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    
    axes[0].plot(history.history['loss'], label='Training Loss', linewidth=2)
    axes[0].plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
    axes[0].set_title(f'{model_name} - Loss Over Epochs', fontsize=14, fontweight='bold')
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('Loss', fontsize=12)
    axes[0].legend(fontsize=10)
    axes[0].grid(True, alpha=0.3)
    
    axes[1].plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
    axes[1].plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
    axes[1].set_title(f'{model_name} - Accuracy Over Epochs', fontsize=14, fontweight='bold')
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('Accuracy', fontsize=12)
    axes[1].legend(fontsize=10)
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(f"{save_dir}/{model_name}_training_curves.png", dpi=300, bbox_inches='tight')
    print(f" Training curves saved: {save_dir}/{model_name}_training_curves.png")
    plt.show()
    plt.close()

def plot_confusion_matrices(y_true, y_pred, model_name, save_dir='results'):
    """Plot confusion matrix and normalized confusion matrix"""
    y_true_labels = np.argmax(y_true, axis=-1).flatten()
    y_pred_labels = np.argmax(y_pred, axis=-1).flatten()
    
    cm = confusion_matrix(y_true_labels, y_pred_labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    class_names = ['Background', 'Disc', 'Cup']
    
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[0], cbar_kws={'label': 'Count'})
    axes[0].set_title(f'{model_name}\\nConfusion Matrix', fontsize=14, fontweight='bold')
    axes[0].set_ylabel('True Label', fontsize=12)
    axes[0].set_xlabel('Predicted Label', fontsize=12)
    
    sns.heatmap(cm_normalized, annot=True, fmt='.3f', cmap='Greens',
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[1], cbar_kws={'label': 'Proportion'})
    axes[1].set_title(f'{model_name}\\nNormalized Confusion Matrix', fontsize=14, fontweight='bold')
    axes[1].set_ylabel('True Label', fontsize=12)
    axes[1].set_xlabel('Predicted Label', fontsize=12)
    
    plt.tight_layout()
    plt.savefig(f"{save_dir}/{model_name}_confusion_matrices.png", dpi=300, bbox_inches='tight')
    print(f" Confusion matrices saved: {save_dir}/{model_name}_confusion_matrices.png")
    plt.show()
    plt.close()
    
    print(f"\\nConfusion Matrix:")
    print(cm)
    print(f"\\nNormalized Confusion Matrix:")
    print(np.round(cm_normalized, 3))
    
    return cm, cm_normalized

# ============================================================================
# MC DROPOUT PREDICTION
# ============================================================================

def mc_dropout_predict(model, X, num_samples=15, batch_size=4, verbose=True):
    """
    MC Dropout prediction using training=True flag
    
    This enables dropout layers during inference to get stochastic predictions
    for uncertainty estimation (following Gal & Ghahramani 2016)
    """
    if verbose:
        print(f"\nRunning MC Dropout with {num_samples} stochastic forward passes...")
    
    predictions = []
    
    # Process in batches to avoid memory issues
    num_batches = int(np.ceil(len(X) / batch_size))
    
    for i in range(num_samples):
        if verbose and (i + 1) % 5 == 0:
            print(f"  Completed: {i+1}/{num_samples} forward passes")
        
        batch_preds = []
        
        for batch_idx in range(num_batches):
            start_idx = batch_idx * batch_size
            end_idx = min(start_idx + batch_size, len(X))
            X_batch = X[start_idx:end_idx]
            
            # Call model with training=True to enable dropout
            pred_batch = model(X_batch, training=True)
            batch_preds.append(pred_batch.numpy())
        
        # Concatenate batch predictions
        pred = np.concatenate(batch_preds, axis=0)
        predictions.append(pred)
        
        # Clear memory periodically
        if (i + 1) % 5 == 0:
            gc.collect()
    
    # Stack predictions: shape (num_samples, batch, height, width, classes)
    all_preds = np.array(predictions)
    
    # Calculate mean and standard deviation across samples
    mean_pred = np.mean(all_preds, axis=0)
    std_pred = np.std(all_preds, axis=0)
    
    # Clear memory
    del all_preds
    gc.collect()
    
    if verbose:
        print(f"✓ MC Dropout completed")
        print(f"  Mean prediction shape: {mean_pred.shape}")
        print(f"  Std prediction shape: {std_pred.shape}")
    
    return mean_pred, std_pred

# ============================================================================
# TRAINING FUNCTION
# ============================================================================

def train_model(X_train, y_train, X_val, y_val, X_test, y_test, model_name, 
               use_focal_eiou=False, use_deeper=False, dropout_rate=0.0,
               augment=None, save_dir='results'):
    """Train combined model with CBAM"""
    print(f"\n{'='*80}")
    print(f"TRAINING: {model_name}")
    print(f"{'='*80}")
    print(f"  Focal-EIoU Loss: {'✓' if use_focal_eiou else '✗'}")
    print(f"  Deeper Decoder: {'✓' if use_deeper else '✗'}")
    print(f"  MC Dropout: {'✓ (rate=' + str(dropout_rate) + ')' if dropout_rate > 0 else '✗'}")
    print(f"  CBAM Attention: ✓ (10 blocks)")
    
    K.clear_session()
    
    # Build model with CBAM
    model = build_combined_unet_with_cbam(use_deeper=use_deeper, dropout_rate=dropout_rate)
    
    # Get parameter count
    param_count = model.count_params()
    print(f"  Total Parameters: {param_count:,}")
    
    # Choose loss
    if use_focal_eiou:
        loss_fn = focal_eiou_combined_loss
    else:
        loss_fn = "categorical_crossentropy"
    
    # Compile
    initial_lr = 5e-4 if use_deeper else 1e-3
    model.compile(
        optimizer=optimizers.Adam(learning_rate=initial_lr),
        loss=loss_fn,
        metrics=[dice_coef_multiclass, dice_class_0, dice_class_1, dice_class_2,
                "accuracy", iou_coef_multiclass, iou_class_0, iou_class_1, iou_class_2]
    )
    
    # Callbacks
    checkpoint = ModelCheckpoint(f"{save_dir}/{model_name}.keras", save_best_only=True, verbose=1, 
                                monitor='val_loss', mode='min')
    reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=3, 
                                  verbose=1, mode='min', min_lr=1e-7)
    early_stop = EarlyStopping(monitor="val_loss", patience=10, verbose=1, 
                              restore_best_weights=True, mode='min')
    
    # Training - reduce batch size for CBAM (more memory intensive)
    batch_size = 4 if use_deeper else 6  # Reduced for CBAM
    steps_train = X_train.shape[0] // batch_size
    steps_val = X_val.shape[0] // batch_size
    
    try:
        history = model.fit(
            data_generator(X_train, y_train, batch_size, augment),
            validation_data=data_generator(X_val, y_val, batch_size, None),
            steps_per_epoch=steps_train,
            validation_steps=steps_val,
            epochs=50,
            callbacks=[checkpoint, reduce_lr, early_stop],
            verbose=1
        )
    except Exception as e:
        print(f"✗ Error: {e}. Retrying with smaller batch...")
        batch_size = 2 if use_deeper else 4
        steps_train = X_train.shape[0] // batch_size
        steps_val = X_val.shape[0] // batch_size
        
        history = model.fit(
            data_generator(X_train, y_train, batch_size, augment),
            validation_data=data_generator(X_val, y_val, batch_size, None),
            steps_per_epoch=steps_train,
            validation_steps=steps_val,
            epochs=50,
            callbacks=[checkpoint, reduce_lr, early_stop],
            verbose=1
        )
    
    print(f"✓ Training completed")
    
    plot_training_history(history, model_name, save_dir)
    
    return model, history, param_count

# ============================================================================
# EVALUATION FUNCTION
# ============================================================================

def evaluate_model(model, X_test, y_test, model_name, run_mc_dropout=False, save_dir='results'):
    """Evaluate model"""
    print(f"\n{'='*80}")
    print(f"EVALUATION: {model_name}")
    print(f"{'='*80}")
    
    y_test_cat = np.array([to_categorical(mask, num_classes=3) for mask in y_test])
    
    # Standard evaluation
    test_metrics = model.evaluate(X_test, y_test_cat, verbose=0, batch_size=4)
    y_pred = model.predict(X_test, verbose=0, batch_size=4)
    
    plot_confusion_matrices(y_test_cat, y_pred, model_name, save_dir)
    
    # Calculate precision, recall, F1 score
    y_true_labels = np.argmax(y_test_cat, axis=-1).flatten()
    y_pred_labels = np.argmax(y_pred, axis=-1).flatten()
    
    precision = precision_score(y_true_labels, y_pred_labels, average=None, zero_division=0)
    recall = recall_score(y_true_labels, y_pred_labels, average=None, zero_division=0)
    f1 = f1_score(y_true_labels, y_pred_labels, average=None, zero_division=0)
    
    print(f"\nPrecision, Recall, F1 Score per class:")
    class_names = ["Background", "Disc", "Cup"]
    for idx, cname in enumerate(class_names):
        print(f"  {cname}: Precision={precision[idx]:.4f}, Recall={recall[idx]:.4f}, F1={f1[idx]:.4f}")
    
    print(f"\nMacro-averaged metrics:")
    print(f"  Precision: {np.mean(precision):.4f}")
    print(f"  Recall: {np.mean(recall):.4f}")
    print(f"  F1 Score: {np.mean(f1):.4f}")
    
    # Per-class metrics
    class_names = ["Background", "Disc", "Cup"]
    results = {'standard': {}}
    
    for cidx, cname in enumerate(class_names):
        y_true_c = (np.argmax(y_test_cat, axis=-1) == cidx).astype(np.float32)
        y_pred_c = (np.argmax(y_pred, axis=-1) == cidx).astype(np.float32)
        
        intersection = np.sum(y_true_c * y_pred_c)
        dice = (2. * intersection + 1e-7) / (np.sum(y_true_c) + np.sum(y_pred_c) + 1e-7)
        union = np.sum(y_true_c) + np.sum(y_pred_c) - intersection
        iou = (intersection + 1e-7) / (union + 1e-7)
        
        results['standard'][cname] = {'dice': dice, 'iou': iou}
        print(f"  {cname}: Dice={dice:.4f}, IoU={iou:.4f}")
    
    # MC Dropout
    if run_mc_dropout:
        print("\nMC Dropout Evaluation:")
        mean_pred, std_pred = mc_dropout_predict(model, X_test[:100], num_samples=10, verbose=True)
        results['mc_dropout'] = {}
        for cidx, cname in enumerate(class_names):
            mean_std = np.mean(std_pred[:, :, :, cidx])
            results['mc_dropout'][cname] = {'mean_uncertainty': mean_std}
            print(f"  {cname} uncertainty: {mean_std:.4f}")
    
    return results

# ============================================================================
# MAIN EXECUTION
# ============================================================================

if __name__ == "__main__":
    # Setup
    gpu_available = configure_gpu()
    root_dir = "/kaggle/input/refuge/REFUGE/"
    train_aug = setup_augmentations()
    save_dir = "results"
    os.makedirs(save_dir, exist_ok=True)
    
    print(f"\n{'='*100}")
    print(f"{'COMBINED EXPERIMENT: DEEPER + FOCAL-EIOU + MC DROPOUT + CBAM':^100s}")
    print(f"{'='*100}")
    
    # Load data
    all_images, all_masks = load_all_data(root_dir)
    (X_train, y_train), (X_val, y_val), (X_test, y_test) = create_new_split(all_images, all_masks)
    
    # Storage
    all_results = {}
    all_params = {}
    
    # ========================================================================
    # EXPERIMENT: FULL COMBINATION + CBAM
    # ========================================================================
    print(f"\n{'='*80}")
    print("EXPERIMENT: FULL (Deeper + Focal-EIoU + MC Dropout + CBAM)")
    print(f"{'='*80}")
    
    model, history, params = train_model(
        X_train, y_train, X_val, y_val, X_test, y_test,
        "FULL_with_CBAM",
        use_focal_eiou=True, use_deeper=True, dropout_rate=0.3,
        augment=train_aug, save_dir=save_dir
    )
    
    all_results['FULL + CBAM'] = evaluate_model(model, X_test, y_test, "Full with CBAM", run_mc_dropout=True, save_dir=save_dir)
    all_params['FULL + CBAM'] = params
    
    # ========================================================================
    # FINAL SUMMARY
    # ========================================================================
    print(f"\n{'='*100}")
    print(f"{'✓ EXPERIMENT COMPLETED!':^100s}")
    print(f"{'='*100}")
    
    print("\nFinal Results:")
    for model_name, results in all_results.items():
        disc_dice = results['standard']['Disc']['dice']
        cup_dice = results['standard']['Cup']['dice']
        print(f"\n{model_name}:")
        print(f"  Parameters: {all_params[model_name]:,}")
        print(f"  Disc Dice: {disc_dice:.4f}")
        print(f"  Cup Dice: {cup_dice:.4f}")
        print(f"  Overall: {(disc_dice + cup_dice)/2:.4f}")
    
    print(f"\n{'='*100}\n")
# Out:
# Configuring GPU settings...
# ✓ GPU found: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
#   GPU device name: /device:GPU:0
#
# ====================================================================================================
#                     COMBINED EXPERIMENT: DEEPER + FOCAL-EIOU + MC DROPOUT + CBAM
# ====================================================================================================
# Loading train data...
# I0000 00:00:1763373099.379770      48 gpu_device.cc:2022] Created device /device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
#   train: 400 samples
# Loading val data...
#   val: 400 samples
# Loading test data...
#   test: 400 samples
# Split - Train: 600, Val: 200, Test: 400
#
# ================================================================================
# EXPERIMENT: FULL (Deeper + Focal-EIoU + MC Dropout + CBAM)
# ================================================================================
#
# ================================================================================
# TRAINING: FULL_with_CBAM
# ================================================================================
#   Focal-EIoU Loss: ✓
#   Deeper Decoder: ✓
#   MC Dropout: ✓ (rate=0.3)
#   CBAM Attention: ✓ (10 blocks)
#
# Building Combined UNet with CBAM...
#   Deeper Architecture: True
#   MC Dropout Rate: 0.3
#   CBAM Attention: Enabled (10 blocks)
#   Applying CBAM to skip connections...
#   Building deeper decoder with CBAM...
#
#   MC Dropout Configuration:
#     Total Dropout Layers: 5
#     Dropout Rates: ['0.30', '0.30', '0.30', '0.21', '0.15']
#
#   CBAM Configuration:
#     Total CBAM Components: 30
#     CBAM Locations: Skip connections (4), Bridge (1), Decoder blocks (4), Final (1)
#   Total Parameters: 37,585,135
# Epoch 1/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.6935 - dice_class_0: 0.7991 - dice_class_1: 0.0098 - dice_class_2: 0.0151 - dice_coef_multiclass: 0.5044 - iou_class_0: 0.6936 - iou_class_1: 0.0050 - iou_class_2: 0.0083 - iou_coef_multiclass: 0.3491 - loss: 1.2182
# Epoch 1: val_loss improved from inf to 0.98677, saving model to results/FULL_with_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 132s 224ms/step - accuracy: 0.6945 - dice_class_0: 0.7998 - dice_class_1: 0.0098 - dice_class_2: 0.0155 - dice_coef_multiclass: 0.5053 - iou_class_0: 0.6945 - iou_class_1: 0.0050 - iou_class_2: 0.0085 - iou_coef_multiclass: 0.3500 - loss: 1.2170 - val_accuracy: 0.9262 - val_dice_class_0: 0.9622 - val_dice_class_1: 3.2286e-11 - val_dice_class_2: 0.0085 - val_dice_coef_multiclass: 0.6710 - val_iou_class_0: 0.9272 - val_iou_class_1: 3.2286e-11 - val_iou_class_2: 0.0043 - val_iou_coef_multiclass: 0.5049 - val_loss: 0.9868 - learning_rate: 5.0000e-04
# Epoch 2/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9740 - dice_class_0: 0.9908 - dice_class_1: 0.0376 - dice_class_2: 0.2967 - dice_coef_multiclass: 0.8787 - iou_class_0: 0.9819 - iou_class_1: 0.0238 - iou_class_2: 0.1836 - iou_coef_multiclass: 0.7853 - loss: 0.7229
# Epoch 2: val_loss improved from 0.98677 to 0.80581, saving model to results/FULL_with_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 160ms/step - accuracy: 0.9740 - dice_class_0: 0.9908 - dice_class_1: 0.0386 - dice_class_2: 0.2973 - dice_coef_multiclass: 0.8789 - iou_class_0: 0.9818 - iou_class_1: 0.0245 - iou_class_2: 0.1842 - iou_coef_multiclass: 0.7856 - loss: 0.7224 - val_accuracy: 0.9836 - val_dice_class_0: 0.9918 - val_dice_class_1: 1.4305e-04 - val_dice_class_2: 1.3730e-04 - val_dice_coef_multiclass: 0.9795 - val_iou_class_0: 0.9836 - val_iou_class_1: 7.1658e-05 - val_iou_class_2: 6.8886e-05 - val_iou_coef_multiclass: 0.9599 - val_loss: 0.8058 - learning_rate: 5.0000e-04
# Epoch 3/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9894 - dice_class_0: 0.9957 - dice_class_1: 0.7086 - dice_class_2: 0.6242 - dice_coef_multiclass: 0.9628 - iou_class_0: 0.9914 - iou_class_1: 0.5558 - iou_class_2: 0.4630 - iou_coef_multiclass: 0.9285 - loss: 0.3889
# Epoch 3: val_loss improved from 0.80581 to 0.31897, saving model to results/FULL_with_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 160ms/step - accuracy: 0.9894 - dice_class_0: 0.9957 - dice_class_1: 0.7090 - dice_class_2: 0.6245 - dice_coef_multiclass: 0.9629 - iou_class_0: 0.9914 - iou_class_1: 0.5562 - iou_class_2: 0.4634 - iou_coef_multiclass: 0.9286 - loss: 0.3887 - val_accuracy: 0.9913 - val_dice_class_0: 0.9963 - val_dice_class_1: 0.7212 - val_dice_class_2: 0.7898 - val_dice_coef_multiclass: 0.9906 - val_iou_class_0: 0.9927 - val_iou_class_1: 0.5691 - val_iou_class_2: 0.6576 - val_iou_coef_multiclass: 0.9815 - val_loss: 0.3190 - learning_rate: 5.0000e-04
# Epoch 4/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9959 - dice_class_0: 0.9987 - dice_class_1: 0.8487 - dice_class_2: 0.8132 - dice_coef_multiclass: 0.9939 - iou_class_0: 0.9973 - iou_class_1: 0.7393 - iou_class_2: 0.6897 - iou_coef_multiclass: 0.9879 - loss: 0.2361
# Epoch 4: val_loss improved from 0.31897 to 0.29990, saving model to results/FULL_with_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 160ms/step - accuracy: 0.9959 - dice_class_0: 0.9987 - dice_class_1: 0.8487 - dice_class_2: 0.8133 - dice_coef_multiclass: 0.9939 - iou_class_0: 0.9973 - iou_class_1: 0.7394 - iou_class_2: 0.6898 - iou_coef_multiclass: 0.9879 - loss: 0.2359 - val_accuracy: 0.9946 - val_dice_class_0: 0.9982 - val_dice_class_1: 0.7589 - val_dice_class_2: 0.7317 - val_dice_coef_multiclass: 0.9946 - val_iou_class_0: 0.9964 - val_iou_class_1: 0.6139 - val_iou_class_2: 0.5815 - val_iou_coef_multiclass: 0.9892 - val_loss: 0.2999 - learning_rate: 5.0000e-04
# Epoch 5/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9971 - dice_class_0: 0.9991 - dice_class_1: 0.8836 - dice_class_2: 0.8590 - dice_coef_multiclass: 0.9970 - iou_class_0: 0.9982 - iou_class_1: 0.7925 - iou_class_2: 0.7545 - iou_coef_multiclass: 0.9940 - loss: 0.1670
# Epoch 5: val_loss improved from 0.29990 to 0.22342, saving model to results/FULL_with_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 161ms/step - accuracy: 0.9971 - dice_class_0: 0.9991 - dice_class_1: 0.8836 - dice_class_2: 0.8590 - dice_coef_multiclass: 0.9970 - iou_class_0: 0.9982 - iou_class_1: 0.7925 - iou_class_2: 0.7545 - iou_coef_multiclass: 0.9940 - loss: 0.1670 - val_accuracy: 0.9961 - val_dice_class_0: 0.9987 - val_dice_class_1: 0.8203 - val_dice_class_2: 0.8399 - val_dice_coef_multiclass: 0.9960 - val_iou_class_0: 0.9974 - val_iou_class_1: 0.6973 - val_iou_class_2: 0.7261 - val_iou_coef_multiclass: 0.9920 - val_loss: 0.2234 - learning_rate: 5.0000e-04
# Epoch 6/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9972 - dice_class_0: 0.9992 - dice_class_1: 0.8889 - dice_class_2: 0.8649 - dice_coef_multiclass: 0.9971 - iou_class_0: 0.9983 - iou_class_1: 0.8011 - iou_class_2: 0.7639 - iou_coef_multiclass: 0.9943 - loss: 0.1592
# Epoch 6: val_loss did not improve from 0.22342
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 137ms/step - accuracy: 0.9972 - dice_class_0: 0.9992 - dice_class_1: 0.8889 - dice_class_2: 0.8649 - dice_coef_multiclass: 0.9971 - iou_class_0: 0.9983 - iou_class_1: 0.8011 - iou_class_2: 0.7639 - iou_coef_multiclass: 0.9943 - loss: 0.1592 - val_accuracy: 0.9961 - val_dice_class_0: 0.9989 - val_dice_class_1: 0.8316 - val_dice_class_2: 0.8220 - val_dice_coef_multiclass: 0.9960 - val_iou_class_0: 0.9978 - val_iou_class_1: 0.7130 - val_iou_class_2: 0.7002 - val_iou_coef_multiclass: 0.9921 - val_loss: 0.2249 - learning_rate: 5.0000e-04
# Epoch 7/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9973 - dice_class_0: 0.9992 - dice_class_1: 0.8937 - dice_class_2: 0.8744 - dice_coef_multiclass: 0.9972 - iou_class_0: 0.9984 - iou_class_1: 0.8089 - iou_class_2: 0.7790 - iou_coef_multiclass: 0.9945 - loss: 0.1514
# Epoch 7: val_loss improved from 0.22342 to 0.18078, saving model to results/FULL_with_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 161ms/step - accuracy: 0.9973 - dice_class_0: 0.9992 - dice_class_1: 0.8937 - dice_class_2: 0.8743 - dice_coef_multiclass: 0.9972 - iou_class_0: 0.9984 - iou_class_1: 0.8089 - iou_class_2: 0.7790 - iou_coef_multiclass: 0.9945 - loss: 0.1514 - val_accuracy: 0.9968 - val_dice_class_0: 0.9990 - val_dice_class_1: 0.8623 - val_dice_class_2: 0.8516 - val_dice_coef_multiclass: 0.9968 - val_iou_class_0: 0.9980 - val_iou_class_1: 0.7608 - val_iou_class_2: 0.7450 - val_iou_coef_multiclass: 0.9935 - val_loss: 0.1808 - learning_rate: 5.0000e-04
# Epoch 8/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9973 - dice_class_0: 0.9992 - dice_class_1: 0.8915 - dice_class_2: 0.8730 - dice_coef_multiclass: 0.9972 - iou_class_0: 0.9984 - iou_class_1: 0.8061 - iou_class_2: 0.7768 - iou_coef_multiclass: 0.9944 - loss: 0.1527
# Epoch 8: val_loss improved from 0.18078 to 0.17137, saving model to results/FULL_with_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 159ms/step - accuracy: 0.9973 - dice_class_0: 0.9992 - dice_class_1: 0.8915 - dice_class_2: 0.8730 - dice_coef_multiclass: 0.9972 - iou_class_0: 0.9984 - iou_class_1: 0.8061 - iou_class_2: 0.7768 - iou_coef_multiclass: 0.9944 - loss: 0.1527 - val_accuracy: 0.9973 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8881 - val_dice_class_2: 0.8348 - val_dice_coef_multiclass: 0.9972 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8006 - val_iou_class_2: 0.7200 - val_iou_coef_multiclass: 0.9944 - val_loss: 0.1714 - learning_rate: 5.0000e-04
# Epoch 9/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9974 - dice_class_0: 0.9992 - dice_class_1: 0.8964 - dice_class_2: 0.8732 - dice_coef_multiclass: 0.9973 - iou_class_0: 0.9985 - iou_class_1: 0.8135 - iou_class_2: 0.7763 - iou_coef_multiclass: 0.9947 - loss: 0.1480
# Epoch 9: val_loss did not improve from 0.17137
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 21s 137ms/step - accuracy: 0.9974 - dice_class_0: 0.9992 - dice_class_1: 0.8965 - dice_class_2: 0.8733 - dice_coef_multiclass: 0.9973 - iou_class_0: 0.9985 - iou_class_1: 0.8135 - iou_class_2: 0.7763 - iou_coef_multiclass: 0.9947 - loss: 0.1480 - val_accuracy: 0.9965 - val_dice_class_0: 0.9990 - val_dice_class_1: 0.8532 - val_dice_class_2: 0.8058 - val_dice_coef_multiclass: 0.9965 - val_iou_class_0: 0.9979 - val_iou_class_1: 0.7456 - val_iou_class_2: 0.6775 - val_iou_coef_multiclass: 0.9931 - val_loss: 0.2098 - learning_rate: 5.0000e-04
# Epoch 10/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9976 - dice_class_0: 0.9993 - dice_class_1: 0.9039 - dice_class_2: 0.8822 - dice_coef_multiclass: 0.9975 - iou_class_0: 0.9985 - iou_class_1: 0.8255 - iou_class_2: 0.7910 - iou_coef_multiclass: 0.9951 - loss: 0.1403
# Epoch 10: val_loss did not improve from 0.17137
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 136ms/step - accuracy: 0.9976 - dice_class_0: 0.9993 - dice_class_1: 0.9039 - dice_class_2: 0.8822 - dice_coef_multiclass: 0.9975 - iou_class_0: 0.9985 - iou_class_1: 0.8255 - iou_class_2: 0.7910 - iou_coef_multiclass: 0.9951 - loss: 0.1403 - val_accuracy: 0.9969 - val_dice_class_0: 0.9991 - val_dice_class_1: 0.8679 - val_dice_class_2: 0.8480 - val_dice_coef_multiclass: 0.9968 - val_iou_class_0: 0.9981 - val_iou_class_1: 0.7680 - val_iou_class_2: 0.7377 - val_iou_coef_multiclass: 0.9936 - val_loss: 0.1798 - learning_rate: 5.0000e-04
# Epoch 11/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9976 - dice_class_0: 0.9993 - dice_class_1: 0.9036 - dice_class_2: 0.8798 - dice_coef_multiclass: 0.9975 - iou_class_0: 0.9986 - iou_class_1: 0.8248 - iou_class_2: 0.7866 - iou_coef_multiclass: 0.9951 - loss: 0.1425
# Epoch 11: val_loss did not improve from 0.17137
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 136ms/step - accuracy: 0.9976 - dice_class_0: 0.9993 - dice_class_1: 0.9036 - dice_class_2: 0.8798 - dice_coef_multiclass: 0.9975 - iou_class_0: 0.9986 - iou_class_1: 0.8248 - iou_class_2: 0.7867 - iou_coef_multiclass: 0.9951 - loss: 0.1425 - val_accuracy: 0.9967 - val_dice_class_0: 0.9990 - val_dice_class_1: 0.8582 - val_dice_class_2: 0.8233 - val_dice_coef_multiclass: 0.9966 - val_iou_class_0: 0.9980 - val_iou_class_1: 0.7541 - val_iou_class_2: 0.7035 - val_iou_coef_multiclass: 0.9933 - val_loss: 0.1993 - learning_rate: 5.0000e-04
# Epoch 12/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9096 - dice_class_2: 0.8946 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9986 - iou_class_1: 0.8349 - iou_class_2: 0.8107 - iou_coef_multiclass: 0.9954 - loss: 0.1298
# Epoch 12: val_loss improved from 0.17137 to 0.14963, saving model to results/FULL_with_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 25s 168ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9096 - dice_class_2: 0.8946 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9986 - iou_class_1: 0.8349 - iou_class_2: 0.8107 - iou_coef_multiclass: 0.9954 - loss: 0.1298 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8982 - val_dice_class_2: 0.8635 - val_dice_coef_multiclass: 0.9975 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8164 - val_iou_class_2: 0.7623 - val_iou_coef_multiclass: 0.9951 - val_loss: 0.1496 - learning_rate: 1.5000e-04
# Epoch 13/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9979 - dice_class_0: 0.9994 - dice_class_1: 0.9148 - dice_class_2: 0.9006 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9987 - iou_class_1: 0.8435 - iou_class_2: 0.8205 - iou_coef_multiclass: 0.9956 - loss: 0.1227
# Epoch 13: val_loss improved from 0.14963 to 0.14808, saving model to results/FULL_with_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 158ms/step - accuracy: 0.9979 - dice_class_0: 0.9994 - dice_class_1: 0.9148 - dice_class_2: 0.9006 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9987 - iou_class_1: 0.8435 - iou_class_2: 0.8205 - iou_coef_multiclass: 0.9956 - loss: 0.1227 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9028 - val_dice_class_2: 0.8693 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8236 - val_iou_class_2: 0.7706 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1481 - learning_rate: 1.5000e-04
# Epoch 14/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9117 - dice_class_2: 0.8976 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9986 - iou_class_1: 0.8386 - iou_class_2: 0.8153 - iou_coef_multiclass: 0.9954 - loss: 0.1249
# Epoch 14: val_loss improved from 0.14808 to 0.14295, saving model to results/FULL_with_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 161ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9117 - dice_class_2: 0.8976 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9986 - iou_class_1: 0.8386 - iou_class_2: 0.8153 - iou_coef_multiclass: 0.9954 - loss: 0.1249 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9001 - val_dice_class_2: 0.8768 - val_dice_coef_multiclass: 0.9975 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8197 - val_iou_class_2: 0.7828 - val_iou_coef_multiclass: 0.9951 - val_loss: 0.1429 - learning_rate: 1.5000e-04
# Epoch 15/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9141 - dice_class_2: 0.9067 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9986 - iou_class_1: 0.8425 - iou_class_2: 0.8305 - iou_coef_multiclass: 0.9956 - loss: 0.1186
# Epoch 15: val_loss improved from 0.14295 to 0.14053, saving model to results/FULL_with_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 158ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9141 - dice_class_2: 0.9067 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9986 - iou_class_1: 0.8425 - iou_class_2: 0.8305 - iou_coef_multiclass: 0.9956 - loss: 0.1187 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9038 - val_dice_class_2: 0.8798 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8258 - val_iou_class_2: 0.7872 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1405 - learning_rate: 1.5000e-04
# Epoch 16/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9163 - dice_class_2: 0.9045 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9987 - iou_class_1: 0.8461 - iou_class_2: 0.8265 - iou_coef_multiclass: 0.9957 - loss: 0.1197
# Epoch 16: val_loss did not improve from 0.14053
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 137ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9163 - dice_class_2: 0.9045 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9987 - iou_class_1: 0.8461 - iou_class_2: 0.8265 - iou_coef_multiclass: 0.9957 - loss: 0.1197 - val_accuracy: 0.9975 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8956 - val_dice_class_2: 0.8486 - val_dice_coef_multiclass: 0.9974 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8118 - val_iou_class_2: 0.7393 - val_iou_coef_multiclass: 0.9949 - val_loss: 0.1612 - learning_rate: 1.5000e-04
# Epoch 17/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9979 - dice_class_0: 0.9994 - dice_class_1: 0.9167 - dice_class_2: 0.9070 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8468 - iou_class_2: 0.8309 - iou_coef_multiclass: 0.9958 - loss: 0.1185
# Epoch 17: val_loss did not improve from 0.14053
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 137ms/step - accuracy: 0.9979 - dice_class_0: 0.9994 - dice_class_1: 0.9167 - dice_class_2: 0.9071 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8468 - iou_class_2: 0.8309 - iou_coef_multiclass: 0.9958 - loss: 0.1185 - val_accuracy: 0.9976 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9010 - val_dice_class_2: 0.8684 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8221 - val_iou_class_2: 0.7699 - val_iou_coef_multiclass: 0.9951 - val_loss: 0.1458 - learning_rate: 1.5000e-04
# Epoch 18/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9197 - dice_class_2: 0.9100 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9988 - iou_class_1: 0.8518 - iou_class_2: 0.8357 - iou_coef_multiclass: 0.9959 - loss: 0.1146
# Epoch 18: val_loss did not improve from 0.14053
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 4.500000213738531e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 136ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9197 - dice_class_2: 0.9100 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9988 - iou_class_1: 0.8518 - iou_class_2: 0.8357 - iou_coef_multiclass: 0.9959 - loss: 0.1146 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9031 - val_dice_class_2: 0.8798 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8244 - val_iou_class_2: 0.7872 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1423 - learning_rate: 1.5000e-04
# Epoch 19/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9197 - dice_class_2: 0.9086 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9988 - iou_class_1: 0.8520 - iou_class_2: 0.8337 - iou_coef_multiclass: 0.9959 - loss: 0.1139
# Epoch 19: val_loss improved from 0.14053 to 0.13796, saving model to results/FULL_with_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 160ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9197 - dice_class_2: 0.9086 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9988 - iou_class_1: 0.8520 - iou_class_2: 0.8338 - iou_coef_multiclass: 0.9959 - loss: 0.1139 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9057 - val_dice_class_2: 0.8861 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8281 - val_iou_class_2: 0.7965 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1380 - learning_rate: 4.5000e-05
# Epoch 20/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9214 - dice_class_2: 0.9143 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8548 - iou_class_2: 0.8432 - iou_coef_multiclass: 0.9960 - loss: 0.1108
# Epoch 20: val_loss did not improve from 0.13796
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 21s 137ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9214 - dice_class_2: 0.9143 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8548 - iou_class_2: 0.8432 - iou_coef_multiclass: 0.9960 - loss: 0.1108 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9018 - val_dice_class_2: 0.8718 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8228 - val_iou_class_2: 0.7755 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1452 - learning_rate: 4.5000e-05
# Epoch 21/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9234 - dice_class_2: 0.9152 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8582 - iou_class_2: 0.8447 - iou_coef_multiclass: 0.9961 - loss: 0.1091
# Epoch 21: val_loss improved from 0.13796 to 0.13671, saving model to results/FULL_with_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 160ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9234 - dice_class_2: 0.9152 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8582 - iou_class_2: 0.8447 - iou_coef_multiclass: 0.9961 - loss: 0.1091 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9062 - val_dice_class_2: 0.8875 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8295 - val_iou_class_2: 0.7987 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1367 - learning_rate: 4.5000e-05
# Epoch 22/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9253 - dice_class_2: 0.9200 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8614 - iou_class_2: 0.8529 - iou_coef_multiclass: 0.9962 - loss: 0.1050
# Epoch 22: val_loss improved from 0.13671 to 0.13661, saving model to results/FULL_with_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 161ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9253 - dice_class_2: 0.9200 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8614 - iou_class_2: 0.8529 - iou_coef_multiclass: 0.9962 - loss: 0.1050 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9069 - val_dice_class_2: 0.8839 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8304 - val_iou_class_2: 0.7933 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1366 - learning_rate: 4.5000e-05
# Epoch 23/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9248 - dice_class_2: 0.9199 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8606 - iou_class_2: 0.8524 - iou_coef_multiclass: 0.9962 - loss: 0.1053
# Epoch 23: val_loss did not improve from 0.13661
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 136ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9248 - dice_class_2: 0.9199 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8606 - iou_class_2: 0.8523 - iou_coef_multiclass: 0.9962 - loss: 0.1053 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9034 - val_dice_class_2: 0.8781 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8249 - val_iou_class_2: 0.7842 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1419 - learning_rate: 4.5000e-05
# Epoch 24/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9270 - dice_class_2: 0.9207 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8644 - iou_class_2: 0.8539 - iou_coef_multiclass: 0.9962 - loss: 0.1036
# Epoch 24: val_loss did not improve from 0.13661
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 136ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9270 - dice_class_2: 0.9207 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8643 - iou_class_2: 0.8539 - iou_coef_multiclass: 0.9962 - loss: 0.1036 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9030 - val_dice_class_2: 0.8797 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8238 - val_iou_class_2: 0.7866 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1413 - learning_rate: 4.5000e-05
# Epoch 25/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9200 - dice_class_2: 0.9157 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8526 - iou_class_2: 0.8452 - iou_coef_multiclass: 0.9960 - loss: 0.1105
# Epoch 25: val_loss did not improve from 0.13661
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.3500000204658135e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 136ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9201 - dice_class_2: 0.9157 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8526 - iou_class_2: 0.8452 - iou_coef_multiclass: 0.9960 - loss: 0.1105 - val_accuracy: 0.9977 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9036 - val_dice_class_2: 0.8751 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8253 - val_iou_class_2: 0.7800 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1427 - learning_rate: 4.5000e-05
# Epoch 26/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9286 - dice_class_2: 0.9239 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8670 - iou_class_2: 0.8593 - iou_coef_multiclass: 0.9963 - loss: 0.1014
# Epoch 26: val_loss did not improve from 0.13661
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 136ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9286 - dice_class_2: 0.9239 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8670 - iou_class_2: 0.8593 - iou_coef_multiclass: 0.9963 - loss: 0.1014 - val_accuracy: 0.9977 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9047 - val_dice_class_2: 0.8838 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8266 - val_iou_class_2: 0.7933 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1390 - learning_rate: 1.3500e-05
# Epoch 27/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9297 - dice_class_2: 0.9251 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8690 - iou_class_2: 0.8614 - iou_coef_multiclass: 0.9963 - loss: 0.0991
# Epoch 27: val_loss improved from 0.13661 to 0.13638, saving model to results/FULL_with_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 160ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9297 - dice_class_2: 0.9251 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8690 - iou_class_2: 0.8614 - iou_coef_multiclass: 0.9963 - loss: 0.0991 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9081 - val_dice_class_2: 0.8852 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8326 - val_iou_class_2: 0.7955 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1364 - learning_rate: 1.3500e-05
# Epoch 28/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9281 - dice_class_2: 0.9231 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8662 - iou_class_2: 0.8577 - iou_coef_multiclass: 0.9963 - loss: 0.1007
# Epoch 28: val_loss did not improve from 0.13638
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 136ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9281 - dice_class_2: 0.9231 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8662 - iou_class_2: 0.8577 - iou_coef_multiclass: 0.9963 - loss: 0.1007 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9026 - val_dice_class_2: 0.8796 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8235 - val_iou_class_2: 0.7871 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1415 - learning_rate: 1.3500e-05
# Epoch 29/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9290 - dice_class_2: 0.9231 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8678 - iou_class_2: 0.8580 - iou_coef_multiclass: 0.9964 - loss: 0.0999
# Epoch 29: val_loss did not improve from 0.13638
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 137ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9290 - dice_class_2: 0.9231 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8678 - iou_class_2: 0.8580 - iou_coef_multiclass: 0.9964 - loss: 0.0999 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9054 - val_dice_class_2: 0.8805 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8282 - val_iou_class_2: 0.7884 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1395 - learning_rate: 1.3500e-05
# Epoch 30/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9266 - dice_class_2: 0.9239 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8637 - iou_class_2: 0.8594 - iou_coef_multiclass: 0.9963 - loss: 0.1018
# Epoch 30: val_loss did not improve from 0.13638
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 4.050000006827758e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 136ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9266 - dice_class_2: 0.9239 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8637 - iou_class_2: 0.8594 - iou_coef_multiclass: 0.9963 - loss: 0.1018 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9011 - val_dice_class_2: 0.8778 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8211 - val_iou_class_2: 0.7842 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1441 - learning_rate: 1.3500e-05
# Epoch 31/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9243 - dice_class_2: 0.9223 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8598 - iou_class_2: 0.8566 - iou_coef_multiclass: 0.9961 - loss: 0.1038
# Epoch 31: val_loss improved from 0.13638 to 0.13539, saving model to results/FULL_with_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 160ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9243 - dice_class_2: 0.9223 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8598 - iou_class_2: 0.8566 - iou_coef_multiclass: 0.9961 - loss: 0.1038 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9086 - val_dice_class_2: 0.8857 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8334 - val_iou_class_2: 0.7962 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1354 - learning_rate: 4.0500e-06
# Epoch 32/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9293 - dice_class_2: 0.9263 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8683 - iou_class_2: 0.8635 - iou_coef_multiclass: 0.9964 - loss: 0.0992
# Epoch 32: val_loss did not improve from 0.13539
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 137ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9293 - dice_class_2: 0.9263 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8683 - iou_class_2: 0.8635 - iou_coef_multiclass: 0.9964 - loss: 0.0992 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9024 - val_dice_class_2: 0.8823 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8233 - val_iou_class_2: 0.7908 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1424 - learning_rate: 4.0500e-06
# Epoch 33/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9268 - dice_class_2: 0.9228 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8639 - iou_class_2: 0.8573 - iou_coef_multiclass: 0.9963 - loss: 0.1030
# Epoch 33: val_loss did not improve from 0.13539
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 136ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9268 - dice_class_2: 0.9228 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8639 - iou_class_2: 0.8573 - iou_coef_multiclass: 0.9963 - loss: 0.1030 - val_accuracy: 0.9977 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9036 - val_dice_class_2: 0.8803 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8257 - val_iou_class_2: 0.7882 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1411 - learning_rate: 4.0500e-06
# Epoch 34/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9296 - dice_class_2: 0.9263 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8689 - iou_class_2: 0.8635 - iou_coef_multiclass: 0.9964 - loss: 0.0989
# Epoch 34: val_loss did not improve from 0.13539
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.2149999747634864e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 136ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9295 - dice_class_2: 0.9263 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8689 - iou_class_2: 0.8634 - iou_coef_multiclass: 0.9964 - loss: 0.0989 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9065 - val_dice_class_2: 0.8884 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8296 - val_iou_class_2: 0.8008 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1360 - learning_rate: 4.0500e-06
# Epoch 35/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9303 - dice_class_2: 0.9272 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8700 - iou_class_2: 0.8648 - iou_coef_multiclass: 0.9964 - loss: 0.0980
# Epoch 35: val_loss did not improve from 0.13539
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 136ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9303 - dice_class_2: 0.9272 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8700 - iou_class_2: 0.8648 - iou_coef_multiclass: 0.9964 - loss: 0.0980 - val_accuracy: 0.9977 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9043 - val_dice_class_2: 0.8840 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8267 - val_iou_class_2: 0.7940 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1401 - learning_rate: 1.2150e-06
# Epoch 36/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9289 - dice_class_2: 0.9237 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8676 - iou_class_2: 0.8589 - iou_coef_multiclass: 0.9963 - loss: 0.1006
# Epoch 36: val_loss did not improve from 0.13539
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 21s 137ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9289 - dice_class_2: 0.9237 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8676 - iou_class_2: 0.8589 - iou_coef_multiclass: 0.9963 - loss: 0.1006 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9030 - val_dice_class_2: 0.8799 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8243 - val_iou_class_2: 0.7870 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1411 - learning_rate: 1.2150e-06
# Epoch 37/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9301 - dice_class_2: 0.9265 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8696 - iou_class_2: 0.8635 - iou_coef_multiclass: 0.9964 - loss: 0.0980
# Epoch 37: val_loss improved from 0.13539 to 0.13495, saving model to results/FULL_with_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 24s 160ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9301 - dice_class_2: 0.9265 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8696 - iou_class_2: 0.8635 - iou_coef_multiclass: 0.9964 - loss: 0.0980 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9098 - val_dice_class_2: 0.8858 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8353 - val_iou_class_2: 0.7966 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1349 - learning_rate: 1.2150e-06
# Epoch 38/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9297 - dice_class_2: 0.9264 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8691 - iou_class_2: 0.8636 - iou_coef_multiclass: 0.9964 - loss: 0.0988
# Epoch 38: val_loss did not improve from 0.13495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 136ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9297 - dice_class_2: 0.9264 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8690 - iou_class_2: 0.8636 - iou_coef_multiclass: 0.9964 - loss: 0.0988 - val_accuracy: 0.9977 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9053 - val_dice_class_2: 0.8825 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8279 - val_iou_class_2: 0.7910 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1395 - learning_rate: 1.2150e-06
# Epoch 39/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9280 - dice_class_2: 0.9249 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8660 - iou_class_2: 0.8609 - iou_coef_multiclass: 0.9963 - loss: 0.1008
# Epoch 39: val_loss did not improve from 0.13495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 137ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9280 - dice_class_2: 0.9249 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8661 - iou_class_2: 0.8609 - iou_coef_multiclass: 0.9963 - loss: 0.1008 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9075 - val_dice_class_2: 0.8861 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8312 - val_iou_class_2: 0.7965 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1366 - learning_rate: 1.2150e-06
# Epoch 40/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9284 - dice_class_2: 0.9276 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8667 - iou_class_2: 0.8657 - iou_coef_multiclass: 0.9963 - loss: 0.0988
# Epoch 40: val_loss did not improve from 0.13495
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 3.644999992502562e-07.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 21s 137ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9284 - dice_class_2: 0.9276 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8667 - iou_class_2: 0.8657 - iou_coef_multiclass: 0.9963 - loss: 0.0988 - val_accuracy: 0.9977 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9050 - val_dice_class_2: 0.8798 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8272 - val_iou_class_2: 0.7870 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1407 - learning_rate: 1.2150e-06
# Epoch 41/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9244 - dice_class_2: 0.9252 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8602 - iou_class_2: 0.8615 - iou_coef_multiclass: 0.9962 - loss: 0.1032
# Epoch 41: val_loss did not improve from 0.13495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 136ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9245 - dice_class_2: 0.9252 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8602 - iou_class_2: 0.8615 - iou_coef_multiclass: 0.9962 - loss: 0.1031 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9064 - val_dice_class_2: 0.8832 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8294 - val_iou_class_2: 0.7919 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1385 - learning_rate: 3.6450e-07
# Epoch 42/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9278 - dice_class_2: 0.9271 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8659 - iou_class_2: 0.8649 - iou_coef_multiclass: 0.9963 - loss: 0.0988
# Epoch 42: val_loss did not improve from 0.13495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 136ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9278 - dice_class_2: 0.9270 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8659 - iou_class_2: 0.8649 - iou_coef_multiclass: 0.9963 - loss: 0.0988 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9049 - val_dice_class_2: 0.8832 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8275 - val_iou_class_2: 0.7924 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1391 - learning_rate: 3.6450e-07
# Epoch 43/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9259 - dice_class_2: 0.9210 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8626 - iou_class_2: 0.8545 - iou_coef_multiclass: 0.9962 - loss: 0.1025
# Epoch 43: val_loss did not improve from 0.13495
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1.0935000318568199e-07.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 136ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9259 - dice_class_2: 0.9210 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8627 - iou_class_2: 0.8545 - iou_coef_multiclass: 0.9962 - loss: 0.1025 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9041 - val_dice_class_2: 0.8844 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8260 - val_iou_class_2: 0.7939 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1405 - learning_rate: 3.6450e-07
# Epoch 44/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9289 - dice_class_2: 0.9284 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8675 - iou_class_2: 0.8669 - iou_coef_multiclass: 0.9964 - loss: 0.0977
# Epoch 44: val_loss did not improve from 0.13495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 136ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9289 - dice_class_2: 0.9284 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8675 - iou_class_2: 0.8669 - iou_coef_multiclass: 0.9964 - loss: 0.0977 - val_accuracy: 0.9977 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9050 - val_dice_class_2: 0.8843 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8277 - val_iou_class_2: 0.7941 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1376 - learning_rate: 1.0935e-07
# Epoch 45/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9294 - dice_class_2: 0.9274 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8686 - iou_class_2: 0.8653 - iou_coef_multiclass: 0.9964 - loss: 0.0986
# Epoch 45: val_loss did not improve from 0.13495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 136ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9294 - dice_class_2: 0.9274 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8686 - iou_class_2: 0.8653 - iou_coef_multiclass: 0.9964 - loss: 0.0986 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9059 - val_dice_class_2: 0.8830 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8292 - val_iou_class_2: 0.7920 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1375 - learning_rate: 1.0935e-07
# Epoch 46/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9291 - dice_class_2: 0.9266 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8678 - iou_class_2: 0.8637 - iou_coef_multiclass: 0.9964 - loss: 0.0986
# Epoch 46: val_loss did not improve from 0.13495
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1e-07.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 137ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9290 - dice_class_2: 0.9266 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8678 - iou_class_2: 0.8637 - iou_coef_multiclass: 0.9964 - loss: 0.0986 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9070 - val_dice_class_2: 0.8849 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8307 - val_iou_class_2: 0.7952 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1371 - learning_rate: 1.0935e-07
# Epoch 47/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9291 - dice_class_2: 0.9276 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8679 - iou_class_2: 0.8656 - iou_coef_multiclass: 0.9964 - loss: 0.0978
# Epoch 47: val_loss did not improve from 0.13495
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 136ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9291 - dice_class_2: 0.9276 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8679 - iou_class_2: 0.8656 - iou_coef_multiclass: 0.9964 - loss: 0.0978 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9046 - val_dice_class_2: 0.8849 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8269 - val_iou_class_2: 0.7949 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1396 - learning_rate: 1.0000e-07
# Epoch 47: early stopping
# Restoring model weights from the end of the best epoch: 37.
# ✓ Training completed
#  Training curves saved: results/FULL_with_CBAM_training_curves.png
# ================================================================================
# EVALUATION: Full with CBAM
# ================================================================================
#  Confusion matrices saved: results/Full with CBAM_confusion_matrices.png
# \nConfusion Matrix:
# [[25768421    16569        0]
#  [   16591   289680     8800]
#  [      10    16730    97599]]
# \nNormalized Confusion Matrix:
# [[0.999 0.001 0.   ]
#  [0.053 0.919 0.028]
#  [0.    0.146 0.854]]
#
# Precision, Recall, F1 Score per class:
#   Background: Precision=0.9994, Recall=0.9994, F1=0.9994
#   Disc: Precision=0.8969, Recall=0.9194, F1=0.9080
#   Cup: Precision=0.9173, Recall=0.8536, F1=0.8843
#
# Macro-averaged metrics:
#   Precision: 0.9378
#   Recall: 0.9241
#   F1 Score: 0.9306
#   Background: Dice=0.9994, IoU=0.9987
#   Disc: Dice=0.9080, IoU=0.8315
#   Cup: Dice=0.8843, IoU=0.7926
#
# MC Dropout Evaluation:
#
# Running MC Dropout with 10 stochastic forward passes...
#   Completed: 5/10 forward passes
#   Completed: 10/10 forward passes
# ✓ MC Dropout completed
#   Mean prediction shape: (100, 256, 256, 3)
#   Std prediction shape: (100, 256, 256, 3)
#   Background uncertainty: 0.0002
#   Disc uncertainty: 0.0004
#   Cup uncertainty: 0.0002
#
# ====================================================================================================
#                                       ✓ EXPERIMENT COMPLETED!
# ====================================================================================================
#
# Final Results:
#
# FULL + CBAM:
#   Parameters: 37,585,135
#   Disc Dice: 0.9080
#   Cup Dice: 0.8843
#   Overall: 0.8962
#
# ====================================================================================================
