# %%
"""
COMBINED ADVANCED MOBILENET-UNET WITH MINIMAL CBAM ATTENTION
==============================================================
This combines:
1. Deeper decoder architecture with enhanced blocks
2. Focal-EIoU loss
3. MC Dropout for uncertainty estimation
4. CBAM (Convolutional Block Attention Module) - MINIMAL VERSION
   - Applied ONLY to: decoder blocks (4 locations)
   - REMOVED from: skip connections, bridge, final layer
   - This reduces over-regularization while keeping attention where it matters

STRATEGY: Place CBAM only in decoder blocks where features are being refined
for the final segmentation output.
"""

import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, backend as K
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import albumentations as A
import warnings
import gc
warnings.filterwarnings('ignore')

plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# ============================================================================
# HELPER FUNCTIONS
# ============================================================================

def configure_gpu():
    """Configure GPU settings for optimal performance"""
    print("Configuring GPU settings...")
    physical_devices = tf.config.list_physical_devices('GPU')
    if physical_devices:
        try:
            for gpu in physical_devices:
                tf.config.experimental.set_memory_growth(gpu, True)
            tf.config.set_visible_devices(physical_devices[0], 'GPU')
            print(f"✓ GPU found: {physical_devices}")
            print("  GPU device name:", tf.test.gpu_device_name())
            return True
        except RuntimeError as e:
            print(f"✗ GPU error: {e}")
            return False
    else:
        print("✗ No GPU found, using CPU")
        return False

def load_images_masks(images_folder, masks_folder, img_size=(256,256)):
    """Load images and masks from folders"""
    images, masks = [], []
    image_files = sorted(os.listdir(images_folder))
    mask_files = sorted(os.listdir(masks_folder))
    mask_dict = {os.path.splitext(f)[0]: f for f in mask_files}
    
    for img_file in image_files:
        base = os.path.splitext(img_file)[0]
        if base in mask_dict:
            img = cv2.imread(os.path.join(images_folder, img_file))
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, img_size) / 255.0
            
            mask = cv2.imread(os.path.join(masks_folder, mask_dict[base]), cv2.IMREAD_GRAYSCALE)
            mask = cv2.resize(mask, img_size)
            unique_vals = np.unique(mask)
            if len(unique_vals) > 3 or np.max(unique_vals) > 2:
                mask = np.clip(mask // 85, 0, 2).astype(np.uint8)
            
            images.append(img)
            masks.append(mask)
    
    return np.array(images, dtype=np.float32), np.array(masks, dtype=np.uint8)

def load_all_data(root_dir):
    """Load all data from existing splits and merge"""
    all_images, all_masks = [], []
    for split in ["train", "val", "test"]:
        print(f"Loading {split} data...")
        imgs, msks = load_images_masks(
            os.path.join(root_dir, split, "Images"),
            os.path.join(root_dir, split, "Masks")
        )
        all_images.append(imgs)
        all_masks.append(msks)
        print(f"  {split}: {imgs.shape[0]} samples")
    
    return np.concatenate(all_images), np.concatenate(all_masks)

def create_new_split(all_images, all_masks):
    """Create new split: 600 train, 200 val, 400 test"""
    X_temp, X_test, y_temp, y_test = train_test_split(
        all_images, all_masks, test_size=400, random_state=42
    )
    X_train, X_val, y_train, y_val = train_test_split(
        X_temp, y_temp, test_size=200, random_state=42
    )
    print(f"Split - Train: {X_train.shape[0]}, Val: {X_val.shape[0]}, Test: {X_test.shape[0]}")
    return (X_train, y_train), (X_val, y_val), (X_test, y_test)

def setup_augmentations():
    return A.Compose([
        A.RandomBrightnessContrast(brightness_limit=0.15, contrast_limit=0.15, p=0.7),
        A.HueSaturationValue(hue_shift_limit=10, sat_shift_limit=15, val_shift_limit=10, p=0.5),
        A.GaussianBlur(blur_limit=3, p=0.3),
        A.RandomGamma(gamma_limit=(80, 120), p=0.3),
    ])

def data_generator(images, masks, batch_size, augment=None):
    idxs = np.arange(len(images))
    while True:
        np.random.shuffle(idxs)
        for i in range(0, len(images), batch_size):
            batch_idxs = idxs[i:i+batch_size]
            batch_x, batch_y = [], []
            
            for idx in batch_idxs:
                img, mask = images[idx], masks[idx]
                
                if augment:
                    aug = augment(image=img, mask=mask)
                    img_aug, mask_aug = aug['image'], aug['mask']
                else:
                    img_aug, mask_aug = img, mask
                
                mask_cat = to_categorical(mask_aug, num_classes=3)
                batch_x.append(img_aug)
                batch_y.append(mask_cat)
            
            batch_x = np.stack(batch_x).astype(np.float32)
            batch_y = np.stack(batch_y).astype(np.float32)
            
            yield batch_x, batch_y

# ============================================================================
# CBAM ATTENTION MODULES
# ============================================================================

def channel_attention(input_feature, ratio=8, name=""):
    """Channel Attention Module (CAM)"""
    channel = input_feature.shape[-1]
    
    shared_layer_one = layers.Dense(channel//ratio, activation='relu', name=f'channel_attention_dense1_{name}')
    shared_layer_two = layers.Dense(channel, activation='sigmoid', name=f'channel_attention_dense2_{name}')
    
    avg_pool = layers.GlobalAveragePooling2D()(input_feature)
    avg_pool = layers.Reshape((1, 1, channel))(avg_pool)
    avg_pool = shared_layer_one(avg_pool)
    avg_pool = shared_layer_two(avg_pool)
    
    max_pool = layers.GlobalMaxPooling2D()(input_feature)
    max_pool = layers.Reshape((1, 1, channel))(max_pool)
    max_pool = shared_layer_one(max_pool)
    max_pool = shared_layer_two(max_pool)
    
    cbam_feature = layers.Add()([avg_pool, max_pool])
    cbam_feature = layers.Multiply()([input_feature, cbam_feature])
    
    return cbam_feature

def spatial_attention(input_feature, name=""):
    """Spatial Attention Module (SAM)"""
    kernel_size = 7
    
    avg_pool = layers.Lambda(lambda x: tf.reduce_mean(x, axis=3, keepdims=True))(input_feature)
    max_pool = layers.Lambda(lambda x: tf.reduce_max(x, axis=3, keepdims=True))(input_feature)
    concat = layers.Concatenate(axis=3)([avg_pool, max_pool])
    
    cbam_feature = layers.Conv2D(filters=1, kernel_size=kernel_size, strides=1, 
                                padding='same', activation='sigmoid', 
                                name=f'spatial_attention_conv_{name}')(concat)
    cbam_feature = layers.Multiply()([input_feature, cbam_feature])
    
    return cbam_feature

def cbam_block(cbam_feature, ratio=8, name=""):
    """CBAM: Convolutional Block Attention Module (Channel + Spatial)"""
    cbam_feature = channel_attention(cbam_feature, ratio, name=f"{name}_channel")
    cbam_feature = spatial_attention(cbam_feature, name=f"{name}_spatial")
    return cbam_feature

# ============================================================================
# LOSS FUNCTIONS
# ============================================================================

def focal_loss(y_true, y_pred, gamma=2.0, alpha=None, epsilon=1e-7):
    if alpha is None:
        alpha = [0.25, 1.0, 1.0]
    
    y_pred = K.clip(y_pred, epsilon, 1.0 - epsilon)
    focal_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        pt = y_pred_c
        focal_weight = K.pow(1.0 - pt, gamma)
        cross_entropy = -K.log(pt)
        focal_loss_c = alpha[c] * focal_weight * cross_entropy * y_true_c
        focal_loss_value += K.mean(focal_loss_c)
    
    return focal_loss_value

def enhanced_iou_loss(y_true, y_pred, smooth=1e-7):
    eiou_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        
        intersection = K.sum(y_true_c * y_pred_c, axis=[1, 2])
        union = K.sum(y_true_c, axis=[1, 2]) + K.sum(y_pred_c, axis=[1, 2]) - intersection
        iou = (intersection + smooth) / (union + smooth)
        
        height = K.cast(K.shape(y_true_c)[1], 'float32')
        width = K.cast(K.shape(y_true_c)[2], 'float32')
        
        y_coords = K.arange(0, height)
        x_coords = K.arange(0, width)
        y_grid = K.tile(K.reshape(y_coords, (-1, 1)), (1, K.cast(width, 'int32')))
        x_grid = K.tile(K.reshape(x_coords, (1, -1)), (K.cast(height, 'int32'), 1))
        y_grid = K.cast(y_grid, 'float32')
        x_grid = K.cast(x_grid, 'float32')
        
        true_mass = K.sum(y_true_c, axis=[1, 2]) + smooth
        true_center_y = K.sum(y_true_c * y_grid, axis=[1, 2]) / true_mass
        true_center_x = K.sum(y_true_c * x_grid, axis=[1, 2]) / true_mass
        
        pred_mass = K.sum(y_pred_c, axis=[1, 2]) + smooth
        pred_center_y = K.sum(y_pred_c * y_grid, axis=[1, 2]) / pred_mass
        pred_center_x = K.sum(y_pred_c * x_grid, axis=[1, 2]) / pred_mass
        
        center_distance = K.square(true_center_y - pred_center_y) + K.square(true_center_x - pred_center_x)
        diagonal = K.square(height) + K.square(width)
        center_penalty = center_distance / (diagonal + smooth)
        
        true_width = K.sqrt(K.sum(K.sum(y_true_c, axis=1), axis=1) + smooth)
        true_height = K.sqrt(K.sum(K.sum(y_true_c, axis=2), axis=1) + smooth)
        pred_width = K.sqrt(K.sum(K.sum(y_pred_c, axis=1), axis=1) + smooth)
        pred_height = K.sqrt(K.sum(K.sum(y_pred_c, axis=2), axis=1) + smooth)
        
        width_diff = K.square(pred_width - true_width)
        height_diff = K.square(pred_height - true_height)
        aspect_penalty = width_diff / (K.square(width) + smooth) + height_diff / (K.square(height) + smooth)
        
        eiou_c = 1.0 - iou + center_penalty + aspect_penalty
        eiou_loss_value += K.mean(eiou_c)
    
    return eiou_loss_value / 3.0

def focal_eiou_combined_loss(y_true, y_pred, focal_weight=1.0, eiou_weight=1.0, gamma=2.0, alpha=None):
    fl = focal_loss(y_true, y_pred, gamma=gamma, alpha=alpha)
    eiou = enhanced_iou_loss(y_true, y_pred)
    return focal_weight * fl + eiou_weight * eiou

# ============================================================================
# ENHANCED DECODER BLOCK WITH MINIMAL CBAM
# ============================================================================

def enhanced_decoder_block_with_cbam(x, skip_connection, filters, block_name, dropout_rate=0.3):
    """
    Enhanced decoder block with residual connections, dropout, and CBAM attention
    
    MINIMAL CBAM VERSION:
    - CBAM applied ONLY at the end of each decoder block
    - NO CBAM on skip connections (they come in raw)
    """
    x = layers.UpSampling2D((2, 2), name=f'{block_name}_upsample')(x)
    
    if skip_connection.shape[-1] != x.shape[-1]:
        skip_connection = layers.Conv2D(x.shape[-1], (1, 1), activation='relu', 
                                      padding='same', name=f'{block_name}_skip_align')(skip_connection)
        skip_connection = layers.BatchNormalization(name=f'{block_name}_skip_bn')(skip_connection)
    
    x = layers.Concatenate(name=f'{block_name}_concat')([x, skip_connection])
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv1')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn1')(x)
    x = layers.Dropout(dropout_rate, name=f'{block_name}_dropout')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv2')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn2')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv3')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn3')(x)
    
    residual = x
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv4')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn4')(x)
    
    x = layers.Add(name=f'{block_name}_residual')([x, residual])
    x = layers.Conv2D(filters, (1, 1), activation='relu', padding='same', name=f'{block_name}_conv_final')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn_final')(x)
    
    # CBAM applied ONLY here (at the end of decoder block)
    x = cbam_block(x, ratio=8, name=block_name)
    
    return x

# ============================================================================
# MODEL: MINIMAL CBAM VERSION (4 blocks only in decoder)
# ============================================================================

def build_combined_unet_minimal_cbam(input_shape=(256, 256, 3), num_classes=3, 
                                     use_deeper=False, dropout_rate=0.3):
    """
    Combined MobileNet-UNet with MINIMAL CBAM
    
    CBAM Placement (MINIMAL VERSION):
    - Skip connections: NO CBAM ❌
    - Bridge: NO CBAM ❌
    - Decoder blocks: YES (4 locations) ✅
    - Final layer: NO CBAM ❌
    Total: 4 CBAM blocks (vs 10 in full version)
    
    This reduces over-regularization while keeping attention in decoder
    where features are being refined for segmentation.
    """
    
    print(f"\nBuilding Combined UNet with MINIMAL CBAM...")
    print(f"  Deeper Architecture: {use_deeper}")
    print(f"  MC Dropout Rate: {dropout_rate}")
    print(f"  CBAM Attention: MINIMAL (4 blocks in decoder only)")
    
    inputs = layers.Input(input_shape, dtype='float32')
    backbone = MobileNetV2(input_tensor=inputs, weights='imagenet', include_top=False)
    
    # Get skip connections (NO CBAM on skips)
    skip_1 = backbone.get_layer('block_1_expand_relu').output  # 128x128
    skip_2 = backbone.get_layer('block_3_expand_relu').output  # 64x64
    skip_3 = backbone.get_layer('block_6_expand_relu').output  # 32x32
    skip_4 = backbone.get_layer('block_13_expand_relu').output # 16x16
    bridge = backbone.output  # 8x8
    
    # Deeper bridge (if enabled) - NO CBAM on bridge
    if use_deeper:
        bridge = layers.Conv2D(1024, (3, 3), activation='relu', padding='same')(bridge)
        bridge = layers.BatchNormalization()(bridge)
    
    # Apply dropout to bridge
    if dropout_rate > 0:
        bridge = layers.Dropout(dropout_rate, name='bridge_dropout')(bridge)
    
    # NO CBAM on bridge in minimal version
    
    if use_deeper:
        print("  Building deeper decoder with MINIMAL CBAM (decoder blocks only)...")
        # CBAM applied inside each enhanced_decoder_block_with_cbam
        x = enhanced_decoder_block_with_cbam(bridge, skip_4, 512, 'decoder_1', dropout_rate)
        x = enhanced_decoder_block_with_cbam(x, skip_3, 256, 'decoder_2', dropout_rate)
        x = enhanced_decoder_block_with_cbam(x, skip_2, 128, 'decoder_3', dropout_rate * 0.7)
        x = enhanced_decoder_block_with_cbam(x, skip_1, 64, 'decoder_4', dropout_rate * 0.5)
    else:
        print("  Building baseline decoder with MINIMAL CBAM...")
        # Baseline decoder with CBAM only at end of each block
        x = layers.UpSampling2D((2, 2))(bridge)
        x = layers.Concatenate()([x, skip_4])
        x = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        if dropout_rate > 0:
            x = layers.Dropout(dropout_rate)(x)
        x = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = cbam_block(x, ratio=8, name="dec1")
        
        x = layers.UpSampling2D((2, 2))(x)
        x = layers.Concatenate()([x, skip_3])
        x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        if dropout_rate > 0:
            x = layers.Dropout(dropout_rate)(x)
        x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = cbam_block(x, ratio=8, name="dec2")
        
        x = layers.UpSampling2D((2, 2))(x)
        x = layers.Concatenate()([x, skip_2])
        x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        if dropout_rate > 0:
            x = layers.Dropout(dropout_rate * 0.7)(x)
        x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = cbam_block(x, ratio=8, name="dec3")
        
        x = layers.UpSampling2D((2, 2))(x)
        x = layers.Concatenate()([x, skip_1])
        x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        if dropout_rate > 0:
            x = layers.Dropout(dropout_rate * 0.5)(x)
        x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = cbam_block(x, ratio=8, name="dec4")
    
    # Final upsampling - NO CBAM on final layer in minimal version
    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    
    # NO CBAM on final layer
    
    outputs = layers.Conv2D(num_classes, (1, 1), activation='softmax', dtype='float32')(x)
    
    model = models.Model(inputs, outputs)
    
    # Print configuration
    if dropout_rate > 0:
        dropout_layers = [layer for layer in model.layers if isinstance(layer, layers.Dropout)]
        print(f"\n  MC Dropout Configuration:")
        print(f"    Total Dropout Layers: {len(dropout_layers)}")
        print(f"    Dropout Rates: {[f'{layer.rate:.2f}' for layer in dropout_layers]}")
    
    cbam_count = sum(1 for layer in model.layers if 'channel_attention' in layer.name or 'spatial_attention' in layer.name)
    print(f"\n  CBAM Configuration (MINIMAL):")
    print(f"    Total CBAM Components: {cbam_count}")
    print(f"    CBAM Locations: Decoder blocks only (4)")
    print(f"    Removed CBAM from: Skip connections, Bridge, Final layer")
    
    return model

# ============================================================================
# METRICS
# ============================================================================

def dice_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    return (2. * intersection + smooth) / (K.sum(y_true_class) + K.sum(y_pred_class) + smooth)

def dice_class_0(y_true, y_pred): return dice_coef_class(y_true, y_pred, 0)
def dice_class_1(y_true, y_pred): return dice_coef_class(y_true, y_pred, 1)
def dice_class_2(y_true, y_pred): return dice_coef_class(y_true, y_pred, 2)

def iou_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    union = K.sum(y_true_class) + K.sum(y_pred_class) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_class_0(y_true, y_pred): return iou_coef_class(y_true, y_pred, 0)
def iou_class_1(y_true, y_pred): return iou_coef_class(y_true, y_pred, 1)
def iou_class_2(y_true, y_pred): return iou_coef_class(y_true, y_pred, 2)

# ============================================================================
# VISUALIZATION FUNCTIONS
# ============================================================================

def plot_training_history(history, model_name, save_dir='results'):
    """Plot training history: loss and accuracy curves"""
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    
    axes[0].plot(history.history['loss'], label='Training Loss', linewidth=2)
    axes[0].plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
    axes[0].set_title(f'{model_name} - Loss Over Epochs', fontsize=14, fontweight='bold')
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('Loss', fontsize=12)
    axes[0].legend(fontsize=10)
    axes[0].grid(True, alpha=0.3)
    
    axes[1].plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
    axes[1].plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
    axes[1].set_title(f'{model_name} - Accuracy Over Epochs', fontsize=14, fontweight='bold')
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('Accuracy', fontsize=12)
    axes[1].legend(fontsize=10)
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(f"{save_dir}/{model_name}_training_curves.png", dpi=300, bbox_inches='tight')
    print(f"\u2713 Training curves saved: {save_dir}/{model_name}_training_curves.png")
    plt.show()
    plt.close()

def plot_confusion_matrices(y_true, y_pred, model_name, save_dir='results'):
    """Plot confusion matrix and normalized confusion matrix"""
    y_true_labels = np.argmax(y_true, axis=-1).flatten()
    y_pred_labels = np.argmax(y_pred, axis=-1).flatten()
    
    cm = confusion_matrix(y_true_labels, y_pred_labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    class_names = ['Background', 'Disc', 'Cup']
    
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[0], cbar_kws={'label': 'Count'})
    axes[0].set_title(f'{model_name}\\nConfusion Matrix', fontsize=14, fontweight='bold')
    axes[0].set_ylabel('True Label', fontsize=12)
    axes[0].set_xlabel('Predicted Label', fontsize=12)
    
    sns.heatmap(cm_normalized, annot=True, fmt='.3f', cmap='Greens',
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[1], cbar_kws={'label': 'Proportion'})
    axes[1].set_title(f'{model_name}\\nNormalized Confusion Matrix', fontsize=14, fontweight='bold')
    axes[1].set_ylabel('True Label', fontsize=12)
    axes[1].set_xlabel('Predicted Label', fontsize=12)
    
    plt.tight_layout()
    plt.savefig(f"{save_dir}/{model_name}_confusion_matrices.png", dpi=300, bbox_inches='tight')
    print(f"\u2713 Confusion matrices saved: {save_dir}/{model_name}_confusion_matrices.png")
    plt.show()
    plt.close()
    
    print(f"\\nConfusion Matrix:")
    print(cm)
    print(f"\\nNormalized Confusion Matrix:")
    print(np.round(cm_normalized, 3))
    
    return cm, cm_normalized

# ============================================================================
# MC DROPOUT
# ============================================================================

def mc_dropout_predict(model, X, num_samples=15, batch_size=4, verbose=True):
    """MC Dropout prediction using training=True flag"""
    if verbose:
        print(f"\nRunning MC Dropout with {num_samples} stochastic forward passes...")
    
    predictions = []
    num_batches = int(np.ceil(len(X) / batch_size))
    
    for i in range(num_samples):
        if verbose and (i + 1) % 5 == 0:
            print(f"  Completed: {i+1}/{num_samples} forward passes")
        
        batch_preds = []
        for batch_idx in range(num_batches):
            start_idx = batch_idx * batch_size
            end_idx = min(start_idx + batch_size, len(X))
            X_batch = X[start_idx:end_idx]
            
            pred_batch = model(X_batch, training=True)
            batch_preds.append(pred_batch.numpy())
        
        pred = np.concatenate(batch_preds, axis=0)
        predictions.append(pred)
        
        if (i + 1) % 5 == 0:
            gc.collect()
    
    all_preds = np.array(predictions)
    mean_pred = np.mean(all_preds, axis=0)
    std_pred = np.std(all_preds, axis=0)
    
    del all_preds
    gc.collect()
    
    if verbose:
        print(f"✓ MC Dropout completed")
    
    return mean_pred, std_pred

# ============================================================================
# TRAINING
# ============================================================================

def train_model(X_train, y_train, X_val, y_val, X_test, y_test, model_name, 
               use_focal_eiou=False, use_deeper=False, dropout_rate=0.0,
               augment=None, save_dir='results'):
    """Train model with minimal CBAM"""
    print(f"\n{'='*80}")
    print(f"TRAINING: {model_name}")
    print(f"{'='*80}")
    print(f"  Focal-EIoU Loss: {'✓' if use_focal_eiou else '✗'}")
    print(f"  Deeper Decoder: {'✓' if use_deeper else '✗'}")
    print(f"  MC Dropout: {'✓ (rate=' + str(dropout_rate) + ')' if dropout_rate > 0 else '✗'}")
    print(f"  CBAM Attention: ✓ MINIMAL (4 decoder blocks)")
    
    K.clear_session()
    
    model = build_combined_unet_minimal_cbam(use_deeper=use_deeper, dropout_rate=dropout_rate)
    
    param_count = model.count_params()
    print(f"  Total Parameters: {param_count:,}")
    
    if use_focal_eiou:
        loss_fn = focal_eiou_combined_loss
    else:
        loss_fn = "categorical_crossentropy"
    
    initial_lr = 5e-4 if use_deeper else 1e-3
    model.compile(
        optimizer=optimizers.Adam(learning_rate=initial_lr),
        loss=loss_fn,
        metrics=[dice_coef_multiclass, dice_class_0, dice_class_1, dice_class_2,
                "accuracy", iou_coef_multiclass, iou_class_0, iou_class_1, iou_class_2]
    )
    
    checkpoint = ModelCheckpoint(f"{save_dir}/{model_name}.keras", save_best_only=True, verbose=1, 
                                monitor='val_loss', mode='min')
    reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=3, 
                                  verbose=1, mode='min', min_lr=1e-7)
    early_stop = EarlyStopping(monitor="val_loss", patience=10, verbose=1, 
                              restore_best_weights=True, mode='min')
    
    batch_size = 4 if use_deeper else 6
    steps_train = X_train.shape[0] // batch_size
    steps_val = X_val.shape[0] // batch_size
    
    try:
        history = model.fit(
            data_generator(X_train, y_train, batch_size, augment),
            validation_data=data_generator(X_val, y_val, batch_size, None),
            steps_per_epoch=steps_train,
            validation_steps=steps_val,
            epochs=50,
            callbacks=[checkpoint, reduce_lr, early_stop],
            verbose=1
        )
    except Exception as e:
        print(f"✗ Error: {e}. Retrying with smaller batch...")
        batch_size = 2 if use_deeper else 4
        steps_train = X_train.shape[0] // batch_size
        steps_val = X_val.shape[0] // batch_size
        
        history = model.fit(
            data_generator(X_train, y_train, batch_size, augment),
            validation_data=data_generator(X_val, y_val, batch_size, None),
            steps_per_epoch=steps_train,
            validation_steps=steps_val,
            epochs=50,
            callbacks=[checkpoint, reduce_lr, early_stop],
            verbose=1
        )
    
    print(f" Training completed")
    
    plot_training_history(history, model_name, save_dir)
    
    return model, history, param_count

# ============================================================================
# EVALUATION
# ============================================================================

def evaluate_model(model, X_test, y_test, model_name, run_mc_dropout=False, save_dir='results'):
    """Evaluate model"""
    print(f"\n{'='*80}")
    print(f"EVALUATION: {model_name}")
    print(f"{'='*80}")
    
    y_test_cat = np.array([to_categorical(mask, num_classes=3) for mask in y_test])
    
    test_metrics = model.evaluate(X_test, y_test_cat, verbose=0, batch_size=4)
    y_pred = model.predict(X_test, verbose=0, batch_size=4)
    
    plot_confusion_matrices(y_test_cat, y_pred, model_name, save_dir)
    
    # Calculate precision, recall, F1 score
    y_true_labels = np.argmax(y_test_cat, axis=-1).flatten()
    y_pred_labels = np.argmax(y_pred, axis=-1).flatten()
    
    precision = precision_score(y_true_labels, y_pred_labels, average=None, zero_division=0)
    recall = recall_score(y_true_labels, y_pred_labels, average=None, zero_division=0)
    f1 = f1_score(y_true_labels, y_pred_labels, average=None, zero_division=0)
    
    print(f"\nPrecision, Recall, F1 Score per class:")
    class_names = ["Background", "Disc", "Cup"]
    for idx, cname in enumerate(class_names):
        print(f"  {cname}: Precision={precision[idx]:.4f}, Recall={recall[idx]:.4f}, F1={f1[idx]:.4f}")
    
    print(f"\nMacro-averaged metrics:")
    print(f"  Precision: {np.mean(precision):.4f}")
    print(f"  Recall: {np.mean(recall):.4f}")
    print(f"  F1 Score: {np.mean(f1):.4f}")
    
    class_names = ["Background", "Disc", "Cup"]
    results = {'standard': {}}
    
    for cidx, cname in enumerate(class_names):
        y_true_c = (np.argmax(y_test_cat, axis=-1) == cidx).astype(np.float32)
        y_pred_c = (np.argmax(y_pred, axis=-1) == cidx).astype(np.float32)
        
        intersection = np.sum(y_true_c * y_pred_c)
        dice = (2. * intersection + 1e-7) / (np.sum(y_true_c) + np.sum(y_pred_c) + 1e-7)
        union = np.sum(y_true_c) + np.sum(y_pred_c) - intersection
        iou = (intersection + 1e-7) / (union + 1e-7)
        
        results['standard'][cname] = {'dice': dice, 'iou': iou}
        print(f"  {cname}: Dice={dice:.4f}, IoU={iou:.4f}")
    
    if run_mc_dropout:
        print("\nMC Dropout Evaluation:")
        mean_pred, std_pred = mc_dropout_predict(model, X_test[:100], num_samples=10, verbose=True)
        results['mc_dropout'] = {}
        for cidx, cname in enumerate(class_names):
            mean_std = np.mean(std_pred[:, :, :, cidx])
            results['mc_dropout'][cname] = {'mean_uncertainty': mean_std}
            print(f"  {cname} uncertainty: {mean_std:.4f}")
    
    return results

# ============================================================================
# MAIN
# ============================================================================

if __name__ == "__main__":
    gpu_available = configure_gpu()
    root_dir = "/kaggle/input/refuge/REFUGE/"
    train_aug = setup_augmentations()
    save_dir = "results"
    os.makedirs(save_dir, exist_ok=True)
    
    print(f"\n{'='*100}")
    print(f"{'EXPERIMENT: DEEPER + FOCAL-EIOU + MC DROPOUT + MINIMAL CBAM':^100s}")
    print(f"{'='*100}")
    
    all_images, all_masks = load_all_data(root_dir)
    (X_train, y_train), (X_val, y_val), (X_test, y_test) = create_new_split(all_images, all_masks)
    
    all_results = {}
    all_params = {}
    
    print(f"\n{'='*80}")
    print("EXPERIMENT: FULL COMBINATION + MINIMAL CBAM (4 blocks)")
    print(f"{'='*80}")
    
    model, history, params = train_model(
        X_train, y_train, X_val, y_val, X_test, y_test,
        "FULL_with_MINIMAL_CBAM",
        use_focal_eiou=True, use_deeper=True, dropout_rate=0.3,
        augment=train_aug, save_dir=save_dir
    )
    
    all_results['FULL + MINIMAL CBAM'] = evaluate_model(model, X_test, y_test, "Full with Minimal CBAM", run_mc_dropout=True, save_dir=save_dir)
    all_params['FULL + MINIMAL CBAM'] = params
    
    print(f"\n{'='*100}")
    print(f"{'✓ EXPERIMENT COMPLETED!':^100s}")
    print(f"{'='*100}")
    
    print("\nFinal Results:")
    for model_name, results in all_results.items():
        disc_dice = results['standard']['Disc']['dice']
        cup_dice = results['standard']['Cup']['dice']
        print(f"\n{model_name}:")
        print(f"  Parameters: {all_params[model_name]:,}")
        print(f"  Disc Dice: {disc_dice:.4f}")
        print(f"  Cup Dice: {cup_dice:.4f}")
        print(f"  Overall: {(disc_dice + cup_dice)/2:.4f}")
    
    print(f"\n{'='*100}\n")
# Out:
# 2025-11-17 11:01:04.184575: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763377264.374989      38 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763377264.429181      38 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Configuring GPU settings...
# ✓ GPU found: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
#   GPU device name: /device:GPU:0
#
# ====================================================================================================
#                     EXPERIMENT: DEEPER + FOCAL-EIOU + MC DROPOUT + MINIMAL CBAM
# ====================================================================================================
# Loading train data...
# I0000 00:00:1763377280.617665      38 gpu_device.cc:2022] Created device /device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
#   train: 400 samples
# Loading val data...
#   val: 400 samples
# Loading test data...
#   test: 400 samples
# Split - Train: 600, Val: 200, Test: 400
#
# ================================================================================
# EXPERIMENT: FULL COMBINATION + MINIMAL CBAM (4 blocks)
# ================================================================================
#
# ================================================================================
# TRAINING: FULL_with_MINIMAL_CBAM
# ================================================================================
#   Focal-EIoU Loss: ✓
#   Deeper Decoder: ✓
#   MC Dropout: ✓ (rate=0.3)
#   CBAM Attention: ✓ MINIMAL (4 decoder blocks)
#
# Building Combined UNet with MINIMAL CBAM...
#   Deeper Architecture: True
#   MC Dropout Rate: 0.3
#   CBAM Attention: MINIMAL (4 blocks in decoder only)
# I0000 00:00:1763377345.547410      38 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
#   Building deeper decoder with MINIMAL CBAM (decoder blocks only)...
#
#   MC Dropout Configuration:
#     Total Dropout Layers: 5
#     Dropout Rates: ['0.30', '0.30', '0.30', '0.21', '0.15']
#
#   CBAM Configuration (MINIMAL):
#     Total CBAM Components: 12
#     CBAM Locations: Decoder blocks only (4)
#     Removed CBAM from: Skip connections, Bridge, Final layer
#   Total Parameters: 37,219,911
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763377424.242288     100 service.cc:148] XLA service 0x7b79c4025530 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1
- dice_coef_multiclass: 0.9976 - iou_class_0: 0.9985 - iou_class_1: 0.8299 - iou_class_2: 0.8180 - iou_coef_multiclass: 0.9951 - loss: 0.1341
# Epoch 9: val_loss did not improve from 0.15938
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9067 - dice_class_2: 0.8992 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9985 - iou_class_1: 0.8299 - iou_class_2: 0.8180 - iou_coef_multiclass: 0.9951 - loss: 0.1342 - val_accuracy: 0.9972 - val_dice_class_0: 0.9991 - val_dice_class_1: 0.8814 - val_dice_class_2: 0.8726 - val_dice_coef_multiclass: 0.9972 - val_iou_class_0: 0.9983 - val_iou_class_1: 0.7893 - val_iou_class_2: 0.7759 - val_iou_coef_multiclass: 0.9944 - val_loss: 0.1618 - learning_rate: 5.0000e-04
# Epoch 10/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9069 - dice_class_2: 0.8975 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9985 - iou_class_1: 0.8305 - iou_class_2: 0.8155 - iou_coef_multiclass: 0.9951 - loss: 0.1327
# Epoch 10: val_loss did not improve from 0.15938
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 130ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9069 - dice_class_2: 0.8975 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9985 - iou_class_1: 0.8305 - iou_class_2: 0.8155 - iou_coef_multiclass: 0.9951 - loss: 0.1327 - val_accuracy: 0.9973 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8832 - val_dice_class_2: 0.8722 - val_dice_coef_multiclass: 0.9973 - val_iou_class_0: 0.9983 - val_iou_class_1: 0.7917 - val_iou_class_2: 0.7744 - val_iou_coef_multiclass: 0.9945 - val_loss: 0.1626 - learning_rate: 5.0000e-04
# Epoch 11/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9093 - dice_class_2: 0.9027 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9985 - iou_class_1: 0.8342 - iou_class_2: 0.8243 - iou_coef_multiclass: 0.9953 - loss: 0.1283
# Epoch 11: val_loss did not improve from 0.15938
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 130ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9093 - dice_class_2: 0.9027 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9985 - iou_class_1: 0.8342 - iou_class_2: 0.8243 - iou_coef_multiclass: 0.9953 - loss: 0.1283 - val_accuracy: 0.9971 - val_dice_class_0: 0.9991 - val_dice_class_1: 0.8712 - val_dice_class_2: 0.8633 - val_dice_coef_multiclass: 0.9970 - val_iou_class_0: 0.9982 - val_iou_class_1: 0.7730 - val_iou_class_2: 0.7616 - val_iou_coef_multiclass: 0.9941 - val_loss: 0.1798 - learning_rate: 5.0000e-04
# Epoch 12/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9980 - dice_class_0: 0.9993 - dice_class_1: 0.9199 - dice_class_2: 0.9165 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8520 - iou_class_2: 0.8465 - iou_coef_multiclass: 0.9959 - loss: 0.1139
# Epoch 12: val_loss improved from 0.15938 to 0.15482, saving model to results/FULL_with_MINIMAL_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 152ms/step - accuracy: 0.9980 - dice_class_0: 0.9993 - dice_class_1: 0.9199 - dice_class_2: 0.9165 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8520 - iou_class_2: 0.8465 - iou_coef_multiclass: 0.9959 - loss: 0.1139 - val_accuracy: 0.9974 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8882 - val_dice_class_2: 0.8783 - val_dice_coef_multiclass: 0.9973 - val_iou_class_0: 0.9983 - val_iou_class_1: 0.8004 - val_iou_class_2: 0.7844 - val_iou_coef_multiclass: 0.9946 - val_loss: 0.1548 - learning_rate: 1.5000e-04
# Epoch 13/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9234 - dice_class_2: 0.9200 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8580 - iou_class_2: 0.8527 - iou_coef_multiclass: 0.9960 - loss: 0.1091
# Epoch 13: val_loss improved from 0.15482 to 0.13978, saving model to results/FULL_with_MINIMAL_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 152ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9234 - dice_class_2: 0.9200 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8580 - iou_class_2: 0.8527 - iou_coef_multiclass: 0.9960 - loss: 0.1091 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9015 - val_dice_class_2: 0.8870 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8212 - val_iou_class_2: 0.7980 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1398 - learning_rate: 1.5000e-04
# Epoch 14/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9228 - dice_class_2: 0.9220 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8572 - iou_class_2: 0.8559 - iou_coef_multiclass: 0.9961 - loss: 0.1084
# Epoch 14: val_loss did not improve from 0.13978
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 130ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9228 - dice_class_2: 0.9220 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8572 - iou_class_2: 0.8559 - iou_coef_multiclass: 0.9961 - loss: 0.1084 - val_accuracy: 0.9974 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8943 - val_dice_class_2: 0.8690 - val_dice_coef_multiclass: 0.9974 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.8103 - val_iou_class_2: 0.7703 - val_iou_coef_multiclass: 0.9948 - val_loss: 0.1550 - learning_rate: 1.5000e-04
# Epoch 15/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9231 - dice_class_2: 0.9217 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8577 - iou_class_2: 0.8554 - iou_coef_multiclass: 0.9960 - loss: 0.1088
# Epoch 15: val_loss improved from 0.13978 to 0.13836, saving model to results/FULL_with_MINIMAL_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 152ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9231 - dice_class_2: 0.9217 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8577 - iou_class_2: 0.8554 - iou_coef_multiclass: 0.9960 - loss: 0.1088 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9020 - val_dice_class_2: 0.8926 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8226 - val_iou_class_2: 0.8070 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1384 - learning_rate: 1.5000e-04
# Epoch 16/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9283 - dice_class_2: 0.9279 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8664 - iou_class_2: 0.8660 - iou_coef_multiclass: 0.9963 - loss: 0.1016
# Epoch 16: val_loss did not improve from 0.13836
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 130ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9283 - dice_class_2: 0.9279 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8664 - iou_class_2: 0.8660 - iou_coef_multiclass: 0.9963 - loss: 0.1016 - val_accuracy: 0.9975 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8959 - val_dice_class_2: 0.8678 - val_dice_coef_multiclass: 0.9974 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.8125 - val_iou_class_2: 0.7682 - val_iou_coef_multiclass: 0.9948 - val_loss: 0.1541 - learning_rate: 1.5000e-04
# Epoch 17/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9299 - dice_class_2: 0.9292 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8693 - iou_class_2: 0.8687 - iou_coef_multiclass: 0.9963 - loss: 0.0987
# Epoch 17: val_loss did not improve from 0.13836
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 130ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9299 - dice_class_2: 0.9292 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8693 - iou_class_2: 0.8686 - iou_coef_multiclass: 0.9963 - loss: 0.0987 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9017 - val_dice_class_2: 0.8792 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8221 - val_iou_class_2: 0.7857 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1428 - learning_rate: 1.5000e-04
# Epoch 18/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9304 - dice_class_2: 0.9304 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8702 - iou_class_2: 0.8705 - iou_coef_multiclass: 0.9964 - loss: 0.0977
# Epoch 18: val_loss did not improve from 0.13836
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 4.500000213738531e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 130ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9304 - dice_class_2: 0.9304 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8701 - iou_class_2: 0.8705 - iou_coef_multiclass: 0.9964 - loss: 0.0977 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9036 - val_dice_class_2: 0.8916 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8250 - val_iou_class_2: 0.8054 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1385 - learning_rate: 1.5000e-04
# Epoch 19/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9352 - dice_class_2: 0.9377 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8785 - iou_class_2: 0.8832 - iou_coef_multiclass: 0.9966 - loss: 0.0903
# Epoch 19: val_loss did not improve from 0.13836
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 130ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9352 - dice_class_2: 0.9377 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8785 - iou_class_2: 0.8832 - iou_coef_multiclass: 0.9966 - loss: 0.0903 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9055 - val_dice_class_2: 0.8889 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8279 - val_iou_class_2: 0.8008 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1394 - learning_rate: 4.5000e-05
# Epoch 20/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9357 - dice_class_2: 0.9370 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8795 - iou_class_2: 0.8819 - iou_coef_multiclass: 0.9966 - loss: 0.0901
# Epoch 20: val_loss improved from 0.13836 to 0.13589, saving model to results/FULL_with_MINIMAL_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 151ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9357 - dice_class_2: 0.9369 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8795 - iou_class_2: 0.8819 - iou_coef_multiclass: 0.9966 - loss: 0.0901 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9066 - val_dice_class_2: 0.8900 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8298 - val_iou_class_2: 0.8032 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1359 - learning_rate: 4.5000e-05
# Epoch 21/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9356 - dice_class_2: 0.9375 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8793 - iou_class_2: 0.8827 - iou_coef_multiclass: 0.9967 - loss: 0.0898
# Epoch 21: val_loss did not improve from 0.13589
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9356 - dice_class_2: 0.9375 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8793 - iou_class_2: 0.8827 - iou_coef_multiclass: 0.9967 - loss: 0.0898 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9055 - val_dice_class_2: 0.8895 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8281 - val_iou_class_2: 0.8025 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1395 - learning_rate: 4.5000e-05
# Epoch 22/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9385 - dice_class_2: 0.9391 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8844 - iou_class_2: 0.8856 - iou_coef_multiclass: 0.9968 - loss: 0.0873
# Epoch 22: val_loss improved from 0.13589 to 0.13493, saving model to results/FULL_with_MINIMAL_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 151ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9385 - dice_class_2: 0.9391 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8844 - iou_class_2: 0.8856 - iou_coef_multiclass: 0.9968 - loss: 0.0873 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9074 - val_dice_class_2: 0.8932 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8312 - val_iou_class_2: 0.8082 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1349 - learning_rate: 4.5000e-05
# Epoch 23/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9376 - dice_class_2: 0.9417 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8828 - iou_class_2: 0.8901 - iou_coef_multiclass: 0.9968 - loss: 0.0867
# Epoch 23: val_loss did not improve from 0.13493
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 130ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9376 - dice_class_2: 0.9417 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8828 - iou_class_2: 0.8901 - iou_coef_multiclass: 0.9968 - loss: 0.0867 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9046 - val_dice_class_2: 0.8865 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8269 - val_iou_class_2: 0.7976 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1400 - learning_rate: 4.5000e-05
# Epoch 24/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9367 - dice_class_2: 0.9391 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8812 - iou_class_2: 0.8857 - iou_coef_multiclass: 0.9968 - loss: 0.0887
# Epoch 24: val_loss did not improve from 0.13493
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9367 - dice_class_2: 0.9391 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8812 - iou_class_2: 0.8857 - iou_coef_multiclass: 0.9968 - loss: 0.0887 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9052 - val_dice_class_2: 0.8855 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8277 - val_iou_class_2: 0.7957 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1410 - learning_rate: 4.5000e-05
# Epoch 25/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9398 - dice_class_2: 0.9420 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8868 - iou_class_2: 0.8908 - iou_coef_multiclass: 0.9969 - loss: 0.0848
# Epoch 25: val_loss improved from 0.13493 to 0.13215, saving model to results/FULL_with_MINIMAL_CBAM.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 152ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9398 - dice_class_2: 0.9420 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8868 - iou_class_2: 0.8908 - iou_coef_multiclass: 0.9969 - loss: 0.0848 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9088 - val_dice_class_2: 0.8940 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8336 - val_iou_class_2: 0.8096 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1321 - learning_rate: 4.5000e-05
# Epoch 26/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9390 - dice_class_2: 0.9414 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8854 - iou_class_2: 0.8898 - iou_coef_multiclass: 0.9969 - loss: 0.0855
# Epoch 26: val_loss did not improve from 0.13215
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 130ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9390 - dice_class_2: 0.9414 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8854 - iou_class_2: 0.8899 - iou_coef_multiclass: 0.9969 - loss: 0.0855 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9054 - val_dice_class_2: 0.8889 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8278 - val_iou_class_2: 0.8014 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1387 - learning_rate: 4.5000e-05
# Epoch 27/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9407 - dice_class_2: 0.9426 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8884 - iou_class_2: 0.8919 - iou_coef_multiclass: 0.9969 - loss: 0.0831
# Epoch 27: val_loss did not improve from 0.13215
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9407 - dice_class_2: 0.9426 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8884 - iou_class_2: 0.8919 - iou_coef_multiclass: 0.9969 - loss: 0.0831 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9029 - val_dice_class_2: 0.8894 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8236 - val_iou_class_2: 0.8017 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1417 - learning_rate: 4.5000e-05
# Epoch 28/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9372 - dice_class_2: 0.9396 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8823 - iou_class_2: 0.8866 - iou_coef_multiclass: 0.9968 - loss: 0.0873
# Epoch 28: val_loss did not improve from 0.13215
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1.3500000204658135e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9373 - dice_class_2: 0.9396 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8824 - iou_class_2: 0.8866 - iou_coef_multiclass: 0.9968 - loss: 0.0873 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9088 - val_dice_class_2: 0.8932 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8338 - val_iou_class_2: 0.8080 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1345 - learning_rate: 4.5000e-05
# Epoch 29/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9416 - dice_class_2: 0.9426 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8899 - iou_class_2: 0.8918 - iou_coef_multiclass: 0.9970 - loss: 0.0827
# Epoch 29: val_loss did not improve from 0.13215
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9416 - dice_class_2: 0.9426 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8899 - iou_class_2: 0.8918 - iou_coef_multiclass: 0.9970 - loss: 0.0827 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9099 - val_dice_class_2: 0.8914 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8352 - val_iou_class_2: 0.8052 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1342 - learning_rate: 1.3500e-05
# Epoch 30/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9407 - dice_class_2: 0.9456 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8883 - iou_class_2: 0.8971 - iou_coef_multiclass: 0.9969 - loss: 0.0811
# Epoch 30: val_loss did not improve from 0.13215
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 130ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9407 - dice_class_2: 0.9456 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8883 - iou_class_2: 0.8971 - iou_coef_multiclass: 0.9969 - loss: 0.0811 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9065 - val_dice_class_2: 0.8944 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8299 - val_iou_class_2: 0.8103 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1349 - learning_rate: 1.3500e-05
# Epoch 31/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9406 - dice_class_2: 0.9446 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8881 - iou_class_2: 0.8953 - iou_coef_multiclass: 0.9970 - loss: 0.0814
# Epoch 31: val_loss did not improve from 0.13215
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 4.050000006827758e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9406 - dice_class_2: 0.9446 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8881 - iou_class_2: 0.8953 - iou_coef_multiclass: 0.9970 - loss: 0.0815 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9055 - val_dice_class_2: 0.8919 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8280 - val_iou_class_2: 0.8064 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1382 - learning_rate: 1.3500e-05
# Epoch 32/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9406 - dice_class_2: 0.9453 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8882 - iou_class_2: 0.8966 - iou_coef_multiclass: 0.9970 - loss: 0.0821
# Epoch 32: val_loss did not improve from 0.13215
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9406 - dice_class_2: 0.9453 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8882 - iou_class_2: 0.8966 - iou_coef_multiclass: 0.9970 - loss: 0.0821 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9057 - val_dice_class_2: 0.8909 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8285 - val_iou_class_2: 0.8047 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1393 - learning_rate: 4.0500e-06
# Epoch 33/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9434 - dice_class_2: 0.9451 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8930 - iou_class_2: 0.8963 - iou_coef_multiclass: 0.9971 - loss: 0.0796
# Epoch 33: val_loss did not improve from 0.13215
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9434 - dice_class_2: 0.9451 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8930 - iou_class_2: 0.8963 - iou_coef_multiclass: 0.9971 - loss: 0.0796 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9070 - val_dice_class_2: 0.8871 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8306 - val_iou_class_2: 0.7987 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1372 - learning_rate: 4.0500e-06
# Epoch 34/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9428 - dice_class_2: 0.9473 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8921 - iou_class_2: 0.9003 - iou_coef_multiclass: 0.9971 - loss: 0.0786
# Epoch 34: val_loss did not improve from 0.13215
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.2149999747634864e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 20s 130ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9428 - dice_class_2: 0.9473 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8921 - iou_class_2: 0.9003 - iou_coef_multiclass: 0.9971 - loss: 0.0786 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9109 - val_dice_class_2: 0.8930 - val_dice_coef_multiclass: 0.9979 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8368 - val_iou_class_2: 0.8076 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1337 - learning_rate: 4.0500e-06
# Epoch 35/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9430 - dice_class_2: 0.9460 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8924 - iou_class_2: 0.8980 - iou_coef_multiclass: 0.9971 - loss: 0.0790
# Epoch 35: val_loss did not improve from 0.13215
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 129ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9430 - dice_class_2: 0.9460 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8924 - iou_class_2: 0.8980 - iou_coef_multiclass: 0.9971 - loss: 0.0790 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9051 - val_dice_class_2: 0.8924 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8273 - val_iou_class_2: 0.8069 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1363 - learning_rate: 1.2150e-06
# Epoch 35: early stopping
# Restoring model weights from the end of the best epoch: 25.
#  Training completed
# ✓ Training curves saved: results/FULL_with_MINIMAL_CBAM_training_curves.png
# ================================================================================
# EVALUATION: Full with Minimal CBAM
# ================================================================================
# ✓ Confusion matrices saved: results/Full with Minimal CBAM_confusion_matrices.png
# \nConfusion Matrix:
# [[25769826    15164        0]
#  [   17781   287305     9985]
#  [      29    13883   100427]]
# \nNormalized Confusion Matrix:
# [[0.999 0.001 0.   ]
#  [0.056 0.912 0.032]
#  [0.    0.121 0.878]]
#
# Precision, Recall, F1 Score per class:
#   Background: Precision=0.9993, Recall=0.9994, F1=0.9994
#   Disc: Precision=0.9082, Recall=0.9119, F1=0.9100
#   Cup: Precision=0.9096, Recall=0.8783, F1=0.8937
#
# Macro-averaged metrics:
#   Precision: 0.9390
#   Recall: 0.9299
#   F1 Score: 0.9344
#   Background: Dice=0.9994, IoU=0.9987
#   Disc: Dice=0.9100, IoU=0.8349
#   Cup: Dice=0.8937, IoU=0.8078
#
# MC Dropout Evaluation:
#
# Running MC Dropout with 10 stochastic forward passes...
#   Completed: 5/10 forward passes
#   Completed: 10/10 forward passes
# ✓ MC Dropout completed
#   Background uncertainty: 0.0003
#   Disc uncertainty: 0.0004
#   Cup uncertainty: 0.0002
#
# ====================================================================================================
#                                       ✓ EXPERIMENT COMPLETED!
# ====================================================================================================
#
# Final Results:
#
# FULL + MINIMAL CBAM:
#   Parameters: 37,219,911
#   Disc Dice: 0.9100
#   Cup Dice: 0.8937
#   Overall: 0.9018
#
# ====================================================================================================
