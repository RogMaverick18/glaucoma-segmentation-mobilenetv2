# %%
"""
COMBINED ADVANCED MOBILENET-UNET WITH DECODER-ONLY ECA ATTENTION
==================================================================
This combines:
1. Deeper decoder architecture with enhanced blocks
2. Focal-EIoU loss
3. MC Dropout for uncertainty estimation
4. ECA (Efficient Channel Attention) - DECODER-ONLY VERSION
   - Applied ONLY to: Decoder blocks (4 locations)
   - REMOVED from: Skip connections, bridge, final layer
   - This applies attention to decoder features after skip concatenation

STRATEGY: Place ECA only in decoder blocks to refine decoder features
after they merge with encoder skip connections.
"""

import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, backend as K
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import albumentations as A
import warnings
import gc
warnings.filterwarnings('ignore')

plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# ============================================================================
# HELPER FUNCTIONS
# ============================================================================

def configure_gpu():
    """Configure GPU settings for optimal performance"""
    print("Configuring GPU settings...")
    physical_devices = tf.config.list_physical_devices('GPU')
    if physical_devices:
        try:
            for gpu in physical_devices:
                tf.config.experimental.set_memory_growth(gpu, True)
            tf.config.set_visible_devices(physical_devices[0], 'GPU')
            print(f"✓ GPU found: {physical_devices}")
            return True
        except RuntimeError as e:
            print(f"✗ GPU configuration error: {e}")
            return False
    else:
        print("✗ No GPU found, using CPU")
        return False

def load_images_masks(images_folder, masks_folder, img_size=(256,256)):
    """Load images and masks from folders"""
    images, masks = [], []
    image_files = sorted(os.listdir(images_folder))
    mask_files = sorted(os.listdir(masks_folder))
    mask_dict = {os.path.splitext(f)[0]: f for f in mask_files}
    
    for img_file in image_files:
        base = os.path.splitext(img_file)[0]
        if base in mask_dict:
            img = cv2.imread(os.path.join(images_folder, img_file))
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, img_size) / 255.0
            
            mask = cv2.imread(os.path.join(masks_folder, mask_dict[base]), cv2.IMREAD_GRAYSCALE)
            mask = cv2.resize(mask, img_size)
            unique_vals = np.unique(mask)
            if len(unique_vals) > 3 or np.max(unique_vals) > 2:
                mask = np.clip(mask // 85, 0, 2).astype(np.uint8)
            
            images.append(img)
            masks.append(mask)
    
    return np.array(images, dtype=np.float32), np.array(masks, dtype=np.uint8)

def load_all_data(root_dir):
    """Load all data from existing splits and merge"""
    all_images, all_masks = [], []
    for split in ["train", "val", "test"]:
        print(f"Loading {split} data...")
        imgs, msks = load_images_masks(
            os.path.join(root_dir, split, "Images"),
            os.path.join(root_dir, split, "Masks")
        )
        all_images.append(imgs)
        all_masks.append(msks)
        print(f"  {split}: {imgs.shape[0]} samples")
    
    all_images = np.concatenate(all_images, axis=0)
    all_masks = np.concatenate(all_masks, axis=0)
    return all_images, all_masks

def create_new_split(all_images, all_masks):
    """Create new split: 600 train, 200 val, 400 test"""
    X_temp, X_test, y_temp, y_test = train_test_split(
        all_images, all_masks, test_size=400, random_state=42
    )
    X_train, X_val, y_train, y_val = train_test_split(
        X_temp, y_temp, test_size=200, random_state=42
    )
    print(f"Split - Train: {X_train.shape[0]}, Val: {X_val.shape[0]}, Test: {X_test.shape[0]}")
    return (X_train, y_train), (X_val, y_val), (X_test, y_test)

def setup_augmentations():
    return A.Compose([
        A.RandomBrightnessContrast(brightness_limit=0.15, contrast_limit=0.15, p=0.7),
        A.HueSaturationValue(hue_shift_limit=10, sat_shift_limit=15, val_shift_limit=10, p=0.5),
        A.GaussianBlur(blur_limit=3, p=0.3),
        A.RandomGamma(gamma_limit=(80, 120), p=0.3),
    ])

def data_generator(images, masks, batch_size, augment=None):
    idxs = np.arange(len(images))
    while True:
        np.random.shuffle(idxs)
        for i in range(0, len(images), batch_size):
            batch_idxs = idxs[i:i+batch_size]
            batch_x, batch_y = [], []
            
            for idx in batch_idxs:
                img, mask = images[idx], masks[idx]
                
                if augment:
                    aug = augment(image=img, mask=mask)
                    img_aug, mask_aug = aug['image'], aug['mask']
                else:
                    img_aug, mask_aug = img, mask
                
                mask_cat = to_categorical(mask_aug, num_classes=3)
                batch_x.append(img_aug)
                batch_y.append(mask_cat)
            
            yield np.stack(batch_x).astype(np.float32), np.stack(batch_y).astype(np.float32)

# ============================================================================
# ECA ATTENTION MODULE
# ============================================================================

def eca_block(input_feature, b=1, gamma=2, name=""):
    """
    ECA (Efficient Channel Attention) Module
    
    Unlike CBAM which uses both channel and spatial attention, ECA only uses
    efficient channel attention with adaptive kernel size.
    
    Args:
        input_feature: Input tensor
        b: Parameter for adaptive kernel size calculation (default: 1)
        gamma: Parameter for adaptive kernel size calculation (default: 2)
        name: Name prefix for layers
    
    Paper: "ECA-Net: Efficient Channel Attention for Deep Convolutional Neural Networks"
    """
    channel = input_feature.shape[-1]
    
    # Adaptive kernel size calculation
    # k = |log2(channel) / gamma + b / gamma|_odd
    t = int(abs((np.log2(channel) / gamma) + (b / gamma)))
    k = t if t % 2 else t + 1  # Make it odd
    k = max(3, k)  # Minimum kernel size of 3
    
    # Global Average Pooling
    avg_pool = layers.GlobalAveragePooling2D()(input_feature)
    avg_pool = layers.Reshape((channel, 1))(avg_pool)
    
    # 1D Convolution with adaptive kernel size
    # This is the key difference from CBAM - uses 1D conv instead of FC layers
    eca_feature = layers.Conv1D(
        filters=1,
        kernel_size=k,
        padding='same',
        activation='sigmoid',
        name=f'eca_conv1d_{name}'
    )(avg_pool)
    
    eca_feature = layers.Reshape((1, 1, channel))(eca_feature)
    
    # Multiply input with attention weights
    output = layers.Multiply(name=f'eca_multiply_{name}')([input_feature, eca_feature])
    
    return output

# ============================================================================
# LOSS FUNCTIONS
# ============================================================================

def focal_loss(y_true, y_pred, gamma=2.0, alpha=None, epsilon=1e-7):
    if alpha is None:
        alpha = [0.25, 1.0, 1.0]
    
    y_pred = K.clip(y_pred, epsilon, 1.0 - epsilon)
    focal_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        pt = y_pred_c
        focal_weight = K.pow(1.0 - pt, gamma)
        cross_entropy = -K.log(pt)
        focal_loss_c = alpha[c] * focal_weight * cross_entropy * y_true_c
        focal_loss_value += K.mean(focal_loss_c)
    
    return focal_loss_value

def enhanced_iou_loss(y_true, y_pred, smooth=1e-7):
    eiou_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        
        intersection = K.sum(y_true_c * y_pred_c, axis=[1, 2])
        union = K.sum(y_true_c, axis=[1, 2]) + K.sum(y_pred_c, axis=[1, 2]) - intersection
        iou = (intersection + smooth) / (union + smooth)
        
        height = K.cast(K.shape(y_true_c)[1], 'float32')
        width = K.cast(K.shape(y_true_c)[2], 'float32')
        
        y_coords = K.arange(0, height)
        x_coords = K.arange(0, width)
        y_grid = K.tile(K.reshape(y_coords, (-1, 1)), (1, K.cast(width, 'int32')))
        x_grid = K.tile(K.reshape(x_coords, (1, -1)), (K.cast(height, 'int32'), 1))
        y_grid = K.cast(y_grid, 'float32')
        x_grid = K.cast(x_grid, 'float32')
        
        true_mass = K.sum(y_true_c, axis=[1, 2]) + smooth
        true_center_y = K.sum(y_true_c * y_grid, axis=[1, 2]) / true_mass
        true_center_x = K.sum(y_true_c * x_grid, axis=[1, 2]) / true_mass
        
        pred_mass = K.sum(y_pred_c, axis=[1, 2]) + smooth
        pred_center_y = K.sum(y_pred_c * y_grid, axis=[1, 2]) / pred_mass
        pred_center_x = K.sum(y_pred_c * x_grid, axis=[1, 2]) / pred_mass
        
        center_distance = K.square(true_center_y - pred_center_y) + K.square(true_center_x - pred_center_x)
        diagonal = K.square(height) + K.square(width)
        center_penalty = center_distance / (diagonal + smooth)
        
        true_width = K.sqrt(K.sum(K.sum(y_true_c, axis=1), axis=1) + smooth)
        true_height = K.sqrt(K.sum(K.sum(y_true_c, axis=2), axis=1) + smooth)
        pred_width = K.sqrt(K.sum(K.sum(y_pred_c, axis=1), axis=1) + smooth)
        pred_height = K.sqrt(K.sum(K.sum(y_pred_c, axis=2), axis=1) + smooth)
        
        width_diff = K.square(pred_width - true_width)
        height_diff = K.square(pred_height - true_height)
        aspect_penalty = width_diff / (K.square(width) + smooth) + height_diff / (K.square(height) + smooth)
        
        eiou_c = 1.0 - iou + center_penalty + aspect_penalty
        eiou_loss_value += K.mean(eiou_c)
    
    return eiou_loss_value / 3.0

def focal_eiou_combined_loss(y_true, y_pred, focal_weight=1.0, eiou_weight=1.0, gamma=2.0, alpha=None):
    fl = focal_loss(y_true, y_pred, gamma=gamma, alpha=alpha)
    eiou = enhanced_iou_loss(y_true, y_pred)
    return focal_weight * fl + eiou_weight * eiou

# ============================================================================
# ENHANCED DECODER BLOCK WITH ECA
# ============================================================================

def enhanced_decoder_block_with_eca(x, skip_connection, filters, block_name, dropout_rate=0.3):
    """Enhanced decoder block WITH ECA attention"""
    x = layers.UpSampling2D((2, 2), name=f'{block_name}_upsample')(x)
    
    if skip_connection.shape[-1] != x.shape[-1]:
        skip_connection = layers.Conv2D(x.shape[-1], (1, 1), activation='relu', 
                                      padding='same', name=f'{block_name}_skip_align')(skip_connection)
        skip_connection = layers.BatchNormalization(name=f'{block_name}_skip_bn')(skip_connection)
    
    x = layers.Concatenate(name=f'{block_name}_concat')([x, skip_connection])
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv1')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn1')(x)
    x = layers.Dropout(dropout_rate, name=f'{block_name}_dropout')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv2')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn2')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv3')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn3')(x)
    
    residual = x
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv4')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn4')(x)
    
    x = layers.Add(name=f'{block_name}_residual')([x, residual])
    x = layers.Conv2D(filters, (1, 1), activation='relu', padding='same', name=f'{block_name}_conv_final')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn_final')(x)
    
    # Apply ECA attention to decoder features
    x = eca_block(x, name=block_name)
    
    return x

# ============================================================================
# MODEL: DECODER-ONLY ECA VERSION
# ============================================================================

def build_combined_unet_decoder_only_eca(input_shape=(256, 256, 3), num_classes=3, 
                                         use_deeper=False, dropout_rate=0.3):
    """
    Combined MobileNet-UNet with DECODER-ONLY ECA
    
    ECA Placement (DECODER-ONLY VERSION):
    - Skip connections: NO ECA ❌
    - Bridge: NO ECA ❌
    - Decoder_1 (16x16): YES ✅
    - Decoder_2 (32x32): YES ✅
    - Decoder_3 (64x64): YES ✅
    - Decoder_4 (128x128): YES ✅
    - Final layer: NO ECA ❌
    Total: 4 ECA blocks (on decoder blocks only)
    
    Rationale: Apply attention to decoder features after they merge with encoder features,
    allowing the network to refine the fused representation.
    """
    
    print(f"\nBuilding Combined UNet with DECODER-ONLY ECA...")
    print(f"  Deeper Architecture: {use_deeper}")
    print(f"  MC Dropout Rate: {dropout_rate}")
    print(f"  ECA Attention: DECODER-ONLY (4 blocks on decoder blocks)")
    
    inputs = layers.Input(input_shape, dtype='float32')
    backbone = MobileNetV2(input_tensor=inputs, weights='imagenet', include_top=False)
    
    # Get skip connections (NO ECA on skip connections)
    skip_1 = backbone.get_layer('block_1_expand_relu').output  # 128x128
    skip_2 = backbone.get_layer('block_3_expand_relu').output  # 64x64
    skip_3 = backbone.get_layer('block_6_expand_relu').output  # 32x32
    skip_4 = backbone.get_layer('block_13_expand_relu').output # 16x16
    bridge = backbone.output  # 8x8
    
    print("  Applying ECA to decoder blocks...")
    print("    decoder_1 (16x16): WITH ECA ✓")
    print("    decoder_2 (32x32): WITH ECA ✓")
    print("    decoder_3 (64x64): WITH ECA ✓")
    print("    decoder_4 (128x128): WITH ECA ✓")
    
    # Deeper bridge (if enabled) - NO ECA on bridge
    if use_deeper:
        bridge = layers.Conv2D(1024, (3, 3), activation='relu', padding='same')(bridge)
        bridge = layers.BatchNormalization()(bridge)
    
    if dropout_rate > 0:
        bridge = layers.Dropout(dropout_rate, name='bridge_dropout')(bridge)
    
    # Decoder blocks with ECA
    if use_deeper:
        x = enhanced_decoder_block_with_eca(bridge, skip_4, 512, 'decoder_1', dropout_rate)
        x = enhanced_decoder_block_with_eca(x, skip_3, 256, 'decoder_2', dropout_rate)
        x = enhanced_decoder_block_with_eca(x, skip_2, 128, 'decoder_3', dropout_rate * 0.7)
        x = enhanced_decoder_block_with_eca(x, skip_1, 64, 'decoder_4', dropout_rate * 0.5)
    else:
        # Baseline decoder with ECA
        x = layers.UpSampling2D((2, 2))(bridge)
        x = layers.Concatenate()([x, skip_4])
        x = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        if dropout_rate > 0:
            x = layers.Dropout(dropout_rate)(x)
        x = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = eca_block(x, name='decoder_1')
        
        x = layers.UpSampling2D((2, 2))(x)
        x = layers.Concatenate()([x, skip_3])
        x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        if dropout_rate > 0:
            x = layers.Dropout(dropout_rate)(x)
        x = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = eca_block(x, name='decoder_2')
        
        x = layers.UpSampling2D((2, 2))(x)
        x = layers.Concatenate()([x, skip_2])
        x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        if dropout_rate > 0:
            x = layers.Dropout(dropout_rate * 0.7)(x)
        x = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = eca_block(x, name='decoder_3')
        
        x = layers.UpSampling2D((2, 2))(x)
        x = layers.Concatenate()([x, skip_1])
        x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        if dropout_rate > 0:
            x = layers.Dropout(dropout_rate * 0.5)(x)
        x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = eca_block(x, name='decoder_4')
    
    # Final upsampling - NO ECA
    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    
    outputs = layers.Conv2D(num_classes, (1, 1), activation='softmax', dtype='float32')(x)
    
    model = models.Model(inputs, outputs)
    
    # Print configuration
    if dropout_rate > 0:
        dropout_layers = [layer for layer in model.layers if isinstance(layer, layers.Dropout)]
        print(f"\n  MC Dropout Configuration:")
        print(f"    Total Dropout Layers: {len(dropout_layers)}")
        print(f"    Dropout Rates: {[f'{layer.rate:.2f}' for layer in dropout_layers]}")
    
    eca_count = sum(1 for layer in model.layers if 'eca_conv1d' in layer.name)
    print(f"\n  ECA Configuration (DECODER-ONLY):")
    print(f"    Total ECA Blocks: {eca_count}")
    print(f"    ECA Locations: Decoder blocks ONLY (4 blocks)")
    print(f"    Removed ECA from: Skip connections, Bridge, Final layer")
    
    return model

# ============================================================================
# METRICS
# ============================================================================

def dice_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    return (2. * intersection + smooth) / (K.sum(y_true_class) + K.sum(y_pred_class) + smooth)

def dice_class_0(y_true, y_pred): return dice_coef_class(y_true, y_pred, 0)
def dice_class_1(y_true, y_pred): return dice_coef_class(y_true, y_pred, 1)
def dice_class_2(y_true, y_pred): return dice_coef_class(y_true, y_pred, 2)

def iou_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    union = K.sum(y_true_class) + K.sum(y_pred_class) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_class_0(y_true, y_pred): return iou_coef_class(y_true, y_pred, 0)
def iou_class_1(y_true, y_pred): return iou_coef_class(y_true, y_pred, 1)
def iou_class_2(y_true, y_pred): return iou_coef_class(y_true, y_pred, 2)

# ============================================================================
# MC DROPOUT
# ============================================================================

def mc_dropout_predict(model, X, num_samples=15, batch_size=4, verbose=True):
    """MC Dropout prediction using training=True flag"""
    if verbose:
        print(f"\nRunning MC Dropout with {num_samples} stochastic forward passes...")
    
    predictions = []
    num_batches = int(np.ceil(len(X) / batch_size))
    
    for i in range(num_samples):
        if verbose and (i + 1) % 5 == 0:
            print(f"  Completed: {i+1}/{num_samples} forward passes")
        
        batch_preds = []
        for batch_idx in range(num_batches):
            start_idx = batch_idx * batch_size
            end_idx = min(start_idx + batch_size, len(X))
            X_batch = X[start_idx:end_idx]
            
            pred_batch = model(X_batch, training=True)
            batch_preds.append(pred_batch.numpy())
        
        pred = np.concatenate(batch_preds, axis=0)
        predictions.append(pred)
        
        if (i + 1) % 5 == 0:
            gc.collect()
    
    all_preds = np.array(predictions)
    mean_pred = np.mean(all_preds, axis=0)
    std_pred = np.std(all_preds, axis=0)
    
    del all_preds
    gc.collect()
    
    if verbose:
        print(f"✓ MC Dropout completed")
    
    return mean_pred, std_pred

# ============================================================================
# VISUALIZATION FUNCTIONS
# ============================================================================

def plot_training_history(history, model_name, save_dir='results'):
    """Plot training history: loss and accuracy curves"""
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    
    axes[0].plot(history.history['loss'], label='Training Loss', linewidth=2)
    axes[0].plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
    axes[0].set_title(f'{model_name} - Loss Over Epochs', fontsize=14, fontweight='bold')
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('Loss', fontsize=12)
    axes[0].legend(fontsize=10)
    axes[0].grid(True, alpha=0.3)
    
    axes[1].plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
    axes[1].plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
    axes[1].set_title(f'{model_name} - Accuracy Over Epochs', fontsize=14, fontweight='bold')
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('Accuracy', fontsize=12)
    axes[1].legend(fontsize=10)
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(f"{save_dir}/{model_name}_training_curves.png", dpi=300, bbox_inches='tight')
    print(f"✓ Training curves saved: {save_dir}/{model_name}_training_curves.png")
    plt.show()
    plt.close()

def plot_confusion_matrices(y_true, y_pred, model_name, save_dir='results'):
    """Plot confusion matrix and normalized confusion matrix"""
    y_true_labels = np.argmax(y_true, axis=-1).flatten()
    y_pred_labels = np.argmax(y_pred, axis=-1).flatten()
    
    cm = confusion_matrix(y_true_labels, y_pred_labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    class_names = ['Background', 'Disc', 'Cup']
    
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[0], cbar_kws={'label': 'Count'})
    axes[0].set_title(f'{model_name}\nConfusion Matrix', fontsize=14, fontweight='bold')
    axes[0].set_ylabel('True Label', fontsize=12)
    axes[0].set_xlabel('Predicted Label', fontsize=12)
    
    sns.heatmap(cm_normalized, annot=True, fmt='.3f', cmap='Greens',
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[1], cbar_kws={'label': 'Proportion'})
    axes[1].set_title(f'{model_name}\nNormalized Confusion Matrix', fontsize=14, fontweight='bold')
    axes[1].set_ylabel('True Label', fontsize=12)
    axes[1].set_xlabel('Predicted Label', fontsize=12)
    
    plt.tight_layout()
    plt.savefig(f"{save_dir}/{model_name}_confusion_matrices.png", dpi=300, bbox_inches='tight')
    print(f"✓ Confusion matrices saved: {save_dir}/{model_name}_confusion_matrices.png")
    plt.show()
    plt.close()
    
    print(f"\nConfusion Matrix:\n{cm}")
    print(f"\nNormalized Confusion Matrix:\n{np.round(cm_normalized, 3)}")
    
    return cm, cm_normalized

# ============================================================================
# TRAINING
# ============================================================================

def train_model(X_train, y_train, X_val, y_val, X_test, y_test, model_name, 
               use_focal_eiou=False, use_deeper=False, dropout_rate=0.0,
               augment=None, save_dir='results'):
    """Train model with visualization"""
    print(f"\n{'='*80}")
    print(f"TRAINING: {model_name}")
    print(f"{'='*80}")
    print(f"  Focal-EIoU Loss: {'✓' if use_focal_eiou else '✗'}")
    print(f"  Deeper Decoder: {'✓' if use_deeper else '✗'}")
    print(f"  MC Dropout: {'✓ (rate=' + str(dropout_rate) + ')' if dropout_rate > 0 else '✗'}")
    
    K.clear_session()
    
    # Build model
    model = build_combined_unet_decoder_only_eca(use_deeper=use_deeper, dropout_rate=dropout_rate)
    param_count = model.count_params()
    print(f"  Total Parameters: {param_count:,}")
    
    # Choose loss
    if use_focal_eiou:
        loss_fn = focal_eiou_combined_loss
    else:
        loss_fn = "categorical_crossentropy"
    
    # Compile
    initial_lr = 5e-4 if use_deeper else 1e-3
    model.compile(
        optimizer=optimizers.Adam(learning_rate=initial_lr),
        loss=loss_fn,
        metrics=[dice_coef_multiclass, dice_class_0, dice_class_1, dice_class_2,
                "accuracy", iou_coef_multiclass, iou_class_0, iou_class_1, iou_class_2]
    )
    
    # Callbacks
    checkpoint = ModelCheckpoint(f"{save_dir}/{model_name}.keras", save_best_only=True, 
                                verbose=1, monitor='val_loss', mode='min')
    reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=3, 
                                  verbose=1, mode='min', min_lr=1e-7)
    early_stop = EarlyStopping(monitor="val_loss", patience=20, verbose=1, 
                              restore_best_weights=True, mode='min')
    
    # Training
    batch_size = 4 if use_deeper else 8
    steps_train = X_train.shape[0] // batch_size
    steps_val = X_val.shape[0] // batch_size
    
    try:
        history = model.fit(
            data_generator(X_train, y_train, batch_size, augment),
            validation_data=data_generator(X_val, y_val, batch_size, None),
            steps_per_epoch=steps_train,
            validation_steps=steps_val,
            epochs=50,
            callbacks=[checkpoint, reduce_lr, early_stop],
            verbose=1
        )
    except Exception as e:
        print(f"✗ Error: {e}. Retrying with smaller batch...")
        batch_size = 2 if use_deeper else 4
        steps_train = X_train.shape[0] // batch_size
        steps_val = X_val.shape[0] // batch_size
        
        history = model.fit(
            data_generator(X_train, y_train, batch_size, augment),
            validation_data=data_generator(X_val, y_val, batch_size, None),
            steps_per_epoch=steps_train,
            validation_steps=steps_val,
            epochs=50,
            callbacks=[checkpoint, reduce_lr, early_stop],
            verbose=1
        )
    
    print(f"✓ Training completed")
    
    return model, history, param_count

# ============================================================================
# EVALUATION
# ============================================================================

def evaluate_model(model, X_test, y_test, model_name, run_mc_dropout=False, history=None, save_dir='results'):
    """Evaluate model"""
    print(f"\n{'='*80}")
    print(f"EVALUATION: {model_name}")
    print(f"{'='*80}")
    
    y_test_cat = np.array([to_categorical(mask, num_classes=3) for mask in y_test])
    
    # Predict
    y_pred = model.predict(X_test, verbose=0, batch_size=8)
    
    # Classification metrics
    y_true_labels = np.argmax(y_test_cat, axis=-1).flatten()
    y_pred_labels = np.argmax(y_pred, axis=-1).flatten()
    
    precision = precision_score(y_true_labels, y_pred_labels, average=None, zero_division=0)
    recall = recall_score(y_true_labels, y_pred_labels, average=None, zero_division=0)
    f1 = f1_score(y_true_labels, y_pred_labels, average=None, zero_division=0)
    
    print(f"\nPrecision, Recall, F1 Score per class:")
    class_names = ["Background", "Disc", "Cup"]
    for idx, cname in enumerate(class_names):
        print(f"  {cname}: Precision={precision[idx]:.4f}, Recall={recall[idx]:.4f}, F1={f1[idx]:.4f}")
    
    print(f"\nMacro-averaged metrics:")
    print(f"  Precision: {np.mean(precision):.4f}")
    print(f"  Recall: {np.mean(recall):.4f}")
    print(f"  F1 Score: {np.mean(f1):.4f}")
    
    # Per-class Dice and IoU
    results = {'standard': {}}
    for cidx, cname in enumerate(class_names):
        y_true_c = (np.argmax(y_test_cat, axis=-1) == cidx).astype(np.float32)
        y_pred_c = (np.argmax(y_pred, axis=-1) == cidx).astype(np.float32)
        
        intersection = np.sum(y_true_c * y_pred_c)
        dice = (2. * intersection + 1e-7) / (np.sum(y_true_c) + np.sum(y_pred_c) + 1e-7)
        union = np.sum(y_true_c) + np.sum(y_pred_c) - intersection
        iou = (intersection + 1e-7) / (union + 1e-7)
        
        results['standard'][cname] = {'dice': dice, 'iou': iou}
        print(f"  {cname}: Dice={dice:.4f}, IoU={iou:.4f}")
    
    # MC Dropout
    if run_mc_dropout:
        print("\nMC Dropout Evaluation:")
        mean_pred, std_pred = mc_dropout_predict(model, X_test[:100], num_samples=10, verbose=True)
        results['mc_dropout'] = {}
        for cidx, cname in enumerate(class_names):
            mean_std = np.mean(std_pred[:, :, :, cidx])
            results['mc_dropout'][cname] = {'mean_uncertainty': mean_std}
            print(f"  {cname} uncertainty: {mean_std:.4f}")
    
    # Generate visualizations AFTER printing all metrics
    print("\n" + "="*80)
    print("GENERATING VISUALIZATIONS")
    print("="*80)
    
    if history is not None:
        plot_training_history(history, model_name, save_dir)
    
    plot_confusion_matrices(y_test_cat, y_pred, model_name, save_dir=save_dir)
    
    return results

# ============================================================================
# MAIN
# ============================================================================

if __name__ == "__main__":
    gpu_available = configure_gpu()
    root_dir = "/kaggle/input/refuge/REFUGE/"
    train_aug = setup_augmentations()
    save_dir = "results"
    os.makedirs(save_dir, exist_ok=True)
    
    print(f"\n{'='*100}")
    print(f"{'MOBILENET-UNET WITH DECODER-ONLY ECA ATTENTION':^100s}")
    print(f"{'='*100}")
    
    # Load data
    all_images, all_masks = load_all_data(root_dir)
    (X_train, y_train), (X_val, y_val), (X_test, y_test) = create_new_split(all_images, all_masks)
    
    # Train model with ECA
    model, history, params = train_model(
        X_train, y_train, X_val, y_val, X_test, y_test,
        "Deeper_Focal_EIoU_MC_ECA_DecoderOnly",
        use_focal_eiou=True, use_deeper=True, dropout_rate=0.3,
        augment=train_aug, save_dir=save_dir
    )
    
    # Evaluate
    results = evaluate_model(model, X_test, y_test, "Deeper+Focal+EIoU+MC+ECA(Decoder)", 
                            run_mc_dropout=True, history=history, save_dir=save_dir)
    
    print(f"\n{'='*100}")
    print(f"{'✓ TRAINING AND EVALUATION COMPLETED!':^100s}")
    print(f"{'='*100}")
    print(f"\nModel: Deeper + Focal-EIoU + MC Dropout + ECA Attention (DECODER-ONLY)")
    print(f"Attention: ECA on decoder blocks (4 blocks)")
    print(f"Parameters: {params:,}")
    print(f"Results saved in: {save_dir}/")
    print(f"\n{'='*100}\n")
# Out:
# Configuring GPU settings...
# ✓ GPU found: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
#
# ====================================================================================================
#                            MOBILENET-UNET WITH DECODER-ONLY ECA ATTENTION
# ====================================================================================================
# Loading train data...
#   train: 400 samples
# Loading val data...
#   val: 400 samples
# Loading test data...
#   test: 400 samples
# Split - Train: 600, Val: 200, Test: 400
#
# ================================================================================
# TRAINING: Deeper_Focal_EIoU_MC_ECA_DecoderOnly
# ================================================================================
#   Focal-EIoU Loss: ✓
#   Deeper Decoder: ✓
#   MC Dropout: ✓ (rate=0.3)
#
# Building Combined UNet with DECODER-ONLY ECA...
#   Deeper Architecture: True
#   MC Dropout Rate: 0.3
#   ECA Attention: DECODER-ONLY (4 blocks on decoder blocks)
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
#   Applying ECA to decoder blocks...
#     decoder_1 (16x16): WITH ECA ✓
#     decoder_2 (32x32): WITH ECA ✓
#     decoder_3 (64x64): WITH ECA ✓
#     decoder_4 (128x128): WITH ECA ✓
#
#   MC Dropout Configuration:
#     Total Dropout Layers: 5
#     Dropout Rates: ['0.30', '0.30', '0.30', '0.21', '0.15']
#
#   ECA Configuration (DECODER-ONLY):
#     Total ECA Blocks: 4
#     ECA Locations: Decoder blocks ONLY (4 blocks)
#     Removed ECA from: Skip connections, Bridge, Final layer
#   Total Parameters: 37,131,417
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763455550.257006     110 service.cc:148] XLA service 0x7b28d4001ce0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1763455550.257804     110 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1763455556.399246     110 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1763455564.201686     110 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763455564.459914     110 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#   1/150 ━━━━━━━━━━━━━━━━━━━━ 3:47:40 92s/step - accuracy: 0.3633 - dice_class_0: 0.5313 - dice_class_1: 0.0239 - dice_class_2: 0.0104 - dice_coef_multiclass: 0.3485 - iou_class_0: 0.3617 - iou_class_1: 0.0121 - iou_class_2: 0.0052 - iou_coef_multiclass: 0.2110 - loss: 1.6133
# I0000 00:00:1763455596.969315     110 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8574 - dice_class_0: 0.9113 - dice_class_1: 0.3351 - dice_class_2: 0.3221 - dice_coef_multiclass: 0.6014 - iou_class_0: 0.8580 - iou_class_1: 0.2136 - iou_class_2: 0.2130 - iou_coef_multiclass: 0.4410 - loss: 1.1582
# E0000 00:00:1763455620.871998     111 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763455621.135292     111 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Epoch 1: val_loss improved from inf to 1.62491, saving model to results/Deeper_Focal_EIoU_MC_ECA_DecoderOnly.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 124s 216ms/step - accuracy: 0.8580 - dice_class_0: 0.9116 - dice_class_1: 0.3359 - dice_class_2: 0.3231 - dice_coef_multiclass: 0.6021 - iou_class_0: 0.8585 - iou_class_1: 0.2141 - iou_class_2: 0.2138 - iou_coef_multiclass: 0.4419 - loss: 1.1571 - val_accuracy: 0.7142 - val_dice_class_0: 0.8332 - val_dice_class_1: 0.0734 - val_dice_class_2: 0.0734 - val_dice_coef_multiclass: 0.7084 - val_iou_class_0: 0.7142 - val_iou_class_1: 0.0381 - val_iou_class_2: 0.0381 - val_iou_coef_multiclass: 0.5488 - val_loss: 1.6249 - learning_rate: 5.0000e-04
# Epoch 2/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9844 - dice_class_0: 0.9927 - dice_class_1: 0.6819 - dice_class_2: 0.5457 - dice_coef_multiclass: 0.9137 - iou_class_0: 0.9856 - iou_class_1: 0.5219 - iou_class_2: 0.3790 - iou_coef_multiclass: 0.8422 - loss: 0.6871
# Epoch 2: val_loss improved from 1.62491 to 0.81510, saving model to results/Deeper_Focal_EIoU_MC_ECA_DecoderOnly.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 149ms/step - accuracy: 0.9844 - dice_class_0: 0.9927 - dice_class_1: 0.6822 - dice_class_2: 0.5456 - dice_coef_multiclass: 0.9139 - iou_class_0: 0.9856 - iou_class_1: 0.5223 - iou_class_2: 0.3790 - iou_coef_multiclass: 0.8425 - loss: 0.6867 - val_accuracy: 0.9791 - val_dice_class_0: 0.9955 - val_dice_class_1: 3.9610e-05 - val_dice_class_2: 0.2900 - val_dice_coef_multiclass: 0.9791 - val_iou_class_0: 0.9909 - val_iou_class_1: 1.9816e-05 - val_iou_class_2: 0.1707 - val_iou_coef_multiclass: 0.9590 - val_loss: 0.8151 - learning_rate: 5.0000e-04
# Epoch 3/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9942 - dice_class_0: 0.9977 - dice_class_1: 0.8043 - dice_class_2: 0.8250 - dice_coef_multiclass: 0.9827 - iou_class_0: 0.9954 - iou_class_1: 0.6749 - iou_class_2: 0.7048 - iou_coef_multiclass: 0.9661 - loss: 0.4171
# Epoch 3: val_loss improved from 0.81510 to 0.24699, saving model to results/Deeper_Focal_EIoU_MC_ECA_DecoderOnly.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 148ms/step - accuracy: 0.9942 - dice_class_0: 0.9977 - dice_class_1: 0.8044 - dice_class_2: 0.8252 - dice_coef_multiclass: 0.9827 - iou_class_0: 0.9955 - iou_class_1: 0.6752 - iou_class_2: 0.7050 - iou_coef_multiclass: 0.9661 - loss: 0.4167 - val_accuracy: 0.9945 - val_dice_class_0: 0.9980 - val_dice_class_1: 0.8043 - val_dice_class_2: 0.7975 - val_dice_coef_multiclass: 0.9944 - val_iou_class_0: 0.9961 - val_iou_class_1: 0.6747 - val_iou_class_2: 0.6662 - val_iou_coef_multiclass: 0.9889 - val_loss: 0.2470 - learning_rate: 5.0000e-04
# Epoch 4/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9966 - dice_class_0: 0.9988 - dice_class_1: 0.8737 - dice_class_2: 0.8680 - dice_coef_multiclass: 0.9953 - iou_class_0: 0.9977 - iou_class_1: 0.7770 - iou_class_2: 0.7688 - iou_coef_multiclass: 0.9907 - loss: 0.2160
# Epoch 4: val_loss improved from 0.24699 to 0.18446, saving model to results/Deeper_Focal_EIoU_MC_ECA_DecoderOnly.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 148ms/step - accuracy: 0.9966 - dice_class_0: 0.9988 - dice_class_1: 0.8737 - dice_class_2: 0.8680 - dice_coef_multiclass: 0.9953 - iou_class_0: 0.9977 - iou_class_1: 0.7770 - iou_class_2: 0.7687 - iou_coef_multiclass: 0.9907 - loss: 0.2159 - val_accuracy: 0.9968 - val_dice_class_0: 0.9990 - val_dice_class_1: 0.8716 - val_dice_class_2: 0.8507 - val_dice_coef_multiclass: 0.9968 - val_iou_class_0: 0.9981 - val_iou_class_1: 0.7735 - val_iou_class_2: 0.7425 - val_iou_coef_multiclass: 0.9937 - val_loss: 0.1845 - learning_rate: 5.0000e-04
# Epoch 5/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9972 - dice_class_0: 0.9991 - dice_class_1: 0.8924 - dice_class_2: 0.8770 - dice_coef_multiclass: 0.9967 - iou_class_0: 0.9982 - iou_class_1: 0.8063 - iou_class_2: 0.7821 - iou_coef_multiclass: 0.9935 - loss: 0.1732
# Epoch 5: val_loss did not improve from 0.18446
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 127ms/step - accuracy: 0.9972 - dice_class_0: 0.9991 - dice_class_1: 0.8924 - dice_class_2: 0.8770 - dice_coef_multiclass: 0.9967 - iou_class_0: 0.9982 - iou_class_1: 0.8063 - iou_class_2: 0.7821 - iou_coef_multiclass: 0.9935 - loss: 0.1732 - val_accuracy: 0.9965 - val_dice_class_0: 0.9989 - val_dice_class_1: 0.8524 - val_dice_class_2: 0.8333 - val_dice_coef_multiclass: 0.9965 - val_iou_class_0: 0.9978 - val_iou_class_1: 0.7438 - val_iou_class_2: 0.7159 - val_iou_coef_multiclass: 0.9929 - val_loss: 0.2072 - learning_rate: 5.0000e-04
# Epoch 6/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9973 - dice_class_0: 0.9991 - dice_class_1: 0.8930 - dice_class_2: 0.8857 - dice_coef_multiclass: 0.9970 - iou_class_0: 0.9983 - iou_class_1: 0.8076 - iou_class_2: 0.7961 - iou_coef_multiclass: 0.9941 - loss: 0.1577
# Epoch 6: val_loss did not improve from 0.18446
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 127ms/step - accuracy: 0.9973 - dice_class_0: 0.9991 - dice_class_1: 0.8931 - dice_class_2: 0.8856 - dice_coef_multiclass: 0.9970 - iou_class_0: 0.9983 - iou_class_1: 0.8076 - iou_class_2: 0.7960 - iou_coef_multiclass: 0.9941 - loss: 0.1577 - val_accuracy: 0.9950 - val_dice_class_0: 0.9981 - val_dice_class_1: 0.7687 - val_dice_class_2: 0.8330 - val_dice_coef_multiclass: 0.9950 - val_iou_class_0: 0.9962 - val_iou_class_1: 0.6281 - val_iou_class_2: 0.7180 - val_iou_coef_multiclass: 0.9900 - val_loss: 0.2751 - learning_rate: 5.0000e-04
# Epoch 7/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9976 - dice_class_0: 0.9992 - dice_class_1: 0.9039 - dice_class_2: 0.8957 - dice_coef_multiclass: 0.9974 - iou_class_0: 0.9985 - iou_class_1: 0.8251 - iou_class_2: 0.8121 - iou_coef_multiclass: 0.9949 - loss: 0.1435
# Epoch 7: val_loss improved from 0.18446 to 0.18057, saving model to results/Deeper_Focal_EIoU_MC_ECA_DecoderOnly.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 149ms/step - accuracy: 0.9976 - dice_class_0: 0.9992 - dice_class_1: 0.9039 - dice_class_2: 0.8957 - dice_coef_multiclass: 0.9974 - iou_class_0: 0.9985 - iou_class_1: 0.8251 - iou_class_2: 0.8121 - iou_coef_multiclass: 0.9949 - loss: 0.1435 - val_accuracy: 0.9969 - val_dice_class_0: 0.9990 - val_dice_class_1: 0.8658 - val_dice_class_2: 0.8676 - val_dice_coef_multiclass: 0.9969 - val_iou_class_0: 0.9980 - val_iou_class_1: 0.7656 - val_iou_class_2: 0.7684 - val_iou_coef_multiclass: 0.9938 - val_loss: 0.1806 - learning_rate: 5.0000e-04
# Epoch 8/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9078 - dice_class_2: 0.8985 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9985 - iou_class_1: 0.8318 - iou_class_2: 0.8168 - iou_coef_multiclass: 0.9951 - loss: 0.1368
# Epoch 8: val_loss improved from 0.18057 to 0.17793, saving model to results/Deeper_Focal_EIoU_MC_ECA_DecoderOnly.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 149ms/step - accuracy: 0.9977 - dice_class_0: 0.9993 - dice_class_1: 0.9078 - dice_class_2: 0.8985 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9985 - iou_class_1: 0.8318 - iou_class_2: 0.8168 - iou_coef_multiclass: 0.9951 - loss: 0.1368 - val_accuracy: 0.9970 - val_dice_class_0: 0.9990 - val_dice_class_1: 0.8700 - val_dice_class_2: 0.8702 - val_dice_coef_multiclass: 0.9970 - val_iou_class_0: 0.9980 - val_iou_class_1: 0.7724 - val_iou_class_2: 0.7727 - val_iou_coef_multiclass: 0.9940 - val_loss: 0.1779 - learning_rate: 5.0000e-04
# Epoch 9/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9091 - dice_class_2: 0.9024 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9986 - iou_class_1: 0.8338 - iou_class_2: 0.8228 - iou_coef_multiclass: 0.9953 - loss: 0.1328
# Epoch 9: val_loss did not improve from 0.17793
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9091 - dice_class_2: 0.9024 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9986 - iou_class_1: 0.8338 - iou_class_2: 0.8228 - iou_coef_multiclass: 0.9953 - loss: 0.1328 - val_accuracy: 0.9970 - val_dice_class_0: 0.9991 - val_dice_class_1: 0.8757 - val_dice_class_2: 0.8472 - val_dice_coef_multiclass: 0.9969 - val_iou_class_0: 0.9981 - val_iou_class_1: 0.7807 - val_iou_class_2: 0.7362 - val_iou_coef_multiclass: 0.9939 - val_loss: 0.1819 - learning_rate: 5.0000e-04
# Epoch 10/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9977 - dice_class_0: 0.9992 - dice_class_1: 0.9059 - dice_class_2: 0.8998 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9985 - iou_class_1: 0.8289 - iou_class_2: 0.8190 - iou_coef_multiclass: 0.9952 - loss: 0.1338
# Epoch 10: val_loss did not improve from 0.17793
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9977 - dice_class_0: 0.9992 - dice_class_1: 0.9059 - dice_class_2: 0.8998 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9985 - iou_class_1: 0.8290 - iou_class_2: 0.8190 - iou_coef_multiclass: 0.9952 - loss: 0.1338 - val_accuracy: 0.9968 - val_dice_class_0: 0.9990 - val_dice_class_1: 0.8596 - val_dice_class_2: 0.8607 - val_dice_coef_multiclass: 0.9968 - val_iou_class_0: 0.9980 - val_iou_class_1: 0.7557 - val_iou_class_2: 0.7572 - val_iou_coef_multiclass: 0.9936 - val_loss: 0.1871 - learning_rate: 5.0000e-04
# Epoch 11/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9135 - dice_class_2: 0.9046 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9986 - iou_class_1: 0.8417 - iou_class_2: 0.8274 - iou_coef_multiclass: 0.9955 - loss: 0.1247
# Epoch 11: val_loss improved from 0.17793 to 0.16848, saving model to results/Deeper_Focal_EIoU_MC_ECA_DecoderOnly.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 148ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9135 - dice_class_2: 0.9046 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9986 - iou_class_1: 0.8417 - iou_class_2: 0.8274 - iou_coef_multiclass: 0.9955 - loss: 0.1247 - val_accuracy: 0.9972 - val_dice_class_0: 0.9991 - val_dice_class_1: 0.8880 - val_dice_class_2: 0.8452 - val_dice_coef_multiclass: 0.9971 - val_iou_class_0: 0.9983 - val_iou_class_1: 0.7999 - val_iou_class_2: 0.7351 - val_iou_coef_multiclass: 0.9943 - val_loss: 0.1685 - learning_rate: 5.0000e-04
# Epoch 12/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9980 - dice_class_0: 0.9993 - dice_class_1: 0.9188 - dice_class_2: 0.9123 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8501 - iou_class_2: 0.8397 - iou_coef_multiclass: 0.9958 - loss: 0.1169
# Epoch 12: val_loss did not improve from 0.16848
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9980 - dice_class_0: 0.9993 - dice_class_1: 0.9187 - dice_class_2: 0.9123 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8501 - iou_class_2: 0.8396 - iou_coef_multiclass: 0.9958 - loss: 0.1169 - val_accuracy: 0.9967 - val_dice_class_0: 0.9989 - val_dice_class_1: 0.8566 - val_dice_class_2: 0.8584 - val_dice_coef_multiclass: 0.9967 - val_iou_class_0: 0.9979 - val_iou_class_1: 0.7510 - val_iou_class_2: 0.7545 - val_iou_coef_multiclass: 0.9935 - val_loss: 0.1907 - learning_rate: 5.0000e-04
# Epoch 13/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9980 - dice_class_0: 0.9993 - dice_class_1: 0.9188 - dice_class_2: 0.9136 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8504 - iou_class_2: 0.8420 - iou_coef_multiclass: 0.9958 - loss: 0.1160
# Epoch 13: val_loss improved from 0.16848 to 0.14531, saving model to results/Deeper_Focal_EIoU_MC_ECA_DecoderOnly.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 148ms/step - accuracy: 0.9980 - dice_class_0: 0.9993 - dice_class_1: 0.9188 - dice_class_2: 0.9136 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8503 - iou_class_2: 0.8420 - iou_coef_multiclass: 0.9958 - loss: 0.1160 - val_accuracy: 0.9976 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8974 - val_dice_class_2: 0.8897 - val_dice_coef_multiclass: 0.9975 - val_iou_class_0: 0.9984 - val_iou_class_1: 0.8149 - val_iou_class_2: 0.8025 - val_iou_coef_multiclass: 0.9951 - val_loss: 0.1453 - learning_rate: 5.0000e-04
# Epoch 14/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9228 - dice_class_2: 0.9197 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9987 - iou_class_1: 0.8571 - iou_class_2: 0.8520 - iou_coef_multiclass: 0.9961 - loss: 0.1104
# Epoch 14: val_loss did not improve from 0.14531
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9228 - dice_class_2: 0.9197 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9987 - iou_class_1: 0.8571 - iou_class_2: 0.8520 - iou_coef_multiclass: 0.9961 - loss: 0.1104 - val_accuracy: 0.9974 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8839 - val_dice_class_2: 0.8736 - val_dice_coef_multiclass: 0.9973 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.7939 - val_iou_class_2: 0.7774 - val_iou_coef_multiclass: 0.9947 - val_loss: 0.1619 - learning_rate: 5.0000e-04
# Epoch 15/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9222 - dice_class_2: 0.9255 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9987 - iou_class_1: 0.8560 - iou_class_2: 0.8618 - iou_coef_multiclass: 0.9961 - loss: 0.1068
# Epoch 15: val_loss did not improve from 0.14531
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 127ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9222 - dice_class_2: 0.9254 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9987 - iou_class_1: 0.8560 - iou_class_2: 0.8618 - iou_coef_multiclass: 0.9961 - loss: 0.1068 - val_accuracy: 0.9974 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8903 - val_dice_class_2: 0.8589 - val_dice_coef_multiclass: 0.9973 - val_iou_class_0: 0.9984 - val_iou_class_1: 0.8036 - val_iou_class_2: 0.7548 - val_iou_coef_multiclass: 0.9947 - val_loss: 0.1638 - learning_rate: 5.0000e-04
# Epoch 16/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9980 - dice_class_0: 0.9993 - dice_class_1: 0.9210 - dice_class_2: 0.9169 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8539 - iou_class_2: 0.8474 - iou_coef_multiclass: 0.9959 - loss: 0.1125
# Epoch 16: val_loss did not improve from 0.14531
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 127ms/step - accuracy: 0.9980 - dice_class_0: 0.9993 - dice_class_1: 0.9210 - dice_class_2: 0.9169 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8539 - iou_class_2: 0.8474 - iou_coef_multiclass: 0.9959 - loss: 0.1125 - val_accuracy: 0.9973 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8781 - val_dice_class_2: 0.8659 - val_dice_coef_multiclass: 0.9973 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.7836 - val_iou_class_2: 0.7651 - val_iou_coef_multiclass: 0.9945 - val_loss: 0.1730 - learning_rate: 5.0000e-04
# Epoch 17/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9290 - dice_class_2: 0.9280 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8677 - iou_class_2: 0.8664 - iou_coef_multiclass: 0.9963 - loss: 0.1014
# Epoch 17: val_loss improved from 0.14531 to 0.14006, saving model to results/Deeper_Focal_EIoU_MC_ECA_DecoderOnly.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 150ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9290 - dice_class_2: 0.9280 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8677 - iou_class_2: 0.8664 - iou_coef_multiclass: 0.9963 - loss: 0.1014 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9029 - val_dice_class_2: 0.8861 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8237 - val_iou_class_2: 0.7973 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1401 - learning_rate: 1.5000e-04
# Epoch 18/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9303 - dice_class_2: 0.9367 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8701 - iou_class_2: 0.8814 - iou_coef_multiclass: 0.9965 - loss: 0.0937
# Epoch 18: val_loss did not improve from 0.14006
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 127ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9303 - dice_class_2: 0.9367 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8701 - iou_class_2: 0.8814 - iou_coef_multiclass: 0.9965 - loss: 0.0937 - val_accuracy: 0.9976 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8974 - val_dice_class_2: 0.8904 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.8153 - val_iou_class_2: 0.8048 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1410 - learning_rate: 1.5000e-04
# Epoch 19/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9328 - dice_class_2: 0.9336 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8744 - iou_class_2: 0.8764 - iou_coef_multiclass: 0.9966 - loss: 0.0944
# Epoch 19: val_loss did not improve from 0.14006
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 127ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9328 - dice_class_2: 0.9336 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8744 - iou_class_2: 0.8765 - iou_coef_multiclass: 0.9966 - loss: 0.0944 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9029 - val_dice_class_2: 0.8803 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8240 - val_iou_class_2: 0.7881 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1424 - learning_rate: 1.5000e-04
# Epoch 20/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9354 - dice_class_2: 0.9430 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8790 - iou_class_2: 0.8925 - iou_coef_multiclass: 0.9967 - loss: 0.0865
# Epoch 20: val_loss did not improve from 0.14006
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 4.500000213738531e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 127ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9354 - dice_class_2: 0.9430 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8790 - iou_class_2: 0.8925 - iou_coef_multiclass: 0.9967 - loss: 0.0865 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9054 - val_dice_class_2: 0.8801 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8285 - val_iou_class_2: 0.7879 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1412 - learning_rate: 1.5000e-04
# Epoch 21/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9343 - dice_class_2: 0.9375 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8770 - iou_class_2: 0.8830 - iou_coef_multiclass: 0.9966 - loss: 0.0903
# Epoch 21: val_loss improved from 0.14006 to 0.13584, saving model to results/Deeper_Focal_EIoU_MC_ECA_DecoderOnly.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 153ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9343 - dice_class_2: 0.9375 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8771 - iou_class_2: 0.8830 - iou_coef_multiclass: 0.9966 - loss: 0.0903 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9075 - val_dice_class_2: 0.8913 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8313 - val_iou_class_2: 0.8051 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1358 - learning_rate: 4.5000e-05
# Epoch 22/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9380 - dice_class_2: 0.9430 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8835 - iou_class_2: 0.8926 - iou_coef_multiclass: 0.9968 - loss: 0.0844
# Epoch 22: val_loss did not improve from 0.13584
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9380 - dice_class_2: 0.9430 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8835 - iou_class_2: 0.8926 - iou_coef_multiclass: 0.9968 - loss: 0.0844 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9011 - val_dice_class_2: 0.8848 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8209 - val_iou_class_2: 0.7953 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1436 - learning_rate: 4.5000e-05
# Epoch 23/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9409 - dice_class_2: 0.9448 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8887 - iou_class_2: 0.8958 - iou_coef_multiclass: 0.9970 - loss: 0.0810
# Epoch 23: val_loss did not improve from 0.13584
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9409 - dice_class_2: 0.9448 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8886 - iou_class_2: 0.8958 - iou_coef_multiclass: 0.9970 - loss: 0.0810 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9007 - val_dice_class_2: 0.8871 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8203 - val_iou_class_2: 0.7990 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1405 - learning_rate: 4.5000e-05
# Epoch 24/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9378 - dice_class_2: 0.9449 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8832 - iou_class_2: 0.8961 - iou_coef_multiclass: 0.9968 - loss: 0.0830
# Epoch 24: val_loss did not improve from 0.13584
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1.3500000204658135e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9378 - dice_class_2: 0.9449 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8832 - iou_class_2: 0.8961 - iou_coef_multiclass: 0.9968 - loss: 0.0830 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9090 - val_dice_class_2: 0.8873 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8336 - val_iou_class_2: 0.7987 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1364 - learning_rate: 4.5000e-05
# Epoch 25/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9400 - dice_class_2: 0.9438 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8870 - iou_class_2: 0.8940 - iou_coef_multiclass: 0.9969 - loss: 0.0820
# Epoch 25: val_loss did not improve from 0.13584
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9400 - dice_class_2: 0.9438 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8870 - iou_class_2: 0.8940 - iou_coef_multiclass: 0.9969 - loss: 0.0820 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9008 - val_dice_class_2: 0.8932 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8206 - val_iou_class_2: 0.8086 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1400 - learning_rate: 1.3500e-05
# Epoch 26/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9397 - dice_class_2: 0.9476 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9989 - iou_class_1: 0.8865 - iou_class_2: 0.9008 - iou_coef_multiclass: 0.9969 - loss: 0.0796
# Epoch 26: val_loss did not improve from 0.13584
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 127ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9397 - dice_class_2: 0.9476 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9989 - iou_class_1: 0.8865 - iou_class_2: 0.9008 - iou_coef_multiclass: 0.9969 - loss: 0.0796 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9054 - val_dice_class_2: 0.8887 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8282 - val_iou_class_2: 0.8015 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1372 - learning_rate: 1.3500e-05
# Epoch 27/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9400 - dice_class_2: 0.9454 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8871 - iou_class_2: 0.8969 - iou_coef_multiclass: 0.9969 - loss: 0.0819
# Epoch 27: val_loss did not improve from 0.13584
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 4.050000006827758e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9400 - dice_class_2: 0.9454 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8871 - iou_class_2: 0.8969 - iou_coef_multiclass: 0.9969 - loss: 0.0819 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9062 - val_dice_class_2: 0.8892 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8297 - val_iou_class_2: 0.8022 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1361 - learning_rate: 1.3500e-05
# Epoch 28/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9420 - dice_class_2: 0.9479 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8906 - iou_class_2: 0.9014 - iou_coef_multiclass: 0.9970 - loss: 0.0786
# Epoch 28: val_loss improved from 0.13584 to 0.13271, saving model to results/Deeper_Focal_EIoU_MC_ECA_DecoderOnly.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 148ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9420 - dice_class_2: 0.9479 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8906 - iou_class_2: 0.9014 - iou_coef_multiclass: 0.9970 - loss: 0.0786 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9108 - val_dice_class_2: 0.8947 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8366 - val_iou_class_2: 0.8104 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1327 - learning_rate: 4.0500e-06
# Epoch 29/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9425 - dice_class_2: 0.9492 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8916 - iou_class_2: 0.9036 - iou_coef_multiclass: 0.9970 - loss: 0.0777
# Epoch 29: val_loss did not improve from 0.13271
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9425 - dice_class_2: 0.9491 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8916 - iou_class_2: 0.9036 - iou_coef_multiclass: 0.9970 - loss: 0.0777 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9007 - val_dice_class_2: 0.8872 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8203 - val_iou_class_2: 0.7992 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1417 - learning_rate: 4.0500e-06
# Epoch 30/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9409 - dice_class_2: 0.9495 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8887 - iou_class_2: 0.9043 - iou_coef_multiclass: 0.9970 - loss: 0.0783
# Epoch 30: val_loss did not improve from 0.13271
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9409 - dice_class_2: 0.9495 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8887 - iou_class_2: 0.9043 - iou_coef_multiclass: 0.9970 - loss: 0.0783 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9055 - val_dice_class_2: 0.8869 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8291 - val_iou_class_2: 0.7990 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1373 - learning_rate: 4.0500e-06
# Epoch 31/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9427 - dice_class_2: 0.9507 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8919 - iou_class_2: 0.9066 - iou_coef_multiclass: 0.9970 - loss: 0.0766
# Epoch 31: val_loss did not improve from 0.13271
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.2149999747634864e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9427 - dice_class_2: 0.9507 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8918 - iou_class_2: 0.9066 - iou_coef_multiclass: 0.9970 - loss: 0.0766 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9079 - val_dice_class_2: 0.8934 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8320 - val_iou_class_2: 0.8086 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1354 - learning_rate: 4.0500e-06
# Epoch 32/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9406 - dice_class_2: 0.9448 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8882 - iou_class_2: 0.8961 - iou_coef_multiclass: 0.9969 - loss: 0.0817
# Epoch 32: val_loss did not improve from 0.13271
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9406 - dice_class_2: 0.9449 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8882 - iou_class_2: 0.8961 - iou_coef_multiclass: 0.9969 - loss: 0.0817 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9053 - val_dice_class_2: 0.8863 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8279 - val_iou_class_2: 0.7977 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1391 - learning_rate: 1.2150e-06
# Epoch 33/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9414 - dice_class_2: 0.9469 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8895 - iou_class_2: 0.8994 - iou_coef_multiclass: 0.9970 - loss: 0.0794
# Epoch 33: val_loss did not improve from 0.13271
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 127ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9414 - dice_class_2: 0.9469 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8895 - iou_class_2: 0.8995 - iou_coef_multiclass: 0.9970 - loss: 0.0794 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9003 - val_dice_class_2: 0.8891 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8204 - val_iou_class_2: 0.8022 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1403 - learning_rate: 1.2150e-06
# Epoch 34/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9416 - dice_class_2: 0.9488 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8898 - iou_class_2: 0.9029 - iou_coef_multiclass: 0.9970 - loss: 0.0781
# Epoch 34: val_loss did not improve from 0.13271
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 3.644999992502562e-07.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9416 - dice_class_2: 0.9488 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8898 - iou_class_2: 0.9028 - iou_coef_multiclass: 0.9970 - loss: 0.0782 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9090 - val_dice_class_2: 0.8938 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8336 - val_iou_class_2: 0.8088 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1341 - learning_rate: 1.2150e-06
# Epoch 35/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9401 - dice_class_2: 0.9478 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8872 - iou_class_2: 0.9012 - iou_coef_multiclass: 0.9969 - loss: 0.0804
# Epoch 35: val_loss did not improve from 0.13271
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9401 - dice_class_2: 0.9478 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8872 - iou_class_2: 0.9012 - iou_coef_multiclass: 0.9969 - loss: 0.0804 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9036 - val_dice_class_2: 0.8887 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8252 - val_iou_class_2: 0.8011 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1392 - learning_rate: 3.6450e-07
# Epoch 36/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9428 - dice_class_2: 0.9479 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8921 - iou_class_2: 0.9013 - iou_coef_multiclass: 0.9971 - loss: 0.0782
# Epoch 36: val_loss improved from 0.13271 to 0.13059, saving model to results/Deeper_Focal_EIoU_MC_ECA_DecoderOnly.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 149ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9428 - dice_class_2: 0.9479 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8921 - iou_class_2: 0.9013 - iou_coef_multiclass: 0.9971 - loss: 0.0782 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9114 - val_dice_class_2: 0.8964 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8378 - val_iou_class_2: 0.8136 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1306 - learning_rate: 3.6450e-07
# Epoch 37/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9434 - dice_class_2: 0.9496 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8931 - iou_class_2: 0.9044 - iou_coef_multiclass: 0.9971 - loss: 0.0773
# Epoch 37: val_loss did not improve from 0.13059
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9434 - dice_class_2: 0.9496 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8931 - iou_class_2: 0.9044 - iou_coef_multiclass: 0.9971 - loss: 0.0773 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9052 - val_dice_class_2: 0.8893 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8277 - val_iou_class_2: 0.8021 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1380 - learning_rate: 3.6450e-07
# Epoch 38/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9412 - dice_class_2: 0.9511 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9989 - iou_class_1: 0.8891 - iou_class_2: 0.9072 - iou_coef_multiclass: 0.9970 - loss: 0.0769
# Epoch 38: val_loss did not improve from 0.13059
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9412 - dice_class_2: 0.9511 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9989 - iou_class_1: 0.8891 - iou_class_2: 0.9072 - iou_coef_multiclass: 0.9970 - loss: 0.0769 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9028 - val_dice_class_2: 0.8882 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8242 - val_iou_class_2: 0.8006 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1396 - learning_rate: 3.6450e-07
# Epoch 39/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9418 - dice_class_2: 0.9474 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8902 - iou_class_2: 0.9004 - iou_coef_multiclass: 0.9970 - loss: 0.0788
# Epoch 39: val_loss did not improve from 0.13059
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1.0935000318568199e-07.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9418 - dice_class_2: 0.9474 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8902 - iou_class_2: 0.9004 - iou_coef_multiclass: 0.9970 - loss: 0.0788 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9064 - val_dice_class_2: 0.8925 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8294 - val_iou_class_2: 0.8072 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1355 - learning_rate: 3.6450e-07
# Epoch 40/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9417 - dice_class_2: 0.9490 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8902 - iou_class_2: 0.9033 - iou_coef_multiclass: 0.9970 - loss: 0.0783
# Epoch 40: val_loss did not improve from 0.13059
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9417 - dice_class_2: 0.9490 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8902 - iou_class_2: 0.9033 - iou_coef_multiclass: 0.9970 - loss: 0.0783 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9058 - val_dice_class_2: 0.8934 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8287 - val_iou_class_2: 0.8087 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1354 - learning_rate: 1.0935e-07
# Epoch 41/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9430 - dice_class_2: 0.9505 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8924 - iou_class_2: 0.9060 - iou_coef_multiclass: 0.9971 - loss: 0.0770
# Epoch 41: val_loss did not improve from 0.13059
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9430 - dice_class_2: 0.9505 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8923 - iou_class_2: 0.9059 - iou_coef_multiclass: 0.9971 - loss: 0.0770 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9073 - val_dice_class_2: 0.8911 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8312 - val_iou_class_2: 0.8052 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1357 - learning_rate: 1.0935e-07
# Epoch 42/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9439 - dice_class_2: 0.9475 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9990 - iou_class_1: 0.8940 - iou_class_2: 0.9007 - iou_coef_multiclass: 0.9971 - loss: 0.0774
# Epoch 42: val_loss did not improve from 0.13059
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1e-07.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9439 - dice_class_2: 0.9475 - dice_coef_multiclass: 0.9986 - iou_class_0: 0.9990 - iou_class_1: 0.8940 - iou_class_2: 0.9007 - iou_coef_multiclass: 0.9971 - loss: 0.0774 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9041 - val_dice_class_2: 0.8912 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8262 - val_iou_class_2: 0.8048 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1390 - learning_rate: 1.0935e-07
# Epoch 43/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9428 - dice_class_2: 0.9506 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8921 - iou_class_2: 0.9062 - iou_coef_multiclass: 0.9971 - loss: 0.0771
# Epoch 43: val_loss did not improve from 0.13059
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9428 - dice_class_2: 0.9506 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8921 - iou_class_2: 0.9062 - iou_coef_multiclass: 0.9971 - loss: 0.0771 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9071 - val_dice_class_2: 0.8885 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8308 - val_iou_class_2: 0.8007 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1367 - learning_rate: 1.0000e-07
# Epoch 44/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9428 - dice_class_2: 0.9510 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8919 - iou_class_2: 0.9068 - iou_coef_multiclass: 0.9971 - loss: 0.0761
# Epoch 44: val_loss did not improve from 0.13059
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 127ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9428 - dice_class_2: 0.9509 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8919 - iou_class_2: 0.9067 - iou_coef_multiclass: 0.9971 - loss: 0.0761 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9063 - val_dice_class_2: 0.8909 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8294 - val_iou_class_2: 0.8046 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1364 - learning_rate: 1.0000e-07
# Epoch 45/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9409 - dice_class_2: 0.9480 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8885 - iou_class_2: 0.9015 - iou_coef_multiclass: 0.9970 - loss: 0.0796
# Epoch 45: val_loss did not improve from 0.13059
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9409 - dice_class_2: 0.9480 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8886 - iou_class_2: 0.9015 - iou_coef_multiclass: 0.9970 - loss: 0.0796 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9038 - val_dice_class_2: 0.8890 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8254 - val_iou_class_2: 0.8021 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1404 - learning_rate: 1.0000e-07
# Epoch 46/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9402 - dice_class_2: 0.9489 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8875 - iou_class_2: 0.9031 - iou_coef_multiclass: 0.9970 - loss: 0.0793
# Epoch 46: val_loss did not improve from 0.13059
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9402 - dice_class_2: 0.9489 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8875 - iou_class_2: 0.9031 - iou_coef_multiclass: 0.9970 - loss: 0.0793 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9096 - val_dice_class_2: 0.8895 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8346 - val_iou_class_2: 0.8021 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1348 - learning_rate: 1.0000e-07
# Epoch 47/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9422 - dice_class_2: 0.9501 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8911 - iou_class_2: 0.9053 - iou_coef_multiclass: 0.9970 - loss: 0.0780
# Epoch 47: val_loss did not improve from 0.13059
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 127ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9422 - dice_class_2: 0.9501 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8911 - iou_class_2: 0.9053 - iou_coef_multiclass: 0.9970 - loss: 0.0780 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9068 - val_dice_class_2: 0.8930 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8305 - val_iou_class_2: 0.8084 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1352 - learning_rate: 1.0000e-07
# Epoch 48/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9405 - dice_class_2: 0.9472 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8879 - iou_class_2: 0.9001 - iou_coef_multiclass: 0.9970 - loss: 0.0799
# Epoch 48: val_loss did not improve from 0.13059
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9405 - dice_class_2: 0.9472 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8879 - iou_class_2: 0.9001 - iou_coef_multiclass: 0.9970 - loss: 0.0799 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9046 - val_dice_class_2: 0.8913 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8269 - val_iou_class_2: 0.8056 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1378 - learning_rate: 1.0000e-07
# Epoch 49/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9425 - dice_class_2: 0.9492 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8914 - iou_class_2: 0.9039 - iou_coef_multiclass: 0.9971 - loss: 0.0778
# Epoch 49: val_loss did not improve from 0.13059
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 127ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9425 - dice_class_2: 0.9492 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8914 - iou_class_2: 0.9039 - iou_coef_multiclass: 0.9971 - loss: 0.0778 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9064 - val_dice_class_2: 0.8903 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8295 - val_iou_class_2: 0.8037 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1372 - learning_rate: 1.0000e-07
# Epoch 50/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9411 - dice_class_2: 0.9475 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8891 - iou_class_2: 0.9007 - iou_coef_multiclass: 0.9970 - loss: 0.0794
# Epoch 50: val_loss did not improve from 0.13059
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9986 - dice_class_0: 0.9995 - dice_class_1: 0.9411 - dice_class_2: 0.9475 - dice_coef_multiclass: 0.9985 - iou_class_0: 0.9990 - iou_class_1: 0.8891 - iou_class_2: 0.9007 - iou_coef_multiclass: 0.9970 - loss: 0.0794 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9051 - val_dice_class_2: 0.8902 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8278 - val_iou_class_2: 0.8035 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1378 - learning_rate: 1.0000e-07
# Restoring model weights from the end of the best epoch: 36.
# ✓ Training completed
#
# ================================================================================
# EVALUATION: Deeper+Focal+EIoU+MC+ECA(Decoder)
# ================================================================================
#
# Precision, Recall, F1 Score per class:
#   Background: Precision=0.9993, Recall=0.9994, F1=0.9994
#   Disc: Precision=0.9033, Recall=0.9164, F1=0.9098
#   Cup: Precision=0.9142, Recall=0.8723, F1=0.8928
#
# Macro-averaged metrics:
#   Precision: 0.9389
#   Recall: 0.9294
#   F1 Score: 0.9340
#   Background: Dice=0.9994, IoU=0.9987
#   Disc: Dice=0.9098, IoU=0.8345
#   Cup: Dice=0.8928, IoU=0.8063
#
# MC Dropout Evaluation:
#
# Running MC Dropout with 10 stochastic forward passes...
#   Completed: 5/10 forward passes
#   Completed: 10/10 forward passes
# ✓ MC Dropout completed
#   Background uncertainty: 0.0002
#   Disc uncertainty: 0.0004
#   Cup uncertainty: 0.0002
#
# ================================================================================
# GENERATING VISUALIZATIONS
# ================================================================================
# ✓ Training curves saved: results/Deeper+Focal+EIoU+MC+ECA(Decoder)_training_curves.png
# ✓ Confusion matrices saved: results/Deeper+Focal+EIoU+MC+ECA(Decoder)_confusion_matrices.png
# Confusion Matrix:
# [[25768617    16373        0]
#  [   16978   288729     9364]
#  [      53    14547    99739]]
#
# Normalized Confusion Matrix:
# [[0.999 0.001 0.   ]
#  [0.054 0.916 0.03 ]
#  [0.    0.127 0.872]]
#
# ====================================================================================================
#                                 ✓ TRAINING AND EVALUATION COMPLETED!
# ====================================================================================================
#
# Model: Deeper + Focal-EIoU + MC Dropout + ECA Attention (DECODER-ONLY)
# Attention: ECA on decoder blocks (4 blocks)
# Parameters: 37,131,417
# Results saved in: results/
#
# ====================================================================================================
