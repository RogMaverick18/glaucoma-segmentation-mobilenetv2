# %%
"""
MOBILENET-UNET WITH MSCA (MULTI-SCALE CONTEXT AGGREGATOR)
===========================================================
Enhanced with MSCA from ODFormer for multi-scale feature aggregation

MSCA Module:
- Multi-scale dilated convolutions (rates: 1, 2, 3, 5)
- Captures features at different receptive fields
- Lightweight feature fusion with residual connection
- From ODFormer architecture (Swin + MSCA + LBFR)

Configuration:
- Base: Deeper Decoder + Focal-EIoU + MC Dropout
- Enhancement: MSCA on decoder outputs
- MSCA Placement: After each decoder block (4 total)
"""

import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, backend as K
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import albumentations as A
import warnings
import gc
warnings.filterwarnings('ignore')

# Set plot style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# ============================================================================
# GPU CONFIGURATION
# ============================================================================

def configure_gpu():
    """Configure GPU settings for optimal performance"""
    print("Configuring GPU settings...")
    physical_devices = tf.config.list_physical_devices('GPU')
    if physical_devices:
        try:
            for gpu in physical_devices:
                tf.config.experimental.set_memory_growth(gpu, True)
            tf.config.set_visible_devices(physical_devices[0], 'GPU')
            print(f"✓ GPU found: {physical_devices}")
            return True
        except RuntimeError as e:
            print(f"✗ GPU configuration error: {e}")
            return False
    else:
        print("✗ No GPU found, using CPU")
        return False

# ============================================================================
# DATA LOADING
# ============================================================================

def load_images_masks(images_folder, masks_folder, img_size=(256,256)):
    """Load images and masks from folders"""
    images, masks = [], []
    image_files = sorted(os.listdir(images_folder))
    mask_files = sorted(os.listdir(masks_folder))
    mask_dict = {os.path.splitext(f)[0]: f for f in mask_files}
    
    for img_file in image_files:
        base = os.path.splitext(img_file)[0]
        if base in mask_dict:
            img = cv2.imread(os.path.join(images_folder, img_file))
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, img_size) / 255.0
            
            mask = cv2.imread(os.path.join(masks_folder, mask_dict[base]), cv2.IMREAD_GRAYSCALE)
            mask = cv2.resize(mask, img_size)
            unique_vals = np.unique(mask)
            if len(unique_vals) > 3 or np.max(unique_vals) > 2:
                mask = np.clip(mask // 85, 0, 2).astype(np.uint8)
            
            images.append(img)
            masks.append(mask)
    
    return np.array(images, dtype=np.float32), np.array(masks, dtype=np.uint8)

def load_all_data(root_dir):
    """Load all data from existing splits and merge"""
    all_images, all_masks = [], []
    for split in ["train", "val", "test"]:
        print(f"Loading {split} data...")
        imgs, msks = load_images_masks(
            os.path.join(root_dir, split, "Images"),
            os.path.join(root_dir, split, "Masks")
        )
        all_images.append(imgs)
        all_masks.append(msks)
        print(f"  {split}: {imgs.shape[0]} samples")
    
    all_images = np.concatenate(all_images, axis=0)
    all_masks = np.concatenate(all_masks, axis=0)
    return all_images, all_masks

def create_new_split(all_images, all_masks):
    """Create new split: 600 train, 200 val, 400 test"""
    X_temp, X_test, y_temp, y_test = train_test_split(
        all_images, all_masks, test_size=400, random_state=42
    )
    X_train, X_val, y_train, y_val = train_test_split(
        X_temp, y_temp, test_size=200, random_state=42
    )
    print(f"Split - Train: {X_train.shape[0]}, Val: {X_val.shape[0]}, Test: {X_test.shape[0]}")
    return (X_train, y_train), (X_val, y_val), (X_test, y_test)

# ============================================================================
# DATA AUGMENTATION
# ============================================================================

def setup_augmentations():
    return A.Compose([
        A.RandomBrightnessContrast(brightness_limit=0.15, contrast_limit=0.15, p=0.7),
        A.HueSaturationValue(hue_shift_limit=10, sat_shift_limit=15, val_shift_limit=10, p=0.5),
        A.GaussianBlur(blur_limit=3, p=0.3),
        A.RandomGamma(gamma_limit=(80, 120), p=0.3),
    ])

def data_generator(images, masks, batch_size, augment=None):
    idxs = np.arange(len(images))
    while True:
        np.random.shuffle(idxs)
        for i in range(0, len(images), batch_size):
            batch_idxs = idxs[i:i+batch_size]
            batch_x, batch_y = [], []
            
            for idx in batch_idxs:
                img, mask = images[idx], masks[idx]
                
                if augment:
                    aug = augment(image=img, mask=mask)
                    img_aug, mask_aug = aug['image'], aug['mask']
                else:
                    img_aug, mask_aug = img, mask
                
                mask_cat = to_categorical(mask_aug, num_classes=3)
                batch_x.append(img_aug)
                batch_y.append(mask_cat)
            
            yield np.stack(batch_x).astype(np.float32), np.stack(batch_y).astype(np.float32)

# ============================================================================
# MSCA MODULE (FROM ODFORMER)
# ============================================================================

def msca_block(x, channels, dilation_rates=[1, 2, 3, 5], block_name='msca'):
    """
    Multi-scale Context Aggregator (MSCA) from ODFormer
    
    Features:
    - Multi-scale dilated convolutions for different receptive fields
    - Lightweight feature fusion
    - Residual connection for gradient flow
    
    Args:
        x: Input feature map
        channels: Number of channels
        dilation_rates: List of dilation rates for multi-scale context
        block_name: Name prefix for layers
    """
    # Multi-scale dilated convolutions
    multi_scale_features = []
    filters_per_branch = channels // len(dilation_rates)
    
    for i, rate in enumerate(dilation_rates):
        branch = layers.Conv2D(
            filters_per_branch, 
            (3, 3), 
            padding='same',
            dilation_rate=rate,
            use_bias=False,
            name=f'{block_name}_conv_d{rate}'
        )(x)
        branch = layers.BatchNormalization(name=f'{block_name}_bn_d{rate}')(branch)
        branch = layers.Activation('relu', name=f'{block_name}_relu_d{rate}')(branch)
        multi_scale_features.append(branch)
    
    # Concatenate multi-scale features
    concat = layers.Concatenate(name=f'{block_name}_concat')(multi_scale_features)
    
    # Fusion layer
    fused = layers.Conv2D(channels, (1, 1), use_bias=False, name=f'{block_name}_fusion')(concat)
    fused = layers.BatchNormalization(name=f'{block_name}_fusion_bn')(fused)
    fused = layers.Activation('relu', name=f'{block_name}_fusion_relu')(fused)
    
    # Residual connection
    output = layers.Add(name=f'{block_name}_residual')([x, fused])
    
    return output

# ============================================================================
# LOSS FUNCTIONS
# ============================================================================

def focal_loss(y_true, y_pred, gamma=2.0, alpha=None, epsilon=1e-7):
    if alpha is None:
        alpha = [0.25, 1.0, 1.0]
    
    y_pred = K.clip(y_pred, epsilon, 1.0 - epsilon)
    focal_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        pt = y_pred_c
        focal_weight = K.pow(1.0 - pt, gamma)
        cross_entropy = -K.log(pt)
        focal_loss_c = alpha[c] * focal_weight * cross_entropy * y_true_c
        focal_loss_value += K.mean(focal_loss_c)
    
    return focal_loss_value

def enhanced_iou_loss(y_true, y_pred, smooth=1e-7):
    eiou_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        
        intersection = K.sum(y_true_c * y_pred_c, axis=[1, 2])
        union = K.sum(y_true_c, axis=[1, 2]) + K.sum(y_pred_c, axis=[1, 2]) - intersection
        iou = (intersection + smooth) / (union + smooth)
        
        height = K.cast(K.shape(y_true_c)[1], 'float32')
        width = K.cast(K.shape(y_true_c)[2], 'float32')
        
        y_coords = K.arange(0, height)
        x_coords = K.arange(0, width)
        y_grid = K.tile(K.reshape(y_coords, (-1, 1)), (1, K.cast(width, 'int32')))
        x_grid = K.tile(K.reshape(x_coords, (1, -1)), (K.cast(height, 'int32'), 1))
        y_grid = K.cast(y_grid, 'float32')
        x_grid = K.cast(x_grid, 'float32')
        
        true_mass = K.sum(y_true_c, axis=[1, 2]) + smooth
        true_center_y = K.sum(y_true_c * y_grid, axis=[1, 2]) / true_mass
        true_center_x = K.sum(y_true_c * x_grid, axis=[1, 2]) / true_mass
        
        pred_mass = K.sum(y_pred_c, axis=[1, 2]) + smooth
        pred_center_y = K.sum(y_pred_c * y_grid, axis=[1, 2]) / pred_mass
        pred_center_x = K.sum(y_pred_c * x_grid, axis=[1, 2]) / pred_mass
        
        center_distance = K.square(true_center_y - pred_center_y) + K.square(true_center_x - pred_center_x)
        diagonal = K.square(height) + K.square(width)
        center_penalty = center_distance / (diagonal + smooth)
        
        true_width = K.sqrt(K.sum(K.sum(y_true_c, axis=1), axis=1) + smooth)
        true_height = K.sqrt(K.sum(K.sum(y_true_c, axis=2), axis=1) + smooth)
        pred_width = K.sqrt(K.sum(K.sum(y_pred_c, axis=1), axis=1) + smooth)
        pred_height = K.sqrt(K.sum(K.sum(y_pred_c, axis=2), axis=1) + smooth)
        
        width_diff = K.square(pred_width - true_width)
        height_diff = K.square(pred_height - true_height)
        aspect_penalty = width_diff / (K.square(width) + smooth) + height_diff / (K.square(height) + smooth)
        
        eiou_c = 1.0 - iou + center_penalty + aspect_penalty
        eiou_loss_value += K.mean(eiou_c)
    
    return eiou_loss_value / 3.0

def focal_eiou_combined_loss(y_true, y_pred, focal_weight=1.0, eiou_weight=1.0, gamma=2.0, alpha=None):
    fl = focal_loss(y_true, y_pred, gamma=gamma, alpha=alpha)
    eiou = enhanced_iou_loss(y_true, y_pred)
    return focal_weight * fl + eiou_weight * eiou

# ============================================================================
# MODEL ARCHITECTURE WITH MSCA
# ============================================================================

def enhanced_decoder_block_with_msca(x, skip_connection, filters, block_name, dropout_rate=0.3):
    """Enhanced decoder block with MSCA for multi-scale context aggregation"""
    x = layers.UpSampling2D((2, 2), name=f'{block_name}_upsample')(x)
    
    if skip_connection.shape[-1] != x.shape[-1]:
        skip_connection = layers.Conv2D(x.shape[-1], (1, 1), activation='relu', 
                                      padding='same', name=f'{block_name}_skip_align')(skip_connection)
        skip_connection = layers.BatchNormalization(name=f'{block_name}_skip_bn')(skip_connection)
    
    x = layers.Concatenate(name=f'{block_name}_concat')([x, skip_connection])
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv1')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn1')(x)
    x = layers.Dropout(dropout_rate, name=f'{block_name}_dropout')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv2')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn2')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv3')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn3')(x)
    
    residual = x
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv4')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn4')(x)
    
    x = layers.Add(name=f'{block_name}_residual')([x, residual])
    x = layers.Conv2D(filters, (1, 1), activation='relu', padding='same', name=f'{block_name}_conv_final')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn_final')(x)
    
    # Apply MSCA for multi-scale context aggregation
    x = msca_block(x, filters, dilation_rates=[1, 2, 3, 5], block_name=f'{block_name}_msca')
    
    return x

def build_unet_with_msca(input_shape=(256, 256, 3), num_classes=3, dropout_rate=0.3):
    """Build MobileNetV2-UNet with MSCA modules"""
    inputs = layers.Input(input_shape, dtype='float32')
    backbone = MobileNetV2(input_tensor=inputs, weights='imagenet', include_top=False)
    
    skip_1 = backbone.get_layer('block_1_expand_relu').output
    skip_2 = backbone.get_layer('block_3_expand_relu').output
    skip_3 = backbone.get_layer('block_6_expand_relu').output
    skip_4 = backbone.get_layer('block_13_expand_relu').output
    bridge = backbone.output
    
    # Deeper bridge
    bridge = layers.Conv2D(1024, (3, 3), activation='relu', padding='same')(bridge)
    bridge = layers.BatchNormalization()(bridge)
    bridge = layers.Dropout(dropout_rate, name='bridge_dropout')(bridge)
    
    # Decoder with MSCA modules
    x = enhanced_decoder_block_with_msca(bridge, skip_4, 512, 'decoder_1', dropout_rate)
    x = enhanced_decoder_block_with_msca(x, skip_3, 256, 'decoder_2', dropout_rate)
    x = enhanced_decoder_block_with_msca(x, skip_2, 128, 'decoder_3', dropout_rate * 0.7)
    x = enhanced_decoder_block_with_msca(x, skip_1, 64, 'decoder_4', dropout_rate * 0.5)
    
    # Final upsampling
    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    
    outputs = layers.Conv2D(num_classes, (1, 1), activation='softmax', dtype='float32')(x)
    
    model = models.Model(inputs, outputs)
    
    # Print configuration
    dropout_layers = [layer for layer in model.layers if isinstance(layer, layers.Dropout)]
    print(f"\nModel Configuration:")
    print(f"  Total Parameters: {model.count_params():,}")
    print(f"  Dropout Layers: {len(dropout_layers)}")
    print(f"  MSCA Modules: 4 (one per decoder block)")
    print(f"  MSCA Dilation Rates: [1, 2, 3, 5]")
    print(f"  Enhancement: Multi-scale Context Aggregation from ODFormer")
    
    return model

# ============================================================================
# METRICS
# ============================================================================

def dice_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    return (2. * intersection + smooth) / (K.sum(y_true_class) + K.sum(y_pred_class) + smooth)

def dice_class_0(y_true, y_pred): return dice_coef_class(y_true, y_pred, 0)
def dice_class_1(y_true, y_pred): return dice_coef_class(y_true, y_pred, 1)
def dice_class_2(y_true, y_pred): return dice_coef_class(y_true, y_pred, 2)

def iou_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    union = K.sum(y_true_class) + K.sum(y_pred_class) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_class_0(y_true, y_pred): return iou_coef_class(y_true, y_pred, 0)
def iou_class_1(y_true, y_pred): return iou_coef_class(y_true, y_pred, 1)
def iou_class_2(y_true, y_pred): return iou_coef_class(y_true, y_pred, 2)

def mc_dropout_predict(model, X, num_samples=15, batch_size=4, verbose=True):
    """MC Dropout prediction for uncertainty estimation"""
    if verbose:
        print(f"\nRunning MC Dropout with {num_samples} stochastic forward passes...")
    
    predictions = []
    num_batches = int(np.ceil(len(X) / batch_size))
    
    for i in range(num_samples):
        if verbose and (i + 1) % 5 == 0:
            print(f"  Completed: {i+1}/{num_samples} forward passes")
        
        batch_preds = []
        for batch_idx in range(num_batches):
            start_idx = batch_idx * batch_size
            end_idx = min(start_idx + batch_size, len(X))
            X_batch = X[start_idx:end_idx]
            
            pred_batch = model(X_batch, training=True)
            batch_preds.append(pred_batch.numpy())
        
        pred = np.concatenate(batch_preds, axis=0)
        predictions.append(pred)
        
        if (i + 1) % 5 == 0:
            gc.collect()
    
    all_preds = np.array(predictions)
    mean_pred = np.mean(all_preds, axis=0)
    std_pred = np.std(all_preds, axis=0)
    
    del all_preds
    gc.collect()
    
    if verbose:
        print(f"✓ MC Dropout completed")
    
    return mean_pred, std_pred

# ============================================================================
# VISUALIZATION FUNCTIONS
# ============================================================================

def plot_sample_predictions(model, X_test, y_test, model_name, num_samples=6, save_dir='results'):
    """Visualize sample predictions with original image, GT, segmented mask, and overlay"""
    os.makedirs(save_dir, exist_ok=True)
    
    y_pred = model.predict(X_test[:num_samples], verbose=0, batch_size=4)
    y_pred_labels = np.argmax(y_pred, axis=-1)
    
    colors = {0: [0, 0, 0], 1: [0, 255, 0], 2: [255, 0, 0]}
    
    fig, axes = plt.subplots(num_samples, 4, figsize=(16, 4*num_samples))
    
    for i in range(num_samples):
        # Original image
        axes[i, 0].imshow(X_test[i])
        axes[i, 0].set_title('Original Image', fontsize=12, fontweight='bold')
        axes[i, 0].axis('off')
        
        # Ground truth
        gt_colored = np.zeros((256, 256, 3), dtype=np.uint8)
        for class_id, color in colors.items():
            gt_colored[y_test[i] == class_id] = color
        axes[i, 1].imshow(gt_colored)
        axes[i, 1].set_title('Ground Truth (GT)', fontsize=12, fontweight='bold')
        axes[i, 1].axis('off')
        
        # Segmented mask
        pred_colored = np.zeros((256, 256, 3), dtype=np.uint8)
        for class_id, color in colors.items():
            pred_colored[y_pred_labels[i] == class_id] = color
        axes[i, 2].imshow(pred_colored)
        axes[i, 2].set_title('Segmented Mask', fontsize=12, fontweight='bold')
        axes[i, 2].axis('off')
        
        # Overlay
        overlay = X_test[i].copy()
        for class_id, color in colors.items():
            if class_id > 0:
                mask = (y_pred_labels[i] == class_id).astype(np.float32)
                mask_rgb = np.stack([mask * color[0]/255, mask * color[1]/255, mask * color[2]/255], axis=-1)
                overlay = overlay * 0.6 + mask_rgb * 0.4
        axes[i, 3].imshow(overlay)
        axes[i, 3].set_title('Overlay', fontsize=12, fontweight='bold')
        axes[i, 3].axis('off')
        
        # Calculate dice
        y_test_cat = to_categorical(y_test[i], num_classes=3)
        y_pred_cat = to_categorical(y_pred_labels[i], num_classes=3)
        
        disc_dice = 2 * np.sum(y_test_cat[:,:,1] * y_pred_cat[:,:,1]) / (np.sum(y_test_cat[:,:,1]) + np.sum(y_pred_cat[:,:,1]) + 1e-7)
        cup_dice = 2 * np.sum(y_test_cat[:,:,2] * y_pred_cat[:,:,2]) / (np.sum(y_test_cat[:,:,2]) + np.sum(y_pred_cat[:,:,2]) + 1e-7)
        
        axes[i, 0].text(0.5, -0.1, f'Sample {i+1}\nDisc: {disc_dice:.3f} | Cup: {cup_dice:.3f}', 
                       transform=axes[i, 0].transAxes, ha='center', fontsize=10, 
                       bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
    
    plt.suptitle(f'{model_name} - Predictions: Original | GT | Segmented | Overlay', 
                 fontsize=16, fontweight='bold', y=0.995)
    plt.tight_layout()
    plt.savefig(f'{save_dir}/{model_name}_predictions.png', dpi=150, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_predictions.png")
    plt.show()
    plt.close()

def plot_training_history(history, model_name, save_dir='results'):
    """Plot training history"""
    os.makedirs(save_dir, exist_ok=True)
    
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    
    # Loss curves
    axes[0, 0].plot(history.history['loss'], label='Train Loss', linewidth=2)
    axes[0, 0].plot(history.history['val_loss'], label='Val Loss', linewidth=2)
    axes[0, 0].set_title('Loss Curves', fontsize=14, fontweight='bold')
    axes[0, 0].set_xlabel('Epoch', fontsize=12)
    axes[0, 0].set_ylabel('Loss', fontsize=12)
    axes[0, 0].legend(fontsize=10)
    axes[0, 0].grid(True, alpha=0.3)
    
    # Overall Dice
    axes[0, 1].plot(history.history['dice_coef_multiclass'], label='Train Dice', linewidth=2)
    axes[0, 1].plot(history.history['val_dice_coef_multiclass'], label='Val Dice', linewidth=2)
    axes[0, 1].set_title('Overall Dice Coefficient', fontsize=14, fontweight='bold')
    axes[0, 1].set_xlabel('Epoch', fontsize=12)
    axes[0, 1].set_ylabel('Dice', fontsize=12)
    axes[0, 1].legend(fontsize=10)
    axes[0, 1].grid(True, alpha=0.3)
    
    # Disc Dice
    axes[1, 0].plot(history.history['dice_class_1'], label='Train Disc Dice', linewidth=2, color='green')
    axes[1, 0].plot(history.history['val_dice_class_1'], label='Val Disc Dice', linewidth=2, color='darkgreen')
    axes[1, 0].set_title('Disc Segmentation (Class 1)', fontsize=14, fontweight='bold')
    axes[1, 0].set_xlabel('Epoch', fontsize=12)
    axes[1, 0].set_ylabel('Dice', fontsize=12)
    axes[1, 0].legend(fontsize=10)
    axes[1, 0].grid(True, alpha=0.3)
    
    # Cup Dice
    axes[1, 1].plot(history.history['dice_class_2'], label='Train Cup Dice', linewidth=2, color='red')
    axes[1, 1].plot(history.history['val_dice_class_2'], label='Val Cup Dice', linewidth=2, color='darkred')
    axes[1, 1].set_title('Cup Segmentation (Class 2)', fontsize=14, fontweight='bold')
    axes[1, 1].set_xlabel('Epoch', fontsize=12)
    axes[1, 1].set_ylabel('Dice', fontsize=12)
    axes[1, 1].legend(fontsize=10)
    axes[1, 1].grid(True, alpha=0.3)
    
    plt.suptitle(f'{model_name} - Training History', fontsize=16, fontweight='bold')
    plt.tight_layout()
    plt.savefig(f'{save_dir}/{model_name}_history.png', dpi=150, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_history.png")
    plt.show()
    plt.close()

def plot_training_curves(history, model_name, save_dir='results'):
    """Plot training loss and accuracy curves"""
    os.makedirs(save_dir, exist_ok=True)
    
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    
    # Loss
    axes[0].plot(history.history['loss'], label='Training Loss', linewidth=2)
    axes[0].plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
    axes[0].set_title(f'{model_name} - Loss Over Epochs', fontsize=14, fontweight='bold')
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('Loss', fontsize=12)
    axes[0].legend(fontsize=10)
    axes[0].grid(True, alpha=0.3)
    
    # Accuracy
    axes[1].plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
    axes[1].plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
    axes[1].set_title(f'{model_name} - Accuracy Over Epochs', fontsize=14, fontweight='bold')
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('Accuracy', fontsize=12)
    axes[1].legend(fontsize=10)
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(f"{save_dir}/{model_name}_training_curves.png", dpi=300, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_training_curves.png")
    plt.show()
    plt.close()

def plot_confusion_matrices(y_true, y_pred, model_name, save_dir='results'):
    """Plot confusion matrices"""
    os.makedirs(save_dir, exist_ok=True)
    
    y_true_labels = np.argmax(y_true, axis=-1).flatten()
    y_pred_labels = np.argmax(y_pred, axis=-1).flatten()
    
    cm = confusion_matrix(y_true_labels, y_pred_labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    class_names = ['Background', 'Disc', 'Cup']
    
    # Regular confusion matrix
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[0], cbar_kws={'label': 'Count'})
    axes[0].set_title(f'{model_name}\nConfusion Matrix', fontsize=14, fontweight='bold')
    axes[0].set_ylabel('True Label', fontsize=12)
    axes[0].set_xlabel('Predicted Label', fontsize=12)
    
    # Normalized confusion matrix
    sns.heatmap(cm_normalized, annot=True, fmt='.3f', cmap='Greens',
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[1], cbar_kws={'label': 'Proportion'})
    axes[1].set_title(f'{model_name}\nNormalized Confusion Matrix', fontsize=14, fontweight='bold')
    axes[1].set_ylabel('True Label', fontsize=12)
    axes[1].set_xlabel('Predicted Label', fontsize=12)
    
    plt.tight_layout()
    plt.savefig(f"{save_dir}/{model_name}_confusion_matrices.png", dpi=300, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_confusion_matrices.png")
    plt.show()
    plt.close()
    
    print(f"\nConfusion Matrix:\n{cm}")
    print(f"\nNormalized Confusion Matrix:\n{np.round(cm_normalized, 3)}")
    
    return cm, cm_normalized

# ============================================================================
# TRAINING AND EVALUATION
# ============================================================================

def train_model(X_train, y_train, X_val, y_val, X_test, y_test, model_name, 
               augment=None, save_dir='results'):
    """Train model with MSCA enhancement"""
    print(f"\n{'='*80}")
    print(f"TRAINING: {model_name}")
    print(f"{'='*80}")
    print(f"  Loss: Focal + EIoU")
    print(f"  Architecture: Deeper Decoder + MC Dropout + MSCA")
    print(f"  MSCA: Multi-scale Context Aggregator from ODFormer")
    
    K.clear_session()
    
    # Build model
    model = build_unet_with_msca(dropout_rate=0.3)
    param_count = model.count_params()
    
    # Compile
    model.compile(
        optimizer=optimizers.Adam(learning_rate=5e-4),
        loss=focal_eiou_combined_loss,
        metrics=[dice_coef_multiclass, dice_class_0, dice_class_1, dice_class_2,
                "accuracy", iou_coef_multiclass, iou_class_0, iou_class_1, iou_class_2]
    )
    
    # Callbacks
    checkpoint = ModelCheckpoint(f"{save_dir}/{model_name}.keras", save_best_only=True, 
                                verbose=1, monitor='val_loss', mode='min')
    reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=3, 
                                  verbose=1, mode='min', min_lr=1e-7)
    early_stop = EarlyStopping(monitor="val_loss", patience=10, verbose=1, 
                              restore_best_weights=True, mode='min')
    
    # Training
    batch_size = 4
    steps_train = X_train.shape[0] // batch_size
    steps_val = X_val.shape[0] // batch_size
    
    history = model.fit(
        data_generator(X_train, y_train, batch_size, augment),
        validation_data=data_generator(X_val, y_val, batch_size, None),
        steps_per_epoch=steps_train,
        validation_steps=steps_val,
        epochs=50,
        callbacks=[checkpoint, reduce_lr, early_stop],
        verbose=1
    )
    
    print(f"✓ Training completed")
    
    # Visualizations
    print("\nGenerating visualizations...")
    plot_training_curves(history, model_name, save_dir)
    plot_training_history(history, model_name, save_dir)
    plot_sample_predictions(model, X_test, y_test, model_name, num_samples=6, save_dir=save_dir)
    
    return model, history, param_count

def evaluate_model(model, X_test, y_test, model_name, run_mc_dropout=True):
    """Evaluate model"""
    print(f"\n{'='*80}")
    print(f"EVALUATION: {model_name}")
    print(f"{'='*80}")
    
    y_test_cat = np.array([to_categorical(mask, num_classes=3) for mask in y_test])
    
    # Predict
    y_pred = model.predict(X_test, verbose=0, batch_size=8)
    
    # Confusion matrices
    plot_confusion_matrices(y_test_cat, y_pred, model_name, save_dir='results')
    
    # Classification metrics
    y_true_labels = np.argmax(y_test_cat, axis=-1).flatten()
    y_pred_labels = np.argmax(y_pred, axis=-1).flatten()
    
    precision = precision_score(y_true_labels, y_pred_labels, average=None, zero_division=0)
    recall = recall_score(y_true_labels, y_pred_labels, average=None, zero_division=0)
    f1 = f1_score(y_true_labels, y_pred_labels, average=None, zero_division=0)
    
    print(f"\nPrecision, Recall, F1 Score per class:")
    class_names = ["Background", "Disc", "Cup"]
    for idx, cname in enumerate(class_names):
        print(f"  {cname}: Precision={precision[idx]:.4f}, Recall={recall[idx]:.4f}, F1={f1[idx]:.4f}")
    
    print(f"\nMacro-averaged metrics:")
    print(f"  Precision: {np.mean(precision):.4f}")
    print(f"  Recall: {np.mean(recall):.4f}")
    print(f"  F1 Score: {np.mean(f1):.4f}")
    
    # Per-class Dice and IoU
    results = {'standard': {}}
    for cidx, cname in enumerate(class_names):
        y_true_c = (np.argmax(y_test_cat, axis=-1) == cidx).astype(np.float32)
        y_pred_c = (np.argmax(y_pred, axis=-1) == cidx).astype(np.float32)
        
        intersection = np.sum(y_true_c * y_pred_c)
        dice = (2. * intersection + 1e-7) / (np.sum(y_true_c) + np.sum(y_pred_c) + 1e-7)
        union = np.sum(y_true_c) + np.sum(y_pred_c) - intersection
        iou = (intersection + 1e-7) / (union + 1e-7)
        
        results['standard'][cname] = {'dice': dice, 'iou': iou}
        print(f"  {cname}: Dice={dice:.4f}, IoU={iou:.4f}")
    
    # MC Dropout
    if run_mc_dropout:
        print("\nMC Dropout Evaluation:")
        mean_pred, std_pred = mc_dropout_predict(model, X_test[:100], num_samples=10, verbose=True)
        results['mc_dropout'] = {}
        for cidx, cname in enumerate(class_names):
            mean_std = np.mean(std_pred[:, :, :, cidx])
            results['mc_dropout'][cname] = {'mean_uncertainty': mean_std}
            print(f"  {cname} uncertainty: {mean_std:.4f}")
    
    return results

# ============================================================================
# MAIN EXECUTION
# ============================================================================

if __name__ == "__main__":
    # Setup
    gpu_available = configure_gpu()
    root_dir = "/kaggle/input/refuge/REFUGE/"
    train_aug = setup_augmentations()
    save_dir = "results"
    os.makedirs(save_dir, exist_ok=True)
    
    print(f"\n{'='*100}")
    print(f"{'MOBILENET-UNET WITH MSCA (MULTI-SCALE CONTEXT AGGREGATOR)':^100s}")
    print(f"{'='*100}")
    
    # Load data
    all_images, all_masks = load_all_data(root_dir)
    (X_train, y_train), (X_val, y_val), (X_test, y_test) = create_new_split(all_images, all_masks)
    
    # Train model
    model, history, params = train_model(
        X_train, y_train, X_val, y_val, X_test, y_test,
        "Deeper_Focal_MC_MSCA",
        augment=train_aug, save_dir=save_dir
    )
    
    # Evaluate
    results = evaluate_model(model, X_test, y_test, "Deeper+Focal+MC+MSCA", run_mc_dropout=True)
    
    print(f"\n{'='*100}")
    print(f"{'✓ TRAINING AND EVALUATION COMPLETED!':^100s}")
    print(f"{'='*100}")
    print(f"\nModel: Deeper + Focal + EIoU + MC Dropout + MSCA")
    print(f"Enhancement: Multi-scale Context Aggregator from ODFormer")
    print(f"MSCA Dilation Rates: [1, 2, 3, 5]")
    print(f"Parameters: {params:,}")
    print(f"Results saved in: {save_dir}/")
    print(f"\n{'='*100}\n")
# Out:
# Configuring GPU settings...
# ✓ GPU found: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
#
# ====================================================================================================
#                      MOBILENET-UNET WITH MSCA (MULTI-SCALE CONTEXT AGGREGATOR)
# ====================================================================================================
# Loading train data...
#   train: 400 samples
# Loading val data...
#   val: 400 samples
# Loading test data...
#   test: 400 samples
# Split - Train: 600, Val: 200, Test: 400
#
# ================================================================================
# TRAINING: Deeper_Focal_MC_MSCA
# ================================================================================
#   Loss: Focal + EIoU
#   Architecture: Deeper Decoder + MC Dropout + MSCA
#   MSCA: Multi-scale Context Aggregator from ODFormer
#
# Model Configuration:
#   Total Parameters: 40,620,675
#   Dropout Layers: 5
#   MSCA Modules: 4 (one per decoder block)
#   MSCA Dilation Rates: [1, 2, 3, 5]
#   Enhancement: Multi-scale Context Aggregation from ODFormer
# Epoch 1/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.8097 - dice_class_0: 0.8755 - dice_class_1: 0.3144 - dice_class_2: 0.1837 - dice_coef_multiclass: 0.5262 - iou_class_0: 0.8099 - iou_class_1: 0.2022 - iou_class_2: 0.1112 - iou_coef_multiclass: 0.3643 - loss: 1.2533
# Epoch 1: val_loss improved from inf to 0.84804, saving model to results/Deeper_Focal_MC_MSCA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 140s 251ms/step - accuracy: 0.8105 - dice_class_0: 0.8760 - dice_class_1: 0.3153 - dice_class_2: 0.1847 - dice_coef_multiclass: 0.5269 - iou_class_0: 0.8107 - iou_class_1: 0.2029 - iou_class_2: 0.1118 - iou_coef_multiclass: 0.3650 - loss: 1.2522 - val_accuracy: 0.9493 - val_dice_class_0: 0.9758 - val_dice_class_1: 0.4229 - val_dice_class_2: 9.6020e-04 - val_dice_coef_multiclass: 0.8838 - val_iou_class_0: 0.9528 - val_iou_class_1: 0.2690 - val_iou_class_2: 4.8436e-04 - val_iou_coef_multiclass: 0.7918 - val_loss: 0.8480 - learning_rate: 5.0000e-04
# Epoch 2/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9787 - dice_class_0: 0.9898 - dice_class_1: 0.6340 - dice_class_2: 0.4580 - dice_coef_multiclass: 0.8802 - iou_class_0: 0.9799 - iou_class_1: 0.4697 - iou_class_2: 0.3034 - iou_coef_multiclass: 0.7879 - loss: 0.7511
# Epoch 2: val_loss did not improve from 0.84804
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 155ms/step - accuracy: 0.9787 - dice_class_0: 0.9898 - dice_class_1: 0.6343 - dice_class_2: 0.4581 - dice_coef_multiclass: 0.8804 - iou_class_0: 0.9799 - iou_class_1: 0.4701 - iou_class_2: 0.3035 - iou_coef_multiclass: 0.7883 - loss: 0.7506 - val_accuracy: 0.9566 - val_dice_class_0: 0.9778 - val_dice_class_1: 3.2050e-11 - val_dice_class_2: 1.3226e-11 - val_dice_coef_multiclass: 0.9557 - val_iou_class_0: 0.9566 - val_iou_class_1: 3.2050e-11 - val_iou_class_2: 1.3226e-11 - val_iou_coef_multiclass: 0.9153 - val_loss: 0.9889 - learning_rate: 5.0000e-04
# Epoch 3/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9907 - dice_class_0: 0.9960 - dice_class_1: 0.7831 - dice_class_2: 0.6557 - dice_coef_multiclass: 0.9732 - iou_class_0: 0.9921 - iou_class_1: 0.6471 - iou_class_2: 0.5064 - iou_coef_multiclass: 0.9480 - loss: 0.4930
# Epoch 3: val_loss improved from 0.84804 to 0.80815, saving model to results/Deeper_Focal_MC_MSCA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 180ms/step - accuracy: 0.9907 - dice_class_0: 0.9960 - dice_class_1: 0.7832 - dice_class_2: 0.6564 - dice_coef_multiclass: 0.9733 - iou_class_0: 0.9921 - iou_class_1: 0.6472 - iou_class_2: 0.5072 - iou_coef_multiclass: 0.9481 - loss: 0.4925 - val_accuracy: 0.9865 - val_dice_class_0: 0.9934 - val_dice_class_1: 0.2757 - val_dice_class_2: 0.2757 - val_dice_coef_multiclass: 0.9864 - val_iou_class_0: 0.9869 - val_iou_class_1: 0.1718 - val_iou_class_2: 0.1739 - val_iou_coef_multiclass: 0.9732 - val_loss: 0.8082 - learning_rate: 5.0000e-04
# Epoch 4/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9961 - dice_class_0: 0.9986 - dice_class_1: 0.8538 - dice_class_2: 0.8564 - dice_coef_multiclass: 0.9936 - iou_class_0: 0.9973 - iou_class_1: 0.7466 - iou_class_2: 0.7510 - iou_coef_multiclass: 0.9873 - loss: 0.2632
# Epoch 4: val_loss did not improve from 0.80815
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 155ms/step - accuracy: 0.9961 - dice_class_0: 0.9986 - dice_class_1: 0.8538 - dice_class_2: 0.8564 - dice_coef_multiclass: 0.9936 - iou_class_0: 0.9973 - iou_class_1: 0.7467 - iou_class_2: 0.7510 - iou_coef_multiclass: 0.9873 - loss: 0.2630 - val_accuracy: 0.9552 - val_dice_class_0: 0.9777 - val_dice_class_1: 0.3906 - val_dice_class_2: 0.1633 - val_dice_coef_multiclass: 0.9552 - val_iou_class_0: 0.9565 - val_iou_class_1: 0.2451 - val_iou_class_2: 0.0896 - val_iou_coef_multiclass: 0.9144 - val_loss: 0.8380 - learning_rate: 5.0000e-04
# Epoch 5/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9967 - dice_class_0: 0.9989 - dice_class_1: 0.8753 - dice_class_2: 0.8612 - dice_coef_multiclass: 0.9961 - iou_class_0: 0.9978 - iou_class_1: 0.7802 - iou_class_2: 0.7603 - iou_coef_multiclass: 0.9923 - loss: 0.1917
# Epoch 5: val_loss improved from 0.80815 to 0.66497, saving model to results/Deeper_Focal_MC_MSCA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 179ms/step - accuracy: 0.9967 - dice_class_0: 0.9989 - dice_class_1: 0.8753 - dice_class_2: 0.8612 - dice_coef_multiclass: 0.9961 - iou_class_0: 0.9978 - iou_class_1: 0.7802 - iou_class_2: 0.7603 - iou_coef_multiclass: 0.9923 - loss: 0.1917 - val_accuracy: 0.9888 - val_dice_class_0: 0.9949 - val_dice_class_1: 0.4587 - val_dice_class_2: 0.3483 - val_dice_coef_multiclass: 0.9888 - val_iou_class_0: 0.9899 - val_iou_class_1: 0.3155 - val_iou_class_2: 0.2299 - val_iou_coef_multiclass: 0.9779 - val_loss: 0.6650 - learning_rate: 5.0000e-04
# Epoch 6/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9971 - dice_class_0: 0.9991 - dice_class_1: 0.8837 - dice_class_2: 0.8714 - dice_coef_multiclass: 0.9968 - iou_class_0: 0.9981 - iou_class_1: 0.7927 - iou_class_2: 0.7746 - iou_coef_multiclass: 0.9935 - loss: 0.1740
# Epoch 6: val_loss improved from 0.66497 to 0.18000, saving model to results/Deeper_Focal_MC_MSCA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 179ms/step - accuracy: 0.9971 - dice_class_0: 0.9991 - dice_class_1: 0.8838 - dice_class_2: 0.8714 - dice_coef_multiclass: 0.9968 - iou_class_0: 0.9981 - iou_class_1: 0.7928 - iou_class_2: 0.7745 - iou_coef_multiclass: 0.9935 - loss: 0.1740 - val_accuracy: 0.9969 - val_dice_class_0: 0.9990 - val_dice_class_1: 0.8710 - val_dice_class_2: 0.8627 - val_dice_coef_multiclass: 0.9969 - val_iou_class_0: 0.9981 - val_iou_class_1: 0.7746 - val_iou_class_2: 0.7604 - val_iou_coef_multiclass: 0.9938 - val_loss: 0.1800 - learning_rate: 5.0000e-04
# Epoch 7/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9973 - dice_class_0: 0.9991 - dice_class_1: 0.8918 - dice_class_2: 0.8808 - dice_coef_multiclass: 0.9971 - iou_class_0: 0.9983 - iou_class_1: 0.8055 - iou_class_2: 0.7887 - iou_coef_multiclass: 0.9942 - loss: 0.1602
# Epoch 7: val_loss did not improve from 0.18000
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 156ms/step - accuracy: 0.9973 - dice_class_0: 0.9991 - dice_class_1: 0.8918 - dice_class_2: 0.8808 - dice_coef_multiclass: 0.9971 - iou_class_0: 0.9983 - iou_class_1: 0.8056 - iou_class_2: 0.7887 - iou_coef_multiclass: 0.9942 - loss: 0.1602 - val_accuracy: 0.9911 - val_dice_class_0: 0.9964 - val_dice_class_1: 0.7484 - val_dice_class_2: 0.6793 - val_dice_coef_multiclass: 0.9910 - val_iou_class_0: 0.9928 - val_iou_class_1: 0.6077 - val_iou_class_2: 0.5373 - val_iou_coef_multiclass: 0.9822 - val_loss: 0.3201 - learning_rate: 5.0000e-04
# Epoch 8/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9974 - dice_class_0: 0.9992 - dice_class_1: 0.8987 - dice_class_2: 0.8821 - dice_coef_multiclass: 0.9972 - iou_class_0: 0.9983 - iou_class_1: 0.8175 - iou_class_2: 0.7909 - iou_coef_multiclass: 0.9945 - loss: 0.1519
# Epoch 8: val_loss did not improve from 0.18000
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 154ms/step - accuracy: 0.9974 - dice_class_0: 0.9992 - dice_class_1: 0.8987 - dice_class_2: 0.8821 - dice_coef_multiclass: 0.9972 - iou_class_0: 0.9983 - iou_class_1: 0.8175 - iou_class_2: 0.7909 - iou_coef_multiclass: 0.9945 - loss: 0.1519 - val_accuracy: 0.9856 - val_dice_class_0: 0.9937 - val_dice_class_1: 0.4438 - val_dice_class_2: 0.0854 - val_dice_coef_multiclass: 0.9854 - val_iou_class_0: 0.9875 - val_iou_class_1: 0.2949 - val_iou_class_2: 0.0465 - val_iou_coef_multiclass: 0.9713 - val_loss: 0.7661 - learning_rate: 5.0000e-04
# Epoch 9/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9974 - dice_class_0: 0.9992 - dice_class_1: 0.8957 - dice_class_2: 0.8856 - dice_coef_multiclass: 0.9972 - iou_class_0: 0.9983 - iou_class_1: 0.8118 - iou_class_2: 0.7959 - iou_coef_multiclass: 0.9945 - loss: 0.1527
# Epoch 9: val_loss did not improve from 0.18000
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 154ms/step - accuracy: 0.9974 - dice_class_0: 0.9992 - dice_class_1: 0.8957 - dice_class_2: 0.8856 - dice_coef_multiclass: 0.9972 - iou_class_0: 0.9983 - iou_class_1: 0.8119 - iou_class_2: 0.7960 - iou_coef_multiclass: 0.9945 - loss: 0.1526 - val_accuracy: 0.9965 - val_dice_class_0: 0.9987 - val_dice_class_1: 0.8540 - val_dice_class_2: 0.8496 - val_dice_coef_multiclass: 0.9964 - val_iou_class_0: 0.9975 - val_iou_class_1: 0.7506 - val_iou_class_2: 0.7456 - val_iou_coef_multiclass: 0.9928 - val_loss: 0.1989 - learning_rate: 5.0000e-04
# Epoch 10/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9114 - dice_class_2: 0.9018 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9986 - iou_class_1: 0.8378 - iou_class_2: 0.8226 - iou_coef_multiclass: 0.9953 - loss: 0.1298
# Epoch 10: val_loss improved from 0.18000 to 0.16830, saving model to results/Deeper_Focal_MC_MSCA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 179ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9114 - dice_class_2: 0.9019 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9986 - iou_class_1: 0.8378 - iou_class_2: 0.8226 - iou_coef_multiclass: 0.9953 - loss: 0.1297 - val_accuracy: 0.9971 - val_dice_class_0: 0.9990 - val_dice_class_1: 0.8809 - val_dice_class_2: 0.8694 - val_dice_coef_multiclass: 0.9971 - val_iou_class_0: 0.9980 - val_iou_class_1: 0.7891 - val_iou_class_2: 0.7739 - val_iou_coef_multiclass: 0.9942 - val_loss: 0.1683 - learning_rate: 1.5000e-04
# Epoch 11/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9141 - dice_class_2: 0.9081 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9986 - iou_class_1: 0.8423 - iou_class_2: 0.8330 - iou_coef_multiclass: 0.9955 - loss: 0.1248
# Epoch 11: val_loss improved from 0.16830 to 0.16181, saving model to results/Deeper_Focal_MC_MSCA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 178ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9141 - dice_class_2: 0.9081 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9986 - iou_class_1: 0.8422 - iou_class_2: 0.8329 - iou_coef_multiclass: 0.9955 - loss: 0.1248 - val_accuracy: 0.9973 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8866 - val_dice_class_2: 0.8708 - val_dice_coef_multiclass: 0.9972 - val_iou_class_0: 0.9983 - val_iou_class_1: 0.7990 - val_iou_class_2: 0.7752 - val_iou_coef_multiclass: 0.9945 - val_loss: 0.1618 - learning_rate: 1.5000e-04
# Epoch 12/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9156 - dice_class_2: 0.9094 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9986 - iou_class_1: 0.8449 - iou_class_2: 0.8348 - iou_coef_multiclass: 0.9956 - loss: 0.1221
# Epoch 12: val_loss improved from 0.16181 to 0.15877, saving model to results/Deeper_Focal_MC_MSCA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 179ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9156 - dice_class_2: 0.9094 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9986 - iou_class_1: 0.8449 - iou_class_2: 0.8348 - iou_coef_multiclass: 0.9956 - loss: 0.1221 - val_accuracy: 0.9974 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8906 - val_dice_class_2: 0.8717 - val_dice_coef_multiclass: 0.9974 - val_iou_class_0: 0.9984 - val_iou_class_1: 0.8038 - val_iou_class_2: 0.7740 - val_iou_coef_multiclass: 0.9948 - val_loss: 0.1588 - learning_rate: 1.5000e-04
# Epoch 13/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9141 - dice_class_2: 0.9102 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9986 - iou_class_1: 0.8423 - iou_class_2: 0.8360 - iou_coef_multiclass: 0.9955 - loss: 0.1231
# Epoch 13: val_loss improved from 0.15877 to 0.14808, saving model to results/Deeper_Focal_MC_MSCA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 178ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9141 - dice_class_2: 0.9102 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9986 - iou_class_1: 0.8423 - iou_class_2: 0.8361 - iou_coef_multiclass: 0.9955 - loss: 0.1231 - val_accuracy: 0.9975 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8933 - val_dice_class_2: 0.8899 - val_dice_coef_multiclass: 0.9975 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.8091 - val_iou_class_2: 0.8028 - val_iou_coef_multiclass: 0.9950 - val_loss: 0.1481 - learning_rate: 1.5000e-04
# Epoch 14/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9163 - dice_class_2: 0.9140 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9986 - iou_class_1: 0.8461 - iou_class_2: 0.8424 - iou_coef_multiclass: 0.9957 - loss: 0.1193
# Epoch 14: val_loss improved from 0.14808 to 0.14769, saving model to results/Deeper_Focal_MC_MSCA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 179ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9163 - dice_class_2: 0.9139 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9986 - iou_class_1: 0.8461 - iou_class_2: 0.8424 - iou_coef_multiclass: 0.9957 - loss: 0.1193 - val_accuracy: 0.9974 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8946 - val_dice_class_2: 0.8866 - val_dice_coef_multiclass: 0.9974 - val_iou_class_0: 0.9984 - val_iou_class_1: 0.8110 - val_iou_class_2: 0.7979 - val_iou_coef_multiclass: 0.9948 - val_loss: 0.1477 - learning_rate: 1.5000e-04
# Epoch 15/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9198 - dice_class_2: 0.9140 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8519 - iou_class_2: 0.8424 - iou_coef_multiclass: 0.9959 - loss: 0.1152
# Epoch 15: val_loss did not improve from 0.14769
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 154ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9198 - dice_class_2: 0.9140 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8519 - iou_class_2: 0.8424 - iou_coef_multiclass: 0.9959 - loss: 0.1152 - val_accuracy: 0.9975 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8975 - val_dice_class_2: 0.8617 - val_dice_coef_multiclass: 0.9974 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.8152 - val_iou_class_2: 0.7597 - val_iou_coef_multiclass: 0.9949 - val_loss: 0.1592 - learning_rate: 1.5000e-04
# Epoch 16/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9166 - dice_class_2: 0.9120 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9987 - iou_class_1: 0.8467 - iou_class_2: 0.8390 - iou_coef_multiclass: 0.9957 - loss: 0.1184
# Epoch 16: val_loss improved from 0.14769 to 0.13928, saving model to results/Deeper_Focal_MC_MSCA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 179ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9166 - dice_class_2: 0.9120 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9987 - iou_class_1: 0.8467 - iou_class_2: 0.8390 - iou_coef_multiclass: 0.9957 - loss: 0.1184 - val_accuracy: 0.9976 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.9013 - val_dice_class_2: 0.8909 - val_dice_coef_multiclass: 0.9975 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.8211 - val_iou_class_2: 0.8042 - val_iou_coef_multiclass: 0.9951 - val_loss: 0.1393 - learning_rate: 1.5000e-04
# Epoch 17/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9207 - dice_class_2: 0.9175 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9987 - iou_class_1: 0.8534 - iou_class_2: 0.8483 - iou_coef_multiclass: 0.9959 - loss: 0.1138
# Epoch 17: val_loss did not improve from 0.13928
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 155ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9207 - dice_class_2: 0.9175 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9987 - iou_class_1: 0.8534 - iou_class_2: 0.8483 - iou_coef_multiclass: 0.9959 - loss: 0.1138 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8964 - val_dice_class_2: 0.8773 - val_dice_coef_multiclass: 0.9975 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8127 - val_iou_class_2: 0.7826 - val_iou_coef_multiclass: 0.9951 - val_loss: 0.1551 - learning_rate: 1.5000e-04
# Epoch 18/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9235 - dice_class_2: 0.9192 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9987 - iou_class_1: 0.8582 - iou_class_2: 0.8511 - iou_coef_multiclass: 0.9961 - loss: 0.1097
# Epoch 18: val_loss did not improve from 0.13928
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 154ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9235 - dice_class_2: 0.9192 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9987 - iou_class_1: 0.8582 - iou_class_2: 0.8511 - iou_coef_multiclass: 0.9961 - loss: 0.1097 - val_accuracy: 0.9975 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8978 - val_dice_class_2: 0.8790 - val_dice_coef_multiclass: 0.9975 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.8156 - val_iou_class_2: 0.7854 - val_iou_coef_multiclass: 0.9949 - val_loss: 0.1488 - learning_rate: 1.5000e-04
# Epoch 19/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9207 - dice_class_2: 0.9202 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9987 - iou_class_1: 0.8536 - iou_class_2: 0.8529 - iou_coef_multiclass: 0.9960 - loss: 0.1116
# Epoch 19: val_loss did not improve from 0.13928
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 4.500000213738531e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 155ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9207 - dice_class_2: 0.9202 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9987 - iou_class_1: 0.8536 - iou_class_2: 0.8529 - iou_coef_multiclass: 0.9960 - loss: 0.1116 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9059 - val_dice_class_2: 0.8803 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8290 - val_iou_class_2: 0.7877 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1426 - learning_rate: 1.5000e-04
# Epoch 20/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9265 - dice_class_2: 0.9268 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8636 - iou_class_2: 0.8642 - iou_coef_multiclass: 0.9963 - loss: 0.1030
# Epoch 20: val_loss improved from 0.13928 to 0.13691, saving model to results/Deeper_Focal_MC_MSCA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 179ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9265 - dice_class_2: 0.9268 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8636 - iou_class_2: 0.8642 - iou_coef_multiclass: 0.9963 - loss: 0.1030 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9025 - val_dice_class_2: 0.8956 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8233 - val_iou_class_2: 0.8120 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1369 - learning_rate: 4.5000e-05
# Epoch 21/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9301 - dice_class_2: 0.9303 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8696 - iou_class_2: 0.8703 - iou_coef_multiclass: 0.9964 - loss: 0.0992
# Epoch 21: val_loss did not improve from 0.13691
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 154ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9301 - dice_class_2: 0.9303 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8696 - iou_class_2: 0.8703 - iou_coef_multiclass: 0.9964 - loss: 0.0992 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9051 - val_dice_class_2: 0.8916 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8274 - val_iou_class_2: 0.8051 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1387 - learning_rate: 4.5000e-05
# Epoch 22/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9310 - dice_class_2: 0.9313 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8711 - iou_class_2: 0.8721 - iou_coef_multiclass: 0.9964 - loss: 0.0975
# Epoch 22: val_loss did not improve from 0.13691
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 154ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9309 - dice_class_2: 0.9313 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8711 - iou_class_2: 0.8721 - iou_coef_multiclass: 0.9964 - loss: 0.0975 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9076 - val_dice_class_2: 0.8845 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8316 - val_iou_class_2: 0.7944 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1384 - learning_rate: 4.5000e-05
# Epoch 23/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9324 - dice_class_2: 0.9347 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8735 - iou_class_2: 0.8780 - iou_coef_multiclass: 0.9965 - loss: 0.0953
# Epoch 23: val_loss improved from 0.13691 to 0.13513, saving model to results/Deeper_Focal_MC_MSCA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 178ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9324 - dice_class_2: 0.9347 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8735 - iou_class_2: 0.8779 - iou_coef_multiclass: 0.9965 - loss: 0.0953 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9056 - val_dice_class_2: 0.8934 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8284 - val_iou_class_2: 0.8086 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1351 - learning_rate: 4.5000e-05
# Epoch 24/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9304 - dice_class_2: 0.9294 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8703 - iou_class_2: 0.8687 - iou_coef_multiclass: 0.9964 - loss: 0.0993
# Epoch 24: val_loss did not improve from 0.13513
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 154ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9304 - dice_class_2: 0.9294 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8703 - iou_class_2: 0.8687 - iou_coef_multiclass: 0.9964 - loss: 0.0992 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9068 - val_dice_class_2: 0.8929 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8303 - val_iou_class_2: 0.8086 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1358 - learning_rate: 4.5000e-05
# Epoch 25/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9319 - dice_class_2: 0.9312 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8727 - iou_class_2: 0.8719 - iou_coef_multiclass: 0.9965 - loss: 0.0966
# Epoch 25: val_loss improved from 0.13513 to 0.13294, saving model to results/Deeper_Focal_MC_MSCA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 178ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9319 - dice_class_2: 0.9312 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9989 - iou_class_1: 0.8727 - iou_class_2: 0.8720 - iou_coef_multiclass: 0.9965 - loss: 0.0965 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9111 - val_dice_class_2: 0.8946 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8375 - val_iou_class_2: 0.8102 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1329 - learning_rate: 4.5000e-05
# Epoch 26/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9316 - dice_class_2: 0.9352 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8721 - iou_class_2: 0.8787 - iou_coef_multiclass: 0.9965 - loss: 0.0941
# Epoch 26: val_loss did not improve from 0.13294
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 154ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9315 - dice_class_2: 0.9352 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8721 - iou_class_2: 0.8787 - iou_coef_multiclass: 0.9965 - loss: 0.0941 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9047 - val_dice_class_2: 0.8858 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8270 - val_iou_class_2: 0.7965 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1405 - learning_rate: 4.5000e-05
# Epoch 27/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9320 - dice_class_2: 0.9360 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8731 - iou_class_2: 0.8801 - iou_coef_multiclass: 0.9965 - loss: 0.0943
# Epoch 27: val_loss improved from 0.13294 to 0.13283, saving model to results/Deeper_Focal_MC_MSCA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 178ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9320 - dice_class_2: 0.9360 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8731 - iou_class_2: 0.8801 - iou_coef_multiclass: 0.9965 - loss: 0.0943 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9078 - val_dice_class_2: 0.8971 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8316 - val_iou_class_2: 0.8147 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1328 - learning_rate: 4.5000e-05
# Epoch 28/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9347 - dice_class_2: 0.9379 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8776 - iou_class_2: 0.8837 - iou_coef_multiclass: 0.9966 - loss: 0.0911
# Epoch 28: val_loss did not improve from 0.13283
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 154ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9346 - dice_class_2: 0.9379 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8776 - iou_class_2: 0.8837 - iou_coef_multiclass: 0.9966 - loss: 0.0911 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9082 - val_dice_class_2: 0.8952 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8324 - val_iou_class_2: 0.8113 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1356 - learning_rate: 4.5000e-05
# Epoch 29/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9336 - dice_class_2: 0.9353 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8758 - iou_class_2: 0.8790 - iou_coef_multiclass: 0.9966 - loss: 0.0930
# Epoch 29: val_loss did not improve from 0.13283
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 153ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9336 - dice_class_2: 0.9353 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8758 - iou_class_2: 0.8790 - iou_coef_multiclass: 0.9966 - loss: 0.0930 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9072 - val_dice_class_2: 0.8923 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8314 - val_iou_class_2: 0.8071 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1358 - learning_rate: 4.5000e-05
# Epoch 30/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9320 - dice_class_2: 0.9382 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8730 - iou_class_2: 0.8844 - iou_coef_multiclass: 0.9965 - loss: 0.0916
# Epoch 30: val_loss did not improve from 0.13283
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.3500000204658135e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 154ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9320 - dice_class_2: 0.9382 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8730 - iou_class_2: 0.8843 - iou_coef_multiclass: 0.9965 - loss: 0.0916 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9019 - val_dice_class_2: 0.8898 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8220 - val_iou_class_2: 0.8029 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1415 - learning_rate: 4.5000e-05
# Epoch 31/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9341 - dice_class_2: 0.9384 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8768 - iou_class_2: 0.8845 - iou_coef_multiclass: 0.9967 - loss: 0.0898
# Epoch 31: val_loss did not improve from 0.13283
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 154ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9341 - dice_class_2: 0.9384 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8768 - iou_class_2: 0.8845 - iou_coef_multiclass: 0.9967 - loss: 0.0898 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9083 - val_dice_class_2: 0.8922 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8325 - val_iou_class_2: 0.8065 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1346 - learning_rate: 1.3500e-05
# Epoch 32/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9368 - dice_class_2: 0.9387 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8814 - iou_class_2: 0.8850 - iou_coef_multiclass: 0.9967 - loss: 0.0886
# Epoch 32: val_loss improved from 0.13283 to 0.13196, saving model to results/Deeper_Focal_MC_MSCA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 178ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9368 - dice_class_2: 0.9387 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8814 - iou_class_2: 0.8850 - iou_coef_multiclass: 0.9967 - loss: 0.0886 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9092 - val_dice_class_2: 0.8979 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8340 - val_iou_class_2: 0.8158 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1320 - learning_rate: 1.3500e-05
# Epoch 33/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9355 - dice_class_2: 0.9393 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8791 - iou_class_2: 0.8863 - iou_coef_multiclass: 0.9967 - loss: 0.0884
# Epoch 33: val_loss did not improve from 0.13196
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 154ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9355 - dice_class_2: 0.9393 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8791 - iou_class_2: 0.8863 - iou_coef_multiclass: 0.9967 - loss: 0.0884 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9098 - val_dice_class_2: 0.8960 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8350 - val_iou_class_2: 0.8127 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1322 - learning_rate: 1.3500e-05
# Epoch 34/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9368 - dice_class_2: 0.9393 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8814 - iou_class_2: 0.8861 - iou_coef_multiclass: 0.9967 - loss: 0.0881
# Epoch 34: val_loss did not improve from 0.13196
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 154ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9368 - dice_class_2: 0.9393 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8814 - iou_class_2: 0.8861 - iou_coef_multiclass: 0.9967 - loss: 0.0881 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9077 - val_dice_class_2: 0.8891 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8316 - val_iou_class_2: 0.8016 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1364 - learning_rate: 1.3500e-05
# Epoch 35/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9370 - dice_class_2: 0.9408 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8818 - iou_class_2: 0.8888 - iou_coef_multiclass: 0.9968 - loss: 0.0868
# Epoch 35: val_loss did not improve from 0.13196
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 4.050000006827758e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 153ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9369 - dice_class_2: 0.9408 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8818 - iou_class_2: 0.8888 - iou_coef_multiclass: 0.9968 - loss: 0.0868 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9076 - val_dice_class_2: 0.8934 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8316 - val_iou_class_2: 0.8086 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1347 - learning_rate: 1.3500e-05
# Epoch 36/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9366 - dice_class_2: 0.9443 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8810 - iou_class_2: 0.8949 - iou_coef_multiclass: 0.9968 - loss: 0.0852
# Epoch 36: val_loss did not improve from 0.13196
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 153ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9366 - dice_class_2: 0.9443 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8810 - iou_class_2: 0.8949 - iou_coef_multiclass: 0.9968 - loss: 0.0853 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9098 - val_dice_class_2: 0.8939 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8350 - val_iou_class_2: 0.8092 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1339 - learning_rate: 4.0500e-06
# Epoch 37/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9376 - dice_class_2: 0.9414 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8827 - iou_class_2: 0.8899 - iou_coef_multiclass: 0.9968 - loss: 0.0855
# Epoch 37: val_loss did not improve from 0.13196
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 153ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9376 - dice_class_2: 0.9414 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8827 - iou_class_2: 0.8899 - iou_coef_multiclass: 0.9968 - loss: 0.0855 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9083 - val_dice_class_2: 0.8917 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8326 - val_iou_class_2: 0.8063 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1359 - learning_rate: 4.0500e-06
# Epoch 38/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9383 - dice_class_2: 0.9443 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8841 - iou_class_2: 0.8950 - iou_coef_multiclass: 0.9968 - loss: 0.0836
# Epoch 38: val_loss improved from 0.13196 to 0.13157, saving model to results/Deeper_Focal_MC_MSCA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 177ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9383 - dice_class_2: 0.9443 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8840 - iou_class_2: 0.8950 - iou_coef_multiclass: 0.9968 - loss: 0.0837 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9081 - val_dice_class_2: 0.8991 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8323 - val_iou_class_2: 0.8176 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1316 - learning_rate: 4.0500e-06
# Epoch 39/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9393 - dice_class_2: 0.9416 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8858 - iou_class_2: 0.8901 - iou_coef_multiclass: 0.9969 - loss: 0.0846
# Epoch 39: val_loss did not improve from 0.13157
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 153ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9393 - dice_class_2: 0.9416 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9990 - iou_class_1: 0.8858 - iou_class_2: 0.8901 - iou_coef_multiclass: 0.9969 - loss: 0.0846 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9071 - val_dice_class_2: 0.8937 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8307 - val_iou_class_2: 0.8089 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1350 - learning_rate: 4.0500e-06
# Epoch 40/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9386 - dice_class_2: 0.9414 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8845 - iou_class_2: 0.8898 - iou_coef_multiclass: 0.9968 - loss: 0.0849
# Epoch 40: val_loss improved from 0.13157 to 0.13147, saving model to results/Deeper_Focal_MC_MSCA.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 27s 177ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9386 - dice_class_2: 0.9414 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8845 - iou_class_2: 0.8898 - iou_coef_multiclass: 0.9968 - loss: 0.0849 - val_accuracy: 0.9979 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9115 - val_dice_class_2: 0.8975 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8380 - val_iou_class_2: 0.8152 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1315 - learning_rate: 4.0500e-06
# Epoch 41/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9357 - dice_class_2: 0.9386 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8796 - iou_class_2: 0.8849 - iou_coef_multiclass: 0.9967 - loss: 0.0889
# Epoch 41: val_loss did not improve from 0.13147
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.2149999747634864e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 154ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9357 - dice_class_2: 0.9387 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8796 - iou_class_2: 0.8850 - iou_coef_multiclass: 0.9967 - loss: 0.0889 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9048 - val_dice_class_2: 0.8916 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8269 - val_iou_class_2: 0.8058 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1375 - learning_rate: 4.0500e-06
# Epoch 42/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9359 - dice_class_2: 0.9406 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8799 - iou_class_2: 0.8884 - iou_coef_multiclass: 0.9967 - loss: 0.0877
# Epoch 42: val_loss did not improve from 0.13147
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 154ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9359 - dice_class_2: 0.9406 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8799 - iou_class_2: 0.8884 - iou_coef_multiclass: 0.9967 - loss: 0.0877 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9094 - val_dice_class_2: 0.8977 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8344 - val_iou_class_2: 0.8154 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1316 - learning_rate: 1.2150e-06
# Epoch 43/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9381 - dice_class_2: 0.9422 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8836 - iou_class_2: 0.8912 - iou_coef_multiclass: 0.9968 - loss: 0.0853
# Epoch 43: val_loss did not improve from 0.13147
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 154ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9381 - dice_class_2: 0.9422 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8836 - iou_class_2: 0.8912 - iou_coef_multiclass: 0.9968 - loss: 0.0853 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9072 - val_dice_class_2: 0.8924 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8307 - val_iou_class_2: 0.8072 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1368 - learning_rate: 1.2150e-06
# Epoch 44/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9370 - dice_class_2: 0.9382 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8817 - iou_class_2: 0.8843 - iou_coef_multiclass: 0.9967 - loss: 0.0886
# Epoch 44: val_loss did not improve from 0.13147
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 3.644999992502562e-07.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 153ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9370 - dice_class_2: 0.9382 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8817 - iou_class_2: 0.8844 - iou_coef_multiclass: 0.9967 - loss: 0.0886 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9102 - val_dice_class_2: 0.8963 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8357 - val_iou_class_2: 0.8133 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1318 - learning_rate: 1.2150e-06
# Epoch 45/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9372 - dice_class_2: 0.9409 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8822 - iou_class_2: 0.8891 - iou_coef_multiclass: 0.9968 - loss: 0.0866
# Epoch 45: val_loss did not improve from 0.13147
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 153ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9372 - dice_class_2: 0.9409 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8822 - iou_class_2: 0.8891 - iou_coef_multiclass: 0.9968 - loss: 0.0866 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9069 - val_dice_class_2: 0.8929 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8305 - val_iou_class_2: 0.8083 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1359 - learning_rate: 3.6450e-07
# Epoch 46/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9387 - dice_class_2: 0.9429 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8848 - iou_class_2: 0.8925 - iou_coef_multiclass: 0.9968 - loss: 0.0851
# Epoch 46: val_loss did not improve from 0.13147
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 154ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9387 - dice_class_2: 0.9429 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8848 - iou_class_2: 0.8925 - iou_coef_multiclass: 0.9968 - loss: 0.0851 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9079 - val_dice_class_2: 0.8961 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8320 - val_iou_class_2: 0.8125 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1345 - learning_rate: 3.6450e-07
# Epoch 47/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9373 - dice_class_2: 0.9406 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8823 - iou_class_2: 0.8885 - iou_coef_multiclass: 0.9968 - loss: 0.0866
# Epoch 47: val_loss did not improve from 0.13147
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.0935000318568199e-07.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 154ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9373 - dice_class_2: 0.9406 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8823 - iou_class_2: 0.8885 - iou_coef_multiclass: 0.9968 - loss: 0.0866 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9092 - val_dice_class_2: 0.8941 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8342 - val_iou_class_2: 0.8102 - val_iou_coef_multiclass: 0.9956 - val_loss: 0.1325 - learning_rate: 3.6450e-07
# Epoch 48/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9394 - dice_class_2: 0.9452 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8861 - iou_class_2: 0.8965 - iou_coef_multiclass: 0.9969 - loss: 0.0823
# Epoch 48: val_loss did not improve from 0.13147
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 153ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9394 - dice_class_2: 0.9452 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8860 - iou_class_2: 0.8965 - iou_coef_multiclass: 0.9968 - loss: 0.0823 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9083 - val_dice_class_2: 0.8934 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8325 - val_iou_class_2: 0.8086 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1353 - learning_rate: 1.0935e-07
# Epoch 49/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9391 - dice_class_2: 0.9433 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8853 - iou_class_2: 0.8931 - iou_coef_multiclass: 0.9968 - loss: 0.0835
# Epoch 49: val_loss did not improve from 0.13147
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 153ms/step - accuracy: 0.9985 - dice_class_0: 0.9995 - dice_class_1: 0.9391 - dice_class_2: 0.9433 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8853 - iou_class_2: 0.8931 - iou_coef_multiclass: 0.9968 - loss: 0.0835 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9079 - val_dice_class_2: 0.8945 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8320 - val_iou_class_2: 0.8105 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1339 - learning_rate: 1.0935e-07
# Epoch 50/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9368 - dice_class_2: 0.9408 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8813 - iou_class_2: 0.8888 - iou_coef_multiclass: 0.9967 - loss: 0.0874
# Epoch 50: val_loss did not improve from 0.13147
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1e-07.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 23s 154ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9368 - dice_class_2: 0.9408 - dice_coef_multiclass: 0.9984 - iou_class_0: 0.9989 - iou_class_1: 0.8814 - iou_class_2: 0.8889 - iou_coef_multiclass: 0.9967 - loss: 0.0874 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9080 - val_dice_class_2: 0.8951 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8321 - val_iou_class_2: 0.8110 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1338 - learning_rate: 1.0935e-07
# Epoch 50: early stopping
# Restoring model weights from the end of the best epoch: 40.
# ✓ Training completed
#
# Generating visualizations...
#   ✓ Saved: results/Deeper_Focal_MC_MSCA_training_curves.png
#   ✓ Saved: results/Deeper_Focal_MC_MSCA_history.png
# E0000 00:00:1763461351.537962     109 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763461351.800065     109 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#   ✓ Saved: results/Deeper_Focal_MC_MSCA_predictions.png
# ================================================================================
# EVALUATION: Deeper+Focal+MC+MSCA
# ================================================================================
#   ✓ Saved: results/Deeper+Focal+MC+MSCA_confusion_matrices.png
# Confusion Matrix:
# [[25767252    17738        0]
#  [   15376   290991     8704]
#  [      24    14808    99507]]
#
# Normalized Confusion Matrix:
# [[0.999 0.001 0.   ]
#  [0.049 0.924 0.028]
#  [0.    0.13  0.87 ]]
#
# Precision, Recall, F1 Score per class:
#   Background: Precision=0.9994, Recall=0.9993, F1=0.9994
#   Disc: Precision=0.8994, Recall=0.9236, F1=0.9113
#   Cup: Precision=0.9196, Recall=0.8703, F1=0.8942
#
# Macro-averaged metrics:
#   Precision: 0.9395
#   Recall: 0.9311
#   F1 Score: 0.9350
#   Background: Dice=0.9994, IoU=0.9987
#   Disc: Dice=0.9113, IoU=0.8371
#   Cup: Dice=0.8942, IoU=0.8087
#
# MC Dropout Evaluation:
#
# Running MC Dropout with 10 stochastic forward passes...
#   Completed: 5/10 forward passes
#   Completed: 10/10 forward passes
# ✓ MC Dropout completed
#   Background uncertainty: 0.0003
#   Disc uncertainty: 0.0004
#   Cup uncertainty: 0.0002
#
# ====================================================================================================
#                                 ✓ TRAINING AND EVALUATION COMPLETED!
# ====================================================================================================
#
# Model: Deeper + Focal + EIoU + MC Dropout + MSCA
# Enhancement: Multi-scale Context Aggregator from ODFormer
# MSCA Dilation Rates: [1, 2, 3, 5]
# Parameters: 40,620,675
# Results saved in: results/
#
# ====================================================================================================
