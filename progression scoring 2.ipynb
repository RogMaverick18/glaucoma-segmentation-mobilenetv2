# %%
"""
MOBILENET-UNET WITH GLAUCOMA PROGRESSION SCORING
=================================================
Enhanced with:
1. Deeper Decoder Architecture
2. Focal-EIoU Combined Loss
3. MC Dropout for Uncertainty Estimation
4. Glaucoma Progression Scoring based on Cup-to-Disc Ratio (CDR)

Glaucoma Scoring System:
- Normal: CDR < 0.3
- Suspect: 0.3 ≤ CDR < 0.6
- Moderate: 0.6 ≤ CDR < 0.8
- Advanced: CDR ≥ 0.8

Additional Features:
- Vertical CDR calculation (vCDR)
- Horizontal CDR calculation (hCDR)
- Average CDR for overall assessment
- Risk classification per sample
- Progression tracking visualization
"""

import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, backend as K
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import albumentations as A
import warnings
import gc
warnings.filterwarnings('ignore')

# Set plot style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

# ============================================================================
# GPU CONFIGURATION
# ============================================================================

def configure_gpu():
    """Configure GPU settings for optimal performance"""
    print("Configuring GPU settings...")
    physical_devices = tf.config.list_physical_devices('GPU')
    if physical_devices:
        try:
            for gpu in physical_devices:
                tf.config.experimental.set_memory_growth(gpu, True)
            tf.config.set_visible_devices(physical_devices[0], 'GPU')
            print(f"✓ GPU found: {physical_devices}")
            return True
        except RuntimeError as e:
            print(f"✗ GPU configuration error: {e}")
            return False
    else:
        print("✗ No GPU found, using CPU")
        return False

# ============================================================================
# DATA LOADING
# ============================================================================

def load_images_masks(images_folder, masks_folder, img_size=(256,256)):
    """Load images and masks from folders"""
    images, masks = [], []
    image_files = sorted(os.listdir(images_folder))
    mask_files = sorted(os.listdir(masks_folder))
    mask_dict = {os.path.splitext(f)[0]: f for f in mask_files}
    
    for img_file in image_files:
        base = os.path.splitext(img_file)[0]
        if base in mask_dict:
            img = cv2.imread(os.path.join(images_folder, img_file))
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, img_size) / 255.0
            
            mask = cv2.imread(os.path.join(masks_folder, mask_dict[base]), cv2.IMREAD_GRAYSCALE)
            mask = cv2.resize(mask, img_size)
            unique_vals = np.unique(mask)
            if len(unique_vals) > 3 or np.max(unique_vals) > 2:
                mask = np.clip(mask // 85, 0, 2).astype(np.uint8)
            
            images.append(img)
            masks.append(mask)
    
    return np.array(images, dtype=np.float32), np.array(masks, dtype=np.uint8)

def load_all_data(root_dir):
    """Load all data from existing splits and merge"""
    all_images, all_masks = [], []
    for split in ["train", "val", "test"]:
        print(f"Loading {split} data...")
        imgs, msks = load_images_masks(
            os.path.join(root_dir, split, "Images"),
            os.path.join(root_dir, split, "Masks")
        )
        all_images.append(imgs)
        all_masks.append(msks)
        print(f"  {split}: {imgs.shape[0]} samples")
    
    all_images = np.concatenate(all_images, axis=0)
    all_masks = np.concatenate(all_masks, axis=0)
    return all_images, all_masks

def create_new_split(all_images, all_masks):
    """Create new split: 600 train, 200 val, 400 test"""
    X_temp, X_test, y_temp, y_test = train_test_split(
        all_images, all_masks, test_size=400, random_state=42
    )
    X_train, X_val, y_train, y_val = train_test_split(
        X_temp, y_temp, test_size=200, random_state=42
    )
    print(f"Split - Train: {X_train.shape[0]}, Val: {X_val.shape[0]}, Test: {X_test.shape[0]}")
    return (X_train, y_train), (X_val, y_val), (X_test, y_test)

# ============================================================================
# DATA AUGMENTATION
# ============================================================================

def setup_augmentations():
    return A.Compose([
        A.RandomBrightnessContrast(brightness_limit=0.15, contrast_limit=0.15, p=0.7),
        A.HueSaturationValue(hue_shift_limit=10, sat_shift_limit=15, val_shift_limit=10, p=0.5),
        A.GaussianBlur(blur_limit=3, p=0.3),
        A.RandomGamma(gamma_limit=(80, 120), p=0.3),
    ])

def data_generator(images, masks, batch_size, augment=None):
    idxs = np.arange(len(images))
    while True:
        np.random.shuffle(idxs)
        for i in range(0, len(images), batch_size):
            batch_idxs = idxs[i:i+batch_size]
            batch_x, batch_y = [], []
            
            for idx in batch_idxs:
                img, mask = images[idx], masks[idx]
                
                if augment:
                    aug = augment(image=img, mask=mask)
                    img_aug, mask_aug = aug['image'], aug['mask']
                else:
                    img_aug, mask_aug = img, mask
                
                mask_cat = to_categorical(mask_aug, num_classes=3)
                batch_x.append(img_aug)
                batch_y.append(mask_cat)
            
            yield np.stack(batch_x).astype(np.float32), np.stack(batch_y).astype(np.float32)

# ============================================================================
# LOSS FUNCTIONS
# ============================================================================

def focal_loss(y_true, y_pred, gamma=2.0, alpha=None, epsilon=1e-7):
    if alpha is None:
        alpha = [0.25, 1.0, 1.0]
    
    y_pred = K.clip(y_pred, epsilon, 1.0 - epsilon)
    focal_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        pt = y_pred_c
        focal_weight = K.pow(1.0 - pt, gamma)
        cross_entropy = -K.log(pt)
        focal_loss_c = alpha[c] * focal_weight * cross_entropy * y_true_c
        focal_loss_value += K.mean(focal_loss_c)
    
    return focal_loss_value

def enhanced_iou_loss(y_true, y_pred, smooth=1e-7):
    eiou_loss_value = 0.0
    
    for c in range(3):
        y_true_c = y_true[:, :, :, c]
        y_pred_c = y_pred[:, :, :, c]
        
        intersection = K.sum(y_true_c * y_pred_c, axis=[1, 2])
        union = K.sum(y_true_c, axis=[1, 2]) + K.sum(y_pred_c, axis=[1, 2]) - intersection
        iou = (intersection + smooth) / (union + smooth)
        
        height = K.cast(K.shape(y_true_c)[1], 'float32')
        width = K.cast(K.shape(y_true_c)[2], 'float32')
        
        y_coords = K.arange(0, height)
        x_coords = K.arange(0, width)
        y_grid = K.tile(K.reshape(y_coords, (-1, 1)), (1, K.cast(width, 'int32')))
        x_grid = K.tile(K.reshape(x_coords, (1, -1)), (K.cast(height, 'int32'), 1))
        y_grid = K.cast(y_grid, 'float32')
        x_grid = K.cast(x_grid, 'float32')
        
        true_mass = K.sum(y_true_c, axis=[1, 2]) + smooth
        true_center_y = K.sum(y_true_c * y_grid, axis=[1, 2]) / true_mass
        true_center_x = K.sum(y_true_c * x_grid, axis=[1, 2]) / true_mass
        
        pred_mass = K.sum(y_pred_c, axis=[1, 2]) + smooth
        pred_center_y = K.sum(y_pred_c * y_grid, axis=[1, 2]) / pred_mass
        pred_center_x = K.sum(y_pred_c * x_grid, axis=[1, 2]) / pred_mass
        
        center_distance = K.square(true_center_y - pred_center_y) + K.square(true_center_x - pred_center_x)
        diagonal = K.square(height) + K.square(width)
        center_penalty = center_distance / (diagonal + smooth)
        
        true_width = K.sqrt(K.sum(K.sum(y_true_c, axis=1), axis=1) + smooth)
        true_height = K.sqrt(K.sum(K.sum(y_true_c, axis=2), axis=1) + smooth)
        pred_width = K.sqrt(K.sum(K.sum(y_pred_c, axis=1), axis=1) + smooth)
        pred_height = K.sqrt(K.sum(K.sum(y_pred_c, axis=2), axis=1) + smooth)
        
        width_diff = K.square(pred_width - true_width)
        height_diff = K.square(pred_height - true_height)
        aspect_penalty = width_diff / (K.square(width) + smooth) + height_diff / (K.square(height) + smooth)
        
        eiou_c = 1.0 - iou + center_penalty + aspect_penalty
        eiou_loss_value += K.mean(eiou_c)
    
    return eiou_loss_value / 3.0

def focal_eiou_combined_loss(y_true, y_pred, focal_weight=1.0, eiou_weight=1.0, gamma=2.0, alpha=None):
    fl = focal_loss(y_true, y_pred, gamma=gamma, alpha=alpha)
    eiou = enhanced_iou_loss(y_true, y_pred)
    return focal_weight * fl + eiou_weight * eiou

# ============================================================================
# MODEL ARCHITECTURE
# ============================================================================

def enhanced_decoder_block(x, skip_connection, filters, block_name, dropout_rate=0.3):
    """Enhanced decoder block with residual connections and dropout"""
    x = layers.UpSampling2D((2, 2), name=f'{block_name}_upsample')(x)
    
    if skip_connection.shape[-1] != x.shape[-1]:
        skip_connection = layers.Conv2D(x.shape[-1], (1, 1), use_bias=False,
                                      name=f'{block_name}_skip_align')(skip_connection)
        skip_connection = layers.BatchNormalization(name=f'{block_name}_skip_bn')(skip_connection)
    
    x = layers.Concatenate(name=f'{block_name}_concat')([x, skip_connection])
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv1')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn1')(x)
    x = layers.Dropout(dropout_rate, name=f'{block_name}_dropout')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv2')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn2')(x)
    
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv3')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn3')(x)
    
    residual = x
    x = layers.Conv2D(filters, (3, 3), activation='relu', padding='same', name=f'{block_name}_conv4')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn4')(x)
    
    x = layers.Add(name=f'{block_name}_residual')([x, residual])
    x = layers.Conv2D(filters, (1, 1), activation='relu', padding='same', name=f'{block_name}_conv_final')(x)
    x = layers.BatchNormalization(name=f'{block_name}_bn_final')(x)
    
    return x

def build_deeper_focal_mc_unet(input_shape=(256, 256, 3), num_classes=3, dropout_rate=0.3):
    """Build MobileNetV2-UNet with deeper decoder, focal-eiou loss, and MC dropout"""
    inputs = layers.Input(input_shape, dtype='float32')
    backbone = MobileNetV2(input_tensor=inputs, weights='imagenet', include_top=False)
    
    skip_1 = backbone.get_layer('block_1_expand_relu').output  # 128×128
    skip_2 = backbone.get_layer('block_3_expand_relu').output  # 64×64
    skip_3 = backbone.get_layer('block_6_expand_relu').output  # 32×32
    skip_4 = backbone.get_layer('block_13_expand_relu').output # 16×16
    bridge = backbone.output  # 8×8
    
    # Deeper bridge
    bridge = layers.Conv2D(1024, (3, 3), activation='relu', padding='same')(bridge)
    bridge = layers.BatchNormalization()(bridge)
    bridge = layers.Dropout(dropout_rate, name='bridge_dropout')(bridge)
    
    # Decoder with deeper blocks
    x = enhanced_decoder_block(bridge, skip_4, 512, 'decoder_1', dropout_rate)
    x = enhanced_decoder_block(x, skip_3, 256, 'decoder_2', dropout_rate)
    x = enhanced_decoder_block(x, skip_2, 128, 'decoder_3', dropout_rate * 0.7)
    x = enhanced_decoder_block(x, skip_1, 64, 'decoder_4', dropout_rate * 0.5)
    
    # Final upsampling
    x = layers.UpSampling2D((2, 2))(x)
    x = layers.Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = layers.BatchNormalization()(x)
    
    outputs = layers.Conv2D(num_classes, (1, 1), activation='softmax', dtype='float32')(x)
    
    model = models.Model(inputs, outputs)
    
    # Print configuration
    dropout_layers = [layer for layer in model.layers if isinstance(layer, layers.Dropout)]
    print(f"\nModel Configuration:")
    print(f"  Total Parameters: {model.count_params():,}")
    print(f"  Dropout Layers: {len(dropout_layers)}")
    print(f"  Architecture: Deeper Decoder + Focal-EIoU + MC Dropout")
    
    return model

# ============================================================================
# METRICS
# ============================================================================

def dice_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    return (2. * intersection + smooth) / (K.sum(y_true_class) + K.sum(y_pred_class) + smooth)

def dice_class_0(y_true, y_pred): return dice_coef_class(y_true, y_pred, 0)
def dice_class_1(y_true, y_pred): return dice_coef_class(y_true, y_pred, 1)
def dice_class_2(y_true, y_pred): return dice_coef_class(y_true, y_pred, 2)

def iou_coef_multiclass(y_true, y_pred, smooth=1e-7):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_coef_class(y_true, y_pred, class_index, smooth=1e-7):
    y_true_class = K.cast(K.equal(K.argmax(y_true, axis=-1), class_index), 'float32')
    y_pred_class = K.cast(K.equal(K.argmax(y_pred, axis=-1), class_index), 'float32')
    intersection = K.sum(y_true_class * y_pred_class)
    union = K.sum(y_true_class) + K.sum(y_pred_class) - intersection
    return (intersection + smooth) / (union + smooth)

def iou_class_0(y_true, y_pred): return iou_coef_class(y_true, y_pred, 0)
def iou_class_1(y_true, y_pred): return iou_coef_class(y_true, y_pred, 1)
def iou_class_2(y_true, y_pred): return iou_coef_class(y_true, y_pred, 2)

def mc_dropout_predict(model, X, num_samples=15, batch_size=4, verbose=True):
    """MC Dropout prediction for uncertainty estimation"""
    if verbose:
        print(f"\nRunning MC Dropout with {num_samples} stochastic forward passes...")
    
    predictions = []
    num_batches = int(np.ceil(len(X) / batch_size))
    
    for i in range(num_samples):
        if verbose and (i + 1) % 5 == 0:
            print(f"  Completed: {i+1}/{num_samples} forward passes")
        
        batch_preds = []
        for batch_idx in range(num_batches):
            start_idx = batch_idx * batch_size
            end_idx = min(start_idx + batch_size, len(X))
            X_batch = X[start_idx:end_idx]
            
            pred_batch = model(X_batch, training=True)
            batch_preds.append(pred_batch.numpy())
        
        pred = np.concatenate(batch_preds, axis=0)
        predictions.append(pred)
        
        if (i + 1) % 5 == 0:
            gc.collect()
    
    all_preds = np.array(predictions)
    mean_pred = np.mean(all_preds, axis=0)
    std_pred = np.std(all_preds, axis=0)
    
    del all_preds
    gc.collect()
    
    if verbose:
        print(f"✓ MC Dropout completed")
    
    return mean_pred, std_pred

# ============================================================================
# GLAUCOMA PROGRESSION SCORING
# ============================================================================

def calculate_cdr(mask, disc_class=1, cup_class=2, method='vertical'):
    """
    Calculate Cup-to-Disc Ratio (CDR) from segmentation mask
    
    Methods:
    - 'vertical': Vertical diameter ratio (clinical standard, most accurate)
    - 'area_sqrt': Square root of area ratio (robust alternative)
    
    Args:
        mask: Segmentation mask (H, W) with class labels
        disc_class: Class label for optic disc (default=1)
        cup_class: Class label for optic cup (default=2)
        method: Calculation method (default='vertical')
    
    Returns:
        dict with vCDR, hCDR, avgCDR, area_CDR
    """
    disc_mask = (mask == disc_class).astype(np.uint8)
    cup_mask = (mask == cup_class).astype(np.uint8)
    
    # Check if disc and cup are present
    disc_area = disc_mask.sum()
    cup_area = cup_mask.sum()
    
    if disc_area == 0 or cup_area == 0:
        return {'vCDR': 0.0, 'hCDR': 0.0, 'avgCDR': 0.0, 'area_CDR': 0.0, 'valid': False, 
                'method': method, 'disc_area': 0, 'cup_area': 0}
    
    # Find coordinates
    disc_coords = np.where(disc_mask > 0)
    cup_coords = np.where(cup_mask > 0)
    
    # Calculate diameters using bounding box
    disc_v_diameter = disc_coords[0].max() - disc_coords[0].min() + 1
    cup_v_diameter = cup_coords[0].max() - cup_coords[0].min() + 1
    disc_h_diameter = disc_coords[1].max() - disc_coords[1].min() + 1
    cup_h_diameter = cup_coords[1].max() - cup_coords[1].min() + 1
    
    # Calculate CDRs
    vCDR = cup_v_diameter / disc_v_diameter if disc_v_diameter > 0 else 0.0
    hCDR = cup_h_diameter / disc_h_diameter if disc_h_diameter > 0 else 0.0
    
    # Calculate area-based CDR
    area_CDR = np.sqrt(cup_area / disc_area)
    
    # Choose primary CDR based on method
    if method == 'vertical':
        avgCDR = vCDR  # Use vertical CDR (clinical standard)
    elif method == 'area_sqrt':
        avgCDR = area_CDR  # Use area-based
    else:
        avgCDR = (vCDR + hCDR) / 2.0  # Average of both
    
    return {
        'vCDR': float(vCDR),
        'hCDR': float(hCDR),
        'avgCDR': float(avgCDR),
        'area_CDR': float(area_CDR),
        'valid': True,
        'method': method,
        'disc_area': int(disc_area),
        'cup_area': int(cup_area),
        'disc_v_diameter': int(disc_v_diameter),
        'cup_v_diameter': int(cup_v_diameter)
    }

def classify_glaucoma_severity(cdr):
    """
    Classify glaucoma severity based on CDR
    
    Classification:
    - Normal: CDR < 0.3
    - Suspect: 0.3 ≤ CDR < 0.6
    - Moderate: 0.6 ≤ CDR < 0.75
    - Critical: CDR ≥ 0.75
    
    Args:
        cdr: Cup-to-Disc Ratio (float)
    
    Returns:
        tuple: (severity_class, severity_label, color)
    """
    if cdr < 0.3:
        return 0, 'Normal', '#4CAF50'  # Green
    elif cdr < 0.6:
        return 1, 'Suspect', '#FFC107'  # Amber
    elif cdr < 0.75:
        return 2, 'Moderate', '#FF9800'  # Orange
    else:
        return 3, 'Critical', '#F44336'  # Red

def analyze_glaucoma_progression(masks, predictions, cdr_method='vertical'):
    """
    Analyze glaucoma progression for a batch of samples
    
    Args:
        masks: Ground truth masks (N, H, W)
        predictions: Predicted masks (N, H, W)
        cdr_method: CDR calculation method ('vertical', 'area_sqrt')
    
    Returns:
        DataFrame with CDR metrics and classifications
    """
    results = []
    
    for i, (gt_mask, pred_mask) in enumerate(zip(masks, predictions)):
        # Calculate CDR for ground truth
        gt_cdr = calculate_cdr(gt_mask, method=cdr_method)
        
        # Calculate CDR for prediction
        pred_cdr = calculate_cdr(pred_mask, method=cdr_method)
        
        # Classify severity
        if gt_cdr['valid']:
            gt_class, gt_label, gt_color = classify_glaucoma_severity(gt_cdr['avgCDR'])
        else:
            gt_class, gt_label, gt_color = -1, 'Invalid', '#9E9E9E'
        
        if pred_cdr['valid']:
            pred_class, pred_label, pred_color = classify_glaucoma_severity(pred_cdr['avgCDR'])
        else:
            pred_class, pred_label, pred_color = -1, 'Invalid', '#9E9E9E'
        
        # Calculate CDR error
        cdr_error = abs(gt_cdr['avgCDR'] - pred_cdr['avgCDR']) if gt_cdr['valid'] and pred_cdr['valid'] else np.nan
        
        # Check if classification matches
        severity_match = (gt_label == pred_label)
        
        # Manual review needed: Critical cases or mismatches
        manual_review = (gt_label == 'Critical') or (not severity_match)
        
        results.append({
            'Sample': i + 1,
            'GT_vCDR': gt_cdr['vCDR'],
            'GT_hCDR': gt_cdr['hCDR'],
            'GT_avgCDR': gt_cdr['avgCDR'],
            'GT_area_CDR': gt_cdr['area_CDR'],
            'GT_Severity': gt_label,
            'Pred_vCDR': pred_cdr['vCDR'],
            'Pred_hCDR': pred_cdr['hCDR'],
            'Pred_avgCDR': pred_cdr['avgCDR'],
            'Pred_area_CDR': pred_cdr['area_CDR'],
            'Pred_Severity': pred_label,
            'CDR_Error': cdr_error,
            'Severity_Match': severity_match,
            'Manual_Review_Needed': manual_review
        })
    
    return pd.DataFrame(results)

# ============================================================================
# VISUALIZATION FUNCTIONS
# ============================================================================

def plot_sample_predictions_with_cdr(model, X_test, y_test, model_name, num_samples=6, save_dir='results'):
    """Visualize predictions with CDR and glaucoma severity"""
    os.makedirs(save_dir, exist_ok=True)
    
    y_pred = model.predict(X_test[:num_samples], verbose=0, batch_size=4)
    y_pred_labels = np.argmax(y_pred, axis=-1)
    
    colors = {0: [0, 0, 0], 1: [0, 255, 0], 2: [255, 0, 0]}
    
    fig, axes = plt.subplots(num_samples, 4, figsize=(18, 4*num_samples))
    
    for i in range(num_samples):
        # Original image
        axes[i, 0].imshow(X_test[i])
        axes[i, 0].set_title('Original Image', fontsize=12, fontweight='bold')
        axes[i, 0].axis('off')
        
        # Ground truth
        gt_colored = np.zeros((256, 256, 3), dtype=np.uint8)
        for class_id, color in colors.items():
            gt_colored[y_test[i] == class_id] = color
        axes[i, 1].imshow(gt_colored)
        
        # Calculate GT CDR
        gt_cdr = calculate_cdr(y_test[i])
        gt_class, gt_label, gt_color = classify_glaucoma_severity(gt_cdr['avgCDR']) if gt_cdr['valid'] else (-1, 'Invalid', '#9E9E9E')
        
        axes[i, 1].set_title(f'Ground Truth\nCDR: {gt_cdr["avgCDR"]:.3f} | {gt_label}', 
                            fontsize=12, fontweight='bold', color=gt_color)
        axes[i, 1].axis('off')
        
        # Prediction
        pred_colored = np.zeros((256, 256, 3), dtype=np.uint8)
        for class_id, color in colors.items():
            pred_colored[y_pred_labels[i] == class_id] = color
        axes[i, 2].imshow(pred_colored)
        
        # Calculate Pred CDR
        pred_cdr = calculate_cdr(y_pred_labels[i])
        pred_class, pred_label, pred_color = classify_glaucoma_severity(pred_cdr['avgCDR']) if pred_cdr['valid'] else (-1, 'Invalid', '#9E9E9E')
        
        axes[i, 2].set_title(f'Prediction\nCDR: {pred_cdr["avgCDR"]:.3f} | {pred_label}', 
                            fontsize=12, fontweight='bold', color=pred_color)
        axes[i, 2].axis('off')
        
        # Overlay
        overlay = X_test[i].copy()
        for class_id, color in colors.items():
            if class_id > 0:
                mask = (y_pred_labels[i] == class_id).astype(np.float32)
                mask_rgb = np.stack([mask * color[0]/255, mask * color[1]/255, mask * color[2]/255], axis=-1)
                overlay = overlay * 0.6 + mask_rgb * 0.4
        axes[i, 3].imshow(overlay)
        axes[i, 3].set_title('Overlay', fontsize=12, fontweight='bold')
        axes[i, 3].axis('off')
        
        # Calculate dice
        y_test_cat = to_categorical(y_test[i], num_classes=3)
        y_pred_cat = to_categorical(y_pred_labels[i], num_classes=3)
        
        disc_dice = 2 * np.sum(y_test_cat[:,:,1] * y_pred_cat[:,:,1]) / (np.sum(y_test_cat[:,:,1]) + np.sum(y_pred_cat[:,:,1]) + 1e-7)
        cup_dice = 2 * np.sum(y_test_cat[:,:,2] * y_pred_cat[:,:,2]) / (np.sum(y_test_cat[:,:,2]) + np.sum(y_pred_cat[:,:,2]) + 1e-7)
        
        cdr_error = abs(gt_cdr['avgCDR'] - pred_cdr['avgCDR']) if gt_cdr['valid'] and pred_cdr['valid'] else np.nan
        
        info_text = f'Sample {i+1}\n'
        info_text += f'Disc Dice: {disc_dice:.3f} | Cup Dice: {cup_dice:.3f}\n'
        info_text += f'CDR Error: {cdr_error:.3f}' if not np.isnan(cdr_error) else 'CDR Error: N/A'
        
        axes[i, 0].text(0.5, -0.15, info_text, transform=axes[i, 0].transAxes, 
                       ha='center', fontsize=10, bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
    
    plt.suptitle(f'{model_name} - Predictions with Glaucoma Severity Assessment', 
                 fontsize=16, fontweight='bold', y=0.995)
    plt.tight_layout()
    plt.savefig(f'{save_dir}/{model_name}_predictions_cdr.png', dpi=150, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_predictions_cdr.png")
    plt.show()
    plt.close()

def plot_cdr_distribution(df_progression, save_dir='results'):
    """Plot CDR distribution and severity classification"""
    os.makedirs(save_dir, exist_ok=True)
    
    fig, axes = plt.subplots(2, 2, figsize=(16, 12))
    
    # CDR scatter plot (GT vs Pred)
    axes[0, 0].scatter(df_progression['GT_avgCDR'], df_progression['Pred_avgCDR'], 
                      alpha=0.6, s=100, c='blue', edgecolors='black')
    axes[0, 0].plot([0, 1], [0, 1], 'r--', linewidth=2, label='Perfect Prediction')
    axes[0, 0].set_xlabel('Ground Truth CDR', fontsize=12, fontweight='bold')
    axes[0, 0].set_ylabel('Predicted CDR', fontsize=12, fontweight='bold')
    axes[0, 0].set_title('CDR: Ground Truth vs Prediction', fontsize=14, fontweight='bold')
    axes[0, 0].legend(fontsize=10)
    axes[0, 0].grid(True, alpha=0.3)
    
    # Add severity zones
    axes[0, 0].axhspan(0, 0.3, alpha=0.1, color='green', label='Normal')
    axes[0, 0].axhspan(0.3, 0.6, alpha=0.1, color='yellow', label='Suspect')
    axes[0, 0].axhspan(0.6, 0.8, alpha=0.1, color='orange', label='Moderate')
    axes[0, 0].axhspan(0.8, 1.0, alpha=0.1, color='red', label='Advanced')
    
    # CDR error histogram
    valid_errors = df_progression['CDR_Error'].dropna()
    axes[0, 1].hist(valid_errors, bins=30, color='steelblue', edgecolor='black', alpha=0.7)
    axes[0, 1].axvline(valid_errors.mean(), color='red', linestyle='--', linewidth=2, 
                      label=f'Mean Error: {valid_errors.mean():.4f}')
    axes[0, 1].set_xlabel('CDR Error (|GT - Pred|)', fontsize=12, fontweight='bold')
    axes[0, 1].set_ylabel('Frequency', fontsize=12, fontweight='bold')
    axes[0, 1].set_title('CDR Error Distribution', fontsize=14, fontweight='bold')
    axes[0, 1].legend(fontsize=10)
    axes[0, 1].grid(True, alpha=0.3)
    
    # Severity classification confusion matrix
    severity_order = ['Normal', 'Suspect', 'Moderate', 'Critical']
    gt_severity = pd.Categorical(df_progression['GT_Severity'], categories=severity_order, ordered=True)
    pred_severity = pd.Categorical(df_progression['Pred_Severity'], categories=severity_order, ordered=True)
    
    cm = confusion_matrix(gt_severity, pred_severity, labels=severity_order)
    
    sns.heatmap(cm, annot=True, fmt='d', cmap='YlOrRd', 
                xticklabels=severity_order, yticklabels=severity_order,
                ax=axes[1, 0], cbar_kws={'label': 'Count'})
    axes[1, 0].set_title('Glaucoma Severity Classification', fontsize=14, fontweight='bold')
    axes[1, 0].set_ylabel('Ground Truth', fontsize=12, fontweight='bold')
    axes[1, 0].set_xlabel('Predicted', fontsize=12, fontweight='bold')
    
    # Severity distribution
    severity_counts_gt = df_progression['GT_Severity'].value_counts()
    severity_counts_pred = df_progression['Pred_Severity'].value_counts()
    
    x = np.arange(len(severity_order))
    width = 0.35
    
    counts_gt = [severity_counts_gt.get(s, 0) for s in severity_order]
    counts_pred = [severity_counts_pred.get(s, 0) for s in severity_order]
    
    bars1 = axes[1, 1].bar(x - width/2, counts_gt, width, label='Ground Truth', 
                          color=['#4CAF50', '#FFC107', '#FF9800', '#F44336'], alpha=0.7)
    bars2 = axes[1, 1].bar(x + width/2, counts_pred, width, label='Predicted', 
                          color=['#4CAF50', '#FFC107', '#FF9800', '#F44336'], alpha=0.4)
    
    axes[1, 1].set_xlabel('Severity Level', fontsize=12, fontweight='bold')
    axes[1, 1].set_ylabel('Count', fontsize=12, fontweight='bold')
    axes[1, 1].set_title('Severity Distribution', fontsize=14, fontweight='bold')
    axes[1, 1].set_xticks(x)
    axes[1, 1].set_xticklabels(severity_order, rotation=15)
    axes[1, 1].legend(fontsize=10)
    axes[1, 1].grid(True, alpha=0.3, axis='y')
    
    plt.tight_layout()
    plt.savefig(f'{save_dir}/cdr_analysis.png', dpi=150, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/cdr_analysis.png")
    plt.show()
    plt.close()

def calculate_progression_accuracy(df_progression):
    """
    Calculate simple accuracy metrics: GT progression vs Predicted progression
    
    Returns accuracy % like: "GT says Normal for 250 images, model says 230 are Normal"
    """
    results = {}
    
    # Overall accuracy
    total = len(df_progression)
    correct = df_progression['Severity_Match'].sum()
    overall_accuracy = (correct / total) * 100
    
    results['overall'] = {
        'total': total,
        'correct': correct,
        'accuracy': overall_accuracy
    }
    
    # Per-class accuracy
    severity_classes = ['Normal', 'Suspect', 'Moderate', 'Critical']
    results['per_class'] = {}
    
    for severity in severity_classes:
        gt_count = len(df_progression[df_progression['GT_Severity'] == severity])
        pred_count = len(df_progression[df_progression['Pred_Severity'] == severity])
        
        # Correctly predicted: GT is this class AND model predicted it as this class
        correct_count = len(df_progression[
            (df_progression['GT_Severity'] == severity) & 
            (df_progression['Pred_Severity'] == severity)
        ])
        
        class_accuracy = (correct_count / gt_count * 100) if gt_count > 0 else 0.0
        
        results['per_class'][severity] = {
            'gt_count': gt_count,
            'pred_count': pred_count,
            'correct': correct_count,
            'accuracy': class_accuracy
        }
    
    # Manual review statistics
    manual_review_needed = df_progression['Manual_Review_Needed'].sum()
    manual_review_pct = (manual_review_needed / total) * 100
    
    results['manual_review'] = {
        'count': manual_review_needed,
        'percentage': manual_review_pct
    }
    
    return results

def plot_training_history(history, model_name, save_dir='results'):
    """Plot training history - Loss and Accuracy only"""
    os.makedirs(save_dir, exist_ok=True)
    
    fig, axes = plt.subplots(1, 2, figsize=(15, 5))
    
    # Loss curves
    axes[0].plot(history.history['loss'], label='Training Loss', linewidth=2)
    axes[0].plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
    axes[0].set_title(f'{model_name} - Loss Over Epochs', fontsize=14, fontweight='bold')
    axes[0].set_xlabel('Epoch', fontsize=12)
    axes[0].set_ylabel('Loss', fontsize=12)
    axes[0].legend(fontsize=10)
    axes[0].grid(True, alpha=0.3)
    
    # Accuracy curves
    axes[1].plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
    axes[1].plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
    axes[1].set_title(f'{model_name} - Accuracy Over Epochs', fontsize=14, fontweight='bold')
    axes[1].set_xlabel('Epoch', fontsize=12)
    axes[1].set_ylabel('Accuracy', fontsize=12)
    axes[1].legend(fontsize=10)
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(f'{save_dir}/{model_name}_history.png', dpi=150, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_history.png")
    plt.show()
    plt.close()

def plot_confusion_matrices(y_true, y_pred, model_name, save_dir='results'):
    """Plot confusion matrices"""
    os.makedirs(save_dir, exist_ok=True)
    
    y_true_labels = np.argmax(y_true, axis=-1).flatten()
    y_pred_labels = np.argmax(y_pred, axis=-1).flatten()
    
    cm = confusion_matrix(y_true_labels, y_pred_labels)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    class_names = ['Background', 'Disc', 'Cup']
    
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[0], cbar_kws={'label': 'Count'})
    axes[0].set_title(f'{model_name}\nConfusion Matrix', fontsize=14, fontweight='bold')
    axes[0].set_ylabel('True Label', fontsize=12)
    axes[0].set_xlabel('Predicted Label', fontsize=12)
    
    sns.heatmap(cm_normalized, annot=True, fmt='.3f', cmap='Greens',
                xticklabels=class_names, yticklabels=class_names,
                ax=axes[1], cbar_kws={'label': 'Proportion'})
    axes[1].set_title(f'{model_name}\nNormalized Confusion Matrix', fontsize=14, fontweight='bold')
    axes[1].set_ylabel('True Label', fontsize=12)
    axes[1].set_xlabel('Predicted Label', fontsize=12)
    
    plt.tight_layout()
    plt.savefig(f"{save_dir}/{model_name}_confusion_matrices.png", dpi=300, bbox_inches='tight')
    print(f"  ✓ Saved: {save_dir}/{model_name}_confusion_matrices.png")
    plt.show()
    plt.close()
    
    print(f"\nConfusion Matrix:\n{cm}")
    print(f"\nNormalized Confusion Matrix:\n{np.round(cm_normalized, 3)}")
    
    return cm, cm_normalized

# ============================================================================
# TRAINING AND EVALUATION
# ============================================================================

def train_model(X_train, y_train, X_val, y_val, X_test, y_test, model_name, 
               augment=None, save_dir='results'):
    """Train model"""
    print(f"\n{'='*80}")
    print(f"TRAINING: {model_name}")
    print(f"{'='*80}")
    print(f"  Architecture: Deeper Decoder + Focal-EIoU + MC Dropout")
    print(f"  Loss: Focal + Enhanced IoU (Combined)")
    
    K.clear_session()
    
    # Build model
    model = build_deeper_focal_mc_unet(dropout_rate=0.3)
    param_count = model.count_params()
    
    # Compile
    model.compile(
        optimizer=optimizers.Adam(learning_rate=5e-4),
        loss=focal_eiou_combined_loss,
        metrics=[dice_coef_multiclass, dice_class_0, dice_class_1, dice_class_2,
                "accuracy", iou_coef_multiclass, iou_class_0, iou_class_1, iou_class_2]
    )
    
    # Callbacks
    checkpoint = ModelCheckpoint(f"{save_dir}/{model_name}.keras", save_best_only=True, 
                                verbose=1, monitor='val_loss', mode='min')
    reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.3, patience=3, 
                                  verbose=1, mode='min', min_lr=1e-7)
    early_stop = EarlyStopping(monitor="val_loss", patience=10, verbose=1, 
                              restore_best_weights=True, mode='min')
    
    # Training
    batch_size = 4
    steps_train = X_train.shape[0] // batch_size
    steps_val = X_val.shape[0] // batch_size
    
    history = model.fit(
        data_generator(X_train, y_train, batch_size, augment),
        validation_data=data_generator(X_val, y_val, batch_size, None),
        steps_per_epoch=steps_train,
        validation_steps=steps_val,
        epochs=50,
        callbacks=[checkpoint, reduce_lr, early_stop],
        verbose=1
    )
    
    print(f"✓ Training completed")
    
    # Visualizations
    print("\nGenerating visualizations...")
    plot_training_history(history, model_name, save_dir)
    plot_sample_predictions_with_cdr(model, X_test, y_test, model_name, num_samples=8, save_dir=save_dir)
    
    return model, history, param_count

def evaluate_model(model, X_test, y_test, model_name, run_mc_dropout=True):
    """Evaluate model with glaucoma progression analysis"""
    print(f"\n{'='*80}")
    print(f"EVALUATION: {model_name}")
    print(f"{'='*80}")
    
    y_test_cat = np.array([to_categorical(mask, num_classes=3) for mask in y_test])
    
    # Predict
    y_pred = model.predict(X_test, verbose=0, batch_size=8)
    y_pred_labels = np.argmax(y_pred, axis=-1)
    
    # Confusion matrices
    plot_confusion_matrices(y_test_cat, y_pred, model_name, save_dir='results')
    
    # Classification metrics
    y_true_labels = np.argmax(y_test_cat, axis=-1).flatten()
    y_pred_labels_flat = y_pred_labels.flatten()
    
    precision = precision_score(y_true_labels, y_pred_labels_flat, average=None, zero_division=0)
    recall = recall_score(y_true_labels, y_pred_labels_flat, average=None, zero_division=0)
    f1 = f1_score(y_true_labels, y_pred_labels_flat, average=None, zero_division=0)
    
    print(f"\nPrecision, Recall, F1 Score per class:")
    class_names = ["Background", "Disc", "Cup"]
    for idx, cname in enumerate(class_names):
        print(f"  {cname}: Precision={precision[idx]:.4f}, Recall={recall[idx]:.4f}, F1={f1[idx]:.4f}")
    
    print(f"\nMacro-averaged metrics:")
    print(f"  Precision: {np.mean(precision):.4f}")
    print(f"  Recall: {np.mean(recall):.4f}")
    print(f"  F1 Score: {np.mean(f1):.4f}")
    
    # Per-class Dice and IoU
    results = {'standard': {}}
    for cidx, cname in enumerate(class_names):
        y_true_c = (np.argmax(y_test_cat, axis=-1) == cidx).astype(np.float32)
        y_pred_c = (y_pred_labels == cidx).astype(np.float32)
        
        intersection = np.sum(y_true_c * y_pred_c)
        dice = (2. * intersection + 1e-7) / (np.sum(y_true_c) + np.sum(y_pred_c) + 1e-7)
        union = np.sum(y_true_c) + np.sum(y_pred_c) - intersection
        iou = (intersection + 1e-7) / (union + 1e-7)
        
        results['standard'][cname] = {'dice': dice, 'iou': iou}
        print(f"  {cname}: Dice={dice:.4f}, IoU={iou:.4f}")
    
    # Glaucoma Progression Analysis
    print(f"\n{'='*80}")
    print(f"GLAUCOMA PROGRESSION ANALYSIS")
    print(f"{'='*80}")
    print(f"\nMethod:")
    print(f"  1. Calculate vCDR from GT masks (Expert Annotations)")
    print(f"  2. Calculate vCDR from Predicted masks (MobileNet Segmentation)")
    print(f"  3. Classify progression severity using vCDR thresholds")
    print(f"  4. Compare GT progression vs Predicted progression")
    print(f"\nCDR Method: Vertical diameter ratio (clinical standard)")
    print(f"Severity Thresholds:")
    print(f"  - Normal:   vCDR < 0.3")
    print(f"  - Suspect:  0.3 ≤ vCDR < 0.6")
    print(f"  - Moderate: 0.6 ≤ vCDR < 0.75")
    print(f"  - Critical: vCDR ≥ 0.75")
    
    df_progression = analyze_glaucoma_progression(y_test, y_pred_labels, cdr_method='vertical')
    
    # CDR Statistics
    print(f"\n{'-'*80}")
    print(f"CDR Statistics:")
    print(f"{'-'*80}")
    print(f"  Mean GT CDR:   {df_progression['GT_avgCDR'].mean():.4f} ± {df_progression['GT_avgCDR'].std():.4f}")
    print(f"  Mean Pred CDR: {df_progression['Pred_avgCDR'].mean():.4f} ± {df_progression['Pred_avgCDR'].std():.4f}")
    print(f"  Mean CDR Error: {df_progression['CDR_Error'].mean():.4f} ± {df_progression['CDR_Error'].std():.4f}")
    
    # Calculate progression accuracy
    accuracy_results = calculate_progression_accuracy(df_progression)
    
    # Overall Accuracy
    print(f"\n{'='*80}")
    print(f"PROGRESSION CLASSIFICATION ACCURACY")
    print(f"{'='*80}")
    print(f"\nOverall Accuracy: {accuracy_results['overall']['accuracy']:.2f}%")
    print(f"  - Correctly Classified: {accuracy_results['overall']['correct']}/{accuracy_results['overall']['total']} samples")
    print(f"  - Incorrectly Classified: {accuracy_results['overall']['total'] - accuracy_results['overall']['correct']}/{accuracy_results['overall']['total']} samples")
    
    # Per-Class Results
    print(f"\n{'-'*80}")
    print(f"Per-Class Results:")
    print(f"{'-'*80}")
    print(f"{'Severity':<12} {'GT Count':<12} {'Pred Count':<12} {'Correct':<12} {'Accuracy':<12}")
    print(f"{'-'*80}")
    
    for severity in ['Normal', 'Suspect', 'Moderate', 'Critical']:
        stats = accuracy_results['per_class'][severity]
        print(f"{severity:<12} {stats['gt_count']:<12} {stats['pred_count']:<12} "
              f"{stats['correct']:<12} {stats['accuracy']:<12.2f}%")
    
    print(f"\n{'='*80}")
    print(f"INTERPRETATION EXAMPLE:")
    print(f"{'='*80}")
    normal_stats = accuracy_results['per_class']['Normal']
    print(f"  - GT says 'Normal' for {normal_stats['gt_count']} images")
    print(f"  - MobileNet model says 'Normal' for {normal_stats['pred_count']} images")
    print(f"  - MobileNet correctly predicts {normal_stats['correct']} as 'Normal'")
    print(f"  - Accuracy for Normal class: {normal_stats['correct']}/{normal_stats['gt_count']} = {normal_stats['accuracy']:.1f}%")
    
    # Manual Review Recommendations
    print(f"\n{'='*80}")
    print(f"MANUAL REVIEW RECOMMENDATIONS")
    print(f"{'='*80}")
    print(f"\nSamples Requiring Manual Review: {accuracy_results['manual_review']['count']}/{accuracy_results['overall']['total']} "
          f"({accuracy_results['manual_review']['percentage']:.1f}%)")
    print(f"\nCriteria for Manual Review:")
    print(f"  1. All Critical cases (high-risk, requires expert verification)")
    print(f"  2. Classification mismatches (GT ≠ Predicted severity)")
    print(f"\nReason: Critical cases need expert confirmation, and mismatches may")
    print(f"indicate borderline cases or segmentation issues requiring review.")
    
    # Breakdown of manual review cases
    review_df = df_progression[df_progression['Manual_Review_Needed'] == True]
    critical_cases = len(review_df[review_df['GT_Severity'] == 'Critical'])
    mismatch_cases = len(review_df[review_df['Severity_Match'] == False])
    overlap = len(review_df[(review_df['GT_Severity'] == 'Critical') & (review_df['Severity_Match'] == False)])
    
    print(f"\nBreakdown:")
    print(f"  - Critical cases: {critical_cases} samples")
    print(f"  - Classification mismatches: {mismatch_cases} samples")
    print(f"  - Overlap (Critical + Mismatch): {overlap} samples")
    
    # Save progression data
    df_progression.to_csv('results/glaucoma_progression_analysis.csv', index=False)
    print(f"\n✓ Saved: results/glaucoma_progression_analysis.csv")
    
    # Plot CDR analysis
    plot_cdr_distribution(df_progression, save_dir='results')
    
    results['glaucoma'] = {
        'mean_cdr_error': df_progression['CDR_Error'].mean(),
        'median_cdr_error': df_progression['CDR_Error'].median(),
        'classification_accuracy': accuracy_results['overall']['accuracy'] / 100,
        'df_progression': df_progression,
        'accuracy_breakdown': accuracy_results
    }
    
    # MC Dropout
    if run_mc_dropout:
        print(f"\n{'='*80}")
        print(f"MC DROPOUT UNCERTAINTY ESTIMATION")
        print(f"{'='*80}")
        mean_pred, std_pred = mc_dropout_predict(model, X_test[:100], num_samples=15, verbose=True)
        results['mc_dropout'] = {}
        for cidx, cname in enumerate(class_names):
            mean_std = np.mean(std_pred[:, :, :, cidx])
            results['mc_dropout'][cname] = {'mean_uncertainty': mean_std}
            print(f"  {cname} uncertainty: {mean_std:.4f}")
    
    return results

# ============================================================================
# MAIN EXECUTION
# ============================================================================

if __name__ == "__main__":
    # Setup
    gpu_available = configure_gpu()
    root_dir = "/kaggle/input/refuge/REFUGE/"
    train_aug = setup_augmentations()
    save_dir = "results"
    os.makedirs(save_dir, exist_ok=True)
    
    print(f"\n{'='*100}")
    print(f"{'MOBILENET-UNET WITH GLAUCOMA PROGRESSION SCORING':^100s}")
    print(f"{'='*100}")
    print(f"\nGlaucoma Severity Classification:")
    print(f"  - Normal:   vCDR < 0.3  (Green)")
    print(f"  - Suspect:  0.3 ≤ vCDR < 0.6  (Amber)")
    print(f"  - Moderate: 0.6 ≤ vCDR < 0.75 (Orange)")
    print(f"  - Critical: vCDR ≥ 0.75 (Red)")
    print(f"  CDR Method: Vertical diameter ratio (clinical standard)")
    print(f"\nManual Review: Recommended for Critical cases and classification mismatches")
    
    # Load data
    all_images, all_masks = load_all_data(root_dir)
    (X_train, y_train), (X_val, y_val), (X_test, y_test) = create_new_split(all_images, all_masks)
    
    # Train model
    model, history, params = train_model(
        X_train, y_train, X_val, y_val, X_test, y_test,
        "Deeper_Focal_MC_GlaucomaScoring",
        augment=train_aug, save_dir=save_dir
    )
    
    # Evaluate with glaucoma analysis
    results = evaluate_model(model, X_test, y_test, "Deeper+Focal+MC+GlaucomaScoring", run_mc_dropout=True)
    
    print(f"\n{'='*100}")
    print(f"{'✓ TRAINING AND EVALUATION COMPLETED!':^100s}")
    print(f"{'='*100}")
    print(f"\nModel: Deeper + Focal + EIoU + MC Dropout + Glaucoma Scoring")
    print(f"Parameters: {params:,}")
    print(f"Results saved in: {save_dir}/")
    print(f"\nGenerated Files:")
    print(f"  - Training history: {save_dir}/Deeper_Focal_MC_GlaucomaScoring_history.png")
    print(f"  - Predictions with CDR: {save_dir}/Deeper_Focal_MC_GlaucomaScoring_predictions_cdr.png")
    print(f"  - CDR Analysis: {save_dir}/cdr_analysis.png")
    print(f"  - Progression CSV: {save_dir}/glaucoma_progression_analysis.csv")
    print(f"  - Confusion Matrices: {save_dir}/Deeper+Focal+MC+GlaucomaScoring_confusion_matrices.png")
    print(f"\n{'='*100}\n")
# Out:
# 2025-11-18 16:47:04.082333: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763484424.291775      48 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763484424.353576      48 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# Configuring GPU settings...
# ✓ GPU found: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
#
# ====================================================================================================
#                           MOBILENET-UNET WITH GLAUCOMA PROGRESSION SCORING
# ====================================================================================================
#
# Glaucoma Severity Classification:
#   - Normal:   vCDR < 0.3  (Green)
#   - Suspect:  0.3 ≤ vCDR < 0.6  (Amber)
#   - Moderate: 0.6 ≤ vCDR < 0.75 (Orange)
#   - Critical: vCDR ≥ 0.75 (Red)
#   CDR Method: Vertical diameter ratio (clinical standard)
#
# Manual Review: Recommended for Critical cases and classification mismatches
# Loading train data...
#   train: 400 samples
# Loading val data...
#   val: 400 samples
# Loading test data...
#   test: 400 samples
# Split - Train: 600, Val: 200, Test: 400
#
# ================================================================================
# TRAINING: Deeper_Focal_MC_GlaucomaScoring
# ================================================================================
#   Architecture: Deeper Decoder + Focal-EIoU + MC Dropout
#   Loss: Focal + Enhanced IoU (Combined)
# I0000 00:00:1763484533.498609      48 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
#
# Model Configuration:
#   Total Parameters: 37,129,475
#   Dropout Layers: 5
#   Architecture: Deeper Decoder + Focal-EIoU + MC Dropout
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763484579.867350     106 service.cc:148] XLA service 0x7a1e20007640 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1763484579.868102     106 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1763484585.712756     106 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1763484593.234887     106 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763484593.493748     106 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#   1/150 ━━━━━━━━━━━━━━━━━━━━ 3:33:44 86s/step - accuracy: 0.3789 - dice_class_0: 0.5472 - dice_class_1: 0.0342 - dice_class_2: 0.0068 - dice_coef_multiclass: 0.3545 - iou_class_0: 0.3767 - iou_class_1: 0.0174 - iou_class_2: 0.0034 - iou_coef_multiclass: 0.2154 - loss: 1.6127
# I0000 00:00:1763484623.495892     106 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8733 - dice_class_0: 0.9211 - dice_class_1: 0.3565 - dice_class_2: 0.3987 - dice_coef_multiclass: 0.6315 - iou_class_0: 0.8741 - iou_class_1: 0.2303 - iou_class_2: 0.2814 - iou_coef_multiclass: 0.4728 - loss: 1.1236
# E0000 00:00:1763484646.919571     108 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763484647.177635     108 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Epoch 1: val_loss improved from inf to 0.68859, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 117s 210ms/step - accuracy: 0.8738 - dice_class_0: 0.9214 - dice_class_1: 0.3573 - dice_class_2: 0.3998 - dice_coef_multiclass: 0.6322 - iou_class_0: 0.8746 - iou_class_1: 0.2309 - iou_class_2: 0.2822 - iou_coef_multiclass: 0.4735 - loss: 1.1225 - val_accuracy: 0.9625 - val_dice_class_0: 0.9818 - val_dice_class_1: 0.5268 - val_dice_class_2: 0.1767 - val_dice_coef_multiclass: 0.9386 - val_iou_class_0: 0.9644 - val_iou_class_1: 0.3597 - val_iou_class_2: 0.0987 - val_iou_coef_multiclass: 0.8844 - val_loss: 0.6886 - learning_rate: 5.0000e-04
# Epoch 2/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9853 - dice_class_0: 0.9933 - dice_class_1: 0.6578 - dice_class_2: 0.6369 - dice_coef_multiclass: 0.9056 - iou_class_0: 0.9866 - iou_class_1: 0.4948 - iou_class_2: 0.4725 - iou_coef_multiclass: 0.8286 - loss: 0.6953
# Epoch 2: val_loss did not improve from 0.68859
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9853 - dice_class_0: 0.9933 - dice_class_1: 0.6582 - dice_class_2: 0.6368 - dice_coef_multiclass: 0.9058 - iou_class_0: 0.9867 - iou_class_1: 0.4952 - iou_class_2: 0.4725 - iou_coef_multiclass: 0.8289 - loss: 0.6949 - val_accuracy: 0.5971 - val_dice_class_0: 0.7438 - val_dice_class_1: 0.0506 - val_dice_class_2: 0.4266 - val_dice_coef_multiclass: 0.5980 - val_iou_class_0: 0.5924 - val_iou_class_1: 0.0260 - val_iou_class_2: 0.2732 - val_iou_coef_multiclass: 0.4268 - val_loss: 1.9915 - learning_rate: 5.0000e-04
# Epoch 3/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9938 - dice_class_0: 0.9976 - dice_class_1: 0.8108 - dice_class_2: 0.7813 - dice_coef_multiclass: 0.9804 - iou_class_0: 0.9952 - iou_class_1: 0.6851 - iou_class_2: 0.6483 - iou_coef_multiclass: 0.9616 - loss: 0.4355
# Epoch 3: val_loss improved from 0.68859 to 0.28137, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 146ms/step - accuracy: 0.9938 - dice_class_0: 0.9976 - dice_class_1: 0.8109 - dice_class_2: 0.7815 - dice_coef_multiclass: 0.9804 - iou_class_0: 0.9952 - iou_class_1: 0.6852 - iou_class_2: 0.6486 - iou_coef_multiclass: 0.9616 - loss: 0.4351 - val_accuracy: 0.9957 - val_dice_class_0: 0.9990 - val_dice_class_1: 0.8415 - val_dice_class_2: 0.6731 - val_dice_coef_multiclass: 0.9957 - val_iou_class_0: 0.9979 - val_iou_class_1: 0.7286 - val_iou_class_2: 0.5118 - val_iou_coef_multiclass: 0.9915 - val_loss: 0.2814 - learning_rate: 5.0000e-04
# Epoch 4/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9967 - dice_class_0: 0.9989 - dice_class_1: 0.8714 - dice_class_2: 0.8557 - dice_coef_multiclass: 0.9952 - iou_class_0: 0.9978 - iou_class_1: 0.7733 - iou_class_2: 0.7500 - iou_coef_multiclass: 0.9904 - loss: 0.2275
# Epoch 4: val_loss did not improve from 0.28137
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9967 - dice_class_0: 0.9989 - dice_class_1: 0.8714 - dice_class_2: 0.8558 - dice_coef_multiclass: 0.9952 - iou_class_0: 0.9978 - iou_class_1: 0.7733 - iou_class_2: 0.7501 - iou_coef_multiclass: 0.9904 - loss: 0.2274 - val_accuracy: 0.9915 - val_dice_class_0: 0.9976 - val_dice_class_1: 0.6572 - val_dice_class_2: 0.1171 - val_dice_coef_multiclass: 0.9915 - val_iou_class_0: 0.9952 - val_iou_class_1: 0.4947 - val_iou_class_2: 0.0649 - val_iou_coef_multiclass: 0.9831 - val_loss: 0.5937 - learning_rate: 5.0000e-04
# Epoch 5/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9971 - dice_class_0: 0.9990 - dice_class_1: 0.8881 - dice_class_2: 0.8752 - dice_coef_multiclass: 0.9965 - iou_class_0: 0.9981 - iou_class_1: 0.7998 - iou_class_2: 0.7802 - iou_coef_multiclass: 0.9930 - loss: 0.1805
# Epoch 5: val_loss did not improve from 0.28137
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9971 - dice_class_0: 0.9990 - dice_class_1: 0.8881 - dice_class_2: 0.8752 - dice_coef_multiclass: 0.9965 - iou_class_0: 0.9981 - iou_class_1: 0.7998 - iou_class_2: 0.7801 - iou_coef_multiclass: 0.9930 - loss: 0.1805 - val_accuracy: 0.9886 - val_dice_class_0: 0.9947 - val_dice_class_1: 0.4518 - val_dice_class_2: 0.3386 - val_dice_coef_multiclass: 0.9884 - val_iou_class_0: 0.9895 - val_iou_class_1: 0.3075 - val_iou_class_2: 0.2180 - val_iou_coef_multiclass: 0.9771 - val_loss: 0.6837 - learning_rate: 5.0000e-04
# Epoch 6/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9973 - dice_class_0: 0.9992 - dice_class_1: 0.8939 - dice_class_2: 0.8765 - dice_coef_multiclass: 0.9970 - iou_class_0: 0.9983 - iou_class_1: 0.8093 - iou_class_2: 0.7816 - iou_coef_multiclass: 0.9941 - loss: 0.1629
# Epoch 6: val_loss did not improve from 0.28137
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9973 - dice_class_0: 0.9992 - dice_class_1: 0.8939 - dice_class_2: 0.8765 - dice_coef_multiclass: 0.9970 - iou_class_0: 0.9983 - iou_class_1: 0.8093 - iou_class_2: 0.7817 - iou_coef_multiclass: 0.9941 - loss: 0.1629 - val_accuracy: 0.9943 - val_dice_class_0: 0.9980 - val_dice_class_1: 0.7662 - val_dice_class_2: 0.6495 - val_dice_coef_multiclass: 0.9943 - val_iou_class_0: 0.9960 - val_iou_class_1: 0.6307 - val_iou_class_2: 0.4914 - val_iou_coef_multiclass: 0.9887 - val_loss: 0.3599 - learning_rate: 5.0000e-04
# Epoch 7/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9975 - dice_class_0: 0.9992 - dice_class_1: 0.8997 - dice_class_2: 0.8821 - dice_coef_multiclass: 0.9973 - iou_class_0: 0.9984 - iou_class_1: 0.8185 - iou_class_2: 0.7913 - iou_coef_multiclass: 0.9945 - loss: 0.1506
# Epoch 7: val_loss did not improve from 0.28137
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9975 - dice_class_0: 0.9992 - dice_class_1: 0.8997 - dice_class_2: 0.8821 - dice_coef_multiclass: 0.9973 - iou_class_0: 0.9984 - iou_class_1: 0.8185 - iou_class_2: 0.7914 - iou_coef_multiclass: 0.9945 - loss: 0.1506 - val_accuracy: 0.9934 - val_dice_class_0: 0.9973 - val_dice_class_1: 0.7323 - val_dice_class_2: 0.6300 - val_dice_coef_multiclass: 0.9934 - val_iou_class_0: 0.9946 - val_iou_class_1: 0.5910 - val_iou_class_2: 0.4828 - val_iou_coef_multiclass: 0.9868 - val_loss: 0.3709 - learning_rate: 1.5000e-04
# Epoch 8/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9113 - dice_class_2: 0.8974 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9986 - iou_class_1: 0.8376 - iou_class_2: 0.8153 - iou_coef_multiclass: 0.9952 - loss: 0.1336
# Epoch 8: val_loss improved from 0.28137 to 0.24873, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 146ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9112 - dice_class_2: 0.8974 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9986 - iou_class_1: 0.8375 - iou_class_2: 0.8152 - iou_coef_multiclass: 0.9952 - loss: 0.1336 - val_accuracy: 0.9956 - val_dice_class_0: 0.9983 - val_dice_class_1: 0.8178 - val_dice_class_2: 0.7889 - val_dice_coef_multiclass: 0.9955 - val_iou_class_0: 0.9966 - val_iou_class_1: 0.6980 - val_iou_class_2: 0.6649 - val_iou_coef_multiclass: 0.9910 - val_loss: 0.2487 - learning_rate: 1.5000e-04
# Epoch 9/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9132 - dice_class_2: 0.9035 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9986 - iou_class_1: 0.8409 - iou_class_2: 0.8251 - iou_coef_multiclass: 0.9953 - loss: 0.1297
# Epoch 9: val_loss improved from 0.24873 to 0.20752, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 146ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9132 - dice_class_2: 0.9035 - dice_coef_multiclass: 0.9977 - iou_class_0: 0.9986 - iou_class_1: 0.8409 - iou_class_2: 0.8250 - iou_coef_multiclass: 0.9953 - loss: 0.1297 - val_accuracy: 0.9965 - val_dice_class_0: 0.9988 - val_dice_class_1: 0.8526 - val_dice_class_2: 0.8257 - val_dice_coef_multiclass: 0.9964 - val_iou_class_0: 0.9976 - val_iou_class_1: 0.7466 - val_iou_class_2: 0.7098 - val_iou_coef_multiclass: 0.9928 - val_loss: 0.2075 - learning_rate: 1.5000e-04
# Epoch 10/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9115 - dice_class_2: 0.9034 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9986 - iou_class_1: 0.8380 - iou_class_2: 0.8251 - iou_coef_multiclass: 0.9953 - loss: 0.1289
# Epoch 10: val_loss improved from 0.20752 to 0.17539, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 148ms/step - accuracy: 0.9978 - dice_class_0: 0.9993 - dice_class_1: 0.9115 - dice_class_2: 0.9034 - dice_coef_multiclass: 0.9976 - iou_class_0: 0.9986 - iou_class_1: 0.8380 - iou_class_2: 0.8251 - iou_coef_multiclass: 0.9953 - loss: 0.1289 - val_accuracy: 0.9970 - val_dice_class_0: 0.9990 - val_dice_class_1: 0.8768 - val_dice_class_2: 0.8520 - val_dice_coef_multiclass: 0.9969 - val_iou_class_0: 0.9981 - val_iou_class_1: 0.7840 - val_iou_class_2: 0.7480 - val_iou_coef_multiclass: 0.9939 - val_loss: 0.1754 - learning_rate: 1.5000e-04
# Epoch 11/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9151 - dice_class_2: 0.9137 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9986 - iou_class_1: 0.8440 - iou_class_2: 0.8419 - iou_coef_multiclass: 0.9955 - loss: 0.1218
# Epoch 11: val_loss did not improve from 0.17539
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9151 - dice_class_2: 0.9136 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9986 - iou_class_1: 0.8440 - iou_class_2: 0.8418 - iou_coef_multiclass: 0.9955 - loss: 0.1219 - val_accuracy: 0.9971 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.8825 - val_dice_class_2: 0.8127 - val_dice_coef_multiclass: 0.9971 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.7913 - val_iou_class_2: 0.6880 - val_iou_coef_multiclass: 0.9941 - val_loss: 0.1891 - learning_rate: 1.5000e-04
# Epoch 12/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9159 - dice_class_2: 0.9082 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9986 - iou_class_1: 0.8454 - iou_class_2: 0.8327 - iou_coef_multiclass: 0.9956 - loss: 0.1226
# Epoch 12: val_loss improved from 0.17539 to 0.17381, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 147ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9159 - dice_class_2: 0.9082 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9986 - iou_class_1: 0.8454 - iou_class_2: 0.8327 - iou_coef_multiclass: 0.9956 - loss: 0.1226 - val_accuracy: 0.9974 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8938 - val_dice_class_2: 0.8337 - val_dice_coef_multiclass: 0.9973 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8092 - val_iou_class_2: 0.7176 - val_iou_coef_multiclass: 0.9946 - val_loss: 0.1738 - learning_rate: 1.5000e-04
# Epoch 13/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9142 - dice_class_2: 0.9090 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9986 - iou_class_1: 0.8425 - iou_class_2: 0.8341 - iou_coef_multiclass: 0.9956 - loss: 0.1242
# Epoch 13: val_loss improved from 0.17381 to 0.14890, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 146ms/step - accuracy: 0.9979 - dice_class_0: 0.9993 - dice_class_1: 0.9142 - dice_class_2: 0.9090 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9986 - iou_class_1: 0.8425 - iou_class_2: 0.8341 - iou_coef_multiclass: 0.9956 - loss: 0.1242 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.8980 - val_dice_class_2: 0.8775 - val_dice_coef_multiclass: 0.9975 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.8166 - val_iou_class_2: 0.7833 - val_iou_coef_multiclass: 0.9950 - val_loss: 0.1489 - learning_rate: 1.5000e-04
# Epoch 14/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9173 - dice_class_2: 0.9112 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9987 - iou_class_1: 0.8479 - iou_class_2: 0.8378 - iou_coef_multiclass: 0.9957 - loss: 0.1199
# Epoch 14: val_loss improved from 0.14890 to 0.14325, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 148ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9173 - dice_class_2: 0.9112 - dice_coef_multiclass: 0.9978 - iou_class_0: 0.9987 - iou_class_1: 0.8479 - iou_class_2: 0.8378 - iou_coef_multiclass: 0.9957 - loss: 0.1199 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9019 - val_dice_class_2: 0.8831 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8225 - val_iou_class_2: 0.7919 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1433 - learning_rate: 1.5000e-04
# Epoch 15/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9211 - dice_class_2: 0.9134 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8541 - iou_class_2: 0.8415 - iou_coef_multiclass: 0.9959 - loss: 0.1158
# Epoch 15: val_loss did not improve from 0.14325
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9980 - dice_class_0: 0.9994 - dice_class_1: 0.9210 - dice_class_2: 0.9134 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8541 - iou_class_2: 0.8415 - iou_coef_multiclass: 0.9959 - loss: 0.1158 - val_accuracy: 0.9973 - val_dice_class_0: 0.9991 - val_dice_class_1: 0.8915 - val_dice_class_2: 0.8667 - val_dice_coef_multiclass: 0.9972 - val_iou_class_0: 0.9982 - val_iou_class_1: 0.8063 - val_iou_class_2: 0.7725 - val_iou_coef_multiclass: 0.9945 - val_loss: 0.1612 - learning_rate: 1.5000e-04
# Epoch 16/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9980 - dice_class_0: 0.9993 - dice_class_1: 0.9201 - dice_class_2: 0.9201 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8525 - iou_class_2: 0.8529 - iou_coef_multiclass: 0.9958 - loss: 0.1134
# Epoch 16: val_loss did not improve from 0.14325
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9980 - dice_class_0: 0.9993 - dice_class_1: 0.9201 - dice_class_2: 0.9201 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8525 - iou_class_2: 0.8528 - iou_coef_multiclass: 0.9958 - loss: 0.1134 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9024 - val_dice_class_2: 0.8662 - val_dice_coef_multiclass: 0.9975 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8231 - val_iou_class_2: 0.7660 - val_iou_coef_multiclass: 0.9951 - val_loss: 0.1501 - learning_rate: 1.5000e-04
# Epoch 17/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9980 - dice_class_0: 0.9993 - dice_class_1: 0.9195 - dice_class_2: 0.9160 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8516 - iou_class_2: 0.8460 - iou_coef_multiclass: 0.9958 - loss: 0.1145
# Epoch 17: val_loss did not improve from 0.14325
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 4.500000213738531e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9980 - dice_class_0: 0.9993 - dice_class_1: 0.9195 - dice_class_2: 0.9160 - dice_coef_multiclass: 0.9979 - iou_class_0: 0.9987 - iou_class_1: 0.8516 - iou_class_2: 0.8460 - iou_coef_multiclass: 0.9958 - loss: 0.1145 - val_accuracy: 0.9976 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9002 - val_dice_class_2: 0.8806 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8197 - val_iou_class_2: 0.7878 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1459 - learning_rate: 1.5000e-04
# Epoch 18/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9237 - dice_class_2: 0.9256 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8585 - iou_class_2: 0.8620 - iou_coef_multiclass: 0.9961 - loss: 0.1072
# Epoch 18: val_loss improved from 0.14325 to 0.14315, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 147ms/step - accuracy: 0.9981 - dice_class_0: 0.9994 - dice_class_1: 0.9237 - dice_class_2: 0.9256 - dice_coef_multiclass: 0.9980 - iou_class_0: 0.9988 - iou_class_1: 0.8585 - iou_class_2: 0.8619 - iou_coef_multiclass: 0.9961 - loss: 0.1072 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9044 - val_dice_class_2: 0.8801 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8266 - val_iou_class_2: 0.7879 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1431 - learning_rate: 4.5000e-05
# Epoch 19/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9264 - dice_class_2: 0.9230 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8633 - iou_class_2: 0.8578 - iou_coef_multiclass: 0.9962 - loss: 0.1055
# Epoch 19: val_loss did not improve from 0.14315
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9264 - dice_class_2: 0.9230 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8633 - iou_class_2: 0.8578 - iou_coef_multiclass: 0.9962 - loss: 0.1055 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9032 - val_dice_class_2: 0.8766 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8245 - val_iou_class_2: 0.7815 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1468 - learning_rate: 4.5000e-05
# Epoch 20/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9271 - dice_class_2: 0.9273 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8645 - iou_class_2: 0.8651 - iou_coef_multiclass: 0.9962 - loss: 0.1023
# Epoch 20: val_loss improved from 0.14315 to 0.14197, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 147ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9271 - dice_class_2: 0.9273 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8645 - iou_class_2: 0.8651 - iou_coef_multiclass: 0.9962 - loss: 0.1023 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9046 - val_dice_class_2: 0.8831 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8269 - val_iou_class_2: 0.7931 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1420 - learning_rate: 4.5000e-05
# Epoch 21/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9278 - dice_class_2: 0.9333 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8659 - iou_class_2: 0.8755 - iou_coef_multiclass: 0.9963 - loss: 0.0991
# Epoch 21: val_loss did not improve from 0.14197
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9278 - dice_class_2: 0.9333 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8659 - iou_class_2: 0.8755 - iou_coef_multiclass: 0.9963 - loss: 0.0991 - val_accuracy: 0.9975 - val_dice_class_0: 0.9992 - val_dice_class_1: 0.9001 - val_dice_class_2: 0.8794 - val_dice_coef_multiclass: 0.9975 - val_iou_class_0: 0.9985 - val_iou_class_1: 0.8196 - val_iou_class_2: 0.7867 - val_iou_coef_multiclass: 0.9949 - val_loss: 0.1479 - learning_rate: 4.5000e-05
# Epoch 22/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9297 - dice_class_2: 0.9316 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8689 - iou_class_2: 0.8725 - iou_coef_multiclass: 0.9963 - loss: 0.0985
# Epoch 22: val_loss did not improve from 0.14197
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9297 - dice_class_2: 0.9316 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8689 - iou_class_2: 0.8725 - iou_coef_multiclass: 0.9963 - loss: 0.0985 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9043 - val_dice_class_2: 0.8731 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8263 - val_iou_class_2: 0.7769 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1490 - learning_rate: 4.5000e-05
# Epoch 23/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9299 - dice_class_2: 0.9300 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8693 - iou_class_2: 0.8698 - iou_coef_multiclass: 0.9964 - loss: 0.0989
# Epoch 23: val_loss improved from 0.14197 to 0.13817, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 146ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9299 - dice_class_2: 0.9300 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8693 - iou_class_2: 0.8698 - iou_coef_multiclass: 0.9964 - loss: 0.0989 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9061 - val_dice_class_2: 0.8905 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8296 - val_iou_class_2: 0.8039 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1382 - learning_rate: 4.5000e-05
# Epoch 24/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9297 - dice_class_2: 0.9318 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8689 - iou_class_2: 0.8732 - iou_coef_multiclass: 0.9963 - loss: 0.0980
# Epoch 24: val_loss did not improve from 0.13817
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9297 - dice_class_2: 0.9318 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8689 - iou_class_2: 0.8732 - iou_coef_multiclass: 0.9963 - loss: 0.0980 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9060 - val_dice_class_2: 0.8902 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8290 - val_iou_class_2: 0.8036 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1382 - learning_rate: 4.5000e-05
# Epoch 25/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9284 - dice_class_2: 0.9317 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8669 - iou_class_2: 0.8730 - iou_coef_multiclass: 0.9963 - loss: 0.0981
# Epoch 25: val_loss did not improve from 0.13817
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9982 - dice_class_0: 0.9994 - dice_class_1: 0.9285 - dice_class_2: 0.9317 - dice_coef_multiclass: 0.9981 - iou_class_0: 0.9988 - iou_class_1: 0.8669 - iou_class_2: 0.8730 - iou_coef_multiclass: 0.9963 - loss: 0.0981 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9016 - val_dice_class_2: 0.8830 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8218 - val_iou_class_2: 0.7922 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1443 - learning_rate: 4.5000e-05
# Epoch 26/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9313 - dice_class_2: 0.9327 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8717 - iou_class_2: 0.8744 - iou_coef_multiclass: 0.9964 - loss: 0.0963
# Epoch 26: val_loss did not improve from 0.13817
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.3500000204658135e-05.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9312 - dice_class_2: 0.9327 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8717 - iou_class_2: 0.8744 - iou_coef_multiclass: 0.9964 - loss: 0.0963 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9035 - val_dice_class_2: 0.8839 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8251 - val_iou_class_2: 0.7933 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1433 - learning_rate: 4.5000e-05
# Epoch 27/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9321 - dice_class_2: 0.9350 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8732 - iou_class_2: 0.8786 - iou_coef_multiclass: 0.9965 - loss: 0.0938
# Epoch 27: val_loss did not improve from 0.13817
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9321 - dice_class_2: 0.9350 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8732 - iou_class_2: 0.8786 - iou_coef_multiclass: 0.9965 - loss: 0.0938 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9069 - val_dice_class_2: 0.8851 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8306 - val_iou_class_2: 0.7965 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1391 - learning_rate: 1.3500e-05
# Epoch 28/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9301 - dice_class_2: 0.9387 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8698 - iou_class_2: 0.8849 - iou_coef_multiclass: 0.9964 - loss: 0.0933
# Epoch 28: val_loss improved from 0.13817 to 0.13783, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 147ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9301 - dice_class_2: 0.9387 - dice_coef_multiclass: 0.9982 - iou_class_0: 0.9988 - iou_class_1: 0.8698 - iou_class_2: 0.8849 - iou_coef_multiclass: 0.9964 - loss: 0.0933 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9074 - val_dice_class_2: 0.8897 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8312 - val_iou_class_2: 0.8022 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1378 - learning_rate: 1.3500e-05
# Epoch 29/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9334 - dice_class_2: 0.9354 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8754 - iou_class_2: 0.8793 - iou_coef_multiclass: 0.9966 - loss: 0.0927
# Epoch 29: val_loss did not improve from 0.13783
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9334 - dice_class_2: 0.9354 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8754 - iou_class_2: 0.8793 - iou_coef_multiclass: 0.9966 - loss: 0.0927 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9061 - val_dice_class_2: 0.8914 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8289 - val_iou_class_2: 0.8052 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1387 - learning_rate: 1.3500e-05
# Epoch 30/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9341 - dice_class_2: 0.9385 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8767 - iou_class_2: 0.8847 - iou_coef_multiclass: 0.9966 - loss: 0.0917
# Epoch 30: val_loss did not improve from 0.13783
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9341 - dice_class_2: 0.9385 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8767 - iou_class_2: 0.8847 - iou_coef_multiclass: 0.9966 - loss: 0.0917 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9075 - val_dice_class_2: 0.8865 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8314 - val_iou_class_2: 0.7972 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1393 - learning_rate: 1.3500e-05
# Epoch 31/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9343 - dice_class_2: 0.9378 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8768 - iou_class_2: 0.8833 - iou_coef_multiclass: 0.9966 - loss: 0.0906
# Epoch 31: val_loss did not improve from 0.13783
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 4.050000006827758e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9343 - dice_class_2: 0.9378 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8768 - iou_class_2: 0.8833 - iou_coef_multiclass: 0.9966 - loss: 0.0906 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9052 - val_dice_class_2: 0.8894 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8282 - val_iou_class_2: 0.8023 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1391 - learning_rate: 1.3500e-05
# Epoch 32/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9333 - dice_class_2: 0.9387 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8753 - iou_class_2: 0.8849 - iou_coef_multiclass: 0.9966 - loss: 0.0916
# Epoch 32: val_loss improved from 0.13783 to 0.13462, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 146ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9334 - dice_class_2: 0.9387 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8754 - iou_class_2: 0.8849 - iou_coef_multiclass: 0.9966 - loss: 0.0916 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9120 - val_dice_class_2: 0.8903 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8386 - val_iou_class_2: 0.8033 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1346 - learning_rate: 4.0500e-06
# Epoch 33/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9343 - dice_class_2: 0.9388 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8771 - iou_class_2: 0.8851 - iou_coef_multiclass: 0.9966 - loss: 0.0898
# Epoch 33: val_loss did not improve from 0.13462
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9343 - dice_class_2: 0.9388 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8771 - iou_class_2: 0.8851 - iou_coef_multiclass: 0.9966 - loss: 0.0898 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9052 - val_dice_class_2: 0.8933 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8276 - val_iou_class_2: 0.8083 - val_iou_coef_multiclass: 0.9953 - val_loss: 0.1383 - learning_rate: 4.0500e-06
# Epoch 34/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9339 - dice_class_2: 0.9377 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8762 - iou_class_2: 0.8832 - iou_coef_multiclass: 0.9966 - loss: 0.0912
# Epoch 34: val_loss did not improve from 0.13462
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9339 - dice_class_2: 0.9377 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8762 - iou_class_2: 0.8832 - iou_coef_multiclass: 0.9966 - loss: 0.0912 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9069 - val_dice_class_2: 0.8852 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8305 - val_iou_class_2: 0.7952 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1406 - learning_rate: 4.0500e-06
# Epoch 35/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9332 - dice_class_2: 0.9383 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8752 - iou_class_2: 0.8847 - iou_coef_multiclass: 0.9965 - loss: 0.0904
# Epoch 35: val_loss did not improve from 0.13462
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1.2149999747634864e-06.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9983 - dice_class_0: 0.9994 - dice_class_1: 0.9332 - dice_class_2: 0.9383 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8752 - iou_class_2: 0.8847 - iou_coef_multiclass: 0.9965 - loss: 0.0904 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9076 - val_dice_class_2: 0.8876 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8314 - val_iou_class_2: 0.7994 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1384 - learning_rate: 4.0500e-06
# Epoch 36/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9353 - dice_class_2: 0.9388 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8788 - iou_class_2: 0.8851 - iou_coef_multiclass: 0.9967 - loss: 0.0896
# Epoch 36: val_loss did not improve from 0.13462
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9353 - dice_class_2: 0.9388 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8788 - iou_class_2: 0.8851 - iou_coef_multiclass: 0.9967 - loss: 0.0896 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9097 - val_dice_class_2: 0.8930 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8349 - val_iou_class_2: 0.8075 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1348 - learning_rate: 1.2150e-06
# Epoch 37/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9325 - dice_class_2: 0.9410 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8740 - iou_class_2: 0.8890 - iou_coef_multiclass: 0.9966 - loss: 0.0909
# Epoch 37: val_loss did not improve from 0.13462
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9325 - dice_class_2: 0.9410 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8740 - iou_class_2: 0.8890 - iou_coef_multiclass: 0.9966 - loss: 0.0908 - val_accuracy: 0.9977 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9022 - val_dice_class_2: 0.8884 - val_dice_coef_multiclass: 0.9976 - val_iou_class_0: 0.9986 - val_iou_class_1: 0.8233 - val_iou_class_2: 0.8002 - val_iou_coef_multiclass: 0.9952 - val_loss: 0.1429 - learning_rate: 1.2150e-06
# Epoch 38/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9335 - dice_class_2: 0.9394 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8756 - iou_class_2: 0.8862 - iou_coef_multiclass: 0.9966 - loss: 0.0904
# Epoch 38: val_loss improved from 0.13462 to 0.13301, saving model to results/Deeper_Focal_MC_GlaucomaScoring.keras
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9335 - dice_class_2: 0.9394 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8756 - iou_class_2: 0.8862 - iou_coef_multiclass: 0.9966 - loss: 0.0904 - val_accuracy: 0.9979 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9125 - val_dice_class_2: 0.8928 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9988 - val_iou_class_1: 0.8395 - val_iou_class_2: 0.8072 - val_iou_coef_multiclass: 0.9957 - val_loss: 0.1330 - learning_rate: 1.2150e-06
# Epoch 39/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9336 - dice_class_2: 0.9401 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8758 - iou_class_2: 0.8877 - iou_coef_multiclass: 0.9966 - loss: 0.0890
# Epoch 39: val_loss did not improve from 0.13301
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9336 - dice_class_2: 0.9401 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8758 - iou_class_2: 0.8877 - iou_coef_multiclass: 0.9966 - loss: 0.0890 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9067 - val_dice_class_2: 0.8900 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8302 - val_iou_class_2: 0.8033 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1378 - learning_rate: 1.2150e-06
# Epoch 40/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9346 - dice_class_2: 0.9412 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8775 - iou_class_2: 0.8894 - iou_coef_multiclass: 0.9966 - loss: 0.0884
# Epoch 40: val_loss did not improve from 0.13301
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9346 - dice_class_2: 0.9412 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8775 - iou_class_2: 0.8893 - iou_coef_multiclass: 0.9966 - loss: 0.0884 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9067 - val_dice_class_2: 0.8860 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8301 - val_iou_class_2: 0.7967 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1410 - learning_rate: 1.2150e-06
# Epoch 41/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9348 - dice_class_2: 0.9386 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8779 - iou_class_2: 0.8850 - iou_coef_multiclass: 0.9967 - loss: 0.0903
# Epoch 41: val_loss did not improve from 0.13301
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 3.644999992502562e-07.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9348 - dice_class_2: 0.9386 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8779 - iou_class_2: 0.8850 - iou_coef_multiclass: 0.9967 - loss: 0.0903 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9091 - val_dice_class_2: 0.8922 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8341 - val_iou_class_2: 0.8063 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1364 - learning_rate: 1.2150e-06
# Epoch 42/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9332 - dice_class_2: 0.9367 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8752 - iou_class_2: 0.8816 - iou_coef_multiclass: 0.9966 - loss: 0.0920
# Epoch 42: val_loss did not improve from 0.13301
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9332 - dice_class_2: 0.9367 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8752 - iou_class_2: 0.8816 - iou_coef_multiclass: 0.9966 - loss: 0.0920 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9056 - val_dice_class_2: 0.8889 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8282 - val_iou_class_2: 0.8014 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1398 - learning_rate: 3.6450e-07
# Epoch 43/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9364 - dice_class_2: 0.9397 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8806 - iou_class_2: 0.8869 - iou_coef_multiclass: 0.9967 - loss: 0.0885
# Epoch 43: val_loss did not improve from 0.13301
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9364 - dice_class_2: 0.9397 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8806 - iou_class_2: 0.8869 - iou_coef_multiclass: 0.9967 - loss: 0.0885 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9093 - val_dice_class_2: 0.8898 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8343 - val_iou_class_2: 0.8028 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1358 - learning_rate: 3.6450e-07
# Epoch 44/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9356 - dice_class_2: 0.9397 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8793 - iou_class_2: 0.8870 - iou_coef_multiclass: 0.9967 - loss: 0.0882
# Epoch 44: val_loss did not improve from 0.13301
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 1.0935000318568199e-07.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 126ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9356 - dice_class_2: 0.9397 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8793 - iou_class_2: 0.8870 - iou_coef_multiclass: 0.9967 - loss: 0.0882 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9066 - val_dice_class_2: 0.8894 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8302 - val_iou_class_2: 0.8023 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1385 - learning_rate: 3.6450e-07
# Epoch 45/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9363 - dice_class_2: 0.9402 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8805 - iou_class_2: 0.8878 - iou_coef_multiclass: 0.9967 - loss: 0.0883
# Epoch 45: val_loss did not improve from 0.13301
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9984 - dice_class_0: 0.9994 - dice_class_1: 0.9363 - dice_class_2: 0.9402 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8805 - iou_class_2: 0.8878 - iou_coef_multiclass: 0.9967 - loss: 0.0883 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9074 - val_dice_class_2: 0.8911 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8316 - val_iou_class_2: 0.8046 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1371 - learning_rate: 1.0935e-07
# Epoch 46/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9352 - dice_class_2: 0.9395 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8785 - iou_class_2: 0.8864 - iou_coef_multiclass: 0.9966 - loss: 0.0894
# Epoch 46: val_loss did not improve from 0.13301
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9352 - dice_class_2: 0.9395 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8785 - iou_class_2: 0.8864 - iou_coef_multiclass: 0.9966 - loss: 0.0894 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9088 - val_dice_class_2: 0.8896 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8334 - val_iou_class_2: 0.8023 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1376 - learning_rate: 1.0935e-07
# Epoch 47/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9362 - dice_class_2: 0.9393 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8804 - iou_class_2: 0.8861 - iou_coef_multiclass: 0.9967 - loss: 0.0885
# Epoch 47: val_loss did not improve from 0.13301
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1e-07.
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9362 - dice_class_2: 0.9393 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8804 - iou_class_2: 0.8861 - iou_coef_multiclass: 0.9967 - loss: 0.0885 - val_accuracy: 0.9978 - val_dice_class_0: 0.9993 - val_dice_class_1: 0.9053 - val_dice_class_2: 0.8884 - val_dice_coef_multiclass: 0.9977 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8279 - val_iou_class_2: 0.8008 - val_iou_coef_multiclass: 0.9954 - val_loss: 0.1401 - learning_rate: 1.0935e-07
# Epoch 48/50
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9353 - dice_class_2: 0.9389 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8788 - iou_class_2: 0.8854 - iou_coef_multiclass: 0.9967 - loss: 0.0890
# Epoch 48: val_loss did not improve from 0.13301
# 150/150 ━━━━━━━━━━━━━━━━━━━━ 19s 125ms/step - accuracy: 0.9984 - dice_class_0: 0.9995 - dice_class_1: 0.9353 - dice_class_2: 0.9389 - dice_coef_multiclass: 0.9983 - iou_class_0: 0.9989 - iou_class_1: 0.8788 - iou_class_2: 0.8854 - iou_coef_multiclass: 0.9967 - loss: 0.0890 - val_accuracy: 0.9978 - val_dice_class_0: 0.9994 - val_dice_class_1: 0.9085 - val_dice_class_2: 0.8907 - val_dice_coef_multiclass: 0.9978 - val_iou_class_0: 0.9987 - val_iou_class_1: 0.8328 - val_iou_class_2: 0.8039 - val_iou_coef_multiclass: 0.9955 - val_loss: 0.1365 - learning_rate: 1.0000e-07
# Epoch 48: early stopping
# Restoring model weights from the end of the best epoch: 38.
# ✓ Training completed
#
# Generating visualizations...
#   ✓ Saved: results/Deeper_Focal_MC_GlaucomaScoring_history.png
#   ✓ Saved: results/Deeper_Focal_MC_GlaucomaScoring_predictions_cdr.png
# ================================================================================
# EVALUATION: Deeper+Focal+MC+GlaucomaScoring
# ================================================================================
#   ✓ Saved: results/Deeper+Focal+MC+GlaucomaScoring_confusion_matrices.png
# Confusion Matrix:
# [[25767060    17930        0]
#  [   15021   291039     9011]
#  [      52    14865    99422]]
#
# Normalized Confusion Matrix:
# [[0.999 0.001 0.   ]
#  [0.048 0.924 0.029]
#  [0.    0.13  0.87 ]]
#
# Precision, Recall, F1 Score per class:
#   Background: Precision=0.9994, Recall=0.9993, F1=0.9994
#   Disc: Precision=0.8987, Recall=0.9237, F1=0.9111
#   Cup: Precision=0.9169, Recall=0.8695, F1=0.8926
#
# Macro-averaged metrics:
#   Precision: 0.9383
#   Recall: 0.9309
#   F1 Score: 0.9343
#   Background: Dice=0.9994, IoU=0.9987
#   Disc: Dice=0.9111, IoU=0.8366
#   Cup: Dice=0.8926, IoU=0.8060
#
# ================================================================================
# GLAUCOMA PROGRESSION ANALYSIS
# ================================================================================
#
# Method:
#   1. Calculate vCDR from GT masks (Expert Annotations)
#   2. Calculate vCDR from Predicted masks (MobileNet Segmentation)
#   3. Classify progression severity using vCDR thresholds
#   4. Compare GT progression vs Predicted progression
#
# CDR Method: Vertical diameter ratio (clinical standard)
# Severity Thresholds:
#   - Normal:   vCDR < 0.3
#   - Suspect:  0.3 ≤ vCDR < 0.6
#   - Moderate: 0.6 ≤ vCDR < 0.75
#   - Critical: vCDR ≥ 0.75
#
# --------------------------------------------------------------------------------
# CDR Statistics:
# --------------------------------------------------------------------------------
#   Mean GT CDR:   0.4788 ± 0.1008
#   Mean Pred CDR: 0.0727 ± 0.0180
#   Mean CDR Error: 0.4061 ± 0.0872
#
# ================================================================================
# PROGRESSION CLASSIFICATION ACCURACY
# ================================================================================
#
# Overall Accuracy: 0.25%
#   - Correctly Classified: 1/400 samples
#   - Incorrectly Classified: 399/400 samples
#
# --------------------------------------------------------------------------------
# Per-Class Results:
# --------------------------------------------------------------------------------
# Severity     GT Count     Pred Count   Correct      Accuracy
# --------------------------------------------------------------------------------
# Normal       1            400          1            100.00      %
# Suspect      355          0            0            0.00        %
# Moderate     33           0            0            0.00        %
# Critical     11           0            0            0.00        %
#
# ================================================================================
# INTERPRETATION EXAMPLE:
# ================================================================================
#   - GT says 'Normal' for 1 images
#   - MobileNet model says 'Normal' for 400 images
#   - MobileNet correctly predicts 1 as 'Normal'
#   - Accuracy for Normal class: 1/1 = 100.0%
#
# ================================================================================
# MANUAL REVIEW RECOMMENDATIONS
# ================================================================================
#
# Samples Requiring Manual Review: 399/400 (99.8%)
#
# Criteria for Manual Review:
#   1. All Critical cases (high-risk, requires expert verification)
#   2. Classification mismatches (GT ≠ Predicted severity)
#
# Reason: Critical cases need expert confirmation, and mismatches may
# indicate borderline cases or segmentation issues requiring review.
#
# Breakdown:
#   - Critical cases: 11 samples
#   - Classification mismatches: 399 samples
#   - Overlap (Critical + Mismatch): 11 samples
#
# ✓ Saved: results/glaucoma_progression_analysis.csv
#   ✓ Saved: results/cdr_analysis.png
# ================================================================================
# MC DROPOUT UNCERTAINTY ESTIMATION
# ================================================================================
#
# Running MC Dropout with 15 stochastic forward passes...
#   Completed: 5/15 forward passes
#   Completed: 10/15 forward passes
#   Completed: 15/15 forward passes
# ✓ MC Dropout completed
#   Background uncertainty: 0.0003
#   Disc uncertainty: 0.0004
#   Cup uncertainty: 0.0002
#
# ====================================================================================================
#                                 ✓ TRAINING AND EVALUATION COMPLETED!
# ====================================================================================================
#
# Model: Deeper + Focal + EIoU + MC Dropout + Glaucoma Scoring
# Parameters: 37,129,475
# Results saved in: results/
#
# Generated Files:
#   - Training history: results/Deeper_Focal_MC_GlaucomaScoring_history.png
#   - Predictions with CDR: results/Deeper_Focal_MC_GlaucomaScoring_predictions_cdr.png
#   - CDR Analysis: results/cdr_analysis.png
#   - Progression CSV: results/glaucoma_progression_analysis.csv
#   - Confusion Matrices: results/Deeper+Focal+MC+GlaucomaScoring_confusion_matrices.png
#
# ====================================================================================================
